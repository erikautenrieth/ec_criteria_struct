# %%
import numpy as np

# Operator Metriken 
precision = np.array([82.7, 83.0, 81.0, 82.5, 83.2, 82.7, 82.6, 83.1, 82.7, 81.1, 83.1, 82.6, 82.2, 81.9, 82.1, 80.7, 81.8, 82.6, 81.8, 81.6])
recall = np.array([81.7, 83.0, 84.0, 82.8, 82.9, 84.2, 83.1, 83.3, 83.8, 82.8, 81.8, 83.3, 82.6, 83.6, 83.5, 82.3, 82.8, 82.0, 82.0, 81.2])
f1_score = np.array([82.1, 82.8, 82.3, 82.5, 82.9, 83.2, 82.8, 83.1, 83.1, 81.8, 82.4, 82.8, 82.3, 82.6, 82.7, 81.3, 82.2, 82.2, 81.8, 81.3])
precision_mean = np.mean(precision)
recall_mean = np.mean(recall)
f1_score_mean = np.mean(f1_score)
precision_std = np.std(precision)
recall_std = np.std(recall)
f1_score_std = np.std(f1_score)

print("Operator Metrics:")
print(f"Precision: Mean = {precision_mean:.2f}, Std Dev = {precision_std:.2f}")
print(f"Recall: Mean = {recall_mean:.2f}, Std Dev = {recall_std:.2f}")
print(f"F1-Score: Mean = {f1_score_mean:.2f}, Std Dev = {f1_score_std:.2f}")
# Out:
# Operator Metrics:
# Precision: Mean = 82.25, Std Dev = 0.71
# Recall: Mean = 82.84, Std Dev = 0.79
# F1-Score: Mean = 82.41, Std Dev = 0.54

# %%
# Total Entity Extraction Metrics
precision = np.array([90.7, 90.4, 90.4, 90.7, 90.6, 90.5, 90.2, 90.8, 90.6, 90.6, 90.7, 90.0, 90.1, 90.2, 90.6, 90.8, 90.6, 90.3, 90.4, 90.7])
recall = np.array([87.0, 87.3, 87.8, 87.2, 87.4, 87.2, 86.9, 87.2, 86.8, 87.4, 87.4, 86.9, 87.0, 87.6, 87.7, 87.5, 87.1, 86.9, 86.8, 87.7])
f1_score = np.array([88.8, 88.8, 89.1, 88.9, 89.0, 88.8, 88.6, 89.0, 88.7, 89.0, 89.0, 88.4, 88.5, 88.9, 89.2, 89.1, 88.8, 88.6, 88.6, 89.2])
precision_mean = np.mean(precision)
recall_mean = np.mean(recall)
f1_score_mean = np.mean(f1_score)
precision_std = np.std(precision)
recall_std = np.std(recall)
f1_score_std = np.std(f1_score)
# Print results
print("Entity Extraction Metrics:")
print(f"Precision: Mean = {precision_mean:.2f}, Std Dev = {precision_std:.2f}")
print(f"Recall: Mean = {recall_mean:.2f}, Std Dev = {recall_std:.2f}")
print(f"F1-Score: Mean = {f1_score_mean:.2f}, Std Dev = {f1_score_std:.2f}")
# Out:
# Entity Extraction Metrics:
# Precision: Mean = 90.50, Std Dev = 0.23
# Recall: Mean = 87.24, Std Dev = 0.31
# F1-Score: Mean = 88.85, Std Dev = 0.22
