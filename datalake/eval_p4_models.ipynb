# %%
import os
import shutil
import json
import re
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from struct_eval_functions import *
from struct_plot_funcitons import *

# %% [markdown]
# ### JSON to Text

# %%
def process_node(node):
    if 'raw_text' in node:
        return node['raw_text'].strip()

    if 'AND' in node:
        left_text = process_node(node['AND']['left'])
        right_text = process_node(node['AND']['right'])
        return combine_texts(left_text, right_text, '[AND]')

    if 'OR' in node:
        left_text = process_node(node['OR']['left'])
        right_text = process_node(node['OR']['right'])
        return combine_texts(left_text, right_text, '[OR]')

    if 'NOT' in node:
        left_text = process_node(node['NOT']['left'])
        return f"[NOT] {left_text}"

    return ""


def combine_texts(left_text, right_text, operator):
    ### Hier muss es bearbeitet werden Entweder lösche AND am ENDE oder nicht
    #if operator == '[AND]' and (left_text.strip().endswith('.') or right_text.strip().startswith('-')):
    #    return f"{left_text}\n{right_text}"
    combined = f"{left_text.strip()} {operator} {right_text.strip()}"
    if operator == '[AND]' and not right_text.strip():
        return combined + '\n'
    return combined


def json_to_text(json_file_path):
    with open(json_file_path, 'r', encoding="utf-8") as f:
        data = json.load(f)
    text = process_node(data)
    lines = [line.strip() for line in text.split('\n') if line.strip()]
    return '\n'.join(lines)

def process_all_files_in_directory(directory_path, output_directory, failure_directory):
    os.makedirs(output_directory, exist_ok=True)
    os.makedirs(failure_directory, exist_ok=True)

    for filename in os.listdir(directory_path):
        if filename.endswith("_exc.json") or filename.endswith("_inc.json"):
            json_file_path = os.path.join(directory_path, filename)
            try:
                output_text = json_to_text(json_file_path)
                output_file_path = os.path.join(output_directory, os.path.splitext(filename)[0] + ".txt")
                with open(output_file_path, 'w', encoding="utf-8") as output_file:
                    output_file.write(output_text)
                print(f"Processed file: {filename}")
            except Exception as e:
                print(f"Failed to process file: {filename} - Error: {e}")
                shutil.move(json_file_path, os.path.join(failure_directory, filename))
                print(os.path.join(failure_directory, filename))

# %% [markdown]
# ## Calculate Entity Metrics

# %%
def visit(node, category, entities):
    if isinstance(node, dict):
        if category in node:
            entities.extend(node[category])
        for value in node.values():
            visit(value, category, entities)
    elif isinstance(node, list):
        for item in node:
            visit(item, category, entities)

def calculate_metrics(label_data, model_data, metrics):
    for category in categories:
        label_entities = []
        visit(label_data, category, label_entities)
        model_entities = []
        visit(model_data, category, model_entities)

        true_positives = sum(entity in label_entities for entity in model_entities)
        false_positives = sum(entity not in label_entities for entity in model_entities)
        false_negatives = sum(entity not in model_entities for entity in label_entities)

        metrics[category]['true_positives'] += true_positives
        metrics[category]['false_positives'] += false_positives
        metrics[category]['false_negatives'] += false_negatives

        # Count total entities in labels and model outputs
        metrics[category]['total_label_entities'] += len(label_entities)
        metrics[category]['total_model_entities'] += len(model_entities)

def process_files(label_folder, model_folder):
    metrics = {category: {'true_positives': 0, 'false_positives': 0, 'false_negatives': 0,
                          'total_label_entities': 0, 'total_model_entities': 0} for category in categories}
    for filename in os.listdir(model_folder):
        if filename.endswith('.json'):
            model_path = os.path.join(model_folder, filename)
            match = re.search(r'NCT\d+_(?:exc|inc)', filename)
            if match:
                label_filename = f"{match.group(0)}.json"
                label_path = os.path.join(label_folder, label_filename)

                if os.path.exists(label_path):
                    try:
                        with open(label_path, 'r', encoding='utf-8') as label_file, open(model_path, 'r', encoding='utf-8') as model_file:
                            label_data = json.load(label_file)
                            model_data = json.load(model_file)

                            calculate_metrics(label_data, model_data, metrics)
                    except json.JSONDecodeError as e:
                        print(f"Error decoding JSON file: {model_path}")
                        print(f"Error message: {str(e)}")

    for category in categories:
        true_positives = metrics[category]['true_positives']
        false_positives = metrics[category]['false_positives']
        false_negatives = metrics[category]['false_negatives']

        precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        accuracy = true_positives / (true_positives + false_positives + false_negatives) if (true_positives + false_positives + false_negatives) > 0 else 0

        metrics[category]['precision'] = precision
        metrics[category]['recall'] = recall
        metrics[category]['f1'] = f1
        metrics[category]['accuracy'] = accuracy

    return metrics

# %%
models = get_models('model_output/eval_p4/')
models = ['Llama3_70b_Fine-Tuned_p4_ep10_p1']

# %%
categories =  ['Contraindication', 'Eq-Value', 'Severity', 'Drug', 'Observation-Name', 'Age', 'Location', 'Organism-Name', 'Encounter', 'Drug-Name', 'Ethnicity', 'Modifier', 'Condition', 'Eq-Unit', 'Eq-Temporal-Unit', 'Family-Member', 'Organism', 'Other', 'Immunization-Name', 'Polarity', 'Condition-Type', 'Immunization', 'Eq-Operator', 'Eq-Temporal-Recency', 'Procedure-Name', 'Indication', 'Exception', 'Study', 'Language', 'Coreference', 'Provider', 'Acuteness', 'Life-Stage-And-Gender', 'Procedure', 'Risk', 'Death', 'Assertion', 'Allergy-Name', 'Specimen', 'Negation', 'Code', 'Stability', 'Birth', 'Criteria-Count', 'Eq-Comparison', 'Condition-Name', 'Insurance', 'Observation', 'Allergy', 'Eq-Temporal-Period']

label_folder = "../input/lct_p4" # ../input/dataset_p4/test/output"

# %%
# Berechne den Durchschnitt der Metriken für alle Entitäten
def calculate_average_metrics(metrics):
    total_metrics = {
        'true_positives': 0,
        'false_positives': 0,
        'false_negatives': 0,
        'total_label_entities': 0,
        'total_model_entities': 0,
        'precision': 0,
        'recall': 0,
        'f1': 0,
        'accuracy': 0
    }
    num_entities = 50

    for entity, entity_metrics in metrics.items():
        if entity != 'total':
            for key in total_metrics.keys():
                total_metrics[key] += entity_metrics[key]

    print(total_metrics)
    for key in ['precision', 'recall', 'f1', 'accuracy']:
        total_metrics[key] /= num_entities

    metrics['total'] = total_metrics
    return metrics


def calculate_totals_based_on_tp(metrics):
    total_tp = 0
    total_fp = 0
    total_fn = 0
    valid_entities_count = 0

    for entity, values in metrics.items():
        if entity != 'total':
            total_tp += values['true_positives']
            total_fp += values['false_positives']
            total_fn += values['false_negatives']
            valid_entities_count += 1

    total_precision = total_tp / (total_tp + total_fp) if (total_tp + total_fp) > 0 else 0
    total_recall = total_tp / (total_tp + total_fn) if (total_tp + total_fn) > 0 else 0
    total_f1 = 2 * (total_precision * total_recall) / (total_precision + total_recall) if (total_precision + total_recall) > 0 else 0

    metrics['total'] = {
        'true_positives': total_tp,
        'false_positives': total_fp,
        'false_negatives': total_fn,
        'precision': total_precision,
        'recall': total_recall,
        'f1': total_f1
    }

    return metrics

# %% [markdown]
# #### Filter failure model files

# %%
for model_name in models:
    model_folder = f"model_output/eval_p4/{model_name}/output"
    ready_folder = f"model_output/eval_p4/{model_name}/ready"
    failure_folder = f"model_output/eval_p4/{model_name}/failure"
    process_failure_folder = f"model_output/eval_p4/{model_name}/processed_output"
    ## Filter Failure Files
    read_and_process_files(model_path="model_output/eval_p4" ,model_name=model_name)

    ## JSON to Text
    process_all_files_in_directory(ready_folder, process_failure_folder, failure_folder)

    ## Calculate Entity Metrics
    metrics = process_files(label_folder, ready_folder)
    metrics = calculate_totals_based_on_tp(metrics)
    print(f"Metrics for model: {model_name}\n")
    plot_file_counts(model_name)
    #plot_metrics(model_name, metrics)
# Out:
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860220_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860259_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860311_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860324_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860363_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860402_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860402_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860428_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860493_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860545_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860597_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860610_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860623_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860662_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860688_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860701_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860753_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03860766_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861078_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861104_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861182_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861195_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861221_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861312_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861325_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861377_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861442_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861507_inc.json
# JSON syntax error in file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861715_exc.json - Error: Extra data: line 228 column 2 (char 8449)
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861715_inc.json
# Failed to process file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861806_exc.json - Error: 'right'
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861845_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861858_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861962_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03861988_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862027_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862066_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862105_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862209_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862209_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862235_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862274_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862287_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862404_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862417_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862456_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862469_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862521_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862547_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862573_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862612_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862690_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862742_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862781_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862846_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03862963_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863067_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863080_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863158_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863171_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863197_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863210_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863210_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863275_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863353_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863366_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863405_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863496_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863509_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863548_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863548_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863561_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863561_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863600_exc.json
# JSON syntax error in file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863639_inc.json - Error: Unterminated string starting at: line 396 column 27 (char 19376)
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863691_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863691_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863717_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863756_exc.json
# JSON syntax error in file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863847_exc.json - Error: Expecting value: line 426 column 31 (char 23385)
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863847_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863925_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03863938_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864094_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864120_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864133_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864172_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864198_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864263_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864276_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864302_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864302_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864354_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864484_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864497_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864614_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864640_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864705_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864757_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864757_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864770_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864796_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864796_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864809_inc.json
# JSON syntax error in file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864822_exc.json - Error: Expecting property name enclosed in double quotes: line 447 column 21 (char 17272)
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864887_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03864887_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865056_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865108_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865173_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865173_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865186_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865199_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865225_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865251_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865303_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865329_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865342_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865407_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865420_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865420_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865498_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865589_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865602_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865641_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865680_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865706_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865732_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865732_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865758_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865784_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865823_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865862_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865953_exc.json
# Failed to process file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865953_inc.json - Error: 'right'
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03865966_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866031_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866148_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866291_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866291_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866356_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866564_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866590_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866642_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866746_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866746_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866863_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866863_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866876_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866902_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866915_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03866941_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867045_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867045_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867227_inc.json
# JSON syntax error in file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867344_exc.json - Error: Expecting property name enclosed in double quotes: line 434 column 25 (char 26111)
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867344_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867370_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867552_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867552_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867617_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867643_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867682_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867695_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867721_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867760_exc.json
# JSON syntax error in file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867903_exc.json - Error: Extra data: line 97 column 1 (char 2807)
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867903_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867916_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867916_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03867942_exc.json
# JSON syntax error in file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867942_inc.json - Error: Expecting property name enclosed in double quotes: line 410 column 27 (char 22665)
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868033_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868111_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868332_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868358_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868371_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868475_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868579_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868631_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868657_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868709_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868774_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868826_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868891_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868904_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868995_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03868995_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869021_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869073_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869112_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869151_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869281_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869294_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869398_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869424_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869424_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869489_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869502_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869541_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869554_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869580_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869593_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869645_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869645_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869710_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869723_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869814_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869879_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869905_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869957_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869970_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03869996_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03920046_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03920098_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03920267_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03920306_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03920514_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03920579_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03920748_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03920800_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03920891_exc.json
# Failed to process file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03920917_exc.json - Error: 'right'
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03920930_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921060_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921125_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921138_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921216_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921307_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921476_inc.json
# JSON syntax error in file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921502_exc.json - Error: Expecting ',' delimiter: line 410 column 62 (char 27959)
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921632_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921697_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921710_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921749_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921762_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921775_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921905_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921944_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03921983_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922178_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922230_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922243_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922269_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922321_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922347_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922425_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922542_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922568_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922607_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922659_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922737_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922815_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922828_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922841_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922841_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922906_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922958_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922958_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03922971_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923140_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923153_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923192_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923205_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923218_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923335_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923335_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923400_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923413_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923439_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923439_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923465_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923595_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923595_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923647_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923764_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923816_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923920_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923933_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923946_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923959_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03923998_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924024_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924037_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924180_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924206_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924232_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924232_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924284_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924284_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924362_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924375_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924453_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924479_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924492_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924492_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924505_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924544_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924609_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924609_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924687_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924726_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924752_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924817_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924908_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03924921_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925116_inc.json
# JSON syntax error in file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925142_exc.json - Error: Unterminated string starting at: line 430 column 13 (char 22270)
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925168_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925181_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925298_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925363_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925389_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925441_inc.json
# JSON syntax error in file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925454_exc.json - Error: Expecting value: line 421 column 25 (char 20355)
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925506_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925519_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925558_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925584_inc.json
# Failed to process file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925610_exc.json - Error: 'right'
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925649_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925662_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925675_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925727_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925727_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925753_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925818_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925844_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925883_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03925987_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926000_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926013_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926078_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926169_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926169_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926221_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926325_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926429_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926533_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926546_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926572_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926585_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926611_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926663_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926676_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926780_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926806_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926832_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926871_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926949_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926949_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03926975_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03927079_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03927300_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03927339_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03927378_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03927456_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03927482_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03927612_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03927638_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03927872_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03927924_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928015_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928054_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928158_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928171_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928288_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928392_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928470_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928470_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928535_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928548_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928782_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928795_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928860_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928873_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928938_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03928977_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929315_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929471_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929510_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929549_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929562_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929575_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929614_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929640_exc.json
# JSON syntax error in file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929679_exc.json - Error: Expecting ':' delimiter: line 104 column 9 (char 3169)
# JSON syntax error in file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929718_exc.json - Error: Unterminated string starting at: line 432 column 27 (char 23789)
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929718_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929731_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929744_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929744_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929770_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929809_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929822_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929874_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929887_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929926_exc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03929991_inc.json
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03930134_inc.json
# Failed to process file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03934034_inc.json - Error: 'right'
# Failed to process file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03934346_exc.json - Error: 'right'
# Successfully processed Llama3_70b_Fine-Tuned_p4_ep10_NCT03934385_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860220_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860259_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860311_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860324_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860363_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860402_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860402_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860428_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860493_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860545_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860597_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860610_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860623_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860662_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860688_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860701_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860753_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03860766_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861078_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861104_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861182_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861195_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861221_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861312_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861325_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861377_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861442_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861507_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861715_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861845_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861858_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861962_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03861988_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862027_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862066_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862105_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862209_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862209_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862235_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862274_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862287_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862404_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862417_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862456_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862469_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862521_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862547_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862573_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862612_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862690_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862742_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862781_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862846_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03862963_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863067_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863080_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863158_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863171_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863197_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863210_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863210_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863275_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863353_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863366_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863405_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863496_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863509_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863548_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863548_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863561_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863561_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863600_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863691_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863691_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863717_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863756_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863847_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863925_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03863938_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864094_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864120_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864133_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864172_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864198_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864263_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864276_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864302_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864302_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864354_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864484_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864497_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864614_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864640_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864705_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864757_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864757_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864770_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864796_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864796_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864809_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864887_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03864887_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865056_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865108_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865173_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865173_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865186_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865199_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865225_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865251_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865303_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865329_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865342_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865407_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865420_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865420_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865498_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865589_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865602_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865641_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865680_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865706_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865732_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865732_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865758_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865784_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865823_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865862_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865953_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03865966_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866031_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866148_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866291_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866291_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866356_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866564_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866590_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866642_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866746_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866746_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866863_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866863_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866876_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866902_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866915_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03866941_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867045_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867045_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867227_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867344_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867370_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867552_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867552_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867617_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867643_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867682_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867695_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867721_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867760_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867903_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867916_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867916_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03867942_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868033_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868111_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868332_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868358_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868371_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868475_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868579_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868631_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868657_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868709_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868774_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868826_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868891_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868904_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868995_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03868995_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869021_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869073_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869112_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869151_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869281_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869294_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869398_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869424_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869424_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869489_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869502_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869541_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869554_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869580_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869593_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869645_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869645_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869710_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869723_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869814_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869879_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869905_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869957_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869970_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03869996_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03920046_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03920098_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03920267_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03920306_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03920514_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03920579_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03920748_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03920800_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03920891_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03920930_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921060_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921125_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921138_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921216_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921307_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921476_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921632_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921697_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921710_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921749_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921762_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921775_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921905_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921944_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03921983_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922178_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922230_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922243_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922269_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922321_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922347_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922425_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922542_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922568_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922607_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922659_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922737_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922815_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922828_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922841_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922841_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922906_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922958_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922958_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03922971_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923140_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923153_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923192_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923205_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923218_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923335_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923335_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923400_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923413_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923439_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923439_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923465_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923595_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923595_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923647_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923764_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923816_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923920_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923933_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923946_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923959_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03923998_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924024_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924037_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924180_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924206_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924232_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924232_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924284_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924284_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924362_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924375_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924453_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924479_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924492_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924492_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924505_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924544_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924609_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924609_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924687_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924726_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924752_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924817_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924908_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03924921_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925116_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925168_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925181_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925298_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925363_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925389_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925441_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925506_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925519_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925558_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925584_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925649_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925662_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925675_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925727_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925727_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925753_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925818_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925844_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925883_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03925987_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926000_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926013_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926078_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926169_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926169_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926221_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926325_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926429_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926533_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926546_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926572_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926585_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926611_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926663_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926676_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926780_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926806_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926832_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926871_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926949_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926949_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03926975_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03927079_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03927300_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03927339_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03927378_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03927456_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03927482_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03927612_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03927638_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03927872_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03927924_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928015_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928054_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928158_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928171_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928288_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928392_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928470_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928470_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928535_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928548_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928782_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928795_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928860_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928873_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928938_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03928977_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929315_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929471_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929510_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929549_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929562_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929575_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929614_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929640_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929718_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929731_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929744_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929744_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929770_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929809_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929822_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929874_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929887_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929926_exc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03929991_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03930134_inc.json
# Processed file: Llama3_70b_Fine-Tuned_p4_ep10_NCT03934385_exc.json
# Metrics for model: Llama3_70b_Fine-Tuned_p4_ep10_p1
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[41], line 16
#      14 metrics = calculate_totals_based_on_tp(metrics)
#      15 print(f"Metrics for model: {model_name}\n")
# ---> 16 plot_file_counts(model_name)
#      17 #plot_metrics(model_name, metrics)
#
# File ~\DataspellProjects\ec_criteria_struct\lct\evaluate_struct\struct_eval_functions.py:204, in plot_file_counts(model_name)
#     202         percentage = 100
#     203     else:
# --> 204         percentage = (count / total_files) * 100
#     205     ax.annotate(f'{count} ({percentage:.1f}%)',
#     206                 xy=(bar.get_x() + bar.get_width() / 2, height),
#     207                 xytext=(0, 3),
#     208                 textcoords="offset points",
#     209                 ha='center', va='bottom', fontsize=9)
#     211 plt.tight_layout()
#
# ZeroDivisionError: division by zero

# %%
metrics
# Out:
# {'Contraindication': {'true_positives': 25,
#   'false_positives': 2,
#   'false_negatives': 2,
#   'total_label_entities': 27,
#   'total_model_entities': 27,
#   'precision': 0.9259259259259259,
#   'recall': 0.9259259259259259,
#   'f1': 0.9259259259259259,
#   'accuracy': 0.8620689655172413},
#  'Eq-Value': {'true_positives': 616,
#   'false_positives': 71,
#   'false_negatives': 111,
#   'total_label_entities': 788,
#   'total_model_entities': 687,
#   'precision': 0.8966521106259098,
#   'recall': 0.8473177441540578,
#   'f1': 0.8712871287128713,
#   'accuracy': 0.7719298245614035},
#  'Severity': {'true_positives': 101,
#   'false_positives': 10,
#   'false_negatives': 9,
#   'total_label_entities': 109,
#   'total_model_entities': 111,
#   'precision': 0.9099099099099099,
#   'recall': 0.9181818181818182,
#   'f1': 0.914027149321267,
#   'accuracy': 0.8416666666666667},
#  'Drug': {'true_positives': 180,
#   'false_positives': 37,
#   'false_negatives': 50,
#   'total_label_entities': 238,
#   'total_model_entities': 217,
#   'precision': 0.8294930875576036,
#   'recall': 0.782608695652174,
#   'f1': 0.8053691275167785,
#   'accuracy': 0.6741573033707865},
#  'Observation-Name': {'true_positives': 266,
#   'false_positives': 137,
#   'false_negatives': 142,
#   'total_label_entities': 406,
#   'total_model_entities': 403,
#   'precision': 0.6600496277915633,
#   'recall': 0.6519607843137255,
#   'f1': 0.655980271270037,
#   'accuracy': 0.48807339449541287},
#  'Age': {'true_positives': 116,
#   'false_positives': 7,
#   'false_negatives': 46,
#   'total_label_entities': 170,
#   'total_model_entities': 123,
#   'precision': 0.943089430894309,
#   'recall': 0.7160493827160493,
#   'f1': 0.8140350877192982,
#   'accuracy': 0.6863905325443787},
#  'Location': {'true_positives': 61,
#   'false_positives': 12,
#   'false_negatives': 32,
#   'total_label_entities': 95,
#   'total_model_entities': 73,
#   'precision': 0.8356164383561644,
#   'recall': 0.6559139784946236,
#   'f1': 0.7349397590361444,
#   'accuracy': 0.580952380952381},
#  'Organism-Name': {'true_positives': 2,
#   'false_positives': 1,
#   'false_negatives': 0,
#   'total_label_entities': 1,
#   'total_model_entities': 3,
#   'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1': 0.8,
#   'accuracy': 0.6666666666666666},
#  'Encounter': {'true_positives': 35,
#   'false_positives': 12,
#   'false_negatives': 24,
#   'total_label_entities': 58,
#   'total_model_entities': 47,
#   'precision': 0.7446808510638298,
#   'recall': 0.5932203389830508,
#   'f1': 0.6603773584905661,
#   'accuracy': 0.49295774647887325},
#  'Drug-Name': {'true_positives': 137,
#   'false_positives': 34,
#   'false_negatives': 55,
#   'total_label_entities': 195,
#   'total_model_entities': 171,
#   'precision': 0.8011695906432749,
#   'recall': 0.7135416666666666,
#   'f1': 0.7548209366391184,
#   'accuracy': 0.6061946902654868},
#  'Ethnicity': {'true_positives': 7,
#   'false_positives': 1,
#   'false_negatives': 1,
#   'total_label_entities': 10,
#   'total_model_entities': 8,
#   'precision': 0.875,
#   'recall': 0.875,
#   'f1': 0.875,
#   'accuracy': 0.7777777777777778},
#  'Modifier': {'true_positives': 410,
#   'false_positives': 267,
#   'false_negatives': 318,
#   'total_label_entities': 743,
#   'total_model_entities': 677,
#   'precision': 0.6056129985228951,
#   'recall': 0.5631868131868132,
#   'f1': 0.5836298932384341,
#   'accuracy': 0.4120603015075377},
#  'Condition': {'true_positives': 1004,
#   'false_positives': 306,
#   'false_negatives': 312,
#   'total_label_entities': 1336,
#   'total_model_entities': 1310,
#   'precision': 0.766412213740458,
#   'recall': 0.7629179331306991,
#   'f1': 0.7646610814927647,
#   'accuracy': 0.6189889025893958},
#  'Eq-Unit': {'true_positives': 140,
#   'false_positives': 36,
#   'false_negatives': 65,
#   'total_label_entities': 233,
#   'total_model_entities': 176,
#   'precision': 0.7954545454545454,
#   'recall': 0.6829268292682927,
#   'f1': 0.7349081364829395,
#   'accuracy': 0.5809128630705395},
#  'Eq-Temporal-Unit': {'true_positives': 295,
#   'false_positives': 23,
#   'false_negatives': 62,
#   'total_label_entities': 390,
#   'total_model_entities': 318,
#   'precision': 0.9276729559748428,
#   'recall': 0.8263305322128851,
#   'f1': 0.8740740740740739,
#   'accuracy': 0.7763157894736842},
#  'Family-Member': {'true_positives': 8,
#   'false_positives': 1,
#   'false_negatives': 12,
#   'total_label_entities': 20,
#   'total_model_entities': 9,
#   'precision': 0.8888888888888888,
#   'recall': 0.4,
#   'f1': 0.5517241379310346,
#   'accuracy': 0.38095238095238093},
#  'Organism': {'true_positives': 2,
#   'false_positives': 1,
#   'false_negatives': 0,
#   'total_label_entities': 1,
#   'total_model_entities': 3,
#   'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1': 0.8,
#   'accuracy': 0.6666666666666666},
#  'Other': {'true_positives': 48,
#   'false_positives': 10,
#   'false_negatives': 8,
#   'total_label_entities': 57,
#   'total_model_entities': 58,
#   'precision': 0.8275862068965517,
#   'recall': 0.8571428571428571,
#   'f1': 0.8421052631578947,
#   'accuracy': 0.7272727272727273},
#  'Immunization-Name': {'true_positives': 2,
#   'false_positives': 2,
#   'false_negatives': 2,
#   'total_label_entities': 4,
#   'total_model_entities': 4,
#   'precision': 0.5,
#   'recall': 0.5,
#   'f1': 0.5,
#   'accuracy': 0.3333333333333333},
#  'Polarity': {'true_positives': 48,
#   'false_positives': 17,
#   'false_negatives': 21,
#   'total_label_entities': 67,
#   'total_model_entities': 65,
#   'precision': 0.7384615384615385,
#   'recall': 0.6956521739130435,
#   'f1': 0.7164179104477613,
#   'accuracy': 0.5581395348837209},
#  'Condition-Type': {'true_positives': 0,
#   'false_positives': 0,
#   'false_negatives': 2,
#   'total_label_entities': 2,
#   'total_model_entities': 0,
#   'precision': 0,
#   'recall': 0.0,
#   'f1': 0,
#   'accuracy': 0.0},
#  'Immunization': {'true_positives': 3,
#   'false_positives': 3,
#   'false_negatives': 4,
#   'total_label_entities': 8,
#   'total_model_entities': 6,
#   'precision': 0.5,
#   'recall': 0.42857142857142855,
#   'f1': 0.4615384615384615,
#   'accuracy': 0.3},
#  'Eq-Operator': {'true_positives': 522,
#   'false_positives': 231,
#   'false_negatives': 224,
#   'total_label_entities': 817,
#   'total_model_entities': 753,
#   'precision': 0.6932270916334662,
#   'recall': 0.6997319034852547,
#   'f1': 0.6964643095396932,
#   'accuracy': 0.534288638689867},
#  'Eq-Temporal-Recency': {'true_positives': 14,
#   'false_positives': 3,
#   'false_negatives': 14,
#   'total_label_entities': 28,
#   'total_model_entities': 17,
#   'precision': 0.8235294117647058,
#   'recall': 0.5,
#   'f1': 0.6222222222222222,
#   'accuracy': 0.45161290322580644},
#  'Procedure-Name': {'true_positives': 421,
#   'false_positives': 142,
#   'false_negatives': 159,
#   'total_label_entities': 590,
#   'total_model_entities': 563,
#   'precision': 0.7477797513321492,
#   'recall': 0.7258620689655172,
#   'f1': 0.7366579177602799,
#   'accuracy': 0.5831024930747922},
#  'Indication': {'true_positives': 7,
#   'false_positives': 1,
#   'false_negatives': 0,
#   'total_label_entities': 7,
#   'total_model_entities': 8,
#   'precision': 0.875,
#   'recall': 1.0,
#   'f1': 0.9333333333333333,
#   'accuracy': 0.875},
#  'Exception': {'true_positives': 16,
#   'false_positives': 6,
#   'false_negatives': 6,
#   'total_label_entities': 22,
#   'total_model_entities': 22,
#   'precision': 0.7272727272727273,
#   'recall': 0.7272727272727273,
#   'f1': 0.7272727272727273,
#   'accuracy': 0.5714285714285714},
#  'Study': {'true_positives': 155,
#   'false_positives': 35,
#   'false_negatives': 21,
#   'total_label_entities': 171,
#   'total_model_entities': 190,
#   'precision': 0.8157894736842105,
#   'recall': 0.8806818181818182,
#   'f1': 0.8469945355191256,
#   'accuracy': 0.7345971563981043},
#  'Language': {'true_positives': 28,
#   'false_positives': 2,
#   'false_negatives': 1,
#   'total_label_entities': 29,
#   'total_model_entities': 30,
#   'precision': 0.9333333333333333,
#   'recall': 0.9655172413793104,
#   'f1': 0.9491525423728815,
#   'accuracy': 0.9032258064516129},
#  'Coreference': {'true_positives': 0,
#   'false_positives': 3,
#   'false_negatives': 16,
#   'total_label_entities': 16,
#   'total_model_entities': 3,
#   'precision': 0.0,
#   'recall': 0.0,
#   'f1': 0,
#   'accuracy': 0.0},
#  'Provider': {'true_positives': 7,
#   'false_positives': 14,
#   'false_negatives': 10,
#   'total_label_entities': 17,
#   'total_model_entities': 21,
#   'precision': 0.3333333333333333,
#   'recall': 0.4117647058823529,
#   'f1': 0.36842105263157887,
#   'accuracy': 0.22580645161290322},
#  'Acuteness': {'true_positives': 40,
#   'false_positives': 6,
#   'false_negatives': 7,
#   'total_label_entities': 47,
#   'total_model_entities': 46,
#   'precision': 0.8695652173913043,
#   'recall': 0.851063829787234,
#   'f1': 0.8602150537634409,
#   'accuracy': 0.7547169811320755},
#  'Life-Stage-And-Gender': {'true_positives': 104,
#   'false_positives': 5,
#   'false_negatives': 14,
#   'total_label_entities': 121,
#   'total_model_entities': 109,
#   'precision': 0.9541284403669725,
#   'recall': 0.8813559322033898,
#   'f1': 0.9162995594713658,
#   'accuracy': 0.8455284552845529},
#  'Procedure': {'true_positives': 474,
#   'false_positives': 155,
#   'false_negatives': 174,
#   'total_label_entities': 664,
#   'total_model_entities': 629,
#   'precision': 0.753577106518283,
#   'recall': 0.7314814814814815,
#   'f1': 0.7423649177760376,
#   'accuracy': 0.5902864259028643},
#  'Risk': {'true_positives': 20,
#   'false_positives': 3,
#   'false_negatives': 4,
#   'total_label_entities': 24,
#   'total_model_entities': 23,
#   'precision': 0.8695652173913043,
#   'recall': 0.8333333333333334,
#   'f1': 0.851063829787234,
#   'accuracy': 0.7407407407407407},
#  'Death': {'true_positives': 3,
#   'false_positives': 1,
#   'false_negatives': 4,
#   'total_label_entities': 7,
#   'total_model_entities': 4,
#   'precision': 0.75,
#   'recall': 0.42857142857142855,
#   'f1': 0.5454545454545454,
#   'accuracy': 0.375},
#  'Assertion': {'true_positives': 135,
#   'false_positives': 68,
#   'false_negatives': 91,
#   'total_label_entities': 220,
#   'total_model_entities': 203,
#   'precision': 0.6650246305418719,
#   'recall': 0.5973451327433629,
#   'f1': 0.6293706293706295,
#   'accuracy': 0.45918367346938777},
#  'Allergy-Name': {'true_positives': 1,
#   'false_positives': 5,
#   'false_negatives': 6,
#   'total_label_entities': 7,
#   'total_model_entities': 6,
#   'precision': 0.16666666666666666,
#   'recall': 0.14285714285714285,
#   'f1': 0.15384615384615383,
#   'accuracy': 0.08333333333333333},
#  'Specimen': {'true_positives': 2,
#   'false_positives': 3,
#   'false_negatives': 6,
#   'total_label_entities': 7,
#   'total_model_entities': 5,
#   'precision': 0.4,
#   'recall': 0.25,
#   'f1': 0.3076923076923077,
#   'accuracy': 0.18181818181818182},
#  'Negation': {'true_positives': 112,
#   'false_positives': 47,
#   'false_negatives': 81,
#   'total_label_entities': 204,
#   'total_model_entities': 159,
#   'precision': 0.7044025157232704,
#   'recall': 0.5803108808290155,
#   'f1': 0.6363636363636364,
#   'accuracy': 0.4666666666666667},
#  'Code': {'true_positives': 0,
#   'false_positives': 0,
#   'false_negatives': 0,
#   'total_label_entities': 0,
#   'total_model_entities': 0,
#   'precision': 0,
#   'recall': 0,
#   'f1': 0,
#   'accuracy': 0},
#  'Stability': {'true_positives': 51,
#   'false_positives': 20,
#   'false_negatives': 21,
#   'total_label_entities': 70,
#   'total_model_entities': 71,
#   'precision': 0.7183098591549296,
#   'recall': 0.7083333333333334,
#   'f1': 0.7132867132867133,
#   'accuracy': 0.5543478260869565},
#  'Birth': {'true_positives': 6,
#   'false_positives': 3,
#   'false_negatives': 1,
#   'total_label_entities': 7,
#   'total_model_entities': 9,
#   'precision': 0.6666666666666666,
#   'recall': 0.8571428571428571,
#   'f1': 0.75,
#   'accuracy': 0.6},
#  'Criteria-Count': {'true_positives': 1,
#   'false_positives': 2,
#   'false_negatives': 4,
#   'total_label_entities': 5,
#   'total_model_entities': 3,
#   'precision': 0.3333333333333333,
#   'recall': 0.2,
#   'f1': 0.25,
#   'accuracy': 0.14285714285714285},
#  'Eq-Comparison': {'true_positives': 784,
#   'false_positives': 154,
#   'false_negatives': 200,
#   'total_label_entities': 998,
#   'total_model_entities': 938,
#   'precision': 0.835820895522388,
#   'recall': 0.7967479674796748,
#   'f1': 0.8158168574401665,
#   'accuracy': 0.6889279437609842},
#  'Condition-Name': {'true_positives': 941,
#   'false_positives': 305,
#   'false_negatives': 305,
#   'total_label_entities': 1261,
#   'total_model_entities': 1246,
#   'precision': 0.7552166934189406,
#   'recall': 0.7552166934189406,
#   'f1': 0.7552166934189406,
#   'accuracy': 0.6067053513862024},
#  'Insurance': {'true_positives': 1,
#   'false_positives': 1,
#   'false_negatives': 0,
#   'total_label_entities': 1,
#   'total_model_entities': 2,
#   'precision': 0.5,
#   'recall': 1.0,
#   'f1': 0.6666666666666666,
#   'accuracy': 0.5},
#  'Observation': {'true_positives': 268,
#   'false_positives': 135,
#   'false_negatives': 148,
#   'total_label_entities': 414,
#   'total_model_entities': 403,
#   'precision': 0.6650124069478908,
#   'recall': 0.6442307692307693,
#   'f1': 0.6544566544566545,
#   'accuracy': 0.4863883847549909},
#  'Allergy': {'true_positives': 23,
#   'false_positives': 5,
#   'false_negatives': 2,
#   'total_label_entities': 25,
#   'total_model_entities': 28,
#   'precision': 0.8214285714285714,
#   'recall': 0.92,
#   'f1': 0.8679245283018867,
#   'accuracy': 0.7666666666666667},
#  'Eq-Temporal-Period': {'true_positives': 347,
#   'false_positives': 70,
#   'false_negatives': 102,
#   'total_label_entities': 467,
#   'total_model_entities': 417,
#   'precision': 0.8321342925659473,
#   'recall': 0.7728285077951003,
#   'f1': 0.8013856812933025,
#   'accuracy': 0.6685934489402697},
#  'total': {'true_positives': 7989,
#   'false_positives': 2415,
#   'false_negatives': 2899,
#   'precision': 0.7678777393310265,
#   'recall': 0.7337435709037472,
#   'f1': 0.750422693969566}}

# %%
## Ausgae F1 = 0
zero_f1_entities = {}

for entity, values in metrics.items():
    if entity != 'total' and values['f1'] == 0:
        zero_f1_entities[entity] = values
zero_f1_entities
# Out:
# {'Condition-Type': {'true_positives': 0,
#   'false_positives': 0,
#   'false_negatives': 2,
#   'total_label_entities': 2,
#   'total_model_entities': 0,
#   'precision': 0,
#   'recall': 0.0,
#   'f1': 0,
#   'accuracy': 0.0},
#  'Coreference': {'true_positives': 0,
#   'false_positives': 3,
#   'false_negatives': 16,
#   'total_label_entities': 16,
#   'total_model_entities': 3,
#   'precision': 0.0,
#   'recall': 0.0,
#   'f1': 0,
#   'accuracy': 0.0},
#  'Code': {'true_positives': 0,
#   'false_positives': 0,
#   'false_negatives': 0,
#   'total_label_entities': 0,
#   'total_model_entities': 0,
#   'precision': 0,
#   'recall': 0,
#   'f1': 0,
#   'accuracy': 0}}

# %% [markdown]
# #### Anzahl der Fehler in der Modelausgabe

# %%
plot_file_counts(model_name)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plot_file_counts(model_name)
#
# File ~\DataspellProjects\ec_criteria_struct\lct\evaluate_struct\struct_eval_functions.py:204, in plot_file_counts(model_name)
#     202         percentage = 100
#     203     else:
# --> 204         percentage = (count / total_files) * 100
#     205     ax.annotate(f'{count} ({percentage:.1f}%)',
#     206                 xy=(bar.get_x() + bar.get_width() / 2, height),
#     207                 xytext=(0, 3),
#     208                 textcoords="offset points",
#     209                 ha='center', va='bottom', fontsize=9)
#     211 plt.tight_layout()
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Anzahl der ausgegebenen Entitäten

# %%
#plot_entitys(metrics, model_name)

# %%
def plot_metrics_all_entitys(model_name, metrics, categories):
    metrics_to_plot = ['precision', 'recall', 'f1']
    metric_labels = {'precision': 'P', 'recall': 'R', 'f1': 'F1'}

    # Sortiere die Kategorien nach F1-Score absteigend
    categories_sorted = sorted(categories, key=lambda x: metrics[x]['f1'], reverse=True)

    fig, ax = plt.subplots(figsize=(20, 12))  # Vergrößere die Figur

    x = np.arange(len(categories_sorted) + 1)  # +1 für die Gesamtbalken
    bar_width = 0.25
    opacity = 0.8

    for i, metric in enumerate(metrics_to_plot):
        values = [metrics[category][metric] * 100 for category in categories_sorted]
        total_value = metrics['total'][metric] * 100
        values.append(total_value)  # Füge die Gesamtwerte hinzu
        bars = ax.bar(x + i*bar_width, values, bar_width, alpha=opacity, label=f'{metric_labels[metric]}')

        for j, v in enumerate(values):
            ax.text(x[j] + i*bar_width, v + 1, f'{v:.1f}', ha='center', va='bottom', fontsize=8, rotation=90)

    ax.set_xlabel('Kategorie', fontsize=12, labelpad=10)
    ax.set_ylabel('Score (%)', fontsize=12, labelpad=10)
    ax.set_title(f'Evaluation: {model_name}', fontsize=16, pad=20)
    ax.set_xticks(x + bar_width)
    categories_sorted.append('Gesamt')  # Füge die Beschriftung für die Gesamtwerte hinzu
    ax.set_xticklabels(categories_sorted, rotation=90, ha='right', fontsize=8)
    ax.legend(loc='upper right', fontsize=10)
    ax.set_ylim(0, 105)

    plt.tight_layout()
    plt.savefig(f'pics/evaluation_{model_name}_all_categories.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
def plot_heatmap(model_name, metrics, categories):
    # Erstelle eine DataFrame mit den Metriken
    data = {cat: [metrics[cat]['precision'], metrics[cat]['recall'], metrics[cat]['f1']] for cat in categories}
    df = pd.DataFrame(data, index=['Precision', 'Recall', 'F1']).T
    df_sorted = df.sort_values('F1', ascending=False)

    plt.figure(figsize=(15, len(categories) * 0.3))
    sns.heatmap(df_sorted, annot=True, cmap="YlGnBu", fmt=".2f", cbar_kws={'label': 'Score'})
    plt.title(f'Metriken für {model_name}')
    plt.tight_layout()
    plt.savefig(f'pics/heatmap_{model_name}.png')
    plt.show()

# %%
#plot_heatmap(model_name, metrics, categories)

# %% [markdown]
# #### Model Performance

# %%
model_name = "Llama3 70b Fine-Tuned"
plot_metrics_all_entitys(model_name, metrics, categories)

# %%
def generate_latex_table(model_name, metrics, categories):
    # Sortiere die Kategorien nach F1-Score absteigend
    categories_sorted = sorted(categories, key=lambda x: metrics[x]['f1'], reverse=True)

    # Beginne die LaTeX-Tabelle
    latex_table = "\\begin{table}[htbp]\n"
    latex_table += "\\centering\n"
    latex_table += "\\begin{tabular}{p{5cm}ccc}\n"  # Mehr Platz für die erste Spalte
    latex_table += "\\toprule\n"
    latex_table += "\\textbf{Kategorie} & \\textbf{Precision} & \\textbf{Recall} & \\textbf{F1-Score} \\\\\n"
    latex_table += "\\midrule\n"

    # Füge jede Kategorie mit ihren Metriken hinzu
    for category in categories_sorted:
        precision = metrics[category]['precision']
        recall = metrics[category]['recall']
        f1 = metrics[category]['f1']
        latex_table += f"{category} & {precision:.3f} & {recall:.3f} & {f1:.3f} \\\\\n"

    # Schließe die Tabelle
    latex_table += "\\bottomrule\n"
    latex_table += "\\end{tabular}\n"
    latex_table += "\\caption{Metriken für " + model_name + "}\n"  # Caption am Ende
    latex_table += "\\label{tab:metrics_" + model_name.lower().replace(" ", "_") + "}\n"
    latex_table += "\\end{table}"

    # Erstelle den 'latex' Ordner, falls er nicht existiert
    os.makedirs('latex', exist_ok=True)

    # Speichere die LaTeX-Tabelle in einer Datei im 'latex' Ordner
    file_path = os.path.join('latex', f'latex_table_{model_name}.tex')
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(latex_table)

    print(f"LaTeX-Tabelle wurde erstellt und in {file_path} gespeichert.")

    return latex_table

# %%
generate_latex_table(model_name, metrics, categories)
# Out:
# LaTeX-Tabelle wurde erstellt und in latex\latex_table_Llama3 70b Fine-Tuned.tex gespeichert.
# '\\begin{table}[htbp]\n\\centering\n\\begin{tabular}{p{5cm}ccc}\n\\toprule\n\\textbf{Kategorie} & \\textbf{Precision} & \\textbf{Recall} & \\textbf{F1-Score} \\\\\n\\midrule\nLanguage & 0.933 & 0.966 & 0.949 \\\\\nIndication & 0.875 & 1.000 & 0.933 \\\\\nContraindication & 0.926 & 0.926 & 0.926 \\\\\nLife-Stage-And-Gender & 0.954 & 0.881 & 0.916 \\\\\nSeverity & 0.910 & 0.918 & 0.914 \\\\\nEthnicity & 0.875 & 0.875 & 0.875 \\\\\nEq-Temporal-Unit & 0.928 & 0.826 & 0.874 \\\\\nEq-Value & 0.897 & 0.847 & 0.871 \\\\\nAllergy & 0.821 & 0.920 & 0.868 \\\\\nAcuteness & 0.870 & 0.851 & 0.860 \\\\\nRisk & 0.870 & 0.833 & 0.851 \\\\\nStudy & 0.816 & 0.881 & 0.847 \\\\\nOther & 0.828 & 0.857 & 0.842 \\\\\nEq-Comparison & 0.836 & 0.797 & 0.816 \\\\\nAge & 0.943 & 0.716 & 0.814 \\\\\nDrug & 0.829 & 0.783 & 0.805 \\\\\nEq-Temporal-Period & 0.832 & 0.773 & 0.801 \\\\\nOrganism-Name & 0.667 & 1.000 & 0.800 \\\\\nOrganism & 0.667 & 1.000 & 0.800 \\\\\nCondition & 0.766 & 0.763 & 0.765 \\\\\nCondition-Name & 0.755 & 0.755 & 0.755 \\\\\nDrug-Name & 0.801 & 0.714 & 0.755 \\\\\nBirth & 0.667 & 0.857 & 0.750 \\\\\nProcedure & 0.754 & 0.731 & 0.742 \\\\\nProcedure-Name & 0.748 & 0.726 & 0.737 \\\\\nLocation & 0.836 & 0.656 & 0.735 \\\\\nEq-Unit & 0.795 & 0.683 & 0.735 \\\\\nException & 0.727 & 0.727 & 0.727 \\\\\nPolarity & 0.738 & 0.696 & 0.716 \\\\\nStability & 0.718 & 0.708 & 0.713 \\\\\nEq-Operator & 0.693 & 0.700 & 0.696 \\\\\nInsurance & 0.500 & 1.000 & 0.667 \\\\\nEncounter & 0.745 & 0.593 & 0.660 \\\\\nObservation-Name & 0.660 & 0.652 & 0.656 \\\\\nObservation & 0.665 & 0.644 & 0.654 \\\\\nNegation & 0.704 & 0.580 & 0.636 \\\\\nAssertion & 0.665 & 0.597 & 0.629 \\\\\nEq-Temporal-Recency & 0.824 & 0.500 & 0.622 \\\\\nModifier & 0.606 & 0.563 & 0.584 \\\\\nFamily-Member & 0.889 & 0.400 & 0.552 \\\\\nDeath & 0.750 & 0.429 & 0.545 \\\\\nImmunization-Name & 0.500 & 0.500 & 0.500 \\\\\nImmunization & 0.500 & 0.429 & 0.462 \\\\\nProvider & 0.333 & 0.412 & 0.368 \\\\\nSpecimen & 0.400 & 0.250 & 0.308 \\\\\nCriteria-Count & 0.333 & 0.200 & 0.250 \\\\\nAllergy-Name & 0.167 & 0.143 & 0.154 \\\\\nCondition-Type & 0.000 & 0.000 & 0.000 \\\\\nCoreference & 0.000 & 0.000 & 0.000 \\\\\nCode & 0.000 & 0.000 & 0.000 \\\\\n\\bottomrule\n\\end{tabular}\n\\caption{Metriken für Llama3 70b Fine-Tuned}\n\\label{tab:metrics_llama3_70b_fine-tuned}\n\\end{table}'

# %%
def generate_comparison_latex_table(model_name, metrics):
    def format_metrics(p, r, f1):
        return f"{p*100:.1f}/{r*100:.1f}/{f1*100:.1f}"

    latex_table = r"""
\begin{table}[htbp]
\centering
\begin{tabular}{llcc}
\toprule
\textbf{Category} & \textbf{Entity} & \textbf{SciBERT} & \textbf{""" + model_name + r"""} \\
\midrule
\multirow{6}{*}{Clinical} & Condition & 78.4/83.3/80.8 & """ + format_metrics(metrics['Condition']['precision'], metrics['Condition']['recall'], metrics['Condition']['f1']) + r""" \\
 & Contraindication & 100.0/96.6/98.3 & """ + format_metrics(metrics['Contraindication']['precision'], metrics['Contraindication']['recall'], metrics['Contraindication']['f1']) + r""" \\
 & Drug & 73.4/80.9/77.0 & """ + format_metrics(metrics['Drug']['precision'], metrics['Drug']['recall'], metrics['Drug']['f1']) + r""" \\
 & Encounter & 58.3/74.4/65.4 & """ + format_metrics(metrics['Encounter']['precision'], metrics['Encounter']['recall'], metrics['Encounter']['f1']) + r""" \\
 & Observation & 72.1/77.6/74.7 & """ + format_metrics(metrics['Observation']['precision'], metrics['Observation']['recall'], metrics['Observation']['f1']) + r""" \\
 & Procedure & 71.3/79.4/75.1 & """ + format_metrics(metrics['Procedure']['precision'], metrics['Procedure']['recall'], metrics['Procedure']['f1']) + r""" \\
\midrule
\multirow{5}{*}{Demographic} & Age & 99.1/98.3/98.7 & """ + format_metrics(metrics['Age']['precision'], metrics['Age']['recall'], metrics['Age']['f1']) + r""" \\
 & Birth & 100.0/62.5/76.9 & """ + format_metrics(metrics['Birth']['precision'], metrics['Birth']['recall'], metrics['Birth']['f1']) + r""" \\
 & Death & 100.0/20.0/33.3 & """ + format_metrics(metrics['Death']['precision'], metrics['Death']['recall'], metrics['Death']['f1']) + r""" \\
 & Family-Member & 44.9/61.1/51.7 & """ + format_metrics(metrics['Family-Member']['precision'], metrics['Family-Member']['recall'], metrics['Family-Member']['f1']) + r""" \\
 & Language & 96.6/93.5/95.0 & """ + format_metrics(metrics['Language']['precision'], metrics['Language']['recall'], metrics['Language']['f1']) + r""" \\
\midrule
Logical & Negation & 73.5/82.9/77.9 & """ + format_metrics(metrics['Negation']['precision'], metrics['Negation']['recall'], metrics['Negation']['f1']) + r""" \\
\midrule
\multirow{6}{*}{Qualifier} & Assertion & 62.1/65.8/63.9 & """ + format_metrics(metrics['Assertion']['precision'], metrics['Assertion']['recall'], metrics['Assertion']['f1']) + r""" \\
 & Modifier & 58.5/65.4/61.8 & """ + format_metrics(metrics['Modifier']['precision'], metrics['Modifier']['recall'], metrics['Modifier']['f1']) + r""" \\
 & Polarity & 81.4/79.5/80.4 & """ + format_metrics(metrics['Polarity']['precision'], metrics['Polarity']['recall'], metrics['Polarity']['f1']) + r""" \\
 & Risk & 95.4/91.3/93.3 & """ + format_metrics(metrics['Risk']['precision'], metrics['Risk']['recall'], metrics['Risk']['f1']) + r""" \\
 & Severity & 86.5/94.1/90.2 & """ + format_metrics(metrics['Severity']['precision'], metrics['Severity']['recall'], metrics['Severity']['f1']) + r""" \\
 & Stability & 75.3/84.7/79.7 & """ + format_metrics(metrics['Stability']['precision'], metrics['Stability']['recall'], metrics['Stability']['f1']) + r""" \\
\midrule
\multirow{6}{*}{Temporal and Comparative} & Eq-Comparison & 85.3/89.3/87.3 & """ + format_metrics(metrics['Eq-Comparison']['precision'], metrics['Eq-Comparison']['recall'], metrics['Eq-Comparison']['f1']) + r""" \\
 & Criteria-Count & 12.5/20.0/15.5 & """ + format_metrics(metrics['Criteria-Count']['precision'], metrics['Criteria-Count']['recall'], metrics['Criteria-Count']['f1']) + r""" \\
 & Eq-Temporal-Period & 82.6/86.3/84.4 & """ + format_metrics(metrics['Eq-Temporal-Period']['precision'], metrics['Eq-Temporal-Period']['recall'], metrics['Eq-Temporal-Period']['f1']) + r""" \\
 & Eq-Temporal-Recency & 50.0/66.6/57.1 & """ + format_metrics(metrics['Eq-Temporal-Recency']['precision'], metrics['Eq-Temporal-Recency']['recall'], metrics['Eq-Temporal-Recency']['f1']) + r""" \\
 & Eq-Temporal-Unit & 98.2/99.4/98.8 & """ + format_metrics(metrics['Eq-Temporal-Unit']['precision'], metrics['Eq-Temporal-Unit']['recall'], metrics['Eq-Temporal-Unit']['f1']) + r""" \\
 & Eq-Value & 96.4/97.1/96.7 & """ + format_metrics(metrics['Eq-Value']['precision'], metrics['Eq-Value']['recall'], metrics['Eq-Value']['f1']) + r""" \\
\midrule
Other & Location & 73.4/78.3/75.8 & """ + format_metrics(metrics['Location']['precision'], metrics['Location']['recall'], metrics['Location']['f1']) + r""" \\
\midrule
-- & Total & 79.0/83.7/81.3 & """ + format_metrics(metrics['total']['precision'], metrics['total']['recall'], metrics['total']['f1']) + r""" \\
\bottomrule
\end{tabular}
\caption{Leistungsvergleich der Metriken auf dem LCT Korpus: SciBERT vs """ + model_name + r""" (\%, Precision/Recall/F1). Die Gesamtauswertung umfasst 50 Entitätskategorien.}
\label{tab:metrics_comparison}
\end{table}
    """

    os.makedirs('latex', exist_ok=True)
    file_path = os.path.join('latex', f'latex_table_comparison_{model_name}.tex')
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(latex_table)
    return latex_table

# %%
generate_comparison_latex_table(model_name, metrics)
# Out:
# '\n\\begin{table}[htbp]\n\\centering\n\\begin{tabular}{llcc}\n\\toprule\n\\textbf{Category} & \\textbf{Entity} & \\textbf{SciBERT} & \\textbf{Llama3 70b Fine-Tuned} \\\\\n\\midrule\n\\multirow{6}{*}{Clinical} & Condition & 78.4/83.3/80.8 & 76.6/76.3/76.5 \\\\\n & Contraindication & 100.0/96.6/98.3 & 92.6/92.6/92.6 \\\\\n & Drug & 73.4/80.9/77.0 & 82.9/78.3/80.5 \\\\\n & Encounter & 58.3/74.4/65.4 & 74.5/59.3/66.0 \\\\\n & Observation & 72.1/77.6/74.7 & 66.5/64.4/65.4 \\\\\n & Procedure & 71.3/79.4/75.1 & 75.4/73.1/74.2 \\\\\n\\midrule\n\\multirow{5}{*}{Demographic} & Age & 99.1/98.3/98.7 & 94.3/71.6/81.4 \\\\\n & Birth & 100.0/62.5/76.9 & 66.7/85.7/75.0 \\\\\n & Death & 100.0/20.0/33.3 & 75.0/42.9/54.5 \\\\\n & Family-Member & 44.9/61.1/51.7 & 88.9/40.0/55.2 \\\\\n & Language & 96.6/93.5/95.0 & 93.3/96.6/94.9 \\\\\n\\midrule\nLogical & Negation & 73.5/82.9/77.9 & 70.4/58.0/63.6 \\\\\n\\midrule\n\\multirow{6}{*}{Qualifier} & Assertion & 62.1/65.8/63.9 & 66.5/59.7/62.9 \\\\\n & Modifier & 58.5/65.4/61.8 & 60.6/56.3/58.4 \\\\\n & Polarity & 81.4/79.5/80.4 & 73.8/69.6/71.6 \\\\\n & Risk & 95.4/91.3/93.3 & 87.0/83.3/85.1 \\\\\n & Severity & 86.5/94.1/90.2 & 91.0/91.8/91.4 \\\\\n & Stability & 75.3/84.7/79.7 & 71.8/70.8/71.3 \\\\\n\\midrule\n\\multirow{6}{*}{Temporal and Comparative} & Eq-Comparison & 85.3/89.3/87.3 & 83.6/79.7/81.6 \\\\\n & Criteria-Count & 12.5/20.0/15.5 & 33.3/20.0/25.0 \\\\\n & Eq-Temporal-Period & 82.6/86.3/84.4 & 83.2/77.3/80.1 \\\\\n & Eq-Temporal-Recency & 50.0/66.6/57.1 & 82.4/50.0/62.2 \\\\\n & Eq-Temporal-Unit & 98.2/99.4/98.8 & 92.8/82.6/87.4 \\\\\n & Eq-Value & 96.4/97.1/96.7 & 89.7/84.7/87.1 \\\\\n\\midrule\nOther & Location & 73.4/78.3/75.8 & 83.6/65.6/73.5 \\\\\n\\midrule\n-- & Total & 79.0/83.7/81.3 & 76.8/73.4/75.0 \\\\\n\\bottomrule\n\\end{tabular}\n\\caption{Leistungsvergleich der Metriken auf dem LCT Korpus: SciBERT vs Llama3 70b Fine-Tuned (\\%, Precision/Recall/F1). Die Gesamtauswertung umfasst 50 Entitätskategorien.}\n\\label{tab:metrics_comparison}\n\\end{table}\n    '

# %% [markdown]
# ### Calculate Metrics for AND OR NOT

# %%
label_folder = "../input/lct_p1_half_with_and/" # '../input/lct_p1_half/'
raw_lct_text_folder = '../input/lct_txt_half'
model_output_folder = 'model_output/eval_p4/'

# %%
import re
from collections import Counter
import os

def extract_file_name(filename):
    pattern = r'NCT(\d+)_(inc|exc)'
    match = re.search(pattern, filename)

    if match:
        nct_number = 'NCT' + match.group(1)
        suffix = match.group(2)
        return f"{nct_number}_{suffix}"
    else:
        return None

def find_operator_words(text, operators):
    words = {op: [] for op in operators}
    word_list = text.split()
    for i, word in enumerate(word_list):
        if word in ["[AND]", "[OR]", "[NOT]", "[AND1]"]:
            operator = word[1:-1]
            if operator in operators:
                j = i - 1
                while j >= 0 and word_list[j] in ["[AND]", "[OR]", "[NOT]", "[AND1]"]:
                    j -= 1
                if j >= 0:
                    prev_word = re.sub(r'[^\w]', '', word_list[j])  # Remove punctuation
                    words[operator].append(prev_word)
    return words

def compare_operators(label_text, model_text, operator):
    label_operators = extract_operators(label_text) + ['AND1']
    model_operators = extract_operators(model_text)

    label_words_dict = find_operator_words(label_text, label_operators)
    model_words_dict = find_operator_words(model_text, model_operators)

    label_words = label_words_dict.get(operator, [])
    model_words = model_words_dict.get('AND', []) if operator in ['AND', 'AND1'] else model_words_dict.get(operator, [])

    print(operator)
    print("label_words_dict", label_words)
    print("model_words_dict", model_words)

    tp = 0
    fp = 0
    fn = 0

    if operator in ['AND', 'AND1']:
        for word in model_words:
            if word in label_words_dict.get('AND1', []):
                if operator == 'AND1':
                    tp += 1
                # Wenn es AND1 ist, zählen wir es nicht für AND
            elif word in label_words_dict.get('AND', []):
                if operator == 'AND':
                    tp += 1
                # Wenn es AND ist, zählen wir es nicht für AND1
            else:
                if operator == 'AND':
                    fp += 1  # False Positive nur für AND, wenn es in keinem vorkommt

        if operator == 'AND':
            fn = sum(1 for word in label_words_dict.get('AND', []) if word not in model_words)
        else:  # AND1
            fn = sum(1 for word in label_words_dict.get('AND1', []) if word not in model_words)
    else:
        tp = sum(1 for word in label_words if word in model_words)
        fp = sum(1 for word in model_words if word not in label_words)
        fn = sum(1 for word in label_words if word not in model_words)

    return tp, fp, fn, len(label_words), len(model_words)

def evaluate_models(label_folder, model_folder, model_name, raw_lct_text_folder):
    operators = ['AND', 'AND1', 'OR', 'NOT']
    metrics = {op: {'tp': 0, 'fp': 0, 'fn': 0, 'label_count': 0, 'model_count': 0, 'correct_count': 0, 'correct_ncts': set(), 'low_tp_ncts': set()} for op in operators}
    processed_label_files = 0
    total_missing_words = Counter()
    total_missing_pct = 0.0
    model_results = []
    label_files = {f.split('.')[0]: os.path.join(label_folder, f) for f in os.listdir(label_folder) if f.endswith('.txt')}

    for model_file in os.listdir(model_folder):
        if model_file.endswith('.txt'):
            identifier = extract_file_name(model_file)
            print(identifier)
            if identifier in label_files:
                label_file_path = label_files[identifier]
                model_file_path = os.path.join(model_folder, model_file)
                raw_lct_text_path = os.path.join(raw_lct_text_folder, f'{identifier}.txt')

                if os.path.exists(label_file_path):
                    processed_label_files += 1
                    label_text = read_file(label_file_path)
                    model_text = read_file(model_file_path)
                    raw_lct_text = read_file(raw_lct_text_path)
                    model_raw_text = clean_criteria_text(model_text)
                    missing_words, missing_percentage = compare_texts(raw_lct_text, model_raw_text)
                    total_missing_pct += missing_percentage
                    total_missing_words.update(missing_words)

                    model_data = {'nct_number':identifier}

                    # Zähle die gesamten AND-Operatoren im Modell
                    total_model_and = len(find_operator_words(model_text, ['AND'])['AND'])

                    for op in operators:
                        tp, fp, fn, label_count, model_count = compare_operators(label_text, model_text, op)

                        metrics[op]['tp'] += tp
                        metrics[op]['fp'] += fp
                        metrics[op]['fn'] += fn
                        metrics[op]['label_count'] += label_count

                        if op in ['AND', 'AND1']:
                            metrics[op]['model_count'] += total_model_and
                        else:
                            metrics[op]['model_count'] += model_count

                        metrics[op]['correct_count'] += tp

                        model_data[f'{op}_tp'] = tp
                        model_data[f'{op}_fp'] = fp
                        model_data[f'{op}_fn'] = fn
                        model_data[f'{op}_label_count'] = label_count
                        model_data[f'{op}_model_count'] = total_model_and if op in ['AND', 'AND1'] else model_count

                        if tp > 0:
                            metrics[op]['correct_ncts'].add(identifier)
                        if tp == 0 and fn > 4:
                            metrics[op]['low_tp_ncts'].add(identifier)

                    model_results.append(model_data)

    results = calculate_aggregated_results(metrics, processed_label_files, total_missing_pct, operators)
    return results

# %%
all_metrics = {}
for model in models:
    model_folder = os.path.join(model_output_folder, model, 'processed_output')
    metrics = evaluate_models(label_folder, model_folder, model, raw_lct_text_folder)
    all_metrics[model] = metrics
# Out:
# NCT03860220_inc
# AND
# label_words_dict []
# model_words_dict ['mmHg', 'mgdL']
# AND1
# label_words_dict ['mmHg', 'mgdL']
# model_words_dict ['mmHg', 'mgdL']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03860259_inc
# AND
# label_words_dict []
# model_words_dict ['age', 'consent', 'surgery']
# AND1
# label_words_dict ['age', 'consent', 'surgery']
# model_words_dict ['age', 'consent', 'surgery']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03860311_exc
# AND
# label_words_dict []
# model_words_dict ['known', 'patients', 'surgery', 'disease']
# AND1
# label_words_dict ['known', 'patients', 'surgery', 'disease', 'presenting']
# model_words_dict ['known', 'patients', 'surgery', 'disease']
# OR
# label_words_dict ['renal', 'abnormalities', 'pelvic']
# model_words_dict ['renal', 'abnormalities', 'pelvic']
# NOT
# label_words_dict ['presenting']
# model_words_dict []
# NCT03860324_exc
# AND
# label_words_dict ['disease']
# model_words_dict ['refusal', 'kgm2', 'replacement', 'level', '50mlmin', 'opioids', 'Patient', 'block', 'anesthetics', 'block']
# AND1
# label_words_dict ['refusal', 'kgm2', 'replacement', 'Patient', 'level', '50mlmin', 'opioids', 'Patient', 'block', 'anesthetics', 'block']
# model_words_dict ['refusal', 'kgm2', 'replacement', 'level', '50mlmin', 'opioids', 'Patient', 'block', 'anesthetics', 'block']
# OR
# label_words_dict ['Plane', 'Allergy']
# model_words_dict ['Plane', 'Allergy']
# NOT
# label_words_dict ['Patient', 'Patient']
# model_words_dict ['Patient']
# NCT03860363_inc
# AND
# label_words_dict []
# model_words_dict ['18', 'surgery']
# AND1
# label_words_dict ['18', 'undergoing', 'surgery']
# model_words_dict ['18', 'surgery']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict ['undergoing']
# model_words_dict []
# NCT03860402_exc
# AND
# label_words_dict []
# model_words_dict ['delivery', 'lidocaine', 'is', 'anesthesia', 'study', 'agreement', '50kg']
# AND1
# label_words_dict ['delivery', 'lidocaine', 'is', 'anesthesia', 'study', 'agreement']
# model_words_dict ['delivery', 'lidocaine', 'is', 'anesthesia', 'study', 'agreement', '50kg']
# OR
# label_words_dict ['response', 'fentanyl', 'ropivacaine', '50kg']
# model_words_dict ['response', 'fentanyl', 'ropivacaine']
# NOT
# label_words_dict ['is']
# model_words_dict ['is']
# NCT03860402_inc
# AND
# label_words_dict ['women']
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03860428_inc
# AND
# label_words_dict []
# model_words_dict ['weeks', 'g', 'hours', 'mm']
# AND1
# label_words_dict ['weeks', 'g', 'hours', 'mm']
# model_words_dict ['weeks', 'g', 'hours', 'mm']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03860493_exc
# AND
# label_words_dict ['Women']
# model_words_dict ['iodides', 'coagulopathy', 'pregnant', 'breastfeeding']
# AND1
# label_words_dict ['iodides', 'coagulopathy']
# model_words_dict ['iodides', 'coagulopathy', 'pregnant', 'breastfeeding']
# OR
# label_words_dict ['pregnant', 'breastfeeding']
# model_words_dict ['Women']
# NOT
# label_words_dict []
# model_words_dict ['breastfeeding']
# NCT03860545_inc
# AND
# label_words_dict []
# model_words_dict ['grafting']
# AND1
# label_words_dict []
# model_words_dict ['grafting']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03860597_inc
# AND
# label_words_dict []
# model_words_dict ['subjects', 'subjects', 'subjects', '']
# AND1
# label_words_dict ['subjects', 'subjects', 'subjects', '']
# model_words_dict ['subjects', 'subjects', 'subjects', '']
# OR
# label_words_dict ['schizophrenia', 'schizoaffectivedepressed']
# model_words_dict ['schizophrenia', 'schizoaffectivedepressed']
# NOT
# label_words_dict ['']
# model_words_dict ['']
# NCT03860610_inc
# AND
# label_words_dict []
# model_words_dict ['THA', '12', 'OA', '34']
# AND1
# label_words_dict ['12', '34']
# model_words_dict ['THA', '12', 'OA', '34']
# OR
# label_words_dict ['THA', 'knee', 'THA']
# model_words_dict ['12', 'knee', 'THA']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03860623_inc
# AND
# label_words_dict []
# model_words_dict ['kgm2', '96cm', '2', 'Males']
# AND1
# label_words_dict ['kgm2', '96cm', 'Males']
# model_words_dict ['kgm2', '96cm', '2', 'Males']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03860662_inc
# AND
# label_words_dict []
# model_words_dict ['1860', 'study']
# AND1
# label_words_dict ['1860', 'study']
# model_words_dict ['1860', 'study']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03860688_exc
# AND
# label_words_dict []
# model_words_dict ['disease', 'malabsorption', 'malignancy', 'gut', 'disease', 'sequestrants', 'breastfeeding', 'disease', 'benzodiazepine', 'disease', 'month', 'years']
# AND1
# label_words_dict ['disease', 'malabsorption', 'malignancy', 'gut', 'disease', 'sequestrants', 'breastfeeding', 'disease', 'benzodiazepine', 'disease', 'month', 'years']
# model_words_dict ['disease', 'malabsorption', 'malignancy', 'gut', 'disease', 'sequestrants', 'breastfeeding', 'disease', 'benzodiazepine', 'disease', 'month', 'years']
# OR
# label_words_dict ['disease', 'insufficiency', 'mellitus', 'known', 'ezetimibe', 'pregnant', 'cardiac', 'Revestive', 'active', 'tract', 'hepatobiliary']
# model_words_dict ['disease', 'insufficiency', 'mellitus', 'known', 'ezetimibe', 'pregnant', 'cardiac', 'Revestive', 'active', 'tract', 'hepatobiliary']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03860701_inc
# AND
# label_words_dict []
# model_words_dict ['Classification', 'g', 'weeks']
# AND1
# label_words_dict ['Classification', 'g', 'weeks']
# model_words_dict ['Classification', 'g', 'weeks']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03860753_exc
# AND
# label_words_dict ['nicotine']
# model_words_dict ['physician', 'men', 'marijuana', 'medications', 'study', 'safe']
# AND1
# label_words_dict ['physician', 'men', 'marijuana', 'medications', 'study', 'would']
# model_words_dict ['physician', 'men', 'marijuana', 'medications', 'study', 'safe']
# OR
# label_words_dict ['HAMA', 'PSS', 'alcohol', 'contraindicating', 'pregnant', 'nursing', 'illness', 'condition', 'safe']
# model_words_dict ['HAMA', 'PSS', 'pregnant', 'nursing', 'illness', 'condition', 'would']
# NOT
# label_words_dict ['would']
# model_words_dict ['would']
# NCT03860766_exc
# AND
# label_words_dict []
# model_words_dict ['months', 'diseases', 'evaluations']
# AND1
# label_words_dict ['months', 'diseases', 'evaluations']
# model_words_dict ['months', 'diseases', 'evaluations']
# OR
# label_words_dict ['anabolic', 'antiinflammatory', 'alcohol']
# model_words_dict ['anabolic', 'antiinflammatory', 'alcohol']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03861078_inc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03861104_exc
# AND
# label_words_dict []
# model_words_dict ['study', 'surgeries', 'months', 'levels']
# AND1
# label_words_dict ['will', 'study', 'surgeries', 'months', 'levels', 'be']
# model_words_dict ['study', 'surgeries', 'months', 'levels']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict ['will', 'be']
# model_words_dict []
# NCT03861182_inc
# AND
# label_words_dict ['1day']
# model_words_dict ['', 'age', 'Neonates', 'life', 'weight']
# AND1
# label_words_dict ['', 'age', 'Neonates', 'life', 'weight', 'Strasbourg']
# model_words_dict ['', 'age', 'Neonates', 'life', 'weight']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03861195_inc
# AND
# label_words_dict []
# model_words_dict ['years', 'kgm2', 'cancer', 'cancer', 'cancer', 'patients']
# AND1
# label_words_dict ['years', 'kgm2', 'cancer', 'cancer', 'cancer', 'patients']
# model_words_dict ['years', 'kgm2', 'cancer', 'cancer', 'cancer', 'patients']
# OR
# label_words_dict ['disease', 'hysterectomy', 'pelvic', 'hysterectomy', 'pelvic', 'uterus']
# model_words_dict ['disease', 'hysterectomy', 'pelvic', 'hysterectomy', 'pelvic']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03861221_inc
# AND
# label_words_dict []
# model_words_dict ['mammography']
# AND1
# label_words_dict []
# model_words_dict ['mammography']
# OR
# label_words_dict ['mammography', 'ultrasound']
# model_words_dict ['ultrasound']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03861312_exc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict ['diseases', 'hernia', 'surgeries', 'vision', 'hearing', 'trauma']
# model_words_dict ['hernia', 'syndrome', 'surgeries', 'diseases', 'vision', 'hearing', 'trauma', 'area']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03861325_inc
# AND
# label_words_dict []
# model_words_dict ['study', 'plan', 'old']
# AND1
# label_words_dict ['study', 'plan', 'old']
# model_words_dict ['study', 'plan', 'old']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03861377_exc
# AND
# label_words_dict ['anaemia']
# model_words_dict ['hypertension', 'Diabetes', 'disease', 'disease', 'extrasystoles', 'grdl', 'disease', 'peanuts', 'Pregnancy', 'state', 'use']
# AND1
# label_words_dict ['hypertension', 'Diabetes', 'disease', 'disease', 'extrasystoles', 'grdl', 'disease', 'peanuts', 'Pregnancy', 'state', 'use']
# model_words_dict ['hypertension', 'Diabetes', 'disease', 'disease', 'extrasystoles', 'grdl', 'disease', 'peanuts', 'Pregnancy', 'state', 'use']
# OR
# label_words_dict ['disease', 'Kidney', 'soya', 'eggs', '20']
# model_words_dict ['disease', 'Kidney', 'soya', 'eggs', '20']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03861442_exc
# AND
# label_words_dict ['user']
# model_words_dict ['criteria', 'processor', 'C40C', 'status', 'risk', 'or', 'compliance', 'study', 'study']
# AND1
# label_words_dict ['criteria', '2000Hz', 'processor', 'C40C', 'array', 'device', 'status', 'or']
# model_words_dict ['criteria', 'processor', 'C40C', 'status', 'risk', 'or', 'compliance', 'study', 'study']
# OR
# label_words_dict ['C40X', 'Implant', 'risk']
# model_words_dict ['C40X', 'device']
# NOT
# label_words_dict ['or']
# model_words_dict ['or']
# NCT03861507_inc
# AND
# label_words_dict []
# model_words_dict ['older', 'consent', 'biopsy', 'for']
# AND1
# label_words_dict ['older', 'consent', 'biopsy']
# model_words_dict ['older', 'consent', 'biopsy', 'for']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03861715_inc
# AND
# label_words_dict []
# model_words_dict ['years', '1829kgm2', 'days', 'ngml']
# AND1
# label_words_dict ['years', '1829kgm2', 'days', 'ngml']
# model_words_dict ['years', '1829kgm2', 'days', 'ngml']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03861845_inc
# AND
# label_words_dict ['day']
# model_words_dict ['older', 'English']
# AND1
# label_words_dict ['older', 'English']
# model_words_dict ['older', 'English']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03861858_inc
# AND
# label_words_dict []
# model_words_dict ['parent', 'treatment', 'personnel', 'volunteers', 'minutes', 'to', 'does', 'management', 'disorder']
# AND1
# label_words_dict ['parent', 'treatment', 'personnel', 'volunteers', 'minutes', 'to', 'management', 'disorder']
# model_words_dict ['parent', 'treatment', 'personnel', 'volunteers', 'minutes', 'to', 'does', 'management', 'disorder']
# OR
# label_words_dict ['years', 'AA', 'programs', 'selfinjury', 'attempt']
# model_words_dict ['years', 'therapy', 'AA', 'selfinjury', 'attempt']
# NOT
# label_words_dict ['to']
# model_words_dict ['to', 'does']
# NCT03861962_inc
# AND
# label_words_dict ['DNA']
# model_words_dict ['children', 'deceased', 'transplant', 'years']
# AND1
# label_words_dict ['children', 'donor', 'deceased', 'transplant', 'years']
# model_words_dict ['children', 'deceased', 'transplant', 'years']
# OR
# label_words_dict ['adults', '', 'heart', 'lung', 'living']
# model_words_dict ['', '', '', 'living']
# NOT
# label_words_dict ['donor', 'deceased']
# model_words_dict ['deceased']
# NCT03861988_exc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict ['Pregnant']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862027_exc
# AND
# label_words_dict []
# model_words_dict ['pneumomediastinum', 'hours', 'anticoagulants', 'Hg', 'Hg', 'periods', 'Incarceration']
# AND1
# label_words_dict ['pneumomediastinum', 'hours', 'that', 'pathology', 'anticoagulants', 'Hg', 'Hg', 'periods', 'Incarceration']
# model_words_dict ['pneumomediastinum', 'hours', 'anticoagulants', 'Hg', 'Hg', 'periods', 'Incarceration']
# OR
# label_words_dict ['Pneumothorax', 'hours', 'esophageal', 'ulcerations', 'tumors', 'diverticulitis', 'varices', 'sinusitis', 'epistaxis', '30', '3', 'preintervention', 'intervention']
# model_words_dict ['Pneumothorax', 'hours', 'esophageal', 'diverticulitis', 'varices', 'sinusitis', 'epistaxis', '30', '3']
# NOT
# label_words_dict ['that', 'pathology']
# model_words_dict []
# NCT03862066_exc
# AND
# label_words_dict []
# model_words_dict ['nivolumab', 'therapy', 'carcinoma']
# AND1
# label_words_dict ['nivolumab', 'therapy', 'carcinoma']
# model_words_dict ['nivolumab', 'therapy', 'carcinoma']
# OR
# label_words_dict ['immunotherapy', 'cetuximab', 'carcinoma', 'tumor', 'disease']
# model_words_dict ['immunotherapy', 'cetuximab', 'carcinoma', 'tumor', 'disease']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862105_inc
# AND
# label_words_dict ['patients']
# model_words_dict ['days', 'Englishspeaking', 'caregiver', 'read']
# AND1
# label_words_dict ['days', 'Englishspeaking', 'caregiver', 'read']
# model_words_dict ['days', 'Englishspeaking', 'caregiver', 'read']
# OR
# label_words_dict ['Male']
# model_words_dict ['Male']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862209_exc
# AND
# label_words_dict []
# model_words_dict ['do', 'intervention']
# AND1
# label_words_dict []
# model_words_dict ['do', 'intervention']
# OR
# label_words_dict []
# model_words_dict ['study']
# NOT
# label_words_dict []
# model_words_dict ['do']
# NCT03862209_inc
# AND
# label_words_dict ['severe', 'care', 'social', 'systematic']
# model_words_dict ['depression', 'SMI', 'remission', 'remission', 'longterm', 'plan', 'SMI']
# AND1
# label_words_dict ['SMI', 'are', 'remission', 'are', 'remission', 'are', 'longterm']
# model_words_dict ['depression', 'SMI', 'remission', 'remission', 'longterm', 'plan', 'SMI']
# OR
# label_words_dict ['disorder', 'depression', 'temporary', 'networks']
# model_words_dict []
# NOT
# label_words_dict ['are', 'are', 'are']
# model_words_dict []
# NCT03862235_exc
# AND
# label_words_dict []
# model_words_dict ['Smoking', 'consumption', 'medications']
# AND1
# label_words_dict ['Smoking', 'consumption', 'medications']
# model_words_dict ['Smoking', 'consumption', 'medications']
# OR
# label_words_dict ['diuretics', 'Liver']
# model_words_dict ['diuretics', 'Liver']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862274_exc
# AND
# label_words_dict []
# model_words_dict ['Patients', 'TPP1']
# AND1
# label_words_dict ['Patients', 'TPP1']
# model_words_dict ['Patients', 'TPP1']
# OR
# label_words_dict ['CLN2']
# model_words_dict ['CLN2']
# NOT
# label_words_dict ['Patients']
# model_words_dict ['Patients']
# NCT03862287_exc
# AND
# label_words_dict []
# model_words_dict ['old', '3', 'infection', 'impairment', 'psychosis', 'pain', 'impairment', 'study', 'usage']
# AND1
# label_words_dict ['old', '3', 'infection', 'impairment', 'psychosis', 'pain', 'impairment', 'study', 'usage']
# model_words_dict ['old', '3', 'infection', 'impairment', 'psychosis', 'pain', 'impairment', 'study', 'usage']
# OR
# label_words_dict ['Immunosuppression', 'anesthetics', 'analgesics']
# model_words_dict ['Immunosuppression', 'anesthetics']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862404_inc
# AND
# label_words_dict []
# model_words_dict ['years']
# AND1
# label_words_dict []
# model_words_dict ['years']
# OR
# label_words_dict ['Male']
# model_words_dict ['Male']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862417_inc
# AND
# label_words_dict ['old', 'n20']
# model_words_dict ['old', 'n20']
# AND1
# label_words_dict []
# model_words_dict ['old', 'n20']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862456_inc
# AND
# label_words_dict ['screening']
# model_words_dict ['IV', 'surgery', 'molars', 'teeth', 'dentition', 'visit', 'culture', 'patients']
# AND1
# label_words_dict ['surgery', 'molars', 'teeth', 'dentition', 'culture']
# model_words_dict ['IV', 'surgery', 'molars', 'teeth', 'dentition', 'visit', 'culture', 'patients']
# OR
# label_words_dict ['postscaling']
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862469_inc
# AND
# label_words_dict []
# model_words_dict ['Female', 'ID', 'days']
# AND1
# label_words_dict ['Female', 'ID', 'days']
# model_words_dict ['Female', 'ID', 'days']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862521_inc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862547_inc
# AND
# label_words_dict ['men', 'DE']
# model_words_dict ['men', 'DE']
# AND1
# label_words_dict []
# model_words_dict ['men', 'DE']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862573_exc
# AND
# label_words_dict ['Children']
# model_words_dict ['Children', 'communication', 'goggles']
# AND1
# label_words_dict ['may', 'communication', 'features', 'goggles']
# model_words_dict ['Children', 'communication', 'goggles']
# OR
# label_words_dict ['delay', 'autism', 'mask', 'IV']
# model_words_dict ['participation', 'delay', 'autism', 'Children', 'N2O']
# NOT
# label_words_dict ['may', 'features']
# model_words_dict []
# NCT03862612_exc
# AND
# label_words_dict []
# model_words_dict ['consent', 'site', 'coagulopathy', 'anaesthesia', 'deficit', 'abuse', 'condition']
# AND1
# label_words_dict ['consent', 'site', 'coagulopathy', 'anaesthesia', 'deficit', 'abuse', 'condition']
# model_words_dict ['consent', 'site', 'coagulopathy', 'anaesthesia', 'deficit', 'abuse', 'condition']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862690_exc
# AND
# label_words_dict []
# model_words_dict ['study', 'unwillingness', 'barriers', 'cooperation', 'or', 'studies', 'excipients']
# AND1
# label_words_dict ['study', 'cooperation', 'studies', 'excipients']
# model_words_dict ['study', 'unwillingness', 'barriers', 'cooperation', 'or', 'studies', 'excipients']
# OR
# label_words_dict ['unwillingness', 'trial', '30', 'Pregnancy']
# model_words_dict ['incapacity', 'approved', '30', 'Pregnancy']
# NOT
# label_words_dict []
# model_words_dict ['barriers', 'or']
# NCT03862742_exc
# AND
# label_words_dict []
# model_words_dict ['consent', 'age', 'language', 'diagnosis']
# AND1
# label_words_dict ['consent', 'age', '', 'language']
# model_words_dict ['consent', 'age', 'language', 'diagnosis']
# OR
# label_words_dict ['urgency']
# model_words_dict []
# NOT
# label_words_dict ['']
# model_words_dict []
# NCT03862781_inc
# AND
# label_words_dict ['age', 'approach']
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict ['robotic', 'colon']
# model_words_dict ['age', 'robotic', 'artery', 'ileum', 'colon', 'artery']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862846_inc
# AND
# label_words_dict ['mutation']
# model_words_dict ['consent', 'recommendations', 'mutation', 'myopathy']
# AND1
# label_words_dict ['consent', 'recommendations', 'myopathy']
# model_words_dict ['consent', 'recommendations', 'mutation', 'myopathy']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03862963_inc
# AND
# label_words_dict ['T2D']
# model_words_dict ['Islands', 'years', 'T2D', 'medication']
# AND1
# label_words_dict ['Islands', 'years', 'medication']
# model_words_dict ['Islands', 'years', 'T2D', 'medication']
# OR
# label_words_dict ['80']
# model_words_dict ['80']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863067_inc
# AND
# label_words_dict []
# model_words_dict ['practice', 'claudication', 'months', '6', '', 'treatment', '']
# AND1
# label_words_dict ['practice', 'claudication', 'months', '6', '', 'treatment', '']
# model_words_dict ['practice', 'claudication', 'months', '6', '', 'treatment', '']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict ['', '']
# model_words_dict ['', '']
# NCT03863080_exc
# AND
# label_words_dict []
# model_words_dict ['dosing', 'Screening', 'screening', 'screening', 'screening']
# AND1
# label_words_dict ['dosing', 'Screening', 'screening', 'screening', 'screening']
# model_words_dict ['dosing', 'Screening', 'screening', 'screening', 'screening']
# OR
# label_words_dict ['rituximab', 'belimumab', 'eculizumab', 'Immunoglobulins', 'SC', 'IVIG']
# model_words_dict ['rituximab', 'belimumab', 'eculizumab', 'SC', 'IVIG', 'route']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863158_exc
# AND
# label_words_dict []
# model_words_dict ['oedema', 'angiography', 'diagnosis', 'surgery']
# AND1
# label_words_dict ['oedema', 'angiography', 'diagnosis', 'surgery']
# model_words_dict ['oedema', 'angiography', 'diagnosis', 'surgery']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863171_inc
# AND
# label_words_dict []
# model_words_dict ['syndrome', 'degeneration', 'years', 'all']
# AND1
# label_words_dict ['syndrome', 'degeneration', 'years', 'all']
# model_words_dict ['syndrome', 'degeneration', 'years', 'all']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863197_inc
# AND
# label_words_dict []
# model_words_dict ['SCP', 'years', 'impairment']
# AND1
# label_words_dict ['SCP', 'years', 'impairment']
# model_words_dict ['SCP', 'years', 'impairment']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863210_exc
# AND
# label_words_dict []
# model_words_dict ['stroke', 'diseases']
# AND1
# label_words_dict ['stroke', 'diseases']
# model_words_dict ['stroke', 'diseases']
# OR
# label_words_dict ['disease', 'disease', 'systemic']
# model_words_dict ['systemic']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863210_inc
# AND
# label_words_dict ['cholesterol']
# model_words_dict ['sex', 'years', 'smoking']
# AND1
# label_words_dict ['sex', 'years', 'smoking']
# model_words_dict ['sex', 'years', 'smoking']
# OR
# label_words_dict ['overweight', 'kgm2', 'pressure']
# model_words_dict ['overweight', 'kgm2', 'Hg', 'smoking']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863275_exc
# AND
# label_words_dict []
# model_words_dict ['treatment', 'injuries', 'cleft', 'anomalies']
# AND1
# label_words_dict ['treatment', 'injuries', 'cleft']
# model_words_dict ['treatment', 'injuries', 'cleft', 'anomalies']
# OR
# label_words_dict ['Robin', 'anomalies']
# model_words_dict ['Robin']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863353_exc
# AND
# label_words_dict ['opioid']
# model_words_dict ['procedure', 'impairment', 'pain', 'condition', 'conditions', 'nonopioid']
# AND1
# label_words_dict ['Undergoing', 'procedure', 'impairment', 'pain', 'condition', 'conditions', 'a', 'nonopioid']
# model_words_dict ['procedure', 'impairment', 'pain', 'condition', 'conditions', 'nonopioid']
# OR
# label_words_dict ['Hematologic']
# model_words_dict ['Hematologic', 'Liver']
# NOT
# label_words_dict ['Undergoing', 'impairment', 'conditions', 'a']
# model_words_dict ['impairment', 'conditions']
# NCT03863366_exc
# AND
# label_words_dict []
# model_words_dict ['implant', 'disorder', 'condition', 'dependency', 'breastfeeding', 'glucose', 'breastfeeding', 'galactose', 'dependency', 'months']
# AND1
# label_words_dict ['implant', 'disorder', 'condition', 'syndrome', 'breastfeeding', 'glucose', 'dependency', 'months', 'tasks', 'day']
# model_words_dict ['implant', 'disorder', 'condition', 'dependency', 'breastfeeding', 'glucose', 'breastfeeding', 'galactose', 'dependency', 'months']
# OR
# label_words_dict ['injection', 'past', 'Current', 'disorder', 'pregnancy', 'deficiency', 'lactose', 'galactose', 'Current', 'drug', 'psychological', 'same']
# model_words_dict ['past', 'Current', 'drug', 'Current', 'deficiency', 'lactose', 'galactose', 'Current', 'Current']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863405_inc
# AND
# label_words_dict []
# model_words_dict ['criteria', '32']
# AND1
# label_words_dict ['', '32']
# model_words_dict ['criteria', '32']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863496_exc
# AND
# label_words_dict []
# model_words_dict ['procedures', 'parentscaregivers', 'study', 'echocardiography', '20', 'months', 'normal', 'opinion']
# AND1
# label_words_dict ['Patient', 'or', 'procedures', 'parentscaregivers', 'study', 'echocardiography', '20', 'months', 'normal', 'mlmin', 'which']
# model_words_dict ['procedures', 'parentscaregivers', 'study', 'echocardiography', '20', 'months', 'normal', 'opinion']
# OR
# label_words_dict ['unwillingness', 'child', 'ALT', 'AST']
# model_words_dict ['ALT', 'AST', 'mlmin']
# NOT
# label_words_dict ['Patient', 'or', 'which']
# model_words_dict []
# NCT03863509_exc
# AND
# label_words_dict ['women', 'women']
# model_words_dict ['medication', 'women', 'month', 'women', 'pregnant', 'individuals']
# AND1
# label_words_dict ['medication', 'month', 'pregnant', 'individuals']
# model_words_dict ['medication', 'women', 'month', 'women', 'pregnant', 'individuals']
# OR
# label_words_dict ['pregnant', 'sarcoidosis', 'lung']
# model_words_dict ['years']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863548_exc
# AND
# label_words_dict []
# model_words_dict ['curatorship', 'guardianship', 'incompetent', 'woman', 'consent', 'study', 'participation', 'months', 'examination', 'retinopathy', 'hemorrhage']
# AND1
# label_words_dict ['guardianship', 'incompetent', 'woman', 'consent', 'study', 'does', 'participation', 'months', 'examination', 'retinopathy', 'hemorrhage', 'detachment']
# model_words_dict ['curatorship', 'guardianship', 'incompetent', 'woman', 'consent', 'study', 'participation', 'months', 'examination', 'retinopathy', 'hemorrhage']
# OR
# label_words_dict ['pregnant', 'parturient', 'physical', 'severe', 'subretinal']
# model_words_dict ['pregnant', 'physical', 'severe']
# NOT
# label_words_dict ['does']
# model_words_dict []
# NCT03863548_inc
# AND
# label_words_dict []
# model_words_dict ['participate', 'age']
# AND1
# label_words_dict ['participate', 'age']
# model_words_dict ['participate', 'age']
# OR
# label_words_dict ['surgery', 'surgery']
# model_words_dict ['surgery', 'surgery']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863561_exc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863561_inc
# AND
# label_words_dict []
# model_words_dict ['diabetes', 'years', 'English', 'only']
# AND1
# label_words_dict ['diabetes', 'years', 'English', 'only']
# model_words_dict ['diabetes', 'years', 'English', 'only']
# OR
# label_words_dict ['1']
# model_words_dict ['1']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863600_exc
# AND
# label_words_dict []
# model_words_dict ['areas', 'pregnancy', '']
# AND1
# label_words_dict ['areas', 'pregnancy', '']
# model_words_dict ['areas', 'pregnancy', '']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict ['']
# model_words_dict ['']
# NCT03863691_exc
# AND
# label_words_dict []
# model_words_dict ['allergy', 'lactose', 'contraceptives', 'seizures', 'cancer', 'minute', 'thrombosis', 'interval', 'of', 'study', 'present', 'disorders', 'Pregnancy', 'breastfeeding']
# AND1
# label_words_dict ['allergy', 'lactose', 'contraceptives', 'seizures', 'cancer', 'minute', 'thrombosis', 'interval', 'study', 'present', 'disorders']
# model_words_dict ['allergy', 'lactose', 'contraceptives', 'seizures', 'cancer', 'minute', 'thrombosis', 'interval', 'of', 'study', 'present', 'disorders', 'Pregnancy', 'breastfeeding']
# OR
# label_words_dict ['pheochromocytoma', 'prolactinoma', 'stroke', 'thoughts', 'past', 'schizophrenia', 'disorder', 'abuse', 'Pregnancy']
# model_words_dict ['pheochromocytoma', 'stroke', 'thoughts', 'past', 'schizophrenia', 'disorder', 'abuse']
# NOT
# label_words_dict []
# model_words_dict ['of']
# NCT03863691_inc
# AND
# label_words_dict []
# model_words_dict ['language']
# AND1
# label_words_dict ['language']
# model_words_dict ['language']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863717_exc
# AND
# label_words_dict []
# model_words_dict ['old', 'disease', 'or', 'exercise', 'stage', 'an']
# AND1
# label_words_dict ['old', 'disease', 'exercise', 'stage']
# model_words_dict ['old', 'disease', 'or', 'exercise', 'stage', 'an']
# OR
# label_words_dict ['Musculoskeletal', 'stage', 'cognitive']
# model_words_dict ['Musculoskeletal', 'performance', 'stage', 'cognitive']
# NOT
# label_words_dict []
# model_words_dict ['or', 'an']
# NCT03863756_exc
# AND
# label_words_dict []
# model_words_dict ['imaging', 'cognition']
# AND1
# label_words_dict ['imaging', 'cognition']
# model_words_dict ['imaging', 'cognition']
# OR
# label_words_dict ['spine']
# model_words_dict ['CR', 'spine']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863847_inc
# AND
# label_words_dict []
# model_words_dict ['months', 'epicondylalgia']
# AND1
# label_words_dict ['months', 'epicondylalgia']
# model_words_dict ['months', 'epicondylalgia']
# OR
# label_words_dict ['gripping', 'contraction', 'brevis']
# model_words_dict ['gripping', 'extensors']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863925_inc
# AND
# label_words_dict ['compatible', 'acuity']
# model_words_dict ['old', 'decision', 'acuity', 'acuity', 'correction']
# AND1
# label_words_dict ['old', 'decision', 'correction']
# model_words_dict ['old', 'decision', 'acuity', 'acuity', 'correction']
# OR
# label_words_dict ['disorder', 'disorder']
# model_words_dict ['disorder', 'disorder']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03863938_exc
# AND
# label_words_dict ['insertion']
# model_words_dict ['diseases', 'etc', 'hypersensitivity', 'positive', 'catheter', 'abuse', 'intake', '']
# AND1
# label_words_dict ['diseases', 'etc', 'hypersensitivity', 'positive', 'catheter', 'abuse', 'intake', '']
# model_words_dict ['diseases', 'etc', 'hypersensitivity', 'positive', 'catheter', 'abuse', 'intake', '']
# OR
# label_words_dict ['Presence', 'Presence', 'ulcer', 'GERD', 'drug', 'inhibitor', 'aspirin', 'etc', 'intake']
# model_words_dict ['Presence', 'Presence', 'drug', 'inhibitor', 'aspirin', 'intake']
# NOT
# label_words_dict ['']
# model_words_dict ['']
# NCT03864094_inc
# AND
# label_words_dict []
# model_words_dict ['women', 'years', 'procedures']
# AND1
# label_words_dict ['women', 'years', 'procedures']
# model_words_dict ['women', 'years', 'procedures']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864120_exc
# AND
# label_words_dict []
# model_words_dict ['month', 'dialysis', 'failure', 'hernia']
# AND1
# label_words_dict ['month', 'dialysis', 'failure']
# model_words_dict ['month', 'dialysis', 'failure', 'hernia']
# OR
# label_words_dict ['Peritonitis', 'cirrhosis', 'peritoneal']
# model_words_dict ['Peritonitis', 'cirrhosis', 'cavity']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864133_exc
# AND
# label_words_dict ['steady', 'Female']
# model_words_dict ['NSAIDs', 'steady', 'OCT', 'trauma', 'baseline', 'analogue', 'OCT', 'postoperatively', 'appointments']
# AND1
# label_words_dict ['NSAIDs', '', 'OCT', 'trauma', 'baseline', 'analogue', 'OCT', 'postoperatively', '', 'appointments']
# model_words_dict ['NSAIDs', 'steady', 'OCT', 'trauma', 'baseline', 'analogue', 'OCT', 'postoperatively', 'appointments']
# OR
# label_words_dict ['Phenylephrine', 'rupture', 'loss', 'dialysis', 'pregnant', 'lactating']
# model_words_dict ['Phenylephrine', 'rupture', 'loss', 'dialysis', 'pregnant', 'lactating']
# NOT
# label_words_dict ['', '']
# model_words_dict []
# NCT03864172_exc
# AND
# label_words_dict ['supplements']
# model_words_dict ['anaemia', 'medication', 'supplements', 'and']
# AND1
# label_words_dict ['anaemia', 'medication', 'to']
# model_words_dict ['anaemia', 'medication', 'supplements', 'and']
# OR
# label_words_dict ['intestinal', 'diseases', 'renal', 'hepatic', 'diseases', 'disorders', 'ulcer', 'hyperthyroidism', 'malnutrition', 'History', 'steroids', 'hormones', 'diuretics', 'cortisone']
# model_words_dict ['intestinal', 'diseases', 'diabetes', 'renal', 'hepatic', 'diseases', 'disorders', 'ulcer', 'hyperthyroidism', 'steroids', 'hormones', 'diuretics', 'cortisone']
# NOT
# label_words_dict ['to']
# model_words_dict ['and']
# NCT03864198_exc
# AND
# label_words_dict ['drugs']
# model_words_dict ['azoospermia', 'smoke', 'drugs', 'toxicity', 'substances', 'heat', 'mumps', 'diseases', 'cryptorchidism', 'torsion', 'anomalies']
# AND1
# label_words_dict ['azoospermia', 'smoke', 'drugs', 'toxicity', 'substances', 'heat', 'mumps', 'diseases', 'cryptorchidism', 'torsion', 'anomalies', 'deferens']
# model_words_dict ['azoospermia', 'smoke', 'drugs', 'toxicity', 'substances', 'heat', 'mumps', 'diseases', 'cryptorchidism', 'torsion', 'anomalies']
# OR
# label_words_dict ['environmental', 'radiation', 'epididymis']
# model_words_dict ['environmental', 'radiation', 'epididymis']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864263_inc
# AND
# label_words_dict []
# model_words_dict ['present']
# AND1
# label_words_dict ['present']
# model_words_dict ['present']
# OR
# label_words_dict ['father', 'prepregnancy']
# model_words_dict ['father', 'prepregnancy']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864276_inc
# AND
# label_words_dict ['cirrhosis']
# model_words_dict ['cirrhosis']
# AND1
# label_words_dict []
# model_words_dict ['cirrhosis']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864302_exc
# AND
# label_words_dict []
# model_words_dict ['', 'procedures', 'months']
# AND1
# label_words_dict ['', 'procedures', 'months']
# model_words_dict ['', 'procedures', 'months']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict ['']
# model_words_dict ['']
# NCT03864302_inc
# AND
# label_words_dict []
# model_words_dict ['Doctors', 'consent']
# AND1
# label_words_dict ['Doctors', 'consent']
# model_words_dict ['Doctors', 'consent']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864354_exc
# AND
# label_words_dict []
# model_words_dict ['smoker', 'asthma']
# AND1
# label_words_dict ['smoker', 'asthma']
# model_words_dict ['smoker', 'asthma']
# OR
# label_words_dict ['treatment']
# model_words_dict ['treatment']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864484_exc
# AND
# label_words_dict []
# model_words_dict ['stroke', 'hemiplegia', 'life', 'life', 'aphasia', 'neglect', 'atrophy']
# AND1
# label_words_dict ['stroke', 'hemiplegia', 'life', 'aphasia', 'neglect', 'atrophy']
# model_words_dict ['stroke', 'hemiplegia', 'life', 'life', 'aphasia', 'neglect', 'atrophy']
# OR
# label_words_dict ['Vision', 'disease', 'failure', 'disorders']
# model_words_dict ['Vision', 'disease', 'failure', 'disorders']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864497_inc
# AND
# label_words_dict []
# model_words_dict ['following', 'history', 'mellitus', '152μmoll', 'CABG', 'angina', 'disease']
# AND1
# label_words_dict ['following', '', 'history', 'mellitus', '152μmoll', 'CABG', 'angina', 'disease']
# model_words_dict ['following', 'history', 'mellitus', '152μmoll', 'CABG', 'angina', 'disease']
# OR
# label_words_dict ['MI', 'PCI']
# model_words_dict ['MI', 'PCI']
# NOT
# label_words_dict ['']
# model_words_dict []
# NCT03864614_exc
# AND
# label_words_dict []
# model_words_dict ['MDD', 'disorder']
# AND1
# label_words_dict ['MDD', 'disorder']
# model_words_dict ['MDD', 'disorder']
# OR
# label_words_dict ['disorder', 'schizophrenia', 'stimulation', 'therapy']
# model_words_dict ['disorder', 'schizophrenia', 'stimulation', 'therapy', 'episode']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864640_exc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864705_inc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864757_exc
# AND
# label_words_dict []
# model_words_dict ['clinical', 'investigation', 'investigation', 'before', 'years', 'nodules', 'cordectomy', 'adduction', 'Significant', 'therapists']
# AND1
# label_words_dict ['investigation', 'investigation', 'before', 'years', 'nodules', 'cordectomy', 'adduction', 'Significant', 'therapists']
# model_words_dict ['clinical', 'investigation', 'investigation', 'before', 'years', 'nodules', 'cordectomy', 'adduction', 'Significant', 'therapists']
# OR
# label_words_dict ['disease', 'surgery', 'polyp', 'thyroplasty']
# model_words_dict ['disease', 'investigation', 'surgery', 'polyp', 'thyroplasty']
# NOT
# label_words_dict ['Significant']
# model_words_dict ['clinical', 'Significant']
# NCT03864757_inc
# AND
# label_words_dict ['UVFP', 'closure']
# model_words_dict ['years', 'UVFP', 'closure', 'implant']
# AND1
# label_words_dict ['years', 'implant']
# model_words_dict ['years', 'UVFP', 'closure', 'implant']
# OR
# label_words_dict ['Male']
# model_words_dict ['Male']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864770_exc
# AND
# label_words_dict []
# model_words_dict ['Quinine', 'anticonvulsants', 'surgery']
# AND1
# label_words_dict ['anticonvulsants', 'surgery', 'impaired']
# model_words_dict ['Quinine', 'anticonvulsants', 'surgery']
# OR
# label_words_dict ['Quinine', 'diuretics', 'statins', 'blockers', 'limb', 'Uncommunicated']
# model_words_dict ['research', 'diuretics', 'statins', 'blockers', 'limb']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864796_exc
# AND
# label_words_dict []
# model_words_dict ['will', 'as', 'diabetes', 'HCV', 'RA']
# AND1
# label_words_dict ['will', 'or', 'as', 'diabetes', 'HCV', 'RA']
# model_words_dict ['will', 'as', 'diabetes', 'HCV', 'RA']
# OR
# label_words_dict ['immune', 'SLE', 'Liver']
# model_words_dict ['immune', 'SLE', 'Liver']
# NOT
# label_words_dict ['will', 'or']
# model_words_dict ['will']
# NCT03864796_inc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864809_inc
# AND
# label_words_dict []
# model_words_dict ['Psoriasis']
# AND1
# label_words_dict []
# model_words_dict ['Psoriasis']
# OR
# label_words_dict ['Psoriasis']
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864887_exc
# AND
# label_words_dict []
# model_words_dict ['conception', 'surgery', 'specialists', 'Syphilis']
# AND1
# label_words_dict ['conception', 'surgery', 'specialists', 'Syphilis']
# model_words_dict ['conception', 'surgery', 'specialists', 'Syphilis']
# OR
# label_words_dict ['pregnancy', 'surgery', 'Hepatitis', 'Tuberculosis', 'anticoagulants']
# model_words_dict ['pregnancy', 'surgery', 'radiologists', 'AIDS', 'Hepatitis', 'Tuberculosis', 'anticoagulants']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03864887_inc
# AND
# label_words_dict ['people']
# model_words_dict ['trauma']
# AND1
# label_words_dict ['trauma']
# model_words_dict ['trauma']
# OR
# label_words_dict ['death']
# model_words_dict ['death']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865056_exc
# AND
# label_words_dict []
# model_words_dict ['consent', 'years', 'admission', 'intubation', 'study', 'therapy', 'edema', '12', 'death', 'ventilation']
# AND1
# label_words_dict ['consent', 'years', 'admission', 'intubation', 'study', 'therapy', 'edema', '12', 'death', 'ventilation']
# model_words_dict ['consent', 'years', 'admission', 'intubation', 'study', 'therapy', 'edema', '12', 'death', 'ventilation']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865108_inc
# AND
# label_words_dict ['days']
# model_words_dict ['gestation', 'spontaneously', 'age', 'are', 'age', 'Age']
# AND1
# label_words_dict ['gestation', 'is', 'age', 'are', 'eligible', 'Age', 'is']
# model_words_dict ['gestation', 'spontaneously', 'age', 'are', 'age', 'Age']
# OR
# label_words_dict ['spontaneously']
# model_words_dict []
# NOT
# label_words_dict ['is', 'are', 'is']
# model_words_dict ['are']
# NCT03865173_exc
# AND
# label_words_dict []
# model_words_dict ['PAPASéPA']
# AND1
# label_words_dict ['PAPASéPA']
# model_words_dict ['PAPASéPA']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865173_inc
# AND
# label_words_dict []
# model_words_dict ['France', 'physician', 'region', 'PAPASéPA']
# AND1
# label_words_dict ['France', 'physician', 'region', 'PAPASéPA']
# model_words_dict ['France', 'physician', 'region', 'PAPASéPA']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict ['AND1']
# model_words_dict []
# NCT03865186_inc
# AND
# label_words_dict []
# model_words_dict ['DSMIV']
# AND1
# label_words_dict ['DSMIV']
# model_words_dict ['DSMIV']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865199_exc
# AND
# label_words_dict []
# model_words_dict ['include', 'telephone']
# AND1
# label_words_dict ['include']
# model_words_dict ['include', 'telephone']
# OR
# label_words_dict []
# model_words_dict ['speaking']
# NOT
# label_words_dict ['include']
# model_words_dict ['include']
# NCT03865225_exc
# AND
# label_words_dict []
# model_words_dict ['days', 'fibrillation', 'neuropathy', 'unit', 'deficit', 'training', 'insufficiency', 'deafness']
# AND1
# label_words_dict ['days', 'fibrillation', 'neuropathy', 'unit', 'resulted', 'training', 'insufficiency', 'resulted']
# model_words_dict ['days', 'fibrillation', 'neuropathy', 'unit', 'deficit', 'training', 'insufficiency', 'deafness']
# OR
# label_words_dict ['infarct', 'aphasia', 'blindness', 'deafness']
# model_words_dict ['infarct', 'aphasia', 'blindness']
# NOT
# label_words_dict ['resulted', 'resulted']
# model_words_dict ['deficit', 'deafness']
# NCT03865251_inc
# AND
# label_words_dict []
# model_words_dict ['week']
# AND1
# label_words_dict ['week']
# model_words_dict ['week']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865303_exc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865329_inc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865342_exc
# AND
# label_words_dict []
# model_words_dict ['visit', 'diabetes', 'illnesses', 'days', 'enrollment', 'Pregnant', 'nursing', 'months']
# AND1
# label_words_dict ['visit', 'diabetes', 'illnesses', 'days', 'enrollment', 'Pregnant', 'nursing', 'months', 'been']
# model_words_dict ['visit', 'diabetes', 'illnesses', 'days', 'enrollment', 'Pregnant', 'nursing', 'months']
# OR
# label_words_dict ['1', 'serious', 'currently']
# model_words_dict ['1', 'serious']
# NOT
# label_words_dict ['been']
# model_words_dict []
# NCT03865407_exc
# AND
# label_words_dict []
# model_words_dict ['Allopurinol', 'tests', 'dialysis', 'disorder', 'disease', 'Cystinosis', 'Disease', 'nursing']
# AND1
# label_words_dict ['Allopurinol', 'tests', 'dialysis', 'disorder', 'disease', 'Disease', 'Cystinosis', 'Disease']
# model_words_dict ['Allopurinol', 'tests', 'dialysis', 'disorder', 'disease', 'Cystinosis', 'Disease', 'nursing']
# OR
# label_words_dict ['acute', 'Bartter', 'Pregnant']
# model_words_dict ['acute', 'Disease', 'Bartter', 'Pregnant']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865420_exc
# AND
# label_words_dict []
# model_words_dict ['HIV', 'B']
# AND1
# label_words_dict ['HIV', 'B']
# model_words_dict ['HIV', 'B']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865420_inc
# AND
# label_words_dict ['diagnosis', 'testing']
# model_words_dict ['older', '', 'enrollment', 'mutation', 'mutation', 'results', 'procedures']
# AND1
# label_words_dict ['older', '', 'enrollment', 'mutation', 'results', 'procedures']
# model_words_dict ['older', '', 'enrollment', 'mutation', 'mutation', 'results', 'procedures']
# OR
# label_words_dict ['Men', 'ALS', 'mutation']
# model_words_dict ['Men', 'ALS', 'diagnosis']
# NOT
# label_words_dict ['']
# model_words_dict ['']
# NCT03865498_inc
# AND
# label_words_dict []
# model_words_dict ['older', 'territories', 'English', 'Spanishbilingual', 'security']
# AND1
# label_words_dict ['older', 'territories', 'Spanishbilingual', 'security']
# model_words_dict ['older', 'territories', 'English', 'Spanishbilingual', 'security']
# OR
# label_words_dict ['Black', 'English', 'violence', 'misconduct']
# model_words_dict ['Black', 'caregiver', 'smartphone']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865589_exc
# AND
# label_words_dict []
# model_words_dict ['still']
# AND1
# label_words_dict []
# model_words_dict ['still']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865602_exc
# AND
# label_words_dict ['infection']
# model_words_dict ['arms', '2', 'hospital', 'infection', 'hospitals', 'treatment']
# AND1
# label_words_dict ['arms', '2', 'hospital', 'and', 'infection', 'hospitals', 'treatment', 'infection']
# model_words_dict ['arms', '2', 'hospital', 'infection', 'hospitals', 'treatment']
# OR
# label_words_dict ['resident', 'resuscitate']
# model_words_dict ['resident', 'resuscitate']
# NOT
# label_words_dict ['2', 'and', 'infection']
# model_words_dict ['2']
# NCT03865641_exc
# AND
# label_words_dict []
# model_words_dict ['aphasia']
# AND1
# label_words_dict []
# model_words_dict ['aphasia']
# OR
# label_words_dict ['muscles', 'tendons', 'injuries', 'diseasesfracture', 'amputation', 'arthritis', 'physical', 'disability', 'aphasia']
# model_words_dict ['tendons', 'diseases', 'fracture', 'amputation', 'arthritis', 'hand', 'diseases', 'physical']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865680_inc
# AND
# label_words_dict ['children', 'children']
# model_words_dict ['children', 'with', 'diseases', 'children', 'teeth', '3']
# AND1
# label_words_dict ['with', 'diseases', '3']
# model_words_dict ['children', 'with', 'diseases', 'children', 'teeth', '3']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict ['with']
# model_words_dict ['with']
# NCT03865706_inc
# AND
# label_words_dict ['infection']
# model_words_dict ['ICU', 'hospitalization', 'consensus', 'infection', 'baseline', 'administration']
# AND1
# label_words_dict ['ICU', 'hospitalization', 'baseline', 'administration']
# model_words_dict ['ICU', 'hospitalization', 'consensus', 'infection', 'baseline', 'administration']
# OR
# label_words_dict ['known', 'hours']
# model_words_dict ['known']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865732_exc
# AND
# label_words_dict []
# model_words_dict ['ganaxolone', 'screening', 'permitted', 'or', 'phase']
# AND1
# label_words_dict ['ganaxolone', 'seizure', 'screening', 'is', 'permitted', 'is', 'phase']
# model_words_dict ['ganaxolone', 'screening', 'permitted', 'or', 'phase']
# OR
# label_words_dict ['inducers', 'CYP3A4', '5', 'THC', 'days']
# model_words_dict ['inducers', 'THC']
# NOT
# label_words_dict ['seizure', 'is', 'is']
# model_words_dict ['or']
# NCT03865732_inc
# AND
# label_words_dict ['seizures']
# model_words_dict ['variant', 'medications', 'screening']
# AND1
# label_words_dict ['variant', '', 'medications', 'screening']
# model_words_dict ['variant', 'medications', 'screening']
# OR
# label_words_dict ['pathogenic', 'stimulator', 'diet']
# model_words_dict ['pathogenic', 'stimulator', 'diet']
# NOT
# label_words_dict ['']
# model_words_dict []
# NCT03865758_exc
# AND
# label_words_dict []
# model_words_dict ['']
# AND1
# label_words_dict ['']
# model_words_dict ['']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict ['']
# model_words_dict ['']
# NCT03865784_inc
# AND
# label_words_dict []
# model_words_dict ['boxers', 'years', 'Male', 'With']
# AND1
# label_words_dict ['boxers', 'years', 'Male', 'With']
# model_words_dict ['boxers', 'years', 'Male', 'With']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict ['With']
# model_words_dict ['With']
# NCT03865823_inc
# AND
# label_words_dict ['fistula']
# model_words_dict ['patient']
# AND1
# label_words_dict []
# model_words_dict ['patient']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865862_exc
# AND
# label_words_dict []
# model_words_dict ['illness', 'study', 'study']
# AND1
# label_words_dict ['illness', 'study', 'study']
# model_words_dict ['illness', 'study', 'study']
# OR
# label_words_dict ['injury', 'pharmacological']
# model_words_dict ['injury', 'pharmacological']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03865953_exc
# AND
# label_words_dict ['DPN']
# model_words_dict ['NP']
# AND1
# label_words_dict ['NP']
# model_words_dict ['NP']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# ...
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03927339_exc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict ['hypertension', 'treadmillie', 'could']
# model_words_dict []
# OR
# label_words_dict ['cardiac', 'disease', 'neuromuscular', 'conditions', 'arch', 'hip', 'transmission', 'steroid', 'supplementation']
# model_words_dict ['cardiac', 'disease', 'treadmillie', 'neuromuscular', 'conditions', 'could', 'arch', 'hip', 'fractures', 'transmission', 'steroid', 'supplementation']
# NOT
# label_words_dict ['hypertension', 'treadmillie', 'could']
# model_words_dict ['treadmillie', 'could']
# NCT03927378_inc
# AND
# label_words_dict []
# model_words_dict ['years', '10']
# AND1
# label_words_dict ['years', '10']
# model_words_dict ['years', '10']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03927456_inc
# AND
# label_words_dict ['chemotherapy']
# model_words_dict ['HER2', 'Cancer', 'women', 'therapy', 'therapy']
# AND1
# label_words_dict ['Cancer', 'women', 'therapy', 'therapy']
# model_words_dict ['HER2', 'Cancer', 'women', 'therapy', 'therapy']
# OR
# label_words_dict ['recurrent', 'metastatic', 'positive', 'women', 'advanced']
# model_words_dict ['recurrent', 'women']
# NOT
# label_words_dict []
# model_words_dict ['HER2']
# NCT03927482_exc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict ['disorder']
# model_words_dict ['disorder']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03927612_exc
# AND
# label_words_dict []
# model_words_dict ['disorder', 'injury']
# AND1
# label_words_dict ['disorder', 'injury']
# model_words_dict ['disorder', 'injury']
# OR
# label_words_dict ['psychosis', 'current', 'disorder', 'epilepsy']
# model_words_dict ['psychosis', 'current', 'disorder', 'epilepsy']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03927638_inc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03927872_inc
# AND
# label_words_dict ['patients']
# model_words_dict ['criteria', '', 'non', 'group', '5']
# AND1
# label_words_dict ['and', 'criteria', '', 'group', '5']
# model_words_dict ['criteria', '', 'non', 'group', '5']
# OR
# label_words_dict ['CES']
# model_words_dict []
# NOT
# label_words_dict ['and', '']
# model_words_dict ['']
# NCT03927924_inc
# AND
# label_words_dict []
# model_words_dict ['MRI', 'cm3', 'lowrisk', 'biopsy']
# AND1
# label_words_dict ['MRI', 'cm3', 'biopsy', 'or', 'or']
# model_words_dict ['MRI', 'cm3', 'lowrisk', 'biopsy']
# OR
# label_words_dict ['lowrisk', 'biopsy', 'T2', '7']
# model_words_dict ['biopsy', 'T2', '7']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03928015_exc
# AND
# label_words_dict []
# model_words_dict ['agreement', 'hours', 'hours', 'oil', 'screeningrandomization', 'feeding']
# AND1
# label_words_dict ['agreement', 'hours', 'hours', 'oil', 'randomization', 'feeding']
# model_words_dict ['agreement', 'hours', 'hours', 'oil', 'screeningrandomization', 'feeding']
# OR
# label_words_dict ['randomization', 'received', 'neuraxial', 'allergy', 'dronabinol', 'screening', 'Pregnancy']
# model_words_dict ['randomization', 'received', 'neuraxial', 'allergy', 'dronabinol', 'Pregnancy']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03928054_exc
# AND
# label_words_dict []
# model_words_dict ['are', 'walk', 'cancer', 'diseases']
# AND1
# label_words_dict ['walk', 'cancer', 'diseases']
# model_words_dict ['are', 'walk', 'cancer', 'diseases']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict ['are']
# NCT03928158_inc
# AND
# label_words_dict []
# model_words_dict ['men', 'failure', '50', 'echocardiography', 'kgm²']
# AND1
# label_words_dict ['men', 'failure', '50', 'echocardiography', 'kgm²']
# model_words_dict ['men', 'failure', '50', 'echocardiography', 'kgm²']
# OR
# label_words_dict ['Moderate', 'women', 'rest']
# model_words_dict ['Moderate', 'rest']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03928171_exc
# AND
# label_words_dict []
# model_words_dict ['disease', 'lactation', 'surgery', 'kgm2', 'iodine', 'adenomas']
# AND1
# label_words_dict ['disease', 'lactation', 'surgery', 'kgm2', 'iodine', 'adenomas']
# model_words_dict ['disease', 'lactation', 'surgery', 'kgm2', 'iodine', 'adenomas']
# OR
# label_words_dict ['liver', 'Pregnancy', 'diagnostics', 'green', 'Hyperthyroidism']
# model_words_dict ['liver', 'Pregnancy', 'diagnostics', 'Known', 'green', 'iodide', 'Hyperthyroidism']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03928288_exc
# AND
# label_words_dict []
# model_words_dict ['postmenopause', 'hypertension', 'study', 'months', 'disease', 'previous', 'previous']
# AND1
# label_words_dict ['postmenopause', 'hypertension', 'study', 'months', 'disease', 'previous', 'previous']
# model_words_dict ['postmenopause', 'hypertension', 'study', 'months', 'disease', 'previous', 'previous']
# OR
# label_words_dict ['Premenarche', 'pulmonary', 'pericardial', 'mental', 'assessment', 'Pregnant', 'breastfeeding', 'current', 'current', 'phenothiazines', 'metoclopramide']
# model_words_dict ['Premenarche', 'disorder', 'pulmonary', 'pericardial', 'disorder', 'derivatives', 'mental', 'Pregnant', 'breastfeeding', '', 'current', 'current', 'phenothiazines', 'metoclopramide']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03928392_inc
# AND
# label_words_dict []
# model_words_dict ['age', 'months', 'dives']
# AND1
# label_words_dict ['age', 'months', 'dives']
# model_words_dict ['age', 'months', 'dives']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03928470_exc
# AND
# label_words_dict []
# model_words_dict ['esophagus', 'area', 'trial', 'medications', 'test']
# AND1
# label_words_dict ['esophagus', 'area', 'trial', 'medications', 'test']
# model_words_dict ['esophagus', 'area', 'trial', 'medications', 'test']
# OR
# label_words_dict ['stomach', 'stomach']
# model_words_dict ['stomach', 'stomach', 'woman']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03928470_inc
# AND
# label_words_dict []
# model_words_dict ['years', 'visit', 'visit']
# AND1
# label_words_dict ['years', 'visit', 'visit']
# model_words_dict ['years', 'visit', 'visit']
# OR
# label_words_dict ['Male']
# model_words_dict ['Male']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03928535_inc
# AND
# label_words_dict []
# model_words_dict ['AECOPD', 'ventilation', 'extubation', 'extubation']
# AND1
# label_words_dict ['AECOPD', 'ventilation', 'extubation', 'extubation']
# model_words_dict ['AECOPD', 'ventilation', 'extubation', 'extubation']
# OR
# label_words_dict ['HFNC']
# model_words_dict ['HFNC']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03928548_exc
# AND
# label_words_dict ['NICU']
# model_words_dict ['admission', 'women', 'Prisoners', 'NICU', 'prematurity', 'neonates', 'care']
# AND1
# label_words_dict ['admission', 'women', 'Prisoners', 'prematurity', 'neonates', 'care']
# model_words_dict ['admission', 'women', 'Prisoners', 'NICU', 'prematurity', 'neonates', 'care']
# OR
# label_words_dict ['viability', 'palliative']
# model_words_dict ['viability']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03928782_exc
# AND
# label_words_dict []
# model_words_dict ['study']
# AND1
# label_words_dict []
# model_words_dict ['study']
# OR
# label_words_dict []
# model_words_dict ['or']
# NOT
# label_words_dict []
# model_words_dict ['or']
# NCT03928795_exc
# AND
# label_words_dict ['retardation']
# model_words_dict ['defect', 'adhesion', 'emergency', 'anesthesia', 'study', 'Impossibility']
# AND1
# label_words_dict ['defect', 'adhesion', 'emergency', 'anesthesia', 'study', '', 'or']
# model_words_dict ['defect', 'adhesion', 'emergency', 'anesthesia', 'study', 'Impossibility']
# OR
# label_words_dict ['malformation', 'medical', 'Impossibility']
# model_words_dict ['malformation', 'medical']
# NOT
# label_words_dict ['', 'or']
# model_words_dict ['Impossibility']
# NCT03928860_inc
# AND
# label_words_dict []
# model_words_dict ['disease', '0414']
# AND1
# label_words_dict ['disease', '0414']
# model_words_dict ['disease', '0414']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03928873_exc
# AND
# label_words_dict []
# model_words_dict ['study', 'extremities']
# AND1
# label_words_dict ['study', 'extremities']
# model_words_dict ['study', 'extremities']
# OR
# label_words_dict ['therapy', 'injection', 'disease', 'arrhythmia', 'pacemaker']
# model_words_dict ['therapy', 'injection', 'disease', 'infection', 'arthritis', 'arrhythmia']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03928938_inc
# AND
# label_words_dict []
# model_words_dict ['consent', 'cancers', '2wks', '18y', '03']
# AND1
# label_words_dict ['consent', 'cancers', '2wks', '18y', '03']
# model_words_dict ['consent', 'cancers', '2wks', '18y', '03']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03928977_exc
# AND
# label_words_dict []
# model_words_dict ['MRI', 'lesions']
# AND1
# label_words_dict ['MRI', 'lesions']
# model_words_dict ['MRI', 'lesions']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03929315_exc
# AND
# label_words_dict []
# model_words_dict ['study', 'children']
# AND1
# label_words_dict ['study', 'children']
# model_words_dict ['study', 'children']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03929471_inc
# AND
# label_words_dict ['weeks']
# model_words_dict ['', 'months', '11L', 'patient']
# AND1
# label_words_dict ['months', '11L', 'patient']
# model_words_dict ['', 'months', '11L', 'patient']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03929510_exc
# AND
# label_words_dict []
# model_words_dict ['HIV', 'immunodeficiency', 'viruses', 'history', 'present', 'skin', 'test']
# AND1
# label_words_dict ['immunodeficiency', 'viruses', 'history', 'skin', 'Screening']
# model_words_dict ['HIV', 'immunodeficiency', 'viruses', 'history', 'present', 'skin', 'test']
# OR
# label_words_dict ['screening', 'B', 'infections', 'present', 'treated', 'cell', 'abuse', 'drinking', 'use', 'tobacco']
# model_words_dict ['B', 'acute', 'treated', 'abuse', 'drinking', 'use']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03929549_exc
# AND
# label_words_dict ['Fibromyalgia']
# model_words_dict ['40', 'pregnancy', 'hour', 'sleep', 'use', 'disorders', 'Disorders', 'Fibromyalgia', 'pain', 'mm', 'surgery']
# AND1
# label_words_dict ['40', 'pregnancy', 'hour', 'sleep', 'use', 'disorders', 'Disorders', 'pain', '', 'mm', '', 'surgery', 'disorders']
# model_words_dict ['40', 'pregnancy', 'hour', 'sleep', 'use', 'disorders', 'Disorders', 'Fibromyalgia', 'pain', 'mm', 'surgery']
# OR
# label_words_dict ['teeth']
# model_words_dict []
# NOT
# label_words_dict ['', '']
# model_words_dict []
# NCT03929562_exc
# AND
# label_words_dict []
# model_words_dict ['symptoms']
# AND1
# label_words_dict ['symptoms']
# model_words_dict ['symptoms']
# OR
# label_words_dict []
# model_words_dict ['Displays']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03929575_exc
# AND
# label_words_dict []
# model_words_dict ['Questionnaire', 'pregnant', 'kgm2', 'Questionnaire']
# AND1
# label_words_dict ['that', 'Questionnaire', 'pregnant', 'kgm2']
# model_words_dict ['Questionnaire', 'pregnant', 'kgm2', 'Questionnaire']
# OR
# label_words_dict ['women', 'expecting']
# model_words_dict ['women', 'expecting']
# NOT
# label_words_dict ['that']
# model_words_dict []
# NCT03929614_inc
# AND
# label_words_dict ['old']
# model_words_dict ['AIS', 'treatment', 'French']
# AND1
# label_words_dict ['AIS', 'treatment', 'French']
# model_words_dict ['AIS', 'treatment', 'French']
# OR
# label_words_dict ['English']
# model_words_dict ['English']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03929640_exc
# AND
# label_words_dict []
# model_words_dict ['drugs', 'endometritis', 'repair', 'medication', '', 'speaking', 'consent', 'pregnancy']
# AND1
# label_words_dict ['should', 'endometritis', 'repair', 'medication', '', 'speaking', 'consent', 'pregnancy']
# model_words_dict ['drugs', 'endometritis', 'repair', 'medication', '', 'speaking', 'consent', 'pregnancy']
# OR
# label_words_dict ['intraoperative', 'drugs', 'bowel', 'Allergy', 'substance', 'renal']
# model_words_dict ['intraoperative', 'should', 'hysterectomy', 'bowel', 'Allergy', 'opioid', 'substance', 'before', 'renal']
# NOT
# label_words_dict ['should', '']
# model_words_dict ['']
# NCT03929718_inc
# AND
# label_words_dict []
# model_words_dict ['ECG', '', 'time', 'AFL']
# AND1
# label_words_dict ['ECG', '', 'time', 'AFL']
# model_words_dict ['ECG', '', 'time', 'AFL']
# OR
# label_words_dict ['ECG', 'monitor', 'pacemaker', 'HTN', 'reduced']
# model_words_dict ['AF', 'ECG', 'monitor', 'pacemaker', 'HTN', 'reduced']
# NOT
# label_words_dict ['']
# model_words_dict ['']
# NCT03929731_exc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03929744_exc
# AND
# label_words_dict []
# model_words_dict ['compounds', 'screening']
# AND1
# label_words_dict ['compounds', 'screening']
# model_words_dict ['compounds', 'screening']
# OR
# label_words_dict ['LY3502970', 'history', 'cardiovascular', 'respiratory', 'hepatic', 'renal', 'gastrointestinal', 'endocrine', 'hematological']
# model_words_dict ['LY3502970', 'of', 'cardiovascular', 'respiratory', 'hepatic', 'renal', 'gastrointestinal', 'endocrine', 'hematological']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03929744_inc
# AND
# label_words_dict []
# model_words_dict ['history']
# AND1
# label_words_dict ['history']
# model_words_dict ['history']
# OR
# label_words_dict ['male']
# model_words_dict ['male']
# NOT
# label_words_dict []
# model_words_dict []
# NCT03929770_inc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03929809_exc
# AND
# label_words_dict []
# model_words_dict ['surgery', 'might', 'array', 'candidate', 'procedures', 'devices', 'Unwillingness', 'or', 'requirements', 'infection']
# AND1
# label_words_dict ['surgery', 'might', 'array', 'devices', 'requirements', 'infection']
# model_words_dict ['surgery', 'might', 'array', 'candidate', 'procedures', 'devices', 'Unwillingness', 'or', 'requirements', 'infection']
# OR
# label_words_dict ['Medical', 'Ossification', 'procedures']
# model_words_dict ['Medical', 'Ossification', 'benefits', 'risks']
# NOT
# label_words_dict ['might']
# model_words_dict ['might', 'or']
# NCT03929822_inc
# AND
# label_words_dict ['tomosynthesis', 'pregnancy']
# model_words_dict ['Women', 'intervention']
# AND1
# label_words_dict ['or']
# model_words_dict ['Women', 'intervention']
# OR
# label_words_dict ['FFDM', 'masses', 'asymmetries', 'asymmetries', 'with']
# model_words_dict ['FFDM']
# NOT
# label_words_dict ['or']
# model_words_dict []
# NCT03929874_inc
# AND
# label_words_dict ['age']
# model_words_dict ['40', 'surgery']
# AND1
# label_words_dict ['surgery']
# model_words_dict ['40', 'surgery']
# OR
# label_words_dict ['40']
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03929887_exc
# AND
# label_words_dict []
# model_words_dict ['consent', '', 'each']
# AND1
# label_words_dict ['consent', '']
# model_words_dict ['consent', '', 'each']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict ['']
# model_words_dict ['']
# NCT03929926_exc
# AND
# label_words_dict []
# model_words_dict ['EHR']
# AND1
# label_words_dict ['EHR']
# model_words_dict ['EHR']
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03929991_inc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict []
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03930134_inc
# AND
# label_words_dict ['uterus', 'macrosomia']
# model_words_dict ['pregnancy', 'uterus', 'presentation', '4Kg']
# AND1
# label_words_dict ['pregnancy', 'presentation', '4Kg']
# model_words_dict ['pregnancy', 'uterus', 'presentation', '4Kg']
# OR
# label_words_dict ['bi', 'scar', 'myomectomy']
# model_words_dict []
# NOT
# label_words_dict []
# model_words_dict []
# NCT03934385_exc
# AND
# label_words_dict []
# model_words_dict []
# AND1
# label_words_dict []
# model_words_dict []
# OR
# label_words_dict ['bees', 'spiders']
# model_words_dict ['bees', 'spiders']
# NOT
# label_words_dict []
# model_words_dict []

# %%
all_metrics
# Out:
# {'Llama3_70b_Fine-Tuned_p4_ep10_p1': {'AND': {'precision': 3.6958066808813075,
#    'recall': 38.80597014925373,
#    'f1': 6.748864373783257,
#    'accuracy': 38.80597014925373,
#    'total_label': 134,
#    'total_model': 1402,
#    'correct_count': 52,
#    'low_tp_ncts': []},
#   'AND1': {'precision': 80.92016238159675,
#    'recall': 91.0891089108911,
#    'f1': 85.70404872805446,
#    'accuracy': 91.0891089108911,
#    'total_label': 1313,
#    'total_model': 1402,
#    'correct_count': 1196,
#    'low_tp_ncts': ['NCT03924479_inc']},
#   'OR': {'precision': 81.43274853801171,
#    'recall': 73.38603425559947,
#    'f1': 77.20027720027721,
#    'accuracy': 73.38603425559947,
#    'total_label': 759,
#    'total_model': 685,
#    'correct_count': 557,
#    'low_tp_ncts': []},
#   'NOT': {'precision': 67.85714285714286,
#    'recall': 46.62576687116564,
#    'f1': 55.27272727272727,
#    'accuracy': 46.62576687116564,
#    'total_label': 163,
#    'total_model': 110,
#    'correct_count': 76,
#    'low_tp_ncts': ['NCT03924479_inc']},
#   'average_missing_percentage': 0.8508650189674197,
#   'average': {'precision': 58.47646511440816,
#    'recall': 62.476720046727486,
#    'f1': 56.23147939371055,
#    'accuracy': 62.476720046727486}}}

# %%
plot_avg_metrics(all_metrics)

# %%
models
# Out:
# ['Llama3_70b_Fine-Tuned_p4_ep10_p1']

# %%
def plot_operator_metrics(all_metrics):
    operators = ['AND', 'OR', 'NOT']
    metrics_to_plot = ['precision', 'recall', 'f1']
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c']  # Farben für Precision, Recall, F1

    sota_metrics = {
        'SciBERT': {
            'AND': {'precision': 54.1, 'recall': 60.0, 'f1': 56.9},
            'NOT': {'precision': 74.3, 'recall': 91.0, 'f1': 81.8},
            'OR': {'precision': 85.1, 'recall': 93.2, 'f1': 89.0}
        }
    }

    for i, op in enumerate(operators):
        plt.figure(figsize=(12, 8))  # Größere Figur
        

        model_names = ['SOTA'] + [e.replace('_p4_ep10_p1', '') for e in  list(all_metrics.keys())]
        metric_values = {metric: [] for metric in metrics_to_plot}

        # SOTA-Metriken hinzufügen
        for metric in metrics_to_plot:
            metric_values[metric].append(sota_metrics['SciBERT'][op][metric])

        # Andere Modellmetriken hinzufügen
        for model, model_metrics in all_metrics.items():
            for metric in metrics_to_plot:
                metric_values[metric].append(model_metrics[op][metric])

        x = np.arange(len(model_names))
        bar_width = 0.25
        opacity = 0.8

        for j, metric in enumerate(metrics_to_plot):
            plt.bar(x + j * bar_width, metric_values[metric], bar_width,
                    alpha=opacity, label=metric.capitalize(), color=colors[j])

        plt.xlabel('Models', fontsize=14, labelpad=10)
        plt.ylabel('Score (%)', fontsize=14, labelpad=10)
        plt.title(f'Evaluation: {op}', fontsize=18, pad=20)  # Mehr Abstand nach dem Titel
        plt.xticks(x + bar_width, model_names, rotation=45, ha='right', fontsize=12)
        plt.ylim(0, 110)  # Erhöhung des y-Limits für mehr Platz oben
        plt.legend(fontsize=12, loc='upper center', ncol=3)  # Legende unter dem Plot
        plt.grid(axis='y', linestyle='--', alpha=0.7)

        # Werte über den Balken anzeigen
        for j, metric in enumerate(metrics_to_plot):
            for k, v in enumerate(metric_values[metric]):
                plt.text(k + j * bar_width, v + 2, f'{v:.1f}%',
                         ha='center', va='bottom', fontsize=10)

        plt.tight_layout()
        plt.savefig(f'pics/operator_metrics_{op}.png', bbox_inches='tight')
        plt.show()

# %%
plot_operator_metrics(all_metrics)
