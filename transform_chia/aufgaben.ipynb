# %%
import os
import shutil
import re
from functions import *

# %%
def copy_txt_files(source_dir, dest_dir):
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)
    # Durchlaufen aller Dateien im Quellverzeichnis
    for filename in os.listdir(source_dir):
        print(filename)
        if filename.endswith('.txt'):
            # Vollständigen Pfad der Quelldatei erstellen
            source_file = os.path.join(source_dir, filename)
            # Vollständigen Pfad der Zieldatei erstellen
            dest_file = os.path.join(dest_dir, filename)
            # Datei kopieren
            shutil.copy(source_file, dest_file)
            print(f'Kopiert: {source_file} -> {dest_file}')

# %%
source_directory = 'input/ann_text'  # Verzeichnis mit den hochgeladenen Dateien
destination_directory = 'input/half_clinical_trials/'  # Zielverzeichnis

copy_txt_files(source_directory, destination_directory)
# Out:
# NCT00050349_exc.ann
# NCT00050349_exc.txt
# Kopiert: input/ann_text\NCT00050349_exc.txt -> input/half_clinical_trials/NCT00050349_exc.txt
# NCT00050349_inc.ann
# NCT00050349_inc.txt
# Kopiert: input/ann_text\NCT00050349_inc.txt -> input/half_clinical_trials/NCT00050349_inc.txt
# NCT00061308_exc.ann
# NCT00061308_exc.txt
# Kopiert: input/ann_text\NCT00061308_exc.txt -> input/half_clinical_trials/NCT00061308_exc.txt
# NCT00061308_inc.ann
# NCT00061308_inc.txt
# Kopiert: input/ann_text\NCT00061308_inc.txt -> input/half_clinical_trials/NCT00061308_inc.txt
# NCT00094861_exc.ann
# NCT00094861_exc.txt
# Kopiert: input/ann_text\NCT00094861_exc.txt -> input/half_clinical_trials/NCT00094861_exc.txt
# NCT00094861_inc.ann
# NCT00094861_inc.txt
# Kopiert: input/ann_text\NCT00094861_inc.txt -> input/half_clinical_trials/NCT00094861_inc.txt
# NCT00122070_exc.ann
# NCT00122070_exc.txt
# Kopiert: input/ann_text\NCT00122070_exc.txt -> input/half_clinical_trials/NCT00122070_exc.txt
# NCT00122070_inc.ann
# NCT00122070_inc.txt
# Kopiert: input/ann_text\NCT00122070_inc.txt -> input/half_clinical_trials/NCT00122070_inc.txt
# NCT00182520_exc.ann
# NCT00182520_exc.txt
# Kopiert: input/ann_text\NCT00182520_exc.txt -> input/half_clinical_trials/NCT00182520_exc.txt
# NCT00182520_inc.ann
# NCT00182520_inc.txt
# Kopiert: input/ann_text\NCT00182520_inc.txt -> input/half_clinical_trials/NCT00182520_inc.txt
# NCT00183885_exc.ann
# NCT00183885_exc.txt
# Kopiert: input/ann_text\NCT00183885_exc.txt -> input/half_clinical_trials/NCT00183885_exc.txt
# NCT00183885_inc.ann
# NCT00183885_inc.txt
# Kopiert: input/ann_text\NCT00183885_inc.txt -> input/half_clinical_trials/NCT00183885_inc.txt
# NCT00198913_exc.ann
# NCT00198913_exc.txt
# Kopiert: input/ann_text\NCT00198913_exc.txt -> input/half_clinical_trials/NCT00198913_exc.txt
# NCT00198913_inc.ann
# NCT00198913_inc.txt
# Kopiert: input/ann_text\NCT00198913_inc.txt -> input/half_clinical_trials/NCT00198913_inc.txt
# NCT00235170_exc.ann
# NCT00235170_exc.txt
# Kopiert: input/ann_text\NCT00235170_exc.txt -> input/half_clinical_trials/NCT00235170_exc.txt
# NCT00235170_inc.ann
# NCT00235170_inc.txt
# Kopiert: input/ann_text\NCT00235170_inc.txt -> input/half_clinical_trials/NCT00235170_inc.txt
# NCT00236340_exc.ann
# NCT00236340_exc.txt
# Kopiert: input/ann_text\NCT00236340_exc.txt -> input/half_clinical_trials/NCT00236340_exc.txt
# NCT00236340_inc.ann
# NCT00236340_inc.txt
# Kopiert: input/ann_text\NCT00236340_inc.txt -> input/half_clinical_trials/NCT00236340_inc.txt
# NCT00250640_exc.ann
# NCT00250640_exc.txt
# Kopiert: input/ann_text\NCT00250640_exc.txt -> input/half_clinical_trials/NCT00250640_exc.txt
# NCT00250640_inc.ann
# NCT00250640_inc.txt
# Kopiert: input/ann_text\NCT00250640_inc.txt -> input/half_clinical_trials/NCT00250640_inc.txt
# NCT00279552_exc.ann
# NCT00279552_exc.txt
# Kopiert: input/ann_text\NCT00279552_exc.txt -> input/half_clinical_trials/NCT00279552_exc.txt
# NCT00279552_inc.ann
# NCT00279552_inc.txt
# Kopiert: input/ann_text\NCT00279552_inc.txt -> input/half_clinical_trials/NCT00279552_inc.txt
# NCT00305097_exc.ann
# NCT00305097_exc.txt
# Kopiert: input/ann_text\NCT00305097_exc.txt -> input/half_clinical_trials/NCT00305097_exc.txt
# NCT00305097_inc.ann
# NCT00305097_inc.txt
# Kopiert: input/ann_text\NCT00305097_inc.txt -> input/half_clinical_trials/NCT00305097_inc.txt
# NCT00312429_exc.ann
# NCT00312429_exc.txt
# Kopiert: input/ann_text\NCT00312429_exc.txt -> input/half_clinical_trials/NCT00312429_exc.txt
# NCT00312429_inc.ann
# NCT00312429_inc.txt
# Kopiert: input/ann_text\NCT00312429_inc.txt -> input/half_clinical_trials/NCT00312429_inc.txt
# NCT00317148_exc.ann
# NCT00317148_exc.txt
# Kopiert: input/ann_text\NCT00317148_exc.txt -> input/half_clinical_trials/NCT00317148_exc.txt
# NCT00317148_inc.ann
# NCT00317148_inc.txt
# Kopiert: input/ann_text\NCT00317148_inc.txt -> input/half_clinical_trials/NCT00317148_inc.txt
# NCT00319748_exc.ann
# NCT00319748_exc.txt
# Kopiert: input/ann_text\NCT00319748_exc.txt -> input/half_clinical_trials/NCT00319748_exc.txt
# NCT00319748_inc.ann
# NCT00319748_inc.txt
# Kopiert: input/ann_text\NCT00319748_inc.txt -> input/half_clinical_trials/NCT00319748_inc.txt
# NCT00324363_exc.ann
# NCT00324363_exc.txt
# Kopiert: input/ann_text\NCT00324363_exc.txt -> input/half_clinical_trials/NCT00324363_exc.txt
# NCT00324363_inc.ann
# NCT00324363_inc.txt
# Kopiert: input/ann_text\NCT00324363_inc.txt -> input/half_clinical_trials/NCT00324363_inc.txt
# NCT00343668_exc.ann
# NCT00343668_exc.txt
# Kopiert: input/ann_text\NCT00343668_exc.txt -> input/half_clinical_trials/NCT00343668_exc.txt
# NCT00343668_inc.ann
# NCT00343668_inc.txt
# Kopiert: input/ann_text\NCT00343668_inc.txt -> input/half_clinical_trials/NCT00343668_inc.txt
# NCT00344318_exc.ann
# NCT00344318_exc.txt
# Kopiert: input/ann_text\NCT00344318_exc.txt -> input/half_clinical_trials/NCT00344318_exc.txt
# NCT00344318_inc.ann
# NCT00344318_inc.txt
# Kopiert: input/ann_text\NCT00344318_inc.txt -> input/half_clinical_trials/NCT00344318_inc.txt
# NCT00351611_exc.ann
# NCT00351611_exc.txt
# Kopiert: input/ann_text\NCT00351611_exc.txt -> input/half_clinical_trials/NCT00351611_exc.txt
# NCT00351611_inc.ann
# NCT00351611_inc.txt
# Kopiert: input/ann_text\NCT00351611_inc.txt -> input/half_clinical_trials/NCT00351611_inc.txt
# NCT00356148_exc.ann
# NCT00356148_exc.txt
# Kopiert: input/ann_text\NCT00356148_exc.txt -> input/half_clinical_trials/NCT00356148_exc.txt
# NCT00356148_inc.ann
# NCT00356148_inc.txt
# Kopiert: input/ann_text\NCT00356148_inc.txt -> input/half_clinical_trials/NCT00356148_inc.txt
# NCT00379366_exc.ann
# NCT00379366_exc.txt
# Kopiert: input/ann_text\NCT00379366_exc.txt -> input/half_clinical_trials/NCT00379366_exc.txt
# NCT00379366_inc.ann
# NCT00379366_inc.txt
# Kopiert: input/ann_text\NCT00379366_inc.txt -> input/half_clinical_trials/NCT00379366_inc.txt
# NCT00391690_exc.ann
# NCT00391690_exc.txt
# Kopiert: input/ann_text\NCT00391690_exc.txt -> input/half_clinical_trials/NCT00391690_exc.txt
# NCT00391690_inc.ann
# NCT00391690_inc.txt
# Kopiert: input/ann_text\NCT00391690_inc.txt -> input/half_clinical_trials/NCT00391690_inc.txt
# NCT00396734_exc.ann
# NCT00396734_exc.txt
# Kopiert: input/ann_text\NCT00396734_exc.txt -> input/half_clinical_trials/NCT00396734_exc.txt
# NCT00396734_inc.ann
# NCT00396734_inc.txt
# Kopiert: input/ann_text\NCT00396734_inc.txt -> input/half_clinical_trials/NCT00396734_inc.txt
# NCT00397215_exc.ann
# NCT00397215_exc.txt
# Kopiert: input/ann_text\NCT00397215_exc.txt -> input/half_clinical_trials/NCT00397215_exc.txt
# NCT00397215_inc.ann
# NCT00397215_inc.txt
# Kopiert: input/ann_text\NCT00397215_inc.txt -> input/half_clinical_trials/NCT00397215_inc.txt
# NCT00401245_exc.ann
# NCT00401245_exc.txt
# Kopiert: input/ann_text\NCT00401245_exc.txt -> input/half_clinical_trials/NCT00401245_exc.txt
# NCT00401245_inc.ann
# NCT00401245_inc.txt
# Kopiert: input/ann_text\NCT00401245_inc.txt -> input/half_clinical_trials/NCT00401245_inc.txt
# NCT00404495_exc.ann
# NCT00404495_exc.txt
# Kopiert: input/ann_text\NCT00404495_exc.txt -> input/half_clinical_trials/NCT00404495_exc.txt
# NCT00404495_inc.ann
# NCT00404495_inc.txt
# Kopiert: input/ann_text\NCT00404495_inc.txt -> input/half_clinical_trials/NCT00404495_inc.txt
# NCT00425789_exc.ann
# NCT00425789_exc.txt
# Kopiert: input/ann_text\NCT00425789_exc.txt -> input/half_clinical_trials/NCT00425789_exc.txt
# NCT00425789_inc.ann
# NCT00425789_inc.txt
# Kopiert: input/ann_text\NCT00425789_inc.txt -> input/half_clinical_trials/NCT00425789_inc.txt
# NCT00426751_exc.ann
# NCT00426751_exc.txt
# Kopiert: input/ann_text\NCT00426751_exc.txt -> input/half_clinical_trials/NCT00426751_exc.txt
# NCT00426751_inc.ann
# NCT00426751_inc.txt
# Kopiert: input/ann_text\NCT00426751_inc.txt -> input/half_clinical_trials/NCT00426751_inc.txt
# NCT00440245_exc.ann
# NCT00440245_exc.txt
# Kopiert: input/ann_text\NCT00440245_exc.txt -> input/half_clinical_trials/NCT00440245_exc.txt
# NCT00440245_inc.ann
# NCT00440245_inc.txt
# Kopiert: input/ann_text\NCT00440245_inc.txt -> input/half_clinical_trials/NCT00440245_inc.txt
# NCT00445029_exc.ann
# NCT00445029_exc.txt
# Kopiert: input/ann_text\NCT00445029_exc.txt -> input/half_clinical_trials/NCT00445029_exc.txt
# NCT00445029_inc.ann
# NCT00445029_inc.txt
# Kopiert: input/ann_text\NCT00445029_inc.txt -> input/half_clinical_trials/NCT00445029_inc.txt
# NCT00455663_exc.ann
# NCT00455663_exc.txt
# Kopiert: input/ann_text\NCT00455663_exc.txt -> input/half_clinical_trials/NCT00455663_exc.txt
# NCT00455663_inc.ann
# NCT00455663_inc.txt
# Kopiert: input/ann_text\NCT00455663_inc.txt -> input/half_clinical_trials/NCT00455663_inc.txt
# NCT00461136_exc.ann
# NCT00461136_exc.txt
# Kopiert: input/ann_text\NCT00461136_exc.txt -> input/half_clinical_trials/NCT00461136_exc.txt
# NCT00461136_inc.ann
# NCT00461136_inc.txt
# Kopiert: input/ann_text\NCT00461136_inc.txt -> input/half_clinical_trials/NCT00461136_inc.txt
# NCT00480129_exc.ann
# NCT00480129_exc.txt
# Kopiert: input/ann_text\NCT00480129_exc.txt -> input/half_clinical_trials/NCT00480129_exc.txt
# NCT00480129_inc.ann
# NCT00480129_inc.txt
# Kopiert: input/ann_text\NCT00480129_inc.txt -> input/half_clinical_trials/NCT00480129_inc.txt
# NCT00483106_exc.ann
# NCT00483106_exc.txt
# Kopiert: input/ann_text\NCT00483106_exc.txt -> input/half_clinical_trials/NCT00483106_exc.txt
# NCT00483106_inc.ann
# NCT00483106_inc.txt
# Kopiert: input/ann_text\NCT00483106_inc.txt -> input/half_clinical_trials/NCT00483106_inc.txt
# NCT00500500_exc.ann
# NCT00500500_exc.txt
# Kopiert: input/ann_text\NCT00500500_exc.txt -> input/half_clinical_trials/NCT00500500_exc.txt
# NCT00500500_inc.ann
# NCT00500500_inc.txt
# Kopiert: input/ann_text\NCT00500500_inc.txt -> input/half_clinical_trials/NCT00500500_inc.txt
# NCT00502567_exc.ann
# NCT00502567_exc.txt
# Kopiert: input/ann_text\NCT00502567_exc.txt -> input/half_clinical_trials/NCT00502567_exc.txt
# NCT00502567_inc.ann
# NCT00502567_inc.txt
# Kopiert: input/ann_text\NCT00502567_inc.txt -> input/half_clinical_trials/NCT00502567_inc.txt
# NCT00527826_exc.ann
# NCT00527826_exc.txt
# Kopiert: input/ann_text\NCT00527826_exc.txt -> input/half_clinical_trials/NCT00527826_exc.txt
# NCT00527826_inc.ann
# NCT00527826_inc.txt
# Kopiert: input/ann_text\NCT00527826_inc.txt -> input/half_clinical_trials/NCT00527826_inc.txt
# NCT00543712_exc.ann
# NCT00543712_exc.txt
# Kopiert: input/ann_text\NCT00543712_exc.txt -> input/half_clinical_trials/NCT00543712_exc.txt
# NCT00543712_inc.ann
# NCT00543712_inc.txt
# Kopiert: input/ann_text\NCT00543712_inc.txt -> input/half_clinical_trials/NCT00543712_inc.txt
# NCT00576173_exc.ann
# NCT00576173_exc.txt
# Kopiert: input/ann_text\NCT00576173_exc.txt -> input/half_clinical_trials/NCT00576173_exc.txt
# NCT00576173_inc.ann
# NCT00576173_inc.txt
# Kopiert: input/ann_text\NCT00576173_inc.txt -> input/half_clinical_trials/NCT00576173_inc.txt
# NCT00586898_exc.ann
# NCT00586898_exc.txt
# Kopiert: input/ann_text\NCT00586898_exc.txt -> input/half_clinical_trials/NCT00586898_exc.txt
# NCT00586898_inc.ann
# NCT00586898_inc.txt
# Kopiert: input/ann_text\NCT00586898_inc.txt -> input/half_clinical_trials/NCT00586898_inc.txt
# NCT00599924_exc.ann
# NCT00599924_exc.txt
# Kopiert: input/ann_text\NCT00599924_exc.txt -> input/half_clinical_trials/NCT00599924_exc.txt
# NCT00599924_inc.ann
# NCT00599924_inc.txt
# Kopiert: input/ann_text\NCT00599924_inc.txt -> input/half_clinical_trials/NCT00599924_inc.txt
# NCT00609531_exc.ann
# NCT00609531_exc.txt
# Kopiert: input/ann_text\NCT00609531_exc.txt -> input/half_clinical_trials/NCT00609531_exc.txt
# NCT00609531_inc.ann
# NCT00609531_inc.txt
# Kopiert: input/ann_text\NCT00609531_inc.txt -> input/half_clinical_trials/NCT00609531_inc.txt
# NCT00625742_exc.ann
# NCT00625742_exc.txt
# Kopiert: input/ann_text\NCT00625742_exc.txt -> input/half_clinical_trials/NCT00625742_exc.txt
# NCT00625742_inc.ann
# NCT00625742_inc.txt
# Kopiert: input/ann_text\NCT00625742_inc.txt -> input/half_clinical_trials/NCT00625742_inc.txt
# NCT00639795_exc.ann
# NCT00639795_exc.txt
# Kopiert: input/ann_text\NCT00639795_exc.txt -> input/half_clinical_trials/NCT00639795_exc.txt
# NCT00639795_inc.ann
# NCT00639795_inc.txt
# Kopiert: input/ann_text\NCT00639795_inc.txt -> input/half_clinical_trials/NCT00639795_inc.txt
# NCT00650312_exc.ann
# NCT00650312_exc.txt
# Kopiert: input/ann_text\NCT00650312_exc.txt -> input/half_clinical_trials/NCT00650312_exc.txt
# NCT00650312_inc.ann
# NCT00650312_inc.txt
# Kopiert: input/ann_text\NCT00650312_inc.txt -> input/half_clinical_trials/NCT00650312_inc.txt
# NCT00676273_exc.ann
# NCT00676273_exc.txt
# Kopiert: input/ann_text\NCT00676273_exc.txt -> input/half_clinical_trials/NCT00676273_exc.txt
# NCT00676273_inc.ann
# NCT00676273_inc.txt
# Kopiert: input/ann_text\NCT00676273_inc.txt -> input/half_clinical_trials/NCT00676273_inc.txt
# NCT00679341_exc.ann
# NCT00679341_exc.txt
# Kopiert: input/ann_text\NCT00679341_exc.txt -> input/half_clinical_trials/NCT00679341_exc.txt
# NCT00679341_inc.ann
# NCT00679341_inc.txt
# Kopiert: input/ann_text\NCT00679341_inc.txt -> input/half_clinical_trials/NCT00679341_inc.txt
# NCT00718952_exc.ann
# NCT00718952_exc.txt
# Kopiert: input/ann_text\NCT00718952_exc.txt -> input/half_clinical_trials/NCT00718952_exc.txt
# NCT00718952_inc.ann
# NCT00718952_inc.txt
# Kopiert: input/ann_text\NCT00718952_inc.txt -> input/half_clinical_trials/NCT00718952_inc.txt
# NCT00720031_exc.ann
# NCT00720031_exc.txt
# Kopiert: input/ann_text\NCT00720031_exc.txt -> input/half_clinical_trials/NCT00720031_exc.txt
# NCT00720031_inc.ann
# NCT00720031_inc.txt
# Kopiert: input/ann_text\NCT00720031_inc.txt -> input/half_clinical_trials/NCT00720031_inc.txt
# NCT00728156_exc.ann
# NCT00728156_exc.txt
# Kopiert: input/ann_text\NCT00728156_exc.txt -> input/half_clinical_trials/NCT00728156_exc.txt
# NCT00728156_inc.ann
# NCT00728156_inc.txt
# Kopiert: input/ann_text\NCT00728156_inc.txt -> input/half_clinical_trials/NCT00728156_inc.txt
# NCT00730301_exc.ann
# NCT00730301_exc.txt
# Kopiert: input/ann_text\NCT00730301_exc.txt -> input/half_clinical_trials/NCT00730301_exc.txt
# NCT00730301_inc.ann
# NCT00730301_inc.txt
# Kopiert: input/ann_text\NCT00730301_inc.txt -> input/half_clinical_trials/NCT00730301_inc.txt
# NCT00749112_exc.ann
# NCT00749112_exc.txt
# Kopiert: input/ann_text\NCT00749112_exc.txt -> input/half_clinical_trials/NCT00749112_exc.txt
# NCT00749112_inc.ann
# NCT00749112_inc.txt
# Kopiert: input/ann_text\NCT00749112_inc.txt -> input/half_clinical_trials/NCT00749112_inc.txt
# NCT00752310_exc.ann
# NCT00752310_exc.txt
# Kopiert: input/ann_text\NCT00752310_exc.txt -> input/half_clinical_trials/NCT00752310_exc.txt
# NCT00752310_inc.ann
# NCT00752310_inc.txt
# Kopiert: input/ann_text\NCT00752310_inc.txt -> input/half_clinical_trials/NCT00752310_inc.txt
# NCT00785213_exc.ann
# NCT00785213_exc.txt
# Kopiert: input/ann_text\NCT00785213_exc.txt -> input/half_clinical_trials/NCT00785213_exc.txt
# NCT00785213_inc.ann
# NCT00785213_inc.txt
# Kopiert: input/ann_text\NCT00785213_inc.txt -> input/half_clinical_trials/NCT00785213_inc.txt
# NCT00787254_exc.ann
# NCT00787254_exc.txt
# Kopiert: input/ann_text\NCT00787254_exc.txt -> input/half_clinical_trials/NCT00787254_exc.txt
# NCT00787254_inc.ann
# NCT00787254_inc.txt
# Kopiert: input/ann_text\NCT00787254_inc.txt -> input/half_clinical_trials/NCT00787254_inc.txt
# NCT00806273_exc.ann
# NCT00806273_exc.txt
# Kopiert: input/ann_text\NCT00806273_exc.txt -> input/half_clinical_trials/NCT00806273_exc.txt
# NCT00806273_inc.ann
# NCT00806273_inc.txt
# Kopiert: input/ann_text\NCT00806273_inc.txt -> input/half_clinical_trials/NCT00806273_inc.txt
# NCT00806936_exc.ann
# NCT00806936_exc.txt
# Kopiert: input/ann_text\NCT00806936_exc.txt -> input/half_clinical_trials/NCT00806936_exc.txt
# NCT00806936_inc.ann
# NCT00806936_inc.txt
# Kopiert: input/ann_text\NCT00806936_inc.txt -> input/half_clinical_trials/NCT00806936_inc.txt
# NCT00812344_exc.ann
# NCT00812344_exc.txt
# Kopiert: input/ann_text\NCT00812344_exc.txt -> input/half_clinical_trials/NCT00812344_exc.txt
# NCT00812344_inc.ann
# NCT00812344_inc.txt
# Kopiert: input/ann_text\NCT00812344_inc.txt -> input/half_clinical_trials/NCT00812344_inc.txt
# NCT00846703_exc.ann
# NCT00846703_exc.txt
# Kopiert: input/ann_text\NCT00846703_exc.txt -> input/half_clinical_trials/NCT00846703_exc.txt
# NCT00846703_inc.ann
# NCT00846703_inc.txt
# Kopiert: input/ann_text\NCT00846703_inc.txt -> input/half_clinical_trials/NCT00846703_inc.txt
# NCT00862446_exc.ann
# NCT00862446_exc.txt
# Kopiert: input/ann_text\NCT00862446_exc.txt -> input/half_clinical_trials/NCT00862446_exc.txt
# NCT00862446_inc.ann
# NCT00862446_inc.txt
# Kopiert: input/ann_text\NCT00862446_inc.txt -> input/half_clinical_trials/NCT00862446_inc.txt
# NCT00867958_exc.ann
# NCT00867958_exc.txt
# Kopiert: input/ann_text\NCT00867958_exc.txt -> input/half_clinical_trials/NCT00867958_exc.txt
# NCT00867958_inc.ann
# NCT00867958_inc.txt
# Kopiert: input/ann_text\NCT00867958_inc.txt -> input/half_clinical_trials/NCT00867958_inc.txt
# NCT00886158_exc.ann
# NCT00886158_exc.txt
# Kopiert: input/ann_text\NCT00886158_exc.txt -> input/half_clinical_trials/NCT00886158_exc.txt
# NCT00886158_inc.ann
# NCT00886158_inc.txt
# Kopiert: input/ann_text\NCT00886158_inc.txt -> input/half_clinical_trials/NCT00886158_inc.txt
# NCT00894712_exc.ann
# NCT00894712_exc.txt
# Kopiert: input/ann_text\NCT00894712_exc.txt -> input/half_clinical_trials/NCT00894712_exc.txt
# NCT00894712_inc.ann
# NCT00894712_inc.txt
# Kopiert: input/ann_text\NCT00894712_inc.txt -> input/half_clinical_trials/NCT00894712_inc.txt
# NCT00904202_exc.ann
# NCT00904202_exc.txt
# Kopiert: input/ann_text\NCT00904202_exc.txt -> input/half_clinical_trials/NCT00904202_exc.txt
# NCT00904202_inc.ann
# NCT00904202_inc.txt
# Kopiert: input/ann_text\NCT00904202_inc.txt -> input/half_clinical_trials/NCT00904202_inc.txt
# NCT00917891_exc.ann
# NCT00917891_exc.txt
# Kopiert: input/ann_text\NCT00917891_exc.txt -> input/half_clinical_trials/NCT00917891_exc.txt
# NCT00917891_inc.ann
# NCT00917891_inc.txt
# Kopiert: input/ann_text\NCT00917891_inc.txt -> input/half_clinical_trials/NCT00917891_inc.txt
# NCT00926523_exc.ann
# NCT00926523_exc.txt
# Kopiert: input/ann_text\NCT00926523_exc.txt -> input/half_clinical_trials/NCT00926523_exc.txt
# NCT00926523_inc.ann
# NCT00926523_inc.txt
# Kopiert: input/ann_text\NCT00926523_inc.txt -> input/half_clinical_trials/NCT00926523_inc.txt
# NCT00931983_exc.ann
# NCT00931983_exc.txt
# Kopiert: input/ann_text\NCT00931983_exc.txt -> input/half_clinical_trials/NCT00931983_exc.txt
# NCT00931983_inc.ann
# NCT00931983_inc.txt
# Kopiert: input/ann_text\NCT00931983_inc.txt -> input/half_clinical_trials/NCT00931983_inc.txt
# NCT00943865_exc.ann
# NCT00943865_exc.txt
# Kopiert: input/ann_text\NCT00943865_exc.txt -> input/half_clinical_trials/NCT00943865_exc.txt
# NCT00943865_inc.ann
# NCT00943865_inc.txt
# Kopiert: input/ann_text\NCT00943865_inc.txt -> input/half_clinical_trials/NCT00943865_inc.txt
# NCT00954850_exc.ann
# NCT00954850_exc.txt
# Kopiert: input/ann_text\NCT00954850_exc.txt -> input/half_clinical_trials/NCT00954850_exc.txt
# NCT00954850_inc.ann
# NCT00954850_inc.txt
# Kopiert: input/ann_text\NCT00954850_inc.txt -> input/half_clinical_trials/NCT00954850_inc.txt
# NCT00959569_exc.ann
# NCT00959569_exc.txt
# Kopiert: input/ann_text\NCT00959569_exc.txt -> input/half_clinical_trials/NCT00959569_exc.txt
# NCT00959569_inc.ann
# NCT00959569_inc.txt
# Kopiert: input/ann_text\NCT00959569_inc.txt -> input/half_clinical_trials/NCT00959569_inc.txt
# NCT00962364_exc.ann
# NCT00962364_exc.txt
# Kopiert: input/ann_text\NCT00962364_exc.txt -> input/half_clinical_trials/NCT00962364_exc.txt
# NCT00962364_inc.ann
# NCT00962364_inc.txt
# Kopiert: input/ann_text\NCT00962364_inc.txt -> input/half_clinical_trials/NCT00962364_inc.txt
# NCT00965900_exc.ann
# NCT00965900_exc.txt
# Kopiert: input/ann_text\NCT00965900_exc.txt -> input/half_clinical_trials/NCT00965900_exc.txt
# NCT00965900_inc.ann
# NCT00965900_inc.txt
# Kopiert: input/ann_text\NCT00965900_inc.txt -> input/half_clinical_trials/NCT00965900_inc.txt
# NCT00970866_exc.ann
# NCT00970866_exc.txt
# Kopiert: input/ann_text\NCT00970866_exc.txt -> input/half_clinical_trials/NCT00970866_exc.txt
# NCT00970866_inc.ann
# NCT00970866_inc.txt
# Kopiert: input/ann_text\NCT00970866_inc.txt -> input/half_clinical_trials/NCT00970866_inc.txt
# NCT00989261_exc.ann
# NCT00989261_exc.txt
# Kopiert: input/ann_text\NCT00989261_exc.txt -> input/half_clinical_trials/NCT00989261_exc.txt
# NCT00989261_inc.ann
# NCT00989261_inc.txt
# Kopiert: input/ann_text\NCT00989261_inc.txt -> input/half_clinical_trials/NCT00989261_inc.txt
# NCT00994786_exc.ann
# NCT00994786_exc.txt
# Kopiert: input/ann_text\NCT00994786_exc.txt -> input/half_clinical_trials/NCT00994786_exc.txt
# NCT00994786_inc.ann
# NCT00994786_inc.txt
# Kopiert: input/ann_text\NCT00994786_inc.txt -> input/half_clinical_trials/NCT00994786_inc.txt
# NCT01000155_exc.ann
# NCT01000155_exc.txt
# Kopiert: input/ann_text\NCT01000155_exc.txt -> input/half_clinical_trials/NCT01000155_exc.txt
# NCT01000155_inc.ann
# NCT01000155_inc.txt
# Kopiert: input/ann_text\NCT01000155_inc.txt -> input/half_clinical_trials/NCT01000155_inc.txt
# NCT01009359_exc.ann
# NCT01009359_exc.txt
# Kopiert: input/ann_text\NCT01009359_exc.txt -> input/half_clinical_trials/NCT01009359_exc.txt
# NCT01009359_inc.ann
# NCT01009359_inc.txt
# Kopiert: input/ann_text\NCT01009359_inc.txt -> input/half_clinical_trials/NCT01009359_inc.txt
# NCT01032109_exc.ann
# NCT01032109_exc.txt
# Kopiert: input/ann_text\NCT01032109_exc.txt -> input/half_clinical_trials/NCT01032109_exc.txt
# NCT01032109_inc.ann
# NCT01032109_inc.txt
# Kopiert: input/ann_text\NCT01032109_inc.txt -> input/half_clinical_trials/NCT01032109_inc.txt
# NCT01051414_exc.ann
# NCT01051414_exc.txt
# Kopiert: input/ann_text\NCT01051414_exc.txt -> input/half_clinical_trials/NCT01051414_exc.txt
# NCT01051414_inc.ann
# NCT01051414_inc.txt
# Kopiert: input/ann_text\NCT01051414_inc.txt -> input/half_clinical_trials/NCT01051414_inc.txt
# NCT01064752_exc.ann
# NCT01064752_exc.txt
# Kopiert: input/ann_text\NCT01064752_exc.txt -> input/half_clinical_trials/NCT01064752_exc.txt
# NCT01064752_inc.ann
# NCT01064752_inc.txt
# Kopiert: input/ann_text\NCT01064752_inc.txt -> input/half_clinical_trials/NCT01064752_inc.txt
# NCT01078051_exc.ann
# NCT01078051_exc.txt
# Kopiert: input/ann_text\NCT01078051_exc.txt -> input/half_clinical_trials/NCT01078051_exc.txt
# NCT01078051_inc.ann
# NCT01078051_inc.txt
# Kopiert: input/ann_text\NCT01078051_inc.txt -> input/half_clinical_trials/NCT01078051_inc.txt
# NCT01082549_exc.ann
# NCT01082549_exc.txt
# Kopiert: input/ann_text\NCT01082549_exc.txt -> input/half_clinical_trials/NCT01082549_exc.txt
# NCT01082549_inc.ann
# NCT01082549_inc.txt
# Kopiert: input/ann_text\NCT01082549_inc.txt -> input/half_clinical_trials/NCT01082549_inc.txt
# NCT01084993_exc.ann
# NCT01084993_exc.txt
# Kopiert: input/ann_text\NCT01084993_exc.txt -> input/half_clinical_trials/NCT01084993_exc.txt
# NCT01084993_inc.ann
# NCT01084993_inc.txt
# Kopiert: input/ann_text\NCT01084993_inc.txt -> input/half_clinical_trials/NCT01084993_inc.txt
# NCT01088750_exc.ann
# NCT01088750_exc.txt
# Kopiert: input/ann_text\NCT01088750_exc.txt -> input/half_clinical_trials/NCT01088750_exc.txt
# NCT01088750_inc.ann
# NCT01088750_inc.txt
# Kopiert: input/ann_text\NCT01088750_inc.txt -> input/half_clinical_trials/NCT01088750_inc.txt
# NCT01098383_exc.ann
# NCT01098383_exc.txt
# Kopiert: input/ann_text\NCT01098383_exc.txt -> input/half_clinical_trials/NCT01098383_exc.txt
# NCT01098383_inc.ann
# NCT01098383_inc.txt
# Kopiert: input/ann_text\NCT01098383_inc.txt -> input/half_clinical_trials/NCT01098383_inc.txt
# NCT01116882_exc.ann
# NCT01116882_exc.txt
# Kopiert: input/ann_text\NCT01116882_exc.txt -> input/half_clinical_trials/NCT01116882_exc.txt
# NCT01116882_inc.ann
# NCT01116882_inc.txt
# Kopiert: input/ann_text\NCT01116882_inc.txt -> input/half_clinical_trials/NCT01116882_inc.txt
# NCT01116973_exc.ann
# NCT01116973_exc.txt
# Kopiert: input/ann_text\NCT01116973_exc.txt -> input/half_clinical_trials/NCT01116973_exc.txt
# NCT01116973_inc.ann
# NCT01116973_inc.txt
# Kopiert: input/ann_text\NCT01116973_inc.txt -> input/half_clinical_trials/NCT01116973_inc.txt
# NCT01117181_exc.ann
# NCT01117181_exc.txt
# Kopiert: input/ann_text\NCT01117181_exc.txt -> input/half_clinical_trials/NCT01117181_exc.txt
# NCT01117181_inc.ann
# NCT01117181_inc.txt
# Kopiert: input/ann_text\NCT01117181_inc.txt -> input/half_clinical_trials/NCT01117181_inc.txt
# NCT01118871_exc.ann
# NCT01118871_exc.txt
# Kopiert: input/ann_text\NCT01118871_exc.txt -> input/half_clinical_trials/NCT01118871_exc.txt
# NCT01118871_inc.ann
# NCT01118871_inc.txt
# Kopiert: input/ann_text\NCT01118871_inc.txt -> input/half_clinical_trials/NCT01118871_inc.txt
# NCT01175044_exc.ann
# NCT01175044_exc.txt
# Kopiert: input/ann_text\NCT01175044_exc.txt -> input/half_clinical_trials/NCT01175044_exc.txt
# NCT01175044_inc.ann
# NCT01175044_inc.txt
# Kopiert: input/ann_text\NCT01175044_inc.txt -> input/half_clinical_trials/NCT01175044_inc.txt
# NCT01177891_exc.ann
# NCT01177891_exc.txt
# Kopiert: input/ann_text\NCT01177891_exc.txt -> input/half_clinical_trials/NCT01177891_exc.txt
# NCT01177891_inc.ann
# NCT01177891_inc.txt
# Kopiert: input/ann_text\NCT01177891_inc.txt -> input/half_clinical_trials/NCT01177891_inc.txt
# NCT01184638_exc.ann
# NCT01184638_exc.txt
# Kopiert: input/ann_text\NCT01184638_exc.txt -> input/half_clinical_trials/NCT01184638_exc.txt
# NCT01184638_inc.ann
# NCT01184638_inc.txt
# Kopiert: input/ann_text\NCT01184638_inc.txt -> input/half_clinical_trials/NCT01184638_inc.txt
# NCT01205334_exc.ann
# NCT01205334_exc.txt
# Kopiert: input/ann_text\NCT01205334_exc.txt -> input/half_clinical_trials/NCT01205334_exc.txt
# NCT01205334_inc.ann
# NCT01205334_inc.txt
# Kopiert: input/ann_text\NCT01205334_inc.txt -> input/half_clinical_trials/NCT01205334_inc.txt
# NCT01214096_exc.ann
# NCT01214096_exc.txt
# Kopiert: input/ann_text\NCT01214096_exc.txt -> input/half_clinical_trials/NCT01214096_exc.txt
# NCT01214096_inc.ann
# NCT01214096_inc.txt
# Kopiert: input/ann_text\NCT01214096_inc.txt -> input/half_clinical_trials/NCT01214096_inc.txt
# NCT01217671_exc.ann
# NCT01217671_exc.txt
# Kopiert: input/ann_text\NCT01217671_exc.txt -> input/half_clinical_trials/NCT01217671_exc.txt
# NCT01217671_inc.ann
# NCT01217671_inc.txt
# Kopiert: input/ann_text\NCT01217671_inc.txt -> input/half_clinical_trials/NCT01217671_inc.txt
# NCT01218737_exc.ann
# NCT01218737_exc.txt
# Kopiert: input/ann_text\NCT01218737_exc.txt -> input/half_clinical_trials/NCT01218737_exc.txt
# NCT01218737_inc.ann
# NCT01218737_inc.txt
# Kopiert: input/ann_text\NCT01218737_inc.txt -> input/half_clinical_trials/NCT01218737_inc.txt
# NCT01228279_exc.ann
# NCT01228279_exc.txt
# Kopiert: input/ann_text\NCT01228279_exc.txt -> input/half_clinical_trials/NCT01228279_exc.txt
# NCT01228279_inc.ann
# NCT01228279_inc.txt
# Kopiert: input/ann_text\NCT01228279_inc.txt -> input/half_clinical_trials/NCT01228279_inc.txt
# NCT01236417_exc.ann
# NCT01236417_exc.txt
# Kopiert: input/ann_text\NCT01236417_exc.txt -> input/half_clinical_trials/NCT01236417_exc.txt
# NCT01236417_inc.ann
# NCT01236417_inc.txt
# Kopiert: input/ann_text\NCT01236417_inc.txt -> input/half_clinical_trials/NCT01236417_inc.txt
# NCT01261832_exc.ann
# NCT01261832_exc.txt
# Kopiert: input/ann_text\NCT01261832_exc.txt -> input/half_clinical_trials/NCT01261832_exc.txt
# NCT01261832_inc.ann
# NCT01261832_inc.txt
# Kopiert: input/ann_text\NCT01261832_inc.txt -> input/half_clinical_trials/NCT01261832_inc.txt
# NCT01312012_exc.ann
# NCT01312012_exc.txt
# Kopiert: input/ann_text\NCT01312012_exc.txt -> input/half_clinical_trials/NCT01312012_exc.txt
# NCT01312012_inc.ann
# NCT01312012_inc.txt
# Kopiert: input/ann_text\NCT01312012_inc.txt -> input/half_clinical_trials/NCT01312012_inc.txt
# NCT01313676_exc.ann
# NCT01313676_exc.txt
# Kopiert: input/ann_text\NCT01313676_exc.txt -> input/half_clinical_trials/NCT01313676_exc.txt
# NCT01313676_inc.ann
# NCT01313676_inc.txt
# Kopiert: input/ann_text\NCT01313676_inc.txt -> input/half_clinical_trials/NCT01313676_inc.txt
# NCT01314898_exc.ann
# NCT01314898_exc.txt
# Kopiert: input/ann_text\NCT01314898_exc.txt -> input/half_clinical_trials/NCT01314898_exc.txt
# NCT01314898_inc.ann
# NCT01314898_inc.txt
# Kopiert: input/ann_text\NCT01314898_inc.txt -> input/half_clinical_trials/NCT01314898_inc.txt
# NCT01320579_exc.ann
# NCT01320579_exc.txt
# Kopiert: input/ann_text\NCT01320579_exc.txt -> input/half_clinical_trials/NCT01320579_exc.txt
# NCT01320579_inc.ann
# NCT01320579_inc.txt
# Kopiert: input/ann_text\NCT01320579_inc.txt -> input/half_clinical_trials/NCT01320579_inc.txt
# NCT01322464_exc.ann
# NCT01322464_exc.txt
# Kopiert: input/ann_text\NCT01322464_exc.txt -> input/half_clinical_trials/NCT01322464_exc.txt
# NCT01322464_inc.ann
# NCT01322464_inc.txt
# Kopiert: input/ann_text\NCT01322464_inc.txt -> input/half_clinical_trials/NCT01322464_inc.txt
# NCT01346436_exc.ann
# NCT01346436_exc.txt
# Kopiert: input/ann_text\NCT01346436_exc.txt -> input/half_clinical_trials/NCT01346436_exc.txt
# NCT01346436_inc.ann
# NCT01346436_inc.txt
# Kopiert: input/ann_text\NCT01346436_inc.txt -> input/half_clinical_trials/NCT01346436_inc.txt
# NCT01349413_exc.ann
# NCT01349413_exc.txt
# Kopiert: input/ann_text\NCT01349413_exc.txt -> input/half_clinical_trials/NCT01349413_exc.txt
# NCT01349413_inc.ann
# NCT01349413_inc.txt
# Kopiert: input/ann_text\NCT01349413_inc.txt -> input/half_clinical_trials/NCT01349413_inc.txt
# NCT01352598_exc.ann
# NCT01352598_exc.txt
# Kopiert: input/ann_text\NCT01352598_exc.txt -> input/half_clinical_trials/NCT01352598_exc.txt
# NCT01352598_inc.ann
# NCT01352598_inc.txt
# Kopiert: input/ann_text\NCT01352598_inc.txt -> input/half_clinical_trials/NCT01352598_inc.txt
# NCT01373684_exc.ann
# NCT01373684_exc.txt
# Kopiert: input/ann_text\NCT01373684_exc.txt -> input/half_clinical_trials/NCT01373684_exc.txt
# NCT01373684_inc.ann
# NCT01373684_inc.txt
# Kopiert: input/ann_text\NCT01373684_inc.txt -> input/half_clinical_trials/NCT01373684_inc.txt
# NCT01391780_exc.ann
# NCT01391780_exc.txt
# Kopiert: input/ann_text\NCT01391780_exc.txt -> input/half_clinical_trials/NCT01391780_exc.txt
# NCT01391780_inc.ann
# NCT01391780_inc.txt
# Kopiert: input/ann_text\NCT01391780_inc.txt -> input/half_clinical_trials/NCT01391780_inc.txt
# NCT01401335_exc.ann
# NCT01401335_exc.txt
# Kopiert: input/ann_text\NCT01401335_exc.txt -> input/half_clinical_trials/NCT01401335_exc.txt
# NCT01401335_inc.ann
# NCT01401335_inc.txt
# Kopiert: input/ann_text\NCT01401335_inc.txt -> input/half_clinical_trials/NCT01401335_inc.txt
# NCT01410890_exc.ann
# NCT01410890_exc.txt
# Kopiert: input/ann_text\NCT01410890_exc.txt -> input/half_clinical_trials/NCT01410890_exc.txt
# NCT01410890_inc.ann
# NCT01410890_inc.txt
# Kopiert: input/ann_text\NCT01410890_inc.txt -> input/half_clinical_trials/NCT01410890_inc.txt
# NCT01424020_exc.ann
# NCT01424020_exc.txt
# Kopiert: input/ann_text\NCT01424020_exc.txt -> input/half_clinical_trials/NCT01424020_exc.txt
# NCT01424020_inc.ann
# NCT01424020_inc.txt
# Kopiert: input/ann_text\NCT01424020_inc.txt -> input/half_clinical_trials/NCT01424020_inc.txt
# NCT01440296_exc.ann
# NCT01440296_exc.txt
# Kopiert: input/ann_text\NCT01440296_exc.txt -> input/half_clinical_trials/NCT01440296_exc.txt
# NCT01440296_inc.ann
# NCT01440296_inc.txt
# Kopiert: input/ann_text\NCT01440296_inc.txt -> input/half_clinical_trials/NCT01440296_inc.txt
# NCT01446094_exc.ann
# NCT01446094_exc.txt
# Kopiert: input/ann_text\NCT01446094_exc.txt -> input/half_clinical_trials/NCT01446094_exc.txt
# NCT01446094_inc.ann
# NCT01446094_inc.txt
# Kopiert: input/ann_text\NCT01446094_inc.txt -> input/half_clinical_trials/NCT01446094_inc.txt
# NCT01483118_exc.ann
# NCT01483118_exc.txt
# Kopiert: input/ann_text\NCT01483118_exc.txt -> input/half_clinical_trials/NCT01483118_exc.txt
# NCT01483118_inc.ann
# NCT01483118_inc.txt
# Kopiert: input/ann_text\NCT01483118_inc.txt -> input/half_clinical_trials/NCT01483118_inc.txt
# NCT01490034_exc.ann
# NCT01490034_exc.txt
# Kopiert: input/ann_text\NCT01490034_exc.txt -> input/half_clinical_trials/NCT01490034_exc.txt
# NCT01490034_inc.ann
# NCT01490034_inc.txt
# Kopiert: input/ann_text\NCT01490034_inc.txt -> input/half_clinical_trials/NCT01490034_inc.txt
# NCT01491295_exc.ann
# NCT01491295_exc.txt
# Kopiert: input/ann_text\NCT01491295_exc.txt -> input/half_clinical_trials/NCT01491295_exc.txt
# NCT01491295_inc.ann
# NCT01491295_inc.txt
# Kopiert: input/ann_text\NCT01491295_inc.txt -> input/half_clinical_trials/NCT01491295_inc.txt
# NCT01491763_exc.ann
# NCT01491763_exc.txt
# Kopiert: input/ann_text\NCT01491763_exc.txt -> input/half_clinical_trials/NCT01491763_exc.txt
# NCT01491763_inc.ann
# NCT01491763_inc.txt
# Kopiert: input/ann_text\NCT01491763_inc.txt -> input/half_clinical_trials/NCT01491763_inc.txt
# NCT01497639_exc.ann
# NCT01497639_exc.txt
# Kopiert: input/ann_text\NCT01497639_exc.txt -> input/half_clinical_trials/NCT01497639_exc.txt
# NCT01497639_inc.ann
# NCT01497639_inc.txt
# Kopiert: input/ann_text\NCT01497639_inc.txt -> input/half_clinical_trials/NCT01497639_inc.txt
# NCT01501201_exc.ann
# NCT01501201_exc.txt
# Kopiert: input/ann_text\NCT01501201_exc.txt -> input/half_clinical_trials/NCT01501201_exc.txt
# NCT01501201_inc.ann
# NCT01501201_inc.txt
# Kopiert: input/ann_text\NCT01501201_inc.txt -> input/half_clinical_trials/NCT01501201_inc.txt
# NCT01518946_exc.ann
# NCT01518946_exc.txt
# Kopiert: input/ann_text\NCT01518946_exc.txt -> input/half_clinical_trials/NCT01518946_exc.txt
# NCT01518946_inc.ann
# NCT01518946_inc.txt
# Kopiert: input/ann_text\NCT01518946_inc.txt -> input/half_clinical_trials/NCT01518946_inc.txt
# NCT01531257_exc.ann
# NCT01531257_exc.txt
# Kopiert: input/ann_text\NCT01531257_exc.txt -> input/half_clinical_trials/NCT01531257_exc.txt
# NCT01531257_inc.ann
# NCT01531257_inc.txt
# Kopiert: input/ann_text\NCT01531257_inc.txt -> input/half_clinical_trials/NCT01531257_inc.txt
# NCT01567605_exc.ann
# NCT01567605_exc.txt
# Kopiert: input/ann_text\NCT01567605_exc.txt -> input/half_clinical_trials/NCT01567605_exc.txt
# NCT01567605_inc.ann
# NCT01567605_inc.txt
# Kopiert: input/ann_text\NCT01567605_inc.txt -> input/half_clinical_trials/NCT01567605_inc.txt
# NCT01579604_exc.ann
# NCT01579604_exc.txt
# Kopiert: input/ann_text\NCT01579604_exc.txt -> input/half_clinical_trials/NCT01579604_exc.txt
# NCT01579604_inc.ann
# NCT01579604_inc.txt
# Kopiert: input/ann_text\NCT01579604_inc.txt -> input/half_clinical_trials/NCT01579604_inc.txt
# NCT01581749_exc.ann
# NCT01581749_exc.txt
# Kopiert: input/ann_text\NCT01581749_exc.txt -> input/half_clinical_trials/NCT01581749_exc.txt
# NCT01581749_inc.ann
# NCT01581749_inc.txt
# Kopiert: input/ann_text\NCT01581749_inc.txt -> input/half_clinical_trials/NCT01581749_inc.txt
# NCT01602081_exc.ann
# NCT01602081_exc.txt
# Kopiert: input/ann_text\NCT01602081_exc.txt -> input/half_clinical_trials/NCT01602081_exc.txt
# NCT01602081_inc.ann
# NCT01602081_inc.txt
# Kopiert: input/ann_text\NCT01602081_inc.txt -> input/half_clinical_trials/NCT01602081_inc.txt
# NCT01604187_exc.ann
# NCT01604187_exc.txt
# Kopiert: input/ann_text\NCT01604187_exc.txt -> input/half_clinical_trials/NCT01604187_exc.txt
# NCT01604187_inc.ann
# NCT01604187_inc.txt
# Kopiert: input/ann_text\NCT01604187_inc.txt -> input/half_clinical_trials/NCT01604187_inc.txt
# NCT01614041_exc.ann
# NCT01614041_exc.txt
# Kopiert: input/ann_text\NCT01614041_exc.txt -> input/half_clinical_trials/NCT01614041_exc.txt
# NCT01614041_inc.ann
# NCT01614041_inc.txt
# Kopiert: input/ann_text\NCT01614041_inc.txt -> input/half_clinical_trials/NCT01614041_inc.txt
# NCT01630954_exc.ann
# NCT01630954_exc.txt
# Kopiert: input/ann_text\NCT01630954_exc.txt -> input/half_clinical_trials/NCT01630954_exc.txt
# NCT01630954_inc.ann
# NCT01630954_inc.txt
# Kopiert: input/ann_text\NCT01630954_inc.txt -> input/half_clinical_trials/NCT01630954_inc.txt
# NCT01631058_exc.ann
# NCT01631058_exc.txt
# Kopiert: input/ann_text\NCT01631058_exc.txt -> input/half_clinical_trials/NCT01631058_exc.txt
# NCT01631058_inc.ann
# NCT01631058_inc.txt
# Kopiert: input/ann_text\NCT01631058_inc.txt -> input/half_clinical_trials/NCT01631058_inc.txt
# NCT01639664_exc.ann
# NCT01639664_exc.txt
# Kopiert: input/ann_text\NCT01639664_exc.txt -> input/half_clinical_trials/NCT01639664_exc.txt
# NCT01639664_inc.ann
# NCT01639664_inc.txt
# Kopiert: input/ann_text\NCT01639664_inc.txt -> input/half_clinical_trials/NCT01639664_inc.txt
# NCT01642875_exc.ann
# NCT01642875_exc.txt
# Kopiert: input/ann_text\NCT01642875_exc.txt -> input/half_clinical_trials/NCT01642875_exc.txt
# NCT01642875_inc.ann
# NCT01642875_inc.txt
# Kopiert: input/ann_text\NCT01642875_inc.txt -> input/half_clinical_trials/NCT01642875_inc.txt
# NCT01650792_exc.ann
# NCT01650792_exc.txt
# Kopiert: input/ann_text\NCT01650792_exc.txt -> input/half_clinical_trials/NCT01650792_exc.txt
# NCT01650792_inc.ann
# NCT01650792_inc.txt
# Kopiert: input/ann_text\NCT01650792_inc.txt -> input/half_clinical_trials/NCT01650792_inc.txt
# NCT01664507_exc.ann
# NCT01664507_exc.txt
# Kopiert: input/ann_text\NCT01664507_exc.txt -> input/half_clinical_trials/NCT01664507_exc.txt
# NCT01664507_inc.ann
# NCT01664507_inc.txt
# Kopiert: input/ann_text\NCT01664507_inc.txt -> input/half_clinical_trials/NCT01664507_inc.txt
# NCT01665417_exc.ann
# NCT01665417_exc.txt
# Kopiert: input/ann_text\NCT01665417_exc.txt -> input/half_clinical_trials/NCT01665417_exc.txt
# NCT01665417_inc.ann
# NCT01665417_inc.txt
# Kopiert: input/ann_text\NCT01665417_inc.txt -> input/half_clinical_trials/NCT01665417_inc.txt
# NCT01669369_exc.ann
# NCT01669369_exc.txt
# Kopiert: input/ann_text\NCT01669369_exc.txt -> input/half_clinical_trials/NCT01669369_exc.txt
# NCT01669369_inc.ann
# NCT01669369_inc.txt
# Kopiert: input/ann_text\NCT01669369_inc.txt -> input/half_clinical_trials/NCT01669369_inc.txt
# NCT01680081_exc.ann
# NCT01680081_exc.txt
# Kopiert: input/ann_text\NCT01680081_exc.txt -> input/half_clinical_trials/NCT01680081_exc.txt
# NCT01680081_inc.ann
# NCT01680081_inc.txt
# Kopiert: input/ann_text\NCT01680081_inc.txt -> input/half_clinical_trials/NCT01680081_inc.txt
# NCT01684501_exc.ann
# NCT01684501_exc.txt
# Kopiert: input/ann_text\NCT01684501_exc.txt -> input/half_clinical_trials/NCT01684501_exc.txt
# NCT01684501_inc.ann
# NCT01684501_inc.txt
# Kopiert: input/ann_text\NCT01684501_inc.txt -> input/half_clinical_trials/NCT01684501_inc.txt
# NCT01696617_exc.ann
# NCT01696617_exc.txt
# Kopiert: input/ann_text\NCT01696617_exc.txt -> input/half_clinical_trials/NCT01696617_exc.txt
# NCT01696617_inc.ann
# NCT01696617_inc.txt
# Kopiert: input/ann_text\NCT01696617_inc.txt -> input/half_clinical_trials/NCT01696617_inc.txt
# NCT01700790_exc.ann
# NCT01700790_exc.txt
# Kopiert: input/ann_text\NCT01700790_exc.txt -> input/half_clinical_trials/NCT01700790_exc.txt
# NCT01700790_inc.ann
# NCT01700790_inc.txt
# Kopiert: input/ann_text\NCT01700790_inc.txt -> input/half_clinical_trials/NCT01700790_inc.txt
# NCT01701219_exc.ann
# NCT01701219_exc.txt
# Kopiert: input/ann_text\NCT01701219_exc.txt -> input/half_clinical_trials/NCT01701219_exc.txt
# NCT01701219_inc.ann
# NCT01701219_inc.txt
# Kopiert: input/ann_text\NCT01701219_inc.txt -> input/half_clinical_trials/NCT01701219_inc.txt
# NCT01709981_exc.ann
# NCT01709981_exc.txt
# Kopiert: input/ann_text\NCT01709981_exc.txt -> input/half_clinical_trials/NCT01709981_exc.txt
# NCT01709981_inc.ann
# NCT01709981_inc.txt
# Kopiert: input/ann_text\NCT01709981_inc.txt -> input/half_clinical_trials/NCT01709981_inc.txt
# NCT01711801_exc.ann
# NCT01711801_exc.txt
# Kopiert: input/ann_text\NCT01711801_exc.txt -> input/half_clinical_trials/NCT01711801_exc.txt
# NCT01711801_inc.ann
# NCT01711801_inc.txt
# Kopiert: input/ann_text\NCT01711801_inc.txt -> input/half_clinical_trials/NCT01711801_inc.txt
# NCT01715584_exc.ann
# NCT01715584_exc.txt
# Kopiert: input/ann_text\NCT01715584_exc.txt -> input/half_clinical_trials/NCT01715584_exc.txt
# NCT01715584_inc.ann
# NCT01715584_inc.txt
# Kopiert: input/ann_text\NCT01715584_inc.txt -> input/half_clinical_trials/NCT01715584_inc.txt
# NCT01715714_exc.ann
# NCT01715714_exc.txt
# Kopiert: input/ann_text\NCT01715714_exc.txt -> input/half_clinical_trials/NCT01715714_exc.txt
# NCT01715714_inc.ann
# NCT01715714_inc.txt
# Kopiert: input/ann_text\NCT01715714_inc.txt -> input/half_clinical_trials/NCT01715714_inc.txt
# NCT01717911_exc.ann
# NCT01717911_exc.txt
# Kopiert: input/ann_text\NCT01717911_exc.txt -> input/half_clinical_trials/NCT01717911_exc.txt
# NCT01717911_inc.ann
# NCT01717911_inc.txt
# Kopiert: input/ann_text\NCT01717911_inc.txt -> input/half_clinical_trials/NCT01717911_inc.txt
# NCT01720394_exc.ann
# NCT01720394_exc.txt
# Kopiert: input/ann_text\NCT01720394_exc.txt -> input/half_clinical_trials/NCT01720394_exc.txt
# NCT01720394_inc.ann
# NCT01720394_inc.txt
# Kopiert: input/ann_text\NCT01720394_inc.txt -> input/half_clinical_trials/NCT01720394_inc.txt
# NCT01728194_exc.ann
# NCT01728194_exc.txt
# Kopiert: input/ann_text\NCT01728194_exc.txt -> input/half_clinical_trials/NCT01728194_exc.txt
# NCT01728194_inc.ann
# NCT01728194_inc.txt
# Kopiert: input/ann_text\NCT01728194_inc.txt -> input/half_clinical_trials/NCT01728194_inc.txt
# NCT01735955_exc.ann
# NCT01735955_exc.txt
# Kopiert: input/ann_text\NCT01735955_exc.txt -> input/half_clinical_trials/NCT01735955_exc.txt
# NCT01735955_inc.ann
# NCT01735955_inc.txt
# Kopiert: input/ann_text\NCT01735955_inc.txt -> input/half_clinical_trials/NCT01735955_inc.txt
# NCT01742117_exc.ann
# NCT01742117_exc.txt
# Kopiert: input/ann_text\NCT01742117_exc.txt -> input/half_clinical_trials/NCT01742117_exc.txt
# NCT01742117_inc.ann
# NCT01742117_inc.txt
# Kopiert: input/ann_text\NCT01742117_inc.txt -> input/half_clinical_trials/NCT01742117_inc.txt
# NCT01743755_exc.ann
# NCT01743755_exc.txt
# Kopiert: input/ann_text\NCT01743755_exc.txt -> input/half_clinical_trials/NCT01743755_exc.txt
# NCT01743755_inc.ann
# NCT01743755_inc.txt
# Kopiert: input/ann_text\NCT01743755_inc.txt -> input/half_clinical_trials/NCT01743755_inc.txt
# NCT01757717_exc.ann
# NCT01757717_exc.txt
# Kopiert: input/ann_text\NCT01757717_exc.txt -> input/half_clinical_trials/NCT01757717_exc.txt
# NCT01757717_inc.ann
# NCT01757717_inc.txt
# Kopiert: input/ann_text\NCT01757717_inc.txt -> input/half_clinical_trials/NCT01757717_inc.txt
# NCT01765231_exc.ann
# NCT01765231_exc.txt
# Kopiert: input/ann_text\NCT01765231_exc.txt -> input/half_clinical_trials/NCT01765231_exc.txt
# NCT01765231_inc.ann
# NCT01765231_inc.txt
# Kopiert: input/ann_text\NCT01765231_inc.txt -> input/half_clinical_trials/NCT01765231_inc.txt
# NCT01768195_exc.ann
# NCT01768195_exc.txt
# Kopiert: input/ann_text\NCT01768195_exc.txt -> input/half_clinical_trials/NCT01768195_exc.txt
# NCT01768195_inc.ann
# NCT01768195_inc.txt
# Kopiert: input/ann_text\NCT01768195_inc.txt -> input/half_clinical_trials/NCT01768195_inc.txt
# NCT01770340_exc.ann
# NCT01770340_exc.txt
# Kopiert: input/ann_text\NCT01770340_exc.txt -> input/half_clinical_trials/NCT01770340_exc.txt
# NCT01770340_inc.ann
# NCT01770340_inc.txt
# Kopiert: input/ann_text\NCT01770340_inc.txt -> input/half_clinical_trials/NCT01770340_inc.txt
# NCT01774019_exc.ann
# NCT01774019_exc.txt
# Kopiert: input/ann_text\NCT01774019_exc.txt -> input/half_clinical_trials/NCT01774019_exc.txt
# NCT01774019_inc.ann
# NCT01774019_inc.txt
# Kopiert: input/ann_text\NCT01774019_inc.txt -> input/half_clinical_trials/NCT01774019_inc.txt
# NCT01793519_exc.ann
# NCT01793519_exc.txt
# Kopiert: input/ann_text\NCT01793519_exc.txt -> input/half_clinical_trials/NCT01793519_exc.txt
# NCT01793519_inc.ann
# NCT01793519_inc.txt
# Kopiert: input/ann_text\NCT01793519_inc.txt -> input/half_clinical_trials/NCT01793519_inc.txt
# NCT01793831_exc.ann
# NCT01793831_exc.txt
# Kopiert: input/ann_text\NCT01793831_exc.txt -> input/half_clinical_trials/NCT01793831_exc.txt
# NCT01793831_inc.ann
# NCT01793831_inc.txt
# Kopiert: input/ann_text\NCT01793831_inc.txt -> input/half_clinical_trials/NCT01793831_inc.txt
# NCT01794793_exc.ann
# NCT01794793_exc.txt
# Kopiert: input/ann_text\NCT01794793_exc.txt -> input/half_clinical_trials/NCT01794793_exc.txt
# NCT01794793_inc.ann
# NCT01794793_inc.txt
# Kopiert: input/ann_text\NCT01794793_inc.txt -> input/half_clinical_trials/NCT01794793_inc.txt
# NCT01799681_exc.ann
# NCT01799681_exc.txt
# Kopiert: input/ann_text\NCT01799681_exc.txt -> input/half_clinical_trials/NCT01799681_exc.txt
# NCT01799681_inc.ann
# NCT01799681_inc.txt
# Kopiert: input/ann_text\NCT01799681_inc.txt -> input/half_clinical_trials/NCT01799681_inc.txt
# NCT01801072_exc.ann
# NCT01801072_exc.txt
# Kopiert: input/ann_text\NCT01801072_exc.txt -> input/half_clinical_trials/NCT01801072_exc.txt
# NCT01801072_inc.ann
# NCT01801072_inc.txt
# Kopiert: input/ann_text\NCT01801072_inc.txt -> input/half_clinical_trials/NCT01801072_inc.txt
# NCT01803438_exc.ann
# NCT01803438_exc.txt
# Kopiert: input/ann_text\NCT01803438_exc.txt -> input/half_clinical_trials/NCT01803438_exc.txt
# NCT01803438_inc.ann
# NCT01803438_inc.txt
# Kopiert: input/ann_text\NCT01803438_inc.txt -> input/half_clinical_trials/NCT01803438_inc.txt
# NCT01803828_exc.ann
# NCT01803828_exc.txt
# Kopiert: input/ann_text\NCT01803828_exc.txt -> input/half_clinical_trials/NCT01803828_exc.txt
# NCT01803828_inc.ann
# NCT01803828_inc.txt
# Kopiert: input/ann_text\NCT01803828_inc.txt -> input/half_clinical_trials/NCT01803828_inc.txt
# NCT01806558_exc.ann
# NCT01806558_exc.txt
# Kopiert: input/ann_text\NCT01806558_exc.txt -> input/half_clinical_trials/NCT01806558_exc.txt
# NCT01806558_inc.ann
# NCT01806558_inc.txt
# Kopiert: input/ann_text\NCT01806558_inc.txt -> input/half_clinical_trials/NCT01806558_inc.txt
# NCT01807897_exc.ann
# NCT01807897_exc.txt
# Kopiert: input/ann_text\NCT01807897_exc.txt -> input/half_clinical_trials/NCT01807897_exc.txt
# NCT01807897_inc.ann
# NCT01807897_inc.txt
# Kopiert: input/ann_text\NCT01807897_inc.txt -> input/half_clinical_trials/NCT01807897_inc.txt
# NCT01809041_exc.ann
# NCT01809041_exc.txt
# Kopiert: input/ann_text\NCT01809041_exc.txt -> input/half_clinical_trials/NCT01809041_exc.txt
# NCT01809041_inc.ann
# NCT01809041_inc.txt
# Kopiert: input/ann_text\NCT01809041_inc.txt -> input/half_clinical_trials/NCT01809041_inc.txt
# NCT01815580_exc.ann
# NCT01815580_exc.txt
# Kopiert: input/ann_text\NCT01815580_exc.txt -> input/half_clinical_trials/NCT01815580_exc.txt
# NCT01815580_inc.ann
# NCT01815580_inc.txt
# Kopiert: input/ann_text\NCT01815580_inc.txt -> input/half_clinical_trials/NCT01815580_inc.txt
# NCT01816997_exc.ann
# NCT01816997_exc.txt
# Kopiert: input/ann_text\NCT01816997_exc.txt -> input/half_clinical_trials/NCT01816997_exc.txt
# NCT01816997_inc.ann
# NCT01816997_inc.txt
# Kopiert: input/ann_text\NCT01816997_inc.txt -> input/half_clinical_trials/NCT01816997_inc.txt
# NCT01822262_exc.ann
# NCT01822262_exc.txt
# Kopiert: input/ann_text\NCT01822262_exc.txt -> input/half_clinical_trials/NCT01822262_exc.txt
# NCT01822262_inc.ann
# NCT01822262_inc.txt
# Kopiert: input/ann_text\NCT01822262_inc.txt -> input/half_clinical_trials/NCT01822262_inc.txt
# NCT01824537_exc.ann
# NCT01824537_exc.txt
# Kopiert: input/ann_text\NCT01824537_exc.txt -> input/half_clinical_trials/NCT01824537_exc.txt
# NCT01824537_inc.ann
# NCT01824537_inc.txt
# Kopiert: input/ann_text\NCT01824537_inc.txt -> input/half_clinical_trials/NCT01824537_inc.txt
# NCT01846507_exc.ann
# NCT01846507_exc.txt
# Kopiert: input/ann_text\NCT01846507_exc.txt -> input/half_clinical_trials/NCT01846507_exc.txt
# NCT01846507_inc.ann
# NCT01846507_inc.txt
# Kopiert: input/ann_text\NCT01846507_inc.txt -> input/half_clinical_trials/NCT01846507_inc.txt
# NCT01850147_exc.ann
# NCT01850147_exc.txt
# Kopiert: input/ann_text\NCT01850147_exc.txt -> input/half_clinical_trials/NCT01850147_exc.txt
# NCT01850147_inc.ann
# NCT01850147_inc.txt
# Kopiert: input/ann_text\NCT01850147_inc.txt -> input/half_clinical_trials/NCT01850147_inc.txt
# NCT01856491_exc.ann
# NCT01856491_exc.txt
# Kopiert: input/ann_text\NCT01856491_exc.txt -> input/half_clinical_trials/NCT01856491_exc.txt
# NCT01856491_inc.ann
# NCT01856491_inc.txt
# Kopiert: input/ann_text\NCT01856491_inc.txt -> input/half_clinical_trials/NCT01856491_inc.txt
# NCT01857167_exc.ann
# NCT01857167_exc.txt
# Kopiert: input/ann_text\NCT01857167_exc.txt -> input/half_clinical_trials/NCT01857167_exc.txt
# NCT01857167_inc.ann
# NCT01857167_inc.txt
# Kopiert: input/ann_text\NCT01857167_inc.txt -> input/half_clinical_trials/NCT01857167_inc.txt
# NCT01866800_exc.ann
# NCT01866800_exc.txt
# Kopiert: input/ann_text\NCT01866800_exc.txt -> input/half_clinical_trials/NCT01866800_exc.txt
# NCT01866800_inc.ann
# NCT01866800_inc.txt
# Kopiert: input/ann_text\NCT01866800_inc.txt -> input/half_clinical_trials/NCT01866800_inc.txt
# NCT01884337_exc.ann
# NCT01884337_exc.txt
# Kopiert: input/ann_text\NCT01884337_exc.txt -> input/half_clinical_trials/NCT01884337_exc.txt
# NCT01884337_inc.ann
# NCT01884337_inc.txt
# Kopiert: input/ann_text\NCT01884337_inc.txt -> input/half_clinical_trials/NCT01884337_inc.txt
# NCT01888965_exc.ann
# NCT01888965_exc.txt
# Kopiert: input/ann_text\NCT01888965_exc.txt -> input/half_clinical_trials/NCT01888965_exc.txt
# NCT01888965_inc.ann
# NCT01888965_inc.txt
# Kopiert: input/ann_text\NCT01888965_inc.txt -> input/half_clinical_trials/NCT01888965_inc.txt
# NCT01890759_exc.ann
# NCT01890759_exc.txt
# Kopiert: input/ann_text\NCT01890759_exc.txt -> input/half_clinical_trials/NCT01890759_exc.txt
# NCT01890759_inc.ann
# NCT01890759_inc.txt
# Kopiert: input/ann_text\NCT01890759_inc.txt -> input/half_clinical_trials/NCT01890759_inc.txt
# NCT01891383_exc.ann
# NCT01891383_exc.txt
# Kopiert: input/ann_text\NCT01891383_exc.txt -> input/half_clinical_trials/NCT01891383_exc.txt
# NCT01891383_inc.ann
# NCT01891383_inc.txt
# Kopiert: input/ann_text\NCT01891383_inc.txt -> input/half_clinical_trials/NCT01891383_inc.txt
# NCT01891513_exc.ann
# ...
# NCT03431831_inc.ann
# NCT03431831_inc.txt
# Kopiert: input/ann_text\NCT03431831_inc.txt -> input/half_clinical_trials/NCT03431831_inc.txt
# NCT03434951_exc.ann
# NCT03434951_exc.txt
# Kopiert: input/ann_text\NCT03434951_exc.txt -> input/half_clinical_trials/NCT03434951_exc.txt
# NCT03434951_inc.ann
# NCT03434951_inc.txt
# Kopiert: input/ann_text\NCT03434951_inc.txt -> input/half_clinical_trials/NCT03434951_inc.txt
# NCT03444142_exc.ann
# NCT03444142_exc.txt
# Kopiert: input/ann_text\NCT03444142_exc.txt -> input/half_clinical_trials/NCT03444142_exc.txt
# NCT03444142_inc.ann
# NCT03444142_inc.txt
# Kopiert: input/ann_text\NCT03444142_inc.txt -> input/half_clinical_trials/NCT03444142_inc.txt
# NCT03445949_exc.ann
# NCT03445949_exc.txt
# Kopiert: input/ann_text\NCT03445949_exc.txt -> input/half_clinical_trials/NCT03445949_exc.txt
# NCT03445949_inc.ann
# NCT03445949_inc.txt
# Kopiert: input/ann_text\NCT03445949_inc.txt -> input/half_clinical_trials/NCT03445949_inc.txt
# NCT03446885_exc.ann
# NCT03446885_exc.txt
# Kopiert: input/ann_text\NCT03446885_exc.txt -> input/half_clinical_trials/NCT03446885_exc.txt
# NCT03446885_inc.ann
# NCT03446885_inc.txt
# Kopiert: input/ann_text\NCT03446885_inc.txt -> input/half_clinical_trials/NCT03446885_inc.txt
# NCT03460002_exc.ann
# NCT03460002_exc.txt
# Kopiert: input/ann_text\NCT03460002_exc.txt -> input/half_clinical_trials/NCT03460002_exc.txt
# NCT03460002_inc.ann
# NCT03460002_inc.txt
# Kopiert: input/ann_text\NCT03460002_inc.txt -> input/half_clinical_trials/NCT03460002_inc.txt
# NCT03461679_exc.ann
# NCT03461679_exc.txt
# Kopiert: input/ann_text\NCT03461679_exc.txt -> input/half_clinical_trials/NCT03461679_exc.txt
# NCT03461679_inc.ann
# NCT03461679_inc.txt
# Kopiert: input/ann_text\NCT03461679_inc.txt -> input/half_clinical_trials/NCT03461679_inc.txt
# NCT03463564_exc.ann
# NCT03463564_exc.txt
# Kopiert: input/ann_text\NCT03463564_exc.txt -> input/half_clinical_trials/NCT03463564_exc.txt
# NCT03463564_inc.ann
# NCT03463564_inc.txt
# Kopiert: input/ann_text\NCT03463564_inc.txt -> input/half_clinical_trials/NCT03463564_inc.txt
# NCT03464552_exc.ann
# NCT03464552_exc.txt
# Kopiert: input/ann_text\NCT03464552_exc.txt -> input/half_clinical_trials/NCT03464552_exc.txt
# NCT03464552_inc.ann
# NCT03464552_inc.txt
# Kopiert: input/ann_text\NCT03464552_inc.txt -> input/half_clinical_trials/NCT03464552_inc.txt
# NCT03465397_exc.ann
# NCT03465397_exc.txt
# Kopiert: input/ann_text\NCT03465397_exc.txt -> input/half_clinical_trials/NCT03465397_exc.txt
# NCT03465397_inc.ann
# NCT03465397_inc.txt
# Kopiert: input/ann_text\NCT03465397_inc.txt -> input/half_clinical_trials/NCT03465397_inc.txt
# NCT03467750_exc.ann
# NCT03467750_exc.txt
# Kopiert: input/ann_text\NCT03467750_exc.txt -> input/half_clinical_trials/NCT03467750_exc.txt
# NCT03467750_inc.ann
# NCT03467750_inc.txt
# Kopiert: input/ann_text\NCT03467750_inc.txt -> input/half_clinical_trials/NCT03467750_inc.txt
# NCT03471117_exc.ann
# NCT03471117_exc.txt
# Kopiert: input/ann_text\NCT03471117_exc.txt -> input/half_clinical_trials/NCT03471117_exc.txt
# NCT03471117_inc.ann
# NCT03471117_inc.txt
# Kopiert: input/ann_text\NCT03471117_inc.txt -> input/half_clinical_trials/NCT03471117_inc.txt
# NCT03472495_exc.ann
# NCT03472495_exc.txt
# Kopiert: input/ann_text\NCT03472495_exc.txt -> input/half_clinical_trials/NCT03472495_exc.txt
# NCT03472495_inc.ann
# NCT03472495_inc.txt
# Kopiert: input/ann_text\NCT03472495_inc.txt -> input/half_clinical_trials/NCT03472495_inc.txt
# NCT03472508_exc.ann
# NCT03472508_exc.txt
# Kopiert: input/ann_text\NCT03472508_exc.txt -> input/half_clinical_trials/NCT03472508_exc.txt
# NCT03472508_inc.ann
# NCT03472508_inc.txt
# Kopiert: input/ann_text\NCT03472508_inc.txt -> input/half_clinical_trials/NCT03472508_inc.txt
# NCT03472846_exc.ann
# NCT03472846_exc.txt
# Kopiert: input/ann_text\NCT03472846_exc.txt -> input/half_clinical_trials/NCT03472846_exc.txt
# NCT03472846_inc.ann
# NCT03472846_inc.txt
# Kopiert: input/ann_text\NCT03472846_inc.txt -> input/half_clinical_trials/NCT03472846_inc.txt
# NCT03473132_exc.ann
# NCT03473132_exc.txt
# Kopiert: input/ann_text\NCT03473132_exc.txt -> input/half_clinical_trials/NCT03473132_exc.txt
# NCT03473132_inc.ann
# NCT03473132_inc.txt
# Kopiert: input/ann_text\NCT03473132_inc.txt -> input/half_clinical_trials/NCT03473132_inc.txt
# NCT03475589_exc.ann
# NCT03475589_exc.txt
# Kopiert: input/ann_text\NCT03475589_exc.txt -> input/half_clinical_trials/NCT03475589_exc.txt
# NCT03475589_inc.ann
# NCT03475589_inc.txt
# Kopiert: input/ann_text\NCT03475589_inc.txt -> input/half_clinical_trials/NCT03475589_inc.txt
# NCT03476850_exc.ann
# NCT03476850_exc.txt
# Kopiert: input/ann_text\NCT03476850_exc.txt -> input/half_clinical_trials/NCT03476850_exc.txt
# NCT03476850_inc.ann
# NCT03476850_inc.txt
# Kopiert: input/ann_text\NCT03476850_inc.txt -> input/half_clinical_trials/NCT03476850_inc.txt
# NCT03477851_exc.ann
# NCT03477851_exc.txt
# Kopiert: input/ann_text\NCT03477851_exc.txt -> input/half_clinical_trials/NCT03477851_exc.txt
# NCT03477851_inc.ann
# NCT03477851_inc.txt
# Kopiert: input/ann_text\NCT03477851_inc.txt -> input/half_clinical_trials/NCT03477851_inc.txt
# NCT03479502_exc.ann
# NCT03479502_exc.txt
# Kopiert: input/ann_text\NCT03479502_exc.txt -> input/half_clinical_trials/NCT03479502_exc.txt
# NCT03479502_inc.ann
# NCT03479502_inc.txt
# Kopiert: input/ann_text\NCT03479502_inc.txt -> input/half_clinical_trials/NCT03479502_inc.txt
# NCT03480607_exc.ann
# NCT03480607_exc.txt
# Kopiert: input/ann_text\NCT03480607_exc.txt -> input/half_clinical_trials/NCT03480607_exc.txt
# NCT03480607_inc.ann
# NCT03480607_inc.txt
# Kopiert: input/ann_text\NCT03480607_inc.txt -> input/half_clinical_trials/NCT03480607_inc.txt
# NCT03481894_exc.ann
# NCT03481894_exc.txt
# Kopiert: input/ann_text\NCT03481894_exc.txt -> input/half_clinical_trials/NCT03481894_exc.txt
# NCT03481894_inc.ann
# NCT03481894_inc.txt
# Kopiert: input/ann_text\NCT03481894_inc.txt -> input/half_clinical_trials/NCT03481894_inc.txt
# NCT03484091_exc.ann
# NCT03484091_exc.txt
# Kopiert: input/ann_text\NCT03484091_exc.txt -> input/half_clinical_trials/NCT03484091_exc.txt
# NCT03484091_inc.ann
# NCT03484091_inc.txt
# Kopiert: input/ann_text\NCT03484091_inc.txt -> input/half_clinical_trials/NCT03484091_inc.txt
# NCT03491059_exc.ann
# NCT03491059_exc.txt
# Kopiert: input/ann_text\NCT03491059_exc.txt -> input/half_clinical_trials/NCT03491059_exc.txt
# NCT03491059_inc.ann
# NCT03491059_inc.txt
# Kopiert: input/ann_text\NCT03491059_inc.txt -> input/half_clinical_trials/NCT03491059_inc.txt
# NCT03493919_exc.ann
# NCT03493919_exc.txt
# Kopiert: input/ann_text\NCT03493919_exc.txt -> input/half_clinical_trials/NCT03493919_exc.txt
# NCT03493919_inc.ann
# NCT03493919_inc.txt
# Kopiert: input/ann_text\NCT03493919_inc.txt -> input/half_clinical_trials/NCT03493919_inc.txt
# NCT03495557_exc.ann
# NCT03495557_exc.txt
# Kopiert: input/ann_text\NCT03495557_exc.txt -> input/half_clinical_trials/NCT03495557_exc.txt
# NCT03495557_inc.ann
# NCT03495557_inc.txt
# Kopiert: input/ann_text\NCT03495557_inc.txt -> input/half_clinical_trials/NCT03495557_inc.txt
# NCT03495609_exc.ann
# NCT03495609_exc.txt
# Kopiert: input/ann_text\NCT03495609_exc.txt -> input/half_clinical_trials/NCT03495609_exc.txt
# NCT03495609_inc.ann
# NCT03495609_inc.txt
# Kopiert: input/ann_text\NCT03495609_inc.txt -> input/half_clinical_trials/NCT03495609_inc.txt
# NCT03497598_exc.ann
# NCT03497598_exc.txt
# Kopiert: input/ann_text\NCT03497598_exc.txt -> input/half_clinical_trials/NCT03497598_exc.txt
# NCT03497598_inc.ann
# NCT03497598_inc.txt
# Kopiert: input/ann_text\NCT03497598_inc.txt -> input/half_clinical_trials/NCT03497598_inc.txt
# NCT03499639_exc.ann
# NCT03499639_exc.txt
# Kopiert: input/ann_text\NCT03499639_exc.txt -> input/half_clinical_trials/NCT03499639_exc.txt
# NCT03499639_inc.ann
# NCT03499639_inc.txt
# Kopiert: input/ann_text\NCT03499639_inc.txt -> input/half_clinical_trials/NCT03499639_inc.txt
# NCT03500211_exc.ann
# NCT03500211_exc.txt
# Kopiert: input/ann_text\NCT03500211_exc.txt -> input/half_clinical_trials/NCT03500211_exc.txt
# NCT03500211_inc.ann
# NCT03500211_inc.txt
# Kopiert: input/ann_text\NCT03500211_inc.txt -> input/half_clinical_trials/NCT03500211_inc.txt
# NCT03506009_exc.ann
# NCT03506009_exc.txt
# Kopiert: input/ann_text\NCT03506009_exc.txt -> input/half_clinical_trials/NCT03506009_exc.txt
# NCT03506009_inc.ann
# NCT03506009_inc.txt
# Kopiert: input/ann_text\NCT03506009_inc.txt -> input/half_clinical_trials/NCT03506009_inc.txt
# NCT03506477_exc.ann
# NCT03506477_exc.txt
# Kopiert: input/ann_text\NCT03506477_exc.txt -> input/half_clinical_trials/NCT03506477_exc.txt
# NCT03506477_inc.ann
# NCT03506477_inc.txt
# Kopiert: input/ann_text\NCT03506477_inc.txt -> input/half_clinical_trials/NCT03506477_inc.txt
# NCT03506750_exc.ann
# NCT03506750_exc.txt
# Kopiert: input/ann_text\NCT03506750_exc.txt -> input/half_clinical_trials/NCT03506750_exc.txt
# NCT03506750_inc.ann
# NCT03506750_inc.txt
# Kopiert: input/ann_text\NCT03506750_inc.txt -> input/half_clinical_trials/NCT03506750_inc.txt
# NCT03511521_exc.ann
# NCT03511521_exc.txt
# Kopiert: input/ann_text\NCT03511521_exc.txt -> input/half_clinical_trials/NCT03511521_exc.txt
# NCT03511521_inc.ann
# NCT03511521_inc.txt
# Kopiert: input/ann_text\NCT03511521_inc.txt -> input/half_clinical_trials/NCT03511521_inc.txt
# NCT03513757_exc.ann
# NCT03513757_exc.txt
# Kopiert: input/ann_text\NCT03513757_exc.txt -> input/half_clinical_trials/NCT03513757_exc.txt
# NCT03513757_inc.ann
# NCT03513757_inc.txt
# Kopiert: input/ann_text\NCT03513757_inc.txt -> input/half_clinical_trials/NCT03513757_inc.txt
# NCT03513874_exc.ann
# NCT03513874_exc.txt
# Kopiert: input/ann_text\NCT03513874_exc.txt -> input/half_clinical_trials/NCT03513874_exc.txt
# NCT03513874_inc.ann
# NCT03513874_inc.txt
# Kopiert: input/ann_text\NCT03513874_inc.txt -> input/half_clinical_trials/NCT03513874_inc.txt
# NCT03518034_exc.ann
# NCT03518034_exc.txt
# Kopiert: input/ann_text\NCT03518034_exc.txt -> input/half_clinical_trials/NCT03518034_exc.txt
# NCT03518034_inc.ann
# NCT03518034_inc.txt
# Kopiert: input/ann_text\NCT03518034_inc.txt -> input/half_clinical_trials/NCT03518034_inc.txt
# NCT03519568_exc.ann
# NCT03519568_exc.txt
# Kopiert: input/ann_text\NCT03519568_exc.txt -> input/half_clinical_trials/NCT03519568_exc.txt
# NCT03519568_inc.ann
# NCT03519568_inc.txt
# Kopiert: input/ann_text\NCT03519568_inc.txt -> input/half_clinical_trials/NCT03519568_inc.txt
# NCT03530124_exc.ann
# NCT03530124_exc.txt
# Kopiert: input/ann_text\NCT03530124_exc.txt -> input/half_clinical_trials/NCT03530124_exc.txt
# NCT03530124_inc.ann
# NCT03530124_inc.txt
# Kopiert: input/ann_text\NCT03530124_inc.txt -> input/half_clinical_trials/NCT03530124_inc.txt
# NCT03532620_exc.ann
# NCT03532620_exc.txt
# Kopiert: input/ann_text\NCT03532620_exc.txt -> input/half_clinical_trials/NCT03532620_exc.txt
# NCT03532620_inc.ann
# NCT03532620_inc.txt
# Kopiert: input/ann_text\NCT03532620_inc.txt -> input/half_clinical_trials/NCT03532620_inc.txt
# NCT03536520_exc.ann
# NCT03536520_exc.txt
# Kopiert: input/ann_text\NCT03536520_exc.txt -> input/half_clinical_trials/NCT03536520_exc.txt
# NCT03536520_inc.ann
# NCT03536520_inc.txt
# Kopiert: input/ann_text\NCT03536520_inc.txt -> input/half_clinical_trials/NCT03536520_inc.txt
# NCT03537924_exc.ann
# NCT03537924_exc.txt
# Kopiert: input/ann_text\NCT03537924_exc.txt -> input/half_clinical_trials/NCT03537924_exc.txt
# NCT03537924_inc.ann
# NCT03537924_inc.txt
# Kopiert: input/ann_text\NCT03537924_inc.txt -> input/half_clinical_trials/NCT03537924_inc.txt
# NCT03539718_exc.ann
# NCT03539718_exc.txt
# Kopiert: input/ann_text\NCT03539718_exc.txt -> input/half_clinical_trials/NCT03539718_exc.txt
# NCT03539718_inc.ann
# NCT03539718_inc.txt
# Kopiert: input/ann_text\NCT03539718_inc.txt -> input/half_clinical_trials/NCT03539718_inc.txt
# NCT03541980_exc.ann
# NCT03541980_exc.txt
# Kopiert: input/ann_text\NCT03541980_exc.txt -> input/half_clinical_trials/NCT03541980_exc.txt
# NCT03541980_inc.ann
# NCT03541980_inc.txt
# Kopiert: input/ann_text\NCT03541980_inc.txt -> input/half_clinical_trials/NCT03541980_inc.txt
# NCT03555526_exc.ann
# NCT03555526_exc.txt
# Kopiert: input/ann_text\NCT03555526_exc.txt -> input/half_clinical_trials/NCT03555526_exc.txt
# NCT03555526_inc.ann
# NCT03555526_inc.txt
# Kopiert: input/ann_text\NCT03555526_inc.txt -> input/half_clinical_trials/NCT03555526_inc.txt
# NCT03560310_exc.ann
# NCT03560310_exc.txt
# Kopiert: input/ann_text\NCT03560310_exc.txt -> input/half_clinical_trials/NCT03560310_exc.txt
# NCT03560310_inc.ann
# NCT03560310_inc.txt
# Kopiert: input/ann_text\NCT03560310_inc.txt -> input/half_clinical_trials/NCT03560310_inc.txt
# NCT03561753_exc.ann
# NCT03561753_exc.txt
# Kopiert: input/ann_text\NCT03561753_exc.txt -> input/half_clinical_trials/NCT03561753_exc.txt
# NCT03561753_inc.ann
# NCT03561753_inc.txt
# Kopiert: input/ann_text\NCT03561753_inc.txt -> input/half_clinical_trials/NCT03561753_inc.txt
# NCT03589105_exc.ann
# NCT03589105_exc.txt
# Kopiert: input/ann_text\NCT03589105_exc.txt -> input/half_clinical_trials/NCT03589105_exc.txt
# NCT03589105_inc.ann
# NCT03589105_inc.txt
# Kopiert: input/ann_text\NCT03589105_inc.txt -> input/half_clinical_trials/NCT03589105_inc.txt
# NCT03615508_exc.ann
# NCT03615508_exc.txt
# Kopiert: input/ann_text\NCT03615508_exc.txt -> input/half_clinical_trials/NCT03615508_exc.txt
# NCT03615508_inc.ann
# NCT03615508_inc.txt
# Kopiert: input/ann_text\NCT03615508_inc.txt -> input/half_clinical_trials/NCT03615508_inc.txt
# NCT03619707_exc.ann
# NCT03619707_exc.txt
# Kopiert: input/ann_text\NCT03619707_exc.txt -> input/half_clinical_trials/NCT03619707_exc.txt
# NCT03619707_inc.ann
# NCT03619707_inc.txt
# Kopiert: input/ann_text\NCT03619707_inc.txt -> input/half_clinical_trials/NCT03619707_inc.txt
# NCT03620526_exc.ann
# NCT03620526_exc.txt
# Kopiert: input/ann_text\NCT03620526_exc.txt -> input/half_clinical_trials/NCT03620526_exc.txt
# NCT03620526_inc.ann
# NCT03620526_inc.txt
# Kopiert: input/ann_text\NCT03620526_inc.txt -> input/half_clinical_trials/NCT03620526_inc.txt
# NCT03623789_exc.ann
# NCT03623789_exc.txt
# Kopiert: input/ann_text\NCT03623789_exc.txt -> input/half_clinical_trials/NCT03623789_exc.txt
# NCT03623789_inc.ann
# NCT03623789_inc.txt
# Kopiert: input/ann_text\NCT03623789_inc.txt -> input/half_clinical_trials/NCT03623789_inc.txt
# NCT03624517_exc.ann
# NCT03624517_exc.txt
# Kopiert: input/ann_text\NCT03624517_exc.txt -> input/half_clinical_trials/NCT03624517_exc.txt
# NCT03624517_inc.ann
# NCT03624517_inc.txt
# Kopiert: input/ann_text\NCT03624517_inc.txt -> input/half_clinical_trials/NCT03624517_inc.txt
# NCT03624881_exc.ann
# NCT03624881_exc.txt
# Kopiert: input/ann_text\NCT03624881_exc.txt -> input/half_clinical_trials/NCT03624881_exc.txt
# NCT03624881_inc.ann
# NCT03624881_inc.txt
# Kopiert: input/ann_text\NCT03624881_inc.txt -> input/half_clinical_trials/NCT03624881_inc.txt
# NCT03631355_exc.ann
# NCT03631355_exc.txt
# Kopiert: input/ann_text\NCT03631355_exc.txt -> input/half_clinical_trials/NCT03631355_exc.txt
# NCT03631355_inc.ann
# NCT03631355_inc.txt
# Kopiert: input/ann_text\NCT03631355_inc.txt -> input/half_clinical_trials/NCT03631355_inc.txt
# NCT03637946_exc.ann
# NCT03637946_exc.txt
# Kopiert: input/ann_text\NCT03637946_exc.txt -> input/half_clinical_trials/NCT03637946_exc.txt
# NCT03637946_inc.ann
# NCT03637946_inc.txt
# Kopiert: input/ann_text\NCT03637946_inc.txt -> input/half_clinical_trials/NCT03637946_inc.txt
# NCT03639519_exc.ann
# NCT03639519_exc.txt
# Kopiert: input/ann_text\NCT03639519_exc.txt -> input/half_clinical_trials/NCT03639519_exc.txt
# NCT03639519_inc.ann
# NCT03639519_inc.txt
# Kopiert: input/ann_text\NCT03639519_inc.txt -> input/half_clinical_trials/NCT03639519_inc.txt
# NCT03639545_exc.ann
# NCT03639545_exc.txt
# Kopiert: input/ann_text\NCT03639545_exc.txt -> input/half_clinical_trials/NCT03639545_exc.txt
# NCT03639545_inc.ann
# NCT03639545_inc.txt
# Kopiert: input/ann_text\NCT03639545_inc.txt -> input/half_clinical_trials/NCT03639545_inc.txt
# NCT03648021_exc.ann
# NCT03648021_exc.txt
# Kopiert: input/ann_text\NCT03648021_exc.txt -> input/half_clinical_trials/NCT03648021_exc.txt
# NCT03648021_inc.ann
# NCT03648021_inc.txt
# Kopiert: input/ann_text\NCT03648021_inc.txt -> input/half_clinical_trials/NCT03648021_inc.txt
# NCT03663387_exc.ann
# NCT03663387_exc.txt
# Kopiert: input/ann_text\NCT03663387_exc.txt -> input/half_clinical_trials/NCT03663387_exc.txt
# NCT03663387_inc.ann
# NCT03663387_inc.txt
# Kopiert: input/ann_text\NCT03663387_inc.txt -> input/half_clinical_trials/NCT03663387_inc.txt

# %%
def extract_nct_number(filename):
    match = re.search(r'(NCT\d{8})_(inc|exc)', filename)
    return match.groups() if match else (None, None)

def read_file_content(filepath):
    with open(filepath, 'r', encoding='utf-8') as file:
        return file.read()

def read_matching_txt_files(study_folder, label_folder, max_files):
    study_filenames = []
    label_filenames = []
    study_contents = []
    label_contents = []

    study_files = [f for f in os.listdir(study_folder) if f.endswith('.txt')][:max_files]
    label_files = [f for f in os.listdir(label_folder) if f.endswith('.txt')][:max_files]
    for filename in study_files:
        nct_number, inc_exc = extract_nct_number(filename)
        if nct_number:
            study_filenames.append(f"{nct_number}_{inc_exc}_study")
            filepath = os.path.join(study_folder, filename)
            study_contents.append(read_file_content(filepath))
    for filename in label_files:
        nct_number, inc_exc = extract_nct_number(filename)
        if nct_number:
            label_filenames.append(f"{nct_number}_{inc_exc}_label")
            filepath = os.path.join(label_folder, filename)
            label_contents.append(read_file_content(filepath))

    return study_filenames, study_contents, label_filenames, label_contents

# %%
study_folder = 'input/half_clinical_trials/'  
label_folder = 'chia_label/p2_model_input/' 
max_files = 3  

study_filenames, study_contents, label_filenames, label_contents = read_matching_txt_files(study_folder, label_folder, max_files)
studies = dict(zip(study_filenames, study_contents))
labels = dict(zip(label_filenames, label_contents))

study_keys = list(studies.keys())
label_keys = list(labels.keys())
label1 = labels[label_keys[0]]
label2 = labels[label_keys[1]]
label3 = labels[label_keys[2]]

study1 = studies[study_keys[0]]
study2 = studies[study_keys[1]]
study3 = studies[study_keys[2]]

# %%
input = "model_output/Llama-3-8B-Instruct_3_shot/"
output = "model_output/Llama-3-8B-Instruct_3_shot/formatted/"

for filename in os.listdir(input):
    if filename.endswith('.json'):
        file = read_json(input+filename)
        print(filename)
        save_json_to_file(file, output+filename)
# Out:
# Llama-3-8B-Instruct_NCT00050349_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00050349_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00061308_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00094861_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00094861_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00122070_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00122070_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00182520_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00182520_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00183885_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00183885_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00198913_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00198913_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00235170_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00235170_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00236340_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00236340_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00250640_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00250640_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00279552_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00279552_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00730301_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00730301_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00749112_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00749112_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00752310_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00752310_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00785213_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00785213_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00787254_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00787254_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00806273_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00806273_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00806936_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00806936_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00812344_exc_3_shot.json
# Llama-3-8B-Instruct_NCT00812344_inc_3_shot.json
# Llama-3-8B-Instruct_NCT00846703_exc_3_shot.json
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26796\2867243255.py in <module>
#       4 for filename in os.listdir(input):
#       5     if filename.endswith('.json'):
# ----> 6         file = read_json(input+filename)
#       7         print(filename)
#       8         save_json_to_file(file, output+filename)
#
# ~\DataspellProjects\ec_criteria_struct\transform_chia\functions.py in read_json(file_path)
#      10 def read_json(file_path):
#      11     with open(file_path, 'r', encoding='utf-8') as f:
# ---> 12         data = json.load(f)
#      13     return data
#      14
#
# ~\anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Unterminated string starting at: line 1 column 1 (char 0)
