# %%
from preprocessing_functions import *
from Node import *

# %% [markdown]
# #### lct_p1_half To lct_p1_half_s1

# %%
def save_criteria_to_json(text, output_file: str, type: str):
    sentences = text.strip().split('\n')
    sentences = [re.sub(r'\s+', ' ', sentence.strip()) for sentence in sentences if sentence.strip()]
    data = {f"{type}{i+1}": sentence for i, sentence in enumerate(sentences)}
    json_output = json.dumps(data, indent=2, ensure_ascii=False)
    with open(output_file, "w", encoding="utf-8") as file:
        file.write(json_output)
    return json_output

def read_files_and_save_to_json(input_directory, output_directory):
    os.makedirs(output_directory, exist_ok=True)
    for file_name in os.listdir(input_directory):
        file_path = os.path.join(input_directory, file_name)
        if os.path.isfile(file_path):
            with open(file_path, 'r', encoding='utf-8') as file:
                file_content = file.read()
            if file_name.endswith("_exc.txt"):
                output_file_path = os.path.join(output_directory, file_name.replace("_exc.txt", "_exc.json"))
                save_criteria_to_json(file_content, output_file_path, type="EC")
            elif file_name.endswith("_inc.txt"):
                output_file_path = os.path.join(output_directory, file_name.replace("_inc.txt", "_inc.json"))
                save_criteria_to_json(file_content, output_file_path, type="IC")

# %%
input_directory = "corpora/lct_p1_half"
output_directory = "corpora/lct_p1_half_s1"
output_2_directory = "corpora/lct_p2_half"
os.makedirs(output_2_directory, exist_ok=True)
read_files_and_save_to_json(input_directory, output_directory)

# %% [markdown]
# #### lct_p1_half_s1 To lct_p2_half

# %%
for file_name in os.listdir(output_directory):
    if file_name.endswith(".json"):
        file_path = os.path.join(output_directory, file_name)
        file = file_name.split(".")[0]    
        data = read_json(file_path)
        tree = build_tree(data)
        tree_json = tree.to_dict()
        ausgabe = json.dumps(tree_json, indent=2)
        save_json_to_file(ausgabe, f'{output_2_directory}/{file}.json')
# Out:
# NCT03860012_exc.json
# {
#   "AND": {
#     "left": {
#       "raw_text": "1. abnormal folate levels"
#     },
#     "right": {
#       "OR": {
#         "left": {
#           "raw_text": "2. age > 21"
#         },
#         "right": {
#           "raw_text": "or less than 2"
#         }
#       }
#     }
#   }
# }
# NCT03860012_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "raw_text": "1. inflammatory bowel disease"
#                 },
#                 "right": {
#                   "raw_text": "2. on methotrexate at appropriate dosing"
#                 }
#               }
#             },
#             "right": {
#               "raw_text": "3. normal folate levels at onset of study"
#             }
#           }
#         },
#         "right": {
#           "raw_text": "4. treatment with folic acid"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "5. ages 2-21 years"
#     }
#   }
# }
# NCT03860025_exc.json
# {
#   "raw_text": "-"
# }
# NCT03860025_inc.json
# {
#   "AND": {
#     "left": {
#       "raw_text": "- patients with one or more events of hip dislocation after a primary THA"
#     },
#     "right": {
#       "AND": {
#         "left": {
#           "raw_text": "- controls with a primary THA"
#         },
#         "right": {
#           "NOT": {
#             "left": {
#               "raw_text": "without events of hip dislocation"
#             }
#           }
#         }
#       }
#     }
#   }
# }
# NCT03860038_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "raw_text": "1. Subject has received anti-CD38 monoclonal antibody treatment previously;"
#                 },
#                 "right": {
#                   "raw_text": "2. Subject has received CAR-T cell therapy previously;"
#                 }
#               }
#             },
#             "right": {
#               "OR": {
#                 "left": {
#                   "raw_text": "3. Subject has previously received allogenic stem cell transplant,"
#                 },
#                 "right": {
#                   "raw_text": "or subject has received autologous stem cell transplant within 3 months before administration of the study agent;"
#                 }
#               }
#             }
#           }
#         },
#         "right": {
#           "raw_text": "4. Primary refractory multiple myeloma (subject failed to generate any minimal response or any degree of response to any therapy);"
#         }
#       }
#     },
#     "right": {
#       "OR": {
#         "left": {
#           "raw_text": "5. Subject has received anti-myeloma treatment (radiotherapy is excluded) within 4 weeks"
#         },
#         "right": {
#           "raw_text": "or 5 PK half-lives of the treatment, whichever longer, before the first study agent administration."
#         }
#       }
#     }
#   }
# }
# NCT03860038_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "AND": {
#                     "left": {
#                       "OR": {
#                         "left": {
#                           "raw_text": "1. Age \u2265 18, male"
#                         },
#                         "right": {
#                           "raw_text": "or female;"
#                         }
#                       }
#                     },
#                     "right": {
#                       "raw_text": "2. Subject must have had documented MM;"
#                     }
#                   }
#                 },
#                 "right": {
#                   "raw_text": "3. At screening phase, subject must have measurable disease;"
#                 }
#               }
#             },
#             "right": {
#               "raw_text": "4. Subject is in a state of progressive disease (PD);"
#             }
#           }
#         },
#         "right": {
#           "raw_text": "5. Subject must have life expectancy of no less than 6 months;"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "6. Subject must have an ECOG (Eastern Cooperative Oncology Group) performance status score of 0~2;"
#     }
#   }
# }
# NCT03860064_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "raw_text": "- > 35 years"
#             },
#             "right": {
#               "raw_text": "- PCO syndrome carriers"
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- Null follicle aspiration"
#         }
#       }
#     },
#     "right": {
#       "OR": {
#         "left": {
#           "raw_text": "- History of chemotherapy"
#         },
#         "right": {
#           "raw_text": "or radiotherapy"
#         }
#       }
#     }
#   }
# }
# NCT03860064_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "raw_text": "- 18-35-year-old women"
#             },
#             "right": {
#               "AND": {
#                 "left": {
#                   "raw_text": "- BMI: >18"
#                 },
#                 "right": {
#                   "raw_text": "and < 30 kg/m2"
#                 }
#               }
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- Normal female karyotype"
#         }
#       }
#     },
#     "right": {
#       "AND": {
#         "left": {
#           "raw_text": "- Normal uterus"
#         },
#         "right": {
#           "raw_text": "and ovaries at transvaginal ultrasound"
#         }
#       }
#     }
#   }
# }
# NCT03860090_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "raw_text": "- Pre-existing ipsilateral pacing electrode."
#         },
#         "right": {
#           "raw_text": "- Previous ipsilateral lymphadenectomy."
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- Indication of cardiac resynchronization therapy."
#     }
#   }
# }
# NCT03860090_inc.json
# {
#   "OR": {
#     "left": {
#       "raw_text": "- Patients with a endovenous pacemaker"
#     },
#     "right": {
#       "raw_text": "or defibrillator indication."
#     }
#   }
# }
# NCT03860103_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "OR": {
#             "left": {
#               "raw_text": "- Minors, adults under guardianship,"
#             },
#             "right": {
#               "raw_text": "protected persons"
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- Not affiliated to a social security scheme"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- Multiple pregnancy"
#     }
#   }
# }
# NCT03860103_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "AND": {
#                     "left": {
#                       "raw_text": "- Patient who accepted to participate in the study"
#                     },
#                     "right": {
#                       "raw_text": "- Woman over 18 years old"
#                     }
#                   }
#                 },
#                 "right": {
#                   "raw_text": "- Affiliated to a social security scheme"
#                 }
#               }
#             },
#             "right": {
#               "raw_text": "- Mono-fetal pregnancy"
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- Patients with normal pregnancy between 11 and 42 weeks of amenorrhea"
#         }
#       }
#     },
#     "right": {
#       "OR": {
#         "left": {
#           "raw_text": "- Patients hospitalized for preeclampsia"
#         },
#         "right": {
#           "raw_text": "and / or intrauterine growth retardation, beyond 20 weeks of amenorrhea"
#         }
#       }
#     }
#   }
# }
# NCT03860116_exc.json
# {
#   "AND": {
#     "left": {
#       "OR": {
#         "left": {
#           "raw_text": "- 1. under severe physical"
#         },
#         "right": {
#           "AND": {
#             "left": {
#               "raw_text": "or mental condition which"
#             },
#             "right": {
#               "NOT": {
#                 "left": {
#                   "raw_text": "precludes study participation;"
#                 }
#               }
#             }
#           }
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- 2. being an inpatient of the hospital;"
#     }
#   }
# }
# NCT03860116_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "AND": {
#                     "left": {
#                       "raw_text": "- 1. diagnosed as HIV positive;"
#                     },
#                     "right": {
#                       "raw_text": "- 2. initiate antiretroviral therapy on the day of recruitment;"
#                     }
#                   }
#                 },
#                 "right": {
#                   "raw_text": "- 3. was infected through male same-sex behavior;"
#                 }
#               }
#             },
#             "right": {
#               "raw_text": "- 4. has access to internet on a personal mobile phone;"
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- 5. has a Wechat account and use it daily;"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- 6. willing to provide written informed consent;"
#     }
#   }
# }
# NCT03860142_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "raw_text": "- Children"
#                 },
#                 "right": {
#                   "raw_text": "with congenital pathologies (with malformations in the oro-facial sphere)"
#                 }
#               }
#             },
#             "right": {
#               "AND": {
#                 "left": {
#                   "raw_text": "- Children"
#                 },
#                 "right": {
#                   "OR": {
#                     "left": {
#                       "raw_text": "with neurological"
#                     },
#                     "right": {
#                       "raw_text": "and developmental pathologies unrelated to prematurity"
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         },
#         "right": {
#           "AND": {
#             "left": {
#               "raw_text": "- Children"
#             },
#             "right": {
#               "raw_text": "with ENT deformities"
#             }
#           }
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- Parental langage barrier"
#     }
#   }
# }
# NCT03860142_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "raw_text": "- Children"
#         },
#         "right": {
#           "AND": {
#             "left": {
#               "raw_text": "whose age \u2265 24 months"
#             },
#             "right": {
#               "raw_text": "and \u2264 36 months"
#             }
#           }
#         }
#       }
#     },
#     "right": {
#       "OR": {
#         "left": {
#           "raw_text": "- Full-term"
#         },
#         "right": {
#           "raw_text": "or prematurely born (<33 SA) at Nice University Hospital"
#         }
#       }
#     }
#   }
# }
# NCT03860168_exc.json
# {
#   "raw_text": "empty set"
# }
# NCT03860168_inc.json
# {
#   "raw_text": "empty set"
# }
# NCT03860181_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "AND": {
#                     "left": {
#                       "OR": {
#                         "left": {
#                           "raw_text": "- They have a unique, identifying tattoo"
#                         },
#                         "right": {
#                           "raw_text": "or skin marking within 2 inches of intended site of surgical incision"
#                         }
#                       }
#                     },
#                     "right": {
#                       "OR": {
#                         "left": {
#                           "raw_text": "- They self-report a known hypersensitivity to cyanoacrylate,"
#                         },
#                         "right": {
#                           "OR": {
#                             "left": {
#                               "raw_text": "formaldehyde,"
#                             },
#                             "right": {
#                               "OR": {
#                                 "left": {
#                                   "raw_text": "benzalkonium chloride,"
#                                 },
#                                 "right": {
#                                   "raw_text": "or pressure sensitive adhesive;"
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "right": {
#                   "OR": {
#                     "left": {
#                       "raw_text": "- They self-report or have a documented prior ipsilateral shoulder arthroplasty"
#                     },
#                     "right": {
#                       "raw_text": "or other open ispilateral shoulder surgery utilizing the delto-pectoral approach;"
#                     }
#                   }
#                 }
#               }
#             },
#             "right": {
#               "OR": {
#                 "left": {
#                   "raw_text": "- Their medical record shows that they are HIV"
#                 },
#                 "right": {
#                   "raw_text": "positive or otherwise immunocompromised;"
#                 }
#               }
#             }
#           }
#         },
#         "right": {
#           "OR": {
#             "left": {
#               "raw_text": "- Their medical record shows a skin abnormality"
#             },
#             "right": {
#               "raw_text": "or dermatological condition which affects skin healing;"
#             }
#           }
#         }
#       }
#     },
#     "right": {
#       "OR": {
#         "left": {
#           "raw_text": "- They report a personal"
#         },
#         "right": {
#           "OR": {
#             "left": {
#               "raw_text": "or family history of significant keloid"
#             },
#             "right": {
#               "OR": {
#                 "left": {
#                   "raw_text": "or significant hypertrophic scar formations,"
#                 },
#                 "right": {
#                   "raw_text": "or other problems with wound healing."
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# NCT03860181_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "raw_text": "- They are 18 years or older;"
#             },
#             "right": {
#               "raw_text": "- They are undergoing primary total shoulder arthroplasty by the principal and co-investigator."
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- They are willing and have the capacity to provide informed consent;"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- They expect to continue their post-operative follow up care with their operating surgeons at Medical University of South Carolina (MUSC)."
#     }
#   }
# }
# NCT03860194_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "AND": {
#                     "left": {
#                       "raw_text": "- Subject's life expectancy was shorter than 6 months"
#                     },
#                     "right": {
#                       "raw_text": "- Nursing home resident"
#                     }
#                   }
#                 },
#                 "right": {
#                   "raw_text": "- Subject has the history of kidney failure"
#                 }
#               }
#             },
#             "right": {
#               "raw_text": "- Subject has the history of liver failure"
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- Subject has the history of diabetes mellitus"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- Subject has resistance exercise habit."
#     }
#   }
# }
# NCT03860194_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "raw_text": "- Older adults (\u2265 65 years)"
#         },
#         "right": {
#           "raw_text": "- Subject has lower appendicular muscle mass index (AMMI) (<7 kg/m^2 in men; <5.7 kg/m^2 in women) using Bioelectrical impedance analysis (BIA, TANITA BC-418\u00ae, Tokyo, Japan)"
#         }
#       }
#     },
#     "right": {
#       "OR": {
#         "left": {
#           "raw_text": "- Subject has lower handgrip strength (<26 kg in men; <18 kg in women) using dynamometer"
#         },
#         "right": {
#           "raw_text": "(CAMRY\u00ae, Zhongshan, Guangdong) or slowly gait speed (<1 m/s)"
#         }
#       }
#     }
#   }
# }
# NCT03860220_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "AND": {
#                     "left": {
#                       "AND": {
#                         "left": {
#                           "AND": {
#                             "left": {
#                               "raw_text": "- sSBP \u2265 20mmHg"
#                             },
#                             "right": {
#                               "raw_text": "and sDBP \u2265 10mmHg"
#                             }
#                           }
#                         },
#                         "right": {
#                           "OR": {
#                             "left": {
#                               "raw_text": "- symptomatic orthostatic hypotension"
#                             },
#                             "right": {
#                               "OR": {
#                                 "left": {
#                                   "raw_text": "and secondary/"
#                                 },
#                                 "right": {
#                                   "OR": {
#                                     "left": {
#                                       "raw_text": "iatrogenic hypertension"
#                                     },
#                                     "right": {
#                                       "raw_text": "and dyslipidemia"
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     },
#                     "right": {
#                       "OR": {
#                         "left": {
#                           "raw_text": "- history of moderate to severe cerebral ischemia,"
#                         },
#                         "right": {
#                           "OR": {
#                             "left": {
#                               "raw_text": "cerebral hemorrhage,"
#                             },
#                             "right": {
#                               "OR": {
#                                 "left": {
#                                   "raw_text": "transient ischemic attack,"
#                                 },
#                                 "right": {
#                                   "OR": {
#                                     "left": {
#                                       "raw_text": "myocardial infarction,"
#                                     },
#                                     "right": {
#                                       "raw_text": "or unstable angina in the past 6 months; severe heart failure (New York Heart Association functional class III and IV)"
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "right": {
#                   "OR": {
#                     "left": {
#                       "raw_text": "- hypersensitivity to telmisartan"
#                     },
#                     "right": {
#                       "raw_text": "or rosuvastatin"
#                     }
#                   }
#                 }
#               }
#             },
#             "right": {
#               "OR": {
#                 "left": {
#                   "raw_text": "- history of angioedema after treatment with angiotensin-converting enzyme inhibitors"
#                 },
#                 "right": {
#                   "raw_text": "or ARBs; creatinine phosphokinase levels \u22653 times the upper limit of normal"
#                 }
#               }
#             }
#           }
#         },
#         "right": {
#           "OR": {
#             "left": {
#               "raw_text": "- estimated glomerular filtration rate \u226430 mL/min; aspartate aminotransferase"
#             },
#             "right": {
#               "raw_text": "and alanine aminotransferase levels \u22653 times the upper limit of normal"
#             }
#           }
#         }
#       }
#     },
#     "right": {
#       "OR": {
#         "left": {
#           "raw_text": "- potassium"
#         },
#         "right": {
#           "raw_text": "levels >5.5 mmol/L; or any diseases that could affect the results of the study."
#         }
#       }
#     }
#   }
# }
# NCT03860220_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "raw_text": "- 145 mmHg \u2264 msSBP \u2264 190 mmHg"
#         },
#         "right": {
#           "raw_text": "- Triglycerides < 500 mg/dL"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- LDL-C \u2264 250 mg/dL"
#     }
#   }
# }
# NCT03860233_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "AND": {
#                     "left": {
#                       "AND": {
#                         "left": {
#                           "AND": {
#                             "left": {
#                               "raw_text": "- subjects"
#                             },
#                             "right": {
#                               "NOT": {
#                                 "left": {
#                                   "OR": {
#                                     "left": {
#                                       "raw_text": "not willing to"
#                                     },
#                                     "right": {
#                                       "AND": {
#                                         "left": {
#                                           "raw_text": "or otherwise"
#                                         },
#                                         "right": {
#                                           "NOT": {
#                                             "left": {
#                                               "raw_text": "unable to use CPAP for treatment of OSA."
#                                             }
#                                           }
#                                         }
#                                       }
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         },
#                         "right": {
#                           "raw_text": "- Presence of other sleep disorders"
#                         }
#                       }
#                     },
#                     "right": {
#                       "OR": {
#                         "left": {
#                           "raw_text": "- Pregnant"
#                         },
#                         "right": {
#                           "raw_text": "or breastfeeding women"
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "right": {
#                   "AND": {
#                     "left": {
#                       "raw_text": "- Women"
#                     },
#                     "right": {
#                       "AND": {
#                         "left": {
#                           "raw_text": "of child-bearing age (WOCBA)"
#                         },
#                         "right": {
#                           "NOT": {
#                             "left": {
#                               "OR": {
#                                 "left": {
#                                   "raw_text": "not willing"
#                                 },
#                                 "right": {
#                                   "AND": {
#                                     "left": {
#                                       "raw_text": "or"
#                                     },
#                                     "right": {
#                                       "NOT": {
#                                         "left": {
#                                           "AND": {
#                                             "left": {
#                                               "raw_text": "unable to use an accepted method to"
#                                             },
#                                             "right": {
#                                               "NOT": {
#                                                 "left": {
#                                                   "raw_text": "avoid pregnancy for the entire duration of the study"
#                                                 }
#                                               }
#                                             }
#                                           }
#                                         }
#                                       }
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             },
#             "right": {
#               "OR": {
#                 "left": {
#                   "raw_text": "- Prisoners"
#                 },
#                 "right": {
#                   "raw_text": "or subjects who are involuntarily incarcerated"
#                 }
#               }
#             }
#           }
#         },
#         "right": {
#           "OR": {
#             "left": {
#               "raw_text": "- Subjects who are compulsorily detain"
#             },
#             "right": {
#               "OR": {
#                 "left": {
#                   "raw_text": "or treatment of either a psychiatric"
#                 },
#                 "right": {
#                   "raw_text": "or physical (i.e. infectious disease) illness"
#                 }
#               }
#             }
#           }
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- Patients unable to give consent because of a language barrier, or other reason."
#     }
#   }
# }
# NCT03860233_inc.json
# {
#   "OR": {
#     "left": {
#       "raw_text": "- Men"
#     },
#     "right": {
#       "raw_text": "or women 18 years of age or older."
#     }
#   }
# }
# NCT03860246_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "raw_text": "- prior diagnosis of AF"
#         },
#         "right": {
#           "raw_text": "- continuous rhythm monitoring over the past year"
#         }
#       }
#     },
#     "right": {
#       "OR": {
#         "left": {
#           "raw_text": "- pacemaker"
#         },
#         "right": {
#           "raw_text": "or implantable cardioverter defibrillator in situ"
#         }
#       }
#     }
#   }
# }
# NCT03860246_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "AND": {
#                     "left": {
#                       "AND": {
#                         "left": {
#                           "AND": {
#                             "left": {
#                               "AND": {
#                                 "left": {
#                                   "raw_text": "Nursing home residents with \u22652 of the following risk factors for atrial fibrillation:"
#                                 },
#                                 "right": {
#                                   "raw_text": "- age \u226575 years"
#                                 }
#                               }
#                             },
#                             "right": {
#                               "raw_text": "- female sex"
#                             }
#                           }
#                         },
#                         "right": {
#                           "raw_text": "- obstructive sleep apnea"
#                         }
#                       }
#                     },
#                     "right": {
#                       "raw_text": "- peripheral vascular disease"
#                     }
#                   }
#                 },
#                 "right": {
#                   "raw_text": "- diabetes mellitus"
#                 }
#               }
#             },
#             "right": {
#               "raw_text": "- obesity (body mass index [BMI] >30 kg/m2)"
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- hypertension"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- congestive heart failure"
#     }
#   }
# }
# NCT03860259_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "AND": {
#                     "left": {
#                       "raw_text": "1. Opioid dependence"
#                     },
#                     "right": {
#                       "raw_text": "2. Any subject diagnosed with a chronic pain condition which daily opioid use is needed"
#                     }
#                   }
#                 },
#                 "right": {
#                   "raw_text": "3. Anatomical malformation, which in the investigator's opinion may interfere with the placement of the nerve block"
#                 }
#               }
#             },
#             "right": {
#               "raw_text": "4. Raynaud's disease diagnosis"
#             }
#           }
#         },
#         "right": {
#           "raw_text": "5. Vasculopathy"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "6. Patient refusal"
#     }
#   }
# }
# NCT03860259_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "raw_text": "1. Subject is greater than 18 years of age"
#             },
#             "right": {
#               "raw_text": "2. Subject is willing and able to provide informed consent"
#             }
#           }
#         },
#         "right": {
#           "raw_text": "3. Subject is scheduled to undergo elective rotator cuff surgery"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "4. Subject has consented to an interscalene block"
#     }
#   }
# }
# NCT03860311_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "raw_text": "- Pregnancy (known)"
#                 },
#                 "right": {
#                   "raw_text": "- Critically ill patients"
#                 }
#               }
#             },
#             "right": {
#               "OR": {
#                 "left": {
#                   "raw_text": "- Patients with known renal"
#                 },
#                 "right": {
#                   "OR": {
#                     "left": {
#                       "raw_text": "or genitourinary structural abnormalities"
#                     },
#                     "right": {
#                       "OR": {
#                         "left": {
#                           "raw_text": "or prior pelvic/"
#                         },
#                         "right": {
#                           "raw_text": "genitourinary surgery"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- Chronic renal disease"
#         }
#       }
#     },
#     "right": {
#       "AND": {
#         "left": {
#           "raw_text": "- Patients presenting"
#         },
#         "right": {
#           "NOT": {
#             "left": {
#               "raw_text": "outside the defined treatment windows"
#             }
#           }
#         }
#       }
#     }
#   }
# }
# NCT03860311_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "raw_text": "- Age 8yr-18yrs"
#             },
#             "right": {
#               "raw_text": "- Female"
#             }
#           }
#         },
#         "right": {
#           "OR": {
#             "left": {
#               "raw_text": "- Likely to have order placed for transabdominal pelvic ultrasound/"
#             },
#             "right": {
#               "raw_text": "ovarian ultrasound"
#             }
#           }
#         }
#       }
#     },
#     "right": {
#       "AND": {
#         "left": {
#           "raw_text": "-"
#         },
#         "right": {
#           "NOT": {
#             "left": {
#               "OR": {
#                 "left": {
#                   "raw_text": "No history of pelvic"
#                 },
#                 "right": {
#                   "raw_text": "or bladder reconstructive surgery"
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# NCT03860324_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "AND": {
#                     "left": {
#                       "AND": {
#                         "left": {
#                           "AND": {
#                             "left": {
#                               "AND": {
#                                 "left": {
#                                   "AND": {
#                                     "left": {
#                                       "raw_text": "- Patient refusal"
#                                     },
#                                     "right": {
#                                       "raw_text": "- BMI > 40 kg/m2"
#                                     }
#                                   }
#                                 },
#                                 "right": {
#                                   "raw_text": "- Surgical plan for revision of hip replacement"
#                                 }
#                               }
#                             },
#                             "right": {
#                               "AND": {
#                                 "left": {
#                                   "raw_text": "- Patient"
#                                 },
#                                 "right": {
#                                   "NOT": {
#                                     "left": {
#                                       "raw_text": "unable to quantify pain level"
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         },
#                         "right": {
#                           "AND": {
#                             "left": {
#                               "raw_text": "- Chronic kidney disease"
#                             },
#                             "right": {
#                               "raw_text": "with a Glomerular Filtration Rate < 50ml/min"
#                             }
#                           }
#                         }
#                       }
#                     },
#                     "right": {
#                       "raw_text": "- Previously medicated with opioids"
#                     }
#                   }
#                 },
#                 "right": {
#                   "AND": {
#                     "left": {
#                       "raw_text": "- Patient"
#                     },
#                     "right": {
#                       "NOT": {
#                         "left": {
#                           "raw_text": "unable to perform the surgery with spinal block"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             },
#             "right": {
#               "raw_text": "- Allergy to local anesthetics"
#             }
#           }
#         },
#         "right": {
#           "OR": {
#             "left": {
#               "raw_text": "- Infection in the site of the Erector Spinae Plane"
#             },
#             "right": {
#               "raw_text": "or Fascia Iliaca block"
#             }
#           }
#         }
#       }
#     },
#     "right": {
#       "OR": {
#         "left": {
#           "raw_text": "- Allergy"
#         },
#         "right": {
#           "raw_text": "or contraindication to the use of morphine"
#         }
#       }
#     }
#   }
# }
# NCT03860324_inc.json
# {
#   "AND": {
#     "left": {
#       "raw_text": "- Surgical plan for total hip replacement"
#     },
#     "right": {
#       "raw_text": "- Signing of consent form to participate in the study"
#     }
#   }
# }
# NCT03860337_exc.json
# {
#   "OR": {
#     "left": {
#       "raw_text": "- pregnant"
#     },
#     "right": {
#       "raw_text": "or lactating."
#     }
#   }
# }
# NCT03860337_inc.json
# {
#   "raw_text": "-"
# }
# NCT03860350_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "AND": {
#                     "left": {
#                       "AND": {
#                         "left": {
#                           "AND": {
#                             "left": {
#                               "AND": {
#                                 "left": {
#                                   "AND": {
#                                     "left": {
#                                       "AND": {
#                                         "left": {
#                                           "AND": {
#                                             "left": {
#                                               "AND": {
#                                                 "left": {
#                                                   "AND": {
#                                                     "left": {
#                                                       "AND": {
#                                                         "left": {
#                                                           "AND": {
#                                                             "left": {
#                                                               "AND": {
#                                                                 "left": {
#                                                                   "AND": {
#                                                                     "left": {
#                                                                       "AND": {
#                                                                         "left": {
#                                                                           "raw_text": "- Hypersensitivity to AGE therapy,"
#                                                                         },
#                                                                         "right": {
#                                                                           "OR": {
#                                                                             "left": {
#                                                                               "raw_text": "- Unstable medical,"
#                                                                             },
#                                                                             "right": {
#                                                                               "OR": {
#                                                                                 "left": {
#                                                                                   "raw_text": "psychiatric,"
#                                                                                 },
#                                                                                 "right": {
#                                                                                   "raw_text": "or substance abuse disorder that may interfere with continuation in the study,"
#                                                                                 }
#                                                                               }
#                                                                             }
#                                                                           }
#                                                                         }
#                                                                       }
#                                                                     },
#                                                                     "right": {
#                                                                       "raw_text": "- Weight \u2265325 pounds,"
#                                                                     }
#                                                                   }
#                                                                 },
#                                                                 "right": {
#                                                                   "raw_text": "- Bleeding disorder,"
#                                                                 }
#                                                               }
#                                                             },
#                                                             "right": {
#                                                               "raw_text": "- History of myocardial infarction,"
#                                                             }
#                                                           }
#                                                         },
#                                                         "right": {
#                                                           "raw_text": "- Stroke"
#                                                         }
#                                                       }
#                                                     },
#                                                     "right": {
#                                                       "raw_text": "- Life-threatening arrhythmia within prior 6 months,"
#                                                     }
#                                                   }
#                                                 },
#                                                 "right": {
#                                                   "OR": {
#                                                     "left": {
#                                                       "raw_text": "- Resting hypotension"
#                                                     },
#                                                     "right": {
#                                                       "raw_text": "(systolic < 90 mmHg) or hypertension (resting blood pressure >170/110)"
#                                                     }
#                                                   }
#                                                 }
#                                               }
#                                             },
#                                             "right": {
#                                               "raw_text": "- Heart failure NYHA class III or IV,"
#                                             }
#                                           }
#                                         },
#                                         "right": {
#                                           "OR": {
#                                             "left": {
#                                               "raw_text": "- History of malignancy"
#                                             },
#                                             "right": {
#                                               "raw_text": "within the last 5 years (other than skin cancer) or evidence of active cancer which would require concomitant cancer chemotherapy"
#                                             }
#                                           }
#                                         }
#                                       }
#                                     },
#                                     "right": {
#                                       "raw_text": "- Serum creatinine >1.4 mg/dl"
#                                     }
#                                   }
#                                 },
#                                 "right": {
#                                   "raw_text": "- Triglycerides > 400 at baseline visit"
#                                 }
#                               }
#                             },
#                             "right": {
#                               "raw_text": "- Diabetic subjects with HbA1C > 8 %,"
#                             }
#                           }
#                         },
#                         "right": {
#                           "OR": {
#                             "left": {
#                               "raw_text": "- Drug"
#                             },
#                             "right": {
#                               "raw_text": "or alcohol abuse"
#                             }
#                           }
#                         }
#                       }
#                     },
#                     "right": {
#                       "OR": {
#                         "left": {
#                           "raw_text": "- Conditions interfering with accurate assessment of coronary calcification"
#                         },
#                         "right": {
#                           "OR": {
#                             "left": {
#                               "raw_text": "(metal clips,"
#                             },
#                             "right": {
#                               "OR": {
#                                 "left": {
#                                   "raw_text": "bypass patients, intracoronary stents) and drug absorption (partial ileal bypass"
#                                 },
#                                 "right": {
#                                   "raw_text": "or malabsorption syndrome)."
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "right": {
#                   "raw_text": "- Current use of anticoagulants (except for antiplatelet agents)"
#                 }
#               }
#             },
#             "right": {
#               "raw_text": "- Chronic renal failure"
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- Liver failure"
#         }
#       }
#     },
#     "right": {
#       "OR": {
#         "left": {
#           "raw_text": "- Hematological"
#         },
#         "right": {
#           "raw_text": "or biochemical values at baseline visit outside the reference ranges considered as clinically significant."
#         }
#       }
#     }
#   }
# }
# NCT03860350_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "raw_text": "- CAC score >10"
#             },
#             "right": {
#               "raw_text": "- Framingham risk score (10 % or above)"
#             }
#           }
#         },
#         "right": {
# ...
#       "raw_text": "- patient under chronic dialysis"
#     },
#     "right": {
#       "raw_text": "- patient placed under judicial protection"
#     }
#   }
# }
# NCT03927079_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "raw_text": "- patients who undergo a flexible bronchoscopic lavage"
#             },
#             "right": {
#               "OR": {
#                 "left": {
#                   "raw_text": "and with a beta lactamines treatment as cephalosporin of 3rd generation (CEFTRIAXONE"
#                 },
#                 "right": {
#                   "OR": {
#                     "left": {
#                       "raw_text": "/ CEFOTAXIME,"
#                     },
#                     "right": {
#                       "OR": {
#                         "left": {
#                           "raw_text": "CEFTAZIDIME), of 4th generation (CEFEPIM),"
#                         },
#                         "right": {
#                           "OR": {
#                             "left": {
#                               "raw_text": "or AMOXICILLIN-CLAVULANIC ACID,"
#                             },
#                             "right": {
#                               "raw_text": "or PIPERACILLIN-TAZOBACTAM"
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- patient major"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- informed and signed consent form"
#     }
#   }
# }
# NCT03927092_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "raw_text": "- Does"
#         },
#         "right": {
#           "NOT": {
#             "left": {
#               "raw_text": "not accept to answer the questionnaire"
#             }
#           }
#         }
#       }
#     },
#     "right": {
#       "AND": {
#         "left": {
#           "raw_text": "-"
#         },
#         "right": {
#           "NOT": {
#             "left": {
#               "raw_text": "Unable to answer the questions due to a cognitive impairment"
#             }
#           }
#         }
#       }
#     }
#   }
# }
# NCT03927092_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "raw_text": "- Diagnosed as having Multiple Sclerosis"
#             },
#             "right": {
#               "raw_text": "- Attends the annual patient education seminar at the investigators' university hospital"
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- Older than 18 years of age"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- Can read and write"
#     }
#   }
# }
# NCT03927118_exc.json
# {
#   "raw_text": "empty set"
# }
# NCT03927118_inc.json
# {
#   "raw_text": "empty set"
# }
# NCT03927274_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "AND": {
#                     "left": {
#                       "AND": {
#                         "left": {
#                           "AND": {
#                             "left": {
#                               "AND": {
#                                 "left": {
#                                   "AND": {
#                                     "left": {
#                                       "AND": {
#                                         "left": {
#                                           "AND": {
#                                             "left": {
#                                               "AND": {
#                                                 "left": {
#                                                   "OR": {
#                                                     "left": {
#                                                       "raw_text": "- Participant is mentally"
#                                                     },
#                                                     "right": {
#                                                       "raw_text": "or legally incapacitated at the time of the study;"
#                                                     }
#                                                   }
#                                                 },
#                                                 "right": {
#                                                   "OR": {
#                                                     "left": {
#                                                       "raw_text": "- Known HIV(+)"
#                                                     },
#                                                     "right": {
#                                                       "raw_text": "or has been diagnosed with AIDS"
#                                                     }
#                                                   }
#                                                 }
#                                               }
#                                             },
#                                             "right": {
#                                               "raw_text": "- Participation in another investigational drug study in the prior 4 weeks"
#                                             }
#                                           }
#                                         },
#                                         "right": {
#                                           "raw_text": "- Positive pregnancy test in a female"
#                                         }
#                                       }
#                                     },
#                                     "right": {
#                                       "raw_text": "- Patient, in the opinion of the investigator, is likely to be poorly compliant."
#                                     }
#                                   }
#                                 },
#                                 "right": {
#                                   "OR": {
#                                     "left": {
#                                       "raw_text": "- Diffuse subependymal"
#                                     },
#                                     "right": {
#                                       "raw_text": "or Cerebral Spinal Fluid (CSF) disease"
#                                     }
#                                   }
#                                 }
#                               }
#                             },
#                             "right": {
#                               "raw_text": "- Tumors involving the cerebellum"
#                             }
#                           }
#                         },
#                         "right": {
#                           "raw_text": "- Tumor enhancement involving both hemispheres"
#                         }
#                       }
#                     },
#                     "right": {
#                       "raw_text": "- Active infection requiring treatment"
#                     }
#                   }
#                 },
#                 "right": {
#                   "raw_text": "- Unexplained febrile illness"
#                 }
#               }
#             },
#             "right": {
#               "OR": {
#                 "left": {
#                   "raw_text": "- Radiation"
#                 },
#                 "right": {
#                   "raw_text": "or chemotherapy within 4 weeks of enrollment"
#                 }
#               }
#             }
#           }
#         },
#         "right": {
#           "OR": {
#             "left": {
#               "raw_text": "- Systemic diseases associated with unacceptable anesthesia"
#             },
#             "right": {
#               "raw_text": "or operative risk"
#             }
#           }
#         }
#       }
#     },
#     "right": {
#       "AND": {
#         "left": {
#           "raw_text": "-"
#         },
#         "right": {
#           "NOT": {
#             "left": {
#               "raw_text": "Inability to undergo magnetic resonance imaging (MRI)"
#             }
#           }
#         }
#       }
#     }
#   }
# }
# NCT03927274_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "AND": {
#                     "left": {
#                       "AND": {
#                         "left": {
#                           "raw_text": "- Histologically confirmed diagnosis of supratentorial WHO Grade III or IV Glioma (High Grade Glioma)"
#                         },
#                         "right": {
#                           "OR": {
#                             "left": {
#                               "raw_text": "that has undergone surgical biopsy"
#                             },
#                             "right": {
#                               "AND": {
#                                 "left": {
#                                   "raw_text": "or resection followed by adjuvant chemoradiotherapy,"
#                                 },
#                                 "right": {
#                                   "OR": {
#                                     "left": {
#                                       "raw_text": "that has evidence of recurrence"
#                                     },
#                                     "right": {
#                                       "AND": {
#                                         "left": {
#                                           "raw_text": "or progression based on imaging studies"
#                                         },
#                                         "right": {
#                                           "OR": {
#                                             "left": {
#                                               "raw_text": "and a stereotactic biopsy is indicated for confirmation of recurrence/"
#                                             },
#                                             "right": {
#                                               "raw_text": "progression."
#                                             }
#                                           }
#                                         }
#                                       }
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     },
#                     "right": {
#                       "raw_text": "- 18 years of age or older"
#                     }
#                   }
#                 },
#                 "right": {
#                   "raw_text": "- Karnofsky Performance Status 70-100;"
#                 }
#               }
#             },
#             "right": {
#               "OR": {
#                 "left": {
#                   "raw_text": "- MRI demonstration of a stereotactically accessible enhancing"
#                 },
#                 "right": {
#                   "AND": {
#                     "left": {
#                       "raw_text": "or predominantly non- enhancing mass"
#                     },
#                     "right": {
#                       "AND": {
#                         "left": {
#                           "raw_text": "that does"
#                         },
#                         "right": {
#                           "NOT": {
#                             "left": {
#                               "raw_text": "not require resection to relieve clinically significant mass effect;"
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- Participant understands the procedures and agrees to comply with the study requirements by providing written informed consent"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- Adequate organ function as indicated in protocol"
#     }
#   }
# }
# NCT03927287_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "raw_text": "1. Patients that were younger than 18,"
#             },
#             "right": {
#               "OR": {
#                 "left": {
#                   "raw_text": "2. Patients with prostate cancer other than adenocarcinoma, such as small cell"
#                 },
#                 "right": {
#                   "raw_text": "and neuroendocrine cancer"
#                 }
#               }
#             }
#           }
#         },
#         "right": {
#           "AND": {
#             "left": {
#               "raw_text": "3. Patients with prostate adenocarcinoma"
#             },
#             "right": {
#               "AND": {
#                 "left": {
#                   "raw_text": "that did"
#                 },
#                 "right": {
#                   "NOT": {
#                     "left": {
#                       "raw_text": "not develop biochemical recurrence."
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     },
#     "right": {
#       "AND": {
#         "left": {
#           "raw_text": "4. In the retrospective cohorts - patients that did"
#         },
#         "right": {
#           "NOT": {
#             "left": {
#               "raw_text": "not have at least one post-treatment free PSA blood test."
#             }
#           }
#         }
#       }
#     }
#   }
# }
# NCT03927287_inc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "AND": {
#                 "left": {
#                   "raw_text": "For the two retrospective cohorts:"
#                 },
#                 "right": {
#                   "OR": {
#                     "left": {
#                       "raw_text": "1. All patients that older than 18 treated for localized adenocarcinoma of the prostate between 2000 and 2017 with either radical prostatectomy"
#                     },
#                     "right": {
#                       "raw_text": "or radiotherapy"
#                     }
#                   }
#                 }
#               }
#             },
#             "right": {
#               "AND": {
#                 "left": {
#                   "raw_text": "2. All treated patients had a rising post-treatment PSA,"
#                 },
#                 "right": {
#                   "raw_text": "with at least one post-treatment free PSA blood test."
#                 }
#               }
#             }
#           }
#         },
#         "right": {
#           "raw_text": "For the biobank validation cohort:"
#         }
#       }
#     },
#     "right": {
#       "AND": {
#         "left": {
#           "raw_text": "1. All patients treated"
#         },
#         "right": {
#           "raw_text": "with radical prostatectomy for localized prostate cancer between 2000 and 2017 who had biobank samples taken when developing biochemical recurrence."
#         }
#       }
#     }
#   }
# }
# NCT03927300_exc.json
# {
#   "AND": {
#     "left": {
#       "AND": {
#         "left": {
#           "AND": {
#             "left": {
#               "raw_text": "- Patients who have started a peritoneal dialysis program before the periods of investigation;"
#             },
#             "right": {
#               "raw_text": "- Patients who have been equipped with apTeleCare during the dialysis program;"
#             }
#           }
#         },
#         "right": {
#           "raw_text": "- Subject under guardianship, curators or safeguard of justice;"
#         }
#       }
#     },
#     "right": {
#       "raw_text": "- Patient not affiliated to a French social protection;"
#     }
#   }
# }
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
