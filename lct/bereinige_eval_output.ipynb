# %%
import os

# %%
def process_files(base_directory):
    eval_directories = [d for d in os.listdir(base_directory) if d.startswith("eval_")]
    print(eval_directories)
    for eval_directory in eval_directories:
        eval_path = os.path.join(base_directory, eval_directory)
        model_output_directories = [d for d in os.listdir(eval_path) if d.startswith("model_output")]
        print(model_output_directories)
        for model_output_directory in model_output_directories:
            model_output_path = os.path.join(eval_path, model_output_directory)
            for root, dirs, files in os.walk(model_output_path):
                if "output" in dirs:
                    output_path = os.path.join(root, "output")
                    print(output_path)
                    print(f"Processing directory: {output_path}")
                    for file in os.listdir(output_path):
                        if file.endswith(".txt"):
                            file_path = os.path.join(output_path, file)
                            process_file(file_path)

def process_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    start_tag = "<EDITED_CRITERIA>"
    end_tag = "</EDITED_CRITERIA>"
    start_index = content.find(start_tag)
    end_index = content.find(end_tag)

    if start_index != -1 and end_index != -1:
        start_index += len(start_tag)
        extracted_content = content[start_index:end_index].strip()
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(extracted_content)

# %%
# Beispielaufruf
base_directory = "C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate"  # Ersetze durch das Verzeichnis, das du durchsuchen möchtest
process_files(base_directory)
# Out:
# ['eval_p1', 'eval_p1_0_shot', 'eval_p1_0_shot_temp', 'eval_p1_0_shot_top', 'eval_p1_finetuned', 'eval_p1_finetuned_testset', 'eval_p1_n_shot', 'eval_p3']
# ['model_output']
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1\model_output\ Naive greedy match\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1\model_output\ Naive greedy match\output
# ['model_output']
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_1\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_1\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_1_p1\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_1_p1\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_2\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_2\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_3\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_3\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_p1\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_p1\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_p6\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_p6\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_p6_cot\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_p6_cot\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_4\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_4\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_5\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_5\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_6_p6\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_6_p6\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_6_p6_cot\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_6_p6_cot\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_7\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_7\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_7_p6\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_7_p6\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_8\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_8\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_8_p6\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot\model_output\Llama-3-70B-Instruct_0_shot_prompt_8_p6\output
# ['model_output']
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_temp\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_temp_2\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_temp\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_temp_2\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_temp\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_temp_4\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_temp\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_temp_4\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_temp\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_temp_5\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_temp\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_temp_5\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_temp\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_temp_5.5\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_temp\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_temp_5.5\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_temp\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_temp_6\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_temp\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_temp_6\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_temp\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_temp_8\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_temp\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_temp_8\output
# ['model_output']
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_top\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_top_0.7\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_top\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_top_0.7\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_top\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_top_0.8\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_top\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_top_0.8\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_top\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_top_0.9\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_top\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_top_0.9\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_top\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_top_0.95\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_top\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_top_0.95\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_top\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_top_0.98\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_0_shot_top\model_output\Llama-3-70B-Instruct_0_shot_prompt_3_top_0.98\output
# ['model_output']
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned\model_output\Llama-3-8B-Instruct_5_shot_prompt_1\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned\model_output\Llama-3-8B-Instruct_5_shot_prompt_1\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned\model_output\Llama-3-8B-Tuned_LORA_0_shot_prompt_1\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned\model_output\Llama-3-8B-Tuned_LORA_0_shot_prompt_1\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned\model_output\llama3_8b_lora_model_ep10_0_shot_prompt_1\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned\model_output\llama3_8b_lora_model_ep10_0_shot_prompt_1\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned\model_output\llama3_8b_lora_model_ep1_0_shot_prompt_1\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned\model_output\llama3_8b_lora_model_ep1_0_shot_prompt_1\output
# ['model_output']
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned_testset\model_output\ Naive greedy match\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned_testset\model_output\ Naive greedy match\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned_testset\model_output\Llama-3-70B-Instruct_0_shot_p1_p6\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned_testset\model_output\Llama-3-70B-Instruct_0_shot_p1_p6\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned_testset\model_output\Llama-3-70B-Instruct_5_shot_p1_p6\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned_testset\model_output\Llama-3-70B-Instruct_5_shot_p1_p6\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned_testset\model_output\Llama3_8b_Lora_ep10_p_1\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned_testset\model_output\Llama3_8b_Lora_ep10_p_1\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned_testset\model_output\llama3_8b_lora_model_ep10_prompt_1\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_finetuned_testset\model_output\llama3_8b_lora_model_ep10_prompt_1\output
# ['model_output']
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_n_shot\model_output\Llama-3-70B-Instruct-Gradient_15_shot\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_n_shot\model_output\Llama-3-70B-Instruct-Gradient_15_shot\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_n_shot\model_output\Llama-3-70B-Instruct_5_shot\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_n_shot\model_output\Llama-3-70B-Instruct_5_shot\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_n_shot\model_output\Llama-3-8B-Instruct-Gradient-1048k_15_shot\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_n_shot\model_output\Llama-3-8B-Instruct-Gradient-1048k_15_shot\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_n_shot\model_output\Llama-3-8B-Instruct_5_shot\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_n_shot\model_output\Llama-3-8B-Instruct_5_shot\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_n_shot\model_output\OpenBioLLM-Llama3-70B_5_shot\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_n_shot\model_output\OpenBioLLM-Llama3-70B_5_shot\output
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_n_shot\model_output\OpenBioLLM-Llama3-8B_5_shot\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p1_n_shot\model_output\OpenBioLLM-Llama3-8B_5_shot\output
# ['model_output']
# C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p3\model_output\Llama-3-70B-Instruct_3_shot\output
# Processing directory: C://Users//e-aut//DataspellProjects//ec_criteria_struct//lct//evaluate\eval_p3\model_output\Llama-3-70B-Instruct_3_shot\output
