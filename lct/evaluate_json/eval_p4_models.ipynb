# %%
from struct_eval_functions import *
from struct_plot_funcitons import *

# %% [markdown]
# ### JSON to Text

# %%
def process_node(node):
    if 'raw_text' in node:
        return node['raw_text'].strip()
    if 'AND' in node:
        left_text = process_node(node['AND']['left'])
        right_text = process_node(node['AND']['right'])
        return combine_texts(left_text, right_text, '[AND]')
    if 'OR' in node:
        left_text = process_node(node['OR']['left'])
        right_text = process_node(node['OR']['right'])
        return combine_texts(left_text, right_text, '[OR]')
    if 'NOT' in node:
        left_text = process_node(node['NOT']['left'])
        return f"[NOT] {left_text}"

    return ""

def combine_texts(left_text, right_text, operator):
    combined = f"{left_text.strip()} {operator} {right_text.strip()}"
    if operator == '[AND]' and not right_text.strip():
        return combined + '\n'
    return combined


def json_to_text(json_file_path):
    with open(json_file_path, 'r', encoding="utf-8") as f:
        data = json.load(f)
    text = process_node(data)
    lines = [line.strip() for line in text.split('\n') if line.strip()]
    return '\n'.join(lines)

def process_all_files_in_directory(directory_path, output_directory, failure_directory):
    os.makedirs(output_directory, exist_ok=True)
    os.makedirs(failure_directory, exist_ok=True)
    for filename in os.listdir(directory_path):
        if filename.endswith("_exc.json") or filename.endswith("_inc.json"):
            json_file_path = os.path.join(directory_path, filename)
            try:
                output_text = json_to_text(json_file_path)
                output_file_path = os.path.join(output_directory, os.path.splitext(filename)[0] + ".txt")
                with open(output_file_path, 'w', encoding="utf-8") as output_file:
                    output_file.write(output_text)
            except Exception as e:
                shutil.move(json_file_path, os.path.join(failure_directory, filename))

# %% [markdown]
# ## Calculate Entity Metrics

# %%
def visit(node, category, entities):
    if isinstance(node, dict):
        if category in node:
            entities.extend(node[category])
        for value in node.values():
            visit(value, category, entities)
    elif isinstance(node, list):
        for item in node:
            visit(item, category, entities)

def calculate_metrics(label_data, model_data, metrics):
    for category in categories:
        label_entities = []
        visit(label_data, category, label_entities)
        model_entities = []
        visit(model_data, category, model_entities)
        true_positives = sum(entity in label_entities for entity in model_entities)
        false_positives = sum(entity not in label_entities for entity in model_entities)
        false_negatives = sum(entity not in model_entities for entity in label_entities)
        metrics[category]['true_positives'] += true_positives
        metrics[category]['false_positives'] += false_positives
        metrics[category]['false_negatives'] += false_negatives
        # Count total entities in labels and model outputs
        metrics[category]['total_label_entities'] += len(label_entities)
        metrics[category]['total_model_entities'] += len(model_entities)

def process_files(label_folder, model_folder):
    metrics = {category: {'true_positives': 0, 'false_positives': 0, 'false_negatives': 0,
                          'total_label_entities': 0, 'total_model_entities': 0} for category in categories}
    for filename in os.listdir(model_folder):
        if filename.endswith('.json'):
            model_path = os.path.join(model_folder, filename)
            match = re.search(r'NCT\d+_(?:exc|inc)', filename)
            if match:
                label_filename = f"{match.group(0)}.json"
                label_path = os.path.join(label_folder, label_filename)

                if os.path.exists(label_path):
                    try:
                        with open(label_path, 'r', encoding='utf-8') as label_file, open(model_path, 'r', encoding='utf-8') as model_file:
                            label_data = json.load(label_file)
                            model_data = json.load(model_file)
                            calculate_metrics(label_data, model_data, metrics)
                    except json.JSONDecodeError as e:
                        print(f"Error decoding JSON file: {model_path}")
                        print(f"Error message: {str(e)}")

    for category in categories:
        true_positives = metrics[category]['true_positives']
        false_positives = metrics[category]['false_positives']
        false_negatives = metrics[category]['false_negatives']
        precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        accuracy = true_positives / (true_positives + false_positives + false_negatives) if (true_positives + false_positives + false_negatives) > 0 else 0

        metrics[category]['precision'] = precision
        metrics[category]['recall'] = recall
        metrics[category]['f1'] = f1
        metrics[category]['accuracy'] = accuracy
    return metrics

# %%
batch_path = "eval_p4"
label_folder = "../input/lct_p4" # ../input/dataset_p4/test/output"
models = get_models(f'{batch_path}/model_output/')
print(models)
models = [models[6]]
models
# Out:
# ['GPT-4o_10_shot_short_files', 'GPT-4o_25_shot_short_files', 'GPT-4o_2_shot_short_files', 'Llama-3-70B-Instruct_10_Shot_short_files', 'Llama-3-70B-Instruct_2_Shot_short_files', 'llama3_70b_Lora_ep10_r256_prompt1_train_only_p4', 'llama3_8b_Lora_ep10_r256_prompt1_train_only_p4', 'Qwen2-72B_10_Shot_short_files', 'Qwen2-72B_25_Shot_short_files', 'Qwen2-72B_2_Shot_short_files']
# ['llama3_8b_Lora_ep10_r256_prompt1_train_only_p4']

# %%
categories =  ['Contraindication', 'Eq-Value', 'Severity', 'Drug', 'Observation-Name', 'Age', 'Location', 'Organism-Name', 'Encounter', 'Drug-Name', 'Ethnicity', 'Modifier', 'Condition', 'Eq-Unit', 'Eq-Temporal-Unit', 'Family-Member', 'Organism', 'Other', 'Immunization-Name', 'Polarity', 'Condition-Type', 'Immunization', 'Eq-Operator', 'Eq-Temporal-Recency', 'Procedure-Name', 'Indication', 'Exception', 'Study', 'Language', 'Coreference', 'Provider', 'Acuteness', 'Life-Stage-And-Gender', 'Procedure', 'Risk', 'Death', 'Assertion', 'Allergy-Name', 'Specimen', 'Negation', 'Code', 'Stability', 'Birth', 'Criteria-Count', 'Eq-Comparison', 'Condition-Name', 'Insurance', 'Observation', 'Allergy', 'Eq-Temporal-Period']

# %%
# Berechne den Durchschnitt der Metriken für alle Entitäten
def calculate_average_metrics(metrics):
    total_metrics = {
        'true_positives': 0,
        'false_positives': 0,
        'false_negatives': 0,
        'total_label_entities': 0,
        'total_model_entities': 0,
        'precision': 0,
        'recall': 0,
        'f1': 0,
        'accuracy': 0
    }
    num_entities = 50
    for entity, entity_metrics in metrics.items():
        if entity != 'total':
            for key in total_metrics.keys():
                total_metrics[key] += entity_metrics[key]
    for key in ['precision', 'recall', 'f1', 'accuracy']:
        total_metrics[key] /= num_entities

    metrics['total'] = total_metrics
    return metrics

def calculate_totals_based_on_tp(metrics):
    total_tp = 0
    total_fp = 0
    total_fn = 0
    valid_entities_count = 0

    for entity, values in metrics.items():
        if entity != 'total':
            total_tp += values['true_positives']
            total_fp += values['false_positives']
            total_fn += values['false_negatives']
            valid_entities_count += 1

    total_precision = total_tp / (total_tp + total_fp) if (total_tp + total_fp) > 0 else 0
    total_recall = total_tp / (total_tp + total_fn) if (total_tp + total_fn) > 0 else 0
    total_f1 = 2 * (total_precision * total_recall) / (total_precision + total_recall) if (total_precision + total_recall) > 0 else 0

    metrics['total'] = {
        'true_positives': total_tp,
        'false_positives': total_fp,
        'false_negatives': total_fn,
        'precision': total_precision,
        'recall': total_recall,
        'f1': total_f1
    }

    return metrics

# %% [markdown]
# #### Filter failure model files

# %%
for model_name in models:
    model_folder = f"{batch_path}/model_output/{model_name}/output"
    ready_folder = f"{batch_path}/model_output/{model_name}/ready"
    failure_folder = f"{batch_path}/model_output/{model_name}/failure"
    process_failure_folder = f"{batch_path}/model_output/{model_name}/processed_output"
    
    ## Filter Failure Files
    read_and_process_files(model_path="eval_p4/model_output" ,model_name=model_name)

    ## JSON to Text
    process_all_files_in_directory(ready_folder, process_failure_folder, failure_folder)

    ## Calculate Entity Metrics
    metrics = process_files(label_folder, ready_folder)
    metrics = calculate_totals_based_on_tp(metrics)
# Out:
# JSON syntax error in file: llama3_8b_Lora_ep10_r256_prompt1_train_only_p4_NCT03867305_exc.json - Error: Unterminated string starting at: line 410 column 25 (char 19744)
# JSON syntax error in file: llama3_8b_Lora_ep10_r256_prompt1_train_only_p4_NCT03869372_exc.json - Error: Unterminated string starting at: line 422 column 9 (char 17206)
# JSON syntax error in file: llama3_8b_Lora_ep10_r256_prompt1_train_only_p4_NCT03925142_exc.json - Error: Expecting property name enclosed in double quotes: line 431 column 17 (char 24007)
# JSON syntax error in file: llama3_8b_Lora_ep10_r256_prompt1_train_only_p4_NCT03925142_inc.json - Error: Expecting ',' delimiter: line 432 column 21 (char 20625)
# JSON syntax error in file: llama3_8b_Lora_ep10_r256_prompt1_train_only_p4_NCT03925454_exc.json - Error: Unterminated string starting at: line 420 column 13 (char 21724)

# %%
## Ausgabe Entitys F1 = 0
zero_f1_entities = {}
for entity, values in metrics.items():
    if entity != 'total' and values['f1'] == 0:
        zero_f1_entities[entity] = values
zero_f1_entities
# Out:
# {'Immunization-Name': {'true_positives': 0,
#   'false_positives': 0,
#   'false_negatives': 3,
#   'total_label_entities': 3,
#   'total_model_entities': 0,
#   'precision': 0,
#   'recall': 0.0,
#   'f1': 0,
#   'accuracy': 0.0},
#  'Criteria-Count': {'true_positives': 0,
#   'false_positives': 0,
#   'false_negatives': 1,
#   'total_label_entities': 1,
#   'total_model_entities': 0,
#   'precision': 0,
#   'recall': 0.0,
#   'f1': 0,
#   'accuracy': 0.0}}

# %% [markdown]
# #### Anzahl der Fehler in der Modelausgabe

# %%
plot_file_counts(model_name, batch_name=batch_path)

# %%
def latex_file_counts_table(model_name, batch_name):
    model_folder_count, ready_folder_count, failure_folder_count, struct_failure_folder_count = count_files(model_name, batch_name)
    total_files = model_folder_count

    latex_table = f"""
\\begin{{table}}[!ht]
\\centering
\\begin{{tabular}}{{lrr}}
\\toprule
\\textbf{{Kategorie}} & \\textbf{{Anzahl}} & \\textbf{{Prozent}} \\\\
\\midrule
Ausgabe & {model_folder_count} & 100.0\\% \\\\
Korrekt & {ready_folder_count} & {(ready_folder_count / total_files * 100):.1f}\\% \\\\
Parse Fehler & {failure_folder_count} & {(failure_folder_count / total_files * 100):.1f}\\% \\\\
Struktur Fehler & {struct_failure_folder_count} & {(struct_failure_folder_count / total_files * 100):.1f}\\% \\\\
\\bottomrule
\\end{{tabular}}
\\caption{{Ausgabe {model_name}}}
\\label{{tab:file_counts_{model_name.replace(" ", "_")}}}
\\end{{table}}
    """

    return latex_table

# Beispielaufruf:
print(latex_file_counts_table(model_name, batch_name=batch_path))
# Out:
# \begin{table}[!ht]
# \centering
# \begin{tabular}{lrr}
# \toprule
# \textbf{Kategorie} & \textbf{Anzahl} & \textbf{Prozent} \\
# \midrule
# Ausgabe & 404 & 100.0\% \\
# Korrekt & 399 & 98.8\% \\
# Parse Fehler & 0 & 0.0\% \\
# Struktur Fehler & 5 & 1.2\% \\
# \bottomrule
# \end{tabular}
# \caption{Ausgabe llama3_8b_Lora_ep10_r256_prompt1_train_only_p4}
# \label{tab:file_counts_llama3_8b_Lora_ep10_r256_prompt1_train_only_p4}
# \end{table}

# %%
def plot_metrics_all_entitys(model_name, metrics, categories):
    metrics_to_plot = ['precision', 'recall', 'f1']
    metric_labels = {'precision': 'P', 'recall': 'R', 'f1': 'F1'}

    # Sortiere die Kategorien nach F1-Score absteigend
    categories_sorted = sorted(categories, key=lambda x: metrics[x]['f1'], reverse=True)

    fig, ax = plt.subplots(figsize=(20, 12))  # Vergrößere die Figur

    x = np.arange(len(categories_sorted) + 1)  # +1 für die Gesamtbalken
    bar_width = 0.25
    opacity = 0.8

    for i, metric in enumerate(metrics_to_plot):
        values = [metrics[category][metric] * 100 for category in categories_sorted]
        total_value = metrics['total'][metric] * 100
        values.append(total_value)  # Füge die Gesamtwerte hinzu
        bars = ax.bar(x + i*bar_width, values, bar_width, alpha=opacity, label=f'{metric_labels[metric]}')

        for j, v in enumerate(values):
            ax.text(x[j] + i*bar_width, v + 1, f'{v:.1f}', ha='center', va='bottom', fontsize=8, rotation=90)

    ax.set_xlabel('Kategorie', fontsize=12, labelpad=10)
    ax.set_ylabel('Score (%)', fontsize=12, labelpad=10)
    ax.set_title(f'Evaluation: {model_name}', fontsize=16, pad=20)
    ax.set_xticks(x + bar_width)
    categories_sorted.append('Gesamt')  # Füge die Beschriftung für die Gesamtwerte hinzu
    ax.set_xticklabels(categories_sorted, rotation=90, ha='right', fontsize=8)
    ax.legend(loc='upper right', fontsize=10)
    ax.set_ylim(0, 105)

    plt.tight_layout()
    plt.savefig(f'data/pics/evaluation_{model_name}_all_categories.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
def plot_heatmap(model_name, metrics, categories):
    # Erstelle eine DataFrame mit den Metriken
    data = {cat: [metrics[cat]['precision'], metrics[cat]['recall'], metrics[cat]['f1']] for cat in categories}
    df = pd.DataFrame(data, index=['Precision', 'Recall', 'F1']).T
    df_sorted = df.sort_values('F1', ascending=False)

    plt.figure(figsize=(15, len(categories) * 0.3))
    sns.heatmap(df_sorted, annot=True, cmap="YlGnBu", fmt=".2f", cbar_kws={'label': 'Score'})
    plt.title(f'Metriken für {model_name}')
    plt.tight_layout()
    plt.savefig(f'data/pics/heatmap_{model_name}.png')
    plt.show()

# %%
#plot_heatmap(model_name, metrics, categories)

# %% [markdown]
# #### Model Performance

# %%
model_name = models[0]
plot_metrics_all_entitys(model_name, metrics, categories)

# %%
def generate_latex_table(model_name, metrics, categories):
    # Sortiere die Kategorien nach F1-Score absteigend
    categories_sorted = sorted(categories, key=lambda x: metrics[x]['f1'], reverse=True)

    # Beginne die LaTeX-Tabelle
    latex_table = "\\begin{table}[htbp]\n"
    latex_table += "\\centering\n"
    latex_table += "\\begin{tabular}{p{5cm}ccc}\n"  # Mehr Platz für die erste Spalte
    latex_table += "\\toprule\n"
    latex_table += "\\textbf{Kategorie} & \\textbf{Precision} & \\textbf{Recall} & \\textbf{F1-Score} \\\\\n"
    latex_table += "\\midrule\n"

    # Füge jede Kategorie mit ihren Metriken hinzu
    for category in categories_sorted:
        precision = metrics[category]['precision']
        recall = metrics[category]['recall']
        f1 = metrics[category]['f1']
        latex_table += f"{category} & {precision:.3f} & {recall:.3f} & {f1:.3f} \\\\\n"

    # Schließe die Tabelle
    latex_table += "\\bottomrule\n"
    latex_table += "\\end{tabular}\n"
    latex_table += "\\caption{Metriken für " + model_name + "}\n"  # Caption am Ende
    latex_table += "\\label{tab:metrics_" + model_name.lower().replace(" ", "_") + "}\n"
    latex_table += "\\end{table}"

    # Erstelle den 'latex' Ordner, falls er nicht existiert
    os.makedirs('latex', exist_ok=True)

    # Speichere die LaTeX-Tabelle in einer Datei im 'latex' Ordner
    file_path = f'data/latex/{model_name}_all_enitys.tex'
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(latex_table)

    return latex_table

# %%
generate_latex_table(model_name, metrics, categories)
# Out:
# '\\begin{table}[htbp]\n\\centering\n\\begin{tabular}{p{5cm}ccc}\n\\toprule\n\\textbf{Kategorie} & \\textbf{Precision} & \\textbf{Recall} & \\textbf{F1-Score} \\\\\n\\midrule\nCondition-Type & 1.000 & 1.000 & 1.000 \\\\\nIndication & 1.000 & 1.000 & 1.000 \\\\\nAllergy-Name & 1.000 & 1.000 & 1.000 \\\\\nCode & 1.000 & 1.000 & 1.000 \\\\\nLife-Stage-And-Gender & 0.993 & 0.960 & 0.976 \\\\\nAge & 0.993 & 0.948 & 0.970 \\\\\nContraindication & 1.000 & 0.941 & 0.970 \\\\\nLanguage & 1.000 & 0.929 & 0.963 \\\\\nEq-Temporal-Unit & 0.974 & 0.930 & 0.952 \\\\\nEq-Value & 0.964 & 0.934 & 0.949 \\\\\nEq-Operator & 0.967 & 0.914 & 0.939 \\\\\nSeverity & 0.960 & 0.905 & 0.931 \\\\\nFamily-Member & 1.000 & 0.867 & 0.929 \\\\\nEq-Comparison & 0.923 & 0.901 & 0.912 \\\\\nAllergy & 0.885 & 0.920 & 0.902 \\\\\nEq-Temporal-Period & 0.905 & 0.894 & 0.899 \\\\\nAcuteness & 0.889 & 0.873 & 0.881 \\\\\nBirth & 0.778 & 1.000 & 0.875 \\\\\nEq-Temporal-Recency & 0.913 & 0.840 & 0.875 \\\\\nCondition & 0.884 & 0.862 & 0.873 \\\\\nDrug & 0.864 & 0.880 & 0.872 \\\\\nDrug-Name & 0.869 & 0.874 & 0.872 \\\\\nCondition-Name & 0.880 & 0.862 & 0.871 \\\\\nStudy & 0.856 & 0.883 & 0.869 \\\\\nOther & 0.820 & 0.911 & 0.863 \\\\\nProcedure & 0.874 & 0.843 & 0.858 \\\\\nEthnicity & 1.000 & 0.750 & 0.857 \\\\\nException & 0.857 & 0.857 & 0.857 \\\\\nRisk & 1.000 & 0.750 & 0.857 \\\\\nEq-Unit & 0.838 & 0.868 & 0.853 \\\\\nNegation & 0.885 & 0.819 & 0.851 \\\\\nObservation-Name & 0.855 & 0.845 & 0.850 \\\\\nObservation & 0.859 & 0.838 & 0.848 \\\\\nProcedure-Name & 0.860 & 0.831 & 0.846 \\\\\nLocation & 0.849 & 0.839 & 0.844 \\\\\nModifier & 0.843 & 0.793 & 0.817 \\\\\nEncounter & 0.851 & 0.770 & 0.809 \\\\\nProvider & 0.778 & 0.778 & 0.778 \\\\\nStability & 0.845 & 0.710 & 0.772 \\\\\nAssertion & 0.813 & 0.730 & 0.769 \\\\\nPolarity & 0.817 & 0.699 & 0.753 \\\\\nDeath & 1.000 & 0.600 & 0.750 \\\\\nInsurance & 0.600 & 1.000 & 0.750 \\\\\nSpecimen & 0.875 & 0.636 & 0.737 \\\\\nCoreference & 0.647 & 0.688 & 0.667 \\\\\nOrganism-Name & 1.000 & 0.267 & 0.421 \\\\\nOrganism & 1.000 & 0.267 & 0.421 \\\\\nImmunization & 0.667 & 0.200 & 0.308 \\\\\nImmunization-Name & 0.000 & 0.000 & 0.000 \\\\\nCriteria-Count & 0.000 & 0.000 & 0.000 \\\\\n\\bottomrule\n\\end{tabular}\n\\caption{Metriken für llama3_8b_Lora_ep10_r256_prompt1_train_only_p4}\n\\label{tab:metrics_llama3_8b_lora_ep10_r256_prompt1_train_only_p4}\n\\end{table}'

# %%
def generate_comparison_latex_table(model_name, metrics):
    def format_metrics(p, r, f1):
        return f"{p*100:.1f}/{r*100:.1f}/{f1*100:.1f}"

    latex_table = r"""
\begin{table}[htbp]
\centering
\begin{tabular}{llcc}
\toprule
\textbf{Category} & \textbf{Entity} & \textbf{SciBERT} & \textbf{""" + model_name + r"""} \\
\midrule
\multirow{6}{*}{Clinical} & Condition & 78.4/83.3/80.8 & """ + format_metrics(metrics['Condition']['precision'], metrics['Condition']['recall'], metrics['Condition']['f1']) + r""" \\
 & Contraindication & 100.0/96.6/98.3 & """ + format_metrics(metrics['Contraindication']['precision'], metrics['Contraindication']['recall'], metrics['Contraindication']['f1']) + r""" \\
 & Drug & 73.4/80.9/77.0 & """ + format_metrics(metrics['Drug']['precision'], metrics['Drug']['recall'], metrics['Drug']['f1']) + r""" \\
 & Encounter & 58.3/74.4/65.4 & """ + format_metrics(metrics['Encounter']['precision'], metrics['Encounter']['recall'], metrics['Encounter']['f1']) + r""" \\
 & Observation & 72.1/77.6/74.7 & """ + format_metrics(metrics['Observation']['precision'], metrics['Observation']['recall'], metrics['Observation']['f1']) + r""" \\
 & Procedure & 71.3/79.4/75.1 & """ + format_metrics(metrics['Procedure']['precision'], metrics['Procedure']['recall'], metrics['Procedure']['f1']) + r""" \\
\midrule
\multirow{5}{*}{Demographic} & Age & 99.1/98.3/98.7 & """ + format_metrics(metrics['Age']['precision'], metrics['Age']['recall'], metrics['Age']['f1']) + r""" \\
 & Birth & 100.0/62.5/76.9 & """ + format_metrics(metrics['Birth']['precision'], metrics['Birth']['recall'], metrics['Birth']['f1']) + r""" \\
 & Death & 100.0/20.0/33.3 & """ + format_metrics(metrics['Death']['precision'], metrics['Death']['recall'], metrics['Death']['f1']) + r""" \\
 & Family-Member & 44.9/61.1/51.7 & """ + format_metrics(metrics['Family-Member']['precision'], metrics['Family-Member']['recall'], metrics['Family-Member']['f1']) + r""" \\
 & Language & 96.6/93.5/95.0 & """ + format_metrics(metrics['Language']['precision'], metrics['Language']['recall'], metrics['Language']['f1']) + r""" \\
\midrule
Logical & Negation & 73.5/82.9/77.9 & """ + format_metrics(metrics['Negation']['precision'], metrics['Negation']['recall'], metrics['Negation']['f1']) + r""" \\
\midrule
\multirow{6}{*}{Qualifier} & Assertion & 62.1/65.8/63.9 & """ + format_metrics(metrics['Assertion']['precision'], metrics['Assertion']['recall'], metrics['Assertion']['f1']) + r""" \\
 & Modifier & 58.5/65.4/61.8 & """ + format_metrics(metrics['Modifier']['precision'], metrics['Modifier']['recall'], metrics['Modifier']['f1']) + r""" \\
 & Polarity & 81.4/79.5/80.4 & """ + format_metrics(metrics['Polarity']['precision'], metrics['Polarity']['recall'], metrics['Polarity']['f1']) + r""" \\
 & Risk & 95.4/91.3/93.3 & """ + format_metrics(metrics['Risk']['precision'], metrics['Risk']['recall'], metrics['Risk']['f1']) + r""" \\
 & Severity & 86.5/94.1/90.2 & """ + format_metrics(metrics['Severity']['precision'], metrics['Severity']['recall'], metrics['Severity']['f1']) + r""" \\
 & Stability & 75.3/84.7/79.7 & """ + format_metrics(metrics['Stability']['precision'], metrics['Stability']['recall'], metrics['Stability']['f1']) + r""" \\
\midrule
\multirow{6}{*}{Temporal and Comparative} & Eq-Comparison & 85.3/89.3/87.3 & """ + format_metrics(metrics['Eq-Comparison']['precision'], metrics['Eq-Comparison']['recall'], metrics['Eq-Comparison']['f1']) + r""" \\
 & Criteria-Count & 12.5/20.0/15.5 & """ + format_metrics(metrics['Criteria-Count']['precision'], metrics['Criteria-Count']['recall'], metrics['Criteria-Count']['f1']) + r""" \\
 & Eq-Temporal-Period & 82.6/86.3/84.4 & """ + format_metrics(metrics['Eq-Temporal-Period']['precision'], metrics['Eq-Temporal-Period']['recall'], metrics['Eq-Temporal-Period']['f1']) + r""" \\
 & Eq-Temporal-Recency & 50.0/66.6/57.1 & """ + format_metrics(metrics['Eq-Temporal-Recency']['precision'], metrics['Eq-Temporal-Recency']['recall'], metrics['Eq-Temporal-Recency']['f1']) + r""" \\
 & Eq-Temporal-Unit & 98.2/99.4/98.8 & """ + format_metrics(metrics['Eq-Temporal-Unit']['precision'], metrics['Eq-Temporal-Unit']['recall'], metrics['Eq-Temporal-Unit']['f1']) + r""" \\
 & Eq-Value & 96.4/97.1/96.7 & """ + format_metrics(metrics['Eq-Value']['precision'], metrics['Eq-Value']['recall'], metrics['Eq-Value']['f1']) + r""" \\
\midrule
Other & Location & 73.4/78.3/75.8 & """ + format_metrics(metrics['Location']['precision'], metrics['Location']['recall'], metrics['Location']['f1']) + r""" \\
\midrule
-- & Total & 79.0/83.7/81.3 & """ + format_metrics(metrics['total']['precision'], metrics['total']['recall'], metrics['total']['f1']) + r""" \\
\bottomrule
\end{tabular}
\caption{Leistungsvergleich der Metriken auf dem LCT Korpus: SciBERT vs """ + model_name + r""" (\%, Precision/Recall/F1). Die Gesamtauswertung umfasst 50 Entitätskategorien.}
\label{tab:metrics_comparison}
\end{table}
    """

    file_path =  f'data/latex/{model_name}_compare_entitys.tex'
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(latex_table)
    return latex_table

# %%
generate_comparison_latex_table(model_name, metrics)
# Out:
# '\n\\begin{table}[htbp]\n\\centering\n\\begin{tabular}{llcc}\n\\toprule\n\\textbf{Category} & \\textbf{Entity} & \\textbf{SciBERT} & \\textbf{llama3_8b_Lora_ep10_r256_prompt1_train_only_p4} \\\\\n\\midrule\n\\multirow{6}{*}{Clinical} & Condition & 78.4/83.3/80.8 & 88.4/86.2/87.3 \\\\\n & Contraindication & 100.0/96.6/98.3 & 100.0/94.1/97.0 \\\\\n & Drug & 73.4/80.9/77.0 & 86.4/88.0/87.2 \\\\\n & Encounter & 58.3/74.4/65.4 & 85.1/77.0/80.9 \\\\\n & Observation & 72.1/77.6/74.7 & 85.9/83.8/84.8 \\\\\n & Procedure & 71.3/79.4/75.1 & 87.4/84.3/85.8 \\\\\n\\midrule\n\\multirow{5}{*}{Demographic} & Age & 99.1/98.3/98.7 & 99.3/94.8/97.0 \\\\\n & Birth & 100.0/62.5/76.9 & 77.8/100.0/87.5 \\\\\n & Death & 100.0/20.0/33.3 & 100.0/60.0/75.0 \\\\\n & Family-Member & 44.9/61.1/51.7 & 100.0/86.7/92.9 \\\\\n & Language & 96.6/93.5/95.0 & 100.0/92.9/96.3 \\\\\n\\midrule\nLogical & Negation & 73.5/82.9/77.9 & 88.5/81.9/85.1 \\\\\n\\midrule\n\\multirow{6}{*}{Qualifier} & Assertion & 62.1/65.8/63.9 & 81.3/73.0/76.9 \\\\\n & Modifier & 58.5/65.4/61.8 & 84.3/79.3/81.7 \\\\\n & Polarity & 81.4/79.5/80.4 & 81.7/69.9/75.3 \\\\\n & Risk & 95.4/91.3/93.3 & 100.0/75.0/85.7 \\\\\n & Severity & 86.5/94.1/90.2 & 96.0/90.5/93.1 \\\\\n & Stability & 75.3/84.7/79.7 & 84.5/71.0/77.2 \\\\\n\\midrule\n\\multirow{6}{*}{Temporal and Comparative} & Eq-Comparison & 85.3/89.3/87.3 & 92.3/90.1/91.2 \\\\\n & Criteria-Count & 12.5/20.0/15.5 & 0.0/0.0/0.0 \\\\\n & Eq-Temporal-Period & 82.6/86.3/84.4 & 90.5/89.4/89.9 \\\\\n & Eq-Temporal-Recency & 50.0/66.6/57.1 & 91.3/84.0/87.5 \\\\\n & Eq-Temporal-Unit & 98.2/99.4/98.8 & 97.4/93.0/95.2 \\\\\n & Eq-Value & 96.4/97.1/96.7 & 96.4/93.4/94.9 \\\\\n\\midrule\nOther & Location & 73.4/78.3/75.8 & 84.9/83.9/84.4 \\\\\n\\midrule\n-- & Total & 79.0/83.7/81.3 & 89.6/86.4/88.0 \\\\\n\\bottomrule\n\\end{tabular}\n\\caption{Leistungsvergleich der Metriken auf dem LCT Korpus: SciBERT vs llama3_8b_Lora_ep10_r256_prompt1_train_only_p4 (\\%, Precision/Recall/F1). Die Gesamtauswertung umfasst 50 Entitätskategorien.}\n\\label{tab:metrics_comparison}\n\\end{table}\n    '

# %% [markdown]
# ### Calculate Metrics for AND OR NOT

# %%
label_folder = "../input/lct_p1_half_with_and/" # '../input/lct_p1_half/'
raw_lct_text_folder = '../input/lct_txt_half'
model_output_folder = f'{batch_path}/model_output/'

# %%
def extract_file_name(filename):
    pattern = r'NCT(\d+)_(inc|exc)'
    match = re.search(pattern, filename)
    if match:
        nct_number = 'NCT' + match.group(1)
        suffix = match.group(2)
        return f"{nct_number}_{suffix}"
    else:
        return None

def find_operator_words(text, operators):
    words = {op: [] for op in operators}
    word_list = text.split()
    for i, word in enumerate(word_list):
        if word in ["[AND]", "[OR]", "[NOT]", "[AND1]"]:
            operator = word[1:-1]
            if operator in operators:
                j = i - 1
                while j >= 0 and word_list[j] in ["[AND]", "[OR]", "[NOT]", "[AND1]"]:
                    j -= 1
                if j >= 0:
                    prev_word = re.sub(r'[^\w]', '', word_list[j])  # Remove punctuation
                    words[operator].append(prev_word)
    return words

def compare_operators(label_text, model_text, operator):
    label_operators = extract_operators(label_text) + ['AND1']
    model_operators = extract_operators(model_text)

    label_words_dict = find_operator_words(label_text, label_operators)
    model_words_dict = find_operator_words(model_text, model_operators)

    tp = 0
    fp = 0
    fn = 0
    label_count = 0
    model_word_count = 0

    if operator in ['AND', 'AND1']:
        label_words_and = label_words_dict.get('AND', [])
        label_words_and1 = label_words_dict.get('AND1', [])
        model_words = model_words_dict.get('AND', [])
        model_word_count = len(model_words)
        print("Label AND:", label_words_and)
        print("Label AND1:", label_words_and1)
        print("Model  AND:", model_words)
        for word in model_words:
            if operator == 'AND':
                if word in label_words_and:
                    tp += 1
                elif word not in label_words_and1:
                    fp += 1
            elif operator == 'AND1':
                if word in label_words_and1:
                    tp += 1
                elif word not in label_words_and:
                    fp += 1

        if operator == 'AND':
            fn = sum(1 for word in label_words_and if word not in model_words)
            label_count = len(label_words_and)
        else:  # AND1
            fn = sum(1 for word in label_words_and1 if word not in model_words)
            label_count = len(label_words_and1)
    else:  # OR und NOT
        label_words = label_words_dict.get(operator, [])
        model_words = model_words_dict.get(operator, [])

        tp = sum(1 for word in label_words if word in model_words)
        fp = sum(1 for word in model_words if word not in label_words)
        fn = sum(1 for word in label_words if word not in model_words)
        label_count = len(label_words)
        model_word_count = len(model_words)
    if operator == "AND" or operator == "AND1":
        print(operator)
        print(f"TP: {tp}, FP: {fp}, FN: {fn}, Label count: {label_count}, Model count: {model_word_count}")
    return tp, fp, fn, label_count, model_word_count

def evaluate_models(label_folder, model_folder, model_name, raw_lct_text_folder):
    operators = ['AND', 'AND1', 'OR', 'NOT']
    metrics = {op: {'tp': 0, 'fp': 0, 'fn': 0, 'label_count': 0, 'model_count': 0, 'correct_count': 0, 'correct_ncts': set(), 'low_tp_ncts': set()} for op in operators}
    processed_label_files = 0
    total_missing_words = Counter()
    total_missing_pct = 0.0
    model_results = []
    label_files = {f.split('.')[0]: os.path.join(label_folder, f) for f in os.listdir(label_folder) if f.endswith('.txt')}

    for model_file in os.listdir(model_folder):
        if model_file.endswith('.txt'):
            identifier = extract_file_name(model_file)
            print(identifier)
            if identifier in label_files:
                label_file_path = label_files[identifier]
                model_file_path = os.path.join(model_folder, model_file)
                raw_lct_text_path = os.path.join(raw_lct_text_folder, f'{identifier}.txt')

                if os.path.exists(label_file_path):
                    processed_label_files += 1
                    label_text = read_file(label_file_path)
                    model_text = read_file(model_file_path)
                    raw_lct_text = read_file(raw_lct_text_path)
                    model_raw_text = clean_criteria_text(model_text)
                    missing_words, missing_percentage = compare_texts(raw_lct_text, model_raw_text)
                    total_missing_pct += missing_percentage
                    total_missing_words.update(missing_words)

                    model_data = {'nct_number': identifier}

                    for op in operators:
                        tp, fp, fn, label_count, model_count = compare_operators(label_text, model_text, op)

                        metrics[op]['tp'] += tp
                        metrics[op]['fp'] += fp
                        metrics[op]['fn'] += fn
                        metrics[op]['label_count'] += label_count
                        metrics[op]['model_count'] += model_count

                        metrics[op]['correct_count'] += tp

                        model_data[f'{op}_tp'] = tp
                        model_data[f'{op}_fp'] = fp
                        model_data[f'{op}_fn'] = fn
                        model_data[f'{op}_label_count'] = label_count
                        model_data[f'{op}_model_count'] = model_count

                        if tp > 0:
                            metrics[op]['correct_ncts'].add(identifier)
                        if tp == 0 and fn > 4:
                            metrics[op]['low_tp_ncts'].add(identifier)

                    model_results.append(model_data)

    results = calculate_aggregated_results(metrics, processed_label_files, total_missing_pct, operators)
    return results

# %%
all_metrics = {}
for model in models:
    model_folder = os.path.join(model_output_folder, model, 'processed_output')
    metrics = evaluate_models(label_folder, model_folder, model, raw_lct_text_folder)
    all_metrics[model] = metrics
# Out:
# NCT03860194_exc
# Label AND: []
# Label AND1: ['months', 'resident', 'failure', 'failure', 'mellitus']
# Model  AND: ['months', 'resident', 'failure', 'failure', 'mellitus']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 5
# Label AND: []
# Label AND1: ['months', 'resident', 'failure', 'failure', 'mellitus']
# Model  AND: ['months', 'resident', 'failure', 'failure', 'mellitus']
# AND1
# TP: 5, FP: 0, FN: 0, Label count: 5, Model count: 5
# NCT03860194_inc
# Label AND: []
# Label AND1: ['years', 'Japan']
# Model  AND: ['years', 'Japan']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['years', 'Japan']
# Model  AND: ['years', 'Japan']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# NCT03860415_exc
# Label AND: []
# Label AND1: ['TNFalphainhibitors', 'care', 'immunodeficiency', 'disorder', 'abuse', 'dementia']
# Model  AND: ['TNFalphainhibitors', 'care', 'immunodeficiency', 'disorder', 'abuse', 'dementia']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 6
# Label AND: []
# Label AND1: ['TNFalphainhibitors', 'care', 'immunodeficiency', 'disorder', 'abuse', 'dementia']
# Model  AND: ['TNFalphainhibitors', 'care', 'immunodeficiency', 'disorder', 'abuse', 'dementia']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 6, Model count: 6
# NCT03860415_inc
# Label AND: []
# Label AND1: ['by', 'antibiogram', 'sachets', 'Swedish', 'Sweden']
# Model  AND: ['by', 'antibiogram', 'sachets', 'Swedish', 'Sweden']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 5
# Label AND: []
# Label AND1: ['by', 'antibiogram', 'sachets', 'Swedish', 'Sweden']
# Model  AND: ['by', 'antibiogram', 'sachets', 'Swedish', 'Sweden']
# AND1
# TP: 5, FP: 0, FN: 0, Label count: 5, Model count: 5
# NCT03860454_exc
# Label AND: []
# Label AND1: ['would', 'bloodletting', 'consent', 'MRI', 'be']
# Model  AND: ['would', 'bloodletting', 'consent', 'MRI', 'be']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 5
# Label AND: []
# Label AND1: ['would', 'bloodletting', 'consent', 'MRI', 'be']
# Model  AND: ['would', 'bloodletting', 'consent', 'MRI', 'be']
# AND1
# TP: 5, FP: 0, FN: 0, Label count: 5, Model count: 5
# NCT03860454_inc
# Label AND: ['LMNA', 'patients', 'but', 'patients']
# Label AND1: ['Trust', 'Trust']
# Model  AND: ['LMNA', 'patients', 'Trust', 'but', 'patients', 'Trust']
# AND
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 6
# Label AND: ['LMNA', 'patients', 'but', 'patients']
# Label AND1: ['Trust', 'Trust']
# Model  AND: ['LMNA', 'patients', 'Trust', 'but', 'patients', 'Trust']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 6
# NCT03860584_exc
# Label AND: []
# Label AND1: ['3mo', 'Vegetarian', 'intolerance', '1mo', '6mo', 'disorders', 'diarrhea', 'Smoker', 'drinksd', 'hwk', 'use']
# Model  AND: ['3mo', 'Vegetarian', 'intolerance', '1mo', '6mo', 'disorders', 'diarrhea', 'Smoker', 'drinksd', 'hwk', 'use']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 11
# Label AND: []
# Label AND1: ['3mo', 'Vegetarian', 'intolerance', '1mo', '6mo', 'disorders', 'diarrhea', 'Smoker', 'drinksd', 'hwk', 'use']
# Model  AND: ['3mo', 'Vegetarian', 'intolerance', '1mo', '6mo', 'disorders', 'diarrhea', 'Smoker', 'drinksd', 'hwk', 'use']
# AND1
# TP: 11, FP: 0, FN: 0, Label count: 11, Model count: 11
# NCT03860584_inc
# Label AND: []
# Label AND1: ['mgdl', 'M', 'M', 'mgdl', 'mmHg']
# Model  AND: ['mgdl', 'M', 'M', 'mgdl', 'mmHg']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 5
# Label AND: []
# Label AND1: ['mgdl', 'M', 'M', 'mgdl', 'mmHg']
# Model  AND: ['mgdl', 'M', 'M', 'mgdl', 'mmHg']
# AND1
# TP: 5, FP: 0, FN: 0, Label count: 5, Model count: 5
# NCT03860766_exc
# Label AND: []
# Label AND1: ['months', 'diseases', 'evaluations']
# Model  AND: ['months', 'diseases', 'evaluations']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['months', 'diseases', 'evaluations']
# Model  AND: ['months', 'diseases', 'evaluations']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03860766_inc
# Label AND: ['year']
# Label AND1: ['players', 'Healthy']
# Model  AND: ['players', 'Healthy', 'year']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 3
# Label AND: ['year']
# Label AND1: ['players', 'Healthy']
# Model  AND: ['players', 'Healthy', 'year']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 3
# NCT03860896_exc
# Label AND: []
# Label AND1: ['infection', 'are']
# Model  AND: ['infection', 'are']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['infection', 'are']
# Model  AND: ['infection', 'are']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# NCT03860896_inc
# Label AND: ['assessment']
# Label AND1: []
# Model  AND: ['assessment']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# Label AND: ['assessment']
# Label AND1: []
# Model  AND: ['assessment']
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# NCT03861182_exc
# Label AND: []
# Label AND1: ['', 'disease', 'state', 'sampling', 'Neonates', '7gDL']
# Model  AND: ['', 'disease', 'state', 'sampling', 'Neonates', '7gDL']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 6
# Label AND: []
# Label AND1: ['', 'disease', 'state', 'sampling', 'Neonates', '7gDL']
# Model  AND: ['', 'disease', 'state', 'sampling', 'Neonates', '7gDL']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 6, Model count: 6
# NCT03861182_inc
# Label AND: ['1day']
# Label AND1: ['', 'age', 'Neonates', 'life', 'weight', 'Strasbourg']
# Model  AND: ['', 'age', 'Neonates', 'life', '1day', 'weight']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 6
# Label AND: ['1day']
# Label AND1: ['', 'age', 'Neonates', 'life', 'weight', 'Strasbourg']
# Model  AND: ['', 'age', 'Neonates', 'life', '1day', 'weight']
# AND1
# TP: 5, FP: 0, FN: 1, Label count: 6, Model count: 6
# NCT03861195_exc
# Label AND: ['women', 'women']
# Label AND1: ['adhesions', 'laparoscopy', 'avoided', 'hemostasis', 'pregnancy', 'that', 'approach']
# Model  AND: ['adhesions', 'laparoscopy', 'women', 'avoided', 'women', 'hemostasis', 'pregnancy', 'that', 'approach']
# AND
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 9
# Label AND: ['women', 'women']
# Label AND1: ['adhesions', 'laparoscopy', 'avoided', 'hemostasis', 'pregnancy', 'that', 'approach']
# Model  AND: ['adhesions', 'laparoscopy', 'women', 'avoided', 'women', 'hemostasis', 'pregnancy', 'that', 'approach']
# AND1
# TP: 7, FP: 0, FN: 0, Label count: 7, Model count: 9
# NCT03861195_inc
# Label AND: []
# Label AND1: ['years', 'kgm2', 'cancer', 'cancer', 'cancer', 'patients']
# Model  AND: ['years', 'kgm2', 'cancer', 'cancer', 'cancer', 'uterus', 'patients']
# AND
# TP: 0, FP: 1, FN: 0, Label count: 0, Model count: 7
# Label AND: []
# Label AND1: ['years', 'kgm2', 'cancer', 'cancer', 'cancer', 'patients']
# Model  AND: ['years', 'kgm2', 'cancer', 'cancer', 'cancer', 'uterus', 'patients']
# AND1
# TP: 6, FP: 1, FN: 0, Label count: 6, Model count: 7
# NCT03861299_exc
# Label AND: []
# Label AND1: ['midline', 'lesions', 'transformation', 'reasons', 'pacemaker', 'barrier', 'history', 'surgery', 'glioma', 'skin']
# Model  AND: ['midline', 'lesions', 'transformation', 'reasons', 'pacemaker', 'barrier', 'history', 'surgery', 'gliomas', 'years', 'skin']
# AND
# TP: 0, FP: 2, FN: 0, Label count: 0, Model count: 11
# Label AND: []
# Label AND1: ['midline', 'lesions', 'transformation', 'reasons', 'pacemaker', 'barrier', 'history', 'surgery', 'glioma', 'skin']
# Model  AND: ['midline', 'lesions', 'transformation', 'reasons', 'pacemaker', 'barrier', 'history', 'surgery', 'gliomas', 'years', 'skin']
# AND1
# TP: 9, FP: 2, FN: 1, Label count: 10, Model count: 11
# NCT03861299_inc
# Label AND: ['years', 'walls']
# Label AND1: ['years', 'surgeon', 'II', 'neurosurgeon', 'more']
# Model  AND: ['years', 'years', 'walls', 'surgeon', 'II', 'neurosurgeon', 'more']
# AND
# TP: 3, FP: 0, FN: 0, Label count: 2, Model count: 7
# Label AND: ['years', 'walls']
# Label AND1: ['years', 'surgeon', 'II', 'neurosurgeon', 'more']
# Model  AND: ['years', 'years', 'walls', 'surgeon', 'II', 'neurosurgeon', 'more']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 5, Model count: 7
# NCT03861312_exc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03861312_inc
# Label AND: ['Pain']
# Label AND1: []
# Model  AND: ['Pain']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# Label AND: ['Pain']
# Label AND1: []
# Model  AND: ['Pain']
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# NCT03861429_exc
# Label AND: []
# Label AND1: ['aphasia', 'Comatose', 'intact']
# Model  AND: ['aphasia', 'Comatose', 'intact']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['aphasia', 'Comatose', 'intact']
# Model  AND: ['aphasia', 'Comatose', 'intact']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03861429_inc
# Label AND: []
# Label AND1: ['dementia', 'only', 'record', 'record', 'resident', 'years', 'English', 'Family', 'English', 'videos', 'participating', 'Staff', 'English', 'videos', 'surveys']
# Model  AND: ['dementia', 'only', 'record', 'record', 'resident', 'years', 'English', 'Family', 'English', 'videos', 'participating', 'Staff', 'English', 'videos', 'residents', 'years']
# AND
# TP: 0, FP: 1, FN: 0, Label count: 0, Model count: 16
# Label AND: []
# Label AND1: ['dementia', 'only', 'record', 'record', 'resident', 'years', 'English', 'Family', 'English', 'videos', 'participating', 'Staff', 'English', 'videos', 'surveys']
# Model  AND: ['dementia', 'only', 'record', 'record', 'resident', 'years', 'English', 'Family', 'English', 'videos', 'participating', 'Staff', 'English', 'videos', 'residents', 'years']
# AND1
# TP: 15, FP: 1, FN: 1, Label count: 15, Model count: 16
# NCT03861494_exc
# Label AND: ['admitted', 'admitted']
# Label AND1: ['attack', 'hemorrhage', 'infarction', 'patients', 'discharge', 'hospice']
# Model  AND: ['admitted', 'attack', 'admitted', 'hemorrhage', 'infarction', 'patients', 'discharge', 'hospice']
# AND
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 8
# Label AND: ['admitted', 'admitted']
# Label AND1: ['attack', 'hemorrhage', 'infarction', 'patients', 'discharge', 'hospice']
# Model  AND: ['admitted', 'attack', 'admitted', 'hemorrhage', 'infarction', 'patients', 'discharge', 'hospice']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 6, Model count: 8
# NCT03861494_inc
# Label AND: ['hospitalized']
# Label AND1: ['infarction', 'older', 'speaking', 'Thursday', 'consent', 'months', 'obesity', 'counties']
# Model  AND: ['hospitalized', 'infarction', 'older', 'speaking', 'Thursday', 'consent', 'months', 'obesity', 'counties']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 9
# Label AND: ['hospitalized']
# Label AND1: ['infarction', 'older', 'speaking', 'Thursday', 'consent', 'months', 'obesity', 'counties']
# Model  AND: ['hospitalized', 'infarction', 'older', 'speaking', 'Thursday', 'consent', 'months', 'obesity', 'counties']
# AND1
# TP: 8, FP: 0, FN: 0, Label count: 8, Model count: 9
# NCT03861507_exc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03861507_inc
# Label AND: []
# Label AND1: ['older', 'consent', 'biopsy']
# Model  AND: ['older', 'consent', 'biopsy']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['older', 'consent', 'biopsy']
# Model  AND: ['older', 'consent', 'biopsy']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03861546_exc
# Label AND: ['illness']
# Label AND1: ['chemotherapyinduced', 'years', 'that', 'failure', '4', 'activity', 'pregnancy', 'capacity', 'abuse', 'or']
# Model  AND: ['chemotherapyinduced', 'illness', 'years', 'that', 'failure', '4', 'activity', 'pregnancy', 'capacity', 'abuse', 'or']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 11
# Label AND: ['illness']
# Label AND1: ['chemotherapyinduced', 'years', 'that', 'failure', '4', 'activity', 'pregnancy', 'capacity', 'abuse', 'or']
# Model  AND: ['chemotherapyinduced', 'illness', 'years', 'that', 'failure', '4', 'activity', 'pregnancy', 'capacity', 'abuse', 'or']
# AND1
# TP: 10, FP: 0, FN: 0, Label count: 10, Model count: 11
# NCT03861546_inc
# Label AND: []
# Label AND1: ['years', '100', 'influencer', 'dyad']
# Model  AND: ['years', '100', 'influencer', 'dyad']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 4
# Label AND: []
# Label AND1: ['years', '100', 'influencer', 'dyad']
# Model  AND: ['years', '100', 'influencer', 'dyad']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 4
# NCT03861572_exc
# Label AND: ['release', 'diseases']
# Label AND1: ['did', 'did', 'with']
# Model  AND: ['did', 'did', 'release', 'diseases', 'with']
# AND
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 5
# Label AND: ['release', 'diseases']
# Label AND1: ['did', 'did', 'with']
# Model  AND: ['did', 'did', 'release', 'diseases', 'with']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 5
# NCT03861572_inc
# Label AND: ['subjects', 'rupture']
# Label AND1: []
# Model  AND: ['subjects', 'rupture']
# AND
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# Label AND: ['subjects', 'rupture']
# Label AND1: []
# Model  AND: ['subjects', 'rupture']
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# NCT03861624_exc
# Label AND: ['TBSA']
# Label AND1: ['fracture', 'fracture', 'fracture', '', 'paralysis', 'injury', 'surgery', 'abnormality', '9']
# Model  AND: ['fracture', 'fracture', 'fracture', '', 'paralysis', 'injury', 'surgery', 'abnormality', '9']
# AND
# TP: 0, FP: 0, FN: 1, Label count: 1, Model count: 9
# Label AND: ['TBSA']
# Label AND1: ['fracture', 'fracture', 'fracture', '', 'paralysis', 'injury', 'surgery', 'abnormality', '9']
# Model  AND: ['fracture', 'fracture', 'fracture', '', 'paralysis', 'injury', 'surgery', 'abnormality', '9']
# AND1
# TP: 9, FP: 0, FN: 0, Label count: 9, Model count: 9
# NCT03861624_inc
# Label AND: []
# Label AND1: ['maturity', 'fractures', '', 'needed', '', 'sustained']
# Model  AND: ['maturity', 'fractures', '', 'needed', '', 'sustained']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 6
# Label AND: []
# Label AND1: ['maturity', 'fractures', '', 'needed', '', 'sustained']
# Model  AND: ['maturity', 'fractures', '', 'needed', '', 'sustained']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 6, Model count: 6
# NCT03861650_exc
# Label AND: []
# Label AND1: ['disease', 'region', 'period']
# Model  AND: ['disease', 'region', 'period']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['disease', 'region', 'period']
# Model  AND: ['disease', 'region', 'period']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03861650_inc
# Label AND: []
# Label AND1: ['Patients', 'study', 'old', 'deformity']
# Model  AND: ['Patients', 'study', 'old', 'deformity']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 4
# Label AND: []
# Label AND1: ['Patients', 'study', 'old', 'deformity']
# Model  AND: ['Patients', 'study', 'old', 'deformity']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 4
# NCT03861845_exc
# Label AND: []
# Label AND1: ['impairment', '', 'pillbox', '']
# Model  AND: ['impairment', '', 'pillbox', '']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 4
# Label AND: []
# Label AND1: ['impairment', '', 'pillbox', '']
# Model  AND: ['impairment', '', 'pillbox', '']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 4
# NCT03861845_inc
# Label AND: ['day']
# Label AND1: ['older', 'English']
# Model  AND: ['older', 'English', 'day']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 3
# Label AND: ['day']
# Label AND1: ['older', 'English']
# Model  AND: ['older', 'English', 'day']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 3
# NCT03861884_exc
# Label AND: []
# Label AND1: ['involvement', '2', 'years', 'disability']
# Model  AND: ['involvement', '2', 'years', 'disability']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 4
# Label AND: []
# Label AND1: ['involvement', '2', 'years', 'disability']
# Model  AND: ['involvement', '2', 'years', 'disability']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 4
# NCT03861884_inc
# Label AND: []
# Label AND1: ['consent']
# Model  AND: ['consent']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# Label AND: []
# Label AND1: ['consent']
# Model  AND: ['consent']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# NCT03862014_exc
# Label AND: []
# Label AND1: ['caries', 'treatment', 'are', 'procedure']
# Model  AND: ['caries', 'treatment', 'are', 'procedure']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 4
# Label AND: []
# Label AND1: ['caries', 'treatment', 'are', 'procedure']
# Model  AND: ['caries', 'treatment', 'are', 'procedure']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 4
# NCT03862014_inc
# Label AND: []
# Label AND1: ['consent', 'EAPD', 'erupted', 'sealant']
# Model  AND: ['consent', 'EAPD', 'erupted', 'sealant']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 4
# Label AND: []
# Label AND1: ['consent', 'EAPD', 'erupted', 'sealant']
# Model  AND: ['consent', 'EAPD', 'erupted', 'sealant']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 4
# NCT03862105_exc
# Label AND: []
# Label AND1: ['read', 'consent', 'illness', 'surgery', 'diagnosis', '']
# Model  AND: ['read', 'consent', 'illness', 'surgery', 'diagnosis', '']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 6
# Label AND: []
# Label AND1: ['read', 'consent', 'illness', 'surgery', 'diagnosis', '']
# Model  AND: ['read', 'consent', 'illness', 'surgery', 'diagnosis', '']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 6, Model count: 6
# NCT03862105_inc
# Label AND: ['patients']
# Label AND1: ['days', 'Englishspeaking', 'caregiver', 'read']
# Model  AND: ['patients', 'days', 'Englishspeaking', 'caregiver', 'read']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 5
# Label AND: ['patients']
# Label AND1: ['days', 'Englishspeaking', 'caregiver', 'read']
# Model  AND: ['patients', 'days', 'Englishspeaking', 'caregiver', 'read']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 5
# NCT03862248_exc
# Label AND: []
# Label AND1: ['facility']
# Model  AND: ['facility']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# Label AND: []
# Label AND1: ['facility']
# Model  AND: ['facility']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# NCT03862248_inc
# Label AND: []
# Label AND1: ['TB', 'limit']
# Model  AND: ['TB', 'limit']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['TB', 'limit']
# Model  AND: ['TB', 'limit']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# NCT03862287_exc
# Label AND: []
# Label AND1: ['old', '3', 'infection', 'impairment', 'psychosis', 'pain', 'impairment', 'study', 'usage']
# Model  AND: ['old', '3', 'infection', 'impairment', 'psychosis', 'pain', 'impairment', 'study', 'usage']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 9
# Label AND: []
# Label AND1: ['old', '3', 'infection', 'impairment', 'psychosis', 'pain', 'impairment', 'study', 'usage']
# Model  AND: ['old', '3', 'infection', 'impairment', 'psychosis', 'pain', 'impairment', 'study', 'usage']
# AND1
# TP: 9, FP: 0, FN: 0, Label count: 9, Model count: 9
# NCT03862287_inc
# Label AND: ['old']
# Label AND1: []
# Model  AND: ['old']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# Label AND: ['old']
# Label AND1: []
# Model  AND: ['old']
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# NCT03862482_exc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03862482_inc
# Label AND: ['years']
# Label AND1: ['', 'nonsmoker', '', 'pain']
# Model  AND: ['', 'nonsmoker', '', 'pain', 'years']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 5
# Label AND: ['years']
# Label AND1: ['', 'nonsmoker', '', 'pain']
# Model  AND: ['', 'nonsmoker', '', 'pain', 'years']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 5
# NCT03862755_exc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03862755_inc
# Label AND: ['patients', 'surgery']
# Label AND1: []
# Model  AND: ['patients', 'surgery']
# AND
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# Label AND: ['patients', 'surgery']
# Label AND1: []
# Model  AND: ['patients', 'surgery']
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# NCT03862781_exc
# Label AND: ['performed']
# Label AND1: ['women', 'proctectomy', 'consent', 'postoperatively', 'cases', 'if', 'resection']
# Model  AND: ['women', 'proctectomy', 'consent', 'postoperatively', 'cases', 'if', 'resection']
# AND
# TP: 0, FP: 0, FN: 1, Label count: 1, Model count: 7
# Label AND: ['performed']
# Label AND1: ['women', 'proctectomy', 'consent', 'postoperatively', 'cases', 'if', 'resection']
# Model  AND: ['women', 'proctectomy', 'consent', 'postoperatively', 'cases', 'if', 'resection']
# AND1
# TP: 7, FP: 0, FN: 0, Label count: 7, Model count: 7
# NCT03862781_inc
# Label AND: ['age', 'approach']
# Label AND1: []
# Model  AND: ['age', 'colon']
# AND
# TP: 1, FP: 1, FN: 1, Label count: 2, Model count: 2
# Label AND: ['age', 'approach']
# Label AND1: []
# Model  AND: ['age', 'colon']
# AND1
# TP: 0, FP: 1, FN: 0, Label count: 0, Model count: 2
# NCT03862820_exc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03862820_inc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03863275_exc
# Label AND: []
# Label AND1: ['treatment', 'injuries', 'cleft']
# Model  AND: ['treatment', 'injury', 'cleft']
# AND
# TP: 0, FP: 1, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['treatment', 'injuries', 'cleft']
# Model  AND: ['treatment', 'injury', 'cleft']
# AND1
# TP: 2, FP: 1, FN: 1, Label count: 3, Model count: 3
# NCT03863275_inc
# Label AND: ['old']
# Label AND1: []
# Model  AND: ['old']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# Label AND: ['old']
# Label AND1: []
# Model  AND: ['old']
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# NCT03863444_exc
# Label AND: []
# Label AND1: ['abnormality', 'pregnancy', '3']
# Model  AND: ['abnormality', 'pregnancy', '3']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['abnormality', 'pregnancy', '3']
# Model  AND: ['abnormality', 'pregnancy', '3']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03863444_inc
# Label AND: ['primipara', 'visits']
# Label AND1: ['weeks', 'adults', 'spouses', 'center', 'Taiwanese']
# Model  AND: ['weeks', 'adults', 'primipara', 'spouses', 'visits', 'center', 'Taiwanese']
# AND
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 7
# Label AND: ['primipara', 'visits']
# Label AND1: ['weeks', 'adults', 'spouses', 'center', 'Taiwanese']
# Model  AND: ['weeks', 'adults', 'primipara', 'spouses', 'visits', 'center', 'Taiwanese']
# AND1
# TP: 5, FP: 0, FN: 0, Label count: 5, Model count: 7
# NCT03863535_exc
# Label AND: []
# Label AND1: ['eye', 'accident', 'days', 'hypertension', 'causes', 'months', 'mellitus', 'aspirin']
# Model  AND: ['eye', 'accident', 'days', 'hypertension', 'causes', 'months', 'mellitus', 'aspirin']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 8
# Label AND: []
# Label AND1: ['eye', 'accident', 'days', 'hypertension', 'causes', 'months', 'mellitus', 'aspirin']
# Model  AND: ['eye', 'accident', 'days', 'hypertension', 'causes', 'months', 'mellitus', 'aspirin']
# AND1
# TP: 8, FP: 0, FN: 0, Label count: 8, Model count: 8
# NCT03863535_inc
# Label AND: []
# Label AND1: ['had', 'severe', 'with', 'edema', 'equivalent', '3']
# Model  AND: ['had', 'severe', 'with', 'edema', 'equivalent', '3']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 6
# Label AND: []
# Label AND1: ['had', 'severe', 'with', 'edema', 'equivalent', '3']
# Model  AND: ['had', 'severe', 'with', 'edema', 'equivalent', '3']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 6, Model count: 6
# NCT03863717_exc
# Label AND: []
# Label AND1: ['old', 'disease', 'exercise', 'stage']
# Model  AND: ['old', 'disease', 'or', 'exercise', 'stage', 'setting']
# AND
# TP: 0, FP: 2, FN: 0, Label count: 0, Model count: 6
# Label AND: []
# Label AND1: ['old', 'disease', 'exercise', 'stage']
# Model  AND: ['old', 'disease', 'or', 'exercise', 'stage', 'setting']
# AND1
# TP: 4, FP: 2, FN: 0, Label count: 4, Model count: 6
# NCT03863717_inc
# Label AND: ['examination']
# Label AND1: ['test', '', 'disease', 'study']
# Model  AND: ['examination', 'test', '', 'disease', 'study']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 5
# Label AND: ['examination']
# Label AND1: ['test', '', 'disease', 'study']
# Model  AND: ['examination', 'test', '', 'disease', 'study']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 5
# NCT03863951_exc
# Label AND: []
# Label AND1: ['tumor', 'antipsychotics', 'weeks', 'women', 'PD']
# Model  AND: ['tumor', 'antipsychotics', 'weeks', 'women', 'PD']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 5
# Label AND: []
# Label AND1: ['tumor', 'antipsychotics', 'weeks', 'women', 'PD']
# Model  AND: ['tumor', 'antipsychotics', 'weeks', 'women', 'PD']
# AND1
# TP: 5, FP: 0, FN: 0, Label count: 5, Model count: 5
# NCT03863951_inc
# Label AND: []
# Label AND1: ['MRI', 'has', 'antipsychotics']
# Model  AND: ['MRI', 'has', 'antipsychotics']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['MRI', 'has', 'antipsychotics']
# Model  AND: ['MRI', 'has', 'antipsychotics']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03863977_exc
# Label AND: []
# Label AND1: ['60', 'IIIIV', 'anesthetics', 'injection', 'disorders', 'kgm2']
# Model  AND: ['60', 'IIIIV', 'anesthetics', 'injection', 'disorders', 'kgm2']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 6
# Label AND: []
# Label AND1: ['60', 'IIIIV', 'anesthetics', 'injection', 'disorders', 'kgm2']
# Model  AND: ['60', 'IIIIV', 'anesthetics', 'injection', 'disorders', 'kgm2']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 6, Model count: 6
# NCT03863977_inc
# Label AND: []
# Label AND1: ['old', 'Anesthesiologists', 'repair']
# Model  AND: ['old', 'Anesthesiologists', 'repair']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['old', 'Anesthesiologists', 'repair']
# Model  AND: ['old', 'Anesthesiologists', 'repair']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03864133_exc
# Label AND: ['steady', 'Female']
# Label AND1: ['NSAIDs', '', 'OCT', 'trauma', 'baseline', 'analogue', 'OCT', 'postoperatively', '', 'appointments']
# Model  AND: ['NSAIDs', '', 'steady', 'OCT', 'trauma', 'baseline', 'analogue', 'OCT', 'postoperatively', '', 'appointments', 'patients']
# AND
# TP: 1, FP: 1, FN: 1, Label count: 2, Model count: 12
# Label AND: ['steady', 'Female']
# Label AND1: ['NSAIDs', '', 'OCT', 'trauma', 'baseline', 'analogue', 'OCT', 'postoperatively', '', 'appointments']
# Model  AND: ['NSAIDs', '', 'steady', 'OCT', 'trauma', 'baseline', 'analogue', 'OCT', 'postoperatively', '', 'appointments', 'patients']
# AND1
# TP: 10, FP: 1, FN: 0, Label count: 10, Model count: 12
# NCT03864133_inc
# Label AND: ['years', 'vasectomy', 'vasectomy', 'female']
# Label AND1: ['eyes', 'included']
# Model  AND: ['years', 'eyes', 'potential']
# AND
# TP: 1, FP: 1, FN: 3, Label count: 4, Model count: 3
# Label AND: ['years', 'vasectomy', 'vasectomy', 'female']
# Label AND1: ['eyes', 'included']
# Model  AND: ['years', 'eyes', 'potential']
# AND1
# TP: 1, FP: 1, FN: 1, Label count: 2, Model count: 3
# NCT03864159_exc
# Label AND: []
# Label AND1: ['limbs', 'coagulopathies', 'hypermobility']
# Model  AND: ['limbs', 'coagulopathies', 'hypermobility']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['limbs', 'coagulopathies', 'hypermobility']
# Model  AND: ['limbs', 'coagulopathies', 'hypermobility']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03864159_inc
# Label AND: []
# Label AND1: ['years', 'players', 'club', '']
# Model  AND: ['years', 'players', 'club', '']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 4
# Label AND: []
# Label AND1: ['years', 'players', 'club', '']
# Model  AND: ['years', 'players', 'club', '']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 4
# NCT03864172_exc
# Label AND: ['supplements']
# Label AND1: ['anaemia', 'medication', 'to']
# Model  AND: ['anaemia', 'medication', 'supplements', 'study']
# AND
# TP: 1, FP: 1, FN: 0, Label count: 1, Model count: 4
# Label AND: ['supplements']
# Label AND1: ['anaemia', 'medication', 'to']
# Model  AND: ['anaemia', 'medication', 'supplements', 'study']
# AND1
# TP: 2, FP: 1, FN: 1, Label count: 3, Model count: 4
# NCT03864172_inc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03864263_exc
# Label AND: []
# Label AND1: ['infection']
# Model  AND: ['infection']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# Label AND: []
# Label AND1: ['infection']
# Model  AND: ['infection']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# NCT03864263_inc
# Label AND: []
# Label AND1: ['present']
# Model  AND: ['present']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# Label AND: []
# Label AND1: ['present']
# Model  AND: ['present']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# NCT03864289_exc
# Label AND: ['Children']
# Label AND1: ['sclerosis', 'disabilities']
# Model  AND: ['Children', 'sclerosis', 'disabilities']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 3
# Label AND: ['Children']
# Label AND1: ['sclerosis', 'disabilities']
# Model  AND: ['Children', 'sclerosis', 'disabilities']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 3
# NCT03864289_inc
# Label AND: ['Children', 'educated']
# Label AND1: ['autism', 'ethic']
# Model  AND: ['Children', 'autism', 'ethic', 'educated']
# AND
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 4
# Label AND: ['Children', 'educated']
# Label AND1: ['autism', 'ethic']
# Model  AND: ['Children', 'autism', 'ethic', 'educated']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 4
# NCT03864341_exc
# Label AND: []
# Label AND1: ['unstable', 'intoxication', 'custody', '', 'English', 'Lives', 'andor', 'code', 'streets', 'followup', 'visit']
# Model  AND: ['unstable', 'intoxication', 'custody', '', 'English', '', 'code', 'streets', 'followup', 'study', 'visit']
# AND
# TP: 0, FP: 1, FN: 0, Label count: 0, Model count: 11
# Label AND: []
# Label AND1: ['unstable', 'intoxication', 'custody', '', 'English', 'Lives', 'andor', 'code', 'streets', 'followup', 'visit']
# Model  AND: ['unstable', 'intoxication', 'custody', '', 'English', '', 'code', 'streets', 'followup', 'study', 'visit']
# AND1
# TP: 10, FP: 1, FN: 2, Label count: 11, Model count: 11
# NCT03864341_inc
# Label AND: []
# Label AND1: ['ED', 'old', 'HRST', 'use']
# Model  AND: ['ED', 'old', 'HRST', 'use']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 4
# Label AND: []
# Label AND1: ['ED', 'old', 'HRST', 'use']
# Model  AND: ['ED', 'old', 'HRST', 'use']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 4
# NCT03864380_exc
# Label AND: []
# Label AND1: ['fundus']
# Model  AND: ['fundus']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# Label AND: []
# Label AND1: ['fundus']
# Model  AND: ['fundus']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# NCT03864380_inc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03864705_exc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03864705_inc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03864731_exc
# Label AND: []
# Label AND1: ['breastfeeding', 'aid', 'Manufacturer', 'may', 'adapter', 'is', 'questionnaires', 'disorder']
# Model  AND: ['breastfeeding', 'aid', 'Manufacturer', 'may', 'adapter', 'questionnaires', 'disorder']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 7
# Label AND: []
# Label AND1: ['breastfeeding', 'aid', 'Manufacturer', 'may', 'adapter', 'is', 'questionnaires', 'disorder']
# Model  AND: ['breastfeeding', 'aid', 'Manufacturer', 'may', 'adapter', 'questionnaires', 'disorder']
# AND1
# TP: 7, FP: 0, FN: 1, Label count: 8, Model count: 7
# NCT03864731_inc
# Label AND: []
# Label AND1: ['CHL', 'average', 'device', 'older', 'language', 'study']
# Model  AND: ['CHL', 'average', 'device', 'older', 'language', 'study']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 6
# Label AND: []
# Label AND1: ['CHL', 'average', 'device', 'older', 'language', 'study']
# Model  AND: ['CHL', 'average', 'device', 'older', 'language', 'study']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 6, Model count: 6
# NCT03864835_exc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03864835_inc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03864887_exc
# Label AND: []
# Label AND1: ['conception', 'surgery', 'specialists', 'Syphilis']
# Model  AND: ['conception', 'surgery', 'are', 'specialists', 'Syphilis']
# AND
# TP: 0, FP: 1, FN: 0, Label count: 0, Model count: 5
# Label AND: []
# Label AND1: ['conception', 'surgery', 'specialists', 'Syphilis']
# Model  AND: ['conception', 'surgery', 'are', 'specialists', 'Syphilis']
# AND1
# TP: 4, FP: 1, FN: 0, Label count: 4, Model count: 5
# NCT03864887_inc
# Label AND: ['people']
# Label AND1: ['trauma']
# Model  AND: ['trauma', 'people']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 2
# Label AND: ['people']
# Label AND1: ['trauma']
# Model  AND: ['trauma', 'people']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 2
# NCT03864913_exc
# Label AND: ['males']
# Label AND1: []
# Model  AND: ['males']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# Label AND: ['males']
# Label AND1: []
# Model  AND: ['males']
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# NCT03864913_inc
# Label AND: []
# Label AND1: ['Testosterone', 'naive', 'male']
# Model  AND: ['Testosterone', 'naive', 'male']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['Testosterone', 'naive', 'male']
# Model  AND: ['Testosterone', 'naive', 'male']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03865043_exc
# Label AND: []
# Label AND1: ['patient']
# Model  AND: ['patient']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# Label AND: []
# Label AND1: ['patient']
# Model  AND: ['patient']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# NCT03865043_inc
# Label AND: []
# Label AND1: ['Hospital', '2017', 'EDWARDS']
# Model  AND: ['Hospital', '2017', 'EDWARDS']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['Hospital', '2017', 'EDWARDS']
# Model  AND: ['Hospital', '2017', 'EDWARDS']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03865108_exc
# Label AND: ['Women']
# Label AND1: []
# Model  AND: ['Women']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# Label AND: ['Women']
# Label AND1: []
# Model  AND: ['Women']
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# NCT03865108_inc
# Label AND: ['days']
# Label AND1: ['gestation', 'is', 'age', 'are', 'eligible', 'Age', 'is']
# Model  AND: ['gestation', 'is', 'age', 'are', 'age', 'information', 'Age']
# AND
# TP: 0, FP: 1, FN: 1, Label count: 1, Model count: 7
# Label AND: ['days']
# Label AND1: ['gestation', 'is', 'age', 'are', 'eligible', 'Age', 'is']
# Model  AND: ['gestation', 'is', 'age', 'are', 'age', 'information', 'Age']
# AND1
# TP: 6, FP: 1, FN: 1, Label count: 7, Model count: 7
# NCT03865121_exc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03865121_inc
# Label AND: ['age']
# Label AND1: ['disease', 'Yahr', '', 'life', '', 'diseases', '', 'abnormalities', '', 'nicotine', 'spray', 'evaluations', 'dose', '', 'treatment', 'Criteria', '', 'protocol', 'reaction']
# Model  AND: ['age', 'disease', 'Yahr', '', 'life', '', 'diseases', '', 'abnormalities', '', 'treatment', 'Criteria', 'protocol', 'reaction', 'Death', 'dose', '', 'treatment', 'evaluations']
# AND
# TP: 1, FP: 1, FN: 0, Label count: 1, Model count: 19
# Label AND: ['age']
# Label AND1: ['disease', 'Yahr', '', 'life', '', 'diseases', '', 'abnormalities', '', 'nicotine', 'spray', 'evaluations', 'dose', '', 'treatment', 'Criteria', '', 'protocol', 'reaction']
# Model  AND: ['age', 'disease', 'Yahr', '', 'life', '', 'diseases', '', 'abnormalities', '', 'treatment', 'Criteria', 'protocol', 'reaction', 'Death', 'dose', '', 'treatment', 'evaluations']
# AND1
# TP: 17, FP: 1, FN: 2, Label count: 19, Model count: 19
# NCT03865134_exc
# Label AND: ['child']
# Label AND1: ['does', 'OCT', '', 'assessments', 'do']
# Model  AND: ['child', 'does', 'OCT', '', 'assessments', 'do']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 6
# Label AND: ['child']
# Label AND1: ['does', 'OCT', '', 'assessments', 'do']
# Model  AND: ['child', 'does', 'OCT', '', 'assessments', 'do']
# AND1
# TP: 5, FP: 0, FN: 0, Label count: 5, Model count: 6
# NCT03865134_inc
# Label AND: []
# Label AND1: ['age', 'weeks', 'prematurity', 'and', 'disease', 'evaluations']
# Model  AND: ['age', 'weeks', 'prematurity', 'and', 'disease', 'evaluations', 'children', 'study']
# AND
# TP: 0, FP: 2, FN: 0, Label count: 0, Model count: 8
# Label AND: []
# Label AND1: ['age', 'weeks', 'prematurity', 'and', 'disease', 'evaluations']
# Model  AND: ['age', 'weeks', 'prematurity', 'and', 'disease', 'evaluations', 'children', 'study']
# AND1
# TP: 6, FP: 2, FN: 0, Label count: 6, Model count: 8
# NCT03865199_exc
# Label AND: []
# Label AND1: ['include']
# Model  AND: ['include', 'speaking']
# AND
# TP: 0, FP: 1, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['include']
# Model  AND: ['include', 'speaking']
# AND1
# TP: 1, FP: 1, FN: 0, Label count: 1, Model count: 2
# NCT03865199_inc
# Label AND: []
# Label AND1: ['having']
# Model  AND: ['having']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# Label AND: []
# Label AND1: ['having']
# Model  AND: ['having']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# NCT03865420_exc
# Label AND: []
# Label AND1: ['HIV', 'B']
# Model  AND: ['HIV', 'B']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['HIV', 'B']
# Model  AND: ['HIV', 'B']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# NCT03865420_inc
# Label AND: ['diagnosis', 'testing']
# Label AND1: ['older', '', 'enrollment', 'mutation', 'results', 'procedures']
# Model  AND: ['older', '', 'enrollment', 'testing', 'mutation', 'results', 'procedures']
# AND
# TP: 1, FP: 0, FN: 1, Label count: 2, Model count: 7
# Label AND: ['diagnosis', 'testing']
# Label AND1: ['older', '', 'enrollment', 'mutation', 'results', 'procedures']
# Model  AND: ['older', '', 'enrollment', 'testing', 'mutation', 'results', 'procedures']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 6, Model count: 7
# NCT03865524_exc
# Label AND: []
# Label AND1: ['lactation', 'representative', 'devices', 'show', 'study', 'influence', 'realignment', 'TKA', '']
# Model  AND: ['lactation', 'representative', 'devices', 'show', 'study', 'influence', 'realignment', 'TKA', '']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 9
# Label AND: []
# Label AND1: ['lactation', 'representative', 'devices', 'show', 'study', 'influence', 'realignment', 'TKA', '']
# Model  AND: ['lactation', 'representative', 'devices', 'show', 'study', 'influence', 'realignment', 'TKA', '']
# AND1
# TP: 9, FP: 0, FN: 0, Label count: 9, Model count: 9
# NCT03865524_inc
# Label AND: []
# Label AND1: ['old', 'procedure', 'm2', 'osteoarthritis']
# Model  AND: ['old', 'procedure', 'm2', 'osteoarthritis']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 4
# Label AND: []
# Label AND1: ['old', 'procedure', 'm2', 'osteoarthritis']
# Model  AND: ['old', 'procedure', 'm2', 'osteoarthritis']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 4
# NCT03865602_exc
# Label AND: ['infection']
# Label AND1: ['arms', '2', 'hospital', 'and', 'infection', 'hospitals', 'treatment', 'infection']
# Model  AND: ['arms', '2', 'hospital', 'prophylaxis', 'and', 'resident', 'hospitals', 'do', 'do', 'hospitalization']
# AND
# TP: 0, FP: 5, FN: 1, Label count: 1, Model count: 10
# Label AND: ['infection']
# Label AND1: ['arms', '2', 'hospital', 'and', 'infection', 'hospitals', 'treatment', 'infection']
# Model  AND: ['arms', '2', 'hospital', 'prophylaxis', 'and', 'resident', 'hospitals', 'do', 'do', 'hospitalization']
# AND1
# TP: 5, FP: 5, FN: 3, Label count: 8, Model count: 10
# NCT03865602_inc
# Label AND: []
# Label AND1: ['of', 'Northeast', 'admission', 'and', 'or', 'Shock', 'models', '5']
# Model  AND: ['of', 'Northeast', 'admission', 'and', 'hours', 'oral', 'and']
# AND
# TP: 0, FP: 2, FN: 0, Label count: 0, Model count: 7
# Label AND: []
# Label AND1: ['of', 'Northeast', 'admission', 'and', 'or', 'Shock', 'models', '5']
# Model  AND: ['of', 'Northeast', 'admission', 'and', 'hours', 'oral', 'and']
# AND1
# TP: 5, FP: 2, FN: 4, Label count: 8, Model count: 7
# NCT03865693_exc
# Label AND: []
# Label AND1: ['history', 'surgery', 'pacemaker', 'diseases', 'disorder', 'mellitus', 'function']
# Model  AND: ['history', 'surgery', 'pacemaker', 'diseases', 'disorder', 'mellitus', 'function']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 7
# Label AND: []
# Label AND1: ['history', 'surgery', 'pacemaker', 'diseases', 'disorder', 'mellitus', 'function']
# Model  AND: ['history', 'surgery', 'pacemaker', 'diseases', 'disorder', 'mellitus', 'function']
# AND1
# TP: 7, FP: 0, FN: 0, Label count: 7, Model count: 7
# NCT03865693_inc
# Label AND: []
# Label AND1: ['patients']
# Model  AND: ['patients']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# Label AND: []
# Label AND1: ['patients']
# Model  AND: ['patients']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# NCT03865758_exc
# Label AND: []
# Label AND1: ['']
# Model  AND: ['']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# Label AND: []
# Label AND1: ['']
# Model  AND: ['']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# NCT03865758_inc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03865784_exc
# Label AND: ['boxers']
# Label AND1: ['diagnosis', 'months', 'skin']
# Model  AND: ['boxers', 'diagnosis', 'months', 'skin']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 4
# Label AND: ['boxers']
# Label AND1: ['diagnosis', 'months', 'skin']
# Model  AND: ['boxers', 'diagnosis', 'months', 'skin']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 4
# NCT03865784_inc
# Label AND: []
# Label AND1: ['boxers', 'years', 'Male', 'With']
# Model  AND: ['boxers', 'years', 'Male', 'With', 'does']
# AND
# TP: 0, FP: 1, FN: 0, Label count: 0, Model count: 5
# Label AND: []
# Label AND1: ['boxers', 'years', 'Male', 'With']
# Model  AND: ['boxers', 'years', 'Male', 'With', 'does']
# AND1
# TP: 4, FP: 1, FN: 0, Label count: 4, Model count: 5
# NCT03865810_exc
# Label AND: []
# Label AND1: ['surgery', 'procedures', '', 'surgery']
# Model  AND: ['surgery', 'procedures', '', 'surgery']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 4
# Label AND: []
# Label AND1: ['surgery', 'procedures', '', 'surgery']
# Model  AND: ['surgery', 'procedures', '', 'surgery']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 4
# NCT03865810_inc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03865823_exc
# Label AND: []
# Label AND1: ['Suppuration']
# Model  AND: ['Suppuration']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# Label AND: []
# Label AND1: ['Suppuration']
# Model  AND: ['Suppuration']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# NCT03865823_inc
# Label AND: ['fistula']
# Label AND1: []
# Model  AND: ['fistula']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# Label AND: ['fistula']
# Label AND1: []
# Model  AND: ['fistula']
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# NCT03865953_exc
# Label AND: ['DPN']
# Label AND1: ['NP']
# Model  AND: ['assessment']
# AND
# TP: 0, FP: 1, FN: 1, Label count: 1, Model count: 1
# Label AND: ['DPN']
# Label AND1: ['NP']
# Model  AND: ['assessment']
# AND1
# TP: 0, FP: 1, FN: 1, Label count: 1, Model count: 1
# NCT03865953_inc
# Label AND: ['neuralgia', 'mellitus', 'months', 'mmolmol', 'PDQ', 'pain', '4']
# Label AND1: ['OR', 'with', 'and', 'and', '3', 'study', 'by', 'and', 'DPN', 'and']
# Model  AND: ['OR', 'with', 'symmetrical', 'and', 'insulin', 'and', 'study', 'by', 'and', 'DPN', 'randomisation', 'scale', 'examination']
# AND
# TP: 0, FP: 5, FN: 7, Label count: 7, Model count: 13
# Label AND: ['neuralgia', 'mellitus', 'months', 'mmolmol', 'PDQ', 'pain', '4']
# Label AND1: ['OR', 'with', 'and', 'and', '3', 'study', 'by', 'and', 'DPN', 'and']
# Model  AND: ['OR', 'with', 'symmetrical', 'and', 'insulin', 'and', 'study', 'by', 'and', 'DPN', 'randomisation', 'scale', 'examination']
# AND1
# TP: 8, FP: 5, FN: 1, Label count: 10, Model count: 13
# NCT03866018_exc
# Label AND: []
# Label AND1: ['years', 'failure', '4', 'activity', 'deafness', 'disability', 'justice']
# Model  AND: ['years', 'failure', '4', 'activity', 'deafness', 'disability', 'justice']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 7
# Label AND: []
# Label AND1: ['years', 'failure', '4', 'activity', 'deafness', 'disability', 'justice']
# Model  AND: ['years', 'failure', '4', 'activity', 'deafness', 'disability', 'justice']
# AND1
# TP: 7, FP: 0, FN: 0, Label count: 7, Model count: 7
# NCT03866018_inc
# Label AND: []
# Label AND1: ['old', '30', 'etiology', 'Subject', 'impairment', 'Subject', 'activity', 'System']
# Model  AND: ['old', '30', 'etiology', 'Subject', 'impairment', 'Subject', 'activity', 'System']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 8
# Label AND: []
# Label AND1: ['old', '30', 'etiology', 'Subject', 'impairment', 'Subject', 'activity', 'System']
# Model  AND: ['old', '30', 'etiology', 'Subject', 'impairment', 'Subject', 'activity', 'System']
# AND1
# TP: 8, FP: 0, FN: 0, Label count: 8, Model count: 8
# NCT03866031_exc
# Label AND: []
# Label AND1: ['smokers', 'implants']
# Model  AND: ['steroids', 'implants']
# AND
# TP: 0, FP: 1, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['smokers', 'implants']
# Model  AND: ['steroids', 'implants']
# AND1
# TP: 1, FP: 1, FN: 1, Label count: 2, Model count: 2
# NCT03866031_inc
# Label AND: ['mm']
# Label AND1: ['months', 'relation', 'mm']
# Model  AND: ['months', 'relation', 'mm', 'mm']
# AND
# TP: 2, FP: 0, FN: 0, Label count: 1, Model count: 4
# Label AND: ['mm']
# Label AND1: ['months', 'relation', 'mm']
# Model  AND: ['months', 'relation', 'mm', 'mm']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 3, Model count: 4
# NCT03866057_exc
# Label AND: []
# Label AND1: ['rehabilitation', 'analysis', 'exacerbation', 'aphasia']
# Model  AND: ['rehabilitation', 'analysis', 'exacerbation', 'aphasia']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 4
# Label AND: []
# Label AND1: ['rehabilitation', 'analysis', 'exacerbation', 'aphasia']
# Model  AND: ['rehabilitation', 'analysis', 'exacerbation', 'aphasia']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 4
# NCT03866057_inc
# Label AND: []
# Label AND1: ['1890', 'days', 'data', 'Markers', 'subproject', 'subproject']
# Model  AND: ['1890', 'days', 'data', 'Markers', 'subproject', 'subproject']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 6
# Label AND: []
# Label AND1: ['1890', 'days', 'data', 'Markers', 'subproject', 'subproject']
# Model  AND: ['1890', 'days', 'data', 'Markers', 'subproject', 'subproject']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 6, Model count: 6
# NCT03866083_exc
# Label AND: ['20000', 'patients']
# ...
# AND1
# TP: 6, FP: 1, FN: 0, Label count: 6, Model count: 7
# NCT03928015_inc
# Label AND: []
# Label AND1: ['inclusive', 'injury', 'admission', 'NRS']
# Model  AND: ['inclusive', 'injury', 'admission', 'NRS', 'usage']
# AND
# TP: 0, FP: 1, FN: 0, Label count: 0, Model count: 5
# Label AND: []
# Label AND1: ['inclusive', 'injury', 'admission', 'NRS']
# Model  AND: ['inclusive', 'injury', 'admission', 'NRS', 'usage']
# AND1
# TP: 4, FP: 1, FN: 0, Label count: 4, Model count: 5
# NCT03928080_exc
# Label AND: []
# Label AND1: ['mouth', 'females', 'months']
# Model  AND: ['mouth', 'females', 'months']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['mouth', 'females', 'months']
# Model  AND: ['mouth', 'females', 'months']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03928080_inc
# Label AND: []
# Label AND1: ['above', 'toothbrush']
# Model  AND: ['above', 'toothbrush']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['above', 'toothbrush']
# Model  AND: ['above', 'toothbrush']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# NCT03928197_exc
# Label AND: ['Women']
# Label AND1: ['contraception', 'comorbidities', 'women', 'date']
# Model  AND: ['contraception', 'comorbidities', 'women', 'Women', 'date']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 5
# Label AND: ['Women']
# Label AND1: ['contraception', 'comorbidities', 'women', 'date']
# Model  AND: ['contraception', 'comorbidities', 'women', 'Women', 'date']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 5
# NCT03928197_inc
# Label AND: []
# Label AND1: ['years', '2']
# Model  AND: ['years', '2']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['years', '2']
# Model  AND: ['years', '2']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# NCT03928223_exc
# Label AND: []
# Label AND1: ['blindness', 'time', '']
# Model  AND: ['blindness', 'time', '']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['blindness', 'time', '']
# Model  AND: ['blindness', 'time', '']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03928223_inc
# Label AND: ['outpatients']
# Label AND1: []
# Model  AND: ['outpatients']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# Label AND: ['outpatients']
# Label AND1: []
# Model  AND: ['outpatients']
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# NCT03928392_exc
# Label AND: []
# Label AND1: ['age', '', 'recruitment', 'Has', 'dives', '']
# Model  AND: ['age', '', 'recruitment', 'Has', 'dives', '']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 6
# Label AND: []
# Label AND1: ['age', '', 'recruitment', 'Has', 'dives', '']
# Model  AND: ['age', '', 'recruitment', 'Has', 'dives', '']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 6, Model count: 6
# NCT03928392_inc
# Label AND: []
# Label AND1: ['age', 'months', 'dives']
# Model  AND: ['age', 'months', 'dives']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['age', 'months', 'dives']
# Model  AND: ['age', 'months', 'dives']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03928405_exc
# Label AND: []
# Label AND1: ['could', 'did', 'event', 'infection', 'radiotherapy', 'depression', 'above']
# Model  AND: ['could', 'did', 'event', 'infection', 'radiotherapy', 'depression', 'above']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 7
# Label AND: []
# Label AND1: ['could', 'did', 'event', 'infection', 'radiotherapy', 'depression', 'above']
# Model  AND: ['could', 'did', 'event', 'infection', 'radiotherapy', 'depression', 'above']
# AND1
# TP: 7, FP: 0, FN: 0, Label count: 7, Model count: 7
# NCT03928405_inc
# Label AND: []
# Label AND1: ['AD', '', 'problems', 'study', 'event', 'MS', 'scored']
# Model  AND: ['AD', '', 'problems', 'study', 'event', 'MS', 'scored']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 7
# Label AND: []
# Label AND1: ['AD', '', 'problems', 'study', 'event', 'MS', 'scored']
# Model  AND: ['AD', '', 'problems', 'study', 'event', 'MS', 'scored']
# AND1
# TP: 7, FP: 0, FN: 0, Label count: 7, Model count: 7
# NCT03928431_exc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03928431_inc
# Label AND: ['mothers']
# Label AND1: []
# Model  AND: ['mothers']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# Label AND: ['mothers']
# Label AND1: []
# Model  AND: ['mothers']
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# NCT03928522_exc
# Label AND: []
# Label AND1: ['capacity', 'allergy', 'allergy', 'perioperatively']
# Model  AND: ['capacity', 'allergy', 'allergy', 'perioperatively']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 4
# Label AND: []
# Label AND1: ['capacity', 'allergy', 'allergy', 'perioperatively']
# Model  AND: ['capacity', 'allergy', 'allergy', 'perioperatively']
# AND1
# TP: 4, FP: 0, FN: 0, Label count: 4, Model count: 4
# NCT03928522_inc
# Label AND: []
# Label AND1: ['18', 'Wright', 'osteoarthritis']
# Model  AND: ['18', 'Wright', 'osteoarthritis']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['18', 'Wright', 'osteoarthritis']
# Model  AND: ['18', 'Wright', 'osteoarthritis']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03928639_exc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03928639_inc
# Label AND: []
# Label AND1: ['years', 'site']
# Model  AND: ['years', 'site']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['years', 'site']
# Model  AND: ['years', 'site']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# NCT03928769_exc
# Label AND: []
# Label AND1: ['site']
# Model  AND: ['site']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# Label AND: []
# Label AND1: ['site']
# Model  AND: ['site']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# NCT03928769_inc
# Label AND: ['programmed']
# Label AND1: ['years', 'segment', 'patient', 'procedure', 'data']
# Model  AND: ['years', 'programmed', 'segment', 'patient', 'procedure', 'data']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 6
# Label AND: ['programmed']
# Label AND1: ['years', 'segment', 'patient', 'procedure', 'data']
# Model  AND: ['years', 'programmed', 'segment', 'patient', 'procedure', 'data']
# AND1
# TP: 5, FP: 0, FN: 0, Label count: 5, Model count: 6
# NCT03928795_exc
# Label AND: ['retardation']
# Label AND1: ['defect', 'adhesion', 'emergency', 'anesthesia', 'study', '', 'or']
# Model  AND: ['defect', 'adhesion', 'emergency', 'anesthesia', 'study', 'or']
# AND
# TP: 0, FP: 0, FN: 1, Label count: 1, Model count: 6
# Label AND: ['retardation']
# Label AND1: ['defect', 'adhesion', 'emergency', 'anesthesia', 'study', '', 'or']
# Model  AND: ['defect', 'adhesion', 'emergency', 'anesthesia', 'study', 'or']
# AND1
# TP: 6, FP: 0, FN: 1, Label count: 7, Model count: 6
# NCT03928795_inc
# Label AND: []
# Label AND1: ['pregnancy', 'old', '37SA']
# Model  AND: ['pregnancy', 'old', '37SA']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['pregnancy', 'old', '37SA']
# Model  AND: ['pregnancy', 'old', '37SA']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03928834_exc
# Label AND: []
# Label AND1: ['assent']
# Model  AND: ['assent']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# Label AND: []
# Label AND1: ['assent']
# Model  AND: ['assent']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# NCT03928834_inc
# Label AND: ['initiation']
# Label AND1: ['status', 'records']
# Model  AND: ['status', 'initiation', 'records']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 3
# Label AND: ['initiation']
# Label AND1: ['status', 'records']
# Model  AND: ['status', 'initiation', 'records']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 3
# NCT03929055_exc
# Label AND: []
# Label AND1: ['is', 'is', 'is']
# Model  AND: ['is', 'is', 'is']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['is', 'is', 'is']
# Model  AND: ['is', 'is', 'is']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03929055_inc
# Label AND: ['intubated']
# Label AND1: ['failure']
# Model  AND: ['failure', 'intubated']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 2
# Label AND: ['intubated']
# Label AND1: ['failure']
# Model  AND: ['failure', 'intubated']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 2
# NCT03929198_exc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03929198_inc
# Label AND: ['pressure']
# Label AND1: ['visit', 'males', 'medication', 'higher', '', 'year', '', 'year', 'exercise', '']
# Model  AND: ['pressure', 'visit', 'males', 'medication', 'higher', '', 'year', '', 'year', 'exercise', '']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 11
# Label AND: ['pressure']
# Label AND1: ['visit', 'males', 'medication', 'higher', '', 'year', '', 'year', 'exercise', '']
# Model  AND: ['pressure', 'visit', 'males', 'medication', 'higher', '', 'year', '', 'year', 'exercise', '']
# AND1
# TP: 10, FP: 0, FN: 0, Label count: 10, Model count: 11
# NCT03929276_exc
# Label AND: []
# Label AND1: ['capsulitis', 'infection', 'months', 'surgery', 'lesion', 'disease']
# Model  AND: ['capsulitis', 'infection', 'months', 'surgery', 'lesion', 'disease']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 6
# Label AND: []
# Label AND1: ['capsulitis', 'infection', 'months', 'surgery', 'lesion', 'disease']
# Model  AND: ['capsulitis', 'infection', 'months', 'surgery', 'lesion', 'disease']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 6, Model count: 6
# NCT03929276_inc
# Label AND: []
# Label AND1: ['motion', 'month', '']
# Model  AND: ['motion', 'month', '']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['motion', 'month', '']
# Model  AND: ['motion', 'month', '']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03929380_exc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03929380_inc
# Label AND: ['Males']
# Label AND1: []
# Model  AND: ['Males']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# Label AND: ['Males']
# Label AND1: []
# Model  AND: ['Males']
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# NCT03929406_exc
# Label AND: []
# Label AND1: ['Patient', 'surgery', 'mothers', 'decision', 'protected']
# Model  AND: ['Patient', 'surgery', 'mothers', 'decision', 'protected']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 5
# Label AND: []
# Label AND1: ['Patient', 'surgery', 'mothers', 'decision', 'protected']
# Model  AND: ['Patient', 'surgery', 'mothers', 'decision', 'protected']
# AND1
# TP: 5, FP: 0, FN: 0, Label count: 5, Model count: 5
# NCT03929406_inc
# Label AND: []
# Label AND1: ['surgery', 'scheme']
# Model  AND: ['surgery', 'scheme']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['surgery', 'scheme']
# Model  AND: ['surgery', 'scheme']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# NCT03929536_exc
# Label AND: []
# Label AND1: ['metastasis']
# Model  AND: ['metastasis']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 1
# Label AND: []
# Label AND1: ['metastasis']
# Model  AND: ['metastasis']
# AND1
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 1
# NCT03929536_inc
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# Label AND: []
# Label AND1: []
# Model  AND: []
# AND1
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 0
# NCT03929614_exc
# Label AND: []
# Label AND1: ['curvature', 'disorder']
# Model  AND: ['curvature', 'disorder']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['curvature', 'disorder']
# Model  AND: ['curvature', 'disorder']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# NCT03929614_inc
# Label AND: ['old']
# Label AND1: ['AIS', 'treatment', 'French']
# Model  AND: ['AIS', 'old', 'treatment', 'French', 'Physical']
# AND
# TP: 1, FP: 1, FN: 0, Label count: 1, Model count: 5
# Label AND: ['old']
# Label AND1: ['AIS', 'treatment', 'French']
# Model  AND: ['AIS', 'old', 'treatment', 'French', 'Physical']
# AND1
# TP: 3, FP: 1, FN: 0, Label count: 3, Model count: 5
# NCT03929822_exc
# Label AND: []
# Label AND1: ['old', 'abnormalities', 'patients', 'patients', 'contrast', '45']
# Model  AND: ['old', 'abnormalities', 'patients', 'patients', 'contrast', '45']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 6
# Label AND: []
# Label AND1: ['old', 'abnormalities', 'patients', 'patients', 'contrast', '45']
# Model  AND: ['old', 'abnormalities', 'patients', 'patients', 'contrast', '45']
# AND1
# TP: 6, FP: 0, FN: 0, Label count: 6, Model count: 6
# NCT03929822_inc
# Label AND: ['tomosynthesis', 'pregnancy']
# Label AND1: ['or']
# Model  AND: ['distortion', 'or']
# AND
# TP: 0, FP: 1, FN: 2, Label count: 2, Model count: 2
# Label AND: ['tomosynthesis', 'pregnancy']
# Label AND1: ['or']
# Model  AND: ['distortion', 'or']
# AND1
# TP: 1, FP: 1, FN: 0, Label count: 1, Model count: 2
# NCT03929887_exc
# Label AND: []
# Label AND1: ['consent', '']
# Model  AND: ['consent', '']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['consent', '']
# Model  AND: ['consent', '']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# NCT03929887_inc
# Label AND: []
# Label AND1: ['definitions', '2010', 'site']
# Model  AND: ['definitions', '2010', 'site']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['definitions', '2010', 'site']
# Model  AND: ['definitions', '2010', 'site']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03929900_exc
# Label AND: ['failure']
# Label AND1: ['disease', 'consent', 'dialysis', 'transplant', '4', '3', 'women', 'donation', 'year']
# Model  AND: ['disease', 'consent', 'dialysis', 'transplant', 'failure', '4', '3', 'women', 'donation', 'year']
# AND
# TP: 1, FP: 0, FN: 0, Label count: 1, Model count: 10
# Label AND: ['failure']
# Label AND1: ['disease', 'consent', 'dialysis', 'transplant', '4', '3', 'women', 'donation', 'year']
# Model  AND: ['disease', 'consent', 'dialysis', 'transplant', 'failure', '4', '3', 'women', 'donation', 'year']
# AND1
# TP: 9, FP: 0, FN: 0, Label count: 9, Model count: 10
# NCT03929900_inc
# Label AND: []
# Label AND1: ['years', 'equation']
# Model  AND: ['years', 'equation']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['years', 'equation']
# Model  AND: ['years', 'equation']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# NCT03930901_exc
# Label AND: []
# Label AND1: ['1', 'diseases', 'consent']
# Model  AND: ['1', 'diseases', 'consent']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 3
# Label AND: []
# Label AND1: ['1', 'diseases', 'consent']
# Model  AND: ['1', 'diseases', 'consent']
# AND1
# TP: 3, FP: 0, FN: 0, Label count: 3, Model count: 3
# NCT03930901_inc
# Label AND: []
# Label AND1: ['6', 'ethnicity']
# Model  AND: ['6', 'ethnicity']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['6', 'ethnicity']
# Model  AND: ['6', 'ethnicity']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2
# NCT03934346_exc
# Label AND: []
# Label AND1: ['abuse', 'both', 'meat']
# Model  AND: ['abuse', 'both', 'those', 'meat']
# AND
# TP: 0, FP: 1, FN: 0, Label count: 0, Model count: 4
# Label AND: []
# Label AND1: ['abuse', 'both', 'meat']
# Model  AND: ['abuse', 'both', 'those', 'meat']
# AND1
# TP: 3, FP: 1, FN: 0, Label count: 3, Model count: 4
# NCT03934346_inc
# Label AND: []
# Label AND1: ['men', 'kgm2']
# Model  AND: ['men', 'kgm2']
# AND
# TP: 0, FP: 0, FN: 0, Label count: 0, Model count: 2
# Label AND: []
# Label AND1: ['men', 'kgm2']
# Model  AND: ['men', 'kgm2']
# AND1
# TP: 2, FP: 0, FN: 0, Label count: 2, Model count: 2

# %%
all_metrics
# Out:
# {'llama3_8b_Lora_ep10_r256_prompt1_train_only_p4': {'AND': {'precision': 61.53846153846154,
#    'recall': 78.43137254901961,
#    'f1': 68.96551724137932,
#    'accuracy': 78.43137254901961,
#    'total_label': 150,
#    'total_model': 1524,
#    'correct_count': 120,
#    'low_tp_ncts': ['NCT03865953_inc']},
#   'AND1': {'precision': 94.6958981612447,
#    'recall': 94.6958981612447,
#    'f1': 94.6958981612447,
#    'accuracy': 94.6958981612447,
#    'total_label': 1407,
#    'total_model': 1524,
#    'correct_count': 1339,
#    'low_tp_ncts': ['NCT03921437_exc', 'NCT03927781_exc']},
#   'OR': {'precision': 90.21897810218978,
#    'recall': 86.0724233983287,
#    'f1': 88.09693513898789,
#    'accuracy': 86.0724233983287,
#    'total_label': 718,
#    'total_model': 683,
#    'correct_count': 618,
#    'low_tp_ncts': ['NCT03921437_exc', 'NCT03865953_inc']},
#   'NOT': {'precision': 87.13450292397661,
#    'recall': 84.6590909090909,
#    'f1': 85.87896253602305,
#    'accuracy': 84.6590909090909,
#    'total_label': 176,
#    'total_model': 171,
#    'correct_count': 149,
#    'low_tp_ncts': ['NCT03921437_exc']},
#   'average_missing_percentage': 0.9099545859583257,
#   'average': {'precision': 83.39696018146816,
#    'recall': 85.96469625442097,
#    'f1': 84.40932826940875,
#    'accuracy': 85.96469625442097}}}

# %%
plot_avg_metrics(all_metrics)

# %%
def plot_operator_metrics(all_metrics):
    operators = ['AND', 'AND1', 'OR', 'NOT']
    metrics_to_plot = ['precision', 'recall', 'f1']
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c']  # Farben für Precision, Recall, F1

    sota_metrics = {
        'SciBERT': {
            'AND': {'precision': 54.1, 'recall': 60.0, 'f1': 56.9},
            'AND1': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0}, 
            'NOT': {'precision': 74.3, 'recall': 91.0, 'f1': 81.8},
            'OR': {'precision': 85.1, 'recall': 93.2, 'f1': 89.0}
        }
    }

    for i, op in enumerate(operators):
        plt.figure(figsize=(12, 8))  # Größere Figur

        model_names = ['SOTA'] + [e.replace('_p4_ep10_p1', '') for e in list(all_metrics.keys())]
        metric_values = {metric: [] for metric in metrics_to_plot}

        # SOTA-Metriken hinzufügen
        for metric in metrics_to_plot:
            metric_values[metric].append(sota_metrics['SciBERT'][op][metric])

        # Andere Modellmetriken hinzufügen
        for model, model_metrics in all_metrics.items():
            for metric in metrics_to_plot:
                metric_values[metric].append(model_metrics[op][metric])

        x = np.arange(len(model_names))
        bar_width = 0.25
        opacity = 0.8

        for j, metric in enumerate(metrics_to_plot):
            plt.bar(x + j * bar_width, metric_values[metric], bar_width,
                    alpha=opacity, label=metric.capitalize(), color=colors[j])

        plt.xlabel('Models', fontsize=14, labelpad=10)
        plt.ylabel('Score (%)', fontsize=14, labelpad=10)
        plt.title(f'Evaluation: {op}', fontsize=18, pad=20)  # Mehr Abstand nach dem Titel
        plt.xticks(x + bar_width, model_names, rotation=45, ha='right', fontsize=12)
        plt.ylim(0, 110)  # Erhöhung des y-Limits für mehr Platz oben
        plt.legend(fontsize=12, loc='upper center', ncol=3)  # Legende unter dem Plot
        plt.grid(axis='y', linestyle='--', alpha=0.7)

        # Werte über den Balken anzeigen
        for j, metric in enumerate(metrics_to_plot):
            for k, v in enumerate(metric_values[metric]):
                plt.text(k + j * bar_width, v + 2, f'{v:.1f}%',
                         ha='center', va='bottom', fontsize=10)

        plt.tight_layout()
        plt.savefig(f'data/pics/operator_metrics_{op}.png', bbox_inches='tight')
        plt.show()

# %%
plot_operator_metrics(all_metrics)

# %%
def latex_operator_metrics_table(all_metrics):
    operators = ['AND', 'AND1', 'OR', 'NOT']
    metrics_to_plot = ['precision', 'recall', 'f1']

    sota_metrics = {
        'SciBERT': {
            'AND': {'precision': 54.1, 'recall': 60.0, 'f1': 56.9},
            'AND1': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0},
            'NOT': {'precision': 74.3, 'recall': 91.0, 'f1': 81.8},
            'OR': {'precision': 85.1, 'recall': 93.2, 'f1': 89.0}
        }
    }

    latex_table = r"\begin{table}[!ht]" + "\n"
    latex_table += r"\centering" + "\n"
    latex_table += r"\small" + "\n"
    latex_table += r"\begin{tabular}{llrrrrr}" + "\n"  # Eine weitere Spalte für den Durchschnittswert
    latex_table += r"\toprule" + "\n"
    latex_table += r"\textbf{Model} & \textbf{Metrik} & \multicolumn{4}{c}{\textbf{Operator}} & \textbf{Durchschnitt} \\" + "\n"
    latex_table += r"\cmidrule(lr){3-6}" + "\n"
    latex_table += r"& & AND & AND1 & OR & NOT & \\" + "\n"
    latex_table += r"\midrule" + "\n"

    model_names = ['SOTA'] + list(all_metrics.keys())

    for model in model_names:
        model_display = 'SOTA\n(SciBERT)' if model == 'SOTA' else 'Llama3 70B\n(Fine-Tuned)'
        for i, metric in enumerate(metrics_to_plot):
            metric_display = 'Precision' if metric == 'precision' else 'Recall' if metric == 'recall' else 'F1-Score'
            latex_table += f"{model_display if i == 0 else ''} & {metric_display}"
            values = []
            for op in operators:
                if model == 'SOTA':
                    value = sota_metrics['SciBERT'][op][metric]
                else:
                    value = all_metrics[model][op][metric]
                latex_table += f" & {value:.1f}"
                if op != 'AND1':  # AND1 nicht in die Durchschnittsberechnung einbeziehen
                    values.append(value)
            average_value = sum(values) / len(values)  # Durchschnitt berechnen ohne AND1
            latex_table += f" & {average_value:.1f}"  # Durchschnittswert hinzufügen
            latex_table += r" \\" + "\n"
        if model != model_names[-1]:
            latex_table += r"\midrule" + "\n"

    latex_table += r"\bottomrule" + "\n"
    latex_table += r"\end{tabular}" + "\n"
    latex_table += r"\caption{Vergleich der Operatormetriken für SOTA (SciBERT) und Llama3 70B (Fine-Tuned)}" + "\n"
    latex_table += r"\label{tab:operator_metrics}" + "\n"
    latex_table += r"\end{table}"

    return latex_table

# Beispielaufruf:
print(latex_operator_metrics_table(all_metrics))
# Out:
# \begin{table}[!ht]
# \centering
# \small
# \begin{tabular}{llrrrrr}
# \toprule
# \textbf{Model} & \textbf{Metrik} & \multicolumn{4}{c}{\textbf{Operator}} & \textbf{Durchschnitt} \\
# \cmidrule(lr){3-6}
# & & AND & AND1 & OR & NOT & \\
# \midrule
# SOTA
# (SciBERT) & Precision & 54.1 & 0.0 & 85.1 & 74.3 & 71.2 \\
#  & Recall & 60.0 & 0.0 & 93.2 & 91.0 & 81.4 \\
#  & F1-Score & 56.9 & 0.0 & 89.0 & 81.8 & 75.9 \\
# \midrule
# Llama3 70B
# (Fine-Tuned) & Precision & 61.5 & 94.7 & 90.2 & 87.1 & 79.6 \\
#  & Recall & 78.4 & 94.7 & 86.1 & 84.7 & 83.1 \\
#  & F1-Score & 69.0 & 94.7 & 88.1 & 85.9 & 81.0 \\
# \bottomrule
# \end{tabular}
# \caption{Vergleich der Operatormetriken für SOTA (SciBERT) und Llama3 70B (Fine-Tuned)}
# \label{tab:operator_metrics}
# \end{table}
