# %%
import tensorflow as tf

tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\e-aut\AppData\Local\Temp\ipykernel_23980\501657313.py:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %%
print(tf.reduce_sum(tf.random.normal([1000, 1000])))
# Out:
# tf.Tensor(149.54646, shape=(), dtype=float32)
