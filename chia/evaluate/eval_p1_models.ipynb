# %% [markdown]
# #### Versuch exact matching zu evaluieren

# %%
import os
import re
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from eval_p1_functions import *

# %%
def read_file(file_path):
    with open(file_path, 'r', encoding="utf-8") as file:
        return file.read()

def extract_nct_number(filename):
    match = re.search(r'(NCT\d+_(exc|inc))', filename)
    return match.group(1) if match else None

def extract_operators(text):
    operators = re.findall(r'\[(AND|OR|NOT)\]', text)
    return operators

def find_operator_words(text, operators):
    words = {op: [] for op in operators}
    word_list = text.split()
    for i, word in enumerate(word_list):
        if word in ["[AND]", "[OR]", "[NOT]"]:
            operator = word[1:-1]
            if operator in ['AND', 'OR', 'NOT'] and i - 1 >= 0: # Wort vor dem Operator
                prev_word = re.sub(r'[^\w]', '', word_list[i - 1])  # Entferne Satzzeichen
                words[operator].append(prev_word)
    return words

# %%
def compare_operators(label_text, model_text, operator):
    label_operators = extract_operators(label_text)
    model_operators = extract_operators(model_text)

    label_words_dict = find_operator_words(label_text, label_operators)
    model_words_dict = find_operator_words(model_text, model_operators)

    
    
    label_words = label_words_dict.get(operator, [])
    model_words = model_words_dict.get(operator, [])
    print("label_words_dict",label_words)
    print("model_words_dict",model_words)
    print([word for word in label_words if word in model_words])
    
    tp = sum(1 for word in label_words if word in model_words)
    fp = sum(1 for word in model_words if word not in label_words)
    fn = sum(1 for word in label_words if word not in model_words)

    return tp, fp, fn, len(label_words), len(model_words)

def calculate_metrics(tp, fp, fn):
    precision = tp / (tp + fp) if tp + fp > 0 else 0
    recall = tp / (tp + fn) if tp + fn > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if precision + recall > 0 else 0
    accuracy = tp / (tp + fn) if tp + fn > 0 else 0
    return precision, recall, f1, accuracy

# %%
def evaluate_models(label_folder, model_folder,model_name, output_folder="excel_eval"):
    operators = ['AND', 'OR', 'NOT']
    metrics = {op: {'tp': 0, 'fp': 0, 'fn': 0, 'label_count': 0, 'model_count': 0, 'correct_count': 0, 'correct_ncts': set(), 'low_tp_ncts': set()} for op in operators}
    processed_label_files = 0
    model_results = []

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for model_file in os.listdir(model_folder):
        if model_file.endswith('.txt'):
            nct_number = extract_nct_number(model_file)
            print("nct_number",nct_number)
            if nct_number:
                label_file_path = os.path.join(label_folder, f'{nct_number}.txt')
                model_file_path = os.path.join(model_folder, model_file)
                print("label_file_path",label_file_path)
                print("model_file_path",model_file_path)


                if os.path.exists(label_file_path):
                    processed_label_files += 1
                    label_text = read_file(label_file_path)
                    model_text = read_file(model_file_path)

                    model_data = {'nct_number': nct_number}

                    for op in operators:
                        tp, fp, fn, label_count, model_count = compare_operators(label_text, model_text, op)

                        metrics[op]['tp'] += tp
                        metrics[op]['fp'] += fp
                        metrics[op]['fn'] += fn
                        metrics[op]['label_count'] += label_count
                        metrics[op]['model_count'] += model_count
                        metrics[op]['correct_count'] += tp

                        model_data[f'{op}_tp'] = tp
                        model_data[f'{op}_fp'] = fp
                        model_data[f'{op}_fn'] = fn
                        model_data[f'{op}_label_count'] = label_count
                        model_data[f'{op}_model_count'] = model_count

                        if tp > 0:
                            metrics[op]['correct_ncts'].add(nct_number)
                        if tp == 0 and fn > 4:
                            metrics[op]['low_tp_ncts'].add(nct_number)

                    model_results.append(model_data)

    results = {}
    for op in operators:
        precision, recall, f1, accuracy = calculate_metrics(metrics[op]['tp'], metrics[op]['fp'], metrics[op]['fn'])
        results[op] = {
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'accuracy': accuracy,
            'total_label': metrics[op]['label_count'],
            'total_model': metrics[op]['model_count'],
            'correct_count': metrics[op]['correct_count'],
            'low_tp_ncts': list(metrics[op]['low_tp_ncts'])  # Konvertiere das Set zurück in eine Liste für die Ausgabe
        }


    df_results = pd.DataFrame(model_results)
    excel_path = os.path.join(output_folder, f'{model_name}_evaluation_results.xlsx')
    #with pd.ExcelWriter(excel_path) as writer:
    #    df_results.to_excel(writer, sheet_name='Model Results', index=False)

    return results

# %%
versuch_ordner = "eval_p1/" # "eval_p1_n_shot/" # "eval_p1/"


label_folder = '../input/chia_p1'
model_output_folder = versuch_ordner + 'model_output'

models = [folder for folder in os.listdir(model_output_folder) if os.path.isdir(os.path.join(model_output_folder, folder))]

# %%
all_metrics = {}

for model in models:
    model_folder = os.path.join(model_output_folder, model, 'output')
    metrics = evaluate_models(label_folder, model_folder, model)
    for op in metrics:
        for metric in metrics[op]:
            metrics[op][metric] *= 100

    all_metrics[model] = metrics
# Out:
# nct_number NCT00050349_exc
# label_file_path ../input/chia_p1/NCT00050349_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00050349_exc_0_shot.txt
# label_words_dict ['of', 'metastases', 'metastases', 'diarrhea', 'insufficiency', 'agents', 'less']
# model_words_dict ['insufficiency', 'therapies']
# ['insufficiency']
# label_words_dict ['metastases', 'treated', 'months', 'neuropathy', 'Coumadin', 'dose', 'lines', 'active', 'acute', 'abcesses', 'medical', 'study', 'consent', 'regimens', 'inability', 'Pregnant']
# model_words_dict ['metastases', 'response', 'months', 'neuropathy', 'Coumadin', 'lines', 'cancer', 'active', 'acute', 'abcesses', 'medical', 'study', 'regimens', 'inability', 'Pregnant']
# ['metastases', 'months', 'neuropathy', 'Coumadin', 'lines', 'active', 'acute', 'abcesses', 'medical', 'study', 'regimens', 'inability', 'Pregnant']
# label_words_dict ['AND', 'AND', 'entry']
# model_words_dict ['visits', 'patients']
# []
# nct_number NCT00050349_inc
# label_file_path ../input/chia_p1/NCT00050349_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00050349_inc_0_shot.txt
# label_words_dict ['VIPomas', 'ULN', 'Female']
# model_words_dict ['Gastrinomas', 'entry', 'months']
# []
# label_words_dict ['tumors', 'Gastrinomas', 'irradiated', 'renal', 'bilirubin', 'ULN', 'oophorectomy', 'hysterectomy']
# model_words_dict ['tumors', 'irradiated', 'renal', 'hysterectomy']
# ['tumors', 'irradiated', 'renal', 'hysterectomy']
# label_words_dict ['either', 'has']
# model_words_dict ['either', 'has']
# ['either', 'has']
# nct_number NCT00061308_exc
# label_file_path ../input/chia_p1/NCT00061308_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00061308_exc_0_shot.txt
# label_words_dict ['potential', 'infection', 'radiation']
# model_words_dict []
# []
# label_words_dict ['Pregnant', 'Concomitant', 'cell', 'topotecan', 'camptothecin']
# model_words_dict ['Pregnant', 'Concomitant', 'cell', 'carcinoid', 'topotecan', 'camptothecin']
# ['Pregnant', 'Concomitant', 'cell', 'topotecan', 'camptothecin']
# label_words_dict ['that', 'with']
# model_words_dict ['do']
# []
# nct_number NCT00061308_inc
# label_file_path ../input/chia_p1/NCT00061308_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00061308_inc_0_shot.txt
# label_words_dict ['regimen']
# model_words_dict ['platinum']
# []
# label_words_dict ['surgery']
# model_words_dict ['surgery', '01']
# ['surgery']
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00094861_exc
# label_file_path ../input/chia_p1/NCT00094861_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00094861_exc_0_shot.txt
# label_words_dict ['treatment', 'toxicity', 'treatment', 'sensitivity']
# model_words_dict ['malignancy', 'consent', 'study']
# []
# label_words_dict ['Pleural', 'tomography', 'tomography', 'dysphagia', 'disease', 'investigational', 'productdevice', 'for', 'Pregnant', 'consent', 'form']
# model_words_dict ['Pleural', 'scan', 'radiotherapy', 'cancer', 'Presence', 'dysphagia', 'weeks', 'study', 'study', 'HCV', 'Pregnant', 'Unwilling', 'familial']
# ['Pleural', 'dysphagia', 'Pregnant']
# label_words_dict ['years', 'prior']
# model_words_dict ['than', 'are']
# []
# nct_number NCT00094861_inc
# label_file_path ../input/chia_p1/NCT00094861_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00094861_inc_0_shot.txt
# label_words_dict ['Females', 'capability']
# model_words_dict ['0', '1', 'gdL', '109L', 'mgdL', '14']
# []
# label_words_dict ['histologically', 'stage', 'than', 'than', 'than', 'than', 'support', 'than', 'than', 'than', 'mgdL', 'than', 'than', 'than', 'serum', 'studyspecific']
# model_words_dict ['histologically', 'IIIa', 'age', 'support', 'serum', 'randomization']
# ['histologically', 'support', 'serum']
# label_words_dict ['gdL', '109L']
# model_words_dict ['potential']
# []
# nct_number NCT00122070_exc
# label_file_path ../input/chia_p1/NCT00122070_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00122070_exc_0_shot.txt
# label_words_dict []
# model_words_dict ['SCIDI', 'period']
# []
# label_words_dict ['pregnant', 'drugs', 'Disorder']
# model_words_dict ['pregnant', 'drugs', 'Disorder', 'examination']
# ['pregnant', 'drugs', 'Disorder']
# label_words_dict []
# model_words_dict ['Patients', 'may']
# []
# nct_number NCT00122070_inc
# label_file_path ../input/chia_p1/NCT00122070_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00122070_inc_0_shot.txt
# label_words_dict ['BPD']
# model_words_dict ['18', 'read', 'English']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00182520_exc
# label_file_path ../input/chia_p1/NCT00182520_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00182520_exc_0_shot.txt
# label_words_dict ['hypersensitivity']
# model_words_dict ['topiramate']
# []
# label_words_dict ['disorder', 'therapy', 'Allergy']
# model_words_dict ['disorder', 'disorder', 'schizophrenia', 'disorder', 'therapy', 'Allergy']
# ['disorder', 'therapy', 'Allergy']
# label_words_dict []
# model_words_dict ['months', 'topiramate', '20']
# []
# nct_number NCT00182520_inc
# label_file_path ../input/chia_p1/NCT00182520_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00182520_inc_0_shot.txt
# label_words_dict ['Outpatient', 'to']
# model_words_dict ['OCD', 'mgday', 'antipsychotics']
# []
# label_words_dict ['fluoxetine', 'paroxetine', 'fluvoxamine', 'clomipramine', 'sertraline', 'citalopram', 'CGII', '3']
# model_words_dict ['3']
# ['3']
# label_words_dict []
# model_words_dict ['a']
# []
# nct_number NCT00183885_exc
# label_file_path ../input/chia_p1/NCT00183885_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00183885_exc_0_shot.txt
# label_words_dict ['chemotherapy', 'B', 'C', 'potential']
# model_words_dict ['lamivudine', 'Men']
# []
# label_words_dict ['consent', 'Pregnant']
# model_words_dict ['active', 'consent', 'Pregnant']
# ['consent', 'Pregnant']
# label_words_dict []
# model_words_dict ['may']
# []
# nct_number NCT00183885_inc
# label_file_path ../input/chia_p1/NCT00183885_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00183885_inc_0_shot.txt
# label_words_dict ['histologically', 'to', 'function', 'function']
# model_words_dict ['liver', 'ngmL', '02', 'gmdl', 'hypersplenism', '60']
# []
# label_words_dict []
# model_words_dict ['biopsyresection', 'ascites']
# []
# label_words_dict ['Patients']
# model_words_dict ['is', 'opinion', 'may']
# []
# nct_number NCT00198913_exc
# label_file_path ../input/chia_p1/NCT00198913_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00198913_exc_0_shot.txt
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['diabetic']
# model_words_dict ['diabetic']
# ['diabetic']
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00198913_inc
# label_file_path ../input/chia_p1/NCT00198913_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00198913_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['diabetic', 'over']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00235170_exc
# label_file_path ../input/chia_p1/NCT00235170_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00235170_exc_0_shot.txt
# label_words_dict ['infarction', 'pain', 'of']
# model_words_dict ['days']
# []
# label_words_dict ['CABG', 'surgery', 'surgery', 'of', 'aortic']
# model_words_dict ['CABG', 'surgery', 'aortic']
# ['CABG', 'surgery', 'surgery', 'aortic']
# label_words_dict ['CK']
# model_words_dict ['has']
# []
# nct_number NCT00235170_inc
# label_file_path ../input/chia_p1/NCT00235170_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00235170_inc_0_shot.txt
# label_words_dict ['documented', 'amenable', 'one']
# model_words_dict ['pectoris', 'vessels', 'LAD', 'branch', 'circumflex', 'included', 'month']
# []
# label_words_dict ['stable', 'angioplasty', 'occluded', 'duration']
# model_words_dict ['3', 'ischemia', 'pain', 'angioplasty', 'disease', 'vessel', 'duration', 'interpretation']
# ['angioplasty', 'duration']
# label_words_dict []
# model_words_dict ['should', 'included']
# []
# nct_number NCT00236340_exc
# label_file_path ../input/chia_p1/NCT00236340_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00236340_exc_0_shot.txt
# label_words_dict ['of', 'Fetus']
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['fetuses', 'abruptio', 'IUGR', 'preeclampsia']
# []
# label_words_dict ['preeclampsia']
# model_words_dict ['OR']
# []
# nct_number NCT00236340_inc
# label_file_path ../input/chia_p1/NCT00236340_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00236340_inc_0_shot.txt
# label_words_dict ['ultrasound', 'twin']
# model_words_dict ['discomfort', 'AFI25cm']
# []
# label_words_dict ['Single']
# model_words_dict ['Single']
# ['Single']
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00250640_exc
# label_file_path ../input/chia_p1/NCT00250640_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00250640_exc_0_shot.txt
# label_words_dict ['contraindications']
# model_words_dict ['study', 'pregnancy', 'Characteristics']
# []
# label_words_dict ['pregnancy']
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00250640_inc
# label_file_path ../input/chia_p1/NCT00250640_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00250640_inc_0_shot.txt
# label_words_dict ['hypertension', 'hypertension']
# model_words_dict ['patient', 'Hypertension', 'Association']
# []
# label_words_dict ['Hypertension', 'Ventavis']
# model_words_dict ['Hypertension', 'Ventavis']
# ['Hypertension', 'Ventavis']
# label_words_dict ['Association']
# model_words_dict ['AND']
# []
# nct_number NCT00279552_exc
# label_file_path ../input/chia_p1/NCT00279552_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00279552_exc_0_shot.txt
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['pregnant', 'nursing']
# []
# label_words_dict ['or']
# model_words_dict ['OR']
# []
# nct_number NCT00279552_inc
# label_file_path ../input/chia_p1/NCT00279552_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00279552_inc_0_shot.txt
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00305097_exc
# label_file_path ../input/chia_p1/NCT00305097_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00305097_exc_0_shot.txt
# label_words_dict ['of']
# model_words_dict ['GERD']
# []
# label_words_dict ['that', 'pregnancy', 'function', 'function', 'glucose', 'alcoholism', 'abuse']
# model_words_dict ['outcomes', 'pregnancy', 'range', 'mgdl', 'mgdl', 'alcoholism', 'abuse']
# ['pregnancy', 'alcoholism', 'abuse']
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00305097_inc
# label_file_path ../input/chia_p1/NCT00305097_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00305097_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['years', 'ability', 'day']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['interventions']
# []
# nct_number NCT00312429_exc
# label_file_path ../input/chia_p1/NCT00312429_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00312429_exc_0_shot.txt
# label_words_dict []
# model_words_dict ['entry', 'participation']
# []
# label_words_dict ['participation']
# model_words_dict ['medical', 'Pregnant']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00312429_inc
# label_file_path ../input/chia_p1/NCT00312429_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00312429_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['center', 'Cancer', 'creatinine', 'performed', 'fraction', 'study']
# []
# label_words_dict ['disease']
# model_words_dict ['disease', 'cardiology', 'heart']
# ['disease']
# label_words_dict []
# model_words_dict ['AND']
# []
# nct_number NCT00317148_exc
# label_file_path ../input/chia_p1/NCT00317148_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00317148_exc_0_shot.txt
# label_words_dict ['products']
# model_words_dict ['metabolic']
# []
# label_words_dict ['metabolic', 'steroids', 'systemic', 'therapies', 'fibroids']
# model_words_dict ['kgm2', 'steroids', 'progestin', 'therapies', 'fibroids', '2']
# ['steroids', 'therapies', 'fibroids']
# label_words_dict []
# model_words_dict ['more', 'diseases', 'cancer', 'estrogen', 'randomization', 'randomization', '3']
# []
# nct_number NCT00317148_inc
# label_file_path ../input/chia_p1/NCT00317148_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00317148_inc_0_shot.txt
# label_words_dict ['more']
# model_words_dict ['40']
# []
# label_words_dict []
# model_words_dict ['50']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00319748_exc
# label_file_path ../input/chia_p1/NCT00319748_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00319748_exc_0_shot.txt
# nct_number NCT00319748_inc
# label_file_path ../input/chia_p1/NCT00319748_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00319748_inc_0_shot.txt
# label_words_dict ['to', 'disease', 'respond', 'regimen', 'with', 'agent', 'therapy', 'disease', 'two', 'Histologically', '2', 'Histologically', 'treatment', '2']
# model_words_dict ['female', 'entry', 'positive', 'regimens', 'therapy', 'therapy']
# ['therapy']
# label_words_dict ['endometrial', 'Measurable', 'on', 'receptor', 'hormone', 'borderline', 'cisplatin', 'recurrent', 'surgery', 'recurrent', 'surgery']
# model_words_dict ['endometrial', 'on', 'receptor', 'hormone', 'cancer', 'one', 'cisplatin', 'one', 'recurrent', 'recurrent', 'carcinoma']
# ['endometrial', 'on', 'receptor', 'hormone', 'cisplatin', 'recurrent', 'recurrent']
# label_words_dict ['is', 'is']
# model_words_dict ['borderline', 'is', 'is']
# ['is', 'is']
# nct_number NCT00324363_exc
# label_file_path ../input/chia_p1/NCT00324363_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00324363_exc_0_shot.txt
# label_words_dict []
# model_words_dict ['metformin']
# []
# label_words_dict ['study', 'exenatide', 'metformin']
# model_words_dict ['previously', 'exenatide', 'surgical']
# ['exenatide']
# label_words_dict []
# model_words_dict ['characteristics']
# []
# nct_number NCT00324363_inc
# label_file_path ../input/chia_p1/NCT00324363_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00324363_inc_0_shot.txt
# label_words_dict ['mgday', 'metformin', 'ANDmetformin']
# model_words_dict ['mgday', 'HbA1c', '71', 'kgm2']
# ['mgday']
# label_words_dict []
# model_words_dict ['metformin', 'sulfonylurea']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00343668_exc
# label_file_path ../input/chia_p1/NCT00343668_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00343668_exc_0_shot.txt
# label_words_dict ['tumor', 'radiation', 'of', 'of', 'neoplasm', 'serious']
# model_words_dict ['tendency', 'phenytoin', 'fluoropyrimidine']
# []
# label_words_dict ['metastases', 'obstruction', 'cancer', 'Pregnant', 'lactating', 'illness', 'disease', 'neurologic', 'dementia', 'drug', 'drug', 'fluoropyrimidine']
# model_words_dict ['metastases', 'obstruction', 'Past', 'cancer', 'Pregnant', 'illness', 'neurologic', 'dementia', 'investigation', 'therapy']
# ['metastases', 'obstruction', 'cancer', 'Pregnant', 'illness', 'neurologic', 'dementia']
# label_words_dict ['AND', 'cancer', 'potential']
# model_words_dict ['potential']
# ['potential']
# nct_number NCT00343668_inc
# label_file_path ../input/chia_p1/NCT00343668_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00343668_inc_0_shot.txt
# label_words_dict ['Pathologically', 'diameter', 'bilirubin']
# model_words_dict ['1500µL', 'gdL', 'UNL']
# []
# label_words_dict ['xray', 'ANC', 'hemoglobin', 'times', 'capecitabine', 'S1']
# model_words_dict ['scan', 'xray', 'examination', '2', 'capecitabine', 'S1']
# ['xray', 'capecitabine', 'S1']
# label_words_dict ['UNL', 'prior', 'prior', 'NOT', 'excluded']
# model_words_dict ['UNL', 'analogues']
# ['UNL']
# nct_number NCT00344318_exc
# label_file_path ../input/chia_p1/NCT00344318_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00344318_exc_0_shot.txt
# label_words_dict ['Planned', 'pneumoniae']
# model_words_dict ['immunosuppressants', 'vaccines', '1', 'b', 'polio', 'history']
# []
# label_words_dict ['product', 'drug', 'immunosuppressants', '1', '2', 'disease', 'seizures', 'immunosuppressive', 'defects', 'immunoglobulins', 'birth']
# model_words_dict ['vaccine', '2', 'of', 'disease', 'past', 'confirmed', 'immunosuppressive', 'congenital', 'defects', 'birth']
# ['2', 'disease', 'immunosuppressive', 'defects', 'birth']
# label_words_dict ['AND', 'criterion']
# model_words_dict ['does']
# []
# nct_number NCT00344318_inc
# label_file_path ../input/chia_p1/NCT00344318_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00344318_inc_0_shot.txt
# label_words_dict ['Born']
# model_words_dict ['can', 'history', '36']
# []
# label_words_dict ['parent']
# model_words_dict ['parent']
# ['parent']
# label_words_dict ['subject']
# model_words_dict ['weeks', 'weeks']
# []
# nct_number NCT00351611_exc
# label_file_path ../input/chia_p1/NCT00351611_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00351611_exc_0_shot.txt
# label_words_dict ['pregabalin']
# model_words_dict ['glaucoma']
# []
# label_words_dict ['response']
# model_words_dict ['seizure']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00351611_inc
# label_file_path ../input/chia_p1/NCT00351611_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00351611_inc_0_shot.txt
# label_words_dict ['Epilepsy']
# model_words_dict ['subjects']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00356148_exc
# label_file_path ../input/chia_p1/NCT00356148_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00356148_exc_0_shot.txt
# label_words_dict ['stage', 'History', 'History', 'History', 'reaction']
# model_words_dict []
# []
# label_words_dict ['Advanced']
# model_words_dict ['cancer', 'Advanced']
# ['Advanced']
# label_words_dict ['antibiotics']
# model_words_dict ['antibiotics']
# ['antibiotics']
# nct_number NCT00356148_inc
# label_file_path ../input/chia_p1/NCT00356148_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00356148_inc_0_shot.txt
# label_words_dict ['cancer']
# model_words_dict ['I', 'I']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00379366_exc
# label_file_path ../input/chia_p1/NCT00379366_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00379366_exc_0_shot.txt
# label_words_dict ['contraindications']
# model_words_dict ['radiotherapy']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00379366_inc
# label_file_path ../input/chia_p1/NCT00379366_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00379366_inc_0_shot.txt
# label_words_dict ['stenosis', 'speed', 'stenosis']
# model_words_dict ['years', 'old', 'affiliation']
# []
# label_words_dict []
# model_words_dict ['anastomosis']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00391690_exc
# label_file_path ../input/chia_p1/NCT00391690_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00391690_exc_0_shot.txt
# label_words_dict []
# model_words_dict ['disease']
# []
# label_words_dict ['mgdl', 'mgdl', 'metabolism', 'disease', 'physical', 'acid', 'history', 'of', 'the', 'jawbone', 'dental', 'current', 'Recent', 'dental']
# model_words_dict ['mmolL', 'physical', 'protocol', 'drug', 'III', 'acid', 'history', 'alcohol', 'teeth', 'maxilla', 'dental', 'trauma', 'current', 'mouth', 'weeks', 'dental']
# ['physical', 'acid', 'history', 'dental', 'current', 'dental']
# label_words_dict []
# model_words_dict ['bisphosphonates', 'randomization']
# []
# nct_number NCT00391690_inc
# label_file_path ../input/chia_p1/NCT00391690_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00391690_inc_0_shot.txt
# label_words_dict ['histologically', 'cancer', 'first', 'second']
# model_words_dict ['cancer', 'value', 'procedures']
# ['cancer']
# label_words_dict ['cancer', 'chemotherapy', 'psychiatric']
# model_words_dict ['PSA', 'chemotherapy', '1', 'psychiatric']
# ['chemotherapy', 'psychiatric']
# label_words_dict ['which']
# model_words_dict ['have', 'which', 'must']
# ['which']
# nct_number NCT00396734_exc
# label_file_path ../input/chia_p1/NCT00396734_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00396734_exc_0_shot.txt
# label_words_dict ['injury']
# model_words_dict []
# []
# label_words_dict ['illness', 'history', 'history', 'history']
# model_words_dict ['1', 'disease', 'herpes', 'consciousness']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00396734_inc
# label_file_path ../input/chia_p1/NCT00396734_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00396734_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['day']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00397215_exc
# label_file_path ../input/chia_p1/NCT00397215_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00397215_exc_0_shot.txt
# label_words_dict ['second', 'vaccination', 'History', 'product']
# model_words_dict ['history', 'egg', 'history']
# []
# label_words_dict ['not', 'confirmed', 'immunosuppressive', 'consumption', 'allergic', 'hepatic', 'chronic', 'immunoglobulins', 'vaccination', 'investigational', 'drug']
# model_words_dict ['Fluad', 'Addigrip', 'Flu', 'vaccines', 'immunosuppressants', 'confirmed', 'immunosuppressive', 'disease', 'pulmonary', 'cardiovascular', 'hepatic', 'examination', 'pulmonary', 'cardiovascular', 'renal', 'neurological', 'psychiatric', 'investigational', 'drug']
# ['confirmed', 'immunosuppressive', 'hepatic', 'investigational', 'drug']
# label_words_dict ['vaccine']
# model_words_dict ['vaccine']
# ['vaccine']
# nct_number NCT00397215_inc
# label_file_path ../input/chia_p1/NCT00397215_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00397215_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['can']
# []
# label_words_dict ['male', 'Healthy']
# model_words_dict ['male', 'subjects']
# ['male']
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00401245_exc
# label_file_path ../input/chia_p1/NCT00401245_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00401245_exc_0_shot.txt
# label_words_dict ['disorder']
# model_words_dict []
# []
# label_words_dict ['important']
# model_words_dict ['History', 'disease', 'disease', 'Presence', 'disorder', 'disorder', 'disorder']
# []
# label_words_dict ['AND']
# model_words_dict ['disorder']
# []
# nct_number NCT00401245_inc
# label_file_path ../input/chia_p1/NCT00401245_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00401245_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['amenorrhea', 'Hysterectomized', 'oophorectomy']
# []
# label_words_dict ['oophorectomy']
# model_words_dict ['oophorectomy']
# ['oophorectomy']
# label_words_dict ['Hysterectomized']
# model_words_dict ['AND']
# []
# nct_number NCT00404495_exc
# label_file_path ../input/chia_p1/NCT00404495_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00404495_exc_0_shot.txt
# label_words_dict []
# model_words_dict ['glioma']
# []
# label_words_dict []
# model_words_dict ['therapy']
# []
# label_words_dict []
# model_words_dict ['diarrhea']
# []
# nct_number NCT00404495_inc
# label_file_path ../input/chia_p1/NCT00404495_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00404495_inc_0_shot.txt
# label_words_dict ['medulloblastoma', 'glioma']
# model_words_dict ['4']
# []
# label_words_dict []
# model_words_dict ['Recurrent', '3']
# []
# label_words_dict []
# model_words_dict ['is']
# []
# nct_number NCT00425789_exc
# label_file_path ../input/chia_p1/NCT00425789_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00425789_exc_0_shot.txt
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['disease']
# model_words_dict ['disease', 'disease']
# ['disease']
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00425789_inc
# label_file_path ../input/chia_p1/NCT00425789_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00425789_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['exoderm', 'consent', 'age', 'color', 'type', 'peeling']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00426751_exc
# label_file_path ../input/chia_p1/NCT00426751_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00426751_exc_0_shot.txt
# label_words_dict ['History', 'Severe']
# model_words_dict ['insufficiency']
# []
# label_words_dict ['platelets', '100000µl', 'Stroke', 'TIA', 'gastrointestinal', 'abciximab', 'eptifibatide', 'study', 'renal', 'insufficiency', 'expectation', 'drug', 'drug']
# model_words_dict ['100000µl', 'Stroke', 'months', 'gastrointestinal', 'abciximab', 'eptifibatide', '30mlmin', 'drug', 'days', 'geographic', 'treatment']
# ['100000µl', 'Stroke', 'gastrointestinal', 'abciximab', 'eptifibatide', 'drug', 'drug']
# label_words_dict ['Subjects']
# model_words_dict ['Subjects', 'is', 'is', 'with']
# ['Subjects']
# nct_number NCT00426751_inc
# label_file_path ../input/chia_p1/NCT00426751_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00426751_inc_0_shot.txt
# label_words_dict ['Women', 'doubt', 'Planned']
# model_words_dict ['min', 'intervention']
# []
# label_words_dict ['Angina']
# model_words_dict ['period', 'Angina']
# ['Angina']
# label_words_dict ['months', 'ie']
# model_words_dict ['are']
# []
# nct_number NCT00440245_exc
# label_file_path ../input/chia_p1/NCT00440245_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00440245_exc_0_shot.txt
# label_words_dict []
# model_words_dict ['EDITED_CRITERIAasthma']
# []
# label_words_dict ['asthma']
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00440245_inc
# label_file_path ../input/chia_p1/NCT00440245_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00440245_inc_0_shot.txt
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['asthma']
# model_words_dict ['EDITED_CRITERIAasthma']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00445029_exc
# label_file_path ../input/chia_p1/NCT00445029_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00445029_exc_0_shot.txt
# label_words_dict ['profile', 'indemnities']
# model_words_dict ['rights']
# []
# label_words_dict ['Pregnant', 'recurrent', 'corticotherapy', 'Local', 'to', 'a', 'barrier']
# model_words_dict ['Pregnant', 'chronic', 'recurrent', 'corticotherapy', 'month', 'Local', 'sun', 'custody', 'judiciary', 'study', 'barrier']
# ['Pregnant', 'recurrent', 'corticotherapy', 'Local', 'barrier']
# label_words_dict ['AND']
# model_words_dict ['Patients']
# []
# nct_number NCT00445029_inc
# label_file_path ../input/chia_p1/NCT00445029_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00445029_inc_0_shot.txt
# label_words_dict ['Female', 'dermatitis', 'PPD', 'PPD']
# model_words_dict ['method', 'understand', 'Consent', 'dermatitis']
# ['dermatitis']
# label_words_dict []
# model_words_dict ['system']
# []
# label_words_dict ['volunteers']
# model_words_dict ['volunteers']
# ['volunteers']
# nct_number NCT00455663_exc
# label_file_path ../input/chia_p1/NCT00455663_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00455663_exc_0_shot.txt
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['abuse', 'dependence']
# model_words_dict ['trauma', 'disorder', 'alcohol', 'abuse']
# ['abuse']
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00455663_inc
# label_file_path ../input/chia_p1/NCT00455663_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00455663_inc_0_shot.txt
# label_words_dict ['treatment', 'antipsychotic']
# model_words_dict ['recent', 'antipsychotic', 'medication']
# ['antipsychotic']
# label_words_dict ['schizophrenia']
# model_words_dict ['schizophrenia']
# ['schizophrenia']
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00461136_exc
# label_file_path ../input/chia_p1/NCT00461136_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00461136_exc_0_shot.txt
# label_words_dict ['Hypertension', 'block', 'History', 'history', 'History', 'contraindications', 'allergy']
# model_words_dict ['leukemia', 'inhibitors']
# []
# label_words_dict ['MSDBP', 'treatment', 'disease', 'diabetes', '35', 'encephalopathy', 'Second', 'arrhythmia', 'leukemia', 'Donation', 'surgical', 'active', 'history', 'pancreatitis', 'pancreatic', 'lipase', 'history', 'history', 'cholestyramine', 'HBsAg', 'drug', 'that', 'of', 'regimens', 'inhibitors', 'diuretics', 'surgical', 'drug', 'Pregnant']
# model_words_dict ['mmHg', '1gday', 'diabetes', '35', 'encephalopathy', 'surgery', 'Second', 'arrhythmia', 'dosing', 'Donation', 'surgical', 'metabolism', 'gastroenterostomy', 'active', 'duodenal', 'ulcers', 'pancreatitis', 'lipase', 'varices', 'cholestyramine', 'HBsAg', 'drug', 'investigator', 'efficacy', 'regimens', 'Known', 'diuretics', 'surgical', 'study', 'study', 'drug', 'Pregnant']
# ['diabetes', '35', 'encephalopathy', 'Second', 'arrhythmia', 'Donation', 'surgical', 'active', 'pancreatitis', 'lipase', 'cholestyramine', 'HBsAg', 'drug', 'regimens', 'diuretics', 'surgical', 'drug', 'Pregnant']
# label_words_dict ['AND']
# model_words_dict ['disease', 'but', 'but']
# []
# nct_number NCT00461136_inc
# label_file_path ../input/chia_p1/NCT00461136_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00461136_inc_0_shot.txt
# label_words_dict ['therapy', 'patients']
# model_words_dict ['Incipient', '1', 'willing', 'antagonist', 'participation', 'investigator']
# []
# label_words_dict []
# model_words_dict ['postmenopausal', 'oophorectomy', 'sterilized']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00480129_exc
# label_file_path ../input/chia_p1/NCT00480129_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00480129_exc_0_shot.txt
# label_words_dict []
# model_words_dict ['immunotherapy', 'infection']
# []
# label_words_dict []
# model_words_dict ['Pregnancy', 'lactoseintolerance']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00480129_inc
# label_file_path ../input/chia_p1/NCT00480129_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00480129_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['attacks', 'grass']
# []
# label_words_dict ['grass']
# model_words_dict ['test']
# []
# label_words_dict ['the']
# model_words_dict ['nose']
# []
# nct_number NCT00483106_exc
# label_file_path ../input/chia_p1/NCT00483106_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00483106_exc_0_shot.txt
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['Psychosis', 'syndrome', '70']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00483106_inc
# label_file_path ../input/chia_p1/NCT00483106_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00483106_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['age', 'DSM5']
# []
# label_words_dict []
# model_words_dict ['schizophrenia', 'disorders', 'seizures', 'tumor', 'medication', 'medication', 'months', 'study', 'period', 'lactating']
# []
# label_words_dict []
# model_words_dict ['capsules', 'procedures']
# []
# nct_number NCT00500500_exc
# label_file_path ../input/chia_p1/NCT00500500_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00500500_exc_0_shot.txt
# label_words_dict []
# model_words_dict ['study', 'B12', 'illness', 'cancer', 'illness']
# []
# label_words_dict []
# model_words_dict ['relevant']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00500500_inc
# label_file_path ../input/chia_p1/NCT00500500_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00500500_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['old', 'Diagnostic']
# []
# label_words_dict []
# model_words_dict ['female', 'inferior']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00502567_exc
# label_file_path ../input/chia_p1/NCT00502567_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00502567_exc_0_shot.txt
# label_words_dict ['history']
# model_words_dict ['reserve']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00502567_inc
# label_file_path ../input/chia_p1/NCT00502567_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00502567_inc_0_shot.txt
# label_words_dict ['histologically', 'lesion']
# model_words_dict ['intent']
# []
# label_words_dict ['surgery']
# model_words_dict ['surgery', 'CT']
# ['surgery']
# label_words_dict []
# model_words_dict ['is']
# []
# nct_number NCT00527826_exc
# label_file_path ../input/chia_p1/NCT00527826_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00527826_exc_0_shot.txt
# label_words_dict ['scheduled', 'corticosteroids']
# model_words_dict ['COPD', 'arthritis', '1', 'inhibitors', 'antidepressants']
# []
# label_words_dict ['disorders', 'arthritis', 'surgery', 'inhibitors', 'chronic', 'drug', 'sensitivity', 'corticosteroids', 'Moderate', 'corticosteroids', 'antibiotics', 'Pregnant', 'lactating']
# model_words_dict ['disorders', 'SZ', 'transplant', 'chronic', 'study', 'drug', 'History', 'sensitivity', 'corticosteroids', 'Moderate', 'corticosteroids', 'antibiotics', 'Pregnant', 'female', 'coordinator', 'investigator']
# ['disorders', 'chronic', 'drug', 'sensitivity', 'corticosteroids', 'Moderate', 'corticosteroids', 'antibiotics', 'Pregnant']
# label_words_dict ['AND']
# model_words_dict ['GSK', '1']
# []
# nct_number NCT00527826_inc
# label_file_path ../input/chia_p1/NCT00527826_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00527826_inc_0_shot.txt
# label_words_dict ['COPD', 'Females', 'COPD', 'managed', 'beta1agonists']
# model_words_dict ['ATS', 'ovaries', 'normal', 'corticosteroids', 'added', 'outpatients', 'ambulatory', 'therapy', 'signed', 'protocol']
# []
# label_words_dict ['Male', 'ligation', 'moderate', 'corticosteroids', 'corticosteroids', 'antibiotics', 'Current', 'beta2agonists', 'shortacting', 'anticholinergics', 'therapy']
# model_words_dict ['Male', 'ligation', 'hysterectomy', 'III', 'moderate', 'corticosteroids', 'antibiotics', 'Current', 'years', 'shortacting']
# ['Male', 'ligation', 'moderate', 'corticosteroids', 'corticosteroids', 'antibiotics', 'Current', 'shortacting']
# label_words_dict ['of', 'of']
# model_words_dict ['AND']
# []
# nct_number NCT00543712_exc
# label_file_path ../input/chia_p1/NCT00543712_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00543712_exc_0_shot.txt
# label_words_dict ['infection', 'NYHA', 'contraindicates', 'risk']
# model_words_dict ['consent']
# []
# label_words_dict ['therapy', '1', 'Prior', 'therapy', 'injury', 'study', 'ongoing', 'C', 'of', 'disease', 'results', 'trials', 'Pregnancy', 'consent']
# model_words_dict ['therapy', 'biopsy', '1', 'ongoing', 'II', 'II', 'disease', '1', 'C', 'finding', 'disease', 'drug', 'study', 'trials', 'Pregnancy']
# ['therapy', '1', 'therapy', 'study', 'ongoing', 'C', 'disease', 'trials', 'Pregnancy']
# label_words_dict ['Any', 'that']
# model_words_dict ['but']
# []
# nct_number NCT00543712_inc
# label_file_path ../input/chia_p1/NCT00543712_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00543712_inc_0_shot.txt
# label_words_dict ['Histologic', 'potential']
# model_words_dict ['understand', 'males', 'trial']
# []
# label_words_dict []
# model_words_dict ['treated']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00576173_exc
# label_file_path ../input/chia_p1/NCT00576173_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00576173_exc_0_shot.txt
# label_words_dict []
# model_words_dict ['medications', 'anesthetics']
# []
# label_words_dict ['morphine', 'hepatic', 'in', 'antidepressants', 'medications', 'anesthetics']
# model_words_dict ['120mg', 'hepatic', 'CNS', 'respiratory', 'antidepressants', 'drugs', 'hypnotics', 'inhibitor', 'analgesics']
# ['hepatic', 'antidepressants']
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00576173_inc
# label_file_path ../input/chia_p1/NCT00576173_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00576173_inc_0_shot.txt
# label_words_dict ['malignancy']
# model_words_dict ['study']
# []
# label_words_dict ['radiologically', 'opioids']
# model_words_dict ['histologically', 'radiologically', 'opioids']
# ['radiologically', 'opioids']
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00586898_exc
# label_file_path ../input/chia_p1/NCT00586898_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00586898_exc_0_shot.txt
# label_words_dict []
# model_words_dict ['protocol', 'followup']
# []
# label_words_dict ['CNS', 'Inability']
# model_words_dict ['IIIIV', 'CNS', 'Inability']
# ['CNS', 'Inability']
# label_words_dict []
# model_words_dict ['tumor']
# []
# nct_number NCT00586898_inc
# label_file_path ../input/chia_p1/NCT00586898_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00586898_inc_0_shot.txt
# label_words_dict ['radiographic', 'treatment', 'therapy']
# model_words_dict ['radiation', 'MSKCC', '_3500mm3', 'age']
# []
# label_words_dict ['radiation', 'diagnosis', 'disease', 'disease', 'Bilirubin', 'Creatinine', 'therapy']
# model_words_dict ['diagnosis', 'disease', 'bone', 'mgdl', 'mgdl', 'therapy']
# ['diagnosis', 'disease', 'disease', 'therapy']
# label_words_dict []
# model_words_dict ['may', 'minimum', 'does']
# []
# nct_number NCT00599924_exc
# label_file_path ../input/chia_p1/NCT00599924_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00599924_exc_0_shot.txt
# label_words_dict ['cycles', 'cycles', 'cancer', '2']
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['regimens', 'regimens']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00599924_inc
# label_file_path ../input/chia_p1/NCT00599924_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00599924_inc_0_shot.txt
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['colon', '0']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00609531_exc
# label_file_path ../input/chia_p1/NCT00609531_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00609531_exc_0_shot.txt
# label_words_dict ['poorlycontrolled', 'history', 'citalopram', 'medication', 'doses']
# model_words_dict ['months', 'tattoos', 'placebo', 'treatment', 'doses', 'doses']
# ['doses']
# label_words_dict ['years', 'disorder', 'a', 'Implanted', 'mania', 'hypomania', 'medication']
# model_words_dict ['years', 'participation', 'stroke', 'neurosurgery', 'neurologist', 'Implanted', 'citalopram', 'mania', 'therapy', 'disorder']
# ['years', 'disorder', 'Implanted', 'mania']
# label_words_dict ['AND']
# model_words_dict []
# []
# nct_number NCT00609531_inc
# label_file_path ../input/chia_p1/NCT00609531_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00609531_inc_0_shot.txt
# label_words_dict ['medication', 'medication']
# model_words_dict ['consent', 'years', 'Disorder', '70', 'Scale', 'neuroleptics']
# []
# label_words_dict ['SSRIs']
# model_words_dict ['SSRIs']
# ['SSRIs']
# label_words_dict ['Scale']
# model_words_dict ['scanning']
# []
# nct_number NCT00625742_exc
# label_file_path ../input/chia_p1/NCT00625742_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00625742_exc_0_shot.txt
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['dementia', 'ascites', 'events', 'bleeding', 'coagulopathy']
# model_words_dict ['dementia', 'edema', 'ascites', 'bleeding', 'perforation', 'coagulopathy']
# ['dementia', 'ascites', 'bleeding', 'coagulopathy']
# label_words_dict []
# model_words_dict ['Are']
# []
# nct_number NCT00625742_inc
# label_file_path ../input/chia_p1/NCT00625742_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00625742_inc_0_shot.txt
# label_words_dict ['weight']
# model_words_dict ['study', 'procedures', 'acetate']
# []
# label_words_dict []
# model_words_dict ['age', '60']
# []
# label_words_dict ['Are']
# model_words_dict ['Are']
# ['Are']
# nct_number NCT00639795_exc
# label_file_path ../input/chia_p1/NCT00639795_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00639795_exc_0_shot.txt
# label_words_dict ['illness', 'obesity', 'psychosis', 'treatment', 'infections']
# model_words_dict ['neuropathy']
# []
# label_words_dict ['sulfate', 'to', 'inhaled']
# model_words_dict ['Clinical', 'sulfate', 'blockade', 'local', 'conditions', 'block', 'inhaled']
# ['sulfate', 'inhaled']
# label_words_dict []
# model_words_dict ['Patients']
# []
# nct_number NCT00639795_inc
# label_file_path ../input/chia_p1/NCT00639795_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00639795_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['18']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00650312_exc
# label_file_path ../input/chia_p1/NCT00650312_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00650312_exc_0_shot.txt
# label_words_dict ['hypersensitivity']
# model_words_dict ['contraceptives', 'males', 'Abnormal', 'Abnormal']
# []
# label_words_dict ['disease', 'drug', 'disease', 'levels', 'Allergy']
# model_words_dict ['caffeine', 'vitamins', 'dietary', 'evaluation', 'B', 'disease', 'females', 'Donation', 'blood', 'Allergy', 'medication']
# ['disease', 'disease', 'Allergy']
# label_words_dict []
# model_words_dict ['will']
# []
# nct_number NCT00650312_inc
# label_file_path ../input/chia_p1/NCT00650312_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00650312_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['Male', 'study', 'study', 'man', 'women', 'normal', 'B', 'test', 'phencyclidine']
# []
# label_words_dict ['Male', 'abstinence', 'device', 'postmenopausal', 'oophorectomy', 'man']
# model_words_dict ['abstinence', 'period', 'containing', 'agent', 'year', 'oophorectomy']
# ['abstinence', 'oophorectomy']
# label_words_dict ['and', 'nonpregnant']
# model_words_dict []
# []
# nct_number NCT00676273_exc
# label_file_path ../input/chia_p1/NCT00676273_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00676273_exc_0_shot.txt
# label_words_dict ['deficiency']
# model_words_dict ['100cc', 'lymphoma']
# []
# label_words_dict ['pregnant', 'study', 'local']
# model_words_dict ['pregnant', 'study', 'condition', 'sclerosis', 'local']
# ['pregnant', 'study', 'local']
# label_words_dict []
# model_words_dict ['H2O', 'sling']
# []
# nct_number NCT00676273_inc
# label_file_path ../input/chia_p1/NCT00676273_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00676273_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['age', 'testing', 'questionnaire', 'comprehend', 'consent', 'Understand', 'evaluations', 'stable', 'investigator', 'ambulatory']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00679341_exc
# label_file_path ../input/chia_p1/NCT00679341_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_10_cot/output/Llama-3-70B-Instruct_NCT00679341_exc_0_shot.txt
# label_words_dict ['Stage', 'disease', 'Grade']
# model_words_dict ['120mgm2', 'B']
# []
# label_words_dict ['advanced', 'metastases', 'Doxorubicin', 'LVEF', 'complications', 'procedure', 'injury', 'pregnancy', 'B', 'intolerance', 'unable']
# model_words_dict ['neoadjuvant', 'cancer', 'advanced', 'irradiated', 'symptomatic', 'symptoms', 'surgery', 'Doxorubicin', 'failure', 'LVEF', 'malignancy', 'pulmonary', 'ulcers', 'procedure', 'randomization', 'pregnancy', 'reaction', 'proteins', 'excipients', 'able']
# ['advanced', 'Doxorubicin', 'LVEF', 'procedure', 'pregnancy']
# label_words_dict ['years']
# model_words_dict ['for', 'is', 'be']
# []
# nct_number NCT00679341_inc
# ...
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00502567_inc_0_shot.txt
# label_words_dict ['histologically', 'lesion']
# model_words_dict ['intent']
# []
# label_words_dict ['surgery']
# model_words_dict ['surgery', 'CT']
# ['surgery']
# label_words_dict []
# model_words_dict ['is']
# []
# nct_number NCT00527826_exc
# label_file_path ../input/chia_p1/NCT00527826_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00527826_exc_0_shot.txt
# label_words_dict ['scheduled', 'corticosteroids']
# model_words_dict ['arthritis', '1', 'inhibitors', 'antidepressants', 'corticosteroids']
# ['corticosteroids']
# label_words_dict ['disorders', 'arthritis', 'surgery', 'inhibitors', 'chronic', 'drug', 'sensitivity', 'corticosteroids', 'Moderate', 'corticosteroids', 'antibiotics', 'Pregnant', 'lactating']
# model_words_dict ['disorders', 'SZ', 'transplant', 'chronic', 'study', 'drug', 'History', 'sensitivity', 'corticosteroids', 'Moderate', 'corticosteroids', 'antibiotics', 'Pregnant', 'female', 'coordinator', 'investigator', '1']
# ['disorders', 'chronic', 'drug', 'sensitivity', 'corticosteroids', 'Moderate', 'corticosteroids', 'antibiotics', 'Pregnant']
# label_words_dict ['AND']
# model_words_dict ['is']
# []
# nct_number NCT00527826_inc
# label_file_path ../input/chia_p1/NCT00527826_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00527826_inc_0_shot.txt
# label_words_dict ['COPD', 'Females', 'COPD', 'managed', 'beta1agonists']
# model_words_dict ['ovaries', 'normal', 'corticosteroids', 'added', 'ambulatory', 'therapy', 'signed', 'protocol']
# []
# label_words_dict ['Male', 'ligation', 'moderate', 'corticosteroids', 'corticosteroids', 'antibiotics', 'Current', 'beta2agonists', 'shortacting', 'anticholinergics', 'therapy']
# model_words_dict ['ATS', 'Male', 'ligation', 'hysterectomy', 'III', 'moderate', 'corticosteroids', 'antibiotics', 'Current', 'years', 'shortacting']
# ['Male', 'ligation', 'moderate', 'corticosteroids', 'corticosteroids', 'antibiotics', 'Current', 'shortacting']
# label_words_dict ['of', 'of']
# model_words_dict ['AND']
# []
# nct_number NCT00543712_exc
# label_file_path ../input/chia_p1/NCT00543712_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00543712_exc_0_shot.txt
# label_words_dict ['infection', 'NYHA', 'contraindicates', 'risk']
# model_words_dict ['therapy', 'consent']
# []
# label_words_dict ['therapy', '1', 'Prior', 'therapy', 'injury', 'study', 'ongoing', 'C', 'of', 'disease', 'results', 'trials', 'Pregnancy', 'consent']
# model_words_dict ['therapy', 'biopsy', '1', 'ongoing', 'II', 'II', 'disease', '1', 'C', 'finding', 'disease', 'drug', 'study', 'trials', 'Pregnancy']
# ['therapy', '1', 'therapy', 'study', 'ongoing', 'C', 'disease', 'trials', 'Pregnancy']
# label_words_dict ['Any', 'that']
# model_words_dict ['study', 'but']
# []
# nct_number NCT00543712_inc
# label_file_path ../input/chia_p1/NCT00543712_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00543712_inc_0_shot.txt
# label_words_dict ['Histologic', 'potential']
# model_words_dict ['understand', 'trial']
# []
# label_words_dict []
# model_words_dict ['treated', 'males']
# []
# label_words_dict []
# model_words_dict ['treatment']
# []
# nct_number NCT00576173_exc
# label_file_path ../input/chia_p1/NCT00576173_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00576173_exc_0_shot.txt
# label_words_dict []
# model_words_dict ['Fentanyl', 'medications']
# []
# label_words_dict ['morphine', 'hepatic', 'in', 'antidepressants', 'medications', 'anesthetics']
# model_words_dict ['morphine', '120mg', 'hepatic', 'CNS', 'respiratory', 'antidepressants', 'drugs', 'hypnotics', 'inhibitor', 'analgesics']
# ['morphine', 'hepatic', 'antidepressants']
# label_words_dict []
# model_words_dict ['Patients', 'Patients']
# []
# nct_number NCT00576173_inc
# label_file_path ../input/chia_p1/NCT00576173_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00576173_inc_0_shot.txt
# label_words_dict ['malignancy']
# model_words_dict ['study']
# []
# label_words_dict ['radiologically', 'opioids']
# model_words_dict ['histologically', 'radiologically', 'opioids']
# ['radiologically', 'opioids']
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00586898_exc
# label_file_path ../input/chia_p1/NCT00586898_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00586898_exc_0_shot.txt
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['CNS', 'Inability']
# model_words_dict ['IIIIV', 'CNS', 'Inability', 'followup']
# ['CNS', 'Inability']
# label_words_dict []
# model_words_dict ['disease', 'infection', 'epiduraltumor']
# []
# nct_number NCT00586898_inc
# label_file_path ../input/chia_p1/NCT00586898_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00586898_inc_0_shot.txt
# label_words_dict ['radiographic', 'treatment', 'therapy']
# model_words_dict ['states', '_3500mm3']
# []
# label_words_dict ['radiation', 'diagnosis', 'disease', 'disease', 'Bilirubin', 'Creatinine', 'therapy']
# model_words_dict ['radiation', 'diagnosis', 'disease', 'bone', 'mgdl', 'mgdl', 'therapy']
# ['radiation', 'diagnosis', 'disease', 'disease', 'therapy']
# label_words_dict []
# model_words_dict ['may', 'minimum', 'does']
# []
# nct_number NCT00599924_exc
# label_file_path ../input/chia_p1/NCT00599924_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00599924_exc_0_shot.txt
# label_words_dict ['cycles', 'cycles', 'cancer', '2']
# model_words_dict ['treatment', 'treatment', 'treatment']
# []
# label_words_dict []
# model_words_dict ['regimens', 'regimens']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00599924_inc
# label_file_path ../input/chia_p1/NCT00599924_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00599924_inc_0_shot.txt
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['colon', '0']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00609531_exc
# label_file_path ../input/chia_p1/NCT00609531_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00609531_exc_0_shot.txt
# label_words_dict ['poorlycontrolled', 'history', 'citalopram', 'medication', 'doses']
# model_words_dict ['interfere', 'tattoos', 'placebo', 'treatment', 'interfere', 'doses', 'doses']
# ['doses']
# label_words_dict ['years', 'disorder', 'a', 'Implanted', 'mania', 'hypomania', 'medication']
# model_words_dict ['years', 'participation', 'neurosurgery', 'neurologist', 'Implanted', 'citalopram', 'mania', 'therapy', 'disorder']
# ['years', 'disorder', 'Implanted', 'mania']
# label_words_dict ['AND']
# model_words_dict ['70']
# []
# nct_number NCT00609531_inc
# label_file_path ../input/chia_p1/NCT00609531_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00609531_inc_0_shot.txt
# label_words_dict ['medication', 'medication']
# model_words_dict ['SSRIs', 'neuroleptics']
# []
# label_words_dict ['SSRIs']
# model_words_dict ['than']
# []
# label_words_dict ['Scale']
# model_words_dict ['where']
# []
# nct_number NCT00625742_exc
# label_file_path ../input/chia_p1/NCT00625742_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00625742_exc_0_shot.txt
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['dementia', 'ascites', 'events', 'bleeding', 'coagulopathy']
# model_words_dict ['dementia', 'edema', 'ascites', 'bleeding', 'coagulopathy']
# ['dementia', 'ascites', 'bleeding', 'coagulopathy']
# label_words_dict []
# model_words_dict ['Are']
# []
# nct_number NCT00625742_inc
# label_file_path ../input/chia_p1/NCT00625742_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00625742_inc_0_shot.txt
# label_words_dict ['weight']
# model_words_dict ['Clinic', 'procedures', 'acetate']
# []
# label_words_dict []
# model_words_dict ['age', '60']
# []
# label_words_dict ['Are']
# model_words_dict ['Are']
# ['Are']
# nct_number NCT00639795_exc
# label_file_path ../input/chia_p1/NCT00639795_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00639795_exc_0_shot.txt
# label_words_dict ['illness', 'obesity', 'psychosis', 'treatment', 'infections']
# model_words_dict ['neuropathy']
# []
# label_words_dict ['sulfate', 'to', 'inhaled']
# model_words_dict ['Clinical', 'sulfate', 'blockade', 'local', 'conditions', 'block', 'inhaled']
# ['sulfate', 'inhaled']
# label_words_dict []
# model_words_dict ['uncontrolled', 'Patients']
# []
# nct_number NCT00639795_inc
# label_file_path ../input/chia_p1/NCT00639795_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00639795_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['18']
# []
# label_words_dict []
# model_words_dict ['estimate']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00650312_exc
# label_file_path ../input/chia_p1/NCT00650312_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00650312_exc_0_shot.txt
# label_words_dict ['hypersensitivity']
# model_words_dict ['contraceptives', 'males', 'Abnormal', 'Abnormal']
# []
# label_words_dict ['disease', 'drug', 'disease', 'levels', 'Allergy']
# model_words_dict ['caffeine', 'vitamins', 'dietary', 'evaluation', 'B', 'disease', 'females', 'Donation', 'blood', 'Allergy', 'medication']
# ['disease', 'disease', 'Allergy']
# label_words_dict []
# model_words_dict ['will']
# []
# nct_number NCT00650312_inc
# label_file_path ../input/chia_p1/NCT00650312_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00650312_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['years', 'Male', 'study', 'study', 'accompanied', 'man', 'women', 'normal', 'B', 'test', 'phencyclidine', 'medication']
# []
# label_words_dict ['Male', 'abstinence', 'device', 'postmenopausal', 'oophorectomy', 'man']
# model_words_dict ['Sunday', 'abstinence', 'period', 'containing', 'agent', 'year', 'oophorectomy']
# ['abstinence', 'oophorectomy']
# label_words_dict ['and', 'nonpregnant']
# model_words_dict ['AND']
# []
# nct_number NCT00676273_exc
# label_file_path ../input/chia_p1/NCT00676273_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00676273_exc_0_shot.txt
# label_words_dict ['deficiency']
# model_words_dict []
# []
# label_words_dict ['pregnant', 'study', 'local']
# model_words_dict ['pregnant', 'study', 'condition', 'sclerosis', 'local']
# ['pregnant', 'study', 'local']
# label_words_dict []
# model_words_dict ['H2O', 'sling']
# []
# nct_number NCT00676273_inc
# label_file_path ../input/chia_p1/NCT00676273_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00676273_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['age', 'testing', 'questionnaire', 'comprehend', 'consent', 'Understand', 'evaluations', 'stable', 'investigator', 'ambulatory']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00679341_exc
# label_file_path ../input/chia_p1/NCT00679341_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00679341_exc_0_shot.txt
# label_words_dict ['Stage', 'disease', 'Grade']
# model_words_dict ['120mgm2', 'B']
# []
# label_words_dict ['advanced', 'metastases', 'Doxorubicin', 'LVEF', 'complications', 'procedure', 'injury', 'pregnancy', 'B', 'intolerance', 'unable']
# model_words_dict ['neoadjuvant', 'cancer', 'advanced', 'irradiated', 'symptomatic', 'symptoms', 'surgery', 'Doxorubicin', 'failure', 'LVEF', 'malignancy', 'pulmonary', 'ulcers', 'procedure', 'randomization', 'pregnancy', 'reaction', 'proteins', 'excipients', 'able']
# ['advanced', 'Doxorubicin', 'LVEF', 'procedure', 'pregnancy']
# label_words_dict ['years']
# model_words_dict ['is', 'be']
# []
# nct_number NCT00679341_inc
# label_file_path ../input/chia_p1/NCT00679341_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00679341_inc_0_shot.txt
# label_words_dict ['breast', 'chemotherapy', 'pregnant']
# model_words_dict ['disease', 'potential', 'treatment']
# []
# label_words_dict ['Histologically', 'potential', 'contraception']
# model_words_dict ['Histologically', 'advanced', 'contraception']
# ['Histologically', 'contraception']
# label_words_dict ['HER2positive']
# model_words_dict ['HER2positive']
# ['HER2positive']
# nct_number NCT00718952_exc
# label_file_path ../input/chia_p1/NCT00718952_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00718952_exc_0_shot.txt
# label_words_dict ['nitrate']
# model_words_dict ['kidney']
# []
# label_words_dict ['consents', 'involved', 'CYP3A4inhibitor', 'sildenafil', 'sildenafil']
# model_words_dict ['consents', 'acute', 'brain', 'CYP3A4inhibitor', 'PAH', 'sildenafil']
# ['consents', 'CYP3A4inhibitor', 'sildenafil', 'sildenafil']
# label_words_dict []
# model_words_dict ['with']
# []
# nct_number NCT00718952_inc
# label_file_path ../input/chia_p1/NCT00718952_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00718952_inc_0_shot.txt
# label_words_dict ['function']
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['hypertension', 'hypertension']
# []
# label_words_dict []
# model_words_dict []
# []
# nct_number NCT00720031_exc
# label_file_path ../input/chia_p1/NCT00720031_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00720031_exc_0_shot.txt
# label_words_dict []
# model_words_dict ['evoluting', 'evoluting']
# []
# label_words_dict ['evoluting', 'evoluting', 'Transplanted', 'Pregnant']
# model_words_dict ['patients', 'Pregnant']
# ['Pregnant']
# label_words_dict ['women']
# model_words_dict ['do', 'women']
# ['women']
# nct_number NCT00720031_inc
# label_file_path ../input/chia_p1/NCT00720031_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00720031_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['patients', 'state', 'HIV', 'B']
# []
# label_words_dict ['locoregional', 'cutaneous', 'chemotherapy', 'radiotherapy']
# model_words_dict ['locoregional', 'cutaneous', 'infusion', 'radiotherapy', '1']
# ['locoregional', 'cutaneous', 'radiotherapy']
# label_words_dict ['nodules', 'antigen']
# model_words_dict ['nodules', 'antigen', 'infusion']
# ['nodules', 'antigen']
# nct_number NCT00728156_exc
# label_file_path ../input/chia_p1/NCT00728156_exc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00728156_exc_0_shot.txt
# label_words_dict ['Contraindication', 'Women']
# model_words_dict ['smokers', 'malignancy']
# []
# label_words_dict ['ANDdiagnosed', 'malignancy']
# model_words_dict ['diagnosed', 'Anaemia', 'malignancy', 'Cirrhosis']
# ['malignancy']
# label_words_dict []
# model_words_dict ['tests']
# []
# nct_number NCT00728156_inc
# label_file_path ../input/chia_p1/NCT00728156_inc.txt
# model_file_path eval_p1/model_output/Llama-3-70B-Instruct_0_shot_prompt_8_cot/output/Llama-3-70B-Instruct_NCT00728156_inc_0_shot.txt
# label_words_dict []
# model_words_dict ['T2DM', '18', 'procedures']
# []
# label_words_dict ['enzyme', 'evidence', 'percutaneous']
# model_words_dict ['Angina', 'enzyme', 'percutaneous']
# ['enzyme', 'percutaneous']
# label_words_dict []
# model_words_dict []
# []

# %% [markdown]
# ### Plot Models Operators

# %%
# 7 = Agent
# 8 Claude Prompt
plot_metrics(all_metrics)

# %% [markdown]
# ### Plot Anzahl Operators

# %%
def plot_count_comparison(all_metrics):
    operators = ['AND', 'OR', 'NOT']
    count_metrics = ['total_label', 'total_model']
    fig, ax = plt.subplots(figsize=(16, 8))
    x = np.arange(len(operators))

    label_counts = [all_metrics[next(iter(all_metrics))][op]['total_label'] for op in operators]
    bar_width = 0.16
    opacity = 0.8

    colors = sns.color_palette("husl", len(all_metrics) + 1)

    ax.bar(x, label_counts, bar_width, alpha=opacity, color=colors[0], label='Label Count')
    for i, model in enumerate(all_metrics.keys()):
        count_values = [all_metrics[model][op]['total_model'] for op in operators]
        model_name = model.replace('Instruct', '').replace('_', ' ')
        ax.bar(x + (i + 1) * bar_width, count_values, bar_width, alpha=opacity, color=colors[i + 1], label=model_name)

        for j, v in enumerate(count_values):
            label_count = label_counts[j]
            diff_percent = ((v - label_count) / label_count) * 100
            color = 'darkgreen' if diff_percent >= 0 else 'red'
            ax.text(x[j] + (i + 1) * bar_width, v / 2, f'{diff_percent:+.0f}%', ha='center', va='center', fontsize=10, color=color, fontweight='bold')
            ax.text(x[j] + (i + 1) * bar_width, v + 100, str(v), ha='center', fontsize=11)

    for i, v in enumerate(label_counts):
        ax.text(x[i], v + 100, str(v), ha='center', fontsize=10)

    ax.set_xticks(x + bar_width * len(all_metrics) / 2)
    ax.set_xticklabels([f'{op}' for op in operators], fontsize=12)
    ax.set_xlabel('Operators', fontsize=12)
    ax.set_ylabel('Anzahl', fontsize=12)
    ax.set_title('Count Comparison: Labels vs Models per Operator', fontsize=16, pad=30)
    ax.legend(fontsize=11)
    ax.grid(True)

    plt.tight_layout()
    plt.show()

# %%
plot_count_comparison(all_metrics)

# %% [markdown]
# ## Model vs SOTA

# %%
print(models)

model_to_plot = models[0]

model_name = "Llama-3-70B-DPO-5-shot"
# Out:
# ['Llama-3-70B-DPO-v0.2_5_shot_prompt_9', 'Llama-3-70B-Instruct_1_shot_prompt_7', 'Llama-3-70B-Instruct_3_shot_prompt_7', 'Llama-3-70B-Instruct_5_random_shot_prompt_7', 'Llama-3-70B-Instruct_5_shot_prompt_7']

# %%
model_metrics = all_metrics[model_to_plot]

sota_metrics = {
    'SciBERT': {
        'AND': {'precision': 54.1, 'recall': 60.0, 'f1': 56.9},
        'NOT': {'precision': 74.3, 'recall': 91.0, 'f1': 81.8},
        'OR': {'precision': 85.1, 'recall': 93.2, 'f1': 89.0}
    },
    'R-BERT + SciBERT': {
        'AND': {'precision': 53.8, 'recall': 53.8, 'f1': 53.8},
        'NOT': {'precision': 74.5, 'recall': 88.7, 'f1': 81.0},
        'OR': {'precision': 88.4, 'recall': 92.2, 'f1': 90.2}
    }
}

operators = ['AND', 'OR', 'NOT']
metrics_to_plot = ['precision', 'recall', 'f1']
metric_labels = {'precision': 'P', 'recall': 'R', 'f1': 'F1'}

fig, ax = plt.subplots(figsize=(16, 10))

x = np.arange(len(operators))
bar_width = 0.4
opacity = 0.8
gap = 0.1

for i, metric in enumerate(metrics_to_plot):
    model_values = [model_metrics[op][metric] for op in operators]
    sota_values = [sota_metrics['SciBERT'][op][metric] for op in operators]

    ax.bar(x - bar_width/2 - gap/2 + i*bar_width/3, model_values, bar_width/3, alpha=opacity, label=f'Llama-3-70B-5-shot - {metric_labels[metric]}')
    ax.bar(x + bar_width/2 + gap/2 + i*bar_width/3, sota_values, bar_width/3, alpha=opacity, label=f'SciBERT - {metric_labels[metric]}')

    for j, (model_value, sota_value) in enumerate(zip(model_values, sota_values)):
        ax.text(j - bar_width/2 - gap/2 + i*bar_width/3, model_value/2, f'{metric_labels[metric]}', ha='center', va='center', fontsize=14, fontweight='bold', color='white')
        ax.text(j + bar_width/2 + gap/2 + i*bar_width/3, sota_value/2, f'{metric_labels[metric]}', ha='center', va='center', fontsize=14, fontweight='bold', color='white')

        ax.text(j - bar_width/2 - gap/2 + i*bar_width/3, model_value + 2, f'{model_value:.1f}%', ha='center', fontsize=12)
        ax.text(j + bar_width/2 + gap/2 + i*bar_width/3, sota_value + 2, f'{sota_value:.1f}%', ha='center', fontsize=12)

ax.set_xticks(x)
ax.set_xticklabels(operators, fontsize=14)
ax.set_xlabel('Operatoren', fontsize=16, fontweight='bold', labelpad=15)
ax.set_ylabel('Score (%)', fontsize=16, fontweight='bold', labelpad=15)
ax.set_ylim(0, 105)
ax.set_yticks(np.arange(0, 101, 10))
ax.tick_params(axis='y', labelsize=14, width=2)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_title(f'Evaluation: {model_name} vs. SciBERT', fontsize=20, pad=20)
ax.legend(fontsize=12, ncol=2, loc='upper left')
ax.grid(True)

plt.tight_layout()
if not os.path.exists("pics"):
    os.makedirs("pics")
plt.savefig(f"pics/{model_to_plot}_vs_sota.png")
plt.show()

# %%
def generate_latex_table(all_metrics, operators, metrics_to_plot):
    latex_table = "\\begin{table}[h]\n"
    latex_table += "\\centering\n"
    latex_table += "\\begin{tabular}{l" + "c" * (len(metrics_to_plot) * len(operators)) + "}\n"
    latex_table += "\\toprule\n"
    latex_table += "Model & " + " & ".join([f"\\multicolumn{{{len(metrics_to_plot)}}}{{c}}{{{op}}}" for op in operators]) + " \\\\\n"
    latex_table += "\\cmidrule(lr){2-" + str(len(metrics_to_plot) + 1) + "} " + " \\cmidrule(lr){" + str(len(metrics_to_plot) + 2) + "-" + str(2 * len(metrics_to_plot) + 1) + "} " + " \\cmidrule(lr){" + str(2 * len(metrics_to_plot) + 2) + "-" + str(3 * len(metrics_to_plot) + 1) + "}\n"
    latex_table += " & " + " & ".join([" & ".join(metric[:1].upper() for metric in metrics_to_plot) for _ in operators]) + " \\\\\n"
    latex_table += "\\midrule\n"

    for model, model_metrics in all_metrics.items():
        row = model.replace("_", "-")  # Replace underscores with hyphens in the model name
        for op in operators:
            for metric in metrics_to_plot:
                row += " & {:.2f}".format(model_metrics[op][metric])
        row += " \\\\\n"
        latex_table += row

    latex_table += "\\bottomrule\n"
    latex_table += "\\end{tabular}\n"
    latex_table += "\\caption{Model Performance Metrics}\n"
    latex_table += "\\label{tab:model_metrics}\n"
    latex_table += "\\end{table}\n"

    os.makedirs("latex", exist_ok=True)
    with open("latex/model_metrics_table.tex", "w") as file:
        file.write(latex_table)
    return latex_table

# Generate LaTeX table
latex_table = generate_latex_table(all_metrics, operators, metrics_to_plot)

print(latex_table)
