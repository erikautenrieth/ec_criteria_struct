# %% [markdown]
# #### Versuch exact matching zu evaluieren

# %%
import os
import re
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from eval_p1_functions import *

# %%
def read_file(file_path):
    with open(file_path, 'r', encoding="utf-8") as file:
        return file.read()

def extract_nct_number(filename):
    match = re.search(r'NCT\d+', filename)
    return match.group() if match else None

def extract_operators(text):
    operators = re.findall(r'\[(AND|OR|NOT)\]', text)
    return operators

def find_operator_words(text, operators):
    words = {op: [] for op in operators}
    word_list = text.split()
    for i, word in enumerate(word_list):
        if word in ["[AND]", "[OR]", "[NOT]"]:
            operator = word[1:-1]
            if operator in ['AND', 'OR', 'NOT'] and i - 1 >= 0: # Wort vor dem Operator
                prev_word = re.sub(r'[^\w]', '', word_list[i - 1])  # Entferne Satzzeichen
                words[operator].append(prev_word)
    return words

# %%
def compare_operators(label_text, model_text, operator):
    label_operators = extract_operators(label_text)
    model_operators = extract_operators(model_text)

    label_words_dict = find_operator_words(label_text, label_operators)
    model_words_dict = find_operator_words(model_text, model_operators)

    
    
    label_words = label_words_dict.get(operator, [])
    model_words = model_words_dict.get(operator, [])
    print("label_words_dict",label_words)
    print("model_words_dict",model_words)
    print([word for word in label_words if word in model_words])
    
    tp = sum(1 for word in label_words if word in model_words)
    fp = sum(1 for word in model_words if word not in label_words)
    fn = sum(1 for word in label_words if word not in model_words)

    return tp, fp, fn, len(label_words), len(model_words)

def calculate_metrics(tp, fp, fn):
    precision = tp / (tp + fp) if tp + fp > 0 else 0
    recall = tp / (tp + fn) if tp + fn > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if precision + recall > 0 else 0
    accuracy = tp / (tp + fn) if tp + fn > 0 else 0
    return precision, recall, f1, accuracy

# %%
def evaluate_models(label_folder, model_folder,model_name, output_folder="excel_eval"):
    operators = ['AND', 'OR', 'NOT']
    metrics = {op: {'tp': 0, 'fp': 0, 'fn': 0, 'label_count': 0, 'model_count': 0, 'correct_count': 0, 'correct_ncts': set(), 'low_tp_ncts': set()} for op in operators}
    processed_label_files = 0
    model_results = []

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for model_file in os.listdir(model_folder):
        if model_file.endswith('.txt'):
            nct_number = extract_nct_number(model_file)

            if nct_number:
                label_file_path = os.path.join(label_folder, f'{nct_number}.txt')
                model_file_path = os.path.join(model_folder, model_file)

                if os.path.exists(label_file_path):
                    processed_label_files += 1
                    label_text = read_file(label_file_path)
                    model_text = read_file(model_file_path)

                    model_data = {'nct_number': nct_number}

                    for op in operators:
                        tp, fp, fn, label_count, model_count = compare_operators(label_text, model_text, op)

                        metrics[op]['tp'] += tp
                        metrics[op]['fp'] += fp
                        metrics[op]['fn'] += fn
                        metrics[op]['label_count'] += label_count
                        metrics[op]['model_count'] += model_count
                        metrics[op]['correct_count'] += tp

                        model_data[f'{op}_tp'] = tp
                        model_data[f'{op}_fp'] = fp
                        model_data[f'{op}_fn'] = fn
                        model_data[f'{op}_label_count'] = label_count
                        model_data[f'{op}_model_count'] = model_count

                        if tp > 0:
                            metrics[op]['correct_ncts'].add(nct_number)
                        if tp == 0 and fn > 4:
                            metrics[op]['low_tp_ncts'].add(nct_number)

                    model_results.append(model_data)

    results = {}
    for op in operators:
        precision, recall, f1, accuracy = calculate_metrics(metrics[op]['tp'], metrics[op]['fp'], metrics[op]['fn'])
        results[op] = {
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'accuracy': accuracy,
            'total_label': metrics[op]['label_count'],
            'total_model': metrics[op]['model_count'],
            'correct_count': metrics[op]['correct_count'],
            'low_tp_ncts': list(metrics[op]['low_tp_ncts'])  # Konvertiere das Set zurück in eine Liste für die Ausgabe
        }


    df_results = pd.DataFrame(model_results)
    excel_path = os.path.join(output_folder, f'{model_name}_evaluation_results.xlsx')
    #with pd.ExcelWriter(excel_path) as writer:
    #    df_results.to_excel(writer, sheet_name='Model Results', index=False)

    return results

# %%
versuch_ordner = "eval_p1/" # "eval_p1_n_shot/" # "eval_p1/"


label_folder = '../input/lct_p1'
model_output_folder = versuch_ordner + 'model_output'

models = [folder for folder in os.listdir(model_output_folder) if os.path.isdir(os.path.join(model_output_folder, folder))]

# %%
all_metrics = {}

for model in models:
    model_folder = os.path.join(model_output_folder, model, 'output')
    metrics = evaluate_models(label_folder, model_folder, model)
    for op in metrics:
        for metric in metrics[op]:
            metrics[op][metric] *= 100

    all_metrics[model] = metrics
# Out:
# label_words_dict []
# model_words_dict ['2']
# []
# label_words_dict ['21']
# model_words_dict ['21']
# ['21']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['THA']
# []
# label_words_dict []
# model_words_dict ['one']
# []
# label_words_dict ['THA']
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['administration']
# []
# label_words_dict ['male', 'transplant', 'weeks']
# model_words_dict ['male', '0', '1', 'transplant', 'response', 'weeks']
# ['male', 'transplant', 'weeks']
# label_words_dict []
# model_words_dict ['of', 'is']
# []
# label_words_dict ['18', 'uterus']
# model_words_dict ['18', 'uterus']
# ['18', 'uterus']
# label_words_dict ['chemotherapy']
# model_words_dict ['chemotherapy']
# ['chemotherapy']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['pacemaker']
# model_words_dict ['pacemaker']
# ['pacemaker']
# label_words_dict []
# model_words_dict ['', '']
# []
# label_words_dict []
# model_words_dict ['11']
# []
# label_words_dict ['preeclampsia', 'guardianship']
# model_words_dict ['preeclampsia', 'Minors', 'guardianship']
# ['preeclampsia', 'guardianship']
# label_words_dict []
# model_words_dict ['Patient', '']
# []
# label_words_dict []
# model_words_dict ['account']
# []
# label_words_dict ['physical']
# model_words_dict ['physical']
# ['physical']
# label_words_dict ['which']
# model_words_dict ['1', '2']
# []
# label_words_dict ['Children', 'months', 'Children', 'Children', 'Children']
# model_words_dict ['months', 'pathologies', 'neurological']
# ['months']
# label_words_dict ['Fullterm', 'neurological']
# model_words_dict ['Fullterm', 'barrier']
# ['Fullterm']
# label_words_dict []
# model_words_dict ['pathologies', 'OR']
# []
# label_words_dict ['children']
# model_words_dict ['children', 'protocol']
# ['children']
# label_words_dict ['infants', 'chest']
# model_words_dict []
# []
# label_words_dict ['for', 'be']
# model_words_dict ['', 'to', 'for']
# ['for']
# label_words_dict []
# model_words_dict ['principal', 'willing']
# []
# label_words_dict ['tattoo', 'cyanoacrylate', 'formaldehyde', 'chloride', 'arthroplasty', 'HIV', 'abnormality', 'personal', 'keloid', 'formations']
# model_words_dict ['tattoo', 'cyanoacrylate', 'formaldehyde', 'chloride', 'selfreport', 'arthroplasty', 'positive', 'abnormality', 'personal', 'keloid', 'formations']
# ['tattoo', 'cyanoacrylate', 'formaldehyde', 'chloride', 'arthroplasty', 'abnormality', 'personal', 'keloid', 'formations']
# label_words_dict []
# model_words_dict ['They', 'are']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['dynamometer']
# model_words_dict ['men', 'men', 'Guangdong']
# []
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict ['sSBP']
# model_words_dict ['20mmHg', 'hypotension', 'hypertension', 'III', 'aminotransferase']
# []
# label_words_dict ['hypotension', 'secondary', 'hypertension', 'ischemia', 'hemorrhage', 'attack', 'infarction', 'telmisartan', 'inhibitors', 'aminotransferase', 'potassium']
# model_words_dict ['infarction', 'telmisartan', 'inhibitors', 'mmolL']
# ['infarction', 'telmisartan', 'inhibitors']
# label_words_dict []
# model_words_dict ['', 'has']
# []
# label_words_dict ['Women']
# model_words_dict ['detained']
# []
# label_words_dict ['Men', 'to', 'Pregnant', 'willing', 'Prisoners', 'detain', 'psychiatric']
# model_words_dict ['Men', 'age', 'to', 'Pregnant', 'willing', 'Prisoners', 'psychiatric', 'barrier']
# ['Men', 'to', 'Pregnant', 'willing', 'Prisoners', 'psychiatric']
# label_words_dict ['subjects', 'otherwise', 'WOCBA', 'or', 'to']
# model_words_dict ['subjects', 'otherwise', 'WOCBA', 'Patients']
# ['subjects', 'otherwise', 'WOCBA']
# label_words_dict []
# model_words_dict ['residents']
# []
# label_words_dict ['pacemaker']
# model_words_dict ['pacemaker']
# ['pacemaker']
# label_words_dict []
# model_words_dict ['', '', '']
# []
# label_words_dict []
# model_words_dict ['willing']
# []
# label_words_dict []
# model_words_dict ['independence', 'interfere', 'refusal']
# []
# label_words_dict []
# model_words_dict ['1', 'OR']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['ultrasound', 'pelvic', 'renal', 'abnormalities', 'pelvic']
# model_words_dict ['ultrasound', 'pelvic', 'renal', 'abnormalities', 'pelvic']
# ['ultrasound', 'pelvic', 'renal', 'abnormalities', 'pelvic']
# label_words_dict ['', 'presenting']
# model_words_dict ['']
# ['']
# label_words_dict ['disease']
# model_words_dict ['disease', 'surgery']
# ['disease']
# label_words_dict ['Plane', 'Allergy']
# model_words_dict ['medicated', 'Plane', 'Allergy']
# ['Plane', 'Allergy']
# label_words_dict ['Patient', 'Patient']
# model_words_dict ['Patient', 'Patient']
# ['Patient', 'Patient']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['pregnant']
# model_words_dict ['pregnant']
# ['pregnant']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['HbA1C']
# model_words_dict ['80', 'interfering', 'stents']
# []
# label_words_dict ['medical', 'psychiatric', 'hypotension', 'malignancy', 'Drug', 'calcification', 'clips', 'bypass', 'Hematological']
# model_words_dict ['10', 'psychiatric', 'mmHg', 'III', 'cancer', 'Drug', 'bypass', 'Hematological']
# ['psychiatric', 'Drug', 'bypass', 'Hematological']
# label_words_dict []
# model_words_dict ['', '']
# []
# label_words_dict []
# model_words_dict ['interfere']
# []
# label_words_dict ['disease', 'condition', 'previous']
# model_words_dict ['disease', 'medical', 'condition', 'previous']
# ['disease', 'condition', 'previous']
# label_words_dict ['undergoing']
# model_words_dict ['is']
# []
# label_words_dict []
# model_words_dict ['Subjects', 'parents', 'available', 'testing', 'tumors']
# []
# label_words_dict ['suspected', 'recurrent', 'scheduled', 'biopsy', 'excised', 'draw', 'available', 'testing', 'tumors']
# model_words_dict ['gender', 'race', 'suspected', 'recurrent', 'for', 'biopsy', 'tumors', 'draw']
# ['suspected', 'recurrent', 'biopsy', 'draw', 'tumors']
# label_words_dict ['do', 'is']
# model_words_dict ['who', 'is']
# ['is']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['which']
# model_words_dict ['']
# []
# label_words_dict ['women']
# model_words_dict ['Patients', 'more']
# []
# label_words_dict ['response', 'fentanyl', 'ropivacaine', '50kg']
# model_words_dict ['hypersensitivity', 'response', 'read', '50kg']
# ['response', '50kg']
# label_words_dict ['is']
# model_words_dict ['it', 'who', 'who', 'weight']
# []
# label_words_dict []
# model_words_dict ['by', 'speak']
# []
# label_words_dict ['species', 'phenotype', 'chemotheraphy', 'alcohol']
# model_words_dict ['phenotype']
# ['phenotype']
# label_words_dict []
# model_words_dict ['', 'care', '', '', '', '', '']
# []
# label_words_dict []
# model_words_dict ['parents']
# []
# label_words_dict ['Birthweight', 'PDA', 'IVH', 'Suspected', 'Suspected']
# model_words_dict ['g', 'PDA', 'hours']
# ['PDA']
# label_words_dict []
# model_words_dict ['', '', '']
# []
# label_words_dict ['LMNA', 'LMNA', 'failure', 'DCMWT']
# model_words_dict ['LMNA', 'failure']
# ['LMNA', 'LMNA', 'failure']
# label_words_dict ['LMNA', 'transfusion']
# model_words_dict ['month']
# []
# label_words_dict ['would', 'be']
# model_words_dict ['', 'Participants']
# []
# label_words_dict []
# model_words_dict ['seizures']
# []
# label_words_dict ['clinically']
# model_words_dict ['one', 'clinically']
# ['clinically']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['old', 'pain']
# model_words_dict ['old', 'history', 'empyema']
# ['old']
# label_words_dict ['lobectomy', 'opioid', 'anticoagulation', 'empyema', 'anesthetics', 'fentanyl', 'deficit']
# model_words_dict ['lobectomy', 'opioid', 'anticoagulation', 'fentanyl', 'deficit', 'intra']
# ['lobectomy', 'opioid', 'anticoagulation', 'fentanyl', 'deficit']
# label_words_dict ['Technical']
# model_words_dict ['', 'Technical']
# ['Technical']
# label_words_dict ['Women']
# model_words_dict ['Spoken', 'understand', 'procedures']
# []
# label_words_dict ['pregnant', 'breastfeeding']
# model_words_dict ['pregnant', 'breastfeeding']
# ['pregnant', 'breastfeeding']
# label_words_dict []
# model_words_dict ['1', '2', 'was']
# []
# label_words_dict []
# model_words_dict ['grafting', 'operation']
# []
# label_words_dict ['operations', 'tract', 'iron', 'polycythemia', 'porphyria', 'autoimmune']
# model_words_dict ['operations', 'tract', 'iron', 'NSAIDs', 'immunosuppression', 'polycythemia', 'porphyria', 'autoimmune']
# ['operations', 'tract', 'iron', 'polycythemia', 'porphyria', 'autoimmune']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['Glucose']
# []
# label_words_dict ['F', 'F', 'allergies', 'supplements', 'Pregnancy', 'antibiotic']
# model_words_dict ['FM', 'FM', 'allergies', 'supplements', 'antibiotic']
# ['allergies', 'supplements', 'antibiotic']
# label_words_dict []
# model_words_dict ['', '', '', 'OR', '', 'OR', '', 'Nonpregnant', 'lactating', '', '', '', '', '', '', 'OR']
# []
# label_words_dict ['injury']
# model_words_dict ['injury']
# ['injury']
# label_words_dict ['schizophrenia', 'schizoaffectivedepressed', 'MEM', 'cancer', 'diabetes', 'disease', 'HIV', 'injury', 'hearing']
# model_words_dict ['schizophrenia', 'schizoaffectivedepressed', 'I', 'MEM', 'injury', 'hearing']
# ['schizophrenia', 'schizoaffectivedepressed', 'MEM', 'injury', 'hearing']
# label_words_dict ['']
# model_words_dict ['']
# ['']
# label_words_dict []
# model_words_dict ['years', 'week']
# []
# label_words_dict ['THA', 'knee', 'THA', 'disorders', 'extremities']
# model_words_dict ['THA', 'knee', 'THA', 'disorders', 'hip', 'extremities']
# ['THA', 'knee', 'THA', 'disorders', 'extremities']
# label_words_dict ['']
# model_words_dict ['']
# ['']
# label_words_dict []
# model_words_dict ['96cm']
# []
# label_words_dict ['thrombosis', 'syndrome', 'gastroparesis', 'thoracic', '3']
# model_words_dict ['thrombosis', 'disease', 'syndrome', 'gastroparesis', 'thoracic', 'movementsweek']
# ['thrombosis', 'syndrome', 'gastroparesis', 'thoracic']
# label_words_dict []
# model_words_dict ['2day']
# []
# label_words_dict ['breastfeeding']
# model_words_dict ['18', 'medication', 'disease', 'therapy', 'allergies']
# []
# label_words_dict ['medication', 'disease', 'therapy', 'allergies', 'cleaning']
# model_words_dict ['2', 'women', 'breastfeeding', '', '', 'cleaning']
# ['cleaning']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['Men']
# []
# label_words_dict ['Men', 'disease', 'insufficiency', 'mellitus', 'known', 'ezetimibe', 'pregnant', 'cardiac', 'Revestive', 'active', 'tract', 'hepatobiliary']
# model_words_dict ['insufficiency', 'mellitus', 'known', 'ezetimibe', 'pregnant', 'cardiac', 'Revestive', 'active']
# ['insufficiency', 'mellitus', 'known', 'ezetimibe', 'pregnant', 'cardiac', 'Revestive', 'active']
# label_words_dict []
# model_words_dict ['are', 'have']
# []
# label_words_dict []
# model_words_dict ['study']
# []
# label_words_dict ['ischemia', 'arterial']
# model_words_dict ['greater', 'arterial', 'instability']
# ['arterial']
# label_words_dict ['', '']
# model_words_dict ['', '', 'OR']
# ['', '']
# label_words_dict []
# model_words_dict ['Nationality', 'disease', 'dysfunction']
# []
# label_words_dict ['aspheochromocytoma', 'disease', 'liver']
# model_words_dict ['points', 'points', 'aspheochromocytoma']
# ['aspheochromocytoma']
# label_words_dict ['']
# model_words_dict ['diagnosis', 'AND', 'AND']
# []
# label_words_dict ['nicotine']
# model_words_dict ['alcohol', 'women', 'alcohol', 'nicotine', 'PI', 'safe']
# ['nicotine']
# label_words_dict ['HAMA', 'mild', 'anxiety', 'HAMA', 'PSS', 'alcohol', 'contraindicating', 'pregnant', 'nursing', 'illness', 'condition', 'safe']
# model_words_dict ['HAMA', '23', 'HAMA', 'PSS', 'pioglitazone', 'pharmacotherapy', 'illness', 'condition']
# ['HAMA', 'HAMA', 'PSS', 'illness', 'condition']
# label_words_dict ['would']
# model_words_dict ['', 'pregnant', 'nursing']
# []
# label_words_dict ['match']
# model_words_dict ['year']
# []
# label_words_dict ['anabolic', 'antiinflammatory', 'alcohol']
# model_words_dict ['antiinflammatory', 'alcohol']
# ['antiinflammatory', 'alcohol']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['colonoscopy']
# []
# label_words_dict []
# model_words_dict ['I']
# []
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['50']
# []
# label_words_dict ['home', 'unit', 'diabetes', 'chemotherapy', 'radiation', 'attack', 'trial', 'drug']
# model_words_dict ['05', 'home', 'unit', 'chemotherapy', 'years', 'trial', 'drug']
# ['home', 'unit', 'chemotherapy', 'trial', 'drug']
# label_words_dict ['', 'or']
# model_words_dict ['']
# ['']
# label_words_dict ['Visual', 'computerized', 'health', 'Willing', 'study', 'Rating', 'Females']
# model_words_dict ['60', 'Visual', 'neuropsychological', 'health', 'Willing', 'study', '0', 'exposure']
# ['Visual', 'health', 'Willing', 'study']
# label_words_dict ['MRI', 'disease', 'sclerosis', 'cyst', 'tumor', 'hypertension', 'deficiency', 'schizophrenia', 'disorder', 'disorder', 'dementia', 'Alcohol', 'abuse', 'pacemakers', 'clips', 'valves', 'implants', 'fragments', 'eyes', 'skin', 'pregnant', 'exposure']
# model_words_dict ['MRI', 'tumor', 'deficiency', 'disorder', 'dementia', 'Alcohol', 'abuse', 'fragments', 'skin', 'pregnant']
# ['MRI', 'tumor', 'deficiency', 'disorder', 'disorder', 'dementia', 'Alcohol', 'abuse', 'fragments', 'skin', 'pregnant']
# label_words_dict ['with', 'also']
# model_words_dict ['4', '6']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['']
# model_words_dict ['']
# ['']
# label_words_dict ['colitis']
# model_words_dict ['1874', 'assessment', 'agents', 'agents']
# []
# label_words_dict ['disease', 'colitis', 'bacterial', 'agents']
# model_words_dict ['disease', 'colitis', 'bacterial', 'excluded']
# ['disease', 'colitis', 'bacterial']
# label_words_dict ['are']
# model_words_dict ['patients']
# []
# label_words_dict ['Female']
# model_words_dict ['dyspareunia']
# []
# label_words_dict ['pain', 'dysmenorrhea', 'dyspareunia', 'MRI', 'peacemaker', 'bodies']
# model_words_dict ['pain', 'dysmenorrhea', 'peacemaker', 'bodies', 'claustrophobia']
# ['pain', 'dysmenorrhea', 'peacemaker', 'bodies']
# label_words_dict []
# model_words_dict ['with']
# []
# label_words_dict ['referred', 'pain']
# model_words_dict ['groups', 'pain']
# ['pain']
# label_words_dict ['joint', 'device', 'pacemakers']
# model_words_dict ['joint', 'joint', 'device', 'pacemakers']
# ['joint', 'device', 'pacemakers']
# label_words_dict []
# model_words_dict ['Patients']
# []
# label_words_dict ['surgery', 'analgesic']
# model_words_dict ['blocks', 'surgery']
# ['surgery']
# label_words_dict ['unilateral', 'moderate']
# model_words_dict ['unilateral', 'years', 'moderate', 'limitation', 'investigators']
# ['unilateral', 'moderate']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['benign']
# []
# label_words_dict ['benign']
# model_words_dict ['II', 'III']
# []
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['session']
# []
# label_words_dict ['breastfeeding']
# model_words_dict ['breastfeeding', 'pounds', 'session']
# ['breastfeeding']
# label_words_dict []
# model_words_dict ['with', 'are', '', 'are']
# []
# label_words_dict []
# model_words_dict ['septoplasty']
# []
# label_words_dict ['septoplasty']
# model_words_dict ['septoplasty']
# ['septoplasty']
# label_words_dict ['will', 'be']
# model_words_dict ['who', 'patient']
# []
# label_words_dict ['Intubated', 'disease', 'disease']
# model_words_dict ['Intubated', 'disease', 'disease']
# ['Intubated', 'disease', 'disease']
# label_words_dict ['Pregnancy', 'Prisoner']
# model_words_dict ['old', 'Pregnancy', 'Prisoner']
# ['Pregnancy', 'Prisoner']
# label_words_dict ['']
# model_words_dict ['', '']
# ['']
# label_words_dict ['fever', 'fever']
# model_words_dict ['days', 'fever', 'criteria']
# ['fever', 'fever']
# label_words_dict ['erythema', 'hands', 'lips', 'erythema', 'lips', 'tongue', 'oral', 'CRP']
# model_words_dict ['erythema', 'erythema', 'two', 'CRP']
# ['erythema', 'erythema', 'CRP']
# label_words_dict ['injection', 'do']
# model_words_dict ['do', 'meeting', 'do']
# ['do']
# label_words_dict ['study', 'study']
# model_words_dict ['treatment', 'adequate', 'period', 'test']
# []
# label_words_dict ['Histologically', 'advanced', 'first', 'gefitinib', 'exclude', 'first', 'compression', 'Severe', 'hypertension', 'diatheses', 'asthma', 'Chemotherapy']
# model_words_dict ['Histologically', 'advanced', 'first', 'gefitinib', 'first', 'diatheses', 'Chemotherapy']
# ['Histologically', 'advanced', 'first', 'gefitinib', 'first', 'diatheses', 'Chemotherapy']
# label_words_dict ['lesion', 'to', 'in']
# model_words_dict ['lesion', '']
# ['lesion']
# label_words_dict ['Born']
# model_words_dict ['life', '1day']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['', '']
# []
# label_words_dict ['women', 'women']
# model_words_dict ['hysterectomy', 'hysterectomy']
# []
# label_words_dict ['disease', 'hysterectomy', 'pelvic', 'hysterectomy', 'pelvic', 'uterus', 'pacemaker', 'internal']
# model_words_dict ['disease', '', '', 'pacemaker', 'internal']
# ['disease', 'pacemaker', 'internal']
# label_words_dict ['that']
# model_words_dict ['women', 'women', '']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['behavior', 'learning']
# model_words_dict []
# []
# label_words_dict ['', '']
# model_words_dict ['', '']
# ['', '']
# label_words_dict []
# model_words_dict ['Female', 'mammography', 'therapy']
# []
# label_words_dict ['mammography', 'ultrasound', 'pregnancy', 'periarthritis', 'pacemaker']
# model_words_dict ['mammography', 'pregnancy', 'pacemaker']
# ['mammography', 'pregnancy', 'pacemaker']
# label_words_dict ['may']
# model_words_dict ['that']
# []
# label_words_dict []
# model_words_dict ['bypass']
# []
# label_words_dict ['surgery', 'deficiency']
# model_words_dict ['defects', 'deficiency']
# ['deficiency']
# label_words_dict []
# model_words_dict ['Patients', 'days']
# []
# label_words_dict ['years', 'Tumor']
# model_words_dict ['years', 'enhancement', 'walls', 'gliomas']
# ['years']
# label_words_dict ['cortex', 'cortex', 'tract', 'cerebellum', 'stem', 'carcinoma', 'aphasia']
# model_words_dict ['in', 'tract', 'II', '80', 'stem', 'of', 'organ', 'aphasia']
# ['tract', 'stem', 'aphasia']
# label_words_dict ['reasons']
# model_words_dict ['5', 'years']
# []
# label_words_dict ['Pain']
# model_words_dict ['men', '18', 'Pain']
# ['Pain']
# label_words_dict ['men', 'diseases', 'hernia', 'surgeries', 'vision', 'hearing', 'trauma']
# model_words_dict ['surgeries', 'hearing', 'trauma']
# ['surgeries', 'hearing', 'trauma']
# label_words_dict []
# model_words_dict ['patients']
# []
# label_words_dict []
# model_words_dict ['patient', 'newsletter', 'sepsis']
# []
# label_words_dict ['guardianship', 'guardianship', 'pregnant', 'breastfeeding', 'limitation', 'undergone', 'scheduled', 'neoplasia']
# model_words_dict ['patient', 'affiliate', 'guardianship', 'patient', 'parturient', 'limitation', 'undergone', 'scheduled']
# ['guardianship', 'guardianship', 'limitation', 'undergone', 'scheduled']
# label_words_dict []
# model_words_dict ['AND']
# []
# label_words_dict ['anaemia']
# model_words_dict ['mmHg', 'anaemia']
# ['anaemia']
# label_words_dict ['disease', 'Kidney', 'soya', 'eggs', '20']
# model_words_dict ['disease', 'disease', 'propofol', 'soya', 'eggs', '20']
# ['disease', 'soya', 'eggs', '20']
# label_words_dict []
# model_words_dict ['', '']
# []
# label_words_dict []
# model_words_dict ['C0500', 'B0700', 'B0800', 'weeks', 'Willing', 'Willing', 'Willing', 'Willing']
# []
# label_words_dict ['Alzheimers']
# model_words_dict ['Alzheimers']
# ['Alzheimers']
# label_words_dict []
# model_words_dict ['Being', 'will', '', '', '']
# []
# label_words_dict ['CI']
# model_words_dict ['C40', 'Signed', '1000']
# []
# label_words_dict ['C40X', 'Implant', 'risk']
# model_words_dict ['severe', 'to', 'C40X', 'Implant', 'risk', 'with']
# ['C40X', 'Implant', 'risk']
# label_words_dict ['or']
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['study']
# []
# label_words_dict ['disease', 'respiratory', 'metabolic', 'insufficiency', 'disease', 'hepatitis']
# model_words_dict ['disease', 'respiratory', 'metabolic', '4', '5', 'disease', 'hepatitis']
# ['disease', 'respiratory', 'metabolic', 'disease', 'hepatitis']
# label_words_dict ['with']
# model_words_dict ['Patients']
# []
# label_words_dict ['hospitalized', 'admitted', 'admitted']
# model_words_dict ['understand', 'Madison']
# []
# label_words_dict ['acute', 'HTN', 'smoker', 'DM']
# model_words_dict ['acute', 'age', 'patient', 'one', 'before']
# ['acute']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['Male', 'for']
# []
# label_words_dict []
# model_words_dict ['years']
# []
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['pregnancy']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['condition']
# []
# label_words_dict ['LDLC']
# model_words_dict ['morbidity']
# []
# label_words_dict ['morbidity', 'disease']
# model_words_dict ['disease', 'therapy']
# ['disease']
# label_words_dict []
# model_words_dict ['1', 'Currently', '2', '3']
# []
# label_words_dict ['illness']
# model_words_dict ['participate']
# []
# label_words_dict ['prediabetes', 'glucose', 'diabetes', 'steroidinduced', 'insufficiency', 'malignancy', 'disease', 'disease', 'deficits', 'alcohol', 'homelessness']
# model_words_dict ['prediabetes', '57', '140', 'member', 'diabetes', 'insufficiency', 'malignancy', 'disease', 'disease', 'deficits', 'alcohol', 'homelessness']
# ['prediabetes', 'diabetes', 'insufficiency', 'malignancy', 'disease', 'disease', 'deficits', 'alcohol', 'homelessness']
# label_words_dict ['that', '4', 'or']
# model_words_dict ['4', 'OR']
# ['4']
# label_words_dict ['health', 'Women', 'Women', 'potential']
# model_words_dict ['health', 'polyps']
# ['health']
# label_words_dict ['current', 'pregnant', 'inhaled', 'corticosteroids', 'cromolyn', 'renal', 'hepatic', 'neurologic', 'cardiovascular', 'hematologic', 'metabolic', 'cerebrovascular', 'respiratory', 'gastrointestinal', 'illness', 'disorder', 'respiratory', 'polyps', 'allergies', 'antihistamines', 'nasal', 'oral', 'decongestants']
# model_words_dict ['current', 'schedule', 'pregnant', 'inhaled', 'cromolyn', 'gastrointestinal', 'illness', 'study', 'respiratory', 'allergies', 'antihistamines', 'oral', 'decongestants']
# ['current', 'pregnant', 'inhaled', 'cromolyn', 'respiratory', 'gastrointestinal', 'illness', 'respiratory', 'allergies', 'antihistamines', 'oral', 'decongestants']
# label_words_dict ['and', 'are']
# model_words_dict ['are', 'using']
# ['are']
# label_words_dict ['female', 'rupture', 'release', 'diseases']
# model_words_dict ['rupture', 'understanding', 'test']
# ['rupture']
# label_words_dict ['male', 'medical', 'physical']
# model_words_dict ['male', 'medical', 'medical']
# ['male', 'medical']
# label_words_dict ['did', 'did', 'with']
# model_words_dict ['that', 'that']
# []
# label_words_dict []
# model_words_dict ['7', 'Diagnostic']
# []
# label_words_dict ['Normal', 'troubles', 'dysphasia', 'disorder']
# model_words_dict ['Normal', 'parent', 'troubles', 'dysphasia', 'disorder']
# ['Normal', 'troubles', 'dysphasia', 'disorder']
# label_words_dict ['']
# model_words_dict ['']
# ['']
# label_words_dict ['MRI']
# model_words_dict ['MRI']
# ['MRI']
# label_words_dict ['chemotherapy', 'Progressive', 'pressure', 'Severe', 'asthma']
# model_words_dict ['chemotherapy', 'Progressive', 'Severe', 'asthma']
# ['chemotherapy', 'Progressive', 'Severe', 'asthma']
# label_words_dict ['or', 'that', 'bpm']
# model_words_dict ['bpm', '']
# ['bpm']
# label_words_dict []
# model_words_dict ['LBP', 'back', 'pain', 'hours', 'LBP', 'home']
# []
# label_words_dict ['Men', 'Allergic']
# model_words_dict ['Men', 'Pregnant', 'to']
# ['Men']
# label_words_dict ['', '', '']
# model_words_dict ['muscles', '', 'syndrome', 'medications']
# ['', '', '']
# label_words_dict ['TBSA']
# model_words_dict ['pulses']
# []
# label_words_dict ['flap', 'paresis', 'TBSA', 'thickness', 'Prior', 'deformity']
# model_words_dict ['flap', 'paresis', 'TBSA', 'thickness', 'Prior', 'deformity']
# ['flap', 'paresis', 'TBSA', 'thickness', 'Prior', 'deformity']
# label_words_dict ['9']
# model_words_dict ['closeable', 'AND', '9']
# ['9']
# label_words_dict ['TSAT']
# model_words_dict ['therapy', '', '']
# []
# label_words_dict ['Acute', 'bleeding', 'infection', 'pressure', 'B12', 'Uncontrolled', 'Acute', 'disease', 'Hemodialysis']
# model_words_dict ['Acute', 'bleeding', 'weeks', 'infection', '100mmHg', 'B12', 'Uncontrolled', 'Acute', 'disease']
# ['Acute', 'bleeding', 'infection', 'B12', 'Uncontrolled', 'Acute', 'disease']
# label_words_dict ['or']
# model_words_dict ['with', 'with']
# []
# label_words_dict []
# model_words_dict ['sexes']
# []
# label_words_dict ['microsomia', 'Collins', 'head']
# model_words_dict ['patients', 'microsomia', 'Collins', 'site']
# ['microsomia', 'Collins']
# label_words_dict ['Patients']
# model_words_dict ['of', 'does']
# []
# label_words_dict ['MRI', 'treatment']
# model_words_dict ['MRI', 'treatment']
# ['MRI', 'treatment']
# label_words_dict ['Nx', 'Mx', 'medical', 'device', 'implants', 'medication']
# model_words_dict ['Nx', 'Mx', 'medical', 'device', 'medication']
# ['Nx', 'Mx', 'medical', 'device', 'medication']
# label_words_dict ['would', 'which', 'claustrophobia']
# model_words_dict ['', 'claustrophobia']
# ['claustrophobia']
# label_words_dict []
# model_words_dict ['consented']
# []
# label_words_dict ['biologics', 'bladder', 'reaction']
# model_words_dict ['biologics', 'bladder', 'reaction']
# ['biologics', 'bladder', 'reaction']
# label_words_dict []
# model_words_dict ['causes', 'refuse']
# []
# label_words_dict ['women', 'women', 'women', 'women']
# model_words_dict ['ngml']
# []
# label_words_dict ['diabetes', 'disease', 'enzymes', 'failure', 'inflammatory', 'cycle']
# model_words_dict ['diabetes', 'disease', 'prolongation', 'enzymes', 'failure', 'inflammatory', 'III', 'cycle']
# ['diabetes', 'disease', 'enzymes', 'failure', 'inflammatory', 'cycle']
# label_words_dict []
# model_words_dict ['', '', '']
# []
# label_words_dict []
# model_words_dict ['FDR', '16']
# []
# label_words_dict ['FDR', 'Syndrome', 'Syndrome', 'Syndrome', 'syndrome', 'syndrome', 'syndrome', 'trauma']
# model_words_dict ['syndrome', 'trauma']
# ['syndrome', 'syndrome', 'syndrome', 'trauma']
# label_words_dict []
# model_words_dict ['Probands', 'Probands', 'associated', 'Probandsrelatives']
# []
# label_words_dict []
# model_words_dict ['18']
# []
# label_words_dict ['exercise', 'exercise']
# model_words_dict ['exercise', 'exercise']
# ['exercise', 'exercise']
# label_words_dict ['reasons', 'Medication']
# model_words_dict ['reasons', 'Medication']
# ['reasons', 'Medication']
# label_words_dict ['stroke']
# model_words_dict ['stroke', 'consent']
# ['stroke']
# label_words_dict ['seizure', 'epilepsy', 'disorders', 'surgery', 'implant', 'medications', 'inhibitors', 'dopamine', 'agonists', 'haloperidol', 'lithium', 'inhibitors', 'betablockers', 'nimodipine', 'levetiracetam', 'ethosuximide', 'benzodiazepines', 'baclofen', 'neuropathy', 'Social']
# model_words_dict ['seizureepilepsy', 'pacemaker', 'disorders', 'surgery', 'head', 'inhibitors', 'dopamine', 'agonists', 'haloperidol', 'lithium', 'inhibitors', 'betablockers', 'nimodipine', 'levetiracetam', 'ethosuximide', 'benzodiazepines', 'baclofen', 'neuropathy', 'social']
# ['disorders', 'surgery', 'inhibitors', 'dopamine', 'agonists', 'haloperidol', 'lithium', 'inhibitors', 'betablockers', 'nimodipine', 'levetiracetam', 'ethosuximide', 'benzodiazepines', 'baclofen', 'neuropathy']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['steatohepatitis', 'aneurism', 'serology', 'write', 'exercise']
# []
# label_words_dict ['steatohepatitis', 'minutes', 'symptoms', 'myocarditis', 'aneurism', 'serology', 'cirrhosis', 'disease', 'past', 'varices', 'ascites', 'immunosuppression', 'male']
# model_words_dict ['intensity', 'symptoms', 'myocarditis', 'suspected', 'biopsy', 'disease', 'past', 'immunosuppression', 'male']
# ['symptoms', 'myocarditis', 'disease', 'past', 'immunosuppression', 'male']
# label_words_dict ['', '', '', '', '', '', '', 'except', '', '']
# model_words_dict ['', '', 'exercise', 'event', 'angina', 'compromise', 'stenosis', 'failure', 'embolus', 'pericarditis', 'AND', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '']
# label_words_dict ['medications']
# model_words_dict ['day']
# []
# label_words_dict []
# model_words_dict ['age', 'two']
# []
# label_words_dict ['', '']
# model_words_dict ['', '']
# ['', '']
# label_words_dict []
# model_words_dict ['home', 'videotapingaudiotaping', 'scale']
# []
# label_words_dict ['years', 'AA', 'programs', 'selfinjury', 'attempt', 'treatment', 'schizophrenia']
# model_words_dict ['years', 'programs', 'schizophrenia', 'anorexia']
# ['years', 'programs', 'schizophrenia']
# label_words_dict ['to', 'services', 'should', 'be', '']
# model_words_dict ['does', 'services', 'should', '', '']
# ['services', 'should', '']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['pathological', 'genetic', 'Degeneration', 'Disease']
# model_words_dict ['Either', 'pathological', 'genetic', 'Disease', 'Impairment']
# ['pathological', 'genetic', 'Disease']
# label_words_dict ['2']
# model_words_dict ['1', 'to', 'Does', '3']
# []
# label_words_dict []
# model_words_dict ['gastrointestinal']
# []
# label_words_dict ['gastrointestinal', 'prebiotics']
# model_words_dict ['prebiotics']
# ['prebiotics']
# label_words_dict ['']
# model_words_dict ['']
# ['']
# label_words_dict []
# model_words_dict ['pain', 'pain', 'Read', 'treated', 'pain']
# []
# label_words_dict ['pain', 'radiculopathy', 'radiculitis', 'needling', '10']
# model_words_dict ['Signs', 'radiculitis', 'needling', '10']
# ['radiculitis', 'needling', '10']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict ['nonambulant']
# model_words_dict ['I']
# []
# label_words_dict ['ventilation', 'cardiorespiratory']
# model_words_dict ['ventilation', 'cardiorespiratory']
# ['ventilation', 'cardiorespiratory']
# label_words_dict ['were']
# model_words_dict ['were']
# ['were']
# label_words_dict ['DNA']
# model_words_dict ['adults', 'DNA']
# ['DNA']
# label_words_dict ['adults', 'kidney', 'heart', 'lung', 'living']
# model_words_dict ['transplant', 'heart', 'lung', 'living']
# ['heart', 'lung', 'living']
# label_words_dict ['donor', 'deceased']
# model_words_dict ['deceased', '', 'is']
# ['deceased']
# label_words_dict ['carcinoma', 'understand', 'prognosis']
# model_words_dict ['breast', 'understand', 'prognosis', 'neurologic']
# ['understand', 'prognosis']
# label_words_dict ['histologically', 'invasive', 'neurologic', 'ongoing', 'pectoris', 'arrhythmia', 'illness', 'abduct']
# model_words_dict ['histologically', 'invasive', 'but', 'ongoing', 'arrhythmia', 'body']
# ['histologically', 'invasive', 'ongoing', 'arrhythmia']
# label_words_dict ['be', 'Participants']
# model_words_dict ['', 'Participants']
# ['Participants']
# label_words_dict []
# model_words_dict ['arthroplasty']
# []
# label_words_dict []
# model_words_dict ['Pregnant']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['speaker']
# []
# label_words_dict []
# model_words_dict ['English']
# []
# label_words_dict ['smoker', '', 'did', 'language']
# model_words_dict ['no', '', 'did', 'does', 'OR']
# ['', 'did']
# label_words_dict []
# model_words_dict ['Patients', 'participate']
# []
# label_words_dict ['restored', 'flourosis']
# model_words_dict ['restored', 'flourosis']
# ['restored', 'flourosis']
# label_words_dict ['are']
# model_words_dict ['are']
# ['are']
# label_words_dict ['ventilation']
# model_words_dict ['ventilation']
# ['ventilation']
# label_words_dict ['Pneumothorax', 'expectancy', 'esophageal', 'ulcerations', 'tumors', 'diverticulitis', 'varices', 'sinusitis', 'epistaxis', 'thrombocytopenia', 'INR', 'preintervention', 'intervention']
# model_words_dict ['Pneumothorax', 'hours', 'esophageal', 'varices', 'epistaxis', '30', '3', 'intervention']
# ['Pneumothorax', 'esophageal', 'varices', 'epistaxis', 'intervention']
# label_words_dict ['that', 'pathology']
# model_words_dict ['3']
# []
# label_words_dict []
# model_words_dict ['metastases']
# []
# label_words_dict ['OSCC', 'tongue', 'mouth', 'gingiva', 'trigone', 'Recurrent', 'immunotherapy', 'cetuximab', 'carcinoma', 'tumor', 'disease']
# model_words_dict ['trigone', 'mucosa', 'Recurrent', 'immunotherapy', 'cetuximab', 'carcinoma', 'tumor', 'disease', 'metastases']
# ['trigone', 'Recurrent', 'immunotherapy', 'cetuximab', 'carcinoma', 'tumor', 'disease']
# label_words_dict ['OSCC']
# model_words_dict ['OR']
# []
# label_words_dict ['AHCT', 'not', 'antibiotics']
# model_words_dict ['source', 'stable', 'IC', 'piptazo']
# []
# label_words_dict ['donor', 'meropenem', 'meropenem', 'unwilling', 'piptazo', 'allergy', 'medical', 'risk']
# model_words_dict ['donor', 'meropenem', 'meropenem', 'unwilling', 'allergy', 'medical', 'subject']
# ['donor', 'meropenem', 'meropenem', 'unwilling', 'allergy', 'medical']
# label_words_dict ['and', 'or', 'Patients']
# model_words_dict ['AND', 'Patients']
# ['Patients']
# label_words_dict []
# model_words_dict ['years']
# []
# label_words_dict ['21']
# model_words_dict ['acid', 'levels', '21', '2', 'treatment']
# ['21']
# label_words_dict []
# model_words_dict ['3', '4', '5']
# []
# label_words_dict []
# model_words_dict ['THA']
# []
# label_words_dict []
# model_words_dict ['one']
# []
# label_words_dict ['THA']
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['male', 'transplant', 'weeks']
# model_words_dict ['male', '0', '1', 'transplant', 'response', 'weeks']
# ['male', 'transplant', 'weeks']
# label_words_dict []
# model_words_dict ['of', 'failed']
# []
# label_words_dict ['18', 'uterus']
# model_words_dict ['18', 'uterus']
# ['18', 'uterus']
# label_words_dict ['chemotherapy']
# model_words_dict ['chemotherapy']
# ['chemotherapy']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['preexisting', 'previous']
# []
# label_words_dict ['pacemaker']
# model_words_dict ['pacemaker']
# ['pacemaker']
# label_words_dict []
# model_words_dict ['therapy']
# []
# label_words_dict []
# model_words_dict ['Patient']
# []
# label_words_dict ['preeclampsia', 'guardianship']
# model_words_dict ['11', 'preeclampsia']
# ['preeclampsia']
# label_words_dict []
# model_words_dict ['', 'Patient', '']
# []
# label_words_dict []
# model_words_dict ['account']
# []
# label_words_dict ['physical']
# model_words_dict ['physical']
# ['physical']
# label_words_dict ['which']
# model_words_dict ['1', '2']
# []
# label_words_dict ['Children', 'months', 'Children', 'Children', 'Children']
# model_words_dict ['months', 'pathologies', 'neurological']
# ['months']
# label_words_dict ['Fullterm', 'neurological']
# model_words_dict ['Fullterm']
# ['Fullterm']
# label_words_dict []
# model_words_dict ['barrier']
# []
# label_words_dict ['children']
# model_words_dict ['children', 'protocol']
# ['children']
# label_words_dict ['infants', 'chest']
# model_words_dict ['chest']
# ['chest']
# label_words_dict ['for', 'be']
# model_words_dict ['', 'to', 'for']
# ['for']
# label_words_dict []
# model_words_dict ['principal', 'willing']
# []
# label_words_dict ['tattoo', 'cyanoacrylate', 'formaldehyde', 'chloride', 'arthroplasty', 'HIV', 'abnormality', 'personal', 'keloid', 'formations']
# model_words_dict ['years', 'tattoo', 'cyanoacrylate', 'formaldehyde', 'chloride', 'selfreport', 'arthroplasty', 'positive', 'abnormality', 'personal', 'keloid', 'formations']
# ['tattoo', 'cyanoacrylate', 'formaldehyde', 'chloride', 'arthroplasty', 'abnormality', 'personal', 'keloid', 'formations']
# label_words_dict []
# model_words_dict ['The']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['dynamometer']
# model_words_dict ['men', 'men', 'Guangdong']
# []
# label_words_dict []
# model_words_dict ['', 'has']
# []
# label_words_dict ['sSBP']
# model_words_dict ['20mmHg', 'hypotension', 'hypertension', 'III', 'aminotransferase']
# []
# label_words_dict ['hypotension', 'secondary', 'hypertension', 'ischemia', 'hemorrhage', 'attack', 'infarction', 'telmisartan', 'inhibitors', 'aminotransferase', 'potassium']
# model_words_dict ['infarction', 'telmisartan', 'inhibitors', 'mmolL']
# ['infarction', 'telmisartan', 'inhibitors']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict ['Women']
# model_words_dict ['detained']
# []
# label_words_dict ['Men', 'to', 'Pregnant', 'willing', 'Prisoners', 'detain', 'psychiatric']
# model_words_dict ['Men', 'age', 'to', 'Pregnant', 'willing', 'Prisoners', 'psychiatric', 'barrier']
# ['Men', 'to', 'Pregnant', 'willing', 'Prisoners', 'psychiatric']
# label_words_dict ['subjects', 'otherwise', 'WOCBA', 'or', 'to']
# model_words_dict ['subjects', 'otherwise', 'WOCBA', 'OR', 'Patients']
# ['subjects', 'otherwise', 'WOCBA']
# label_words_dict []
# model_words_dict ['residents']
# []
# label_words_dict ['pacemaker']
# model_words_dict ['pacemaker']
# ['pacemaker']
# label_words_dict []
# model_words_dict ['', '', '']
# []
# label_words_dict []
# model_words_dict ['willing']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['has', 'Patient']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['ultrasound', 'pelvic', 'renal', 'abnormalities', 'pelvic']
# model_words_dict ['ultrasound', 'pelvic', 'renal', 'abnormalities', 'pelvic']
# ['ultrasound', 'pelvic', 'renal', 'abnormalities', 'pelvic']
# label_words_dict ['', 'presenting']
# model_words_dict ['']
# ['']
# label_words_dict ['disease']
# model_words_dict ['disease', 'surgery']
# ['disease']
# label_words_dict ['Plane', 'Allergy']
# model_words_dict ['medicated', 'Plane', 'Allergy']
# ['Plane', 'Allergy']
# label_words_dict ['Patient', 'Patient']
# model_words_dict ['Patient', 'Patient']
# ['Patient', 'Patient']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['pregnant']
# model_words_dict ['pregnant']
# ['pregnant']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['HbA1C']
# model_words_dict ['80', 'stents']
# []
# label_words_dict ['medical', 'psychiatric', 'hypotension', 'malignancy', 'Drug', 'calcification', 'clips', 'bypass', 'Hematological']
# model_words_dict ['score', 'psychiatric', 'mmHg', 'III', 'cancer', 'Drug', 'bypass', 'Hematological']
# ['psychiatric', 'Drug', 'bypass', 'Hematological']
# label_words_dict []
# model_words_dict ['', '', '']
# []
# label_words_dict []
# model_words_dict ['reason', 'interfere']
# []
# label_words_dict ['disease', 'condition', 'previous']
# model_words_dict ['disease', 'medical', 'condition', 'previous']
# ['disease', 'condition', 'previous']
# label_words_dict ['undergoing']
# model_words_dict ['is']
# []
# label_words_dict []
# model_words_dict ['Subjects', 'available', 'tumors']
# []
# label_words_dict ['suspected', 'recurrent', 'scheduled', 'biopsy', 'excised', 'draw', 'available', 'testing', 'tumors']
# model_words_dict ['years', 'race', 'suspected', 'recurrent', 'for', 'biopsy', 'tumors', 'draw', 'parents']
# ['suspected', 'recurrent', 'biopsy', 'draw', 'tumors']
# label_words_dict ['do', 'is']
# model_words_dict ['who', 'is']
# ['is']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['which']
# model_words_dict ['']
# []
# label_words_dict ['women']
# model_words_dict ['Patients']
# []
# label_words_dict ['response', 'fentanyl', 'ropivacaine', '50kg']
# model_words_dict ['hypersensitivity', 'response', 'read', '50kg']
# ['response', '50kg']
# label_words_dict ['is']
# model_words_dict ['Patients', 'who', 'who']
# []
# label_words_dict []
# model_words_dict ['by', 'phenotype', 'speak']
# []
# label_words_dict ['species', 'phenotype', 'chemotheraphy', 'alcohol']
# model_words_dict ['chemotherapy']
# []
# label_words_dict []
# model_words_dict ['', '', '', '', '']
# []
# label_words_dict []
# model_words_dict ['g']
# []
# label_words_dict ['Birthweight', 'PDA', 'IVH', 'Suspected', 'Suspected']
# model_words_dict ['weeks', 'PDA', 'hours']
# ['PDA']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict ['LMNA', 'LMNA', 'failure', 'DCMWT']
# model_words_dict ['cases', 'LMNA', 'failure']
# ['LMNA', 'LMNA', 'failure']
# label_words_dict ['LMNA', 'transfusion']
# model_words_dict ['month']
# []
# label_words_dict ['would', 'be']
# model_words_dict ['excluded']
# []
# label_words_dict []
# model_words_dict ['seizures']
# []
# label_words_dict ['clinically']
# model_words_dict ['one', 'clinically']
# ['clinically']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['old', 'pain']
# model_words_dict ['old', 'history', 'empyema']
# ['old']
# label_words_dict ['lobectomy', 'opioid', 'anticoagulation', 'empyema', 'anesthetics', 'fentanyl', 'deficit']
# model_words_dict ['lobectomy', 'opioid', 'anticoagulation', 'anesthetics', 'fentanyl', 'deficit', 'intra']
# ['lobectomy', 'opioid', 'anticoagulation', 'anesthetics', 'fentanyl', 'deficit']
# label_words_dict ['Technical']
# model_words_dict ['Patients', 'Technical']
# ['Technical']
# label_words_dict ['Women']
# model_words_dict ['Spoken', 'understand', 'procedures']
# []
# label_words_dict ['pregnant', 'breastfeeding']
# model_words_dict ['pregnant', 'breastfeeding']
# ['pregnant', 'breastfeeding']
# label_words_dict []
# model_words_dict ['was']
# []
# label_words_dict []
# model_words_dict ['grafting', 'operation']
# []
# label_words_dict ['operations', 'tract', 'iron', 'polycythemia', 'porphyria', 'autoimmune']
# model_words_dict ['operations', 'tract', 'NSAIDs', 'immunosuppression', 'polycythemia', 'porphyria', 'autoimmune']
# ['operations', 'tract', 'polycythemia', 'porphyria', 'autoimmune']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['Glucose']
# []
# label_words_dict ['F', 'F', 'allergies', 'supplements', 'Pregnancy', 'antibiotic']
# model_words_dict ['C', 'cm', 'mgdl', 'mmHg', 'allergies', 'supplements', 'Pregnancy', 'lactation', 'antibiotic', 'mmHg']
# ['allergies', 'supplements', 'Pregnancy', 'antibiotic']
# label_words_dict []
# model_words_dict ['', '', '']
# []
# label_words_dict ['injury']
# model_words_dict ['injury']
# ['injury']
# label_words_dict ['schizophrenia', 'schizoaffectivedepressed', 'MEM', 'cancer', 'diabetes', 'disease', 'HIV', 'injury', 'hearing']
# model_words_dict ['schizophrenia', 'schizoaffectivedepressed', 'I', 'MEM', 'injury', 'hearing']
# ['schizophrenia', 'schizoaffectivedepressed', 'MEM', 'injury', 'hearing']
# label_words_dict ['']
# model_words_dict ['']
# ['']
# label_words_dict []
# model_words_dict ['years', 'week']
# []
# label_words_dict ['THA', 'knee', 'THA', 'disorders', 'extremities']
# model_words_dict ['THA', 'knee', 'THA', 'disorders', 'hip', 'extremities']
# ['THA', 'knee', 'THA', 'disorders', 'extremities']
# label_words_dict ['']
# model_words_dict ['']
# ['']
# label_words_dict []
# model_words_dict ['96cm', 'movementsweek']
# []
# label_words_dict ['thrombosis', 'syndrome', 'gastroparesis', 'thoracic', '3']
# model_words_dict ['thrombosis', 'disease', 'syndrome', 'gastroparesis', 'thoracic', 'movementsweek']
# ['thrombosis', 'syndrome', 'gastroparesis', 'thoracic']
# label_words_dict []
# model_words_dict ['', 'AND']
# []
# label_words_dict ['breastfeeding']
# model_words_dict ['18', 'medication', 'disease', 'therapy', 'allergies']
# []
# label_words_dict ['medication', 'disease', 'therapy', 'allergies', 'cleaning']
# model_words_dict ['2', 'women', 'breastfeeding', '', '', 'cleaning']
# ['cleaning']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['Men']
# []
# label_words_dict ['Men', 'disease', 'insufficiency', 'mellitus', 'known', 'ezetimibe', 'pregnant', 'cardiac', 'Revestive', 'active', 'tract', 'hepatobiliary']
# model_words_dict ['disease', 'insufficiency', 'mellitus', 'known', 'ezetimibe', 'pregnant', 'cardiac', 'Revestive', 'ingredient', 'active']
# ['disease', 'insufficiency', 'mellitus', 'known', 'ezetimibe', 'pregnant', 'cardiac', 'Revestive', 'active']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['g']
# []
# label_words_dict ['ischemia', 'arterial']
# model_words_dict ['arterial']
# ['arterial']
# label_words_dict ['', '']
# model_words_dict ['Patients', 'Patients']
# []
# label_words_dict []
# model_words_dict ['Nationality', 'dysfunction']
# []
# label_words_dict ['aspheochromocytoma', 'disease', 'liver']
# model_words_dict ['points', 'points', 'aspheochromocytoma', 'disease']
# ['aspheochromocytoma', 'disease']
# label_words_dict ['']
# model_words_dict ['diagnosis']
# []
# label_words_dict ['nicotine']
# model_words_dict ['alcohol', 'women', 'nicotine']
# ['nicotine']
# label_words_dict ['HAMA', 'mild', 'anxiety', 'HAMA', 'PSS', 'alcohol', 'contraindicating', 'pregnant', 'nursing', 'illness', 'condition', 'safe']
# model_words_dict ['women', 'HAMA', '23', 'HAMA', 'PSS', 'pharmacotherapy', 'nursing', 'condition']
# ['HAMA', 'HAMA', 'PSS', 'nursing', 'condition']
# label_words_dict ['would']
# model_words_dict ['']
# []
# label_words_dict ['match']
# model_words_dict ['year']
# []
# label_words_dict ['anabolic', 'antiinflammatory', 'alcohol']
# model_words_dict ['antiinflammatory', 'alcohol']
# ['antiinflammatory', 'alcohol']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['colonoscopy']
# []
# label_words_dict []
# model_words_dict ['I']
# []
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['50']
# []
# label_words_dict ['home', 'unit', 'diabetes', 'chemotherapy', 'radiation', 'attack', 'trial', 'drug']
# model_words_dict ['05', 'home', 'unit', 'chemotherapy', 'years', 'trial', 'drug']
# ['home', 'unit', 'chemotherapy', 'trial', 'drug']
# label_words_dict ['', 'or']
# model_words_dict ['']
# ['']
# label_words_dict ['Visual', 'computerized', 'health', 'Willing', 'study', 'Rating', 'Females']
# model_words_dict ['60', 'Visual', 'neuropsychological', 'health', 'Willing', 'study', 'MRI', '0', 'exposure']
# ['Visual', 'health', 'Willing', 'study']
# label_words_dict ['MRI', 'disease', 'sclerosis', 'cyst', 'tumor', 'hypertension', 'deficiency', 'schizophrenia', 'disorder', 'disorder', 'dementia', 'Alcohol', 'abuse', 'pacemakers', 'clips', 'valves', 'implants', 'fragments', 'eyes', 'skin', 'pregnant', 'exposure']
# model_words_dict ['tumor', 'deficiency', 'disorder', 'dementia', 'abuse', 'fragments', 'skin', 'pregnant']
# ['tumor', 'deficiency', 'disorder', 'disorder', 'dementia', 'abuse', 'fragments', 'skin', 'pregnant']
# label_words_dict ['with', 'also']
# model_words_dict ['4', '6', 'are']
# []
# label_words_dict []
# model_words_dict ['Healthy']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['']
# model_words_dict ['']
# ['']
# label_words_dict ['colitis']
# model_words_dict ['1874', 'assessment', 'agents']
# []
# label_words_dict ['disease', 'colitis', 'bacterial', 'agents']
# model_words_dict ['disease', 'colitis', 'bacterial']
# ['disease', 'colitis', 'bacterial']
# label_words_dict ['are']
# model_words_dict ['excluded']
# []
# label_words_dict ['Female']
# model_words_dict ['dyspareunia']
# []
# label_words_dict ['pain', 'dysmenorrhea', 'dyspareunia', 'MRI', 'peacemaker', 'bodies']
# model_words_dict ['pain', 'dysmenorrhea', 'peacemaker', 'bodies']
# ['pain', 'dysmenorrhea', 'peacemaker', 'bodies']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['referred', 'pain']
# model_words_dict ['groups', 'pain']
# ['pain']
# label_words_dict ['joint', 'device', 'pacemakers']
# model_words_dict ['joint', 'joint', 'device', 'pacemakers']
# ['joint', 'device', 'pacemakers']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['surgery', 'analgesic']
# model_words_dict ['surgery', 'analgesic']
# ['surgery', 'analgesic']
# label_words_dict ['unilateral', 'moderate']
# model_words_dict ['unilateral', 'years', 'surgery', 'moderate', 'limitation', 'investigators']
# ['unilateral', 'moderate']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['benign']
# []
# label_words_dict ['benign']
# model_words_dict ['II', 'III']
# []
# label_words_dict []
# model_words_dict ['Patients']
# []
# label_words_dict []
# model_words_dict ['session']
# []
# label_words_dict ['breastfeeding']
# model_words_dict ['breastfeeding', 'pounds']
# ['breastfeeding']
# label_words_dict []
# model_words_dict ['who']
# []
# label_words_dict []
# model_words_dict ['septoplasty']
# []
# label_words_dict ['septoplasty']
# model_words_dict ['septoplasty']
# ['septoplasty']
# label_words_dict ['will', 'be']
# model_words_dict ['who', 'patient']
# []
# label_words_dict ['Intubated', 'disease', 'disease']
# model_words_dict ['Intubated', 'disease', 'disease']
# ['Intubated', 'disease', 'disease']
# label_words_dict ['Pregnancy', 'Prisoner']
# model_words_dict ['old', 'Pregnancy', 'Prisoner']
# ['Pregnancy', 'Prisoner']
# label_words_dict ['']
# model_words_dict ['', '', '', '']
# ['']
# label_words_dict ['fever', 'fever']
# model_words_dict ['days', 'fever', 'criteria']
# ['fever', 'fever']
# label_words_dict ['erythema', 'hands', 'lips', 'erythema', 'lips', 'tongue', 'oral', 'CRP']
# model_words_dict ['erythema', 'erythema', 'oral', 'two', 'CRP']
# ['erythema', 'erythema', 'oral', 'CRP']
# label_words_dict ['injection', 'do']
# model_words_dict ['do', 'meeting', 'do']
# ['do']
# label_words_dict ['study', 'study']
# model_words_dict ['treatment', 'adequate', 'period', 'dose', 'test']
# []
# ...
# []
# label_words_dict ['behavior', 'learning']
# model_words_dict []
# []
# label_words_dict ['', '']
# model_words_dict ['', '']
# ['', '']
# label_words_dict []
# model_words_dict ['Female', 'mammography']
# []
# label_words_dict ['mammography', 'ultrasound', 'pregnancy', 'periarthritis', 'pacemaker']
# model_words_dict ['mammography', 'pregnancy', 'pacemaker']
# ['mammography', 'pregnancy', 'pacemaker']
# label_words_dict ['may']
# model_words_dict ['', 'may']
# ['may']
# label_words_dict []
# model_words_dict ['bypass', 'associated']
# []
# label_words_dict ['surgery', 'deficiency']
# model_words_dict ['defects', 'deficiency']
# ['deficiency']
# label_words_dict []
# model_words_dict ['Patients']
# []
# label_words_dict ['years', 'Tumor']
# model_words_dict ['years', 'enhancement', 'walls']
# ['years']
# label_words_dict ['cortex', 'cortex', 'tract', 'cerebellum', 'stem', 'carcinoma', 'aphasia']
# model_words_dict ['in', 'tract', 'II', '80', 'stem', 'barrier', 'organ', 'aphasia']
# ['tract', 'stem', 'aphasia']
# label_words_dict ['reasons']
# model_words_dict ['reasons', '5', 'years']
# ['reasons']
# label_words_dict ['Pain']
# model_words_dict ['men', '18', '65years', 'Pain']
# ['Pain']
# label_words_dict ['men', 'diseases', 'hernia', 'surgeries', 'vision', 'hearing', 'trauma']
# model_words_dict ['diseases', 'hernia', 'syndrome', 'surgeries', 'vision', 'hearing', 'trauma']
# ['diseases', 'hernia', 'surgeries', 'vision', 'hearing', 'trauma']
# label_words_dict []
# model_words_dict ['patients', 'b', 'c', 'd']
# []
# label_words_dict []
# model_words_dict ['patient', 'newsletter', 'sepsis']
# []
# label_words_dict ['guardianship', 'guardianship', 'pregnant', 'breastfeeding', 'limitation', 'undergone', 'scheduled', 'neoplasia']
# model_words_dict ['patient', 'affiliate', 'guardianship', 'guardianship', 'patient', 'pregnant', 'parturient', 'limitation', 'undergone', 'scheduled', 'neoplasia', 'lymphoma']
# ['guardianship', 'guardianship', 'pregnant', 'limitation', 'undergone', 'scheduled', 'neoplasia']
# label_words_dict []
# model_words_dict ['AND']
# []
# label_words_dict ['anaemia']
# model_words_dict ['mmHg', 'anaemia']
# ['anaemia']
# label_words_dict ['disease', 'Kidney', 'soya', 'eggs', '20']
# model_words_dict ['disease', 'disease', 'propofol', 'soya', 'eggs', '20']
# ['disease', 'soya', 'eggs', '20']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['C0500', 'B0700', 'B0800', 'weeks', 'Willing', 'Willing', 'Willing', 'Willing']
# []
# label_words_dict ['Alzheimers']
# model_words_dict ['Alzheimers']
# ['Alzheimers']
# label_words_dict []
# model_words_dict ['surveys', '', '', '', '']
# []
# label_words_dict ['CI']
# model_words_dict ['C40', 'Signed', '1000']
# []
# label_words_dict ['C40X', 'Implant', 'risk']
# model_words_dict ['severe', 'to', 'C40X', 'Implant', 'risk', 'with']
# ['C40X', 'Implant', 'risk']
# label_words_dict ['or']
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['study']
# []
# label_words_dict ['disease', 'respiratory', 'metabolic', 'insufficiency', 'disease', 'hepatitis']
# model_words_dict ['disease', 'metabolic', '4', '5', 'disease', 'hepatitis']
# ['disease', 'metabolic', 'disease', 'hepatitis']
# label_words_dict ['with']
# model_words_dict ['Patients']
# []
# label_words_dict ['hospitalized', 'admitted', 'admitted']
# model_words_dict ['understand', 'Madison']
# []
# label_words_dict ['acute', 'HTN', 'smoker', 'DM']
# model_words_dict ['acute', 'age', 'patient', 'one', 'before']
# ['acute']
# label_words_dict []
# model_words_dict ['', '', '']
# []
# label_words_dict []
# model_words_dict ['Male', 'for']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['gestation']
# []
# label_words_dict []
# model_words_dict ['pregnancies']
# []
# label_words_dict []
# model_words_dict ['patient']
# []
# label_words_dict ['LDLC']
# model_words_dict ['morbidity']
# []
# label_words_dict ['morbidity', 'disease']
# model_words_dict ['disease', 'therapy']
# ['disease']
# label_words_dict []
# model_words_dict ['1', '2', '3']
# []
# label_words_dict ['illness']
# model_words_dict ['participate']
# []
# label_words_dict ['prediabetes', 'glucose', 'diabetes', 'steroidinduced', 'insufficiency', 'malignancy', 'disease', 'disease', 'deficits', 'alcohol', 'homelessness']
# model_words_dict ['prediabetes', '57', '140', 'member', 'diabetes', 'steroidinduced', 'insufficiency', 'malignancy', 'disease', 'disease', 'deficits', 'alcohol', 'homelessness']
# ['prediabetes', 'diabetes', 'steroidinduced', 'insufficiency', 'malignancy', 'disease', 'disease', 'deficits', 'alcohol', 'homelessness']
# label_words_dict ['that', '4', 'or']
# model_words_dict ['4', 'OR']
# ['4']
# label_words_dict ['health', 'Women', 'Women', 'potential']
# model_words_dict ['health', 'polyps', 'rhinitis']
# ['health']
# label_words_dict ['current', 'pregnant', 'inhaled', 'corticosteroids', 'cromolyn', 'renal', 'hepatic', 'neurologic', 'cardiovascular', 'hematologic', 'metabolic', 'cerebrovascular', 'respiratory', 'gastrointestinal', 'illness', 'disorder', 'respiratory', 'polyps', 'allergies', 'antihistamines', 'nasal', 'oral', 'decongestants']
# model_words_dict ['current', 'schedule', 'pregnant', 'inhaled', 'cromolyn', 'renal', 'hepatic', 'neurologic', 'cardiovascular', 'hematologic', 'metabolic', 'cerebrovascular', 'respiratory', 'gastrointestinal', 'illness', 'study', 'respiratory', 'allergies', 'antihistamines', 'nasal', 'oral', 'decongestants']
# ['current', 'pregnant', 'inhaled', 'cromolyn', 'renal', 'hepatic', 'neurologic', 'cardiovascular', 'hematologic', 'metabolic', 'cerebrovascular', 'respiratory', 'gastrointestinal', 'illness', 'respiratory', 'allergies', 'antihistamines', 'nasal', 'oral', 'decongestants']
# label_words_dict ['and', 'are']
# model_words_dict ['are', 'does']
# ['are']
# label_words_dict ['female', 'rupture', 'release', 'diseases']
# model_words_dict ['rupture', 'diseases', 'test']
# ['rupture', 'diseases']
# label_words_dict ['male', 'medical', 'physical']
# model_words_dict ['male', 'medical', 'medical']
# ['male', 'medical']
# label_words_dict ['did', 'did', 'with']
# model_words_dict ['did', 'did']
# ['did', 'did']
# label_words_dict []
# model_words_dict ['7']
# []
# label_words_dict ['Normal', 'troubles', 'dysphasia', 'disorder']
# model_words_dict ['Normal', 'parent', 'disorder']
# ['Normal', 'disorder']
# label_words_dict ['']
# model_words_dict ['']
# ['']
# label_words_dict ['MRI']
# model_words_dict ['MRI']
# ['MRI']
# label_words_dict ['chemotherapy', 'Progressive', 'pressure', 'Severe', 'asthma']
# model_words_dict ['chemotherapy', 'Progressive', 'blockers', 'Severe', 'asthma']
# ['chemotherapy', 'Progressive', 'Severe', 'asthma']
# label_words_dict ['or', 'that', 'bpm']
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['LBP', 'back', 'hours']
# []
# label_words_dict ['Men', 'Allergic']
# model_words_dict ['Men', 'to']
# ['Men']
# label_words_dict ['', '', '']
# model_words_dict ['']
# ['', '', '']
# label_words_dict ['TBSA']
# model_words_dict ['maturity', 'fractures', 'needed', 'sustained']
# []
# label_words_dict ['flap', 'paresis', 'TBSA', 'thickness', 'Prior', 'deformity']
# model_words_dict ['fracture', 'fracture', 'fracture', 'GCS12', 'paresisparalysis', 'TBSA', 'thickness', 'injury', 'surgery', 'Prior', 'deformity', 'abnormality']
# ['TBSA', 'thickness', 'Prior', 'deformity']
# label_words_dict ['9']
# model_words_dict ['closeable', 'pulses', 'Unable']
# []
# label_words_dict ['TSAT']
# model_words_dict ['10mgdL', '20', '', 'disease', '']
# []
# label_words_dict ['Acute', 'bleeding', 'infection', 'pressure', 'B12', 'Uncontrolled', 'Acute', 'disease', 'Hemodialysis']
# model_words_dict ['Acute', 'bleeding', 'weeks', 'infection', '100mmHg', 'B12', 'Uncontrolled', 'Acute']
# ['Acute', 'bleeding', 'infection', 'B12', 'Uncontrolled', 'Acute']
# label_words_dict ['or']
# model_words_dict []
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['microsomia', 'Collins', 'head']
# model_words_dict ['patients', 'microsomia', 'Collins']
# ['microsomia', 'Collins']
# label_words_dict ['Patients']
# model_words_dict ['Patients']
# ['Patients']
# label_words_dict ['MRI', 'treatment']
# model_words_dict ['MRI', 'treatment']
# ['MRI', 'treatment']
# label_words_dict ['Nx', 'Mx', 'medical', 'device', 'implants', 'medication']
# model_words_dict ['Nx', 'Mx', 'medical', 'device', 'medication']
# ['Nx', 'Mx', 'medical', 'device', 'medication']
# label_words_dict ['would', 'which', 'claustrophobia']
# model_words_dict ['', 'claustrophobia']
# ['claustrophobia']
# label_words_dict []
# model_words_dict ['bladder', 'consented']
# []
# label_words_dict ['biologics', 'bladder', 'reaction']
# model_words_dict ['biologics', 'reaction']
# ['biologics', 'reaction']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict ['women', 'women', 'women', 'women']
# model_words_dict ['days', 'ngml', 'diabetes']
# []
# label_words_dict ['diabetes', 'disease', 'enzymes', 'failure', 'inflammatory', 'cycle']
# model_words_dict ['disease', 'prolongation', 'enzymes', 'failure', 'inflammatory', 'III', 'cycle']
# ['disease', 'enzymes', 'failure', 'inflammatory', 'cycle']
# label_words_dict []
# model_words_dict ['gonadotrophins']
# []
# label_words_dict []
# model_words_dict ['programme']
# []
# label_words_dict ['FDR', 'Syndrome', 'Syndrome', 'Syndrome', 'syndrome', 'syndrome', 'syndrome', 'trauma']
# model_words_dict ['syndrome', 'trauma']
# ['syndrome', 'syndrome', 'syndrome', 'trauma']
# label_words_dict []
# model_words_dict ['Probandsrelatives']
# []
# label_words_dict []
# model_words_dict ['30']
# []
# label_words_dict ['exercise', 'exercise']
# model_words_dict []
# []
# label_words_dict ['reasons', 'Medication']
# model_words_dict ['reasons', 'Medication']
# ['reasons', 'Medication']
# label_words_dict ['stroke']
# model_words_dict ['stroke', '60', 'consent']
# ['stroke']
# label_words_dict ['seizure', 'epilepsy', 'disorders', 'surgery', 'implant', 'medications', 'inhibitors', 'dopamine', 'agonists', 'haloperidol', 'lithium', 'inhibitors', 'betablockers', 'nimodipine', 'levetiracetam', 'ethosuximide', 'benzodiazepines', 'baclofen', 'neuropathy', 'Social']
# model_words_dict ['seizureepilepsy', 'pacemaker', 'disorders', 'surgery', 'head', 'inhibitors', 'dopamine', 'agonists', 'haloperidol', 'lithium', 'inhibitors', 'betablockers', 'nimodipine', 'levetiracetam', 'ethosuximide', 'benzodiazepines', 'baclofen', 'neuropathy']
# ['disorders', 'surgery', 'inhibitors', 'dopamine', 'agonists', 'haloperidol', 'lithium', 'inhibitors', 'betablockers', 'nimodipine', 'levetiracetam', 'ethosuximide', 'benzodiazepines', 'baclofen', 'neuropathy']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict []
# model_words_dict ['steatohepatitis', 'serology', 'write', 'exercise']
# []
# label_words_dict ['steatohepatitis', 'minutes', 'symptoms', 'myocarditis', 'aneurism', 'serology', 'cirrhosis', 'disease', 'past', 'varices', 'ascites', 'immunosuppression', 'male']
# model_words_dict ['intensity', 'event', 'angina', 'symptoms', 'compromise', 'stenosis', 'failure', 'embolus', 'myocarditis', 'pericarditis', 'suspected', 'aneurism', 'biopsy', 'disease', 'past', 'varices', 'ascites', 'immunosuppression', 'male']
# ['symptoms', 'myocarditis', 'aneurism', 'disease', 'past', 'varices', 'ascites', 'immunosuppression', 'male']
# label_words_dict ['', '', '', '', '', '', '', 'except', '', '']
# model_words_dict ['', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '']
# label_words_dict ['medications']
# model_words_dict ['day']
# []
# label_words_dict []
# model_words_dict ['age', 'two']
# []
# label_words_dict ['', '']
# model_words_dict ['be', 'be']
# []
# label_words_dict []
# model_words_dict ['treatment', 'videotapingaudiotaping', 'scale']
# []
# label_words_dict ['years', 'AA', 'programs', 'selfinjury', 'attempt', 'treatment', 'schizophrenia']
# model_words_dict ['years', 'programs', 'selfinjury', 'attempt', 'schizophrenia', 'anorexia']
# ['years', 'programs', 'selfinjury', 'attempt', 'schizophrenia']
# label_words_dict ['to', 'services', 'should', 'be', '']
# model_words_dict ['does', 'services', 'should', '', 'forms']
# ['services', 'should', '']
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['pathological', 'genetic', 'Degeneration', 'Disease']
# model_words_dict ['pathological', 'genetic', 'Degeneration', 'Disease', 'Impairment']
# ['pathological', 'genetic', 'Degeneration', 'Disease']
# label_words_dict ['2']
# model_words_dict ['1', '2', '3']
# ['2']
# label_words_dict []
# model_words_dict ['months', 'gastrointestinal']
# []
# label_words_dict ['gastrointestinal', 'prebiotics']
# model_words_dict ['anaphylaxis', 'syndrome', 'allergies', 'diseases', 'eczema', 'tract', 'diseases', 'defects', 'tuberculosis', 'diseases', 'immunodeficiency', 'diseases', 'disease', 'fibrosis', 'diseases', 'malignancy', 'diseases', 'tract', 'prebiotics']
# ['prebiotics']
# label_words_dict ['']
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['pain', 'Read', 'pain']
# []
# label_words_dict ['pain', 'radiculopathy', 'radiculitis', 'needling', '10']
# model_words_dict ['radiculitis', 'needling', '10']
# ['radiculitis', 'needling', '10']
# label_words_dict []
# model_words_dict ['']
# []
# label_words_dict ['nonambulant']
# model_words_dict ['I']
# []
# label_words_dict ['ventilation', 'cardiorespiratory']
# model_words_dict ['ventilation', 'cardiorespiratory']
# ['ventilation', 'cardiorespiratory']
# label_words_dict ['were']
# model_words_dict ['were']
# ['were']
# label_words_dict ['DNA']
# model_words_dict ['adults', 'DNA']
# ['DNA']
# label_words_dict ['adults', 'kidney', 'heart', 'lung', 'living']
# model_words_dict ['transplant', 'heart', 'lung', 'living']
# ['heart', 'lung', 'living']
# label_words_dict ['donor', 'deceased']
# model_words_dict ['deceased', '', 'is']
# ['deceased']
# label_words_dict ['carcinoma', 'understand', 'prognosis']
# model_words_dict ['breast', 'understand', 'prognosis', 'neurologic']
# ['understand', 'prognosis']
# label_words_dict ['histologically', 'invasive', 'neurologic', 'ongoing', 'pectoris', 'arrhythmia', 'illness', 'abduct']
# model_words_dict ['histologically', 'invasive', 'ongoing', 'arrhythmia', 'body']
# ['histologically', 'invasive', 'ongoing', 'arrhythmia']
# label_words_dict ['be', 'Participants']
# model_words_dict ['', 'but', 'Participants']
# ['Participants']
# label_words_dict []
# model_words_dict ['arthroplasty']
# []
# label_words_dict []
# model_words_dict ['Pregnant']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict []
# model_words_dict ['speaker']
# []
# label_words_dict []
# model_words_dict []
# []
# label_words_dict ['smoker', '', 'did', 'language']
# model_words_dict ['', '', 'does']
# ['']
# label_words_dict []
# model_words_dict ['Patients', 'participate']
# []
# label_words_dict ['restored', 'flourosis']
# model_words_dict ['restored', 'flourosis']
# ['restored', 'flourosis']
# label_words_dict ['are']
# model_words_dict ['are']
# ['are']
# label_words_dict ['ventilation']
# model_words_dict ['18', 'Hospital', 'ventilation']
# ['ventilation']
# label_words_dict ['Pneumothorax', 'expectancy', 'esophageal', 'ulcerations', 'tumors', 'diverticulitis', 'varices', 'sinusitis', 'epistaxis', 'thrombocytopenia', 'INR', 'preintervention', 'intervention']
# model_words_dict ['Pneumothorax', 'hours', 'esophageal', 'varices', 'epistaxis', '30', '3', 'intervention']
# ['Pneumothorax', 'esophageal', 'varices', 'epistaxis', 'intervention']
# label_words_dict ['that', 'pathology']
# model_words_dict ['3', 'surgery']
# []
# label_words_dict []
# model_words_dict ['OSCC']
# []
# label_words_dict ['OSCC', 'tongue', 'mouth', 'gingiva', 'trigone', 'Recurrent', 'immunotherapy', 'cetuximab', 'carcinoma', 'tumor', 'disease']
# model_words_dict ['trigone', 'mucosa', 'immunotherapy', 'cetuximab', 'carcinoma', 'tumor', 'disease']
# ['trigone', 'immunotherapy', 'cetuximab', 'carcinoma', 'tumor', 'disease']
# label_words_dict ['OSCC']
# model_words_dict ['', '', '', '']
# []
# label_words_dict ['AHCT', 'not', 'antibiotics']
# model_words_dict ['pre', 'source', 'stable', 'IC']
# []
# label_words_dict ['donor', 'meropenem', 'meropenem', 'unwilling', 'piptazo', 'allergy', 'medical', 'risk']
# model_words_dict ['donor', 'meropenem', 'meropenem', 'unwilling', 'allergy', 'medical', 'subject']
# ['donor', 'meropenem', 'meropenem', 'unwilling', 'allergy', 'medical']
# label_words_dict ['and', 'or', 'Patients']
# model_words_dict ['AND', 'Patients']
# ['Patients']

# %% [markdown]
# ### Plot Models Operators

# %%
# 7 = Agent
# 8 Claude Prompt
plot_metrics(all_metrics)

# %% [markdown]
# ### Plot Anzahl Operators

# %%
def plot_count_comparison(all_metrics):
    operators = ['AND', 'OR', 'NOT']
    count_metrics = ['total_label', 'total_model']
    fig, ax = plt.subplots(figsize=(16, 8))
    x = np.arange(len(operators))

    label_counts = [all_metrics[next(iter(all_metrics))][op]['total_label'] for op in operators]
    bar_width = 0.16
    opacity = 0.8

    colors = sns.color_palette("husl", len(all_metrics) + 1)

    ax.bar(x, label_counts, bar_width, alpha=opacity, color=colors[0], label='Label Count')
    for i, model in enumerate(all_metrics.keys()):
        count_values = [all_metrics[model][op]['total_model'] for op in operators]
        model_name = model.replace('Instruct', '').replace('_', ' ')
        ax.bar(x + (i + 1) * bar_width, count_values, bar_width, alpha=opacity, color=colors[i + 1], label=model_name)

        for j, v in enumerate(count_values):
            label_count = label_counts[j]
            diff_percent = ((v - label_count) / label_count) * 100
            color = 'darkgreen' if diff_percent >= 0 else 'red'
            ax.text(x[j] + (i + 1) * bar_width, v / 2, f'{diff_percent:+.0f}%', ha='center', va='center', fontsize=10, color=color, fontweight='bold')
            ax.text(x[j] + (i + 1) * bar_width, v + 100, str(v), ha='center', fontsize=11)

    for i, v in enumerate(label_counts):
        ax.text(x[i], v + 100, str(v), ha='center', fontsize=10)

    ax.set_xticks(x + bar_width * len(all_metrics) / 2)
    ax.set_xticklabels([f'{op}' for op in operators], fontsize=12)
    ax.set_xlabel('Operators', fontsize=12)
    ax.set_ylabel('Anzahl', fontsize=12)
    ax.set_title('Count Comparison: Labels vs Models per Operator', fontsize=16, pad=30)
    ax.legend(fontsize=11)
    ax.grid(True)

    plt.tight_layout()
    plt.show()

# %%
plot_count_comparison(all_metrics)

# %% [markdown]
# ## Model vs SOTA

# %%
print(models)

model_to_plot = models[0]

model_name = "Llama-3-70B-DPO-5-shot"
# Out:
# ['Llama-3-70B-DPO-v0.2_5_shot_prompt_9', 'Llama-3-70B-Instruct_1_shot_prompt_7', 'Llama-3-70B-Instruct_3_shot_prompt_7', 'Llama-3-70B-Instruct_5_random_shot_prompt_7', 'Llama-3-70B-Instruct_5_shot_prompt_7']

# %%
model_metrics = all_metrics[model_to_plot]

sota_metrics = {
    'SciBERT': {
        'AND': {'precision': 54.1, 'recall': 60.0, 'f1': 56.9},
        'NOT': {'precision': 74.3, 'recall': 91.0, 'f1': 81.8},
        'OR': {'precision': 85.1, 'recall': 93.2, 'f1': 89.0}
    },
    'R-BERT + SciBERT': {
        'AND': {'precision': 53.8, 'recall': 53.8, 'f1': 53.8},
        'NOT': {'precision': 74.5, 'recall': 88.7, 'f1': 81.0},
        'OR': {'precision': 88.4, 'recall': 92.2, 'f1': 90.2}
    }
}

operators = ['AND', 'OR', 'NOT']
metrics_to_plot = ['precision', 'recall', 'f1']
metric_labels = {'precision': 'P', 'recall': 'R', 'f1': 'F1'}

fig, ax = plt.subplots(figsize=(16, 10))

x = np.arange(len(operators))
bar_width = 0.4
opacity = 0.8
gap = 0.1

for i, metric in enumerate(metrics_to_plot):
    model_values = [model_metrics[op][metric] for op in operators]
    sota_values = [sota_metrics['SciBERT'][op][metric] for op in operators]

    ax.bar(x - bar_width/2 - gap/2 + i*bar_width/3, model_values, bar_width/3, alpha=opacity, label=f'Llama-3-70B-5-shot - {metric_labels[metric]}')
    ax.bar(x + bar_width/2 + gap/2 + i*bar_width/3, sota_values, bar_width/3, alpha=opacity, label=f'SciBERT - {metric_labels[metric]}')

    for j, (model_value, sota_value) in enumerate(zip(model_values, sota_values)):
        ax.text(j - bar_width/2 - gap/2 + i*bar_width/3, model_value/2, f'{metric_labels[metric]}', ha='center', va='center', fontsize=14, fontweight='bold', color='white')
        ax.text(j + bar_width/2 + gap/2 + i*bar_width/3, sota_value/2, f'{metric_labels[metric]}', ha='center', va='center', fontsize=14, fontweight='bold', color='white')

        ax.text(j - bar_width/2 - gap/2 + i*bar_width/3, model_value + 2, f'{model_value:.1f}%', ha='center', fontsize=12)
        ax.text(j + bar_width/2 + gap/2 + i*bar_width/3, sota_value + 2, f'{sota_value:.1f}%', ha='center', fontsize=12)

ax.set_xticks(x)
ax.set_xticklabels(operators, fontsize=14)
ax.set_xlabel('Operatoren', fontsize=16, fontweight='bold', labelpad=15)
ax.set_ylabel('Score (%)', fontsize=16, fontweight='bold', labelpad=15)
ax.set_ylim(0, 105)
ax.set_yticks(np.arange(0, 101, 10))
ax.tick_params(axis='y', labelsize=14, width=2)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_title(f'Evaluation: {model_name} vs. SciBERT', fontsize=20, pad=20)
ax.legend(fontsize=12, ncol=2, loc='upper left')
ax.grid(True)

plt.tight_layout()
if not os.path.exists("pics"):
    os.makedirs("pics")
plt.savefig(f"pics/{model_to_plot}_vs_sota.png")
plt.show()

# %%
def generate_latex_table(all_metrics, operators, metrics_to_plot):
    latex_table = "\\begin{table}[h]\n"
    latex_table += "\\centering\n"
    latex_table += "\\begin{tabular}{l" + "c" * (len(metrics_to_plot) * len(operators)) + "}\n"
    latex_table += "\\toprule\n"
    latex_table += "Model & " + " & ".join([f"\\multicolumn{{{len(metrics_to_plot)}}}{{c}}{{{op}}}" for op in operators]) + " \\\\\n"
    latex_table += "\\cmidrule(lr){2-" + str(len(metrics_to_plot) + 1) + "} " + " \\cmidrule(lr){" + str(len(metrics_to_plot) + 2) + "-" + str(2 * len(metrics_to_plot) + 1) + "} " + " \\cmidrule(lr){" + str(2 * len(metrics_to_plot) + 2) + "-" + str(3 * len(metrics_to_plot) + 1) + "}\n"
    latex_table += " & " + " & ".join([" & ".join(metric[:1].upper() for metric in metrics_to_plot) for _ in operators]) + " \\\\\n"
    latex_table += "\\midrule\n"

    for model, model_metrics in all_metrics.items():
        row = model.replace("_", "-")  # Replace underscores with hyphens in the model name
        for op in operators:
            for metric in metrics_to_plot:
                row += " & {:.2f}".format(model_metrics[op][metric])
        row += " \\\\\n"
        latex_table += row

    latex_table += "\\bottomrule\n"
    latex_table += "\\end{tabular}\n"
    latex_table += "\\caption{Model Performance Metrics}\n"
    latex_table += "\\label{tab:model_metrics}\n"
    latex_table += "\\end{table}\n"

    os.makedirs("latex", exist_ok=True)
    with open("latex/model_metrics_table.tex", "w") as file:
        file.write(latex_table)
    return latex_table

# Generate LaTeX table
latex_table = generate_latex_table(all_metrics, operators, metrics_to_plot)

print(latex_table)
