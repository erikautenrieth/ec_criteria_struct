# %% [markdown]
# #### Exact Matching  Evaluierung

# %%
from chia_evaluate_functions import *
from plot_functions_p1 import *

# %% [markdown]
# ### Wähle den evaluations Ordner

# %%
versuch_ordner = "eval_full_chia/"
versuch_name = "Llama3-70b Modelle full Chia Datensatz"


raw_lct_text_folder = '../input/chia_text_full'
label_folder = '../input/chia_p1_full'
model_output_folder = versuch_ordner + 'model_output'

models = [folder for folder in os.listdir(model_output_folder) if os.path.isdir(os.path.join(model_output_folder, folder))]
models
# Out:
# [' Naive greedy match (CHIA Prompt)',
#  ' Naive greedy match (LCT Prompt 2)',
#  'Llama-3-70B-Instruct_0_shot_chia_prompt',
#  'Llama-3-70B-Instruct_0_shot_lct_prompt',
#  'Llama-3-70B-Instruct_5_shot_chia_prompt2',
#  'Llama-3-70B-Instruct_5_shot_lct_prompt2',
#  'llama3_70b_Lora_ep10_r256_prompt6_lct_model_lct2_prompt']

# %%
all_metrics = {}
for model in models:
    model_folder = os.path.join(model_output_folder, model, 'output')
    metrics = evaluate_models(label_folder, model_folder, model, raw_lct_text_folder)
    all_metrics[model] = metrics
# Out:
# NCT00050349
# NCT00050349
# label_words_dict ['biopsyproven', 'VIPomas', 'ULN', 'Female', 'of', 'metastases', 'metastases', 'diarrhea', 'insufficiency', 'agents', 'less']
# model_words_dict ['Patients', 'Gastrinomas', 'VIPomas', 'bone', 'impairment', 'function', 'defined', 'metastases', 'Patients', 'analogue', 'be', 'dose', 'prior', 'entry', 'analogues', 'judged', 'be', 'dose', 'prior', 'Must', 'expectancy', 'patients', 'patients', 'must', 'applicable', 'patients', 'oophorectomy', 'or', 'patients', 'who', 'Patients', 'Patients', 'metastases', 'treated', 'or', 'stable', 'prior', 'Subjects', 'history', 'metastases', 'metastases', 'must', 'CT', 'contrast', 'Patients', 'metastases', 'sites', 'Patients', 'chemoembolization', 'there', 'sites', 'Patients', 'who', 'treated', 'Patients', 'who', 'treated', 'Patients', 'Patients', 'agents', 'exception', 'less', 'maintenance', 'history', 'malignancy', 'prior', 'Patients', 'infection', 'Patients', 'illness', 'consent', 'history', 'noncompliance', 'unwillingness', 'return']
# label_words_dict ['tumors', 'Gastrinomas', 'irradiated', 'renal', 'bilirubin', 'ULN', 'oophorectomy', 'hysterectomy', 'metastases', 'treated', 'months', 'neuropathy', 'Coumadin', 'dose', 'lines', 'active', 'acute', 'abcesses', 'medical', 'study', 'consent', 'regimens', 'inability', 'Pregnant']
# model_words_dict ['tumors', 'cell', 'irradiated', 'renal', 'AST', 'and', 'hysterectomy', 'metastases', 'metastases', 'and', 'response', 'neuropathy', 'Coumadin', 'mg', 'lines', 'cancer', 'cancer', 'active', 'acute', 'abcesses', 'medical', 'study', 'and', 'regimens', 'inability', 'Pregnant']
# label_words_dict ['either', 'has', 'AND', 'agents', 'entry']
# model_words_dict ['either', 'has']
# NCT00061308
# NCT00061308
# label_words_dict ['regimen', 'potential', 'infection', 'radiation']
# model_words_dict ['regimen', 'treatment', 'Must', 'interval', 'response', 'status', 'Women', 'potential', 'malignancies', 'exception', 'free', 'infection', 'unrelated', 'compliance', 'radiation', '10', 'treatment', 'Hypersensitivity', 'Use', 'agent']
# label_words_dict ['surgery', 'Pregnant', 'Concomitant', 'cell', 'topotecan', 'camptothecin']
# model_words_dict ['surgery', '01', 'Pregnant', 'Concomitant', 'cell', 'cancer', 'cancer', 'carcinoid', 'topotecan', 'camptothecin']
# label_words_dict ['that', 'the']
# model_words_dict ['do', 'disease']
# NCT00094861
# NCT00094861
# label_words_dict ['Females', 'capability', 'treatment', 'toxicity', 'treatment', 'sensitivity']
# model_words_dict ['Patients', 'diagnosis', 'field', 'treatment', 'equal', '30', 'equal', 'equal', 'years', 'status', 'equal', 'equal', 'equal', 'equal', 'limit', 'equal', 'Patients', 'equal', '14', 'equal', 'dL', 'equal', 'Females', 'Patient', 'Patients', 'capability', 'agree', 'volume', 'documented', 'documented', 'cytology', 'malignancy', 'capable', 'radiotherapy', 'investigator', 'patient', 'suspects', 'effusions', 'evaluated', 'approval', 'Plan', 'Shielding', 'part', 'esophagus', 'surgery', 'malignancy', 'Patients', 'carcinoma', 'etc', 'approval', 'history', 'predisposing', 'History', 'completion', 'presence', 'treatment', 'or', 'Known', 'seropositive', 'sensitivity', 'ability', 'patient', 'consent', 'or', 'comply', 'Refusal', 'form', 'study', 'unable', 'reasons']
# label_words_dict ['histologically', 'IIIa', 'than', 'than', 'than', 'than', 'support', 'than', 'than', 'than', 'mgdL', 'than', 'than', 'than', 'serum', 'studyspecific', 'Pleural', 'scan', 'dysphagia', 'study', 'Pregnant', 'consent']
# model_words_dict ['histologically', 'IIIa', 'than', 'than', 'than', 'age', 'than', 'g', 'support', 'than', '109', 'than', '109', 'than', 'than', 'mg', 'than', 'than', 'mg', 'than', 'mL', 'serum', 'procedure', 'randomization', 'M1', 'Pleural', 'PET', 'scan', 'chemo', 'disease', 'NSCLC', 'acceptable', 'malignant', 'chemo', 'chemotherapy', 'radiotherapy', 'eg', 'cancer', 'cancer', 'cervix', 'however', 'Presence', 'dysphagia', 'eg', 'GERD', 'dyspepsia', 'weeks', 'product', 'study', 'study', 'HIV', 'HCV', 'Pregnant', 'and', 'form', 'Unwilling', 'Psychological', 'social', 'familial']
# label_words_dict ['gdL', '109L', 'years', 'prior']
# model_words_dict ['dL', 'L', 'be', 'years', 'are', 'not', 'or', 'would']
# NCT00122070
# NCT00122070
# label_words_dict ['BPD']
# model_words_dict ['18', 'able', 'read', 'English', 'instructions', 'criteria', 'BPD', 'assessed', 'Interview', 'products', 'prior', 'diagnosis', 'Disorder', 'diagnosed', 'Interview', 'SCIDI', 'subsequent', 'disorder', 'determined', 'responsible', 'based', 'response', 'trial', 'quetiapine', 'judged', 'psychotherapy', 'period', 'but', 'prior', 'Patients', 'who', 'therapy', 'period']
# label_words_dict ['pregnant', 'drugs', 'Disorder']
# model_words_dict ['speak', 'pregnant', 'drugs', 'Schizophrenia', 'Disorder', 'Disorder', 'examination']
# label_words_dict []
# model_words_dict ['may']
# NCT00182520
# NCT00182520
# label_words_dict ['Outpatient', 'mgday', 'hypersensitivity']
# model_words_dict ['Outpatient', 'Completion', 'trial', 'day', 'responses', 'CGII', 'reduction', 'medications', 'antipsychotics', 'criteria', 'trial', 'hypersensitivity', 'History']
# label_words_dict ['non', '3', 'disorder', 'therapy', 'Allergy']
# model_words_dict ['mg', 'day', 'mg', 'day', 'mg', 'day', 'mg', 'day', 'mg', 'day', 'mg', 'day', 'mg', 'non', '3', '4', 'wks', 'benzodiazepines', 'hypnotics', 'disorder', 'disorder', 'schizophrenia', 'disorder', 'alcohol', 'therapy', 'Allergy']
# label_words_dict []
# model_words_dict []
# NCT00183885
# NCT00183885
# label_words_dict ['histologically', 'to', 'function', 'function', 'chemotherapy', 'B', 'C', 'potential']
# model_words_dict ['carcinoma', 'limited', 'tumor', 'This', 'biopsy', 'requirement', 'biopsy', 'mL', 'explained', 'Patients', 'agree', 'to', 'drawn', 'addition', 'labs', 'cycle', 'Patients', 'Patients', 'must', 'disease', 'Patients', 'Patients', 'must', 'status', 'Patients', 'Patients', 'must', 'expectancy', 'Patients', 'Patients', 'must', 'bands', 'equal', 'level', 'equal', 'dl', 'equal', 'requirement', 'hypersplenism', 'Patients', 'Patients', 'must', 'function', 'documented', 'Patients', 'Patients', 'must', 'function', 'documented', 'equal', 'limit', 'regardless', 'patients', 'secondary', 'Patients', 'not', 'ascites', 'responsive', 'Patients', 'who', 'chemotherapy', 'Patients', 'infection', 'Patients', 'placed', 'Patients', 'Patients', 'disorders', 'interfere', 'Men', 'women', 'potential', 'they', 'agreed', 'Patients', 'judgment', 'inappropriate']
# label_words_dict ['consent', 'Pregnant']
# model_words_dict ['Unresectable', 'biopsy', 'resection', 'available', 'ng', 'administered', 'ie', 'than', '1500', 'mm3', 'than', 'gm', 'than', '50000', 'than', 'normal', 'ascites', 'active', 'consent', 'Pregnant', 'disease', 'investigator']
# label_words_dict ['Patients']
# model_words_dict ['is', 'opinion', 'may', 'may']
# NCT00198913
# NCT00198913
# label_words_dict []
# model_words_dict ['18']
# label_words_dict ['diabetic']
# model_words_dict ['diabetic', 'over', 'consent', 'diabetic']
# label_words_dict []
# model_words_dict []
# NCT00235170
# NCT00235170
# label_words_dict ['documented', 'amenable', 'LAD', 'infarction', 'pain', 'of']
# model_words_dict ['Patients', 'pectoris', 'patients', 'those', 'who', 'they', 'Patients', 'who', 'eligible', 'vessels', 'amenable', 'disease', 'LAD', 'and', 'treatment', 'disease', 'viewed', 'combination', 'branch', 'circumflex', 'included', 'targeted', 'long', 'amenable', 'age', 'infarction', 'subtended', 'Patients', 'vessels', 'month', 'mm', 'even', 'vessel', 'defined', 'stenosis', 'view', 'preferably', 'fraction', 'need', 'resection', 'infarction', 'days', 'returned', 'minutes', 'History', 'stenosis', 'Intention']
# label_words_dict ['4', 'angioplasty', 'vessel', 'duration', 'CABG', 'surgery', 'of', 'aortic']
# model_words_dict ['1', '2', '3', '4', 'IB', 'IC', 'IIB', 'IIC', 'IIIB', 'ischemia', 'pain', 'test', 'scintigraphy', 'echocardiography', 'angioplasty', 'disease', 'descending', 'vessel', 'SA', 'instability', 'duration', 'included', 'third', 'interpretation', 'CABG', 'surgery', 'aortic', 'aneurysm', 'endarterectomy', 'preprocedure', '50']
# label_words_dict ['has']
# model_words_dict ['should', 'included', 'has']
# NCT00236340
# NCT00236340
# label_words_dict ['discumfort', 'twin', 'of', 'Fetus']
# model_words_dict ['women', 'discumfort', 'diagnosis', 'history', 'Fetus', 'complicated', 'Unability']
# label_words_dict ['Single']
# model_words_dict ['Single']
# label_words_dict ['preeclampsia']
# model_words_dict []
# NCT00250640
# NCT00250640
# label_words_dict ['Hypertension', 'hypertension', 'contraindications']
# model_words_dict ['Ventavis', 'treatment', 'Patient', 'Hypertension', 'classified', 'treatment', 'treatments', 'hypertension', 'weeks', 'date', 'advised', 'condition', 'study', 'pregnancy', 'contraindications', 'Summary', 'Characteristics']
# label_words_dict ['Hypertension', 'Ventavis', 'pregnancy']
# model_words_dict ['Hypertension', 'Ventavis']
# label_words_dict ['Association']
# model_words_dict []
# NCT00279552
# NCT00279552
# label_words_dict []
# model_words_dict ['suspected', 'to', 'defined', 'Patients', 'able']
# label_words_dict []
# model_words_dict ['pmol', 'pregnant', 'nursing']
# label_words_dict ['or']
# model_words_dict ['or', 'were']
# NCT00305097
# NCT00305097
# label_words_dict ['of']
# model_words_dict ['years', 'ability', 'willingness', 'Users', 'cups', 'day', 'who', 'willing', 'randomized', 'any', 'illness', 'that', 'such', 'history', 'ulcer', 'according', 'use', 'medications', 'interfere', 'treatment']
# label_words_dict ['that', 'pregnancy', 'function', 'alcoholism', 'abuse']
# model_words_dict ['kg', 'condition', 'outcomes', 'pregnancy', 'breastfeeding', 'mellitus', 'disease', 'stroke', 'hypertension', 'syndromes', 'GERD', 'range', 'mg', 'dl', '', 'mg', 'dl', '140', 'alcoholism', 'abuse', 'bronchodilators', 'antibiotics', 'inhibitors', 'anxiolytics', 'ranitidine', 'corticosteroids', 'hormone']
# label_words_dict []
# model_words_dict []
# NCT00312429
# NCT00312429
# label_words_dict []
# model_words_dict ['center', 'confirmed', 'criterion', 'cancer', 'defined', 'expectancy', 'Cancer', 'equal', 'creatinine', 'reviewed', 'MRI', 'performed', 'reviewed', 'individuals', 'fraction', 'DLCO', 'consultations', 'initiation', 'number', 'available', 'willing', 'therapy', 'weeks', 'Diagnosed', 'illness', 'that', 'interfere']
# label_words_dict ['disease', 'medical']
# model_words_dict ['disease', 'than', 'count', 'platelet', 'hematocrit', 'tuberculosis', 'AST', 'ALT', 'phosphatase', 'MUGA', 'echocardiogram', 'and', '4050', 'cardiology', 'heart', 'female', 'medical']
# label_words_dict []
# model_words_dict []
# NCT00317148
# NCT00317148
# label_words_dict ['more', 'products']
# model_words_dict ['women', 'moderate', '40', 'years', 'BMI', 'metabolic', 'Diagnosis', 'Use', 'drugs', 'interfere', 'metabolism', 'Use', 'prior', 'Use', 'products', 'prior']
# label_words_dict ['metabolic', 'steroids', 'therapies', 'fibroids']
# model_words_dict ['50', 'kg', 'm2', 'steroids', 'estrogen', 'progestin', 'therapies', 'fibroids', '2']
# label_words_dict []
# model_words_dict []
# NCT00319748
# NCT00319748
# label_words_dict ['entry', '1cm', 'respond', 'regimen', 'therapy', 'agent', 'only', 'disease', 'two', 'Histologically', 'therapy', 'Histologically', 'treatment', 'therapy']
# model_words_dict ['female', 'and', 'potential', 'willing', 'prior', 'entry', 'and', 'duration', 'function', 'days', 'Diagnosis', 'one', 'Progression', 'failure', 'respond', 'regimen', 'Progression', 'therapy', 'positive', 'or', 'only', 'only', 'must', 'disease', 'defined', 'tumor', 'tumor', 'must', 'histologically', 'Subjects', 'Subjects', 'must', 'Paclitaxel', 'Paclitaxel', 'must', 'component', 'regimens', 'carboplatin', 'carboplatin', 'must', 'component', 'cancer', 'amenable', 'treatment', 'surgery', 'adenocarcinoma', 'cervix', 'amenable', 'treatment', 'surgery', 'Had', 'injectable', 'days', 'dose', 'steroids', 'agents', 'days', 'dose', 'therapy', 'agents', 'days', 'dose', 'nitrosoureas', 'days', 'known', 'prolongation', 'required', 'Radiotherapy', 'weeks', 'dose', 'transplantation', 'weeks', 'dose', 'Evidence', 'infection', 'days', 'dose', 'stable', 'uncontrolled', 'History', 'evidence', 'opinion', 'results', 'disease', 'therapy', 'controlled', 'except', 'carcinomas', 'carcinomas', 'that', 'history']
# label_words_dict ['endometrial', 'on', 'receptor', 'hormone', 'borderline', 'cisplatin', 'recurrent', 'surgery', 'recurrent', 'surgery']
# model_words_dict ['Ovarian', 'endometrial', 'hormonal', 'method', 'on', 'receptor', 'and', 'hormone', 'cancer', 'cancer', 'borderline', 'one', 'cisplatin', 'one', 'recurrent', 'and', 'recurrent', 'carcinoma', 'carcinoma', 'and', 'prior', 'oral', 'topical', 'drugs', 'and', 'infection', 'ischemia', 'arrhythmias', 'of', 'of', 'which', 'investigator', 'study', 'intercurrent', 'Pregnant', 'remission', 'disease', 'metastases']
# label_words_dict ['is', 'is']
# model_words_dict ['site', 'is', 'is', 'disorder', 'disease']
# NCT00324363
# NCT00324363
# label_words_dict ['mgday', 'mgday', 'ANDmetformin']
# model_words_dict ['Treated', 'dose', 'one', 'following', 'prior', 'day', '71', 'm2', 'study', 'days', 'treated', 'insulin', 'week', 'prior', 'drugs', 'loss', 'month']
# label_words_dict ['exenatide', 'metformin']
# model_words_dict ['mg', 'metformin', 'mg', 'sulfonylurea', 'sulfonylurea', '110', 'kg', 'kg', 'previously', 'exenatide', 'interventional', 'medical', 'surgical', 'metformin']
# label_words_dict []
# model_words_dict []
# NCT00343668
# NCT00343668
# label_words_dict ['Pathologically', 'cm', 'times', 'tumor', 'radiation', 'of', 'of', 'neoplasm', 'conditions']
# model_words_dict ['adenocarcinoma', 'cm', '1cm', '18', 'expectancy', 'status', 'times', 'patients', 'chemotherapy', 'chemotherapy', 'therapy', 'radiation', 'Evidence', 'lesions', 'history', 'except', 'carcinoma', 'women', 'disease', 'infarction', 'prior', 'History', 'disorders', 'ability', 'patient', 'administration', 'interaction', 'concentration', 'toxicity', 'according', 'activity']
# label_words_dict ['xray', 'times', 'capecitabine', 'S1', 'metastases', 'obstruction', 'cancer', 'Pregnant', 'lactating', 'illness', 'neurologic', 'dementia', 'fluoropyrimidine']
# model_words_dict ['scan', 'xray', 'examination', '2', '1500', 'µL', 'g', '100000', 'mg', 'but', 'capecitabine', 'S1', 'metastases', 'obstruction', 'Past', 'cancer', 'cancer', 'Pregnant', 'women', 'illness', 'treatment', 'neurologic', 'dementia', 'investigation', 'chemotherapy', 'therapy', 'Warfarin']
# label_words_dict ['UNL', 'prior', 'prior', 'excluded', 'Criteria', 'neoplasm', 'cancer', 'potential']
# model_words_dict ['was', 'neoplasm', 'potential']
# NCT00344318
# NCT00344318
# label_words_dict ['Born', 'vaccines', 'pneumoniae']
# model_words_dict ['between', 'and', '42', 'days', 'time', 'Subjects', 'believes', 'can', 'comply', 'requirements', 'guardian', 'Free', 'problems', 'established', 'history', '36', 'Use', 'vaccines', 'dose', 'use', 'defined', 'days', 'drugs', 'prior', 'administration', 'foreseen', 'protocol', 'dose', 'vaccines', '1', 'b', 'pneumoniae', 'exception', 'given', 'weeks', 'life', 'according', 'History', 'polio', 'History', 'likely', 'exacerbated', 'component', 'History', 'apply', 'subjects', 'who', 'time', 'based', 'history', 'history', 'Administration', 'immunoglobulins', 'administration', 'phase']
# label_words_dict ['parent', 'drug', 'vaccine', 'immunosuppressants', '1', '2', 'disease', 'past', 'immunosuppressive', 'defects', 'immunoglobulins', 'birth']
# model_words_dict ['Male', 'including', 'parents', 'parent', 'investigational', 'drug', 'vaccine', 'immunosuppressants', 'administration', '2', 'diphtheria', 'tetanus', 'pertussis', 'polio', 'B', 'and', 'of', 'diphtheria', 'tetanus', 'pertussis', 'B', 'disease', 'single', 'past', 'confirmed', 'immunosuppressive', 'congenital', 'defects', 'and', 'birth']
# label_words_dict ['subject', 'the', 'does']
# model_words_dict ['vaccine', 'vaccine', 'does']
# NCT00351611
# NCT00351611
# label_words_dict ['Epilepsy', 'pregabalin']
# model_words_dict ['1', 'response', 'treatment']
# label_words_dict []
# model_words_dict ['seizure']
# label_words_dict []
# model_words_dict []
# NCT00356148
# NCT00356148
# label_words_dict ['III', 'OR', 'of', 'of', 'of', 'reaction']
# model_words_dict ['age', 'III', 'Society', 'score', 'History', 'antibiotics', 'History', 'History', 'reaction', 'Denial']
# label_words_dict ['Advanced']
# model_words_dict ['cancer', 'Advanced', 'stage', 'therapy', 'months', 'immunodeficiency', 'infection', 'antibiotics']
# label_words_dict ['antibiotics']
# model_words_dict []
# NCT00379366
# NCT00379366
# label_words_dict ['70', 'angiography', 'contraindications']
# model_words_dict ['30', '70', 'angiography', 'or', 'anastomosis', 'contraindications', 'angioplasty']
# label_words_dict []
# model_words_dict ['speed', 'anastomosis']
# label_words_dict []
# model_words_dict []
# NCT00391690
# NCT00391690
# label_words_dict ['histologically', 'patients', 'value', 'value']
# model_words_dict ['Patients', 'diagnosis', 'cancer', 'who', 'patients', 'Patients', 'who', 'relative', 'separated', 'measurement', 'value', 'and', 'measurement', 'radiotherapy', 'radiotherapy', 'must', 'prior', 'score', 'patients', '50', 'bed', 'limit', 'prior', 'Patients', 'consent', 'treatment', 'function', 'evidenced', 'adjusted', 'Patients', 'History', 'diseases', 'influence', 'such', 'disease', 'diseases', 'compliance', 'provisions', 'or', 'assessment', 'hypersensitivity', 'Use', 'prior', 'date', 'abuse', 'Subjects', 'opinion', 'investigator', 'unlikely', 'fully', 'problems', 'infection', 'diagnosis', 'osteonecrosis', 'ONJ', 'or', 'criteria']
# label_words_dict ['PSA', 'chemotherapy', 'psychiatric', 'mgdl', 'mmolL', 'mgdl', 'metabolism', 'disease', 'physical', 'acid', 'history', 'alcohol', 'teeth', 'maxilla', 'dental', 'current', 'weeks', 'dental']
# model_words_dict ['PSA', 'value', 'chemotherapy', '0', '1', 'psychiatric', 'ml', 'mg', 'mmol', 'L', 'mg', 'mmol', 'physical', 'protocol', 'drug', 'safety', 'ascites', 'failure', 'III', 'IV', 'acid', 'history', 'alcohol', 'who', 'teeth', 'maxilla', 'dental', 'trauma', 'current', 'mouth', 'weeks', 'dental', 'extraction', 'inclusion']
# label_words_dict ['which']
# model_words_dict ['have', 'Patients', 'which', 'must']
# NCT00396734
# NCT00396734
# label_words_dict ['injury']
# model_words_dict ['1g', '1', 'week', 'Subjects', 'who', 'diagnosed', 'illness', 'according', 'or', 'history', 'history', 'infection', 'history', 'injury', 'loss']
# label_words_dict []
# model_words_dict ['122', 'disease', 'HIV', 'syphilis', 'cytomegalovirus', 'herpes']
# label_words_dict []
# model_words_dict []
# NCT00397215
# NCT00397215
# label_words_dict ['protocol', 'vaccination', 'History', 'vaccine', 'which']
# model_words_dict ['Subjects', 'believes', 'can', 'comply', 'requirements', 'protocol', 'time', 'subjects', 'Administration', 'such', 'Invivac', 'Administration', 'vaccines', 'prior', 'administration', 'foreseen', 'up', 'vaccination', 'defined', 'days', 'drugs', 'prior', 'administration', 'based', 'history', 'History', 'consumption', 'History', 'hypersensitivity', 'History', 'likely', 'exacerbated', 'component', 'egg', 'abnormality', 'determined', 'time', 'disease', 'disorder', 'determined', 'history', 'Administration', 'immunoglobulins', 'products', 'or', 'Use', 'vaccines', 'prior', 'use', 'opinion']
# label_words_dict ['male', 'subjects', 'Fluad', 'Flu', '', 'vaccine', 'confirmed', 'immunosuppressive', 'consumption', 'allergic', 'hepatic', 'psychiatric', 'immunoglobulins', 'vaccination', 'investigational', 'drug']
# model_words_dict ['male', 'years', 'subjects', 'vaccines', 'Fluad', 'Addigrip', 'V', 'Flu', 'vaccines', 'immunosuppressants', 'confirmed', 'immunosuppressive', 'condition', 'and', 'disease', 'pulmonary', 'cardiovascular', 'hepatic', 'examination', 'pulmonary', 'cardiovascular', 'renal', 'neurological', 'psychiatric', 'and', 'vaccination', 'investigational', 'drug', 'vaccination', 'which', 'investigator']
# label_words_dict ['vaccine']
# model_words_dict ['vaccine', 'vaccine']
# NCT00401245
# NCT00401245
# label_words_dict ['disorder']
# model_words_dict ['woman', 'treatment', '1', 'months', 'months', 'amenorrhea', 'oophorectomy', 'and', 'History', 'presence', 'history', 'disorder']
# label_words_dict ['with', 'hysterectomy', 'hepatic']
# model_words_dict ['healthy', 'mIU', 'with', 'mIU', 'History', 'hepatic', 'disease', 'Presence', 'disorder', 'disorder', 'disorder']
# label_words_dict ['Hysterectomized', 'disorder']
# model_words_dict ['or', 'Hysterectomized', 'disorder']
# NCT00404495
# NCT00404495
# label_words_dict ['medulloblastoma', 'glioma']
# model_words_dict ['approaches', 'required', 'Diagnosis', 'administration']
# label_words_dict []
# model_words_dict ['Recurrent', '3']
# label_words_dict []
# model_words_dict ['is']
# NCT00425789
# NCT00425789
# label_words_dict []
# model_words_dict ['treated', '7', 'Prior', 'signed', 'consent', 'will', 'matched', 'color', 'type', 'indication', 'peeling', 'up', 'they']
# label_words_dict ['disease']
# model_words_dict ['exoderm', 'old', 'treatments', 'each', 'ATF', 'treatment', 'age', 'disease', 'disease']
# label_words_dict []
# model_words_dict ['be']
# NCT00426751
# NCT00426751
# label_words_dict ['Women', 'doubt', 'Planned', 'of', 'disease']
# model_words_dict ['Women', 'women', 'potential', 'allowed', 'cases', 'test', 'replacement', 'defined', 'min', 'serves', 'consent', 'able', 'therapy', 'anticoagulation', 'TIA', 'Evidence', 'surgery', 'History', 'reaction', 'insufficiency', 'well', 'disease', 'device', 'or', 'halflives', 'longer', 'Subjects', 'inaccessible', 'due', 'factors', 'affiliated', 'beneficiary']
# label_words_dict ['Angina', '100000µl', 'diathesis', 'Stroke', 'months', 'gastrointestinal', 'abciximab', 'eptifibatide', 'study', '30mlmin', 'expectation', 'drug', 'days']
# model_words_dict ['period', 'sterile', 'Angina', 'lead', 'ECG', 'informed', '100000', 'µl', 'Stroke', 'months', 'gastrointestinal', 'abciximab', 'eptifibatide', '30ml', 'min', 'ALT', 'drug', 'days', 'geographic', 'treatment', 'France']
# label_words_dict ['months', 'ie', 'Subjects']
# model_words_dict ['months', 'are', 'Subjects', 'is']
# NCT00440245
# NCT00440245
# label_words_dict []
# model_words_dict ['asthma']
# label_words_dict ['asthma', 'asthma']
# model_words_dict ['asthma']
# label_words_dict []
# model_words_dict []
# NCT00445029
# NCT00445029
# label_words_dict ['participants', 'dermatitis', 'dermatitis', 'dermatitis', 'profile', 'indemnities']
# model_words_dict ['18', 'eligible', 'participants', 'Feasibility', 'Participants', 'able', 'understand', 'Consent', 'comply', 'aspects', 'Patients', 'or', 'Patients', 'dermatitis', 'based', 'history', 'dermatitis', 'history', 'dermatitis', 'disease', 'Patients', 'treatment', 'interacts', 'Exposure', 'deprived', 'subject', 'subject', 'Patients', 'judged', 'investigator', 'unlikely', 'compatible', 'risk', 'Patients', 'indemnities', 'trials', 'months']
# label_words_dict ['Pregnant', 'recurrent', 'corticotherapy', 'Local', 'sun', 'a', 'barrier']
# model_words_dict ['system', 'Pregnant', 'chronic', 'recurrent', 'corticotherapy', 'month', 'Local', 'sun', 'radiations', 'rights', 'custody', 'tutorial', 'judiciary', 'study', 'barrier']
# label_words_dict ['volunteers', 'profile']
# model_words_dict []
# NCT00455663
# NCT00455663
# label_words_dict ['treatment', 'antipsychotic']
# model_words_dict ['Diagnosis', 'study', 'treatment', 'antipsychotic', 'continuation', 'responsibility', 'History', 'History', 'dependence', 'prior', 'History', 'violence', 'prior']
# label_words_dict ['schizophrenia', 'abuse', 'dependence']
# model_words_dict ['schizophrenia', 'inpatient', 'trauma', 'disorder', 'alcohol', 'abuse']
# label_words_dict []
# model_words_dict []
# NCT00461136
# NCT00461136
# label_words_dict ['therapy', 'patients', 'Hypertension', 'block', 'of', 'of', 'of', 'medications', 'allergy']
# model_words_dict ['Male', 'years', 'age', 'diagnosis', 'Incipient', 'day', 'Modification', 'patients', 'or', 'or', 'must', 'or', 'or', 'must', 'prior', 'patients', 'Patients', 'therapy', 'therapy', 'must', 'Hg', 'patients', 'be', 'medications', 'prior', 'patients', 'patients', 'must', 'Hg', 'Patients', 'be', 'medications', 'prior', 'Patients', 'willing', 'able', 'antagonist', 'medications', 'duration', 'temperature', 'Able', 'prior', 'Able', 'well', 'investigator', 'comply', 'requirements', 'mmHg', 'use', 'caused', '173m2', 'measured', 'History', 'prior', 'diagnosis', 'History', 'PCI', 'prior', 'History', 'malignancy', 'leukemia', 'carcinoma', 'investigation', 'prior', 'required', 'loss', 'more', 'blood', 'prior', 'illness', 'prior', 'excretion', 'drugs', 'including', 'limited', 'any', 'History', 'such', 'disease', 'prior', 'bleeding', 'prior', 'history', 'evidence', 'injury', 'indicated', 'Evidence', 'history', 'history', 'history', 'treatment', 'History', 'immunocompromise', 'History', 'History', 'abuse', 'prior', 'execution', 'condition', 'opinion', 'evaluation', 'History', 'noncompliance', 'unwillingness', 'comply', 'contraindications', 'medications', 'history', 'allergy', 'inhibitors', 'or', 'opinion', 'investigator', 'likely', 'complying', 'requirements', 'Use', 'prohibited', 'Patients', 'criteria']
# label_words_dict ['mmHg', '1gday', 'disease', 'diabetes', '35', 'encephalopathy', 'Second', 'arrhythmia', 'leukemia', 'Donation', 'surgical', 'active', 'pancreatitis', 'pancreatic', 'lipase', 'history', 'cholestyramine', 'HBsAg', 'drug', 'investigator', 'efficacy', 'regimens', 'inhibitors', 'diuretics', 'surgical', 'drug', 'Pregnant']
# model_words_dict ['and', 'mg', 'mg', 'ml', 'postmenopausal', 'oophorectomy', 'sterilized', '135', '170', '135', '170', 'ACEI', 'ARB', 'and', '1g', 'day', 'diabetes', '35', 'mEq', 'ml', 'min', '20mg', 'encephalopathy', 'infarction', 'pectoris', 'surgery', 'Second', 'arrhythmia', 'dosing', 'Donation', 'mL', 'surgical', 'absorption', 'distribution', 'metabolism', 'to', 'gastrectomy', 'gastroenterostomy', 'active', 'gastritis', 'duodenal', 'ulcers', 'gastrointestinal', 'injury', 'pancreatitis', 'function', 'lipase', 'disease', 'encephalopathy', 'varices', 'cholestyramine', 'HBsAg', 'drug', 'investigator', 'efficacy', 'regimens', 'Known', 'and', 'diuretics', 'surgical', 'condition', 'his', 'study', 'study', 'drug', 'Pregnant', 'inclusion']
# label_words_dict ['block']
# model_words_dict ['disease', 'block', 'but', 'but', 'to']
# NCT00480129
# NCT00480129
# label_words_dict []
# model_words_dict ['diagnosis', 'based', 'absence', 'cold', 'History', 'RAST', 'grass', 'history', 'allergies']
# label_words_dict ['grass']
# model_words_dict ['attacks', 'runny', 'blocked', 'test', 'and', 'lactoseintolerance']
# label_words_dict ['the']
# model_words_dict ['the']
# NCT00483106
# NCT00483106
# label_words_dict []
# model_words_dict []
# label_words_dict []
# model_words_dict []
# label_words_dict []
# model_words_dict []
# NCT00500500
# NCT00500500
# label_words_dict []
# model_words_dict ['male', '50', 'old', '16', 'equal', 'Institute', 'Neurological', 'Disorders', 'Disease', 'positive', 'Diagnostic', 'Manual', 'positive', 'treated', 'interfere', 'level', 'B12', 'which', 'considered']
# label_words_dict []
# model_words_dict ['female', 'inferior', '', 'NINCDS', 'Disorders', 'illness', 'cancer', 'illness']
# label_words_dict []
# model_words_dict []
# NCT00502567
# NCT00502567
# label_words_dict ['cancer', 'lesion', 'of']
# model_words_dict ['cancer', 'amenable', 'therapy', 'lesion', 'techniques', 'according', 'history']
# label_words_dict ['surgery']
# model_words_dict ['surgery', 'CT']
# label_words_dict []
# model_words_dict ['is']
# NCT00527826
# NCT00527826
# label_words_dict ['COPD', 'Females', 'COPD', 'ambulatory', 'beta1agonists', 'scheduled', 'corticosteroids']
# model_words_dict ['Subject', 'Subject', 'must', 'diagnosis', 'based', 'Females', 'be', 'definition', 'is', 'regardless', 'age', 'ovaries', 'and', 'who', 'females', 'who', 'IV', 'according', '50', 'normal', 'leading', 'dosage', 'corticosteroids', 'hospitalization', 'medication', 'prior', 'added', 'exsmokers', 'history', 'number', 'number', 'number', 'day', 'day', 'outpatients', 'ambulatory', 'able', 'travel', 'treated', 'beta2agonists', 'therapy', 'can', 'signed', 'prior', 'Able', 'comply', 'requirements', 'protocol', 'available', 'signs', 'history', 'arthritis', 'Known', 'resection', 'scheduled', '1', 'and', 'duration', 'study', 'any', 'inhibitors', 'antidepressants', 'likely', 'interfere', 'impact', 'opinion', 'evidence', 'History', 'presence', 'reaction', 'dosage', 'corticosteroids', 'hospitalization', 'prior', 'infection', 'prior', 'female', 'female', 'employee', 'member', 'employee', 'study', 'prior']
# label_words_dict ['Male', 'ligation', 'moderate', 'corticosteroids', 'corticosteroids', 'antibiotics', 'Current', 'beta2agonists', 'shortacting', 'anticholinergics', 'therapy', 'disorders', 'arthritis', 'transplant', 'inhibitors', 'chronic', 'drug', 'sensitivity', 'corticosteroids', 'Moderate', 'corticosteroids', 'antibiotics', 'Pregnant', 'female']
# model_words_dict ['ATS', 'Male', 'subjects', 'Females', 'ligation', 'hysterectomy', 'III', 'Volume', 'FEV1', 'moderate', 'corticosteroids', 'and', 'antibiotics', 'Current', '', 'smoked', 'eg', 'years', 'vaccines', 'needed', 'shortacting', 'tiotropium', 'beta2agonists', 'theophylline', 'mucolytics', 'antioxidants', 'indication', 'ventilation', 'disorders', 'asthma', 'cancer', 'sarcoidosis', 'tuberculosis', 'fibrosis', 'fibrosis', 'disease', 'SZ', 'surgery', 'transplant', 'chronic', 'Serious', 'study', 'Have', 'investigator', 'alcohol', 'drug', 'History', 'sensitivity', 'corticosteroids', 'Moderate', 'corticosteroids', 'and', 'antibiotics', 'Pregnant', 'investigator', 'subinvestigator', 'coordinator', 'investigator']
# label_words_dict ['of', 'of', 'AND']
# model_words_dict ['and', 'disease']
# NCT00543712
# NCT00543712
# label_words_dict ['diagnosis', 'patients', 'infection', 'NYHA', 'contraindicates', 'risk']
# model_words_dict ['Ability', 'understand', 'willingness', 'diagnosis', 'options', 'standard', 'status', 'expectancy', 'patients', 'males', 'use', 'means', 'trial', 'and', 'exposure', 'radiotherapy', 'prior', 'therapy', 'injury', 'prior', 'anticipation', 'need', 'procedure', 'course', 'malignancies', 'prior', 'illness', 'including', 'limited', 'infection', 'history', 'surgery', 'months', 'situation', 'compliance', 'Known', 'positive', 'History', 'suspicion', 'condition', 'use', 'or', 'interpretation', 'results', 'risk', 'Use', 'procedures', 'prior', 'sensitivity', 'any', 'administered', 'disorder', 'ability', 'patient', 'consent', 'comply']
# label_words_dict ['therapy', '1', 'Prior', 'therapy', 'injury', 'study', 'ongoing', 'C', 'of', 'disease', 'results', 'trials', 'Pregnancy', 'consent']
# model_words_dict ['chondrosarcoma', 'treated', 'females', 'eg', 'pill', 'IUD', 'therapy', 'procedure', 'biopsy', '1', 'ongoing', 'significant', 'disease', 'II', 'failure', 'arrhythmia', 'II', 'disease', '1', 'C', 'disease', 'dysfunction', 'finding', 'disease', 'drug', 'study', 'trials', 'Pregnancy', 'and']
# label_words_dict ['Any', 'that']
# model_words_dict ['disease', 'but']
# NCT00576173
# NCT00576173
# label_words_dict ['malignancy']
# model_words_dict ['Patients', 'judged', 'investigator', 'caused', 'Patients', 'Patients', 'must', 'been', 'dose', 'opioids', 'prior', 'study', 'and', 'dosage', 'duration', 'Patients', 'Patients', 'must', 'Patients', 'who', 'morphine', 'Fentanyl', 'Patients', 'opinion', 'Patients', 'Patients', 'who', 'medications', 'anesthetics']
# label_words_dict ['radiologically', 'opioids', '120mg', 'hepatic', 'respiratory', 'antidepressants', 'medications', 'anesthetics']
# model_words_dict ['histologically', 'radiologically', 'opioids', '120mg', '50ug', 'hepatic', 'would', 'investigator', 'CNS', 'respiratory', 'function', 'antidepressants', 'drugs', 'hypnotics', 'inhibitor', 'analgesics', 'and', 'Tramadol']
# label_words_dict []
# model_words_dict ['investigator']
# NCT00586898
# NCT00586898
# label_words_dict ['evidence', 'treatment', 'therapy']
# model_words_dict ['Patients', 'history', 'disease', 'who', 'patients', 'progression', 'biochemically', 'group', 'not', 'Patients', 'present', 'evidence', 'time', 'treatment', 'patients', 'defined', 'no', 'range', 'Diagnosis', 'Patient', 'Patient', 'must', 'level', 'limit', 'Patients', 'Patients', 'must', 'function', 'defined', 'limit', 'allowed', 'prior', 'provided', 'duration', 'cycle', 'up', 'exposure', 'Patients', 'years', 'Patients', 'Patients', 'must', 'stating', 'nature', 'survival', 'unwillingness', 'comply']
# label_words_dict ['radiation', 'diagnosis', 'disease', 'bone', 'mgdl', 'mgdl', 'therapy', 'CNS', 'Inability']
# model_words_dict ['radiation', 'diagnosis', 'disease', 'bone', 'ng', '_3500', 'mm3', '_100000', 'mg', 'dl', 'mg', 'dl', 'cc', 'therapy', 'prostatectomy', 'III', 'IV', 'CNS', 'Inability', 'protocol', 'followup']
# label_words_dict []
# model_words_dict ['may', 'minimum', 'does', 'epiduraltumor']
# NCT00599924
# NCT00599924
# label_words_dict ['cycles', 'cycles', 'patients', 'treatment']
# model_words_dict ['limited', 'adenocarcinoma', 'treatment', 'cycles', 'treatment', 'cycles', 'treatment']
# label_words_dict []
# model_words_dict ['dose', 'colon', '0', 'cohorts']
# label_words_dict []
# model_words_dict []
# NCT00609531
# NCT00609531
# label_words_dict ['medication', 'medication', 'poorlycontrolled', 'of', 'doses', 'medication', 'duration']
# model_words_dict ['time', 'diagnosis', 'equal', '8', 'Free', 'medication', 'month', 'weeks', 'SSRIs', 'neuroleptics', 'days', 'prior', 'duration', 'medication', 'time', 'seizure', 'prior', 'Presence', 'conditions', 'interfere', 'History', 'seizure', 'care', 'neurosurgeon', 'determined', 'History', 'tattoos', 'verified', 'prior', 'administration', 'placebo', 'prior', 'imaging', 'due', 'risk', 'that', 'associated', 'treatment', 'imaging', 'contraindications', 'therapy', 'determined', 'induction', 'hypomania', 'medication', 'interfere', 'history', 'doses', 'history', 'failure', 'doses', 'need', 'duration', 'medication']
# label_words_dict ['SSRIs', 'years', 'disorder', 'a', 'Implanted', 'mania', 'hypomania', 'medication']
# model_words_dict ['than', 'years', 'years', 'participation', 'trauma', 'months', 'stroke', 'neurosurgery', 'neurologist', 'Implanted', 'citalopram', 'mania', 'therapy', 'disorder']
# label_words_dict ['Scale', 'medication']
# model_words_dict ['medication']
# NCT00625742
# NCT00625742
# label_words_dict ['acetate']
# model_words_dict ['referred', 'Clinic', 'loss', '5', 'weight', 'years', 'score', 'intake', 'procedures', 'acetate', 'continue', 'weight', 'weeks', 'clearance', 'determined', 'corticosteroids', 'edema', 'unable', 'history', 'perforationhistory', 'limit', 'Patients', 'such']
# label_words_dict ['dementia', 'ascites', 'bleeding', 'coagulopathy']
# model_words_dict ['age', '60', '', 'cc', 'dementia', 'edema', 'ascites', 'ie', 'bleeding', 'coagulopathy', 'ALT']
# label_words_dict ['Are']
# model_words_dict ['Are', 'Are']
# NCT00639795
# NCT00639795
# label_words_dict ['illness', 'obesity', 'psychosis', 'treatment', 'infections']
# model_words_dict ['thoracoscopy', 'estimate', 'conversion', 'evidence', 'pregnancy', 'assessed', 'illness', 'allergy', 'Contraindication', 'anesthesia', 'site', 'allergy', 'neuropathy', 'use', 'use', 'Patients', 'such', 'psychosis', 'treatment', 'unable', 'Patients', 'infections', 'antibiotics', 'month', 'trials', 'that', 'interfere']
# label_words_dict ['sulfate', 'to', 'inhaled']
# model_words_dict ['Clinical', 'Serious', 'uncontrolled', 'oxycodone', 'sulfate', 'blockade', 'local', 'seconds', 'conditions', 'block', 'inhaled', 'BMI40kg']
# label_words_dict []
# model_words_dict ['Patients']
# NCT00650312
# NCT00650312
# label_words_dict ['hypersensitivity']
# model_words_dict ['years', 'Male', 'Women', 'potential', 'potential', 'must', 'performed', 'prior', 'start', 'study', 'and', 'prior', 'scheduled', 'test', 'given', 'prior', 'dosing', 'completion', 'Women', 'potential', 'form', 'duration', 'forms', 'place', 'prior', 'start', 'study', 'place', 'conjunction', 'accompanied', 'course', 'course', '', 'women', 'potential', 'method', 'contraception', 'addition', 'advice', 'lbs', 'man', 'lbs', 'women', 'and', '15', 'IBW', 'referenced', 'Table', 'Weights', 'subjects', 'normal', 'healthy', 'B', 'test', 'screen', 'phencyclidine', 'performed', 'days', 'dose', 'Use', 'Ingestion', 'beverage', 'prior', 'dose', 'Ingestion', 'products', 'prior', 'dose', 'test', 'Use', 'medication', 'prior', 'dose', 'Use', 'known', 'activity', 'prior', 'dose', 'Use', 'contraceptives', 'therapy', 'prior', 'dose', 'History', 'disease', 'History', 'drug', 'time', 'suggested', 'equal', 'males', 'equal', 'Abnormal', 'Guide', 'Abnormal', 'loss', 'volume', 'mL', 'prior', 'dose', 'Subjects', 'who', 'drug', 'prior', 'dose', 'hypersensitivity', 'History']
# label_words_dict ['Male', 'abstinence', 'period', 'postmenopausal', 'oophorectomy', 'man', 'disease', 'drug', 'disease', 'males', 'females', 'Allergy']
# model_words_dict ['nonpregnant', 'Sunday', 'Monday', 'abstinence', 'period', 'containing', 'agent', 'year', 'ligation', 'oophorectomy', 'study', 'period', 'Company', 'examination', 'evaluation', 'ECG', 'tests', 'amphetamine', 'barbiturates', 'benzodiazepine', 'cannabinoid', 'cocaine', 'opiates', 'alcoholic', 'caffeine', 'food', 'vitamins', 'recent', 'dietary', 'and', 'and', 'evaluation', 'HIV', 'B', 'disease', 'than', 'mg', 'than', 'mg', 'females', 'Donation', 'blood', 'Allergy', 'medication']
# label_words_dict ['and', 'nonpregnant']
# model_words_dict ['will']
# NCT00676273
# NCT00676273
# label_words_dict ['deficiency']
# model_words_dict ['years', 'test', 'impact', 'incontinence', 'quality', 'able', 'comprehend', 'Understand', 'and', 'willing', 'comply', 'requirements', 'agreeing', 'available', 'stable', 'suitable', 'determined', 'ambulatory', 'able', 'Who', 'planning', 'pregnant', 'defined', 'or', 'evidence', 'infection', 'evidence', 'deficiency', 'defined', 'pressure']
# label_words_dict ['pregnant', 'study', 'local']
# model_words_dict ['pregnant', 'study', 'condition', 'HIV', 'sclerosis', 'local']
# label_words_dict []
# model_words_dict []
# NCT00679341
# NCT00679341
# label_words_dict ['breast', 'chemotherapy', 'pregnant', 'I', 'disease', '34']
# model_words_dict ['adenocarcinoma', 'breast', 'disease', 'candidate', 'chemotherapy', 'women', 'potential', 'men', 'partners', 'agreement', 'form', 'forms', 'contraception', 'patient', 'use', 'continue', 'duration', 'treatment', 'and', 'dose', 'partners', 'pregnant', 'condoms', 'duration', 'History', 'chemotherapy', 'interval', 'completion', 'time', 'prior', 'prior', 'neuropathy', 'History', 'malignancy', 'except', 'situ', 'cancers', 'outcome', 'radiotherapy', 'treatment', '25', 'fraction', 'administered', 'prior', 'metastases', 'that', 'therapy', 'therapy', 'metastases', 'prior', 'History', 'exposure', 'doses', 'm2', 'History', 'arrhythmia', 'History', 'infarction', 'prior', '50', 'prior', 'History', 'CHF', 'mL', 'days', 'because', 'complications', 'or', 'injury', 'prior', 'anticipation', 'need', 'surgery', 'course', 'History', 'treatment', 'prior', 'infection', 'B', 'History', 'hypersensitivity', 'hypersensitivity', 'any', 'drugs', 'Assessed', 'investigator', 'unwilling', 'comply', 'requirements']
# label_words_dict ['Histologically', 'potential', 'contraception', 'advanced', 'symptoms', 'Doxorubicin', 'LVEF', 'malignancy', 'procedure', 'randomization', 'pregnancy', 'B', 'reaction', 'unable']
# model_words_dict ['Histologically', 'advanced', 'potential', 'effective', 'contraception', 'and', 'neoadjuvant', 'years', 'cervix', 'carcinoma', 'cancer', 'unresectable', 'advanced', 'irradiated', 'untreated', 'symptomatic', 'symptoms', 'radiation', 'surgery', 'Doxorubicin', 'mg', 'mg', '120mg', 'mg', 'failure', 'LVEF', 'ng', 'malignancy', 'severe', 'eg', 'cardiovascular', 'pulmonary', 'ulcers', 'procedure', 'randomization', 'pregnancy', 'HIV', 'and', 'reaction', 'trastuzumab', 'proteins', 'excipients', 'unable']
# label_words_dict ['HER2positive', 'years']
# model_words_dict ['is', 'be']
# NCT00718952
# NCT00718952
# label_words_dict ['IIIII', 'nitrate']
# model_words_dict ['IIIII', 'nonresponder', 'types', 'Subjects', 'refuse', 'cooperate', 'Subjects', 'kidney', 'or', 'have', 'nitrate', 'Subjects', 'who', 'treated', 'sildenafil']
# label_words_dict ['consents', 'CYP3A4inhibitor', 'PAH', 'sildenafil']
# model_words_dict ['hypertension', 'hypertension', 'consents', 'acute', 'liver', 'brain', 'CYP3A4inhibitor', 'PAH', 'sildenafil']
# label_words_dict []
# model_words_dict []
# NCT00720031
# NCT00720031
# label_words_dict []
# model_words_dict ['patients', 'except', 'treatment', 'expectancy', 'state', 'Patient', 'negative', 'HIV', 'B', 'beginning', 'compared', 'evoluting', 'evoluting', 'and', 'troubles']
# label_words_dict ['locoregional', 'cutaneous', 'infusion', 'radiotherapy', 'evoluting', 'evoluting', 'patients', 'Pregnant']
# model_words_dict ['locoregional', 'cutaneous', 'MelanA', 'infusion', 'radiotherapy', '80', '0', '1', 'mm3', '105g', 'dl', 'mm3', '1', 'pathologies', 'uncontrolled', 'HTA', 'deficiency', 'angor', 'patients', 'Pregnant']
# label_words_dict ['nodules', 'antigen', 'women']
# model_words_dict ['nodules', 'do']
# NCT00728156
# NCT00728156
# label_words_dict ['Contraindication', 'Women']
# model_words_dict ['Patients', 'T2DM', 'CAS', 'Diagnosed', 'according', 'CADPresence', 'one', 'enzyme', 'stenosis', '18', 'consent', 'prior', 'Contraindication', 'smokers', 'patients', 'Women', 'Use', 'malignancy', 'patients', 'limit', 'Unable', 'Use', 'drugs', 'prior']
# label_words_dict ['enzyme', 'evidence', 'percutaneous', 'ANDdiagnosed', 'malignancy']
# model_words_dict ['test', 'and', 'infarction', 'vessel', 'percutaneous', 'procedures', 'Malignancydiagnosed', 'Anaemia', 'malignancy', 'corticosteroids', 'Cirrhosis']
# label_words_dict []
# model_words_dict []
# NCT00730301
# NCT00730301
# label_words_dict ['Lab', 'Dysrhythmia']
# model_words_dict ['diagnosed', 'Lab', 'distribution', '40', '40', 'Stable', 'Hg', 'walk', 'Nonsmoking', 'prior', 'interview', 'agrees', 'willing', 'able', 'assessments', 'treatment', 'disease', 'nodule', 'History', 'evidence', 'Dysrhythmia', 'risk', 'failure', 'mo', 'history', 'History', 'MI', 'mo', 'Evidence', 'expected', 'survival', 'condition', 'interferes', 'completion', 'unable', 'minutes', 'peddling']
# label_words_dict ['rehabilitation', 'Pleural', 'bullectomy', 'during', 'Evidence', 'disease', 'disease']
# model_words_dict ['kg', 'value', 'FEV1', 'predicted', '', 'rehabilitation', 'Pleural', 'transplant', 'LVRS', 'sternotomy', 'bullectomy', 'Fever', 'count', 'exercise', 'Evidence', 'beats', 'min', 'PVCs', 'arrhythmia', 'disease', 'disease', 'initial']
# label_words_dict ['has', 'that']
# model_words_dict ['has', 'is']
# NCT00749112
# NCT00749112
# label_words_dict []
# model_words_dict ['anemia', 'clinical', 'evidence', 'refractory', 'purpura', 'refractory', 'serology']
# label_words_dict ['relapse', 'relapse']
# model_words_dict ['', 'treatment', 'relapse', '50000', 'treatment', 'relapse', 'viral', 'HIV', 'HCV']
# label_words_dict []
# model_words_dict []
# NCT00752310
# NCT00752310
# label_words_dict ['Healthy', 'evaluation', 'abnormality', 'hypersensitivity']
# model_words_dict ['day', 'prior', 'weight', 'defined', 'divided', 'square', 'meters', '180', 'Able', 'comply', 'Healthy', 'basis', 'evaluation', 'absence', 'abnormality', 'signs', 'results', 'coagulation', 'tests', 'history', 'such', 'as', 'limited', 'history', 'allergy', 'such', 'as', 'limited', 'sulphonamides', 'hypersensitivity', 'any', 'excipients', 'subject', 'use', 'willing', 'methods', 'end']
# label_words_dict ['1', 'rash', 'sulphonamides', 'allergy', 'control', 'test']
# model_words_dict ['Nonsmoking', 'cigarettes', 'cigars', 'BMI', 'kg', 'm2', 'examination', 'history', 'ECG', 'biochemistry', '1', 'rash', 'eruptions', 'allergies', 'allergy', 'dermatitis', 'eczema', 'psoriasis', 'to', 'allergy', 'methods', 'test']
# label_words_dict ['Criteria', 'the', 'potential', 'or']
# model_words_dict ['smoking', 'the', 'screening', 'but', 'urticaria', 'but', 'penicillins', 'trial', 'potential', 'or', 'period']
# NCT00785213
# NCT00785213
# label_words_dict []
# model_words_dict ['years', 'equal', 'healthy', 'basis', 'history', '', 'Completion', 'process', 'prior', 'Provision', 'screening', 'evidence', 'presence', 'Subjects', 'who', 'known', 'enzymes', 'Pgp', 'prior', 'dose', 'allergies']
# label_words_dict ['sterile', 'donation', 'Pregnant', 'history', 'alcoholism', 'drugs', 'sulfate']
# model_words_dict ['postmenopausal', 'sterile', 'than', '', '115g', 'donation', 'Pregnant', 'HIV', 'HbsAg', 'history', 'alcoholism', 'History', 'cardiovascular', 'pulmonary', 'hepatic', 'gallbladder', 'tract', 'renal', 'hematologic', 'gastrointestinal', 'endocrine', 'immunologic', 'dermatologic', 'neurologic', 'drugs', 'inhibit', 'and', 'sulfate']
# label_words_dict ['age', 'Nonsmoking']
# model_words_dict []
# NCT00787254
# NCT00787254
# label_words_dict []
# model_words_dict ['was', 'treatment', 'obtained', 'treatment', 'confirmed', 'to', 'history', 'gastric', 'ulcers', 'hemorrhage', 'history', 'hypersensitivity']
# label_words_dict ['ulcer', 'gastric', 'Current', 'asthma', 'hepatic']
# model_words_dict ['ulcer', 'and', 'Current', 'asthma', 'Past', 'hepatic', 'dysfunction', 'hypertension']
# label_words_dict []
# model_words_dict []
# NCT00806273
# NCT00806273
# label_words_dict ['plan']
# model_words_dict ['Pts', 'OHSU', 'extraction', 'all', 'teeth', 'scheduled', 'delivery', 'used', 'able', 'isolated', 'Understand', 'inability', 'isolate', 'Unable']
# label_words_dict []
# model_words_dict ['some', 'understand']
# label_words_dict ['3']
# model_words_dict []
# NCT00806936
# NCT00806936
# label_words_dict ['allergy']
# model_words_dict ['decision', 'analogues', 'controlled', 'eligible', 'selection', 'discretion', 'allergy', 'Subjects', 'who', 'unlikely', 'comply', 'inability', 'return', 'Subjects', 'Females', 'potential', 'who', 'intend', 'or', 'receipt', 'product', 'prior']
# label_words_dict ['products', 'potential', 'breastfeeding', 'become', 'pregnant']
# model_words_dict ['insulin', 'subject', 'two', 'Known', 'products', 'requirements', 'attitude', 'pregnant', 'breastfeeding', 'pregnant']
# label_words_dict ['are']
# model_words_dict ['are']
# NCT00812344
# NCT00812344
# label_words_dict []
# model_words_dict ['19', 'm2', '50']
# label_words_dict ['trauma']
# model_words_dict ['kg', 'illness', 'trauma']
# label_words_dict []
# model_words_dict []
# NCT00846703
# NCT00846703
# label_words_dict ['relapse', 'meeting', 'Blasts', 'complications']
# model_words_dict ['relapse', 'Patients', 'one', 'all', 'PB', '1', '5', 'marrow', 'marrow', 'years', 'PB', 'marrow', 'marrow', 'criteria', 'marrow', '15', 'marrow', 'criteria', 'marrow', 'SR', 'M3', 'PB', 'marrow', 'disease', 'Not', 'owing', 'complications', 'due', 'one', 'data', 'that', 'needed', 'or', 'selection']
# label_words_dict ['M1', 'Aged', 'M1', '15', 'M2', 'chromosomepositive']
# model_words_dict ['1000', '20000', '5', '1', 'and', '20000', '1000', 'M1', '1000', 'M2', 'BCR', 'chromosomepositive', 'MLL', 'eg', 'diagnosis']
# label_words_dict ['ALL', 'Criteria', 'syndrome', 'complications']
# model_words_dict []
# NCT00862446
# NCT00862446
# label_words_dict []
# model_words_dict ['cholestasis', 'treatment', 'Lack']
# label_words_dict []
# model_words_dict ['mg']
# label_words_dict []
# model_words_dict []
# NCT00867958
# NCT00867958
# label_words_dict []
# model_words_dict ['scheduled', 'signs', 'ICF', 'understanding', 'allergy', 'diagnosis', 'which', 'contraindications', 'evidence']
# label_words_dict ['local', 'carcinomatosis', 'problems']
# model_words_dict ['obstruction', 'strangulation', 'peritonitis', 'perforation', 'local', 'infection', 'bowel', 'carcinomatosis', 'problems']
# label_words_dict []
# model_words_dict []
# NCT00886158
# NCT00886158
# label_words_dict ['recipients']
# model_words_dict ['birth', 'consent', 'Lack']
# label_words_dict []
# model_words_dict ['appropriate']
# label_words_dict []
# model_words_dict []
# NCT00894712
# NCT00894712
# label_words_dict ['pathologically']
# model_words_dict ['Must', 'situ', 'Patients', 'Patients', 'must', 'Patients', 'not', 'therapy', 'Patients', 'not', 'prior', 'Patients', 'because', 'potential', 'harm', 'result', 'Women', 'prior', 'entry', 'they', 'counseled', 'importance', 'pregnancy', 'Patients', 'not', 'compliance', 'patients', 'informed', 'nature', 'study', 'accordance', 'institutional', 'History', 'hypersensitivity', 'disease']
# label_words_dict ['adenocarcinoma', 'Sarcoma']
# model_words_dict ['adenocarcinoma', 'ie', 'medical', 'consent', 'pathology', 'freckles', 'disease', 'Sarcoma']
# label_words_dict ['must', 'must']
# ...
# label_words_dict ['anesthesia']
# model_words_dict ['anesthesia', 'tramadol']
# label_words_dict ['Criteria']
# model_words_dict []
# NCT03479502
# NCT03479502
# label_words_dict ['findings', 'arthritis', 'treatment']
# model_words_dict ['physician', 'disease']
# label_words_dict ['Doxycycline', 'arthritis']
# model_words_dict ['Doxycycline', 'arthritis', 'trauma', 'injury']
# label_words_dict ['and']
# model_words_dict ['and']
# NCT03480607
# NCT03480607
# label_words_dict ['allergy']
# model_words_dict []
# label_words_dict ['wound']
# model_words_dict ['wound']
# label_words_dict ['illness']
# model_words_dict []
# NCT03481894
# NCT03481894
# label_words_dict ['indication']
# model_words_dict ['start']
# label_words_dict ['Male', 'PN', 'corn', 'substances', 'hyperlipidemia', 'hypertriglyceridemia', 'acidosis', 'Pregnancy']
# model_words_dict ['Male', 'PN', 'egg', 'proteins', 'proteins', 'corn', 'products', 'substances', 'hyperlipidemia', 'edema', 'insufficiency', 'infarction', 'acidosis', 'AST', 'ALT', 'GGPT', 'sodium', 'potassium', 'magnesium', 'calcium', 'chloride', 'pH', 'saturation', 'Pregnancy']
# label_words_dict []
# model_words_dict []
# NCT03484091
# NCT03484091
# label_words_dict ['Allergy']
# model_words_dict ['osteoarthritis']
# label_words_dict ['varus', 'hip', 'Posttraumatic', 'Pregnancy']
# model_words_dict ['varus', 'hip', 'Posttraumatic', 'Pregnancy', 'arthritis', 'stroke', 'malignancy']
# label_words_dict []
# model_words_dict []
# NCT03491059
# NCT03491059
# label_words_dict ['user', 'user']
# model_words_dict ['days']
# label_words_dict ['males', 'renal']
# model_words_dict ['males', 'tobacco', 'pregnant', 'hypertension', 'disease', 'diabetes', 'renal', 'impairment', 'hypertrophy', 'stroke', 'schizophrenia', 'ADHD', 'current', 'tranquilizers', 'antipsychotics', 'rifampicin', 'dexamethasone', 'tobacco']
# label_words_dict ['Criteria']
# model_words_dict ['Criteria', 'consent', 'drugs']
# NCT03493919
# NCT03493919
# label_words_dict ['history', 'performed']
# model_words_dict ['history', 'subjects', 'kg', 'subjects', 'vaccination', 'vaccination', 'treatment', 'or', 'therapy', 'history']
# label_words_dict ['male', 'tubal', 'ovariectomy', 'unstable', 'products', 'vaccination', 'antineoplastic', 'agents', 'immunoglobulins', 'investigational', 'vaccination', 'meningococcal', 'visit', 'apheresis', 'investigational', 'reaction', 'Pregnant', 'pregnant', 'confirmed', 'immunosuppressive', 'history', 'congenital', 'consumption']
# model_words_dict ['male', 'ligation', 'occlusion', 'hysterectomy', 'ovariectomy', 'unstable', 'vaccines', 'products', 'vaccination', 'PO', 'IV', 'antineoplastic', 'agents', 'immunoglobulins', 'investigational', 'vaccination', 'meningococcal', '60', 'apheresis', 'been', 'investigational', 'vaccine', 'reaction', 'Pregnant', 'pregnant', 'confirmed', 'immunosuppressive', 'congenital', 'consumption']
# label_words_dict ['but', 'of']
# model_words_dict ['with', 'investigator', 'but', 'of', 'study', 'or', 'of', 'a', 'anaemia', 'to']
# NCT03495557
# NCT03495557
# label_words_dict ['Conversion']
# model_words_dict []
# label_words_dict []
# model_words_dict ['Emergent']
# label_words_dict []
# model_words_dict []
# NCT03495609
# NCT03495609
# label_words_dict ['reaction', 'treatment']
# model_words_dict []
# label_words_dict ['B']
# model_words_dict ['chemical', 'contraceptives', 'androgens', 'prednisone', 'hormones', 'B']
# label_words_dict []
# model_words_dict []
# NCT03497598
# NCT03497598
# label_words_dict ['Lactose']
# model_words_dict []
# label_words_dict ['months', 'Pregnancy']
# model_words_dict ['months', 'Pregnancy']
# label_words_dict []
# model_words_dict []
# NCT03499639
# NCT03499639
# label_words_dict []
# model_words_dict []
# label_words_dict []
# model_words_dict ['HCV']
# label_words_dict ['more']
# model_words_dict ['6']
# NCT03500211
# NCT03500211
# label_words_dict ['anesthesia']
# model_words_dict ['patients']
# label_words_dict ['scheduled', 'lidocaine', 'admission', 'disease', 'fibromyalgia', 'narcotic']
# model_words_dict ['scheduled', 'lidocaine', 'admission', 'disease', 'fibromyalgia', 'arthritis', 'osteoarthritis', 'narcotic']
# label_words_dict []
# model_words_dict ['or']
# NCT03506009
# NCT03506009
# label_words_dict ['therapy']
# model_words_dict ['disease']
# label_words_dict ['malformation', 'mmHg', 'therapy', 'Thrombin']
# model_words_dict ['tumour', 'malformation', 'mmHg', 'therapy', 'Thrombin', 'drug']
# label_words_dict []
# model_words_dict []
# NCT03506477
# NCT03506477
# label_words_dict ['of', 'allergy']
# model_words_dict ['Screening', 'product', 'FCBP', 'history', 'Women', 'potential']
# label_words_dict ['Male', 'Islanders', '2', 'diseases', 'topical', 'medications', 'oral', 'medications', 'metabolism']
# model_words_dict ['Male', 'race', 'Americans', 'Asians', 'Islanders', 'guttate', 'erythrodermic', 'diseases', 'topical', 'oral', 'psoriasis', 'biologic', 'pregnant', 'nursing', 'metabolism', 'randomization', 'pharmacokinetic']
# label_words_dict ['psoriasis', 'AND']
# model_words_dict ['IVVI']
# NCT03506750
# NCT03506750
# label_words_dict []
# model_words_dict ['detachment', 'postmenopausal', 'pregnant']
# label_words_dict ['1', 'hemorrhage', 'detachment', 'ocular', 'mmHg']
# model_words_dict ['1', 'hemorrhage', 'sterile', 'ocular', 'surgery', 'amputation', 'pressure']
# label_words_dict []
# model_words_dict ['or']
# NCT03511521
# NCT03511521
# label_words_dict []
# model_words_dict ['stay']
# label_words_dict ['methylprednisolone', 'Diabetic', 'methylprednisolone']
# model_words_dict ['methylprednisolone', 'Diabetic', 'methylprednisolone', 'methylprednisolone']
# label_words_dict ['Steroids']
# model_words_dict ['and']
# NCT03513757
# NCT03513757
# label_words_dict []
# model_words_dict ['scans']
# label_words_dict ['eggs', 'disease']
# model_words_dict ['eggs', 'soy', 'disease']
# label_words_dict []
# model_words_dict ['be']
# NCT03513874
# NCT03513874
# label_words_dict []
# model_words_dict ['years', 'patients']
# label_words_dict ['Fasting', 'malignancy', 'compliance']
# model_words_dict ['GADA', 'IA2A', 'Fasting', 'malignancy', 'pregnant', 'compliance']
# label_words_dict ['years']
# model_words_dict ['years']
# NCT03518034
# NCT03518034
# label_words_dict ['hypogonadism', 'therapy']
# model_words_dict ['ngdL', 'hypogonadism', 'months']
# label_words_dict ['sign', 'disease', 'congenital', 'thrombosis', 'embolism', 'cancer', 'Class']
# model_words_dict ['disease', 'congenital', 'thrombosis', 'embolism', 'cancer']
# label_words_dict []
# model_words_dict ['would']
# NCT03519568
# NCT03519568
# label_words_dict ['vaccine', 'vaccine', 'vaccine', 'OR', 'events']
# model_words_dict ['vaccine', 'vaccine', 'vaccine', 'days', 'vaccine', 'days', 'temperature371U2103', 'thrombocytopenia']
# label_words_dict ['history', 'encephalopathy', 'immunodeficiency', 'steroid', 'HIV', 'temperature371U2103', 'thrombocytopenia', 'infection', 'liver', 'suppurative']
# model_words_dict ['history', 'anaphylaxis', 'convulsion', 'epilepsy', 'encephalopathy', 'immunodeficiency', 'therapy', 'immunity', 'thrombocytopenia', 'infection', 'disease', 'liver', 'disease', 'infectious', 'suppurative', 'local', 'reactions']
# label_words_dict ['is', 'and', 'is', 'is', 'is', 'is', 'is', 'is']
# model_words_dict ['is', 'and', 'is', 'is', 'is', 'is', 'is', 'is']
# NCT03530124
# NCT03530124
# label_words_dict ['planned', 'anaphylaxis', 'anaphylaxis', 'latex', 'apnea']
# model_words_dict []
# label_words_dict ['yeast', 'congenital']
# model_words_dict ['English', 'DTaP', 'IPV', 'PCV13', 'DTaP', 'IPV', 'HBV', 'PCV13', 'neomycin', 'yeast', 'congenital', 'Child', 'staff', 'injury']
# label_words_dict ['apnea']
# model_words_dict ['LARs', 'participant']
# NCT03532620
# NCT03532620
# label_words_dict ['hypersensitivity', 'disease', 'treatment']
# model_words_dict ['200mgdl', 'woman']
# label_words_dict ['IGT', '80mmHgDBP110mmHg', 'ALT', 'Diagnosed']
# model_words_dict ['126mgdl', '200mgdl', '130mmHgSBP180mmHg', 'mmHg', 'ALT', 'Diagnosed', 'ACS', 'SCAD', 'revascularization', 'ICM', 'stroke', 'TIA', 'SBP180mmHg', 'blockers', 'SAS', 'PA', 'RAS', 'pheochromocytoma', 'syndrome', 'diseases', 'statins', 'fibrates', 'gastrectomy', 'Diagnosed', 'efficacy', 'Pregnant', 'woman', 'woman']
# label_words_dict []
# model_words_dict ['may']
# NCT03536520
# NCT03536520
# label_words_dict []
# model_words_dict []
# label_words_dict ['men', 'cardiovascular', 'disease', 'hypoxia', 'acetazolamide']
# model_words_dict ['men', 'disease', 'respiratory', 'treatment', 'hypoxia', 'day', 'acetazolamide']
# label_words_dict []
# model_words_dict ['yrs']
# NCT03537924
# NCT03537924
# label_words_dict ['disease']
# model_words_dict []
# label_words_dict ['men', 'disease', 'cardiovascular', 'hypoxia', 'day', 'acetazolamide']
# model_words_dict ['men', 'disease', 'respiratory', 'treatment', 'hypoxia', 'day', 'acetazolamide']
# label_words_dict ['yrs']
# model_words_dict ['yrs']
# NCT03539718
# NCT03539718
# label_words_dict []
# model_words_dict []
# label_words_dict ['males']
# model_words_dict ['males']
# label_words_dict []
# model_words_dict []
# NCT03541980
# NCT03541980
# label_words_dict []
# model_words_dict ['years', 'disease', 'ER', 'crisis']
# label_words_dict ['38C', 'disease']
# model_words_dict ['38C', 'hypersensitivity', 'morphine', 'NSAIDs', 'disease']
# label_words_dict ['Patient']
# model_words_dict ['Patient']
# NCT03555526
# NCT03555526
# label_words_dict ['after', 'allergy']
# model_words_dict []
# label_words_dict ['pregnancy']
# model_words_dict ['pregnancy', 'disease', 'cirrhosis']
# label_words_dict []
# model_words_dict ['or']
# NCT03560310
# NCT03560310
# label_words_dict ['CABG', 'procedure', 'Discharge', 'condition', 'indication', 'Debilitating']
# model_words_dict ['disease']
# label_words_dict ['inhibitors', 'intolerance', 'ticagrelor', 'disease', 'block', 'cyclosporine', 'ritonavir']
# model_words_dict ['STEMI', 'NSTEMI', 'warfarin', 'dabigatran', 'rivaroxaban', 'apixaban', 'heparin', 'heparin', 'Pregnancy', 'intolerance', 'ticagrelor', 'disease', 'dialysis', 'cyclosporine', 'ketoconazole', 'clarithromycin', 'nefazodone', 'ritonavir']
# label_words_dict ['condition', 'patients']
# model_words_dict ['patients']
# NCT03561753
# NCT03561753
# label_words_dict ['smear', 'lesion', 'DST', 'potential', 'to', 'intolerance', 'treatment', 'intolerance', 'studies', 'study']
# model_words_dict ['diagnosed', 'women', 'Willingness', 'visits', 'studies']
# label_words_dict ['diagnosed', 'rifampicin', 'Males', 'Serum', 'Serum', 'Serum', 'Serum', 'allergy', 'AST', 'Pregnant', 'females', 'pregnant', 'study', 'Suspected', 'system', 'bones', 'tuberculosis', 'infected', 'allergy', 'Current', 'incarceration']
# model_words_dict ['isoniazid', 'streptomycin', 'rifampicin', 'Males', 'Serum', 'AST', 'Serum', 'Serum', 'Serum', 'isoniazid', 'rifampin', 'EMB', 'PZA', 'CFZ', 'allergy', 'AST', 'Pregnant', 'females', 'pregnant', 'study', 'Suspected', 'system', 'bones', 'joints', 'tuberculosis', 'infected', 'allergy', 'Current', 'incarceration', 'start', 'studies']
# label_words_dict ['or', 'nonpregnant']
# model_words_dict ['and', 'or', 'nonpregnant', 'Pto', 'be', 'participation']
# NCT03589105
# NCT03589105
# label_words_dict ['lesion', 'MRI', 'contraindications', 'implanted', 'Gadolinium', 'causes', 'causes', 'disorders']
# model_words_dict ['RMS', 'ii', 'screening', 'women', 'period']
# label_words_dict ['clinical', 'lesion', 'new', 'attack', 'CNS', 'brain']
# model_words_dict ['clinical', 'lesion', 'new', 'kg', 'pacemaker', 'implants', 'eye', 'clips', 'stroke', 'attack', 'History', 'CNS', 'meningioma', 'History', 'History', 'syphilis', 'disease', 'HTLV1', 'myopathy', 'encephalopathy', 'acidosis', 'History', 'lupus', 'syndrome', 'syndrome', 'disease', 'brain', 'contusion']
# label_words_dict ['with']
# model_words_dict ['with', 'eg']
# NCT03615508
# NCT03615508
# label_words_dict []
# model_words_dict []
# label_words_dict []
# model_words_dict ['tamsulosin', 'terazosin', 'doxazosin', 'alfuzosin']
# label_words_dict []
# model_words_dict []
# NCT03619707
# NCT03619707
# label_words_dict ['cycles', 'reactions']
# model_words_dict []
# label_words_dict ['Primary']
# model_words_dict ['Primary', 'occlusion', 'factor', 'unexplained', 'endometriosis', 'disease', 'mellitus', 'hypertension', 'conditions']
# label_words_dict []
# model_words_dict []
# NCT03620526
# NCT03620526
# label_words_dict []
# model_words_dict ['Ee13']
# label_words_dict ['mLm2', 'females']
# model_words_dict ['symptoms', 'mLm2', 'males', 'females', 'septal']
# label_words_dict []
# model_words_dict []
# NCT03623789
# NCT03623789
# label_words_dict ['tendency', 'allergies']
# model_words_dict ['head', 'years']
# label_words_dict ['dysplasia', 'osteonecrosis', 'treatment', 'infection', 'disease', 'Coagulopathy']
# model_words_dict ['degeneration', 'arthritis', 'arthritis', 'dysplasia', 'treatment', 'infection', 'level', 'thrombosis', 'disease', 'acid', 'floseal', 'acid', 'floseal', 'rivaroxaban', 'Coagulopathy', 'cirrhosis', 'hemorrhage', 'bleeding']
# label_words_dict ['11gdl']
# model_words_dict ['11gdl']
# NCT03624517
# NCT03624517
# label_words_dict ['secondary', 'varices', 'Bleeding', 'method', 'hypertension', 'allergy']
# model_words_dict ['females', 'varices']
# label_words_dict ['males', 'Evidence', 'known', 'TIPS', 'Known']
# model_words_dict ['males', 'Evidence', 'known', 'transjugular', 'intrahepatic', 'TIPS', 'infarct', 'accident', 'sepsis', 'failure', 'Known']
# label_words_dict ['any']
# model_words_dict ['or', 'to', 'weeks']
# NCT03624881
# NCT03624881
# label_words_dict ['intolerable', 'ablation', 'thrombus', 'Contraindication', 'secondary', 'system', 'intervention', 'pregnant', 'test', 'abnormality']
# model_words_dict ['AF', 'replacement', 'Women']
# label_words_dict ['monitor', 'I', 'pre', 'valve', 'repair', 'stenting', 'heparin', 'clotting', 'months', 'months', 'III', 'mLbeat', '50', 'transplantation', 'constrictive', 'disease', 'disease', 'baffle', 'patch']
# model_words_dict ['monitor', 'AF', 'surgical', 'surgical', 'ventriculotomy', 'atriotomy', 'repair', 'stenting', 'heparin', 'clotting', 'PCI', 'failure', '50', 'transplantation', 'illness', 'infection', 'imbalance', 'disease', 'reversible', 'ICD', 'disease', 'constrictive', 'disease', 'disease', 'lungs', 'anomaly', 'device', 'biologic', 'thrombus', 'myxoma', 'tumor', 'baffle', 'patch', 'access']
# label_words_dict ['intervention']
# model_words_dict ['or', 'intervention', 'would', 'that']
# NCT03631355
# NCT03631355
# label_words_dict ['TTO']
# model_words_dict ['TTO']
# label_words_dict ['incompetent', 'Alzheimers', 'bleeding', 'Renal']
# model_words_dict ['incompetent', 'bleeding', 'disorder']
# label_words_dict []
# model_words_dict ['or']
# NCT03637946
# NCT03637946
# label_words_dict ['nonretentive']
# model_words_dict ['mm', 'enamel', 'mobility', 'GI']
# label_words_dict ['GI', 'mm', 'antibiotics', 'women']
# model_words_dict ['antibiotics', 'women', 'collection']
# label_words_dict ['hygiene']
# model_words_dict ['healthy', 'hygiene', 'a', 'be', 'noncarious', 'teeth', 'that']
# NCT03639519
# NCT03639519
# label_words_dict ['Allergy', 'Allergy', 'reaction']
# model_words_dict []
# label_words_dict ['allergic']
# model_words_dict ['allergic']
# label_words_dict []
# model_words_dict []
# NCT03639545
# NCT03639545
# label_words_dict []
# model_words_dict []
# label_words_dict ['kidney']
# model_words_dict ['heart', 'kidney']
# label_words_dict []
# model_words_dict ['infections']
# NCT03648021
# NCT03648021
# label_words_dict []
# model_words_dict ['Sedation', 'temperature']
# label_words_dict ['neurosurgery', 'temperature', 'paracetamol', 'ASAT', 'NSAIDs', 'paracetamol', 'Pregnant']
# model_words_dict ['neurosurgery', 'paracetamol', 'ASAT', '5N', 'corticosteroids', 'NSAIDs', 'paracetamol', 'Pregnant']
# label_words_dict []
# model_words_dict []
# NCT03663387
# NCT03663387
# label_words_dict ['baseline', 'depression', 'validity', 'failure', 'disease', 'Stroke', 'infarct']
# model_words_dict ['health', 'LP', 'Antidepressants', 'Razadyne', 'brain']
# label_words_dict ['Male', 'language', 'hypertension', 'Dementia', 'tests', 'memantine', 'Namenda', 'tumor', 'itself', 'structure', 'anterior', 'Hostility']
# model_words_dict ['Male', 'language', 'hypertension', 'LBD', 'Dementia', 'tests', 'Aricept', 'Exelon', 'Namenda', 'Sinemet', 'amantadine', 'bromocriptine', 'pergolide', 'enhancing', 'biloba', 'tumor', 'itself', 'radiation', 'structure', 'anterior', 'anterior', 'silent', 'strokes', 'Hostility']
# label_words_dict []
# model_words_dict ['are', 'are', 'are', 'disorders', 'will']

# %%
all_metrics
# Out:
# {' Naive greedy match (CHIA Prompt)': {'AND': {'precision': 6.897993311036789,
#    'recall': 66.3538873994638,
#    'f1': 12.496844231254734,
#    'accuracy': 66.3538873994638,
#    'total_label': 2238,
#    'total_model': 21777,
#    'correct_count': 1485,
#    'low_tp_ncts': ['NCT01214096', 'NCT02041299']},
#   'OR': {'precision': 26.174766655938203,
#    'recall': 75.21387283236994,
#    'f1': 38.834835551841465,
#    'accuracy': 75.21387283236994,
#    'total_label': 4325,
#    'total_model': 12637,
#    'correct_count': 3253,
#    'low_tp_ncts': []},
#   'NOT': {'precision': 33.50785340314136,
#    'recall': 53.333333333333336,
#    'f1': 41.157556270096464,
#    'accuracy': 53.333333333333336,
#    'total_label': 720,
#    'total_model': 1183,
#    'correct_count': 384,
#    'low_tp_ncts': ['NCT01490034']},
#   'average_missing_percentage': 1.2285005622588003,
#   'average_zuviel_percentage': 2.5148036950960035,
#   'total_missing_words': Counter({'and/or': 280,
#            '(including': 69,
#            '(as': 43,
#            'mg/dL': 40,
#            'kg/m2': 31,
#            '(or': 26,
#            'mg/dl': 25,
#            '(with': 25,
#            'g/dL': 22,
#            '(within': 20,
#            '(for': 18,
#            'mL/min': 18,
#            'ml/min': 17,
#            '(other': 14,
#            '(not': 14,
#            'ng/mL': 12,
#            '(no': 11,
#            'his/her': 11,
#            'mg/day': 9,
#            '>/=': 9,
#            '(by': 9,
#            'mmol/L': 9,
#            'IU/L': 9,
#            'kg/m2.': 9,
#            'mmol/mol': 9,
#            'mg/day,': 7,
#            '(without': 7,
#            'parent/guardian': 7,
#            'mg/dL)': 6,
#            'FEV1/FVC': 6,
#            'cells/mm3': 6,
#            'g/dl': 6,
#            'IU/ml': 6,
#            'ml/min)': 6,
#            'µmol/L': 6,
#            'mg/dl),': 5,
#            'copies/mL': 5,
#            'mL/min/1.73': 5,
#            'mg/dL.': 5,
#            '(according': 5,
#            'mmol/l': 5,
#            '(that': 5,
#            'kg/m2)': 5,
#            'he/she': 5,
#            'mg/dl)': 5,
#            'inclusion/exclusion': 4,
#            '(due': 4,
#            'parent/legal': 4,
#            'moderate-to-severe': 4,
#            '</=': 4,
#            '20/200': 4,
#            'g/L': 4,
#            '(must': 4,
#            'pg/ml': 4,
#            '140/90': 3,
#            'mEq/L': 3,
#            'ml/min/1.73m2': 3,
#            '(but': 3,
#            'kg/m2,': 3,
#            '1,000/µL': 3,
#            '(and/or': 3,
#            '(are)': 3,
#            '/aggression': 3,
#            'ng/ml': 3,
#            '<or=6': 3,
#            'cervical/vault': 3,
#            'allergy/sensitivity': 3,
#            'g/dL)': 3,
#            's/p': 3,
#            'g/dl,': 3,
#            'relapsed/refractory': 3,
#            '(of': 3,
#            'mg/g': 3,
#            'ml/min/1.73': 3,
#            '0/7': 3,
#            'mg/dl,': 3,
#            '(may': 3,
#            '109/L': 3,
#            'mmol/mol)': 3,
#            'with/without': 3,
#            'mL/min,': 3,
#            'consent/assent': 3,
#            '(to': 3,
#            'IU/mL.': 3,
#            'Baseline/Day': 3,
#            '10^9/L': 2,
#            'mL/min)': 2,
#            'chemo/radiotherapy': 2,
#            'kg/m^2': 2,
#            'parents/guardians': 2,
#            'mmol/L)': 2,
#            'mg/day).': 2,
#            '135/85': 2,
#            '170/105': 2,
#            '(requiring': 2,
#            'cc/min.': 2,
#            '(during': 2,
#            'mg/m^2;': 2,
#            '1/2': 2,
#            '20,000/µL': 2,
#            'pelvic/speculum': 2,
#            'disease-free': 2,
#            'IU/mL': 2,
#            'mg/dL,': 2,
#            '30mUI/ml': 2,
#            'Karnofsky/Lansky': 2,
#            'post-albuterol/salbutamol': 2,
#            'albuterol/salbutamol': 2,
#            'Drug/alcohol': 2,
#            'ICS/LABA': 2,
#            'y/o.': 2,
#            'medical/psychiatric': 2,
#            'finger/thumb': 2,
#            'PSA<or=10': 2,
#            'infection/inflammation': 2,
#            'U/L)': 2,
#            'treatment-naive': 2,
#            '109/l,': 2,
#            'mmol/L;': 2,
#            '60ml/min/1.73m2': 2,
#            'min/wk': 2,
#            'IVF/ICSI': 2,
#            'drug-free': 2,
#            'screening/baseline': 2,
#            'umol/ml': 2,
#            '(140-159/90-99': 2,
#            'right-to-left,': 2,
#            'right-to-left': 2,
#            'AND/OR': 2,
#            'mIU/mL': 2,
#            '3mg/dl': 2,
#            'anovulation/oligoovulation.': 2,
#            '(pg/mL)': 2,
#            'drug/alcohol': 2,
#            'seizures/week': 2,
#            'illness/social': 2,
#            'fibrillation/flutter': 2,
#            'kg/m²': 2,
#            '[including': 2,
#            '(+/-': 2,
#            '(and': 2,
#            '20/320': 2,
#            '20/25': 2,
#            '100,000/mm3': 2,
#            '150/95': 2,
#            'mg/kg/day': 2,
#            'III/IV': 2,
#            'trial/study': 2,
#            'willing/able': 2,
#            '160/90': 2,
#            'Kg/m2': 2,
#            '(AST/ALT': 2,
#            ',including': 2,
#            'million/ml': 2,
#            'ml/min).': 2,
#            'HIV/HCV': 2,
#            'pregnancy/breastfeeding)': 2,
#            '3km/h': 2,
#            '(~0.8m/s)': 2,
#            'unwilling/unable': 2,
#            'mg/dl;': 2,
#            'case-by-case': 2,
#            'albumin/creatinine': 2,
#            'mL/kg/min)': 2,
#            'h/o': 2,
#            'R/R': 2,
#            'cells/L.': 2,
#            'mL/minute': 2,
#            'mU/L': 2,
#            'electrocardiogram/hepatic': 2,
#            'function/blood': 2,
#            'gastric/duodenal': 2,
#            'Board/Ethical': 2,
#            'K/cumm': 2,
#            'ng/dL)': 2,
#            'ml/min/1,73': 2,
#            'm/s)': 2,
#            '>140/90': 2,
#            '(FEV1/FVC': 2,
#            'g/dL).': 2,
#            '40/100': 2,
#            'beats/min': 2,
#            '(200mg/dl),': 2,
#            'g/m2': 2,
#            'treatment-free': 1,
#            '(M1)/stage': 1,
#            'product/device': 1,
#            'alcohol/substance': 1,
#            'biopsy/resection': 1,
#            '1,500/mm3,': 1,
#            'gm/dl,': 1,
#            '50,000/mm3.': 1,
#            'pmol/L).': 1,
#            'condition/illness': 1,
#            '(>/=': 1,
#            'Had/have': 1,
#            'prior/concurrent': 1,
#            'drugs/agents': 1,
#            'sulfonylurea/metformin': 1,
#            'kg/m^2.': 1,
#            '≥1,500/µL,': 1,
#            'g/dL,and': 1,
#            '≥100,000/µL)': 1,
#            '(but,': 1,
#            'ml/minute.': 1,
#            'mmol/L).': 1,
#            'mIU/mL;': 1,
#            'mIU/mL.': 1,
#            '100.000/µl': 1,
#            '<30ml/min)': 1,
#            '(ALT)/aspartate': 1,
#            '>1g/day': 1,
#            '2.0mg/dL': 1,
#            'gastrointestinal/rectal': 1,
#            'function/injury': 1,
#            'runny/blocked/itchy': 1,
#            '(NINCDS/ADRDA)': 1,
#            'FEV1/Inspiratory': 1,
#            '50ug/hr': 1,
#            'Tramadol/Acetaminophen': 1,
#            '(ng/ml):': 1,
#            '>_3500/mm3,': 1,
#            '>_100,000/mm3.': 1,
#            'III/IV),or': 1,
#            '(Benadryl®)for': 1,
#            'ALT/AST>3x': 1,
#            'probability(by': 1,
#            '(BMI=40kg/m2)': 1,
#            '120mg/m^2': 1,
#            'mg/m^2.': 1,
#            'disease(with': 1,
#            'Melan-A/MART-1': 1,
#            '10.5g/dl,': 1,
#            'corticosteroids/other': 1,
#            'beats/min),': 1,
#            '11.5g/dL': 1,
#            '[BCR/ABL+]': 1,
#            '[MLL/AF4+].': 1,
#            '0-to-10': 1,
#            'sensitivity/allergy': 1,
#            '<60/min': 1,
#            '<30,000/mm3': 1,
#            'QT/QTc': 1,
#            'dementia/cognitive': 1,
#            'IU/mL)': 1,
#            'cells/μL': 1,
#            'cells/μL).': 1,
#            'Gms/dL.': 1,
#            'chemo/radiation': 1,
#            '>1,500/microL': 1,
#            '>100,000/microL': 1,
#            'national/local': 1,
#            'allergy/hypersensitivity': 1,
#            '<60mL/min': 1,
#            'Board/Ethics': 1,
#            'cells/mm3.': 1,
#            '150µmol/L).': 1,
#            'psychotropics(with': 1,
#            'HIV/AIDS).': 1,
#            'patient/guardian.': 1,
#            'Patient/guardian': 1,
#            ',or': 1,
#            '/dl,': 1,
#            'potassium<3.2mmol/L,': 1,
#            'or>5.5mmol/L;': 1,
#            'scar/change': 1,
#            'inflammation/infection': 1,
#            'disease(ESRD)/chronic': 1,
#            'Hb<10g/dL': 1,
#            'count<100,000/μL': 1,
#            '(FEV1)/(forced': 1,
#            ')with': 1,
#            'moderate/severe': 1,
#            'diseases/abnormalities:': 1,
#            'Drug/food': 1,
#            'kg/m2;': 1,
#            'weight(Kg)/height(m2).': 1,
#            '<1,500/mm3)': 1,
#            '90,000/mm3)': 1,
#            'g/day),': 1,
#            'orphans/vulnerable': 1,
#            '[IRB]/Independent': 1,
#            '1x/wk': 1,
#            'min/session': 1,
#            'lamivudine/adefovir': 1,
#            'IU/ml)': 1,
#            'mg/dl.': 1,
#            '(BCR/ABL)': 1,
#            '<or=10': 1,
#            'cancer,or': 1,
#            'chemotherapy,and': 1,
#            'creatinine(>1.5mg/dl)': 1,
#            '20mg/d),': 1,
#            '40mg/d),': 1,
#            '50mg/d),': 1,
#            '150mg/d),': 1,
#            '45mg/d),': 1,
#            '60mg/d)': 1,
#            'ER(150-225mg/d)': 1,
#            'cells/mm3if': 1,
#            'cells/mm3or': 1,
#            '<30mL/minute': 1,
#            'CYP3A4/P-glycoprotein': 1,
#            '(AST/ALT>2x': 1,
#            'ng/mL.': 1,
#            '20/70;': 1,
#            'cells/mm3,': 1,
#            'simvastatin/lovastatin': 1,
#            'cells/mm3),': 1,
#            'cells/mm3)': 1,
#            'mg/l': 1,
#            'cord/cauda': 1,
#            'd/α/β),': 1,
#            'α/β': 1,
#            '75,000/ml': 1,
#            '9gm/dl': 1,
#            '3.5/ml': 1,
#            'negative/HBcAb': 1,
#            'positive/hepatitis': 1,
#            'at/above': 1,
#            'ERCP/PTC': 1,
#            '(have': 1,
#            'foam/gel/film/cream/vaginal': 1,
#            '<24/30': 1,
#            'left/right': 1,
#            '(who': 1,
#            'events/hour': 1,
#            '(>170/>110)': 1,
#            '180/100': 1,
#            'DDAVP/Stimate': 1,
#            'IIIB/IV': 1,
#            'EGF/EGFR': 1,
#            '9g/dl,': 1,
#            'studies/registries': 1,
#            'knee/hip': 1,
#            '<100,000/mm3': 1,
#            '5-fluorouracil/leucovorin': 1,
#            '(5-FU/LV)': 1,
#            'parent/legally': 1,
#            'illness/infection': 1,
#            'DoD/VA': 1,
#            '(besides': 1,
#            'm/sec': 1,
#            '140/90,': 1,
#            'equivalent/L': 1,
#            '1)or': 1,
#            'cerebral/meningeal': 1,
#            'rest/ice': 1,
#            'skin/soft': 1,
#            'skin/soft-tissue': 1,
#            '100.000/µL': 1,
#            'L/d),': 1,
#            'rifampin/rifampicin,': 1,
#            '100µg/l': 1,
#            'µg/l,': 1,
#            'mg/L,': 1,
#            'HIV/AIDS.': 1,
#            'Oligomenorrhea/amenorrhea': 1,
#            'CLL/SLL': 1,
#            '1-3A/iNHL,': 1,
#            'LPL/WM,': 1,
#            'CLL/SLL,': 1,
#            'MF/SS)': 1,
#            '/refractory': 1,
#            'CT/PET': 1,
#            '1000/uL': 1,
#            '75,000/uL,': 1,
#            '20.0mg/dL': 1,
#            'AST/AST': 1,
#            'HIV/Hep': 1,
#            'gastric/bowel': 1,
#            '<150/95mmHg': 1,
#            '=135/85': 1,
#            '<150/95.': 1,
#            '(ALT/AST>50IU/L)': 1,
#            'durg-naive': 1,
#            'NK/T-cell': 1,
#            'ml/h)': 1,
#            '100.000/mm3;': 1,
#            'gm/day)': 1,
#            'ER/PR': 1,
#            '(20g/day': 1,
#            '30g/day': 1,
#            'aminotransferase/alanine': 1,
#            'planing/being': 1,
#            '159/99': 1,
#            'or/and': 1,
#            'B/C': 1,
#            'ANC>1000/mcl': 1,
#            'platelets>100,000/mcl.': 1,
#            'yes/no': 1,
#            'weeks)/low': 1,
#            'mL/kg': 1,
#            'mg/kg/d': 1,
#            'PET/MRI': 1,
#            'ng/dl': 1,
#            'milliunits/milliliter': 1,
#            '(mU/mL)': 1,
#            '(renal/hepatic': 1,
#            'Current/recent': 1,
#            'parents/patients.': 1,
#            'Mild-to-moderate': 1,
#            '6/7': 1,
#            '50mg/dl': 1,
#            '80U/L': 1,
#            'artifacts/components': 1,
#            '(absence': 1,
#            'is/are': 1,
#            "investigator's/designee's": 1,
#            '(MlU/mL)': 1,
#            '60mL/min/1.73m2)': 1,
#            'equivalents/day.': 1,
#            'beats/minute': 1,
#            'parent/guardian.': 1,
#            'tooth)of': 1,
#            'medical/surgical': 1,
#            'bleeding/clotting': 1,
#            'substance/alcohol': 1,
#            'disease/inflammation': 1,
#            '01/01/2010': 1,
#            '30/09/2013': 1,
#            'attempt/week)': 1,
#            'ng/dL,': 1,
#            'difficult-to-detect': 1,
#            'height/weight': 1,
#            '2400/microl,': 1,
#            'amphetamine/methamphetamine,': 1,
#            'ADHD/LD': 1,
#            'g/dL])': 1,
#            'TPV/r': 1,
#            'Hgb<11g/dL,': 1,
#            'Hct<30g/dL,': 1,
#            '>240mg/dL,': 1,
#            '>500mg/dL,': 1,
#            '>130mg/dL,': 1,
#            'µmol/l)': 1,
#            '<150,000/mm3': 1,
#            '[kilogram(kg)]/height^2': 1,
#            'kg/m^2,': 1,
#            'foam/gel/film/cream/suppository': 1,
#            'foam/gel/film/cream/suppository,': 1,
#            '=(mPAP-PCWP)/CO]>3.0': 1,
#            'count<100,000/L': 1,
#            '<1g/L': 1,
#            'differentiated/de-differentiated': 1,
#            'sarcoma/MFH': 1,
#            'CT/MRI': 1,
#            'asthma/atopy': 1,
#            'nursing/breastfeeding.': 1,
#            '10^9/Liter': 1,
#            '10^9/L,': 1,
#            'gram/deciliter': 1,
#            '(g/dL).': 1,
#            'arterial/venous': 1,
#            '/In': 1,
#            'µmol/L)': 1,
#            'copies/ml': 1,
#            'mmol/L,': 1,
#            'systolic/diastolic': 1,
#            '=128/78': 1,
#            '30ml/min).': 1,
#            'DSM-IV/V': 1,
#            '/5),': 1,
#            'ICD-10/DSM-IV/V,': 1,
#            '(ACC/AHA': 1,
#            'cell/mL),': 1,
#            'g/dL),': 1,
#            'cell/mL).': 1,
#            '20/50': 1,
#            'intravitreal/periocular': 1,
#            'complications/vitreous': 1,
#            'Pd/Pa': 1,
#            'Pd/Pa)': 1,
#            '1250/ul': 1,
#            '100,000/ul': 1,
#            '*28/*28': 1,
#            'ALT/AST': 1,
#            'Allergy/hypersensitivity': 1,
#            'Subject/Caregiver': 1,
#            '(BP>140/90': 1,
#            'x109/L': 1,
#            'severe/unstable': 1,
#            'coronary/peripheral': 1,
#            '=7mmol/l': 1,
#            '=11mmol/l': 1,
#            '7.0mmol/L': 1,
#            '48mmol/mol);': 1,
#            '130µmol/L/': 1,
#            '4.0ng/mL': 1,
#            '1.7mg/dL': 1,
#            'anesthesia/procedures': 1,
#            '20/30': 1,
#            'hours/day': 1,
#            'hours/day)': 1,
#            'clotting/coagulation': 1,
#            'ml/min),': 1,
#            '<100,000/µL': 1,
#            'mmol/l))': 1,
#            'clearance>50ml/min': 1,
#            '(in': 1,
#            '<140/90': 1,
#            'drug/solvent': 1,
#            'platinum-free': 1,
#            'AST/ALT:': 1,
#            'anti-PD1/anti-PD-L1': 1,
#            'Desire/intent': 1,
#            'trimethoprim/sulphamethoxazole': 1,
#            'piperacillin/tazobactam)': 1,
#            '=/>130': 1,
#            'LDL=/>130': 1,
#            '=/>150': 1,
#            'close/intimate': 1,
#            'days/week': 1,
#            'drinks/day)': 1,
#            'cells/µL,': 1,
#            'moderate/good': 1,
#            'eGFR=60(ml/min/1.73': 1,
#            '2/3': 1,
#            'parent/care': 1,
#            '500/µL.': 1,
#            '(E/CIA)': 1,
#            'E/CIA,': 1,
#            'E/CIA': 1,
#            '(TAF)/TAF-containing': 1,
#            '(COBI)/COBI-containing': 1,
#            'TAF/TAF-containing': 1,
#            'COBI/COBI-containing': 1,
#            'copies/mL.': 1,
#            '500/mm^3': 1,
#            '40,000/mm^3': 1,
#            'www.fstrf.org/ACTG/ccc.html': 1,
#            'signs/symptoms': 1,
#            ')/T': 1,
#            'test:WBC=3.0×109/L,Neutrophils=1.5×109/L,Hb=100g/L,Platelet=80×109/L;': 1,
#            'mg/m2,': 1,
#            'mg/m2;': 1,
#            'mol/L': 1,
#            '[no': 1,
#            'study/trial': 1,
#            'agonist/antagonist': 1,
#            '(polyester/ethyl': 1,
#            'DAS28/Erythrocyte': 1,
#            'dapsone-naive.': 1,
#            '1-4h,and': 1,
#            '<50/min.': 1,
#            '/min': 1,
#            '/1,73m),': 1,
#            'evenings/nights': 1,
#            'BMI-for-age': 1,
#            'diseases/drugs': 1,
#            'packs/year': 1,
#            '20/70': 1,
#            'hypotension/capillary': 1,
#            'leak/life': 1,
#            'Pregnant/breast-feeding': 1,
#            'schizophrenia/schizoaffective': 1,
#            'Spontaneous/Induced/Augmented': 1,
#            'H/o': 1,
#            '<or=': 1,
#            '(Ag/Ab': 1,
#            '>140/90,': 1,
#            '+/-': 1,
#            '30Kg/m2': 1,
#            '30ml/min/1.73m2),': 1,
#            'stroke/TIA': 1,
#            'U/L),': 1,
#            '<2.2mg/dl,': 1,
#            'pain(including': 1,
#            'ventilation/perfusion': 1,
#            'overload/dysfunction': 1,
#            'mg/day;': 1,
#            'volume/Forced': 1,
#            'medications/materials:': 1,
#            'acquired/inherited': 1,
#            'IgG/IgM,': 1,
#            'mild/moderate': 1,
#            '(>1/40': 1,
#            '=/>': 1,
#            'cardiovascular/pulmonary': 1,
#            'mmol/mol.': 1,
#            'mmol/l).': 1,
#            'g/l)': 1,
#            'ml/mn': 1,
#            'acid/Cyklokapron®': 1,
#            'III/IV±V': 1,
#            '(ISN/RPS': 1,
#            'protein/creatinine': 1,
#            'micromol/L': 1,
#            'mg/D': 1,
#            'g/D': 1,
#            'g/L,': 1,
#            'g/L)': 1,
#            'haemoglobinopathy/thalassaemia': 1,
#            'trauma/surgery': 1,
#            'abuse/dependence': 1,
#            'CVA/TIA': 1,
#            'Accident/Transient': 1,
#            '(AST)/Alanine': 1,
#            'milliliters/minute/1.73': 1,
#            'arthritis/autoimmune': 1,
#            'mL/min/1.7m2': 1,
#            'mg/day),': 1,
#            '<20/200.': 1,
#            'dyn•s/cm5': 1,
#            'WHO/NYHA-FC': 1,
#            'systemic-to-pulmonary': 1,
#            'disorders/symptoms': 1,
#            'Significant/chronic': 1,
#            'ml/min;': 1,
#            'g/l;': 1,
#            'g/l': 1,
#            'cels/mm3': 1,
#            'cels/mm3;': 1,
#            '20-of': 1,
#            '20/40': 1,
#            'Inclusion/exclusion': 1,
#            'III/IV)': 1,
#            'fusion/other': 1,
#            '109/L,': 1,
#            '9g/dL,': 1,
#            'AST/ALT': 1,
#            'stools/24': 1,
#            'apnea/hypopnea': 1,
#            '10/hour;': 1,
#            '1hour/day;': 1,
#            '/L.': 1,
#            '109/L.': 1,
#            '9g/dL.': 1,
#            'ml/min.': 1,
#            'HBV/HIV': 1,
#            '[or': 1,
#            'parent/guardian]': 1,
#            '3.5g/dl,': 1,
#            '1.5mg/dl': 1,
#            '5.0mg/dl': 1,
#            '1a/ab.': 1,
#            'Baseline/Day1': 1,
#            '/min,': 1,
#            'LDV/SOF': 1,
#            '<30x109/l': 1,
#            '30x109/l': 1,
#            '50mL/min': 1,
#            'aminotransferase)/ALT(alanine': 1,
#            'hours/day.': 1,
#            '1km/day.': 1,
#            '8hours/day': 1,
#            'mg/kg/day,': 1,
#            '180/110': 1,
#            'disorder/diathesis': 1,
#            'cc/day': 1,
#            '>10mg/day': 1,
#            '(weight-for-height': 1,
#            '<4000/uL,': 1,
#            '<9g/dl': 1,
#            '/l': 1,
#            'vaccine/placebo,': 1,
#            'patients,with': 1,
#            'lesions,according': 1,
#            '10mm,on': 1,
#            '2×10^9/L': 1,
#            '100×10^9/L': 1,
#            'g/dL;': 1,
#            'mL/min;': 1,
#            'mg/g,': 1,
#            'mg/day)': 1,
#            'mIU/ml': 1,
#            'mg/dL.)': 1,
#            'mL/min),': 1,
#            'injections/or': 1,
#            'protocol-excluded': 1,
#            '(joint/musculoskeletal,': 1,
#            'BMI>=35kg/m2': 1,
#            'SOF/LDV': 1,
#            'tipranavir/ritonavir': 1,
#            '50,000/mm3': 1,
#            'mL/min.': 1,
#            'nucleoside/nucleotide': 1,
#            'Pa02/Fi02': 1,
#            'Pre-existing/chronic': 1,
#            '100,000/ml': 1,
#            'ng/mg': 1,
#            'procedures/treatments.': 1,
#            'tooth/teeth': 1,
#            'endodontic/periodontal': 1,
#            'units/day.': 1,
#            'assay)or': 1,
#            'transaminase/alkaline': 1,
#            '(AST/ALT)': 1,
#            '≥10000UI/mL.': 1,
#            'mg/d).': 1,
#            'g/dL.': 1,
#            '3g/dL.': 1,
#            'including(but': 1,
#            'mg/d,': 1,
#            'mg/d.': 1,
#            'U/S': 1,
#            'Hemosiderosis/hemochromatosis': 1,
#            'than/equals': 1,
#            'prednisone/prednisolone': 1,
#            '3g/dL': 1,
#            'next-of-kin).': 1,
#            'osteomyelitis/septic': 1,
#            '150,000/mmc.': 1,
#            'g/day': 1,
#            'Intolerance/allergy': 1,
#            'Exposure/treatment': 1,
#            'periorbital/forehead': 1,
#            'breaths/minute': 1,
#            'head-of-bed': 1,
#            'mg/kg/h': 1,
#            'an/or': 1,
#            '(on': 1,
#            '<2.0g/dL': 1,
#            '>2.0mg/dL': 1,
#            '>18gm/dL': 1,
#            '<7gm/dL': 1,
#            'BNP>300pg/ml': 1,
#            'injury/failure': 1,
#            'miscarriage/abortion': 1,
#            'obstruction/blockage': 1,
#            'bowel/rectal': 1,
#            '15/15': 1,
#            '45kg/m2': 1,
#            'frequency/severity': 1,
#            'HA-free': 1,
#            'sedative/hypnotics),': 1,
#            '"as-needed"': 1,
#            '40g/day)': 1,
#            "SSRIs/SNRI's": 1,
#            'thrombophilia/thrombosis': 1,
#            'OB/GYN': 1,
#            '35kg/m2': 1,
#            "E/E'": 1,
#            '120/min.': 1,
#            'University/Barnes-Jewish': 1,
#            'gram/day': 1,
#            'g/l),': 1,
#            'speaking/literate': 1,
#            'speaking/illiterate': 1,
#            '150,000/cubic': 1,
#            'autoimmune/inflammatory': 1,
#            '145/90': 1,
#            'IU/l': 1,
#            'ng/l': 1,
#            '(IUD/IUS)': 1,
#            'infection/year': 1,
#            '(MI/heart': 1,
#            'pg/mL)': 1,
#            'drinks/week)': 1,
#            '12g/dL': 1,
#            'SGOT/SGPT': 1,
#            '1000cp/ml': 1,
#            '1mg/kg/d': 1,
#            'HBV/HCV/HIV': 1,
#            '(dronabinol/marijuana/cannabis/THC,': 1,
#            'acceleration/deceleration': 1,
#            'shrapnel/retained': 1,
#            'alcohol/drug': 1,
#            '<15mmol/L(270mg/dL)': 1,
#            'm/s': 1,
#            'Patients/physicians': 1,
#            'situations/substance': 1,
#            'Oral/Oropharynx': 1,
#            '60mg/day': 1,
#            'mL/h': 1,
#            'mL/injection': 1,
#            'mL/h)': 1,
#            'allergy/contra-indication': 1,
#            'neuropathy/sensory': 1,
#            'm/s,': 1,
#            'drinks/day': 1,
#            'hepatocellular/cholangiocarcinoma': 1,
#            'y/o': 1,
#            'maintenance/extended-use': 1,
#            '1,000/mcL': 1,
#            '75,000/mcL': 1,
#            'Moderate/Weak': 1,
#            'point-of-care': 1,
#            'T2/FLAIR': 1,
#            'FA/ICGA': 1,
#            'and/or,': 1,
#            'PO/NG': 1,
#            '5mg/ml,': 1,
#            '-10mIU/L,': 1,
#            'ml/min/1.73m2).': 1,
#            'U/L).': 1,
#            '20/32': 1,
#            'or/discharge': 1,
#            'of/suspected': 1,
#            'Allergy/intolerance': 1,
#            'husband/wife,': 1,
#            '5ng/mL': 1,
#            'nephropathy/retinopathy/neuropathy': 1,
#            'spondylolisthesis/spondylosis/spondylolysis': 1,
#            'Immunosuppressed/immune': 1,
#            'Allergy/interlerance': 1,
#            'units/week,': 1,
#            'units/week.': 1,
#            'read/understand': 1,
#            'beat/min': 1,
#            'bigemini/trigeminy': 1,
#            'mmol/L.': 1,
#            'finger/fingers': 1,
#            '(Xiapex/Xiaflex': 1,
#            'cell=3.5×109/L,': 1,
#            '=1.5×109/L,': 1,
#            '=80g/L,': 1,
#            'platelet>100×109/L;': 1,
#            '50ml/min': 1,
#            '3g/dl': 1,
#            '103/mL': 1,
#            '5mIU/mL)': 1,
#            'UI/ml': 1,
#            '250mg/dL': 1,
#            '=70mg/dL': 1,
#            '160mg/dL': 1,
#            'TG<500mg/dL': 1,
#            'ml/min,': 1,
#            'consent/refusal': 1,
#            '30ml/min)': 1,
#            "Stroke/Alzheimer's": 1,
#            'Severe/untreated': 1,
#            'mg/dL).': 1,
#            'pg/mL': 1,
#            'IIb/IIIa': 1,
#            '<80x106/mL': 1,
#            'ml/min/': 1,
#            'mL/min/1.73m2.': 1,
#            'parental/patient': 1,
#            'Pregnancy/breastfeeding': 1,
#            'do-not-resuscitate': 1,
#            'Pregnant/lactating': 1,
#            'Roche/Genentech': 1,
#            'Sensistivity/allergy': 1,
#            'U/L': 1,
#            'µmol/L,': 1,
#            '[m/s],': 1,
#            'calories/day)': 1,
#            'mmol/mol).': 1,
#            'Unstable/rapidly': 1,
#            'donation/blood': 1,
#            'Interleukin-12/23': 1,
#            '(IL-12/23),': 1,
#            'its/their': 1,
#            'opioids/opiates,': 1,
#            '(>160/100mmHg)': 1,
#            '(<40mg/dl': 1,
#            'overweight/lean': 1,
#            'moderate/high': 1,
#            'times/week).': 1,
#            '(>160/100': 1,
#            'leg/back': 1,
#            'L5/S1,': 1,
#            'bowel/bladder': 1,
#            'chemical/alcohol': 1,
#            'Aripiprazole>30mg/day,': 1,
#            'Olanzapine>20mg/day,': 1,
#            '6mg/day,': 1,
#            '750mg/day)': 1,
#            'smoked/20]': 1,
#            'ICS/LABA)': 1,
#            'RELVAR/BREO': 1,
#            'Salbutamol/Albuterol': 1,
#            'hypersensitivity/intolerance': 1,
#            'disease/condition': 1,
#            '<100g/L;': 1,
#            'pack/day': 1,
#            'FEV1/FVC>0.70': 1,
#            '(ICSI)/Fertilization': 1,
#            '(IU/L)': 1,
#            '(ng/mL)': 1,
#            '(kg/m^2)': 1,
#            'O/Randomization)': 1,
#            'picogram/milliliter': 1,
#            '0/Randomization)': 1,
#            '[ESHRE]/American': 1,
#            'SOF/VEL': 1,
#            'drugs(including': 1,
#            'Overweight/Obese': 1,
#            '=140/90': 1,
#            'g/dl)': 1,
#            '30g/L);': 1,
#            '200umol/L;': 1,
#            '150/100': 1,
#            '6mg/ml': 1,
#            'tobacco/nicotine': 1,
#            '32kg/m2).': 1,
#            '(PO/IV/IM)': 1,
#            'vaccine/product': 1,
#            'Emergent/elective': 1,
#            'HCV/HBV': 1,
#            '105/mm3;': 1,
#            '(2.7mmol/L);': 1,
#            'race/ethnicity,': 1,
#            'pharmacokinetic/pharmacodynamics': 1,
#            'methylprednisolone/prednisone': 1,
#            'pmol/L': 1,
#            'ng/dL': 1,
#            'parent(s)/legally': 1,
#            'parent/LAR': 1,
#            '5.6mmol/L': 1,
#            '(100mg/dl)=FPG<7.0mmol/L': 1,
#            '(126mg/dl),': 1,
#            '7.8mmol/L': 1,
#            '(140mg/dl)=OGTT': 1,
#            'PG<11.1mmol/L': 1,
#            '(39-47mmol/mol);': 1,
#            '2.6mmol/L': 1,
#            '(100mg/dl)=LDL-C=5.2mmol/L': 1,
#            'TG<5.7mmol/L': 1,
#            '(500mg/dl);': 1,
#            'male<120ml/min,': 1,
#            'female<105ml/min,': 1,
#            'creatinine=2mg/dl': 1,
#            '(186umol/L),': 1,
#            '3sessions/wk.': 1,
#            '6/10': 1,
#            'hypersensitivity/allergy': 1,
#            '5/10': 1,
#            'meq/L': 1,
#            '>/=18': 1,
#            'terazosin/doxazosin/alfuzosin/silodosin)': 1,
#            'pg/ml)': 1,
#            'mL/m2': 1,
#            "(E/e'=13": 1,
#            'cm/s).': 1,
#            '11g/dl,': 1,
#            'ml/min/1.73m2)': 1,
#            'surgical/percutaneous': 1,
#            'PCI/MI': 1,
#            'mL/beat,': 1,
#            'ICD/CRT-D.': 1}),
#   'total_zuviel_words': Counter({'or': 317,
#            '(': 305,
#            'and/': 284,
#            'mg/': 137,
#            'dL': 78,
#            'including': 75,
#            'kg/': 63,
#            'L': 58,
#            'g/': 57,
#            'min': 44,
#            'mL/': 43,
#            'as': 43,
#            'ml/': 43,
#            'dl': 42,
#            'm2': 40,
#            'mmol/': 37,
#            'with': 29,
#            'ml': 28,
#            'mL': 26,
#            'min/': 26,
#            'day': 23,
#            'ng/': 23,
#            'IU/': 23,
#            'within': 20,
#            'for': 19,
#            'cells/': 17,
#            'other': 16,
#            'parent/': 16,
#            'l': 15,
#            '=': 14,
#            'not': 14,
#            '20/': 14,
#            'dl,': 13,
#            'no': 13,
#            'mm3': 13,
#            'min)': 12,
#            'dL)': 12,
#            '/': 12,
#            'day,': 11,
#            '90': 11,
#            'his/': 11,
#            'her': 11,
#            'L,': 11,
#            'dL,': 10,
#            '>/': 10,
#            'by': 10,
#            'without': 10,
#            '1.73': 10,
#            'dL.': 9,
#            'm2.': 9,
#            'µmol/': 9,
#            'mol': 9,
#            'dl),': 8,
#            'L)': 8,
#            'FEV1/': 8,
#            'FVC': 8,
#            'mL)': 8,
#            'guardian': 8,
#            'free': 7,
#            'mL.': 7,
#            'µL': 7,
#            'copies/': 7,
#            'L;': 7,
#            'dl)': 7,
#            '109/': 7,
#            'day)': 7,
#            'min,': 7,
#            'pg/': 7,
#            'and': 6,
#            'min.': 6,
#            'm2)': 6,
#            'alcohol': 6,
#            'd),': 6,
#            'U/': 6,
#            'according': 6,
#            'exclusion': 5,
#            'mIU/': 5,
#            '1.73m2': 5,
#            'III/': 5,
#            'allergy/': 5,
#            'HIV/': 5,
#            '<': 5,
#            'minute': 5,
#            '100': 5,
#            'm/': 5,
#            'of': 5,
#            'that': 5,
#            'he/': 5,
#            'she': 5,
#            'L.': 5,
#            '10^9/': 4,
#            'L).': 4,
#            '140/': 4,
#            'inclusion/': 4,
#            'but': 4,
#            'beats/': 4,
#            'm2,': 4,
#            '1,000/': 4,
#            'allergy': 4,
#            'due': 4,
#            'salbutamol': 4,
#            'legal': 4,
#            'moderate-': 4,
#            'to-severe': 4,
#            '(AST/': 4,
#            '</': 4,
#            'refractory': 4,
#            '200': 4,
#            'right-': 4,
#            '0/': 4,
#            '7': 4,
#            'day.': 4,
#            '[': 4,
#            'dL).': 4,
#            '100,000/': 4,
#            'must': 4,
#            'consent/': 4,
#            'o': 4,
#            'Baseline/': 4,
#            'h': 4,
#            's)': 4,
#            'treatment-': 3,
#            'chemo/': 3,
#            'mm3,': 3,
#            'mm3.': 3,
#            'm^2': 3,
#            'parents/': 3,
#            '100.000/': 3,
#            '85': 3,
#            'mEq/': 3,
#            'function/': 3,
#            'cc/': 3,
#            'min),': 3,
#            'are)': 3,
#            'Board/': 3,
#            'aggression': 3,
#            ',': 3,
#            'chronic': 3,
#            'moderate/': 3,
#            'Drug/': 3,
#            'ICS/': 3,
#            'mm3)': 3,
#            'wk': 3,
#            'y/': 3,
#            'medical/': 3,
#            'finger/': 3,
#            'or=6': 3,
#            'or=10': 3,
#            'infection/': 3,
#            'inflammation': 3,
#            '75,000/': 3,
#            'naive': 3,
#            'cervical/': 3,
#            'vault': 3,
#            'foam/': 3,
#            'gel/': 3,
#            'film/': 3,
#            'cream/': 3,
#            'sensitivity': 3,
#            'IV': 3,
#            'l,': 3,
#            '9g/': 3,
#            's/': 3,
#            'p': 3,
#            'illness/': 3,
#            'relapsed/': 3,
#            'AST/': 3,
#            'gastric/': 3,
#            'mm3;': 3,
#            'g': 3,
#            'hepatic': 3,
#            'drug/': 3,
#            'week': 3,
#            'may': 3,
#            '30ml/': 3,
#            'min).': 3,
#            '-': 3,
#            'Allergy/': 3,
#            'hours/': 3,
#            '=/': 3,
#            'drinks/': 3,
#            'mol)': 3,
#            '150/': 3,
#            'with/': 3,
#            'E/': 3,
#            'assent': 3,
#            'to': 3,
#            '>140/': 3,
#            'ALT': 3,
#            'creatinine': 3,
#            'Day': 3,
#            'units/': 3,
#            '3g/': 3,
#            'blood': 3,
#            'radiotherapy': 2,
#            'alcohol/': 2,
#            'substance': 2,
#            'gm/': 2,
#            '50,000/': 2,
#            'pmol/': 2,
#            'have': 2,
#            'm^2.': 2,
#            'µL,': 2,
#            'guardians': 2,
#            'day).': 2,
#            '135/': 2,
#            '170/': 2,
#            '105': 2,
#            'rectal': 2,
#            'requiring': 2,
#            '(ng/': 2,
#            'during': 2,
#            'ALT/': 2,
#            'm^2;': 2,
#            '1/': 2,
#            '2': 2,
#            '20,000/': 2,
#            'pelvic/': 2,
#            'speculum': 2,
#            'disease-': 2,
#            'μL': 2,
#            'microL': 2,
#            'hypersensitivity': 2,
#            '30mUI/': 2,
#            'Karnofsky/': 2,
#            'Lansky': 2,
#            'guardian.': 2,
#            'infection': 2,
#            'count<100,000/': 2,
#            'post-albuterol/': 2,
#            'albuterol/': 2,
#            'diseases/': 2,
#            'LABA': 2,
#            'm2;': 2,
#            'day),': 2,
#            'o.': 2,
#            'ml)': 2,
#            'psychiatric': 2,
#            'thumb': 2,
#            'PSA<': 2,
#            '50mg/': 2,
#            '60mg/': 2,
#            'd)': 2,
#            'α/': 2,
#            '30': 2,
#            '180/': 2,
#            '60ml/': 2,
#            '<100,000/': 2,
#            'legally': 2,
#            '90,': 2,
#            'skin/': 2,
#            'IVF/': 2,
#            'ICSI': 2,
#            'L/': 2,
#            'CLL/': 2,
#            'CT/': 2,
#            'uL,': 2,
#            'AST': 2,
#            '<150/': 2,
#            'drug-': 2,
#            'h)': 2,
#            'screening/': 2,
#            'baseline': 2,
#            'umol/': 2,
#            '30g/': 2,
#            '(140-159/': 2,
#            '90-99': 2,
#            'to-left,': 2,
#            'to-left': 2,
#            'or/': 2,
#            'd': 2,
#            'MRI': 2,
#            'AND/': 2,
#            'OR': 2,
#            'milliliter': 2,
#            '6/': 2,
#            '3mg/': 2,
#            'anovulation/': 2,
#            'oligoovulation.': 2,
#            '(pg/': 2,
#            '1.73m2)': 2,
#            'seizures/': 2,
#            'social': 2,
#            'disease/': 2,
#            '01/': 2,
#            'week)': 2,
#            'fibrillation/': 2,
#            'flutter': 2,
#            'm²': 2,
#            'l)': 2,
#            'gram/': 2,
#            'DSM-IV/': 2,
#            '(+/': 2,
#            'cell/': 2,
#            '320': 2,
#            'Pd/': 2,
#            'ul': 2,
#            'mol);': 2,
#            '25': 2,
#            '>130': 2,
#            '95': 2,
#            '500/': 2,
#            '(E/': 2,
#            'TAF-containing': 2,
#            'COBI-containing': 2,
#            'mm^3': 2,
#            'symptoms': 2,
#            'study': 2,
#            'trial/': 2,
#            'willing/': 2,
#            'able': 2,
#            'year': 2,
#            'Pregnant/': 2,
#            '160/': 2,
#            'Kg/': 2,
#            'TIA': 2,
#            'L),': 2,
#            'day;': 2,
#            'million/': 2,
#            '40': 2,
#            'D': 2,
#            'HCV': 2,
#            'min;': 2,
#            'cels/': 2,
#            'pregnancy/': 2,
#            'breastfeeding)': 2,
#            'HIV': 2,
#            'HBV/': 2,
#            '3km/': 2,
#            '(~0.8m/': 2,
#            'unwilling/': 2,
#            'unable': 2,
#            'dl;': 2,
#            'vaccine/': 2,
#            'case-': 2,
#            'by-case': 2,
#            'on': 2,
#            'albumin/': 2,
#            'h/': 2,
#            'SOF/': 2,
#            'R/': 2,
#            'R': 2,
#            '150,000/': 2,
#            'mU/': 2,
#            'electrocardiogram/': 2,
#            'duodenal': 2,
#            'bowel/': 2,
#            'Ethical': 2,
#            'K/': 2,
#            'cumm': 2,
#            'speaking/': 2,
#            '1,73': 2,
#            'HCV/': 2,
#            'mcL': 2,
#            'intolerance': 2,
#            '(FEV1/': 2,
#            '(>160/': 2,
#            '40/': 2,
#            '6mg/': 2,
#            'hypersensitivity/': 2,
#            'Randomization)': 2,
#            'L);': 2,
#            '(100mg/': 2,
#            '(200mg/': 2,
#            '10': 2,
#            'stage': 1,
#            '(M1)/': 1,
#            'product/': 1,
#            'device': 1,
#            'biopsy/': 1,
#            'resection': 1,
#            '1,500/': 1,
#            'condition/': 1,
#            'illness': 1,
#            '(>/': 1,
#            'Had/': 1,
#            'prior/': 1,
#            'concurrent': 1,
#            'drugs/': 1,
#            'agents': 1,
#            'metformin': 1,
#            'sulfonylurea/': 1,
#            '≥1,500/': 1,
#            '≥100,000/': 1,
#            'µL)': 1,
#            'but,': 1,
#            'minute.': 1,
#            'mL;': 1,
#            'µl': 1,
#            '<30ml/': 1,
#            '(ALT)/': 1,
#            'aspartate': 1,
#            '>1g/': 1,
#            '2.0mg/': 1,
#            'gastrointestinal/': 1,
#            'injury': 1,
#            'runny/': 1,
#            'blocked/': 1,
#            'itchy': 1,
#            '(NINCDS/': 1,
#            'ADRDA)': 1,
#            'Inspiratory': 1,
#            '50ug/': 1,
#            'hr': 1,
#            'Tramadol/': 1,
#            'Acetaminophen': 1,
#            'ml):': 1,
#            '>_3500/': 1,
#            '>_100,000/': 1,
#            'IV),': 1,
#            '(Benadryl®)': 1,
#            'AST>3x': 1,
#            'probability(': 1,
#            '(BMI=40kg/': 1,
#            '120mg/': 1,
#            'disease(': 1,
#            'Melan-A/': 1,
#            'MART-1': 1,
#            '10.5g/': 1,
#            'corticosteroids/': 1,
#            '11.5g/': 1,
#            '[BCR/': 1,
#            'ABL+]': 1,
#            '[MLL/': 1,
#            'AF4+].': 1,
#            '0-': 1,
#            'to-10': 1,
#            'sensitivity/': 1,
#            '<60/': 1,
#            '<30,000/': 1,
#            'QT/': 1,
#            'QTc': 1,
#            'dementia/': 1,
#            'cognitive': 1,
#            'μL).': 1,
#            'Gms/': 1,
#            'radiation': 1,
#            '>1,500/': 1,
#            '>100,000/': 1,
#            'national/': 1,
#            'local': 1,
#            '<60mL/': 1,
#            'Ethics': 1,
#            '150µmol/': 1,
#            'psychotropics(': 1,
#            'AIDS).': 1,
#            'patient/': 1,
#            'Patient/': 1,
#            'potassium<3.2mmol/': 1,
#            'or>5.5mmol/': 1,
#            'scar/': 1,
#            'change': 1,
#            'inflammation/': 1,
#            'disease(ESRD)/': 1,
#            'Hb<10g/': 1,
#            '(FEV1)/': 1,
#            '(forced': 1,
#            ')': 1,
#            'severe': 1,
#            'abnormalities:': 1,
#            'food': 1,
#            'weight(Kg)/': 1,
#            'height(m2).': 1,
#            '<1,500/': 1,
#            '90,000/': 1,
#            'orphans/': 1,
#            'vulnerable': 1,
#            '[IRB]/': 1,
#            'Independent': 1,
#            '1x/': 1,
#            'session': 1,
#            'lamivudine/': 1,
#            'adefovir': 1,
#            'dl.': 1,
#            '(BCR/': 1,
#            'ABL)': 1,
#            'cancer,': 1,
#            'chemotherapy,': 1,
#            'creatinine(>1.5mg/': 1,
#            '20mg/': 1,
#            '40mg/': 1,
#            '150mg/': 1,
#            '45mg/': 1,
#            'ER(150-225mg/': 1,
#            'mm3if': 1,
#            'mm3or': 1,
#            '<30mL/': 1,
#            'CYP3A4/': 1,
#            'P-glycoprotein': 1,
#            'ALT>2x': 1,
#            '70;': 1,
#            'simvastatin/': 1,
#            'lovastatin': 1,
#            'mm3),': 1,
#            'cord/': 1,
#            'cauda': 1,
#            'd/': 1,
#            'β),': 1,
#            'β': 1,
#            '9gm/': 1,
#            '3.5/': 1,
#            'negative/': 1,
#            'HBcAb': 1,
#            'positive/': 1,
#            'hepatitis': 1,
#            'at/': 1,
#            'above': 1,
#            'ERCP/': 1,
#            'PTC': 1,
#            'vaginal': 1,
#            '<24/': 1,
#            'left/': 1,
#            'right': 1,
#            'who': 1,
#            'events/': 1,
#            'hour': 1,
#            '(>170/': 1,
#            '>110)': 1,
#            'DDAVP/': 1,
#            'Stimate': 1,
#            'IIIB/': 1,
#            'EGF/': 1,
#            'EGFR': 1,
#            'registries': 1,
#            'studies/': 1,
#            'hip': 1,
#            'knee/': 1,
#            '5-fluorouracil/': 1,
#            'leucovorin': 1,
#            '(5-FU/': 1,
#            'LV)': 1,
#            'DoD/': 1,
#            'VA': 1,
#            'besides': 1,
#            'sec': 1,
#            'equivalent/': 1,
#            '1)': 1,
#            'cerebral/': 1,
#            'meningeal': 1,
#            'rest/': 1,
#            'ice': 1,
#            'soft': 1,
#            'soft-tissue': 1,
#            'rifampin/': 1,
#            'rifampicin,': 1,
#            '100µg/': 1,
#            'µg/': 1,
#            'AIDS.': 1,
#            'Oligomenorrhea/': 1,
#            'amenorrhea': 1,
#            'SLL': 1,
#            '1-3A/': 1,
#            'iNHL,': 1,
#            'LPL/': 1,
#            'WM,': 1,
#            'SLL,': 1,
#            'MF/': 1,
#            'SS)': 1,
#            'PET': 1,
#            '1000/': 1,
#            'uL': 1,
#            '20.0mg/': 1,
#            'Hep': 1,
#            'bowel': 1,
#            '95mmHg': 1,
#            '=135/': 1,
#            '95.': 1,
#            '(ALT/': 1,
#            'AST>50IU/': 1,
#            'durg-': 1,
#            'T-cell': 1,
#            'NK/': 1,
#            'ER/': 1,
#            'PR': 1,
#            '(20g/': 1,
#            'aminotransferase/': 1,
#            'alanine': 1,
#            'planing/': 1,
#            'being': 1,
#            '159/': 1,
#            '99': 1,
#            'B/': 1,
#            'C': 1,
#            'ANC>1000/': 1,
#            'mcl': 1,
#            'platelets>100,000/': 1,
#            'mcl.': 1,
#            'yes/': 1,
#            'weeks)/': 1,
#            'low': 1,
#            'kg': 1,
#            'PET/': 1,
#            'milliunits/': 1,
#            '(mU/': 1,
#            '(renal/': 1,
#            'Current/': 1,
#            'recent': 1,
#            'patients.': 1,
#            'Mild-': 1,
#            'to-moderate': 1,
#            '80U/': 1,
#            'artifacts/': 1,
#            'components': 1,
#            'absence': 1,
#            'is/': 1,
#            'are': 1,
#            "investigator's/": 1,
#            "designee's": 1,
#            '(MlU/': 1,
#            '60mL/': 1,
#            'equivalents/': 1,
#            'tooth)': 1,
#            'surgical': 1,
#            'bleeding/': 1,
#            'clotting': 1,
#            'substance/': 1,
#            '2010': 1,
#            '30/': 1,
#            '09/': 1,
#            '2013': 1,
#            'attempt/': 1,
#            'difficult-': 1,
#            'to-detect': 1,
#            'height/': 1,
#            'weight': 1,
#            '2400/': 1,
#            'microl,': 1,
#            'amphetamine/': 1,
#            'methamphetamine,': 1,
#            'ADHD/': 1,
#            'LD': 1,
#            'dL])': 1,
#            'TPV/': 1,
#            'r': 1,
#            'Hgb<11g/': 1,
#            'Hct<30g/': 1,
#            '>240mg/': 1,
#            '>500mg/': 1,
#            '>130mg/': 1,
#            '<150,000/': 1,
#            '[kilogram(kg)]/': 1,
#            'height^2': 1,
#            'm^2,': 1,
#            'suppository': 1,
#            'suppository,': 1,
#            '=(mPAP-PCWP)/': 1,
#            'CO]>3.0': 1,
#            '<1g/': 1,
#            'differentiated/': 1,
#            'de-differentiated': 1,
#            'sarcoma/': 1,
#            'MFH': 1,
#            'asthma/': 1,
#            'atopy': 1,
#            'nursing/': 1,
#            'breastfeeding.': 1,
#            'Liter': 1,
#            'deciliter': 1,
#            '(g/': 1,
#            'arterial/': 1,
#            'venous': 1,
#            'In': 1,
#            'systolic/': 1,
#            'diastolic': 1,
#            '=128/': 1,
#            '78': 1,
#            'V': 1,
#            '5),': 1,
#            'ICD-10/': 1,
#            'V,': 1,
#            '(ACC/': 1,
#            'AHA': 1,
#            'mL),': 1,
#            'dL),': 1,
#            'mL).': 1,
#            '50': 1,
#            'vitreous': 1,
#            'intravitreal/': 1,
#            'periocular': 1,
#            'complications/': 1,
#            'Pa': 1,
#            'Pa)': 1,
#            '1250/': 1,
#            '*28': 1,
#            '*28/': 1,
#            'Caregiver': 1,
#            'Subject/': 1,
#            '(BP>140/': 1,
#            'x109/': 1,
#            'peripheral': 1,
#            'severe/': 1,
#            'unstable': 1,
#            'coronary/': 1,
#            '=7mmol/': 1,
#            '=11mmol/': 1,
#            '7.0mmol/': 1,
#            '48mmol/': 1,
#            '130µmol/': 1,
#            '4.0ng/': 1,
#            '1.7mg/': 1,
#            'anesthesia/': 1,
#            'procedures': 1,
#            'clotting/': 1,
#            'coagulation': 1,
#            'l))': 1,
#            'clearance>50ml/': 1,
#            'in': 1,
#            '<140/': 1,
#            'solvent': 1,
#            'platinum-': 1,
#            'ALT:': 1,
#            'anti-PD1/': 1,
#            'anti-PD-L1': 1,
#            'Desire/': 1,
#            'intent': 1,
#            'trimethoprim/': 1,
#            'sulphamethoxazole': 1,
#            'piperacillin/': 1,
#            'tazobactam)': 1,
#            'LDL=/': 1,
#            '>150': 1,
#            'close/': 1,
#            'intimate': 1,
#            'days/': 1,
#            'good': 1,
#            'eGFR=60(ml/': 1,
#            '2/': 1,
#            '3': 1,
#            'care': 1,
#            'µL.': 1,
#            'CIA)': 1,
#            'CIA,': 1,
#            'CIA': 1,
#            '(TAF)/': 1,
#            '(COBI)/': 1,
#            'TAF/': 1,
#            'COBI/': 1,
#            '40,000/': 1,
#            'www.fstrf.org/': 1,
#            'ACTG/': 1,
#            'ccc.html': 1,
#            'signs/': 1,
#            ')/': 1,
#            'T': 1,
#            'test:WBC=3.0×109/': 1,
#            'L,Neutrophils=1.5×109/': 1,
#            'L,Hb=100g/': 1,
#            'L,Platelet=80×109/': 1,
#            'mol/': 1,
#            'study/': 1,
#            'trial': 1,
#            'agonist/': 1,
#            'antagonist': 1,
#            '(polyester/': 1,
#            'ethyl': 1,
#            'DAS28/': 1,
#            'Erythrocyte': 1,
#            'dapsone-': 1,
#            'naive.': 1,
#            '1-4h,': 1,
#            '<50/': 1,
#            '1,73m),': 1,
#            'evenings/': 1,
#            'nights': 1,
#            'BMI-': 1,
#            'for-age': 1,
#            'drugs': 1,
#            'packs/': 1,
#            '70': 1,
#            'hypotension/': 1,
#            'capillary': 1,
#            'leak/': 1,
#            'life': 1,
#            'breast-feeding': 1,
#            'schizophrenia/': 1,
#            'schizoaffective': 1,
#            'Spontaneous/': 1,
#            'Induced/': 1,
#            'Augmented': 1,
#            'H/': 1,
#            'or=': 1,
#            '(Ag/': 1,
#            'Ab': 1,
#            '+/': 1,
#            '30Kg/': 1,
#            '1.73m2),': 1,
#            'stroke/': 1,
#            '<2.2mg/': 1,
#            'pain(': 1,
#            'ventilation/': 1,
#            'perfusion': 1,
#            'overload/': 1,
#            'dysfunction': 1,
#            'Forced': 1,
#            'volume/': 1,
#            'medications/': 1,
#            'materials:': 1,
#            'acquired/': 1,
#            'inherited': 1,
#            'IgG/': 1,
#            'IgM,': 1,
#            'mild/': 1,
#            'moderate': 1,
#            '(>1/': 1,
#            '>': 1,
#            'cardiovascular/': 1,
#            'pulmonary': 1,
#            'mol.': 1,
#            'l).': 1,
#            'mn': 1,
#            'acid/': 1,
#            'Cyklokapron®': 1,
#            'IV±V': 1,
#            '(ISN/': 1,
#            'RPS': 1,
#            'protein/': 1,
#            'micromol/': 1,
#            'haemoglobinopathy/': 1,
#            'thalassaemia': 1,
#            'trauma/': 1,
#            'surgery': 1,
#            'abuse/': 1,
#            'dependence': 1,
#            'CVA/': 1,
#            'Accident/': 1,
#            'Transient': 1,
# ...
#            'albuterol/': 2,
#            'diseases/': 2,
#            'LABA': 2,
#            'psychiatric': 2,
#            'finger/': 2,
#            'thumb': 2,
#            'infection/': 2,
#            '60ml/min/1.73': 2,
#            'skin/': 2,
#            'IVF/': 2,
#            'ICSI': 2,
#            'CLL/': 2,
#            'CT/': 2,
#            'screening/': 2,
#            'baseline': 2,
#            'MRI': 2,
#            'anovulation/': 2,
#            'oligoovulation.': 2,
#            'm2)': 2,
#            'social': 2,
#            'disease/': 2,
#            'fibrillation/': 2,
#            'flutter': 2,
#            'non-infectious)': 2,
#            'AST': 2,
#            'trial': 2,
#            'sensitivity': 2,
#            'symptoms': 2,
#            'study': 2,
#            'trial/': 2,
#            'Pregnant/': 2,
#            'TIA': 2,
#            'pregnancy/': 2,
#            'breastfeeding)': 2,
#            'flexion-': 2,
#            'extension': 2,
#            'HIV': 2,
#            'HBV/': 2,
#            'vaccine/': 2,
#            'albumin/': 2,
#            'creatinine': 2,
#            'with': 2,
#            'SOF/': 2,
#            'electrocardiogram/': 2,
#            'duodenal': 2,
#            'bowel/': 2,
#            '(systolic': 2,
#            'HCV/': 2,
#            'intolerance': 2,
#            'be': 2,
#            '(FEV1/': 2,
#            'hypersensitivity/': 2,
#            'GILD': 2,
#            'Investigator,': 2,
#            'one': 1,
#            'Not': 1,
#            'product/': 1,
#            'device': 1,
#            'biopsy/': 1,
#            'resection': 1,
#            'condition/': 1,
#            'illness': 1,
#            'have': 1,
#            'Had/': 1,
#            'prior/': 1,
#            'concurrent': 1,
#            'drugs/': 1,
#            'agents': 1,
#            'metformin': 1,
#            'sulfonylurea/': 1,
#            'g/dL,': 1,
#            '(ALT)/': 1,
#            'aspartate': 1,
#            'participation..': 1,
#            '2.0': 1,
#            'mg/dL': 1,
#            'gastrointestinal/': 1,
#            'injury': 1,
#            'runny/': 1,
#            'blocked/': 1,
#            'itchy': 1,
#            'Inspiratory': 1,
#            '1.': 1,
#            'Tramadol/': 1,
#            'Acetaminophen': 1,
#            'III/IV),': 1,
#            'AST>3x': 1,
#            'Melan-A/': 1,
#            'MART-1': 1,
#            'corticosteroids/': 1,
#            'Investigator)': 1,
#            'HIV-': 1,
#            'sensitivity/': 1,
#            'QT/': 1,
#            'QTc': 1,
#            'therapy.': 1,
#            'dementia/': 1,
#            'cognitive': 1,
#            'method).': 1,
#            'month,': 1,
#            'scar/': 1,
#            'change': 1,
#            'inflammation/': 1,
#            'disease(ESRD)': 1,
#            'on': 1,
#            '(FEV1)': 1,
#            '(forced': 1,
#            'severe': 1,
#            'abnormalities:': 1,
#            'food': 1,
#            'half-lives,': 1,
#            'orphans/': 1,
#            'vulnerable': 1,
#            'lamivudine/': 1,
#            'adefovir': 1,
#            'HCl,': 1,
#            'cancer,': 1,
#            'only)': 1,
#            'chemotherapy,': 1,
#            'cardia,': 1,
#            'liver': 1,
#            'CYP3A4/': 1,
#            'P-glycoprotein': 1,
#            'ALT>2x': 1,
#            'simvastatin/': 1,
#            'lovastatin': 1,
#            'cord/': 1,
#            'cauda': 1,
#            'negative/': 1,
#            'HBcAb': 1,
#            'positive/': 1,
#            'hepatitis': 1,
#            'ERCP/': 1,
#            'PTC': 1,
#            'vaginal': 1,
#            'Yahr,1967;': 1,
#            'ischaemic': 1,
#            'gallbladder,': 1,
#            'gallstone': 1,
#            'cholecystitis,': 1,
#            'pancreatitis,': 1,
#            'pancreaticobiliary': 1,
#            'DDAVP/': 1,
#            'Stimate': 1,
#            'IIIB/': 1,
#            'IV': 1,
#            'EGF/': 1,
#            'EGFR': 1,
#            'registries': 1,
#            'studies/': 1,
#            'hip': 1,
#            'knee/': 1,
#            '5-fluorouracil/': 1,
#            'leucovorin': 1,
#            '(5-FU/': 1,
#            'LV)': 1,
#            '1)': 1,
#            'HBsAg-': 1,
#            'cerebral/': 1,
#            'meningeal': 1,
#            'rest/': 1,
#            'ice': 1,
#            'soft': 1,
#            'soft-tissue': 1,
#            'rifampin/': 1,
#            'rifampicin,': 1,
#            'AF': 1,
#            'Oligomenorrhea/': 1,
#            'amenorrhea': 1,
#            'gestation.scheduled': 1,
#            'etc).Rupture': 1,
#            'SLL': 1,
#            '1-3A/': 1,
#            'iNHL,': 1,
#            'LPL/': 1,
#            'WM,': 1,
#            'SLL,': 1,
#            'MF/': 1,
#            'SS)': 1,
#            'PET': 1,
#            'HIV/': 1,
#            'Hep': 1,
#            'bowel': 1,
#            '([women]': 1,
#            '(ALT/': 1,
#            'AST>50IU/L)': 1,
#            'anti-inflammatories,': 1,
#            'durg-': 1,
#            'drug-': 1,
#            'ER/': 1,
#            'PR': 1,
#            'aminotransferase/': 1,
#            'alanine': 1,
#            'planing/': 1,
#            'being': 1,
#            'liter.': 1,
#            'PET/': 1,
#            '(renal/': 1,
#            'Current/': 1,
#            'recent': 1,
#            'parents/': 1,
#            'patients.': 1,
#            'APA,': 1,
#            'H2blocker,': 1,
#            'artifacts/': 1,
#            'components': 1,
#            'absence': 1,
#            '60mL/min/1.73': 1,
#            'surgical': 1,
#            'bleeding/': 1,
#            'clotting': 1,
#            'substance/': 1,
#            'non-cardiac)': 1,
#            'height/': 1,
#            'weight': 1,
#            'amphetamine/': 1,
#            'methamphetamine,': 1,
#            'ADHD/': 1,
#            'LD': 1,
#            'suppository': 1,
#            'suppository,': 1,
#            '=(mPAP-': 1,
#            'PCWP)/CO]>3.0': 1,
#            'differentiated/': 1,
#            'de-differentiated': 1,
#            'sarcoma/': 1,
#            'MFH': 1,
#            'are': 1,
#            'asthma/': 1,
#            'atopy': 1,
#            'nursing/': 1,
#            'breastfeeding.': 1,
#            'arterial/': 1,
#            'venous': 1,
#            'systolic/': 1,
#            'diastolic': 1,
#            'ICD-10/': 1,
#            'DSM-IV/V,': 1,
#            'vitreous': 1,
#            'intravitreal/': 1,
#            'periocular': 1,
#            'complications/': 1,
#            'peripheral': 1,
#            'severe/': 1,
#            'unstable': 1,
#            'coronary/': 1,
#            'anesthesia/': 1,
#            'procedures': 1,
#            'clotting/': 1,
#            'coagulation': 1,
#            'spermicide).': 1,
#            'HCV-': 1,
#            'negative,': 1,
#            'eligible..': 1,
#            'solvent': 1,
#            'platinum-': 1,
#            'ALT:': 1,
#            'anti-PD1/': 1,
#            'anti-PD-L1': 1,
#            'Desire/': 1,
#            'intent': 1,
#            'trimethoprim/': 1,
#            'sulphamethoxazole': 1,
#            'piperacillin/': 1,
#            'tazobactam)': 1,
#            'close/': 1,
#            'intimate': 1,
#            'good': 1,
#            'Hbatic': 1,
#            'signs/': 1,
#            ')/': 1,
#            'T': 1,
#            'test:WBC=3.0×109/L,': 1,
#            'Neutrophils=1.5×109/L,': 1,
#            'Hb=100g/L,': 1,
#            'Platelet': 1,
#            '=80': 1,
#            '×109/L;': 1,
#            'months),': 1,
#            'study/': 1,
#            'agonist/': 1,
#            'antagonist': 1,
#            '(polyester/': 1,
#            'ethyl': 1,
#            'DAS28/': 1,
#            'Erythrocyte': 1,
#            'rest,': 1,
#            'home.': 1,
#            'dapsone-': 1,
#            'naive.': 1,
#            'al].': 1,
#            '1-4h,': 1,
#            'analgesics,': 1,
#            'sedatives': 1,
#            'laser,....': 1,
#            '/1,73': 1,
#            'm),': 1,
#            'evenings/': 1,
#            'nights': 1,
#            'drugs': 1,
#            'hypotension/': 1,
#            'capillary': 1,
#            'leak/': 1,
#            'life': 1,
#            'breast-feeding': 1,
#            'schizophrenia/': 1,
#            'schizoaffective': 1,
#            'Spontaneous/': 1,
#            'Induced/': 1,
#            'Augmented': 1,
#            '>1%),': 1,
#            '6.5%,': 1,
#            '30ml/min/1.73': 1,
#            'm2),': 1,
#            'stroke/': 1,
#            'Congenital,': 1,
#            'Mental': 1,
#            'Cardiac,': 1,
#            'Pulmonary,': 1,
#            'Hepatic': 1,
#            'antipyretics,': 1,
#            'sleeping': 1,
#            'contraindication,including': 1,
#            'ventilation/': 1,
#            'perfusion': 1,
#            'overload/': 1,
#            'dysfunction': 1,
#            'medications/': 1,
#            'materials:': 1,
#            'acquired/': 1,
#            'inherited': 1,
#            'IgG/': 1,
#            'IgM,': 1,
#            'mild/': 1,
#            'moderate': 1,
#            'cardiovascular/': 1,
#            'pulmonary': 1,
#            'acid/': 1,
#            'Cyklokapron®': 1,
#            'haemoglobinopathy/': 1,
#            'thalassaemia': 1,
#            'B,': 1,
#            'C': 1,
#            'trauma/': 1,
#            'surgery': 1,
#            'abuse/': 1,
#            'dependence': 1,
#            'rate(CCr)<50%;': 1,
#            'CVA/': 1,
#            'Accident/': 1,
#            'Transient': 1,
#            'arthritis/': 1,
#            'autoimmune': 1,
#            'mL/min/1.7': 1,
#            'WHO/': 1,
#            'NYHA-FC': 1,
#            'disorders/': 1,
#            'Significant/': 1,
#            'Inclusion/Exclusion': 1,
#            'May': 1,
#            'fusion/': 1,
#            'apnea/': 1,
#            'hypopnea': 1,
#            'naïve,': 1,
#            '1a/': 1,
#            'ab.': 1,
#            'LDV/': 1,
#            'SOF': 1,
#            'aminotransferase)/': 1,
#            'ALT(alanine': 1,
#            'aminotransferase)': 1,
#            'disorder/': 1,
#            'diathesis': 1,
#            'Mental,': 1,
#            'the': 1,
#            'trichomonas.': 1,
#            'placebo,': 1,
#            'Patients': 1,
#            'lumbar': 1,
#            'fusion.': 1,
#            'injections/': 1,
#            '(joint/': 1,
#            'musculoskeletal,': 1,
#            'LDV': 1,
#            'tipranavir/': 1,
#            'ritonavir': 1,
#            'nucleoside/': 1,
#            'nucleotide': 1,
#            'Pa02/': 1,
#            'Fi02': 1,
#            'Pre-existing/': 1,
#            'procedures/': 1,
#            'treatments.': 1,
#            'endodontic/': 1,
#            'periodontal': 1,
#            'assay)': 1,
#            'transaminase/': 1,
#            'alkaline': 1,
#            'ALT)': 1,
#            'Hemosiderosis/': 1,
#            'hemochromatosis': 1,
#            'prednisone/': 1,
#            'prednisolone': 1,
#            'osteomyelitis/': 1,
#            'septic': 1,
#            '>5°,': 1,
#            'Intolerance/': 1,
#            'Exposure/': 1,
#            'treatment': 1,
#            'law,': 1,
#            'CNIL).': 1,
#            'periorbital/': 1,
#            'forehead': 1,
#            'ALT,': 1,
#            'failure': 1,
#            'injury/': 1,
#            'miscarriage/': 1,
#            'abortion': 1,
#            'obstruction/': 1,
#            'blockage': 1,
#            'IBS': 1,
#            'severity': 1,
#            'frequency/': 1,
#            'HA-': 1,
#            'pressure<110)': 1,
#            'lightheadedness),': 1,
#            'anti-Inflammatory': 1,
#            'sedative/': 1,
#            'hypnotics),': 1,
#            'thrombophilia/': 1,
#            'thrombosis': 1,
#            '(hypertension),DM': 1,
#            'topiramate,': 1,
#            'phenytoin)': 1,
#            'level?': 1,
#            'reading?': 1,
#            'University/': 1,
#            'Barnes-Jewish': 1,
#            'speaking/': 1,
#            'illiterate': 1,
#            'autoimmune/': 1,
#            'inflammatory': 1,
#            '(IUD/': 1,
#            'IUS)': 1,
#            '(MI/': 1,
#            'heart': 1,
#            "Parkison's": 1,
#            'SGOT/': 1,
#            'SGPT': 1,
#            '(dronabinol/': 1,
#            'marijuana/': 1,
#            'cannabis/': 1,
#            'THC,': 1,
#            'drug': 1,
#            'acceleration/': 1,
#            'deceleration': 1,
#            'shrapnel/': 1,
#            'retained': 1,
#            'Patients/': 1,
#            'physicians': 1,
#            'situations/': 1,
#            'Oral/': 1,
#            'Oropharynx': 1,
#            'contra-indication': 1,
#            'neuropathy/': 1,
#            'sensory': 1,
#            'hepatocellular/': 1,
#            'cholangiocarcinoma': 1,
#            'maintenance/': 1,
#            'extended-use': 1,
#            'illness.': 1,
#            'Moderate/': 1,
#            'Weak': 1,
#            'venetoclax).': 1,
#            'T2/': 1,
#            'FLAIR': 1,
#            'FA/': 1,
#            'ICGA': 1,
#            'PO/': 1,
#            'NG': 1,
#            'm2).': 1,
#            'or/': 1,
#            'discharge': 1,
#            'Hiv/': 1,
#            'test.': 1,
#            'etc.).': 1,
#            'husband/': 1,
#            'wife,': 1,
#            'visible': 1,
#            'nephropathy/': 1,
#            'retinopathy/': 1,
#            'neuropathy': 1,
#            'spondylolisthesis/': 1,
#            'spondylosis/': 1,
#            'spondylolysis': 1,
#            'Immunosuppressed/': 1,
#            'immune': 1,
#            'interlerance': 1,
#            'information': 1,
#            'Lumber': 1,
#            'bigemini/': 1,
#            'trigeminy': 1,
#            'exacerbation': 1,
#            '(Xiapex/': 1,
#            'Xiaflex': 1,
#            'neck,including': 1,
#            'nodes,': 1,
#            'metastasis)': 1,
#            '-': 1,
#            'None': 1,
#            'to,': 1,
#            'Stroke/': 1,
#            "Alzheimer's": 1,
#            'Severe/': 1,
#            'untreated': 1,
#            'Diagnosed': 1,
#            'mL/min/1.73': 1,
#            'm2.': 1,
#            'liver-': 1,
#            'kidney': 1,
#            'ARF,': 1,
#            'scarlet': 1,
#            'fever,': 1,
#            'impetigo,': 1,
#            'acute': 1,
#            'Pregnancy/': 1,
#            'breastfeeding': 1,
#            'without': 1,
#            'lactating': 1,
#            'Sensistivity/': 1,
#            '[': 1,
#            'Unstable/': 1,
#            'rapidly': 1,
#            'donation/': 1,
#            'Interleukin-12/': 1,
#            '23': 1,
#            '(IL-12/': 1,
#            '23),': 1,
#            'opioids/': 1,
#            'opiates,': 1,
#            'overweight/': 1,
#            'lean': 1,
#            'high': 1,
#            'phentermine,': 1,
#            'orlistat,': 1,
#            'tuberculosis,': 1,
#            'back': 1,
#            'leg/': 1,
#            'T-score': 1,
#            'bladder': 1,
#            'chemical/': 1,
#            'never': 1,
#            'LABA)': 1,
#            'RELVAR/': 1,
#            'BREO': 1,
#            'Salbutamol/': 1,
#            'Albuterol': 1,
#            'condition': 1,
#            'VEL': 1,
#            'non-therapy-induced': 1,
#            'that,': 1,
#            'diabetes,': 1,
#            'gestational': 1,
#            'Overweight/': 1,
#            'Obese': 1,
#            'concurrent,': 1,
#            'non-stimulant': 1,
#            'nicotine': 1,
#            'tobacco/': 1,
#            '(PO/': 1,
#            'IV/': 1,
#            'IM)': 1,
#            'product': 1,
#            'Emergent/': 1,
#            'elective': 1,
#            'HBV': 1,
#            'race/': 1,
#            'ethnicity,': 1,
#            'pharmacokinetic/': 1,
#            'pharmacodynamics': 1,
#            'prednisone': 1,
#            'methylprednisolone/': 1,
#            'has': 1,
#            '80': 1,
#            'mmHg=DBP<110': 1,
#            'mmHg': 1,
#            'GFR<30ml•min-1•1.73': 1,
#            'm-2;': 1,
#            'DBP=110': 1,
#            'mmHg;': 1,
#            'terazosin/': 1,
#            'doxazosin/': 1,
#            'alfuzosin/': 1,
#            'silodosin)': 1,
#            'TSH,': 1,
#            'PRL,': 1,
#            'FBS': 1,
#            'range),': 1,
#            'surgical/': 1,
#            'percutaneous': 1,
#            'PCI/': 1,
#            'MI': 1,
#            'ICD/': 1,
#            'CRT-D.': 1}),
#   'average': {'precision': 28.698778816213164,
#    'recall': 54.39723899619063,
#    'f1': 36.8098331418087,
#    'accuracy': 54.39723899619063}}}

# %% [markdown]
# ### Missing Words PCT

# %%
def plot_avg_pct(all_metrics):
    model_names = []
    avg_missing_pcts = []
    avg_zuviel_pcts = []

    for model, metrics in all_metrics.items():
        model_names.append(model.replace('-Instruct', ''))  # Entferne "-Instruct" aus den Modellnamen
        avg_missing_pcts.append(metrics['average_missing_percentage'])
        avg_zuviel_pcts.append(metrics['average_zuviel_percentage'])
        model_names = [name.replace('-Instruct', '') for name in model_names]
    model_names = [name.replace('_', '-') for name in model_names]
    model_names = [name.replace('Gradient', 'Grad') for name in model_names]
    model_names = [name.replace('Llama-3', 'Llama3') for name in model_names]
    model_names = [name.replace('prompt-', 'p') for name in model_names]
    #model_names = [name.replace('-0-shot', '') for name in model_names]
    x = range(len(model_names))

    plt.figure(figsize=(14, 8))

    bar_width = 0.4
    plt.bar(x, avg_missing_pcts, color='skyblue', width=bar_width, label='Mittlere Anzahl fehlender Wörter')
    plt.bar([p + bar_width for p in x], avg_zuviel_pcts, color='lightcoral', width=bar_width, label='Mittlere Anzahl zugefügter Wörter')

    plt.xlabel('Modelle', fontsize=14)
    plt.ylabel('Prozentsatz (%)', fontsize=14)
    plt.title(f'Durchschnittlicher Prozentsatz fehlender und zugefügter Wörter der {versuch_name}', fontsize=18, pad=20)
    plt.xticks([p + bar_width / 2 for p in x], model_names, rotation=45, ha='right', fontsize=14)
    plt.yticks(fontsize=14)
    plt.ylim(0, max(max(avg_missing_pcts), max(avg_zuviel_pcts)) + 5)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.legend()

    for i, (v1, v2) in enumerate(zip(avg_missing_pcts, avg_zuviel_pcts)):
        plt.text(i, v1 + 0.5, f'{v1:.1f}%', ha='center', fontsize=12)
        plt.text(i + bar_width, v2 + 0.5, f'{v2:.1f}%', ha='center', fontsize=12)

    plt.tight_layout()
    plt.savefig(f'pics/missing_pct_{versuch_name}.png')
    plt.show()

# %%
plot_avg_pct(all_metrics)

# %%
def plot_avg_metrics(all_metrics):
    sota_metrics = {
        'PubMedBERT (SOTA)': {
            'average': {'precision': 60.6, 'recall': 63.9, 'f1': 62.2}
        },
    }
    metrics_to_plot = ['precision', 'recall', 'f1']
    model_names = ['PubMedBERT (SOTA)'] + list(all_metrics.keys())
    model_names = [name.replace('-Instruct', '') for name in model_names]
    model_names = [name.replace('_', '-') for name in model_names]
    model_names = [name.replace('Gradient', 'Grad') for name in model_names]
    model_names = [name.replace('Llama-3', 'Llama3') for name in model_names]
    model_names = [name.replace('prompt-', 'p') for name in model_names]
    #model_names = [name.replace('-0-shot', '') for name in model_names]

    avg_precisions = [sota_metrics['PubMedBERT (SOTA)']['average']['precision']]
    avg_recalls = [sota_metrics['PubMedBERT (SOTA)']['average']['recall']]
    avg_f1_scores = [sota_metrics['PubMedBERT (SOTA)']['average']['f1']]

    for model, metrics in all_metrics.items():
        avg_precisions.append(metrics['average']['precision'])
        avg_recalls.append(metrics['average']['recall'])
        avg_f1_scores.append(metrics['average']['f1'])

    x = np.arange(len(model_names) * 4)
    bar_width = 1.8  # Breitere Balken
    opacity = 0.8
    gap = 0.97 # Abstand zwischen den Balken
    model_gap = 1.0  # Abstand zwischen den Modellen

    plt.figure(figsize=(14, 10))  # Größere Figur
    sns.set(style='darkgrid', font_scale=1.2)
    sns.set_palette('deep')
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c']  # Bessere Farben
    for i in range(len(model_names)):
        plt.bar(x[i * 4], avg_precisions[i], bar_width - gap, alpha=opacity, label='Precision' if i == 0 else '', color=colors[0])
        plt.bar(x[i * 4 + 1], avg_recalls[i], bar_width - gap, alpha=opacity, label='Recall' if i == 0 else '', color=colors[1])
        plt.bar(x[i * 4 + 2], avg_f1_scores[i], bar_width - gap, alpha=opacity, label='F1 Score' if i == 0 else '', color=colors[2])

    plt.xlabel('Modelle', fontsize=16)
    plt.ylabel('Score (%)', fontsize=16)
    plt.title(f'{versuch_name}: Durchschnittliche Leistung für AND, OR, NOT Operatoren ', fontsize=18, pad=25)

    # Finde den Index des Modells mit dem höchsten F1-Score (ausgenommen SciBERT (SOTA) und Naive greedy match)
    max_f1 = max(avg_f1_scores[1:])
    max_f1 = round(max_f1,1)# SciBERT (SOTA) ausgeschlossen
    max_f1_indices = [i + 1 for i, f1 in enumerate(avg_f1_scores[1:]) if round(f1,1) == max_f1]
    tick_labels = [
        f'${{\\bf {name} }}$' if i in max_f1_indices else name
        for i, name in enumerate(model_names)
]

    plt.xticks(x[1::4], tick_labels, rotation=40, ha='right', fontsize=16)
    plt.ylim(0, 100)
    plt.yticks(fontsize=14)  # Größere Zahlen an der y-Achse
    plt.legend(title='Metriken', fontsize=12)
    plt.grid(True, linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

    y_offset = 2  # Abstand zwischen Balken und Prozentzahlen
    for i in range(len(model_names)):
        plt.text(x[i * 4], avg_precisions[i] + y_offset, f'{avg_precisions[i]:.1f}%', ha='center', fontsize=10)
        plt.text(x[i * 4 + 1], avg_recalls[i] + y_offset, f'{avg_recalls[i]:.1f}%', ha='center', fontsize=10)
        plt.text(x[i * 4 + 2], avg_f1_scores[i] + y_offset, f'{avg_f1_scores[i]:.1f}%', ha='center', fontsize=10)

    plt.tight_layout()
    os.makedirs('pics', exist_ok=True)
    plt.savefig(f'pics/all_operators_{versuch_name}.png')
    plt.show()

# %% [markdown]
# ### Durchschnittliche Performance über alle Operatoren [AND, OR, NOT]

# %%
plot_avg_metrics(all_metrics)

# %%
def avg_operators_latex(all_metrics, versuch_name):
    metrics_to_plot = ['precision', 'recall', 'f1']

    # SOTA metrics
    sota_metrics = {
        'PubMedBERT (SOTA)': {
            'average': {'precision': 60.6, 'recall': 63.9, 'f1': 62.2}
        }
    }

    max_values = {metric: float('-inf') for metric in metrics_to_plot}
    for model_metrics in [*sota_metrics.values(), *all_metrics.values()]:
        for metric in metrics_to_plot:
            value = model_metrics['average'][metric]
            if value > max_values[metric]:
                max_values[metric] = value

    latex_table = "\\begin{table}[ht]\n"
    latex_table += "\\centering\n"
    latex_table += "\\begin{tabular}{lcccc}\n"
    latex_table += "\\toprule\n"
    latex_table += "Model & Precision & Recall & F1 & Halluzination (%) \\\\\n"
    latex_table += "\\midrule\n"

    # Add rows for SOTA models
    for name, values in sota_metrics.items():
        row = name.replace("_", "-")
        for metric in metrics_to_plot:
            value = values['average'][metric]
            formatted_value = "{:.1f}".format(value)
            if value == max_values[metric]:
                formatted_value = f"\\textbf{{{formatted_value}}}"
            row += f" & {formatted_value}"
        row += " & - \\\\\n"  # No zuviel percentage for SOTA models
        latex_table += row

    # Add rows for other models
    for model, model_metrics in all_metrics.items():
        row = model.replace("_", "-")
        for metric in metrics_to_plot:
            value = model_metrics['average'][metric]
            formatted_value = "{:.1f}".format(value)
            if value == max_values[metric]:
                formatted_value = f"\\textbf{{{formatted_value}}}"
            row += f" & {formatted_value}"
        # Add average zuviel percentage value
        zuvielpct_value = model_metrics['average_zuviel_percentage']
        formatted_zuvielpct_value = "{:.1f}".format(zuvielpct_value)
        row += f" & {formatted_zuvielpct_value} \\\\\n"
        latex_table += row

    latex_table += "\\bottomrule\n"
    latex_table += "\\end{tabular}\n"
    latex_table += f"\\caption{{Average Model Performance Metrics and Zuviel Percentage for {versuch_name}}}\n"
    latex_table += "\\label{tab:avg_model_metrics}\n"
    latex_table += "\\end{table}\n"

    os.makedirs("latex", exist_ok=True)
    with open(f"latex/{versuch_name}.tex", "w") as file:
        file.write(latex_table)
    return latex_table

avg_operators_latex(all_metrics, versuch_name="Llama3-70b Modelle Chia Datensatz")
# Out:
# '\\begin{table}[ht]\n\\centering\n\\begin{tabular}{lcccc}\n\\toprule\nModel & Precision & Recall & F1 & Halluzination (%) \\\\\n\\midrule\nPubMedBERT (SOTA) & \\textbf{60.6} & 63.9 & \\textbf{62.2} & - \\\\\n Naive greedy match (CHIA Prompt) & 22.2 & \\textbf{65.0} & 30.8 & 2.5 \\\\\n Naive greedy match (LCT Prompt 2) & 21.2 & 47.1 & 28.6 & 2.3 \\\\\nLlama-3-70B-Instruct-0-shot-chia-prompt & 23.1 & 51.5 & 31.4 & 4.5 \\\\\nLlama-3-70B-Instruct-0-shot-lct-prompt & 23.5 & 48.3 & 31.4 & 4.3 \\\\\nLlama-3-70B-Instruct-5-shot-chia-prompt2 & 34.9 & 41.9 & 37.9 & 3.7 \\\\\nLlama-3-70B-Instruct-5-shot-lct-prompt2 & 35.6 & 42.2 & 38.5 & 3.6 \\\\\nllama3-70b-Lora-ep10-r256-prompt6-lct-model-lct2-prompt & 28.7 & 54.4 & 36.8 & 0.6 \\\\\n\\bottomrule\n\\end{tabular}\n\\caption{Average Model Performance Metrics and Zuviel Percentage for Llama3-70b Modelle Chia Datensatz}\n\\label{tab:avg_model_metrics}\n\\end{table}\n'

# %% [markdown]
# ### Perfomance der einzelnen Operatoren

# %%
plot_metrics(all_metrics)

# %% [markdown]
# ### Plot Anzahl Operators

# %%
def plot_count_comparison(all_metrics):
    operators = ['AND', 'OR', 'NOT']
    count_metrics = ['total_label', 'total_model']
    fig, ax = plt.subplots(figsize=(16, 8))
    x = np.arange(len(operators))

    label_counts = [all_metrics[next(iter(all_metrics))][op]['total_label'] for op in operators]
    bar_width = 0.16
    opacity = 0.8

    colors = sns.color_palette("husl", len(all_metrics) + 1)

    ax.bar(x, label_counts, bar_width, alpha=opacity, color=colors[0], label='Label Count')
    for i, model in enumerate(all_metrics.keys()):
        count_values = [all_metrics[model][op]['total_model'] for op in operators]
        model_name = model.replace('Instruct', '').replace('_', ' ')
        ax.bar(x + (i + 1) * bar_width, count_values, bar_width, alpha=opacity, color=colors[i + 1], label=model_name)

        for j, v in enumerate(count_values):
            label_count = label_counts[j]
            diff_percent = ((v - label_count) / label_count) * 100
            color = 'darkgreen' if diff_percent >= 0 else 'red'
            ax.text(x[j] + (i + 1) * bar_width, v / 2, f'{diff_percent:+.0f}%', ha='center', va='center', fontsize=10, color=color, fontweight='bold')
            ax.text(x[j] + (i + 1) * bar_width, v + 100, str(v), ha='center', fontsize=11)

    for i, v in enumerate(label_counts):
        ax.text(x[i], v + 100, str(v), ha='center', fontsize=10)

    ax.set_xticks(x + bar_width * len(all_metrics) / 2)
    ax.set_xticklabels([f'{op}' for op in operators], fontsize=12)
    ax.set_xlabel('Operators', fontsize=12)
    ax.set_ylabel('Anzahl', fontsize=12)
    ax.set_title('Count Comparison: Labels vs Models per Operator', fontsize=16, pad=30)
    ax.legend(fontsize=11)
    ax.grid(True)

    plt.tight_layout()
    plt.show()

# %%
plot_count_comparison(all_metrics)

# %% [markdown]
# ### Evaluiere n-shot Modelle

# %% [markdown]
# ## Model vs SOTA

# %%
print(models)

model_to_plot = models[len(models)-2] # len(models)-1
model_name = model_to_plot
model_to_plot
# Out:
# [' Naive greedy match (CHIA Prompt)', ' Naive greedy match (LCT Prompt 2)', 'Llama-3-70B-Instruct_0_shot_chia_prompt', 'Llama-3-70B-Instruct_0_shot_lct_prompt', 'Llama-3-70B-Instruct_5_shot_chia_prompt2', 'Llama-3-70B-Instruct_5_shot_lct_prompt2', 'llama3_70b_Lora_ep10_r256_prompt6_lct_model_lct2_prompt']
# 'Llama-3-70B-Instruct_5_shot_lct_prompt2'

# %%
model_metrics = all_metrics[model_to_plot]


sota_metrics = {
    'SciBERT': {
        'AND': {'precision': 54.1, 'recall': 60.0, 'f1': 56.9},
        'NOT': {'precision': 74.3, 'recall': 91.0, 'f1': 81.8},
        'OR': {'precision': 85.1, 'recall': 93.2, 'f1': 89.0},
        'average': {'precision': 71.16, 'recall': 81.39, 'f1': 75.89}
    },
    'R-BERT + SciBERT': {
        'AND': {'precision': 53.8, 'recall': 53.8, 'f1': 53.8},
        'NOT': {'precision': 74.5, 'recall': 88.7, 'f1': 81.0},
        'OR': {'precision': 88.4, 'recall': 92.2, 'f1': 90.2},
        'average': {'precision': 72.23, 'recall': 78.23, 'f1': 75.0}
    }
}

operators = ['AND', 'OR', 'NOT']
metrics_to_plot = ['precision', 'recall', 'f1']
metric_labels = {'precision': 'P', 'recall': 'R', 'f1': 'F1'}

fig, ax = plt.subplots(figsize=(16, 10))

x = np.arange(len(operators))
bar_width = 0.4
opacity = 0.8
gap = 0.1

for i, metric in enumerate(metrics_to_plot):
    model_values = [model_metrics[op][metric] for op in operators]
    sota_values = [sota_metrics['SciBERT'][op][metric] for op in operators]

    ax.bar(x - bar_width/2 - gap/2 + i*bar_width/3, model_values, bar_width/3, alpha=opacity, label=f'{model_name.split("-Instruct")[0]} - {metric_labels[metric]}')
    ax.bar(x + bar_width/2 + gap/2 + i*bar_width/3, sota_values, bar_width/3, alpha=opacity, label=f'SciBERT - {metric_labels[metric]}')

    for j, (model_value, sota_value) in enumerate(zip(model_values, sota_values)):
        ax.text(j - bar_width/2 - gap/2 + i*bar_width/3, model_value/2, f'{metric_labels[metric]}', ha='center', va='center', fontsize=14, fontweight='bold', color='white')
        ax.text(j + bar_width/2 + gap/2 + i*bar_width/3, sota_value/2, f'{metric_labels[metric]}', ha='center', va='center', fontsize=14, fontweight='bold', color='white')

        ax.text(j - bar_width/2 - gap/2 + i*bar_width/3, model_value + 2, f'{model_value:.1f}%', ha='center', fontsize=12)
        ax.text(j + bar_width/2 + gap/2 + i*bar_width/3, sota_value + 2, f'{sota_value:.1f}%', ha='center', fontsize=12)

ax.set_xticks(x)
ax.set_xticklabels(operators, fontsize=14)
ax.set_xlabel('Operatoren', fontsize=16, fontweight='bold', labelpad=15)
ax.set_ylabel('Score (%)', fontsize=16, fontweight='bold', labelpad=15)
ax.set_ylim(0, 105)
ax.set_yticks(np.arange(0, 101, 10))
ax.tick_params(axis='y', labelsize=14, width=2)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_title(f'Evaluation: {model_name} vs. SciBERT', fontsize=20, pad=20)
ax.legend(fontsize=12, ncol=2, loc='upper left')
ax.grid(True)

plt.tight_layout()
plt.savefig(f"pics/{model_to_plot}_vs_sota__{versuch_name}.png")
plt.show()

# %%
all_metrics
# Out:
# {' Naive greedy match (CHIA Prompt)': {'AND': {'precision': 6.897993311036789,
#    'recall': 66.3538873994638,
#    'f1': 12.496844231254734,
#    'accuracy': 66.3538873994638,
#    'total_label': 2238,
#    'total_model': 21777,
#    'correct_count': 1485,
#    'low_tp_ncts': ['NCT01214096', 'NCT02041299']},
#   'OR': {'precision': 26.174766655938203,
#    'recall': 75.21387283236994,
#    'f1': 38.834835551841465,
#    'accuracy': 75.21387283236994,
#    'total_label': 4325,
#    'total_model': 12637,
#    'correct_count': 3253,
#    'low_tp_ncts': []},
#   'NOT': {'precision': 33.50785340314136,
#    'recall': 53.333333333333336,
#    'f1': 41.157556270096464,
#    'accuracy': 53.333333333333336,
#    'total_label': 720,
#    'total_model': 1183,
#    'correct_count': 384,
#    'low_tp_ncts': ['NCT01490034']},
#   'average_missing_percentage': 1.2285005622588003,
#   'average_zuviel_percentage': 2.5148036950960035,
#   'total_missing_words': Counter({'and/or': 280,
#            '(including': 69,
#            '(as': 43,
#            'mg/dL': 40,
#            'kg/m2': 31,
#            '(or': 26,
#            'mg/dl': 25,
#            '(with': 25,
#            'g/dL': 22,
#            '(within': 20,
#            '(for': 18,
#            'mL/min': 18,
#            'ml/min': 17,
#            '(other': 14,
#            '(not': 14,
#            'ng/mL': 12,
#            '(no': 11,
#            'his/her': 11,
#            'mg/day': 9,
#            '>/=': 9,
#            '(by': 9,
#            'mmol/L': 9,
#            'IU/L': 9,
#            'kg/m2.': 9,
#            'mmol/mol': 9,
#            'mg/day,': 7,
#            '(without': 7,
#            'parent/guardian': 7,
#            'mg/dL)': 6,
#            'FEV1/FVC': 6,
#            'cells/mm3': 6,
#            'g/dl': 6,
#            'IU/ml': 6,
#            'ml/min)': 6,
#            'µmol/L': 6,
#            'mg/dl),': 5,
#            'copies/mL': 5,
#            'mL/min/1.73': 5,
#            'mg/dL.': 5,
#            '(according': 5,
#            'mmol/l': 5,
#            '(that': 5,
#            'kg/m2)': 5,
#            'he/she': 5,
#            'mg/dl)': 5,
#            'inclusion/exclusion': 4,
#            '(due': 4,
#            'parent/legal': 4,
#            'moderate-to-severe': 4,
#            '</=': 4,
#            '20/200': 4,
#            'g/L': 4,
#            '(must': 4,
#            'pg/ml': 4,
#            '140/90': 3,
#            'mEq/L': 3,
#            'ml/min/1.73m2': 3,
#            '(but': 3,
#            'kg/m2,': 3,
#            '1,000/µL': 3,
#            '(and/or': 3,
#            '(are)': 3,
#            '/aggression': 3,
#            'ng/ml': 3,
#            '<or=6': 3,
#            'cervical/vault': 3,
#            'allergy/sensitivity': 3,
#            'g/dL)': 3,
#            's/p': 3,
#            'g/dl,': 3,
#            'relapsed/refractory': 3,
#            '(of': 3,
#            'mg/g': 3,
#            'ml/min/1.73': 3,
#            '0/7': 3,
#            'mg/dl,': 3,
#            '(may': 3,
#            '109/L': 3,
#            'mmol/mol)': 3,
#            'with/without': 3,
#            'mL/min,': 3,
#            'consent/assent': 3,
#            '(to': 3,
#            'IU/mL.': 3,
#            'Baseline/Day': 3,
#            '10^9/L': 2,
#            'mL/min)': 2,
#            'chemo/radiotherapy': 2,
#            'kg/m^2': 2,
#            'parents/guardians': 2,
#            'mmol/L)': 2,
#            'mg/day).': 2,
#            '135/85': 2,
#            '170/105': 2,
#            '(requiring': 2,
#            'cc/min.': 2,
#            '(during': 2,
#            'mg/m^2;': 2,
#            '1/2': 2,
#            '20,000/µL': 2,
#            'pelvic/speculum': 2,
#            'disease-free': 2,
#            'IU/mL': 2,
#            'mg/dL,': 2,
#            '30mUI/ml': 2,
#            'Karnofsky/Lansky': 2,
#            'post-albuterol/salbutamol': 2,
#            'albuterol/salbutamol': 2,
#            'Drug/alcohol': 2,
#            'ICS/LABA': 2,
#            'y/o.': 2,
#            'medical/psychiatric': 2,
#            'finger/thumb': 2,
#            'PSA<or=10': 2,
#            'infection/inflammation': 2,
#            'U/L)': 2,
#            'treatment-naive': 2,
#            '109/l,': 2,
#            'mmol/L;': 2,
#            '60ml/min/1.73m2': 2,
#            'min/wk': 2,
#            'IVF/ICSI': 2,
#            'drug-free': 2,
#            'screening/baseline': 2,
#            'umol/ml': 2,
#            '(140-159/90-99': 2,
#            'right-to-left,': 2,
#            'right-to-left': 2,
#            'AND/OR': 2,
#            'mIU/mL': 2,
#            '3mg/dl': 2,
#            'anovulation/oligoovulation.': 2,
#            '(pg/mL)': 2,
#            'drug/alcohol': 2,
#            'seizures/week': 2,
#            'illness/social': 2,
#            'fibrillation/flutter': 2,
#            'kg/m²': 2,
#            '[including': 2,
#            '(+/-': 2,
#            '(and': 2,
#            '20/320': 2,
#            '20/25': 2,
#            '100,000/mm3': 2,
#            '150/95': 2,
#            'mg/kg/day': 2,
#            'III/IV': 2,
#            'trial/study': 2,
#            'willing/able': 2,
#            '160/90': 2,
#            'Kg/m2': 2,
#            '(AST/ALT': 2,
#            ',including': 2,
#            'million/ml': 2,
#            'ml/min).': 2,
#            'HIV/HCV': 2,
#            'pregnancy/breastfeeding)': 2,
#            '3km/h': 2,
#            '(~0.8m/s)': 2,
#            'unwilling/unable': 2,
#            'mg/dl;': 2,
#            'case-by-case': 2,
#            'albumin/creatinine': 2,
#            'mL/kg/min)': 2,
#            'h/o': 2,
#            'R/R': 2,
#            'cells/L.': 2,
#            'mL/minute': 2,
#            'mU/L': 2,
#            'electrocardiogram/hepatic': 2,
#            'function/blood': 2,
#            'gastric/duodenal': 2,
#            'Board/Ethical': 2,
#            'K/cumm': 2,
#            'ng/dL)': 2,
#            'ml/min/1,73': 2,
#            'm/s)': 2,
#            '>140/90': 2,
#            '(FEV1/FVC': 2,
#            'g/dL).': 2,
#            '40/100': 2,
#            'beats/min': 2,
#            '(200mg/dl),': 2,
#            'g/m2': 2,
#            'treatment-free': 1,
#            '(M1)/stage': 1,
#            'product/device': 1,
#            'alcohol/substance': 1,
#            'biopsy/resection': 1,
#            '1,500/mm3,': 1,
#            'gm/dl,': 1,
#            '50,000/mm3.': 1,
#            'pmol/L).': 1,
#            'condition/illness': 1,
#            '(>/=': 1,
#            'Had/have': 1,
#            'prior/concurrent': 1,
#            'drugs/agents': 1,
#            'sulfonylurea/metformin': 1,
#            'kg/m^2.': 1,
#            '≥1,500/µL,': 1,
#            'g/dL,and': 1,
#            '≥100,000/µL)': 1,
#            '(but,': 1,
#            'ml/minute.': 1,
#            'mmol/L).': 1,
#            'mIU/mL;': 1,
#            'mIU/mL.': 1,
#            '100.000/µl': 1,
#            '<30ml/min)': 1,
#            '(ALT)/aspartate': 1,
#            '>1g/day': 1,
#            '2.0mg/dL': 1,
#            'gastrointestinal/rectal': 1,
#            'function/injury': 1,
#            'runny/blocked/itchy': 1,
#            '(NINCDS/ADRDA)': 1,
#            'FEV1/Inspiratory': 1,
#            '50ug/hr': 1,
#            'Tramadol/Acetaminophen': 1,
#            '(ng/ml):': 1,
#            '>_3500/mm3,': 1,
#            '>_100,000/mm3.': 1,
#            'III/IV),or': 1,
#            '(Benadryl®)for': 1,
#            'ALT/AST>3x': 1,
#            'probability(by': 1,
#            '(BMI=40kg/m2)': 1,
#            '120mg/m^2': 1,
#            'mg/m^2.': 1,
#            'disease(with': 1,
#            'Melan-A/MART-1': 1,
#            '10.5g/dl,': 1,
#            'corticosteroids/other': 1,
#            'beats/min),': 1,
#            '11.5g/dL': 1,
#            '[BCR/ABL+]': 1,
#            '[MLL/AF4+].': 1,
#            '0-to-10': 1,
#            'sensitivity/allergy': 1,
#            '<60/min': 1,
#            '<30,000/mm3': 1,
#            'QT/QTc': 1,
#            'dementia/cognitive': 1,
#            'IU/mL)': 1,
#            'cells/μL': 1,
#            'cells/μL).': 1,
#            'Gms/dL.': 1,
#            'chemo/radiation': 1,
#            '>1,500/microL': 1,
#            '>100,000/microL': 1,
#            'national/local': 1,
#            'allergy/hypersensitivity': 1,
#            '<60mL/min': 1,
#            'Board/Ethics': 1,
#            'cells/mm3.': 1,
#            '150µmol/L).': 1,
#            'psychotropics(with': 1,
#            'HIV/AIDS).': 1,
#            'patient/guardian.': 1,
#            'Patient/guardian': 1,
#            ',or': 1,
#            '/dl,': 1,
#            'potassium<3.2mmol/L,': 1,
#            'or>5.5mmol/L;': 1,
#            'scar/change': 1,
#            'inflammation/infection': 1,
#            'disease(ESRD)/chronic': 1,
#            'Hb<10g/dL': 1,
#            'count<100,000/μL': 1,
#            '(FEV1)/(forced': 1,
#            ')with': 1,
#            'moderate/severe': 1,
#            'diseases/abnormalities:': 1,
#            'Drug/food': 1,
#            'kg/m2;': 1,
#            'weight(Kg)/height(m2).': 1,
#            '<1,500/mm3)': 1,
#            '90,000/mm3)': 1,
#            'g/day),': 1,
#            'orphans/vulnerable': 1,
#            '[IRB]/Independent': 1,
#            '1x/wk': 1,
#            'min/session': 1,
#            'lamivudine/adefovir': 1,
#            'IU/ml)': 1,
#            'mg/dl.': 1,
#            '(BCR/ABL)': 1,
#            '<or=10': 1,
#            'cancer,or': 1,
#            'chemotherapy,and': 1,
#            'creatinine(>1.5mg/dl)': 1,
#            '20mg/d),': 1,
#            '40mg/d),': 1,
#            '50mg/d),': 1,
#            '150mg/d),': 1,
#            '45mg/d),': 1,
#            '60mg/d)': 1,
#            'ER(150-225mg/d)': 1,
#            'cells/mm3if': 1,
#            'cells/mm3or': 1,
#            '<30mL/minute': 1,
#            'CYP3A4/P-glycoprotein': 1,
#            '(AST/ALT>2x': 1,
#            'ng/mL.': 1,
#            '20/70;': 1,
#            'cells/mm3,': 1,
#            'simvastatin/lovastatin': 1,
#            'cells/mm3),': 1,
#            'cells/mm3)': 1,
#            'mg/l': 1,
#            'cord/cauda': 1,
#            'd/α/β),': 1,
#            'α/β': 1,
#            '75,000/ml': 1,
#            '9gm/dl': 1,
#            '3.5/ml': 1,
#            'negative/HBcAb': 1,
#            'positive/hepatitis': 1,
#            'at/above': 1,
#            'ERCP/PTC': 1,
#            '(have': 1,
#            'foam/gel/film/cream/vaginal': 1,
#            '<24/30': 1,
#            'left/right': 1,
#            '(who': 1,
#            'events/hour': 1,
#            '(>170/>110)': 1,
#            '180/100': 1,
#            'DDAVP/Stimate': 1,
#            'IIIB/IV': 1,
#            'EGF/EGFR': 1,
#            '9g/dl,': 1,
#            'studies/registries': 1,
#            'knee/hip': 1,
#            '<100,000/mm3': 1,
#            '5-fluorouracil/leucovorin': 1,
#            '(5-FU/LV)': 1,
#            'parent/legally': 1,
#            'illness/infection': 1,
#            'DoD/VA': 1,
#            '(besides': 1,
#            'm/sec': 1,
#            '140/90,': 1,
#            'equivalent/L': 1,
#            '1)or': 1,
#            'cerebral/meningeal': 1,
#            'rest/ice': 1,
#            'skin/soft': 1,
#            'skin/soft-tissue': 1,
#            '100.000/µL': 1,
#            'L/d),': 1,
#            'rifampin/rifampicin,': 1,
#            '100µg/l': 1,
#            'µg/l,': 1,
#            'mg/L,': 1,
#            'HIV/AIDS.': 1,
#            'Oligomenorrhea/amenorrhea': 1,
#            'CLL/SLL': 1,
#            '1-3A/iNHL,': 1,
#            'LPL/WM,': 1,
#            'CLL/SLL,': 1,
#            'MF/SS)': 1,
#            '/refractory': 1,
#            'CT/PET': 1,
#            '1000/uL': 1,
#            '75,000/uL,': 1,
#            '20.0mg/dL': 1,
#            'AST/AST': 1,
#            'HIV/Hep': 1,
#            'gastric/bowel': 1,
#            '<150/95mmHg': 1,
#            '=135/85': 1,
#            '<150/95.': 1,
#            '(ALT/AST>50IU/L)': 1,
#            'durg-naive': 1,
#            'NK/T-cell': 1,
#            'ml/h)': 1,
#            '100.000/mm3;': 1,
#            'gm/day)': 1,
#            'ER/PR': 1,
#            '(20g/day': 1,
#            '30g/day': 1,
#            'aminotransferase/alanine': 1,
#            'planing/being': 1,
#            '159/99': 1,
#            'or/and': 1,
#            'B/C': 1,
#            'ANC>1000/mcl': 1,
#            'platelets>100,000/mcl.': 1,
#            'yes/no': 1,
#            'weeks)/low': 1,
#            'mL/kg': 1,
#            'mg/kg/d': 1,
#            'PET/MRI': 1,
#            'ng/dl': 1,
#            'milliunits/milliliter': 1,
#            '(mU/mL)': 1,
#            '(renal/hepatic': 1,
#            'Current/recent': 1,
#            'parents/patients.': 1,
#            'Mild-to-moderate': 1,
#            '6/7': 1,
#            '50mg/dl': 1,
#            '80U/L': 1,
#            'artifacts/components': 1,
#            '(absence': 1,
#            'is/are': 1,
#            "investigator's/designee's": 1,
#            '(MlU/mL)': 1,
#            '60mL/min/1.73m2)': 1,
#            'equivalents/day.': 1,
#            'beats/minute': 1,
#            'parent/guardian.': 1,
#            'tooth)of': 1,
#            'medical/surgical': 1,
#            'bleeding/clotting': 1,
#            'substance/alcohol': 1,
#            'disease/inflammation': 1,
#            '01/01/2010': 1,
#            '30/09/2013': 1,
#            'attempt/week)': 1,
#            'ng/dL,': 1,
#            'difficult-to-detect': 1,
#            'height/weight': 1,
#            '2400/microl,': 1,
#            'amphetamine/methamphetamine,': 1,
#            'ADHD/LD': 1,
#            'g/dL])': 1,
#            'TPV/r': 1,
#            'Hgb<11g/dL,': 1,
#            'Hct<30g/dL,': 1,
#            '>240mg/dL,': 1,
#            '>500mg/dL,': 1,
#            '>130mg/dL,': 1,
#            'µmol/l)': 1,
#            '<150,000/mm3': 1,
#            '[kilogram(kg)]/height^2': 1,
#            'kg/m^2,': 1,
#            'foam/gel/film/cream/suppository': 1,
#            'foam/gel/film/cream/suppository,': 1,
#            '=(mPAP-PCWP)/CO]>3.0': 1,
#            'count<100,000/L': 1,
#            '<1g/L': 1,
#            'differentiated/de-differentiated': 1,
#            'sarcoma/MFH': 1,
#            'CT/MRI': 1,
#            'asthma/atopy': 1,
#            'nursing/breastfeeding.': 1,
#            '10^9/Liter': 1,
#            '10^9/L,': 1,
#            'gram/deciliter': 1,
#            '(g/dL).': 1,
#            'arterial/venous': 1,
#            '/In': 1,
#            'µmol/L)': 1,
#            'copies/ml': 1,
#            'mmol/L,': 1,
#            'systolic/diastolic': 1,
#            '=128/78': 1,
#            '30ml/min).': 1,
#            'DSM-IV/V': 1,
#            '/5),': 1,
#            'ICD-10/DSM-IV/V,': 1,
#            '(ACC/AHA': 1,
#            'cell/mL),': 1,
#            'g/dL),': 1,
#            'cell/mL).': 1,
#            '20/50': 1,
#            'intravitreal/periocular': 1,
#            'complications/vitreous': 1,
#            'Pd/Pa': 1,
#            'Pd/Pa)': 1,
#            '1250/ul': 1,
#            '100,000/ul': 1,
#            '*28/*28': 1,
#            'ALT/AST': 1,
#            'Allergy/hypersensitivity': 1,
#            'Subject/Caregiver': 1,
#            '(BP>140/90': 1,
#            'x109/L': 1,
#            'severe/unstable': 1,
#            'coronary/peripheral': 1,
#            '=7mmol/l': 1,
#            '=11mmol/l': 1,
#            '7.0mmol/L': 1,
#            '48mmol/mol);': 1,
#            '130µmol/L/': 1,
#            '4.0ng/mL': 1,
#            '1.7mg/dL': 1,
#            'anesthesia/procedures': 1,
#            '20/30': 1,
#            'hours/day': 1,
#            'hours/day)': 1,
#            'clotting/coagulation': 1,
#            'ml/min),': 1,
#            '<100,000/µL': 1,
#            'mmol/l))': 1,
#            'clearance>50ml/min': 1,
#            '(in': 1,
#            '<140/90': 1,
#            'drug/solvent': 1,
#            'platinum-free': 1,
#            'AST/ALT:': 1,
#            'anti-PD1/anti-PD-L1': 1,
#            'Desire/intent': 1,
#            'trimethoprim/sulphamethoxazole': 1,
#            'piperacillin/tazobactam)': 1,
#            '=/>130': 1,
#            'LDL=/>130': 1,
#            '=/>150': 1,
#            'close/intimate': 1,
#            'days/week': 1,
#            'drinks/day)': 1,
#            'cells/µL,': 1,
#            'moderate/good': 1,
#            'eGFR=60(ml/min/1.73': 1,
#            '2/3': 1,
#            'parent/care': 1,
#            '500/µL.': 1,
#            '(E/CIA)': 1,
#            'E/CIA,': 1,
#            'E/CIA': 1,
#            '(TAF)/TAF-containing': 1,
#            '(COBI)/COBI-containing': 1,
#            'TAF/TAF-containing': 1,
#            'COBI/COBI-containing': 1,
#            'copies/mL.': 1,
#            '500/mm^3': 1,
#            '40,000/mm^3': 1,
#            'www.fstrf.org/ACTG/ccc.html': 1,
#            'signs/symptoms': 1,
#            ')/T': 1,
#            'test:WBC=3.0×109/L,Neutrophils=1.5×109/L,Hb=100g/L,Platelet=80×109/L;': 1,
#            'mg/m2,': 1,
#            'mg/m2;': 1,
#            'mol/L': 1,
#            '[no': 1,
#            'study/trial': 1,
#            'agonist/antagonist': 1,
#            '(polyester/ethyl': 1,
#            'DAS28/Erythrocyte': 1,
#            'dapsone-naive.': 1,
#            '1-4h,and': 1,
#            '<50/min.': 1,
#            '/min': 1,
#            '/1,73m),': 1,
#            'evenings/nights': 1,
#            'BMI-for-age': 1,
#            'diseases/drugs': 1,
#            'packs/year': 1,
#            '20/70': 1,
#            'hypotension/capillary': 1,
#            'leak/life': 1,
#            'Pregnant/breast-feeding': 1,
#            'schizophrenia/schizoaffective': 1,
#            'Spontaneous/Induced/Augmented': 1,
#            'H/o': 1,
#            '<or=': 1,
#            '(Ag/Ab': 1,
#            '>140/90,': 1,
#            '+/-': 1,
#            '30Kg/m2': 1,
#            '30ml/min/1.73m2),': 1,
#            'stroke/TIA': 1,
#            'U/L),': 1,
#            '<2.2mg/dl,': 1,
#            'pain(including': 1,
#            'ventilation/perfusion': 1,
#            'overload/dysfunction': 1,
#            'mg/day;': 1,
#            'volume/Forced': 1,
#            'medications/materials:': 1,
#            'acquired/inherited': 1,
#            'IgG/IgM,': 1,
#            'mild/moderate': 1,
#            '(>1/40': 1,
#            '=/>': 1,
#            'cardiovascular/pulmonary': 1,
#            'mmol/mol.': 1,
#            'mmol/l).': 1,
#            'g/l)': 1,
#            'ml/mn': 1,
#            'acid/Cyklokapron®': 1,
#            'III/IV±V': 1,
#            '(ISN/RPS': 1,
#            'protein/creatinine': 1,
#            'micromol/L': 1,
#            'mg/D': 1,
#            'g/D': 1,
#            'g/L,': 1,
#            'g/L)': 1,
#            'haemoglobinopathy/thalassaemia': 1,
#            'trauma/surgery': 1,
#            'abuse/dependence': 1,
#            'CVA/TIA': 1,
#            'Accident/Transient': 1,
#            '(AST)/Alanine': 1,
#            'milliliters/minute/1.73': 1,
#            'arthritis/autoimmune': 1,
#            'mL/min/1.7m2': 1,
#            'mg/day),': 1,
#            '<20/200.': 1,
#            'dyn•s/cm5': 1,
#            'WHO/NYHA-FC': 1,
#            'systemic-to-pulmonary': 1,
#            'disorders/symptoms': 1,
#            'Significant/chronic': 1,
#            'ml/min;': 1,
#            'g/l;': 1,
#            'g/l': 1,
#            'cels/mm3': 1,
#            'cels/mm3;': 1,
#            '20-of': 1,
#            '20/40': 1,
#            'Inclusion/exclusion': 1,
#            'III/IV)': 1,
#            'fusion/other': 1,
#            '109/L,': 1,
#            '9g/dL,': 1,
#            'AST/ALT': 1,
#            'stools/24': 1,
#            'apnea/hypopnea': 1,
#            '10/hour;': 1,
#            '1hour/day;': 1,
#            '/L.': 1,
#            '109/L.': 1,
#            '9g/dL.': 1,
#            'ml/min.': 1,
#            'HBV/HIV': 1,
#            '[or': 1,
#            'parent/guardian]': 1,
#            '3.5g/dl,': 1,
#            '1.5mg/dl': 1,
#            '5.0mg/dl': 1,
#            '1a/ab.': 1,
#            'Baseline/Day1': 1,
#            '/min,': 1,
#            'LDV/SOF': 1,
#            '<30x109/l': 1,
#            '30x109/l': 1,
#            '50mL/min': 1,
#            'aminotransferase)/ALT(alanine': 1,
#            'hours/day.': 1,
#            '1km/day.': 1,
#            '8hours/day': 1,
#            'mg/kg/day,': 1,
#            '180/110': 1,
#            'disorder/diathesis': 1,
#            'cc/day': 1,
#            '>10mg/day': 1,
#            '(weight-for-height': 1,
#            '<4000/uL,': 1,
#            '<9g/dl': 1,
#            '/l': 1,
#            'vaccine/placebo,': 1,
#            'patients,with': 1,
#            'lesions,according': 1,
#            '10mm,on': 1,
#            '2×10^9/L': 1,
#            '100×10^9/L': 1,
#            'g/dL;': 1,
#            'mL/min;': 1,
#            'mg/g,': 1,
#            'mg/day)': 1,
#            'mIU/ml': 1,
#            'mg/dL.)': 1,
#            'mL/min),': 1,
#            'injections/or': 1,
#            'protocol-excluded': 1,
#            '(joint/musculoskeletal,': 1,
#            'BMI>=35kg/m2': 1,
#            'SOF/LDV': 1,
#            'tipranavir/ritonavir': 1,
#            '50,000/mm3': 1,
#            'mL/min.': 1,
#            'nucleoside/nucleotide': 1,
#            'Pa02/Fi02': 1,
#            'Pre-existing/chronic': 1,
#            '100,000/ml': 1,
#            'ng/mg': 1,
#            'procedures/treatments.': 1,
#            'tooth/teeth': 1,
#            'endodontic/periodontal': 1,
#            'units/day.': 1,
#            'assay)or': 1,
#            'transaminase/alkaline': 1,
#            '(AST/ALT)': 1,
#            '≥10000UI/mL.': 1,
#            'mg/d).': 1,
#            'g/dL.': 1,
#            '3g/dL.': 1,
#            'including(but': 1,
#            'mg/d,': 1,
#            'mg/d.': 1,
#            'U/S': 1,
#            'Hemosiderosis/hemochromatosis': 1,
#            'than/equals': 1,
#            'prednisone/prednisolone': 1,
#            '3g/dL': 1,
#            'next-of-kin).': 1,
#            'osteomyelitis/septic': 1,
#            '150,000/mmc.': 1,
#            'g/day': 1,
#            'Intolerance/allergy': 1,
#            'Exposure/treatment': 1,
#            'periorbital/forehead': 1,
#            'breaths/minute': 1,
#            'head-of-bed': 1,
#            'mg/kg/h': 1,
#            'an/or': 1,
#            '(on': 1,
#            '<2.0g/dL': 1,
#            '>2.0mg/dL': 1,
#            '>18gm/dL': 1,
#            '<7gm/dL': 1,
#            'BNP>300pg/ml': 1,
#            'injury/failure': 1,
#            'miscarriage/abortion': 1,
#            'obstruction/blockage': 1,
#            'bowel/rectal': 1,
#            '15/15': 1,
#            '45kg/m2': 1,
#            'frequency/severity': 1,
#            'HA-free': 1,
#            'sedative/hypnotics),': 1,
#            '"as-needed"': 1,
#            '40g/day)': 1,
#            "SSRIs/SNRI's": 1,
#            'thrombophilia/thrombosis': 1,
#            'OB/GYN': 1,
#            '35kg/m2': 1,
#            "E/E'": 1,
#            '120/min.': 1,
#            'University/Barnes-Jewish': 1,
#            'gram/day': 1,
#            'g/l),': 1,
#            'speaking/literate': 1,
#            'speaking/illiterate': 1,
#            '150,000/cubic': 1,
#            'autoimmune/inflammatory': 1,
#            '145/90': 1,
#            'IU/l': 1,
#            'ng/l': 1,
#            '(IUD/IUS)': 1,
#            'infection/year': 1,
#            '(MI/heart': 1,
#            'pg/mL)': 1,
#            'drinks/week)': 1,
#            '12g/dL': 1,
#            'SGOT/SGPT': 1,
#            '1000cp/ml': 1,
#            '1mg/kg/d': 1,
#            'HBV/HCV/HIV': 1,
#            '(dronabinol/marijuana/cannabis/THC,': 1,
#            'acceleration/deceleration': 1,
#            'shrapnel/retained': 1,
#            'alcohol/drug': 1,
#            '<15mmol/L(270mg/dL)': 1,
#            'm/s': 1,
#            'Patients/physicians': 1,
#            'situations/substance': 1,
#            'Oral/Oropharynx': 1,
#            '60mg/day': 1,
#            'mL/h': 1,
#            'mL/injection': 1,
#            'mL/h)': 1,
#            'allergy/contra-indication': 1,
#            'neuropathy/sensory': 1,
#            'm/s,': 1,
#            'drinks/day': 1,
#            'hepatocellular/cholangiocarcinoma': 1,
#            'y/o': 1,
#            'maintenance/extended-use': 1,
#            '1,000/mcL': 1,
#            '75,000/mcL': 1,
#            'Moderate/Weak': 1,
#            'point-of-care': 1,
#            'T2/FLAIR': 1,
#            'FA/ICGA': 1,
#            'and/or,': 1,
#            'PO/NG': 1,
#            '5mg/ml,': 1,
#            '-10mIU/L,': 1,
#            'ml/min/1.73m2).': 1,
#            'U/L).': 1,
#            '20/32': 1,
#            'or/discharge': 1,
#            'of/suspected': 1,
#            'Allergy/intolerance': 1,
#            'husband/wife,': 1,
#            '5ng/mL': 1,
#            'nephropathy/retinopathy/neuropathy': 1,
#            'spondylolisthesis/spondylosis/spondylolysis': 1,
#            'Immunosuppressed/immune': 1,
#            'Allergy/interlerance': 1,
#            'units/week,': 1,
#            'units/week.': 1,
#            'read/understand': 1,
#            'beat/min': 1,
#            'bigemini/trigeminy': 1,
#            'mmol/L.': 1,
#            'finger/fingers': 1,
#            '(Xiapex/Xiaflex': 1,
#            'cell=3.5×109/L,': 1,
#            '=1.5×109/L,': 1,
#            '=80g/L,': 1,
#            'platelet>100×109/L;': 1,
#            '50ml/min': 1,
#            '3g/dl': 1,
#            '103/mL': 1,
#            '5mIU/mL)': 1,
#            'UI/ml': 1,
#            '250mg/dL': 1,
#            '=70mg/dL': 1,
#            '160mg/dL': 1,
#            'TG<500mg/dL': 1,
#            'ml/min,': 1,
#            'consent/refusal': 1,
#            '30ml/min)': 1,
#            "Stroke/Alzheimer's": 1,
#            'Severe/untreated': 1,
#            'mg/dL).': 1,
#            'pg/mL': 1,
#            'IIb/IIIa': 1,
#            '<80x106/mL': 1,
#            'ml/min/': 1,
#            'mL/min/1.73m2.': 1,
#            'parental/patient': 1,
#            'Pregnancy/breastfeeding': 1,
#            'do-not-resuscitate': 1,
#            'Pregnant/lactating': 1,
#            'Roche/Genentech': 1,
#            'Sensistivity/allergy': 1,
#            'U/L': 1,
#            'µmol/L,': 1,
#            '[m/s],': 1,
#            'calories/day)': 1,
#            'mmol/mol).': 1,
#            'Unstable/rapidly': 1,
#            'donation/blood': 1,
#            'Interleukin-12/23': 1,
#            '(IL-12/23),': 1,
#            'its/their': 1,
#            'opioids/opiates,': 1,
#            '(>160/100mmHg)': 1,
#            '(<40mg/dl': 1,
#            'overweight/lean': 1,
#            'moderate/high': 1,
#            'times/week).': 1,
#            '(>160/100': 1,
#            'leg/back': 1,
#            'L5/S1,': 1,
#            'bowel/bladder': 1,
#            'chemical/alcohol': 1,
#            'Aripiprazole>30mg/day,': 1,
#            'Olanzapine>20mg/day,': 1,
#            '6mg/day,': 1,
#            '750mg/day)': 1,
#            'smoked/20]': 1,
#            'ICS/LABA)': 1,
#            'RELVAR/BREO': 1,
#            'Salbutamol/Albuterol': 1,
#            'hypersensitivity/intolerance': 1,
#            'disease/condition': 1,
#            '<100g/L;': 1,
#            'pack/day': 1,
#            'FEV1/FVC>0.70': 1,
#            '(ICSI)/Fertilization': 1,
#            '(IU/L)': 1,
#            '(ng/mL)': 1,
#            '(kg/m^2)': 1,
#            'O/Randomization)': 1,
#            'picogram/milliliter': 1,
#            '0/Randomization)': 1,
#            '[ESHRE]/American': 1,
#            'SOF/VEL': 1,
#            'drugs(including': 1,
#            'Overweight/Obese': 1,
#            '=140/90': 1,
#            'g/dl)': 1,
#            '30g/L);': 1,
#            '200umol/L;': 1,
#            '150/100': 1,
#            '6mg/ml': 1,
#            'tobacco/nicotine': 1,
#            '32kg/m2).': 1,
#            '(PO/IV/IM)': 1,
#            'vaccine/product': 1,
#            'Emergent/elective': 1,
#            'HCV/HBV': 1,
#            '105/mm3;': 1,
#            '(2.7mmol/L);': 1,
#            'race/ethnicity,': 1,
#            'pharmacokinetic/pharmacodynamics': 1,
#            'methylprednisolone/prednisone': 1,
#            'pmol/L': 1,
#            'ng/dL': 1,
#            'parent(s)/legally': 1,
#            'parent/LAR': 1,
#            '5.6mmol/L': 1,
#            '(100mg/dl)=FPG<7.0mmol/L': 1,
#            '(126mg/dl),': 1,
#            '7.8mmol/L': 1,
#            '(140mg/dl)=OGTT': 1,
#            'PG<11.1mmol/L': 1,
#            '(39-47mmol/mol);': 1,
#            '2.6mmol/L': 1,
#            '(100mg/dl)=LDL-C=5.2mmol/L': 1,
#            'TG<5.7mmol/L': 1,
#            '(500mg/dl);': 1,
#            'male<120ml/min,': 1,
#            'female<105ml/min,': 1,
#            'creatinine=2mg/dl': 1,
#            '(186umol/L),': 1,
#            '3sessions/wk.': 1,
#            '6/10': 1,
#            'hypersensitivity/allergy': 1,
#            '5/10': 1,
#            'meq/L': 1,
#            '>/=18': 1,
#            'terazosin/doxazosin/alfuzosin/silodosin)': 1,
#            'pg/ml)': 1,
#            'mL/m2': 1,
#            "(E/e'=13": 1,
#            'cm/s).': 1,
#            '11g/dl,': 1,
#            'ml/min/1.73m2)': 1,
#            'surgical/percutaneous': 1,
#            'PCI/MI': 1,
#            'mL/beat,': 1,
#            'ICD/CRT-D.': 1}),
#   'total_zuviel_words': Counter({'or': 317,
#            '(': 305,
#            'and/': 284,
#            'mg/': 137,
#            'dL': 78,
#            'including': 75,
#            'kg/': 63,
#            'L': 58,
#            'g/': 57,
#            'min': 44,
#            'mL/': 43,
#            'as': 43,
#            'ml/': 43,
#            'dl': 42,
#            'm2': 40,
#            'mmol/': 37,
#            'with': 29,
#            'ml': 28,
#            'mL': 26,
#            'min/': 26,
#            'day': 23,
#            'ng/': 23,
#            'IU/': 23,
#            'within': 20,
#            'for': 19,
#            'cells/': 17,
#            'other': 16,
#            'parent/': 16,
#            'l': 15,
#            '=': 14,
#            'not': 14,
#            '20/': 14,
#            'dl,': 13,
#            'no': 13,
#            'mm3': 13,
#            'min)': 12,
#            'dL)': 12,
#            '/': 12,
#            'day,': 11,
#            '90': 11,
#            'his/': 11,
#            'her': 11,
#            'L,': 11,
#            'dL,': 10,
#            '>/': 10,
#            'by': 10,
#            'without': 10,
#            '1.73': 10,
#            'dL.': 9,
#            'm2.': 9,
#            'µmol/': 9,
#            'mol': 9,
#            'dl),': 8,
#            'L)': 8,
#            'FEV1/': 8,
#            'FVC': 8,
#            'mL)': 8,
#            'guardian': 8,
#            'free': 7,
#            'mL.': 7,
#            'µL': 7,
#            'copies/': 7,
#            'L;': 7,
#            'dl)': 7,
#            '109/': 7,
#            'day)': 7,
#            'min,': 7,
#            'pg/': 7,
#            'and': 6,
#            'min.': 6,
#            'm2)': 6,
#            'alcohol': 6,
#            'd),': 6,
#            'U/': 6,
#            'according': 6,
#            'exclusion': 5,
#            'mIU/': 5,
#            '1.73m2': 5,
#            'III/': 5,
#            'allergy/': 5,
#            'HIV/': 5,
#            '<': 5,
#            'minute': 5,
#            '100': 5,
#            'm/': 5,
#            'of': 5,
#            'that': 5,
#            'he/': 5,
#            'she': 5,
#            'L.': 5,
#            '10^9/': 4,
#            'L).': 4,
#            '140/': 4,
#            'inclusion/': 4,
#            'but': 4,
#            'beats/': 4,
#            'm2,': 4,
#            '1,000/': 4,
#            'allergy': 4,
#            'due': 4,
#            'salbutamol': 4,
#            'legal': 4,
#            'moderate-': 4,
#            'to-severe': 4,
#            '(AST/': 4,
#            '</': 4,
#            'refractory': 4,
#            '200': 4,
#            'right-': 4,
#            '0/': 4,
#            '7': 4,
#            'day.': 4,
#            '[': 4,
#            'dL).': 4,
#            '100,000/': 4,
#            'must': 4,
#            'consent/': 4,
#            'o': 4,
#            'Baseline/': 4,
#            'h': 4,
#            's)': 4,
#            'treatment-': 3,
#            'chemo/': 3,
#            'mm3,': 3,
#            'mm3.': 3,
#            'm^2': 3,
#            'parents/': 3,
#            '100.000/': 3,
#            '85': 3,
#            'mEq/': 3,
#            'function/': 3,
#            'cc/': 3,
#            'min),': 3,
#            'are)': 3,
#            'Board/': 3,
#            'aggression': 3,
#            ',': 3,
#            'chronic': 3,
#            'moderate/': 3,
#            'Drug/': 3,
#            'ICS/': 3,
#            'mm3)': 3,
#            'wk': 3,
#            'y/': 3,
#            'medical/': 3,
#            'finger/': 3,
#            'or=6': 3,
#            'or=10': 3,
#            'infection/': 3,
#            'inflammation': 3,
#            '75,000/': 3,
#            'naive': 3,
#            'cervical/': 3,
#            'vault': 3,
#            'foam/': 3,
#            'gel/': 3,
#            'film/': 3,
#            'cream/': 3,
#            'sensitivity': 3,
#            'IV': 3,
#            'l,': 3,
#            '9g/': 3,
#            's/': 3,
#            'p': 3,
#            'illness/': 3,
#            'relapsed/': 3,
#            'AST/': 3,
#            'gastric/': 3,
#            'mm3;': 3,
#            'g': 3,
#            'hepatic': 3,
#            'drug/': 3,
#            'week': 3,
#            'may': 3,
#            '30ml/': 3,
#            'min).': 3,
#            '-': 3,
#            'Allergy/': 3,
#            'hours/': 3,
#            '=/': 3,
#            'drinks/': 3,
#            'mol)': 3,
#            '150/': 3,
#            'with/': 3,
#            'E/': 3,
#            'assent': 3,
#            'to': 3,
#            '>140/': 3,
#            'ALT': 3,
#            'creatinine': 3,
#            'Day': 3,
#            'units/': 3,
#            '3g/': 3,
#            'blood': 3,
#            'radiotherapy': 2,
#            'alcohol/': 2,
#            'substance': 2,
#            'gm/': 2,
#            '50,000/': 2,
#            'pmol/': 2,
#            'have': 2,
#            'm^2.': 2,
#            'µL,': 2,
#            'guardians': 2,
#            'day).': 2,
#            '135/': 2,
#            '170/': 2,
#            '105': 2,
#            'rectal': 2,
#            'requiring': 2,
#            '(ng/': 2,
#            'during': 2,
#            'ALT/': 2,
#            'm^2;': 2,
#            '1/': 2,
#            '2': 2,
#            '20,000/': 2,
#            'pelvic/': 2,
#            'speculum': 2,
#            'disease-': 2,
#            'μL': 2,
#            'microL': 2,
#            'hypersensitivity': 2,
#            '30mUI/': 2,
#            'Karnofsky/': 2,
#            'Lansky': 2,
#            'guardian.': 2,
#            'infection': 2,
#            'count<100,000/': 2,
#            'post-albuterol/': 2,
#            'albuterol/': 2,
#            'diseases/': 2,
#            'LABA': 2,
#            'm2;': 2,
#            'day),': 2,
#            'o.': 2,
#            'ml)': 2,
#            'psychiatric': 2,
#            'thumb': 2,
#            'PSA<': 2,
#            '50mg/': 2,
#            '60mg/': 2,
#            'd)': 2,
#            'α/': 2,
#            '30': 2,
#            '180/': 2,
#            '60ml/': 2,
#            '<100,000/': 2,
#            'legally': 2,
#            '90,': 2,
#            'skin/': 2,
#            'IVF/': 2,
#            'ICSI': 2,
#            'L/': 2,
#            'CLL/': 2,
#            'CT/': 2,
#            'uL,': 2,
#            'AST': 2,
#            '<150/': 2,
#            'drug-': 2,
#            'h)': 2,
#            'screening/': 2,
#            'baseline': 2,
#            'umol/': 2,
#            '30g/': 2,
#            '(140-159/': 2,
#            '90-99': 2,
#            'to-left,': 2,
#            'to-left': 2,
#            'or/': 2,
#            'd': 2,
#            'MRI': 2,
#            'AND/': 2,
#            'OR': 2,
#            'milliliter': 2,
#            '6/': 2,
#            '3mg/': 2,
#            'anovulation/': 2,
#            'oligoovulation.': 2,
#            '(pg/': 2,
#            '1.73m2)': 2,
#            'seizures/': 2,
#            'social': 2,
#            'disease/': 2,
#            '01/': 2,
#            'week)': 2,
#            'fibrillation/': 2,
#            'flutter': 2,
#            'm²': 2,
#            'l)': 2,
#            'gram/': 2,
#            'DSM-IV/': 2,
#            '(+/': 2,
#            'cell/': 2,
#            '320': 2,
#            'Pd/': 2,
#            'ul': 2,
#            'mol);': 2,
#            '25': 2,
#            '>130': 2,
#            '95': 2,
#            '500/': 2,
#            '(E/': 2,
#            'TAF-containing': 2,
#            'COBI-containing': 2,
#            'mm^3': 2,
#            'symptoms': 2,
#            'study': 2,
#            'trial/': 2,
#            'willing/': 2,
#            'able': 2,
#            'year': 2,
#            'Pregnant/': 2,
#            '160/': 2,
#            'Kg/': 2,
#            'TIA': 2,
#            'L),': 2,
#            'day;': 2,
#            'million/': 2,
#            '40': 2,
#            'D': 2,
#            'HCV': 2,
#            'min;': 2,
#            'cels/': 2,
#            'pregnancy/': 2,
#            'breastfeeding)': 2,
#            'HIV': 2,
#            'HBV/': 2,
#            '3km/': 2,
#            '(~0.8m/': 2,
#            'unwilling/': 2,
#            'unable': 2,
#            'dl;': 2,
#            'vaccine/': 2,
#            'case-': 2,
#            'by-case': 2,
#            'on': 2,
#            'albumin/': 2,
#            'h/': 2,
#            'SOF/': 2,
#            'R/': 2,
#            'R': 2,
#            '150,000/': 2,
#            'mU/': 2,
#            'electrocardiogram/': 2,
#            'duodenal': 2,
#            'bowel/': 2,
#            'Ethical': 2,
#            'K/': 2,
#            'cumm': 2,
#            'speaking/': 2,
#            '1,73': 2,
#            'HCV/': 2,
#            'mcL': 2,
#            'intolerance': 2,
#            '(FEV1/': 2,
#            '(>160/': 2,
#            '40/': 2,
#            '6mg/': 2,
#            'hypersensitivity/': 2,
#            'Randomization)': 2,
#            'L);': 2,
#            '(100mg/': 2,
#            '(200mg/': 2,
#            '10': 2,
#            'stage': 1,
#            '(M1)/': 1,
#            'product/': 1,
#            'device': 1,
#            'biopsy/': 1,
#            'resection': 1,
#            '1,500/': 1,
#            'condition/': 1,
#            'illness': 1,
#            '(>/': 1,
#            'Had/': 1,
#            'prior/': 1,
#            'concurrent': 1,
#            'drugs/': 1,
#            'agents': 1,
#            'metformin': 1,
#            'sulfonylurea/': 1,
#            '≥1,500/': 1,
#            '≥100,000/': 1,
#            'µL)': 1,
#            'but,': 1,
#            'minute.': 1,
#            'mL;': 1,
#            'µl': 1,
#            '<30ml/': 1,
#            '(ALT)/': 1,
#            'aspartate': 1,
#            '>1g/': 1,
#            '2.0mg/': 1,
#            'gastrointestinal/': 1,
#            'injury': 1,
#            'runny/': 1,
#            'blocked/': 1,
#            'itchy': 1,
#            '(NINCDS/': 1,
#            'ADRDA)': 1,
#            'Inspiratory': 1,
#            '50ug/': 1,
#            'hr': 1,
#            'Tramadol/': 1,
#            'Acetaminophen': 1,
#            'ml):': 1,
#            '>_3500/': 1,
#            '>_100,000/': 1,
#            'IV),': 1,
#            '(Benadryl®)': 1,
#            'AST>3x': 1,
#            'probability(': 1,
#            '(BMI=40kg/': 1,
#            '120mg/': 1,
#            'disease(': 1,
#            'Melan-A/': 1,
#            'MART-1': 1,
#            '10.5g/': 1,
#            'corticosteroids/': 1,
#            '11.5g/': 1,
#            '[BCR/': 1,
#            'ABL+]': 1,
#            '[MLL/': 1,
#            'AF4+].': 1,
#            '0-': 1,
#            'to-10': 1,
#            'sensitivity/': 1,
#            '<60/': 1,
#            '<30,000/': 1,
#            'QT/': 1,
#            'QTc': 1,
#            'dementia/': 1,
#            'cognitive': 1,
#            'μL).': 1,
#            'Gms/': 1,
#            'radiation': 1,
#            '>1,500/': 1,
#            '>100,000/': 1,
#            'national/': 1,
#            'local': 1,
#            '<60mL/': 1,
#            'Ethics': 1,
#            '150µmol/': 1,
#            'psychotropics(': 1,
#            'AIDS).': 1,
#            'patient/': 1,
#            'Patient/': 1,
#            'potassium<3.2mmol/': 1,
#            'or>5.5mmol/': 1,
#            'scar/': 1,
#            'change': 1,
#            'inflammation/': 1,
#            'disease(ESRD)/': 1,
#            'Hb<10g/': 1,
#            '(FEV1)/': 1,
#            '(forced': 1,
#            ')': 1,
#            'severe': 1,
#            'abnormalities:': 1,
#            'food': 1,
#            'weight(Kg)/': 1,
#            'height(m2).': 1,
#            '<1,500/': 1,
#            '90,000/': 1,
#            'orphans/': 1,
#            'vulnerable': 1,
#            '[IRB]/': 1,
#            'Independent': 1,
#            '1x/': 1,
#            'session': 1,
#            'lamivudine/': 1,
#            'adefovir': 1,
#            'dl.': 1,
#            '(BCR/': 1,
#            'ABL)': 1,
#            'cancer,': 1,
#            'chemotherapy,': 1,
#            'creatinine(>1.5mg/': 1,
#            '20mg/': 1,
#            '40mg/': 1,
#            '150mg/': 1,
#            '45mg/': 1,
#            'ER(150-225mg/': 1,
#            'mm3if': 1,
#            'mm3or': 1,
#            '<30mL/': 1,
#            'CYP3A4/': 1,
#            'P-glycoprotein': 1,
#            'ALT>2x': 1,
#            '70;': 1,
#            'simvastatin/': 1,
#            'lovastatin': 1,
#            'mm3),': 1,
#            'cord/': 1,
#            'cauda': 1,
#            'd/': 1,
#            'β),': 1,
#            'β': 1,
#            '9gm/': 1,
#            '3.5/': 1,
#            'negative/': 1,
#            'HBcAb': 1,
#            'positive/': 1,
#            'hepatitis': 1,
#            'at/': 1,
#            'above': 1,
#            'ERCP/': 1,
#            'PTC': 1,
#            'vaginal': 1,
#            '<24/': 1,
#            'left/': 1,
#            'right': 1,
#            'who': 1,
#            'events/': 1,
#            'hour': 1,
#            '(>170/': 1,
#            '>110)': 1,
#            'DDAVP/': 1,
#            'Stimate': 1,
#            'IIIB/': 1,
#            'EGF/': 1,
#            'EGFR': 1,
#            'registries': 1,
#            'studies/': 1,
#            'hip': 1,
#            'knee/': 1,
#            '5-fluorouracil/': 1,
#            'leucovorin': 1,
#            '(5-FU/': 1,
#            'LV)': 1,
#            'DoD/': 1,
#            'VA': 1,
#            'besides': 1,
#            'sec': 1,
#            'equivalent/': 1,
#            '1)': 1,
#            'cerebral/': 1,
#            'meningeal': 1,
#            'rest/': 1,
#            'ice': 1,
#            'soft': 1,
#            'soft-tissue': 1,
#            'rifampin/': 1,
#            'rifampicin,': 1,
#            '100µg/': 1,
#            'µg/': 1,
#            'AIDS.': 1,
#            'Oligomenorrhea/': 1,
#            'amenorrhea': 1,
#            'SLL': 1,
#            '1-3A/': 1,
#            'iNHL,': 1,
#            'LPL/': 1,
#            'WM,': 1,
#            'SLL,': 1,
#            'MF/': 1,
#            'SS)': 1,
#            'PET': 1,
#            '1000/': 1,
#            'uL': 1,
#            '20.0mg/': 1,
#            'Hep': 1,
#            'bowel': 1,
#            '95mmHg': 1,
#            '=135/': 1,
#            '95.': 1,
#            '(ALT/': 1,
#            'AST>50IU/': 1,
#            'durg-': 1,
#            'T-cell': 1,
#            'NK/': 1,
#            'ER/': 1,
#            'PR': 1,
#            '(20g/': 1,
#            'aminotransferase/': 1,
#            'alanine': 1,
#            'planing/': 1,
#            'being': 1,
#            '159/': 1,
#            '99': 1,
#            'B/': 1,
#            'C': 1,
#            'ANC>1000/': 1,
#            'mcl': 1,
#            'platelets>100,000/': 1,
#            'mcl.': 1,
#            'yes/': 1,
#            'weeks)/': 1,
#            'low': 1,
#            'kg': 1,
#            'PET/': 1,
#            'milliunits/': 1,
#            '(mU/': 1,
#            '(renal/': 1,
#            'Current/': 1,
#            'recent': 1,
#            'patients.': 1,
#            'Mild-': 1,
#            'to-moderate': 1,
#            '80U/': 1,
#            'artifacts/': 1,
#            'components': 1,
#            'absence': 1,
#            'is/': 1,
#            'are': 1,
#            "investigator's/": 1,
#            "designee's": 1,
#            '(MlU/': 1,
#            '60mL/': 1,
#            'equivalents/': 1,
#            'tooth)': 1,
#            'surgical': 1,
#            'bleeding/': 1,
#            'clotting': 1,
#            'substance/': 1,
#            '2010': 1,
#            '30/': 1,
#            '09/': 1,
#            '2013': 1,
#            'attempt/': 1,
#            'difficult-': 1,
#            'to-detect': 1,
#            'height/': 1,
#            'weight': 1,
#            '2400/': 1,
#            'microl,': 1,
#            'amphetamine/': 1,
#            'methamphetamine,': 1,
#            'ADHD/': 1,
#            'LD': 1,
#            'dL])': 1,
#            'TPV/': 1,
#            'r': 1,
#            'Hgb<11g/': 1,
#            'Hct<30g/': 1,
#            '>240mg/': 1,
#            '>500mg/': 1,
#            '>130mg/': 1,
#            '<150,000/': 1,
#            '[kilogram(kg)]/': 1,
#            'height^2': 1,
#            'm^2,': 1,
#            'suppository': 1,
#            'suppository,': 1,
#            '=(mPAP-PCWP)/': 1,
#            'CO]>3.0': 1,
#            '<1g/': 1,
#            'differentiated/': 1,
#            'de-differentiated': 1,
#            'sarcoma/': 1,
#            'MFH': 1,
#            'asthma/': 1,
#            'atopy': 1,
#            'nursing/': 1,
#            'breastfeeding.': 1,
#            'Liter': 1,
#            'deciliter': 1,
#            '(g/': 1,
#            'arterial/': 1,
#            'venous': 1,
#            'In': 1,
#            'systolic/': 1,
#            'diastolic': 1,
#            '=128/': 1,
#            '78': 1,
#            'V': 1,
#            '5),': 1,
#            'ICD-10/': 1,
#            'V,': 1,
#            '(ACC/': 1,
#            'AHA': 1,
#            'mL),': 1,
#            'dL),': 1,
#            'mL).': 1,
#            '50': 1,
#            'vitreous': 1,
#            'intravitreal/': 1,
#            'periocular': 1,
#            'complications/': 1,
#            'Pa': 1,
#            'Pa)': 1,
#            '1250/': 1,
#            '*28': 1,
#            '*28/': 1,
#            'Caregiver': 1,
#            'Subject/': 1,
#            '(BP>140/': 1,
#            'x109/': 1,
#            'peripheral': 1,
#            'severe/': 1,
#            'unstable': 1,
#            'coronary/': 1,
#            '=7mmol/': 1,
#            '=11mmol/': 1,
#            '7.0mmol/': 1,
#            '48mmol/': 1,
#            '130µmol/': 1,
#            '4.0ng/': 1,
#            '1.7mg/': 1,
#            'anesthesia/': 1,
#            'procedures': 1,
#            'clotting/': 1,
#            'coagulation': 1,
#            'l))': 1,
#            'clearance>50ml/': 1,
#            'in': 1,
#            '<140/': 1,
#            'solvent': 1,
#            'platinum-': 1,
#            'ALT:': 1,
#            'anti-PD1/': 1,
#            'anti-PD-L1': 1,
#            'Desire/': 1,
#            'intent': 1,
#            'trimethoprim/': 1,
#            'sulphamethoxazole': 1,
#            'piperacillin/': 1,
#            'tazobactam)': 1,
#            'LDL=/': 1,
#            '>150': 1,
#            'close/': 1,
#            'intimate': 1,
#            'days/': 1,
#            'good': 1,
#            'eGFR=60(ml/': 1,
#            '2/': 1,
#            '3': 1,
#            'care': 1,
#            'µL.': 1,
#            'CIA)': 1,
#            'CIA,': 1,
#            'CIA': 1,
#            '(TAF)/': 1,
#            '(COBI)/': 1,
#            'TAF/': 1,
#            'COBI/': 1,
#            '40,000/': 1,
#            'www.fstrf.org/': 1,
#            'ACTG/': 1,
#            'ccc.html': 1,
#            'signs/': 1,
#            ')/': 1,
#            'T': 1,
#            'test:WBC=3.0×109/': 1,
#            'L,Neutrophils=1.5×109/': 1,
#            'L,Hb=100g/': 1,
#            'L,Platelet=80×109/': 1,
#            'mol/': 1,
#            'study/': 1,
#            'trial': 1,
#            'agonist/': 1,
#            'antagonist': 1,
#            '(polyester/': 1,
#            'ethyl': 1,
#            'DAS28/': 1,
#            'Erythrocyte': 1,
#            'dapsone-': 1,
#            'naive.': 1,
#            '1-4h,': 1,
#            '<50/': 1,
#            '1,73m),': 1,
#            'evenings/': 1,
#            'nights': 1,
#            'BMI-': 1,
#            'for-age': 1,
#            'drugs': 1,
#            'packs/': 1,
#            '70': 1,
#            'hypotension/': 1,
#            'capillary': 1,
#            'leak/': 1,
#            'life': 1,
#            'breast-feeding': 1,
#            'schizophrenia/': 1,
#            'schizoaffective': 1,
#            'Spontaneous/': 1,
#            'Induced/': 1,
#            'Augmented': 1,
#            'H/': 1,
#            'or=': 1,
#            '(Ag/': 1,
#            'Ab': 1,
#            '+/': 1,
#            '30Kg/': 1,
#            '1.73m2),': 1,
#            'stroke/': 1,
#            '<2.2mg/': 1,
#            'pain(': 1,
#            'ventilation/': 1,
#            'perfusion': 1,
#            'overload/': 1,
#            'dysfunction': 1,
#            'Forced': 1,
#            'volume/': 1,
#            'medications/': 1,
#            'materials:': 1,
#            'acquired/': 1,
#            'inherited': 1,
#            'IgG/': 1,
#            'IgM,': 1,
#            'mild/': 1,
#            'moderate': 1,
#            '(>1/': 1,
#            '>': 1,
#            'cardiovascular/': 1,
#            'pulmonary': 1,
#            'mol.': 1,
#            'l).': 1,
#            'mn': 1,
#            'acid/': 1,
#            'Cyklokapron®': 1,
#            'IV±V': 1,
#            '(ISN/': 1,
#            'RPS': 1,
#            'protein/': 1,
#            'micromol/': 1,
#            'haemoglobinopathy/': 1,
#            'thalassaemia': 1,
#            'trauma/': 1,
#            'surgery': 1,
#            'abuse/': 1,
#            'dependence': 1,
#            'CVA/': 1,
#            'Accident/': 1,
#            'Transient': 1,
# ...
#            'albuterol/': 2,
#            'diseases/': 2,
#            'LABA': 2,
#            'psychiatric': 2,
#            'finger/': 2,
#            'thumb': 2,
#            'infection/': 2,
#            '60ml/min/1.73': 2,
#            'skin/': 2,
#            'IVF/': 2,
#            'ICSI': 2,
#            'CLL/': 2,
#            'CT/': 2,
#            'screening/': 2,
#            'baseline': 2,
#            'MRI': 2,
#            'anovulation/': 2,
#            'oligoovulation.': 2,
#            'm2)': 2,
#            'social': 2,
#            'disease/': 2,
#            'fibrillation/': 2,
#            'flutter': 2,
#            'non-infectious)': 2,
#            'AST': 2,
#            'trial': 2,
#            'sensitivity': 2,
#            'symptoms': 2,
#            'study': 2,
#            'trial/': 2,
#            'Pregnant/': 2,
#            'TIA': 2,
#            'pregnancy/': 2,
#            'breastfeeding)': 2,
#            'flexion-': 2,
#            'extension': 2,
#            'HIV': 2,
#            'HBV/': 2,
#            'vaccine/': 2,
#            'albumin/': 2,
#            'creatinine': 2,
#            'with': 2,
#            'SOF/': 2,
#            'electrocardiogram/': 2,
#            'duodenal': 2,
#            'bowel/': 2,
#            '(systolic': 2,
#            'HCV/': 2,
#            'intolerance': 2,
#            'be': 2,
#            '(FEV1/': 2,
#            'hypersensitivity/': 2,
#            'GILD': 2,
#            'Investigator,': 2,
#            'one': 1,
#            'Not': 1,
#            'product/': 1,
#            'device': 1,
#            'biopsy/': 1,
#            'resection': 1,
#            'condition/': 1,
#            'illness': 1,
#            'have': 1,
#            'Had/': 1,
#            'prior/': 1,
#            'concurrent': 1,
#            'drugs/': 1,
#            'agents': 1,
#            'metformin': 1,
#            'sulfonylurea/': 1,
#            'g/dL,': 1,
#            '(ALT)/': 1,
#            'aspartate': 1,
#            'participation..': 1,
#            '2.0': 1,
#            'mg/dL': 1,
#            'gastrointestinal/': 1,
#            'injury': 1,
#            'runny/': 1,
#            'blocked/': 1,
#            'itchy': 1,
#            'Inspiratory': 1,
#            '1.': 1,
#            'Tramadol/': 1,
#            'Acetaminophen': 1,
#            'III/IV),': 1,
#            'AST>3x': 1,
#            'Melan-A/': 1,
#            'MART-1': 1,
#            'corticosteroids/': 1,
#            'Investigator)': 1,
#            'HIV-': 1,
#            'sensitivity/': 1,
#            'QT/': 1,
#            'QTc': 1,
#            'therapy.': 1,
#            'dementia/': 1,
#            'cognitive': 1,
#            'method).': 1,
#            'month,': 1,
#            'scar/': 1,
#            'change': 1,
#            'inflammation/': 1,
#            'disease(ESRD)': 1,
#            'on': 1,
#            '(FEV1)': 1,
#            '(forced': 1,
#            'severe': 1,
#            'abnormalities:': 1,
#            'food': 1,
#            'half-lives,': 1,
#            'orphans/': 1,
#            'vulnerable': 1,
#            'lamivudine/': 1,
#            'adefovir': 1,
#            'HCl,': 1,
#            'cancer,': 1,
#            'only)': 1,
#            'chemotherapy,': 1,
#            'cardia,': 1,
#            'liver': 1,
#            'CYP3A4/': 1,
#            'P-glycoprotein': 1,
#            'ALT>2x': 1,
#            'simvastatin/': 1,
#            'lovastatin': 1,
#            'cord/': 1,
#            'cauda': 1,
#            'negative/': 1,
#            'HBcAb': 1,
#            'positive/': 1,
#            'hepatitis': 1,
#            'ERCP/': 1,
#            'PTC': 1,
#            'vaginal': 1,
#            'Yahr,1967;': 1,
#            'ischaemic': 1,
#            'gallbladder,': 1,
#            'gallstone': 1,
#            'cholecystitis,': 1,
#            'pancreatitis,': 1,
#            'pancreaticobiliary': 1,
#            'DDAVP/': 1,
#            'Stimate': 1,
#            'IIIB/': 1,
#            'IV': 1,
#            'EGF/': 1,
#            'EGFR': 1,
#            'registries': 1,
#            'studies/': 1,
#            'hip': 1,
#            'knee/': 1,
#            '5-fluorouracil/': 1,
#            'leucovorin': 1,
#            '(5-FU/': 1,
#            'LV)': 1,
#            '1)': 1,
#            'HBsAg-': 1,
#            'cerebral/': 1,
#            'meningeal': 1,
#            'rest/': 1,
#            'ice': 1,
#            'soft': 1,
#            'soft-tissue': 1,
#            'rifampin/': 1,
#            'rifampicin,': 1,
#            'AF': 1,
#            'Oligomenorrhea/': 1,
#            'amenorrhea': 1,
#            'gestation.scheduled': 1,
#            'etc).Rupture': 1,
#            'SLL': 1,
#            '1-3A/': 1,
#            'iNHL,': 1,
#            'LPL/': 1,
#            'WM,': 1,
#            'SLL,': 1,
#            'MF/': 1,
#            'SS)': 1,
#            'PET': 1,
#            'HIV/': 1,
#            'Hep': 1,
#            'bowel': 1,
#            '([women]': 1,
#            '(ALT/': 1,
#            'AST>50IU/L)': 1,
#            'anti-inflammatories,': 1,
#            'durg-': 1,
#            'drug-': 1,
#            'ER/': 1,
#            'PR': 1,
#            'aminotransferase/': 1,
#            'alanine': 1,
#            'planing/': 1,
#            'being': 1,
#            'liter.': 1,
#            'PET/': 1,
#            '(renal/': 1,
#            'Current/': 1,
#            'recent': 1,
#            'parents/': 1,
#            'patients.': 1,
#            'APA,': 1,
#            'H2blocker,': 1,
#            'artifacts/': 1,
#            'components': 1,
#            'absence': 1,
#            '60mL/min/1.73': 1,
#            'surgical': 1,
#            'bleeding/': 1,
#            'clotting': 1,
#            'substance/': 1,
#            'non-cardiac)': 1,
#            'height/': 1,
#            'weight': 1,
#            'amphetamine/': 1,
#            'methamphetamine,': 1,
#            'ADHD/': 1,
#            'LD': 1,
#            'suppository': 1,
#            'suppository,': 1,
#            '=(mPAP-': 1,
#            'PCWP)/CO]>3.0': 1,
#            'differentiated/': 1,
#            'de-differentiated': 1,
#            'sarcoma/': 1,
#            'MFH': 1,
#            'are': 1,
#            'asthma/': 1,
#            'atopy': 1,
#            'nursing/': 1,
#            'breastfeeding.': 1,
#            'arterial/': 1,
#            'venous': 1,
#            'systolic/': 1,
#            'diastolic': 1,
#            'ICD-10/': 1,
#            'DSM-IV/V,': 1,
#            'vitreous': 1,
#            'intravitreal/': 1,
#            'periocular': 1,
#            'complications/': 1,
#            'peripheral': 1,
#            'severe/': 1,
#            'unstable': 1,
#            'coronary/': 1,
#            'anesthesia/': 1,
#            'procedures': 1,
#            'clotting/': 1,
#            'coagulation': 1,
#            'spermicide).': 1,
#            'HCV-': 1,
#            'negative,': 1,
#            'eligible..': 1,
#            'solvent': 1,
#            'platinum-': 1,
#            'ALT:': 1,
#            'anti-PD1/': 1,
#            'anti-PD-L1': 1,
#            'Desire/': 1,
#            'intent': 1,
#            'trimethoprim/': 1,
#            'sulphamethoxazole': 1,
#            'piperacillin/': 1,
#            'tazobactam)': 1,
#            'close/': 1,
#            'intimate': 1,
#            'good': 1,
#            'Hbatic': 1,
#            'signs/': 1,
#            ')/': 1,
#            'T': 1,
#            'test:WBC=3.0×109/L,': 1,
#            'Neutrophils=1.5×109/L,': 1,
#            'Hb=100g/L,': 1,
#            'Platelet': 1,
#            '=80': 1,
#            '×109/L;': 1,
#            'months),': 1,
#            'study/': 1,
#            'agonist/': 1,
#            'antagonist': 1,
#            '(polyester/': 1,
#            'ethyl': 1,
#            'DAS28/': 1,
#            'Erythrocyte': 1,
#            'rest,': 1,
#            'home.': 1,
#            'dapsone-': 1,
#            'naive.': 1,
#            'al].': 1,
#            '1-4h,': 1,
#            'analgesics,': 1,
#            'sedatives': 1,
#            'laser,....': 1,
#            '/1,73': 1,
#            'm),': 1,
#            'evenings/': 1,
#            'nights': 1,
#            'drugs': 1,
#            'hypotension/': 1,
#            'capillary': 1,
#            'leak/': 1,
#            'life': 1,
#            'breast-feeding': 1,
#            'schizophrenia/': 1,
#            'schizoaffective': 1,
#            'Spontaneous/': 1,
#            'Induced/': 1,
#            'Augmented': 1,
#            '>1%),': 1,
#            '6.5%,': 1,
#            '30ml/min/1.73': 1,
#            'm2),': 1,
#            'stroke/': 1,
#            'Congenital,': 1,
#            'Mental': 1,
#            'Cardiac,': 1,
#            'Pulmonary,': 1,
#            'Hepatic': 1,
#            'antipyretics,': 1,
#            'sleeping': 1,
#            'contraindication,including': 1,
#            'ventilation/': 1,
#            'perfusion': 1,
#            'overload/': 1,
#            'dysfunction': 1,
#            'medications/': 1,
#            'materials:': 1,
#            'acquired/': 1,
#            'inherited': 1,
#            'IgG/': 1,
#            'IgM,': 1,
#            'mild/': 1,
#            'moderate': 1,
#            'cardiovascular/': 1,
#            'pulmonary': 1,
#            'acid/': 1,
#            'Cyklokapron®': 1,
#            'haemoglobinopathy/': 1,
#            'thalassaemia': 1,
#            'B,': 1,
#            'C': 1,
#            'trauma/': 1,
#            'surgery': 1,
#            'abuse/': 1,
#            'dependence': 1,
#            'rate(CCr)<50%;': 1,
#            'CVA/': 1,
#            'Accident/': 1,
#            'Transient': 1,
#            'arthritis/': 1,
#            'autoimmune': 1,
#            'mL/min/1.7': 1,
#            'WHO/': 1,
#            'NYHA-FC': 1,
#            'disorders/': 1,
#            'Significant/': 1,
#            'Inclusion/Exclusion': 1,
#            'May': 1,
#            'fusion/': 1,
#            'apnea/': 1,
#            'hypopnea': 1,
#            'naïve,': 1,
#            '1a/': 1,
#            'ab.': 1,
#            'LDV/': 1,
#            'SOF': 1,
#            'aminotransferase)/': 1,
#            'ALT(alanine': 1,
#            'aminotransferase)': 1,
#            'disorder/': 1,
#            'diathesis': 1,
#            'Mental,': 1,
#            'the': 1,
#            'trichomonas.': 1,
#            'placebo,': 1,
#            'Patients': 1,
#            'lumbar': 1,
#            'fusion.': 1,
#            'injections/': 1,
#            '(joint/': 1,
#            'musculoskeletal,': 1,
#            'LDV': 1,
#            'tipranavir/': 1,
#            'ritonavir': 1,
#            'nucleoside/': 1,
#            'nucleotide': 1,
#            'Pa02/': 1,
#            'Fi02': 1,
#            'Pre-existing/': 1,
#            'procedures/': 1,
#            'treatments.': 1,
#            'endodontic/': 1,
#            'periodontal': 1,
#            'assay)': 1,
#            'transaminase/': 1,
#            'alkaline': 1,
#            'ALT)': 1,
#            'Hemosiderosis/': 1,
#            'hemochromatosis': 1,
#            'prednisone/': 1,
#            'prednisolone': 1,
#            'osteomyelitis/': 1,
#            'septic': 1,
#            '>5°,': 1,
#            'Intolerance/': 1,
#            'Exposure/': 1,
#            'treatment': 1,
#            'law,': 1,
#            'CNIL).': 1,
#            'periorbital/': 1,
#            'forehead': 1,
#            'ALT,': 1,
#            'failure': 1,
#            'injury/': 1,
#            'miscarriage/': 1,
#            'abortion': 1,
#            'obstruction/': 1,
#            'blockage': 1,
#            'IBS': 1,
#            'severity': 1,
#            'frequency/': 1,
#            'HA-': 1,
#            'pressure<110)': 1,
#            'lightheadedness),': 1,
#            'anti-Inflammatory': 1,
#            'sedative/': 1,
#            'hypnotics),': 1,
#            'thrombophilia/': 1,
#            'thrombosis': 1,
#            '(hypertension),DM': 1,
#            'topiramate,': 1,
#            'phenytoin)': 1,
#            'level?': 1,
#            'reading?': 1,
#            'University/': 1,
#            'Barnes-Jewish': 1,
#            'speaking/': 1,
#            'illiterate': 1,
#            'autoimmune/': 1,
#            'inflammatory': 1,
#            '(IUD/': 1,
#            'IUS)': 1,
#            '(MI/': 1,
#            'heart': 1,
#            "Parkison's": 1,
#            'SGOT/': 1,
#            'SGPT': 1,
#            '(dronabinol/': 1,
#            'marijuana/': 1,
#            'cannabis/': 1,
#            'THC,': 1,
#            'drug': 1,
#            'acceleration/': 1,
#            'deceleration': 1,
#            'shrapnel/': 1,
#            'retained': 1,
#            'Patients/': 1,
#            'physicians': 1,
#            'situations/': 1,
#            'Oral/': 1,
#            'Oropharynx': 1,
#            'contra-indication': 1,
#            'neuropathy/': 1,
#            'sensory': 1,
#            'hepatocellular/': 1,
#            'cholangiocarcinoma': 1,
#            'maintenance/': 1,
#            'extended-use': 1,
#            'illness.': 1,
#            'Moderate/': 1,
#            'Weak': 1,
#            'venetoclax).': 1,
#            'T2/': 1,
#            'FLAIR': 1,
#            'FA/': 1,
#            'ICGA': 1,
#            'PO/': 1,
#            'NG': 1,
#            'm2).': 1,
#            'or/': 1,
#            'discharge': 1,
#            'Hiv/': 1,
#            'test.': 1,
#            'etc.).': 1,
#            'husband/': 1,
#            'wife,': 1,
#            'visible': 1,
#            'nephropathy/': 1,
#            'retinopathy/': 1,
#            'neuropathy': 1,
#            'spondylolisthesis/': 1,
#            'spondylosis/': 1,
#            'spondylolysis': 1,
#            'Immunosuppressed/': 1,
#            'immune': 1,
#            'interlerance': 1,
#            'information': 1,
#            'Lumber': 1,
#            'bigemini/': 1,
#            'trigeminy': 1,
#            'exacerbation': 1,
#            '(Xiapex/': 1,
#            'Xiaflex': 1,
#            'neck,including': 1,
#            'nodes,': 1,
#            'metastasis)': 1,
#            '-': 1,
#            'None': 1,
#            'to,': 1,
#            'Stroke/': 1,
#            "Alzheimer's": 1,
#            'Severe/': 1,
#            'untreated': 1,
#            'Diagnosed': 1,
#            'mL/min/1.73': 1,
#            'm2.': 1,
#            'liver-': 1,
#            'kidney': 1,
#            'ARF,': 1,
#            'scarlet': 1,
#            'fever,': 1,
#            'impetigo,': 1,
#            'acute': 1,
#            'Pregnancy/': 1,
#            'breastfeeding': 1,
#            'without': 1,
#            'lactating': 1,
#            'Sensistivity/': 1,
#            '[': 1,
#            'Unstable/': 1,
#            'rapidly': 1,
#            'donation/': 1,
#            'Interleukin-12/': 1,
#            '23': 1,
#            '(IL-12/': 1,
#            '23),': 1,
#            'opioids/': 1,
#            'opiates,': 1,
#            'overweight/': 1,
#            'lean': 1,
#            'high': 1,
#            'phentermine,': 1,
#            'orlistat,': 1,
#            'tuberculosis,': 1,
#            'back': 1,
#            'leg/': 1,
#            'T-score': 1,
#            'bladder': 1,
#            'chemical/': 1,
#            'never': 1,
#            'LABA)': 1,
#            'RELVAR/': 1,
#            'BREO': 1,
#            'Salbutamol/': 1,
#            'Albuterol': 1,
#            'condition': 1,
#            'VEL': 1,
#            'non-therapy-induced': 1,
#            'that,': 1,
#            'diabetes,': 1,
#            'gestational': 1,
#            'Overweight/': 1,
#            'Obese': 1,
#            'concurrent,': 1,
#            'non-stimulant': 1,
#            'nicotine': 1,
#            'tobacco/': 1,
#            '(PO/': 1,
#            'IV/': 1,
#            'IM)': 1,
#            'product': 1,
#            'Emergent/': 1,
#            'elective': 1,
#            'HBV': 1,
#            'race/': 1,
#            'ethnicity,': 1,
#            'pharmacokinetic/': 1,
#            'pharmacodynamics': 1,
#            'prednisone': 1,
#            'methylprednisolone/': 1,
#            'has': 1,
#            '80': 1,
#            'mmHg=DBP<110': 1,
#            'mmHg': 1,
#            'GFR<30ml•min-1•1.73': 1,
#            'm-2;': 1,
#            'DBP=110': 1,
#            'mmHg;': 1,
#            'terazosin/': 1,
#            'doxazosin/': 1,
#            'alfuzosin/': 1,
#            'silodosin)': 1,
#            'TSH,': 1,
#            'PRL,': 1,
#            'FBS': 1,
#            'range),': 1,
#            'surgical/': 1,
#            'percutaneous': 1,
#            'PCI/': 1,
#            'MI': 1,
#            'ICD/': 1,
#            'CRT-D.': 1}),
#   'average': {'precision': 28.698778816213164,
#    'recall': 54.39723899619063,
#    'f1': 36.8098331418087,
#    'accuracy': 54.39723899619063}}}

# %% [markdown]
# #### AND OR NOT EVALUATION LATEX

# %%
def generate_latex_table(all_metrics, operators, metrics_to_plot, versuch_name):
    # Initialize a dictionary to store the maximum values per column
    max_values = {op: {metric: float('-inf') for metric in metrics_to_plot} for op in operators}

    # Find the maximum values per column, including SciBERT and R-BERT + SciBERT
    scibert_values = {
        'AND': {'precision': 54.1, 'recall': 60.0, 'f1': 56.9},
        'OR': {'precision': 85.1, 'recall': 93.2, 'f1': 89.0},
        'NOT': {'precision': 74.3, 'recall': 91.0, 'f1': 81.8}
    }
    rbert_scibert_values = {
        'AND': {'precision': 53.8, 'recall': 53.8, 'f1': 53.8},
        'OR': {'precision': 88.4, 'recall': 92.2, 'f1': 90.2},
        'NOT': {'precision': 74.5, 'recall': 88.7, 'f1': 81.0}
    }

    # Update max_values with SciBERT and R-BERT + SciBERT values
    for op in operators:
        for metric in metrics_to_plot:
            max_values[op][metric] = max(
                scibert_values[op][metric],
                rbert_scibert_values[op][metric],
                max_values[op][metric]
            )

    # Update max_values with all other models
    for model_metrics in all_metrics.values():
        for op in operators:
            for metric in metrics_to_plot:
                value = model_metrics[op][metric]
                if value > max_values[op][metric]:
                    max_values[op][metric] = value

    latex_table = "\\begin{table}[h]\n"
    latex_table += "\\centering\n"
    latex_table += "\\begin{tabular}{l" + "c" * (len(metrics_to_plot) * len(operators)) + "}\n"
    latex_table += "\\toprule\n"
    latex_table += "Model & " + " & ".join([f"\\multicolumn{{{len(metrics_to_plot)}}}{{c}}{{{op}}}" for op in operators]) + " \\\\\n"
    for i, op in enumerate(operators):
        start = i * len(metrics_to_plot) + 2
        end = (i + 1) * len(metrics_to_plot) + 1
        latex_table += f"\\cmidrule(lr){{{start}-{end}}} "
    latex_table += "\n"
    latex_table += " & " + " & ".join([" & ".join(metric[:1].upper() for metric in metrics_to_plot) for _ in operators]) + " \\\\\n"
    latex_table += "\\midrule\n"

    # Add rows for SciBERT and R-BERT + SciBERT with bold for maximum values
    for name, values in [("SciBERT (SOTA)", scibert_values), ("R-BERT + SciBERT", rbert_scibert_values)]:
        row = name
        for op in operators:
            for metric in metrics_to_plot:
                value = values[op][metric]
                formatted_value = "{:.1f}".format(value)
                if value == max_values[op][metric]:
                    formatted_value = f"\\textbf{{{formatted_value}}}"
                row += f" & {formatted_value}"
        row += " \\\\\n"
        latex_table += row

    # Add rows for other models and make the largest values bold
    for model, model_metrics in all_metrics.items():
        row = model.replace("_", "-")  # Replace underscores with hyphens in the model name
        for op in operators:
            for metric in metrics_to_plot:
                value = model_metrics[op][metric]
                formatted_value = "{:.1f}".format(value)
                if value == max_values[op][metric]:
                    formatted_value = f"\\textbf{{{formatted_value}}}"
                row += f" & {formatted_value}"
        row += " \\\\\n"
        latex_table += row

    latex_table += "\\bottomrule\n"
    latex_table += "\\end{tabular}\n"
    latex_table += "\\caption{Model Performance Metrics}\n"
    latex_table += "\\label{tab:model_metrics}\n"
    latex_table += "\\end{table}\n"

    os.makedirs("latex", exist_ok=True)
    with open(f"latex/{versuch_name}_model_metrics_table.tex", "w") as file:
        file.write(latex_table)
    return latex_table

# %%
generate_latex_table(all_metrics, operators, metrics_to_plot, versuch_name)
# Out:
# '\\begin{table}[h]\n\\centering\n\\begin{tabular}{lccccccccc}\n\\toprule\nModel & \\multicolumn{3}{c}{AND} & \\multicolumn{3}{c}{OR} & \\multicolumn{3}{c}{NOT} \\\\\n\\cmidrule(lr){2-4} \\cmidrule(lr){5-7} \\cmidrule(lr){8-10} \n & P & R & F & P & R & F & P & R & F \\\\\n\\midrule\nSciBERT (SOTA) & \\textbf{54.1} & 60.0 & \\textbf{56.9} & 85.1 & \\textbf{93.2} & 89.0 & 74.3 & \\textbf{91.0} & \\textbf{81.8} \\\\\nR-BERT + SciBERT & 53.8 & 53.8 & 53.8 & \\textbf{88.4} & 92.2 & \\textbf{90.2} & \\textbf{74.5} & 88.7 & 81.0 \\\\\n Naive greedy match (CHIA Prompt) & 6.9 & \\textbf{66.4} & 12.5 & 26.2 & 75.2 & 38.8 & 33.5 & 53.3 & 41.2 \\\\\n Naive greedy match (LCT Prompt 2) & 8.1 & 21.8 & 11.8 & 25.7 & 75.4 & 38.3 & 29.9 & 44.0 & 35.6 \\\\\nLlama-3-70B-Instruct-0-shot-chia-prompt & 8.6 & 26.9 & 13.1 & 43.4 & 76.3 & 55.4 & 17.1 & 51.2 & 25.6 \\\\\nLlama-3-70B-Instruct-0-shot-lct-prompt & 7.4 & 15.7 & 10.1 & 44.2 & 78.4 & 56.5 & 18.9 & 50.7 & 27.6 \\\\\nLlama-3-70B-Instruct-5-shot-chia-prompt2 & 12.0 & 15.7 & 13.6 & 53.4 & 71.0 & 60.9 & 39.4 & 38.9 & 39.2 \\\\\nLlama-3-70B-Instruct-5-shot-lct-prompt2 & 12.4 & 15.1 & 13.6 & 54.1 & 70.6 & 61.2 & 40.3 & 41.0 & 40.6 \\\\\nllama3-70b-Lora-ep10-r256-prompt6-lct-model-lct2-prompt & 14.3 & 12.1 & 13.1 & 40.7 & 84.6 & 55.0 & 31.0 & 66.5 & 42.3 \\\\\n\\bottomrule\n\\end{tabular}\n\\caption{Model Performance Metrics}\n\\label{tab:model_metrics}\n\\end{table}\n'

# %%
import pandas as pd

# Daten als Dictionary
data = {
    "Metric": ["P", "R", "F", "P", "R", "F", "P", "R", "F"],
    "Model": ["AND", "AND", "AND", "OR", "OR", "OR", "NOT", "NOT", "NOT"],
    "SciBERT_SOTA": [54.1, 60.0, 56.9, 85.1, 93.2, 89.0, 74.3, 91.0, 81.8],
    "0-shot": [20.9, 54.9, 30.3, 74.2, 61.1, 67.0, 32.6, 61.6, 42.6],
    "5-shot": [24.5, 49.4, 32.8, 74.7, 80.8, 77.6, 61.1, 53.5, 57.1],
    "Llama3-70b-Lora-p1": [69.2, 50.0, 58.1, 86.8, 86.6, 86.7, 76.6, 81.6, 79.1]
}

# DataFrame erstellen
df = pd.DataFrame(data)

# Berechne die prozentualen Differenzen
def calculate_deltas(row):
    sota_value = row["SciBERT_SOTA"]
    return {
        "0-shot": ((row["0-shot"] - sota_value) / sota_value) * 100,
        "5-shot": ((row["5-shot"] - sota_value) / sota_value) * 100,
        "Llama3-70b-Lora-p1": ((row["Llama3-70b-Lora-p1"] - sota_value)) 
    }

# Berechne Deltas für jede Zeile
df[["0-shot_Delta", "5-shot_Delta", "Llama3-70b-Lora-p1_Delta"]] = df.apply(calculate_deltas, axis=1, result_type="expand")

print(df[["Metric", "Model", "SciBERT_SOTA", "0-shot_Delta", "5-shot_Delta", "Llama3-70b-Lora-p1_Delta"]])
# Out:
#   Metric Model  SciBERT_SOTA  0-shot_Delta  5-shot_Delta  \
# 0      P   AND          54.1    -61.367837    -54.713494
# 1      R   AND          60.0     -8.500000    -17.666667
# 2      F   AND          56.9    -46.748682    -42.355009
# 3      P    OR          85.1    -12.808461    -12.220917
# 4      R    OR          93.2    -34.442060    -13.304721
# 5      F    OR          89.0    -24.719101    -12.808989
# 6      P   NOT          74.3    -56.123822    -17.765814
# 7      R   NOT          91.0    -32.307692    -41.208791
# 8      F   NOT          81.8    -47.921760    -30.195599
#
#    Llama3-70b-Lora-p1_Delta
# 0                      15.1
# 1                     -10.0
# 2                       1.2
# 3                       1.7
# 4                      -6.6
# 5                      -2.3
# 6                       2.3
# 7                      -9.4
# 8                      -2.7

# %%
sota_metrics = {
    'SciBERT': {
        'AND': {'precision': 54.1, 'recall': 60.0, 'f1': 56.9},
        'NOT': {'precision': 74.3, 'recall': 91.0, 'f1': 81.8},
        'OR': {'precision': 85.1, 'recall': 93.2, 'f1': 89.0}
    },
    'R-BERT + SciBERT': {
        'AND': {'precision': 53.8, 'recall': 53.8, 'f1': 53.8},
        'NOT': {'precision': 74.5, 'recall': 88.7, 'f1': 81.0},
        'OR': {'precision': 88.4, 'recall': 92.2, 'f1': 90.2}
    }
}

def calculate_average_metrics(metrics):
    avg_metrics = {'precision': 0, 'recall': 0, 'f1': 0}
    operators = ['AND', 'NOT', 'OR']

    for metric in avg_metrics.keys():
        avg_metrics[metric] = sum(metrics[op][metric] for op in operators) / len(operators)

    return avg_metrics

for model, metrics in sota_metrics.items():
    avg_metrics = calculate_average_metrics(metrics)
    print(f"Average metrics for {model}: {avg_metrics}")
# Out:
# Average metrics for SciBERT: {'precision': 71.16666666666667, 'recall': 81.39999999999999, 'f1': 75.89999999999999}
# Average metrics for R-BERT + SciBERT: {'precision': 72.23333333333333, 'recall': 78.23333333333333, 'f1': 75.0}
