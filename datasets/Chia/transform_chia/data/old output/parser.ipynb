# %%
import json
import re

# %%
from functions import *

# %%
def save_as_json(data, output_file):
    with open(output_file, 'w') as f:
        json.dump(data, f, indent=4)
def save_json_to_file(json_data, file_path):
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(json_data)

def read_ann_file(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
            return content
    except FileNotFoundError:
        return "Die Datei konnte nicht gefunden werden."
    except Exception as e:
        return f"Ein Fehler ist aufgetreten: {e}"

# %%
def parse_ann_file(file_path):
    entities = {}
    relationships = []
    scope_or = []
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split('\t')
            if len(parts) < 2:
                continue
            entry_type = parts[0][0]
            if entry_type == 'T':  
                entity_id, entity_info = parts[0], parts[1:]
                label, position = entity_info[0].split(' ')[0], entity_info[0].split(' ')[1:]
                start, end = position[0], position[1]
                if ';' in start:
                    start = start.split(';')[0]
                if ';' in end:
                    end = end.split(';')[0]
                entities[entity_id] = {
                    'type': label,
                    'start': int(start),
                    'end': int(end),
                    'text': parts[2]
                }
            elif entry_type == 'R':  # Relationship
                relation_id, relation_info = parts[0], parts[1]
                relation_type, arg1, arg2 = relation_info.split(' ')[0], relation_info.split(' ')[1].split(':')[1], relation_info.split(' ')[2].split(':')[1]
                relationships.append({
                    'id': relation_id,
                    'type': relation_type,
                    'arg1': arg1,
                    'arg2': arg2
                })
            elif parts[0].startswith('*'):
                relationship_type = parts[1].split()[0]
                entity_ids = parts[1].split()[1:]
                scope_or.append({
                    'type': relationship_type,
                    'entities': entity_ids
                })
    return {
        'entities': entities,
        'relationships': relationships,
        'scope_or': scope_or
    }

# %%
def replace_ids_with_offsets(data):
    entities = data['entities']
    relationships = data['relationships']
    scope_or = data['scope_or']
    for relationship in relationships:
        if relationship['type'] in ["AND", "Has_negation"]:
            if relationship['arg1'] in entities and relationship['arg2'] in entities:
                start1, end1 = entities[relationship['arg1']]['start'], entities[relationship['arg1']]['end']
                start2, end2 = entities[relationship['arg2']]['start'], entities[relationship['arg2']]['end']
                # Sortierung der Offsets für konsistente Reihenfolge
                sorted_offsets = sorted([(start1, end1), (start2, end2)])
                relationship['arg1'] = f"{sorted_offsets[0][0]}-{sorted_offsets[0][1]}"
                relationship['arg2'] = f"{sorted_offsets[1][0]}-{sorted_offsets[1][1]}"
    new_scope_or = []
    for group in scope_or:
        offsets = sorted([f"{entities[id]['start']}-{entities[id]['end']}" for id in group['entities'] if id in entities], key=lambda x: int(x.split('-')[0]))
        new_scope_or.append({'type': group['type'], 'entities': offsets})
    updated_data = {
        'entities': entities, 
        'relationships': relationships,
        'scope_or': new_scope_or
    }
    return updated_data

# %%
ann_file = 'NCT00050349_exc.ann'
ec_file = 'NCT00050349_exc.txt'

ann_data = parse_ann_file(ann_file)
save_as_json(ann_data, 'output_file.json')
print("Conversion complete. JSON saved to 'output_file.json'")
# Out:
# Conversion complete. JSON saved to 'output_file.json'

# %%
def remove_last_elements(data):
    # Entferne das letzte Element aus jeder 'OR' Gruppe, wenn mehr als ein Element vorhanden ist
    for or_group in data['scope_or']:
        if len(or_group['entities']) > 1:
            or_group['entities'].pop()  # Entfernt das letzte Element

    # Entferne das letzte Argument aus den 'AND' und 'Has_negation' Beziehungen
    for relationship in data['relationships']:
        if relationship['type'] in ["AND", "Has_negation"]:
            arg1_end = int(relationship['arg1'].split('-')[1])
            arg2_end = int(relationship['arg2'].split('-')[1])
            if arg1_end > arg2_end:
                relationship['arg1'] = relationship['arg2']  # Setze arg1 auf arg2, wenn arg1 das letzte ist
            # Entferne arg2, da wir nur das erste Argument behalten
            del relationship['arg2']

    return data

# %%
offsets = replace_ids_with_offsets(ann_data)
offsets = remove_last_elements(offsets)

# %%
offsets
# Out:
# {'entities': {'T1': {'type': 'Condition',
#    'start': 26,
#    'end': 40,
#    'text': 'CNS metastases'},
#   'T2': {'type': 'Condition',
#    'start': 44,
#    'end': 70,
#    'text': 'leptomeningeal involvement'},
#   'T5': {'type': 'Procedure', 'start': 144, 'end': 151, 'text': 'treated'},
#   'T6': {'type': 'Qualifier',
#    'start': 164,
#    'end': 179,
#    'text': 'been stable for'},
#   'T7': {'type': 'Temporal',
#    'start': 180,
#    'end': 220,
#    'text': 'at least six months prior to study start'},
#   'T4': {'type': 'Condition',
#    'start': 92,
#    'end': 108,
#    'text': 'brain metastases'},
#   'T8': {'type': 'Observation',
#    'start': 238,
#    'end': 248,
#    'text': 'history of'},
#   'T9': {'type': 'Condition',
#    'start': 249,
#    'end': 265,
#    'text': 'brain metastases'},
#   'T10': {'type': 'Procedure',
#    'start': 278,
#    'end': 299,
#    'text': 'head CT with contrast'},
#   'T11': {'type': 'Scope',
#    'start': 238,
#    'end': 265,
#    'text': 'history of brain metastases'},
#   'T12': {'type': 'Condition',
#    'start': 359,
#    'end': 374,
#    'text': 'bone metastases'},
#   'T13': {'type': 'Procedure',
#    'start': 432,
#    'end': 464,
#    'text': 'hepatic artery chemoembolization'},
#   'T14': {'type': 'Temporal',
#    'start': 465,
#    'end': 489,
#    'text': 'within the last 6 months'},
#   'T15': {'type': 'Temporal', 'start': 491, 'end': 500, 'text': 'one month'},
#   'T16': {'type': 'Observation',
#    'start': 514,
#    'end': 547,
#    'text': 'other sites of measurable disease'},
#   'T17': {'type': 'Scope',
#    'start': 465,
#    'end': 547,
#    'text': 'within the last 6 months (one month if there are other sites of measurable disease'},
#   'T18': {'type': 'Procedure',
#    'start': 597,
#    'end': 627,
#    'text': 'radioactive directed therapies'},
#   'T19': {'type': 'Drug', 'start': 676, 'end': 686, 'text': 'epothilone'},
#   'T20': {'type': 'Condition',
#    'start': 706,
#    'end': 727,
#    'text': 'peripheral neuropathy'},
#   'T21': {'type': 'Condition',
#    'start': 731,
#    'end': 750,
#    'text': 'unresolved diarrhea'},
#   'T22': {'type': 'Measurement', 'start': 764, 'end': 769, 'text': 'Grade'},
#   'T23': {'type': 'Value', 'start': 751, 'end': 763, 'text': 'greater than 1'},
#   'T24': {'type': 'Condition',
#    'start': 787,
#    'end': 815,
#    'text': 'severe cardiac insufficiency'},
#   'T25': {'type': 'Drug', 'start': 832, 'end': 840, 'text': 'Coumadin'},
#   'T26': {'type': 'Drug',
#    'start': 850,
#    'end': 876,
#    'text': 'warfarin-containing agents'},
#   'T27': {'type': 'Qualifier', 'start': 899, 'end': 907, 'text': 'low dose'},
#   'T28': {'type': 'Drug', 'start': 908, 'end': 916, 'text': 'warfarin'},
#   'T29': {'type': 'Multiplier',
#    'start': 918,
#    'end': 930,
#    'text': '1 mg or less'},
#   'T30': {'type': 'Device',
#    'start': 955,
#    'end': 972,
#    'text': 'in-dwelling lines'},
#   'T31': {'type': 'Device',
#    'start': 955,
#    'end': 966,
#    'text': 'in-dwelling ports'},
#   'T32': {'type': 'Scope',
#    'start': 787,
#    'end': 931,
#    'text': 'severe cardiac insufficiency patients taking Coumadin or other warfarin-containing agents with the exception of low dose warfarin (1 mg or less)'},
#   'T34': {'type': 'Condition',
#    'start': 1037,
#    'end': 1055,
#    'text': 'another malignancy'},
#   'T35': {'type': 'Temporal',
#    'start': 1056,
#    'end': 1091,
#    'text': 'within 5 years prior to study entry'},
#   'T36': {'type': 'Scope',
#    'start': 832,
#    'end': 876,
#    'text': 'Coumadin or other warfarin-containing agents'},
#   'T37': {'type': 'Condition',
#    'start': 1118,
#    'end': 1142,
#    'text': 'non-melanoma skin cancer'},
#   'T38': {'type': 'Qualifier',
#    'start': 1099,
#    'end': 1117,
#    'text': 'curatively treated'},
#   'T39': {'type': 'Condition',
#    'start': 1144,
#    'end': 1159,
#    'text': 'prostate cancer'},
#   'T40': {'type': 'Condition',
#    'start': 1164,
#    'end': 1187,
#    'text': 'cervical cancer in situ'},
#   'T41': {'type': 'Scope',
#    'start': 1118,
#    'end': 1187,
#    'text': 'non-melanoma skin cancer, prostate cancer, or cervical cancer in situ'},
#   'T42': {'type': 'Observation',
#    'start': 1026,
#    'end': 1036,
#    'text': 'history of'},
#   'T43': {'type': 'Condition',
#    'start': 1240,
#    'end': 1262,
#    'text': 'uncontrolled infection'},
#   'T44': {'type': 'Condition', 'start': 1273, 'end': 1281, 'text': 'abcesses'},
#   'T45': {'type': 'Condition', 'start': 1285, 'end': 1293, 'text': 'fistulae'},
#   'T46': {'type': 'Scope',
#    'start': 1273,
#    'end': 1293,
#    'text': 'abcesses or fistulae'},
#   'T47': {'type': 'Qualifier', 'start': 1203, 'end': 1209, 'text': 'active'},
#   'T48': {'type': 'Qualifier',
#    'start': 1213,
#    'end': 1222,
#    'text': 'suspected'},
#   'T49': {'type': 'Qualifier', 'start': 1223, 'end': 1228, 'text': 'acute'},
#   'T50': {'type': 'Qualifier', 'start': 1232, 'end': 1239, 'text': 'chronic'},
#   'T51': {'type': 'Scope',
#    'start': 1203,
#    'end': 1239,
#    'text': 'active or suspected acute or chronic'},
#   'T52': {'type': 'Condition',
#    'start': 1322,
#    'end': 1341,
#    'text': 'psychiatric illness'},
#   'T53': {'type': 'Condition',
#    'start': 1311,
#    'end': 1318,
#    'text': 'medical illness'},
#   'T54': {'type': 'Observation',
#    'start': 1353,
#    'end': 1367,
#    'text': 'preclude study'},
#   'T55': {'type': 'Observation',
#    'start': 1371,
#    'end': 1387,
#    'text': 'informed consent'},
#   'T56': {'type': 'Observation',
#    'start': 1406,
#    'end': 1439,
#    'text': 'noncompliance to medical regimens'},
#   'T57': {'type': 'Observation',
#    'start': 1443,
#    'end': 1452,
#    'text': 'inability to return for all scheduled visits'},
#   'T58': {'type': 'Observation',
#    'start': 1456,
#    'end': 1503,
#    'text': 'unwillingness to return for all scheduled visit'},
#   'T59': {'type': 'Scope',
#    'start': 1347,
#    'end': 1504,
#    'text': 'would preclude study or informed consent and/or history of noncompliance to medical regimens or inability or unwillingness to return for all scheduled visits'},
#   'T60': {'type': 'Condition', 'start': 1506, 'end': 1510, 'text': 'HIV+'},
#   'T61': {'type': 'Measurement', 'start': 1506, 'end': 1509, 'text': 'HIV'},
#   'T62': {'type': 'Value', 'start': 1509, 'end': 1510, 'text': '+'},
#   'T63': {'type': 'Condition', 'start': 1521, 'end': 1529, 'text': 'Pregnant'},
#   'T64': {'type': 'Condition',
#    'start': 1533,
#    'end': 1542,
#    'text': 'lactating'},
#   'T65': {'type': 'Qualifier', 'start': 14, 'end': 25, 'text': 'symptomatic'},
#   'T3': {'type': 'Negation',
#    'start': 877,
#    'end': 898,
#    'text': 'with the exception of'},
#   'T66': {'type': 'Negation', 'start': 1092, 'end': 1098, 'text': 'except'},
#   'T33': {'type': 'Non-representable',
#    'start': 983,
#    'end': 1025,
#    'text': 'Patients taking any experimental therapies'},
#   'T67': {'type': 'Temporal', 'start': 652, 'end': 662, 'text': 'previously'},
#   'T68': {'type': 'Temporal', 'start': 573, 'end': 583, 'text': 'previously'},
#   'T69': {'type': 'Multiplier',
#    'start': 382,
#    'end': 416,
#    'text': 'only site(s) of measurable disease'},
#   'T70': {'type': 'Negation', 'start': 110, 'end': 116, 'text': 'unless'}},
#  'relationships': [{'id': 'R1',
#    'type': 'Has_temporal',
#    'arg1': 'T6',
#    'arg2': 'T7'},
#   {'id': 'R3', 'type': 'AND', 'arg1': '238-248'},
#   {'id': 'R4', 'type': 'AND', 'arg1': '238-265'},
#   {'id': 'R5', 'type': 'Has_context', 'arg1': 'T15', 'arg2': 'T16'},
#   {'id': 'R6', 'type': 'Has_scope', 'arg1': 'T13', 'arg2': 'T17'},
#   {'id': 'R7', 'type': 'AND', 'arg1': '731-750'},
#   {'id': 'R8', 'type': 'Has_value', 'arg1': 'T22', 'arg2': 'T23'},
#   {'id': 'R9', 'type': 'AND', 'arg1': '787-815'},
#   {'id': 'R10', 'type': 'Has_qualifier', 'arg1': 'T28', 'arg2': 'T27'},
#   {'id': 'R11', 'type': 'AND', 'arg1': '787-931'},
#   {'id': 'R13', 'type': 'Has_temporal', 'arg1': 'T34', 'arg2': 'T35'},
#   {'id': 'R14', 'type': 'Has_qualifier', 'arg1': 'T41', 'arg2': 'T38'},
#   {'id': 'R16', 'type': 'Has_temporal', 'arg1': 'T34', 'arg2': 'T42'},
#   {'id': 'R17', 'type': 'Subsumes', 'arg1': 'T43', 'arg2': 'T46'},
#   {'id': 'R18', 'type': 'Has_scope', 'arg1': 'T43', 'arg2': 'T51'},
#   {'id': 'R19', 'type': 'Has_scope', 'arg1': 'T53', 'arg2': 'T59'},
#   {'id': 'R2', 'type': 'AND', 'arg1': '92-108'},
#   {'id': 'R20', 'type': 'Has_value', 'arg1': 'T61', 'arg2': 'T62'},
#   {'id': 'R21', 'type': 'multi', 'arg1': 'T60', 'arg2': 'T61'},
#   {'id': 'R22', 'type': 'Has_qualifier', 'arg1': 'T1', 'arg2': 'T65'},
#   {'id': 'R23', 'type': 'Has_qualifier', 'arg1': 'T2', 'arg2': 'T65'},
#   {'id': 'R12', 'type': 'Has_negation', 'arg1': '877-898'},
#   {'id': 'R24', 'type': 'AND', 'arg1': '832-876'},
#   {'id': 'R15', 'type': 'Has_negation', 'arg1': '1092-1098'},
#   {'id': 'R25', 'type': 'Has_scope', 'arg1': 'T34', 'arg2': 'T41'},
#   {'id': 'R26', 'type': 'Has_temporal', 'arg1': 'T19', 'arg2': 'T67'},
#   {'id': 'R27', 'type': 'Has_temporal', 'arg1': 'T18', 'arg2': 'T68'},
#   {'id': 'R28', 'type': 'AND', 'arg1': '359-374'},
#   {'id': 'R29', 'type': 'Has_negation', 'arg1': '110-116'}],
#  'scope_or': [{'type': 'OR', 'entities': ['26-40']},
#   {'type': 'OR', 'entities': ['144-151']},
#   {'type': 'OR', 'entities': ['465-489']},
#   {'type': 'OR', 'entities': ['706-727']},
#   {'type': 'OR', 'entities': ['832-840']},
#   {'type': 'OR', 'entities': ['899-907']},
#   {'type': 'OR', 'entities': ['955-972']},
#   {'type': 'OR', 'entities': ['1118-1142', '1144-1159']},
#   {'type': 'OR', 'entities': ['1273-1281']},
#   {'type': 'OR', 'entities': ['1203-1209']},
#   {'type': 'OR', 'entities': ['1223-1228']},
#   {'type': 'OR', 'entities': ['1311-1318']},
#   {'type': 'OR',
#    'entities': ['1353-1367', '1371-1387', '1406-1439', '1443-1452']},
#   {'type': 'OR', 'entities': ['1521-1529']}]}

# %%
def insert_character_at_offsets(file_path, data):
    all_offsets = []
    label_for_offsets = {}
    inserted_positions = set()  # Zum Speichern bereits eingefügter Positionen

    # Verarbeiten von AND und Has_negation Beziehungen
    for relationship in data['relationships']:
        arg1_offset = f"{relationship['arg1']}"
        if relationship['type'] == "AND":
            label_for_offsets[arg1_offset] = ' [AND]'  # Nach dem Offset
            all_offsets.append(arg1_offset)
        elif relationship['type'] == "Has_negation":
            start_pos = int(arg1_offset.split('-')[0])  # Beginn des Offsets für Negation
            label_for_offsets[arg1_offset] = '[NOT] '  # Vor dem Offset
            all_offsets.append(arg1_offset)
            inserted_positions.add(start_pos)  # Markiere den Startpunkt für Negation

    # Verarbeiten von OR Gruppen
    for or_group in data['scope_or']:
        for offset in or_group['entities']:
            label_for_offsets[offset] = ' [OR]'  # Nach jedem Offset in der Gruppe
            all_offsets.append(offset)

    # Datei lesen
    with open(file_path, 'r') as file:
        content = file.read()

    # Sortieren der Offsets in umgekehrter Reihenfolge, um die Positionen korrekt zu aktualisieren
    sorted_offsets = sorted([(int(offset.split('-')[1]), offset) for offset in all_offsets], reverse=True)

    # Einfügen der Labels in den Text
    for end_pos, offset in sorted_offsets:
        if end_pos not in inserted_positions:  # Überprüfe, ob das Tag bereits eingefügt wurde
            label = label_for_offsets[offset]
            insert_pos = int(offset.split('-')[0]) if label.strip() == '[NOT]' else end_pos
            content = content[:insert_pos] + label + content[insert_pos:]
            inserted_positions.add(insert_pos)

    # Ausgabe in eine neue Datei schreiben
    with open("output_with_tags.txt", 'w') as file:
        file.write(content)

    return content

# %%
content = insert_character_at_offsets(ec_file, offsets)

# %%
content
# Out:
# 'Patients with symptomatic CNS metastases [OR] or leptomeningeal involvement \nPatients with known brain metastases [AND], [NOT] unless these metastases have been treated [OR] and/or have been stable for at least six months prior to study start. Subjects with a history of [AND] brain metastases [AND] must have a head CT with contrast to document either response or progression. \nPatients with bone metastases [AND] as the only site(s) of measurable disease \nPatients with hepatic artery chemoembolization within the last 6 months [OR] (one month if there are other sites of measurable disease) \nPatients who have been previously treated with radioactive directed therapies \nPatients who have been previously treated with epothilone \nPatients with any peripheral neuropathy [OR] or unresolved diarrhea [AND] greater than Grade 1 \nPatients with severe cardiac insufficiency [AND] patients taking Coumadin [OR] or other warfarin-containing agents [AND] [NOT] with the exception of low dose [OR] warfarin (1 mg or less) [AND] for the maintenance of in-dwelling lines [OR] or ports \nPatients taking any experimental therapies history of another malignancy within 5 years prior to study entry [NOT] except curatively treated non-melanoma skin cancer [OR], prostate cancer [OR], or cervical cancer in situ \nPatients with active [OR] or suspected acute [OR] or chronic uncontrolled infection including abcesses [OR] or fistulae \nPatients with a medical [OR] or psychiatric illness that would preclude study [OR] or informed consent [OR] and/or history of noncompliance to medical regimens [OR] or inability [OR] or unwillingness to return for all scheduled visits \nHIV+ patients \nPregnant [OR] or lactating females.       \n    \n'

# %%
def ec_to_json(text, output_file:str):
    sentences = text.strip().split('\n')
    sentences = [sentence.strip() for sentence in sentences if sentence.strip()]
    data = {f"EC{i+1}": sentence for i, sentence in enumerate(sentences)}
    json_output = json.dumps(data, indent=2, ensure_ascii=False)
    with open(output_file, "w", encoding="utf-8") as file:
        file.write(json_output)
    return json_output

# %%
data = ec_to_json(content, output_file="parsed_1.json")

# %%
def parse_to_structured_json(input_json):
    data = json.loads(input_json)

    def process_section(text, path):
        # Segmentierung des Textes basierend auf den Operatoren [OR], [AND], [NOT]
        segments = re.split(r'(\[OR\]|\[AND\]|\[NOT\])', text)
        #print(segments)  # Debug-Ausgabe der Segmente
        elements = []
        operators = []

        for segment in segments:
            segment = segment.strip()
            if segment in ['[OR]', '[AND]', '[NOT]']:
                operators.append(segment.strip('[]'))  # Sammeln der Operatoren ohne Klammern
            else:
                # Entfernung aller übriggebliebenen Tags und Streichen von Leerzeichen
                clean_segment = re.sub(r'\[\w+\]', '', segment).strip()
                if clean_segment:
                    elements.append(clean_segment)

        # Entscheidung, wie die Struktur aufgebaut sein soll, basierend auf der Anzahl der Elemente und Operatoren
        if len(elements) == 1 and not operators:
            return elements[0]  # Ein einzelnes Element ohne Operatoren
        else:
            structure = {}
            for index, element in enumerate(elements, 1):
                structure[f"{path}.{index}"] = element
            if operators:
                structure['operators'] = operators  # Speichern aller Operatoren unter einem eigenen Schlüssel
            return structure

    result_structure = {"EC": {}}
    index = 1
    for key, value in data.items():
        section_path = f"EC{index}"
        result_structure["EC"][section_path] = process_section(value, section_path)
        index += 1

    return json.dumps(result_structure, indent=4, ensure_ascii=False)

# %%
parsed_data = parse_to_structured_json(data)
print(parsed_data)
save_json_to_file(parsed_data, 'parsed_2.json')
# Out:
# ['Patients with symptomatic CNS metastases ', '[OR]', ' or leptomeningeal involvement']
# ['Patients with known brain metastases ', '[AND]', ', ', '[NOT]', ' unless these metastases have been treated ', '[OR]', ' and/or have been stable for at least six months prior to study start. Subjects with a history of ', '[AND]', ' brain metastases ', '[AND]', ' must have a head CT with contrast to document either response or progression.']
# ['Patients with bone metastases ', '[AND]', ' as the only site(s) of measurable disease']
# ['Patients with hepatic artery chemoembolization within the last 6 months ', '[OR]', ' (one month if there are other sites of measurable disease)']
# ['Patients who have been previously treated with radioactive directed therapies']
# ['Patients who have been previously treated with epothilone']
# ['Patients with any peripheral neuropathy ', '[OR]', ' or unresolved diarrhea ', '[AND]', ' greater than Grade 1']
# ['Patients with severe cardiac insufficiency ', '[AND]', ' patients taking Coumadin ', '[OR]', ' or other warfarin-containing agents ', '[AND]', ' ', '[NOT]', ' with the exception of low dose ', '[OR]', ' warfarin (1 mg or less) ', '[AND]', ' for the maintenance of in-dwelling lines ', '[OR]', ' or ports']
# ['Patients taking any experimental therapies history of another malignancy within 5 years prior to study entry ', '[NOT]', ' except curatively treated non-melanoma skin cancer ', '[OR]', ', prostate cancer ', '[OR]', ', or cervical cancer in situ']
# ['Patients with active ', '[OR]', ' or suspected acute ', '[OR]', ' or chronic uncontrolled infection including abcesses ', '[OR]', ' or fistulae']
# ['Patients with a medical ', '[OR]', ' or psychiatric illness that would preclude study ', '[OR]', ' or informed consent ', '[OR]', ' and/or history of noncompliance to medical regimens ', '[OR]', ' or inability ', '[OR]', ' or unwillingness to return for all scheduled visits']
# ['HIV+ patients']
# ['Pregnant ', '[OR]', ' or lactating females.']
# {
#     "EC": {
#         "EC1": {
#             "EC1.1": "Patients with symptomatic CNS metastases",
#             "EC1.2": "or leptomeningeal involvement",
#             "operators": [
#                 "OR"
#             ]
#         },
#         "EC2": {
#             "EC2.1": "Patients with known brain metastases",
#             "EC2.2": ",",
#             "EC2.3": "unless these metastases have been treated",
#             "EC2.4": "and/or have been stable for at least six months prior to study start. Subjects with a history of",
#             "EC2.5": "brain metastases",
#             "EC2.6": "must have a head CT with contrast to document either response or progression.",
#             "operators": [
#                 "AND",
#                 "NOT",
#                 "OR",
#                 "AND",
#                 "AND"
#             ]
#         },
#         "EC3": {
#             "EC3.1": "Patients with bone metastases",
#             "EC3.2": "as the only site(s) of measurable disease",
#             "operators": [
#                 "AND"
#             ]
#         },
#         "EC4": {
#             "EC4.1": "Patients with hepatic artery chemoembolization within the last 6 months",
#             "EC4.2": "(one month if there are other sites of measurable disease)",
#             "operators": [
#                 "OR"
#             ]
#         },
#         "EC5": "Patients who have been previously treated with radioactive directed therapies",
#         "EC6": "Patients who have been previously treated with epothilone",
#         "EC7": {
#             "EC7.1": "Patients with any peripheral neuropathy",
#             "EC7.2": "or unresolved diarrhea",
#             "EC7.3": "greater than Grade 1",
#             "operators": [
#                 "OR",
#                 "AND"
#             ]
#         },
#         "EC8": {
#             "EC8.1": "Patients with severe cardiac insufficiency",
#             "EC8.2": "patients taking Coumadin",
#             "EC8.3": "or other warfarin-containing agents",
#             "EC8.4": "with the exception of low dose",
#             "EC8.5": "warfarin (1 mg or less)",
#             "EC8.6": "for the maintenance of in-dwelling lines",
#             "EC8.7": "or ports",
#             "operators": [
#                 "AND",
#                 "OR",
#                 "AND",
#                 "NOT",
#                 "OR",
#                 "AND",
#                 "OR"
#             ]
#         },
#         "EC9": {
#             "EC9.1": "Patients taking any experimental therapies history of another malignancy within 5 years prior to study entry",
#             "EC9.2": "except curatively treated non-melanoma skin cancer",
#             "EC9.3": ", prostate cancer",
#             "EC9.4": ", or cervical cancer in situ",
#             "operators": [
#                 "NOT",
#                 "OR",
#                 "OR"
#             ]
#         },
#         "EC10": {
#             "EC10.1": "Patients with active",
#             "EC10.2": "or suspected acute",
#             "EC10.3": "or chronic uncontrolled infection including abcesses",
#             "EC10.4": "or fistulae",
#             "operators": [
#                 "OR",
#                 "OR",
#                 "OR"
#             ]
#         },
#         "EC11": {
#             "EC11.1": "Patients with a medical",
#             "EC11.2": "or psychiatric illness that would preclude study",
#             "EC11.3": "or informed consent",
#             "EC11.4": "and/or history of noncompliance to medical regimens",
#             "EC11.5": "or inability",
#             "EC11.6": "or unwillingness to return for all scheduled visits",
#             "operators": [
#                 "OR",
#                 "OR",
#                 "OR",
#                 "OR",
#                 "OR"
#             ]
#         },
#         "EC12": "HIV+ patients",
#         "EC13": {
#             "EC13.1": "Pregnant",
#             "EC13.2": "or lactating females.",
#             "operators": [
#                 "OR"
#             ]
#         }
#     }
# }
