# %%
from datasets import load_dataset

dataset = load_dataset("bigbio/n2c2_2018_track1")
# Out:
# C:\Users\e-aut\anaconda3\lib\site-packages\datasets\load.py:1486: FutureWarning: The repository for bigbio/n2c2_2018_track1 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/bigbio/n2c2_2018_track1
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8368\3788494098.py in <module>
#       1 from datasets import load_dataset
#       2
# ----> 3 dataset = load_dataset("bigbio/n2c2_2018_track1")
#
# ...

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8368\751301708.py in <module>
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined
