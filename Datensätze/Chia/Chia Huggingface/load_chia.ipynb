# %%
from datasets import load_dataset

dataset = load_dataset("bigbio/chia")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~\anaconda3\envs\pythonProject\Lib\site-packages\datasets\builder.py:1676, in GeneratorBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, split_info, check_duplicate_keys, job_id)
#    1675 _time = time.time()
# -> 1676 for key, record in generator:
#    1677     if max_shard_size is not None and writer._num_bytes > max_shard_size:
#
# File ~\.cache\huggingface\modules\datasets_modules\datasets\bigbio--chia\7063f03b3e3f9524c13d81a9caffb4ca1c85c15c76122eb645b752de7202df60\chia.py:253, in ChiaDataset._generate_examples(self, file_paths)
#     251     continue
# --> 253 brat_example = parse_brat_file(file, [".ann"])
#     254 source_example = self._to_source_example(
#     255     file, brat_example, fix_offsets
#     256 )
#
# ...

# %%
dataset.save_to_disk("chia")
