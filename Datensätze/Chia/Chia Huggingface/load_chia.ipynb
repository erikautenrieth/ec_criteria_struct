# %%
from datasets import load_dataset

dataset = load_dataset("bigbio/chia")

# https://huggingface.co/datasets/bigbio/chia/viewer
# Out:
# /home/erik/anaconda3/envs/Stock-Prediction/lib/python3.8/site-packages/datasets/load.py:1461: FutureWarning: The repository for bigbio/chia contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/bigbio/chia
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset.save_to_disk("test.hf")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'document_id', 'text', 'text_type', 'entities', 'relations'],
#         num_rows: 2000
#     })
# })
